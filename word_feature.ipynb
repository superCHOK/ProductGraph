# %%
import csv
import pandas as pd

# %%
df = pd.read_csv('./Data/536-585.csv')

# %%
df
# Out:
#       Unnamed: 0  Unnamed: 1  Unnamed: 2 category_536_0  \
# 0              0           0           0             ไฟ
# 1              0           1           0      ของตกแต่ง
# 2              1           0           0         หลอดไฟ
# 3              2           0           0  หลอดแบล็คไลท์
# 4              3           0           0             ไฟ
# ...          ...         ...         ...            ...
# 2436          19          45           0            NaN
# 2437          19          46           0            NaN
# 2438          19          47           0            NaN
# 2439          19          48           0            NaN
# 2440          19          49           0            NaN
#
#                                    category_536_1  \
# 0                                              ไฟ
# 1                                       ของตกแต่ง
# 2                                          หลอดไฟ
# 3                                   หลอดแบล็คไลท์
# 4     พับแอลอีดีมุมกว้างรูปฟุตบอลเคสระบายความร้อน
# ...                                           ...
# 2436                                          NaN
# 2437                                          NaN
# 2438                                          NaN
# 2439                                          NaN
# 2440                                          NaN
#
#                         category_536_2 category_536_4     category_536_5  \
# 0                                   ไฟ             ไฟ                 ไฟ
# 1                                  LED      ของตกแต่ง          ของตกแต่ง
# 2     ปรับกันกระแทกเปลี่ยนแบบอัตโนมัติ         หลอดไฟ             หลอดไฟ
# 3                                   ST  หลอดแบล็คไลท์      หลอดแบล็คไลท์
# 4                             พร้อมส่ง          XJING  น่ารักฤดูใบไม้ผลิ
# ...                                ...            ...                ...
# 2436                               NaN            NaN                NaN
# 2437                               NaN            NaN                NaN
# 2438                               NaN            NaN                NaN
# 2439                               NaN            NaN                NaN
# 2440                               NaN            NaN                NaN
#
#      category_536_6    category_536_7  ...  category_585_270  \
# 0                ไฟ                ไฟ  ...  เครื่ื่ื่องเขียน
# 1         ของตกแต่ง         ของตกแต่ง  ...          งานฝีมือ
# 2            หลอดไฟ            หลอดไฟ  ...            กระดาษ
# 3     หลอดแบล็คไลท์     หลอดแบล็คไลท์  ...   ฉลากกำกับสินค้า
# 4                ไฟ  คริสต์มาสตะเกียง  ...            Kesoto
# ...             ...               ...  ...               ...
# 2436            NaN               NaN  ...               NaN
# 2437            NaN               NaN  ...               NaN
# 2438            NaN               NaN  ...               NaN
# 2439            NaN               NaN  ...               NaN
# 2440            NaN               NaN  ...               NaN
#
#       category_585_271  category_585_272  category_585_273  category_585_274  \
# 0     เครื่ื่ื่องเขียน  เครื่ื่ื่องเขียน  เครื่ื่ื่องเขียน  เครื่ื่ื่องเขียน
# 1             งานฝีมือ          งานฝีมือ          งานฝีมือ          งานฝีมือ
# 2               กระดาษ            กระดาษ            กระดาษ            กระดาษ
# 3      ฉลากกำกับสินค้า   ฉลากกำกับสินค้า   ฉลากกำกับสินค้า   ฉลากกำกับสินค้า
# 4                    W               100            Kesoto             XINZE
# ...                ...               ...               ...               ...
# 2436               NaN               NaN               NaN               NaN
# 2437               NaN               NaN               NaN               NaN
# 2438               NaN               NaN               NaN               NaN
# 2439               NaN               NaN               NaN               NaN
# 2440               NaN               NaN               NaN               NaN
#
#       category_585_275  category_585_276  category_585_277  category_585_278  \
# 0     เครื่ื่ื่องเขียน  เครื่ื่ื่องเขียน  เครื่ื่ื่องเขียน  เครื่ื่ื่องเขียน
# 1             งานฝีมือ          งานฝีมือ          งานฝีมือ          งานฝีมือ
# 2               กระดาษ            กระดาษ            กระดาษ            กระดาษ
# 3      ฉลากกำกับสินค้า   ฉลากกำกับสินค้า   ฉลากกำกับสินค้า   ฉลากกำกับสินค้า
# 4                  PVC            Kesoto               120            Kesoto
# ...                ...               ...               ...               ...
# 2436               NaN               NaN               NaN               NaN
# 2437               NaN               NaN               NaN               NaN
# 2438               NaN               NaN               NaN               NaN
# 2439               NaN               NaN               NaN               NaN
# 2440               NaN               NaN               NaN               NaN
#
#       category_585_279
# 0     เครื่ื่ื่องเขียน
# 1             งานฝีมือ
# 2               กระดาษ
# 3      ฉลากกำกับสินค้า
# 4                    2
# ...                ...
# 2436               NaN
# 2437               NaN
# 2438               NaN
# 2439               NaN
# 2440               NaN
#
# [2441 rows x 9959 columns]

# %%
# Process data such as drop NaN and drop column that do not use
# Drop column and row that equal to NaN
df = df.dropna(axis=1, how='all')
df = df.dropna(axis=0, how='all')

# Fill NaN with "0"
df = df.fillna(0)

# Drop a column that is index
df = df.drop(columns=['Unnamed: 0','Unnamed: 1','Unnamed: 2'])

# %%
df
# Out:
#      category_536_0                               category_536_1  \
# 0                ไฟ                                           ไฟ
# 1         ของตกแต่ง                                    ของตกแต่ง
# 2            หลอดไฟ                                       หลอดไฟ
# 3     หลอดแบล็คไลท์                                หลอดแบล็คไลท์
# 4                ไฟ  พับแอลอีดีมุมกว้างรูปฟุตบอลเคสระบายความร้อน
# ...             ...                                          ...
# 2436              0                                            0
# 2437              0                                            0
# 2438              0                                            0
# 2439              0                                            0
# 2440              0                                            0
#
#                         category_536_2 category_536_4     category_536_5  \
# 0                                   ไฟ             ไฟ                 ไฟ
# 1                                  LED      ของตกแต่ง          ของตกแต่ง
# 2     ปรับกันกระแทกเปลี่ยนแบบอัตโนมัติ         หลอดไฟ             หลอดไฟ
# 3                                   ST  หลอดแบล็คไลท์      หลอดแบล็คไลท์
# 4                             พร้อมส่ง          XJING  น่ารักฤดูใบไม้ผลิ
# ...                                ...            ...                ...
# 2436                                 0              0                  0
# 2437                                 0              0                  0
# 2438                                 0              0                  0
# 2439                                 0              0                  0
# 2440                                 0              0                  0
#
#      category_536_6    category_536_7 category_536_8 category_536_9  \
# 0                ไฟ                ไฟ             ไฟ             ไฟ
# 1         ของตกแต่ง         ของตกแต่ง      ของตกแต่ง      ของตกแต่ง
# 2            หลอดไฟ            หลอดไฟ         หลอดไฟ         หลอดไฟ
# 3     หลอดแบล็คไลท์     หลอดแบล็คไลท์  หลอดแบล็คไลท์  หลอดแบล็คไลท์
# 4                ไฟ  คริสต์มาสตะเกียง             ไฟ             XQ
# ...             ...               ...            ...            ...
# 2436              0                 0              0              0
# 2437              0                 0              0              0
# 2438              0                 0              0              0
# 2439              0                 0              0              0
# 2440              0                 0              0              0
#
#      category_536_10  ...  category_585_270  category_585_271  \
# 0                 ไฟ  ...  เครื่ื่ื่องเขียน  เครื่ื่ื่องเขียน
# 1          ของตกแต่ง  ...          งานฝีมือ          งานฝีมือ
# 2             หลอดไฟ  ...            กระดาษ            กระดาษ
# 3      หลอดแบล็คไลท์  ...   ฉลากกำกับสินค้า   ฉลากกำกับสินค้า
# 4                BES  ...            Kesoto                 W
# ...              ...  ...               ...               ...
# 2436               0  ...                 0                 0
# 2437               0  ...                 0                 0
# 2438               0  ...                 0                 0
# 2439               0  ...                 0                 0
# 2440               0  ...                 0                 0
#
#       category_585_272  category_585_273  category_585_274  category_585_275  \
# 0     เครื่ื่ื่องเขียน  เครื่ื่ื่องเขียน  เครื่ื่ื่องเขียน  เครื่ื่ื่องเขียน
# 1             งานฝีมือ          งานฝีมือ          งานฝีมือ          งานฝีมือ
# 2               กระดาษ            กระดาษ            กระดาษ            กระดาษ
# 3      ฉลากกำกับสินค้า   ฉลากกำกับสินค้า   ฉลากกำกับสินค้า   ฉลากกำกับสินค้า
# 4                  100            Kesoto             XINZE               PVC
# ...                ...               ...               ...               ...
# 2436                 0                 0                 0                 0
# 2437                 0                 0                 0                 0
# 2438                 0                 0                 0                 0
# 2439                 0                 0                 0                 0
# 2440                 0                 0                 0                 0
#
#       category_585_276  category_585_277  category_585_278  category_585_279
# 0     เครื่ื่ื่องเขียน  เครื่ื่ื่องเขียน  เครื่ื่ื่องเขียน  เครื่ื่ื่องเขียน
# 1             งานฝีมือ          งานฝีมือ          งานฝีมือ          งานฝีมือ
# 2               กระดาษ            กระดาษ            กระดาษ            กระดาษ
# 3      ฉลากกำกับสินค้า   ฉลากกำกับสินค้า   ฉลากกำกับสินค้า   ฉลากกำกับสินค้า
# 4               Kesoto               120            Kesoto                 2
# ...                ...               ...               ...               ...
# 2436                 0                 0                 0                 0
# 2437                 0                 0                 0                 0
# 2438                 0                 0                 0                 0
# 2439                 0                 0                 0                 0
# 2440                 0                 0                 0                 0
#
# [2441 rows x 9956 columns]
