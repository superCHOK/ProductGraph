# %%
# import library
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import pythainlp
import pythaispell
from gingerit.gingerit import GingerIt
from langdetect import detect
import nltk
from keras import *
from keras.utils import to_categorical
from pythainlp import word_tokenize
from pythainlp.corpus import thai_stopwords
from pythainlp.corpus import wordnet
from nltk.stem.porter import PorterStemmer
from nltk.corpus import words
from stop_words import get_stop_words
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import confusion_matrix, classification_report
from pythainlp.corpus.common import thai_words
from pythainlp.tokenize import dict_trie
from pythainlp.tag.named_entity import ThaiNameTagger
from sklearn.model_selection import train_test_split

from sklearn.model_selection import train_test_split

# %%
# import data from Excel
df = pd.read_excel('./All_data.xlsx',sheet_name=None)

# %%
df1 = df['Sheet1'].drop(columns='subCategory')
df2 = df['155-7500'].drop(columns='subCategory')
df3 = df['7501-15001'].drop(columns='subCategory')
df4 = df['Sheet3'].drop(columns='subCategory')
df_cat = df['Category']
df_cat
# Out:
#     id                        category
# 0    0          อุปกรณ์ อิเล็กทรอนิกส์
# 1    1     อุปกรณ์เสริม อิเล็กทรอนิกส์
# 2    2   ทีวีและเครื่องใช้ ไฟฟ้าในบ้าน
# 3    3                สุขภาพและความงาม
# 4    4             เด็กอ่อน และของเล่น
# 5    5  ซูเปอร์มาร์เก็ต และสัตว์เลี้ยง
# 6    6                บ้านและไลฟ์สไตล์
# 7    7                   แฟชั่นผู้หญิง
# 8    8                    แฟชั่นผู้ชาย
# 9    9                   เครื่องประดับ
# 10  10              กีฬาและ การเดินทาง
# 11  11              ยานยนต์ และอุปกรณ์

# %%
df = pd.concat([df1, df2,df3,df4], ignore_index=True)

# %%
df
# Out:
#         Category                                        Description
# 0              0                                        Smartphones
# 1              0              SAMSUNG Galaxy A20s *ประกันศูนย์ 1ปี*
# 2              0           อุปกรณ์ในกล่อง หัวชาร์จ / สาย USB Type-C
# 3              0  A20s ไม่ได้แถม หูฟัง / ฟิล์ม / เคส มาจากทางSAM...
# 4              0  ทางร้านต้องแกะกล่องสินค้าเพื่อนำใบประกันส่งบริ...
# ...          ...                                                ...
# 461043        11                                           หมวกโม่ง
# 461044        11                              หมวก MOTOGP 46 YAMAHA
# 461045        11          หมวก MOTOGP 46 YAMAHA น้ำเงินราคา 590 บาท
# 461046        11                                      แบรนด์ Yamaha
# 461047        11                         SKU 262862108_TH-405416049
#
# [461048 rows x 2 columns]

# %%
i=0
x_train = pd.DataFrame(columns=['Category', 'Description'])
x_val = pd.DataFrame(columns=['Category', 'Description'])
x_test = pd.DataFrame(columns=['Category', 'Description'])

while(i<12):
    df0 = df[df['Category']==i]
    X_train, X_test = train_test_split(df0, test_size=0.2, random_state=47,shuffle=False)
    x_train = pd.concat([x_train,X_train],ignore_index=True)
    x_test = pd.concat([x_test,X_test],ignore_index=True)
    i = i+1

i=0
while(i<12):
    df0 = x_train[x_train['Category']==i]
    X_train, X_val = train_test_split(df0, test_size=0.1, random_state=47,shuffle=False)
    x_train = pd.concat([x_train,X_train],ignore_index=True)
    x_val = pd.concat([x_val,X_val],ignore_index=True)
    i = i+1

# %%
x_val
# Out:
#       Category                                        Description
# 0            0                                          รุ่น none
# 1            0                                กล้องถ่ายภาพและโดรน
# 2            0                       กล้องและระบบรักษาความปลอดภัย
# 3            0                                      Dummy Cameras
# 4            0  Betes Waterproof Outdoor Fake Camera Battery P...
# ...        ...                                                ...
# 36884       11                        วงล้อสีแดง D-MAX 1.2 ขอบ 17
# 36885       11   วงล้อ D-MAX วงล้อมอเตอร์ไซด์ ขนาด 1.2 ขอบ 17 ...
# 36886       11                                       แบรนด์ D-MAX
# 36887       11                         SKU 487918513_TH-876088973
# 36888       11                                         รุ่น D-MAX
#
# [36889 rows x 2 columns]

# %%
# training data
y_train = x_train['Category']
x_train = x_train['Description']

# test data
y_test = x_test['Category']
x_test = x_test['Description']

# validation data
y_val = x_val['Category']
x_val = x_val['Description']

# %%
type(x_train)
# Out:
# str

# %%
# custom dictionary
path_custom_dict = "./custom_dict.txt"

with open(path_custom_dict, 'r',encoding="utf8") as f:
    new_words = f.read().splitlines()
    
words = set(new_words).union(thai_words())
custom_dictionary = dict_trie(words)

# %%
import re
import string

# word correction for EN
#parser = GingerIt()

# download stopwords of TH and EN
nltk.download('words')
th_stop = tuple(thai_stopwords())
en_stop = tuple(get_stop_words('en'))
p_stemmer = PorterStemmer()

# clean the text
def clean_msg(msg): 
    
    # ลบ text ที่อยู่ใน []
    msg = re.sub(r'[<*●•►【】✨✈✅#?>]','', str(msg))
    #msg = re.sub(r'✅','',msg)
    # ลบ hashtag
    #msg = re.sub(r'#','',msg)
    #msg = re.findall(r"[\wก-๙]", str(msg))
    
    # Delete punctuation
    str_punc = string.punctuation.replace(".","")
    for c in str_punc:
        msg = re.sub(r'\{}'.format(c),'',str(msg))
    
    # ลบ separator เช่น \n \t
    msg = ' '.join(msg.split())
    
    return msg

# split to words from text
def split_word(text):
    words = word_tokenize(text,engine='newmm',custom_dict=custom_dictionary,keep_whitespace=False)

    # Remove stop words TH and EN
    words = [i for i in words if not i in th_stop and not i in en_stop]
    
    # รากศัพท์
    # EN
    #words = [p_stemmer.stem(i) for i in words]
    
    # TH
    tokens_temp=[]
    for i in words:
        w_syn = wordnet.synsets(i)
        if (len(w_syn)>0) and (len(w_syn[0].lemma_names('tha'))>0) and not (w_syn[0].lemma_names('tha')[0].isdigit()):
            #print(w_syn[0].lemma_names('tha'))
            if(w_syn[0].lemma_names('tha')[0]=='แบต'):
                tokens_temp.append(w_syn[0].lemma_names('tha')[1])
            #elif(w_syn[0].lemma_names('tha')[0].isdigit()):
                #tokens_temp.append(w_syn[0].lemma_names('tha')[2])
            else:
                tokens_temp.append(w_syn[0].lemma_names('tha')[0])
        else:
            tokens_temp.append(i)
    
    words = tokens_temp
    
    # delete whitespace
    #words = [i for i in words if not ' ' in i]

    return words
# Out:
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\super\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!

# %%
split_word(clean_msg("test test ๑1.2.222"))
# Out:
# ['test', 'test', '๑1.2.222']

# %%
# Clean the data
x_train = [clean_msg(text) for text in x_train]
x_test = [clean_msg(text) for text in x_test]
x_val = [clean_msg(text) for text in x_val]
print(x_val)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
# mark word to split
x_train_word = ['|'.join(split_word(txt)) for txt in x_train]
x_val_word = ['|'.join(split_word(txt)) for txt in x_val]

# %%
# define parameter for embedding layer
max_word = 90000
max_len = 30

# %%
from keras.preprocessing import text
from keras.preprocessing import sequence

# Define Tokenizer
tokenizer = text.Tokenizer(num_words=max_word,split='|') # split word with "|"
tokenizer.fit_on_texts(x_train_word)
tokenizer.word_index
# Out:
# {'การรับประกัน': 1,
#  'ชนิด': 2,
#  'แบรนด์': 3,
#  'sku': 4,
#  '1': 5,
#  'รุ่น': 6,
#  'th': 7,
#  'สำหรับ': 8,
#  '2': 9,
#  'อุปกรณ์': 10,
#  'สินค้า': 11,
#  'ไม่มี': 12,
#  '3': 13,
#  'น': 14,
#  'ประกัน': 15,
#  'ขนาด': 16,
#  'x': 17,
#  '5': 18,
#  'ชุด': 19,
#  'เด็ก': 20,
#  'รถ': 21,
#  'สี': 22,
#  'new': 23,
#  '4': 24,
#  'วัสดุ': 25,
#  'เกือก': 26,
#  'ทำ': 27,
#  'ปี': 28,
#  '6': 29,
#  'ตัว': 30,
#  'ผ้า': 31,
#  'กระเป๋า': 32,
#  'กีฬา': 33,
#  'ระยะเวลา': 34,
#  'ผู้หญิง': 35,
#  'เครื่อง': 36,
#  'ชาย': 37,
#  '0': 38,
#  'ผิว': 39,
#  '100': 40,
#  'สาย': 41,
#  'ซม': 42,
#  'ไฟ': 43,
#  'cm': 44,
#  'ใส่': 45,
#  '8': 46,
#  'นิ้ว': 47,
#  'ม': 48,
#  '00': 49,
#  'น้ำ': 50,
#  '฿': 51,
#  '10': 52,
#  'ชิ้น': 53,
#  'คุณภาพ': 54,
#  'no': 55,
#  '7': 56,
#  'ระบบ': 57,
#  'ใช้': 58,
#  'ก': 59,
#  'ทำความสะอาด': 60,
#  'brand': 61,
#  'เหมาะสำหรับ': 62,
#  'ป้องกัน': 63,
#  'เครื่องประดับ': 64,
#  'ข้างนอก': 65,
#  'กล่อง': 66,
#  'ดูแล': 67,
#  'เดิน': 68,
#  'เอ': 69,
#  'ผม': 70,
#  'เดือน': 71,
#  '12': 72,
#  'วัย': 73,
#  'นุ่ม': 74,
#  'กิจกรรม': 75,
#  'ดี': 76,
#  'ติด': 77,
#  'ลด': 78,
#  'หัด': 79,
#  'เกรด': 80,
#  'ดำ': 81,
#  'ออกแบบ': 82,
#  'เด็กอ่อน': 83,
#  '9': 84,
#  'ขนาดเล็ก': 85,
#  'ค้ำ': 86,
#  'เอ็ม': 87,
#  'ยาง': 88,
#  'แฟชั่น': 89,
#  '์': 90,
#  'รถถีบ': 91,
#  'เสริม': 92,
#  'ทนทาน': 93,
#  'วี': 94,
#  'mm': 95,
#  'w': 96,
#  'ล': 97,
#  'กันน้ำ': 98,
#  'ช่อง': 99,
#  'อาหาร': 100,
#  'model': 101,
#  'คอม': 102,
#  'จำนวน': 103,
#  'บ้าน': 104,
#  'พกพา': 105,
#  'แผ่น': 106,
#  'ร': 107,
#  'เตียง': 108,
#  'usb': 109,
#  'ฟรี': 110,
#  'สวม': 111,
#  'สะดวก': 112,
#  'รับประกัน': 113,
#  '30': 114,
#  'ค่า': 115,
#  'หนัง': 116,
#  'หัว': 117,
#  '20': 118,
#  'ตกแต่ง': 119,
#  'การใช้งาน': 120,
#  'หน้า': 121,
#  'เสื้อ': 122,
#  'ฝา': 123,
#  'g': 124,
#  'แบตเตอรี่': 125,
#  'ชั้น': 126,
#  '50': 127,
#  'เอส': 128,
#  'gb': 129,
#  'ล้อ': 130,
#  'ความงาม': 131,
#  'ชาร์จ': 132,
#  'ติดตั้ง': 133,
#  'กล้อง': 134,
#  'อร': 135,
#  'ไฟฟ้า': 136,
#  'แห้ง': 137,
#  'ml': 138,
#  'แว่นตา': 139,
#  'เบา': 140,
#  'คนขาย': 141,
#  'แข็งแรง': 142,
#  'อุปกรณ์ไฟฟ้า': 143,
#  'ขาว': 144,
#  'สไตล์': 145,
#  'ลาย': 146,
#  'ความร้อน': 147,
#  'หนา': 148,
#  'led': 149,
#  'ถุง': 150,
#  'ส': 151,
#  'นม': 152,
#  'ดู': 153,
#  'กรัม': 154,
#  'กรอง': 155,
#  'สาร': 156,
#  'พิเศษ': 157,
#  'รอง': 158,
#  'size': 159,
#  '15': 160,
#  'พลาสติก': 161,
#  'ทน': 162,
#  'น้ำมัน': 163,
#  'มล': 164,
#  'ง': 165,
#  'คู่': 166,
#  'กลิ่น': 167,
#  'ใช้ได้': 168,
#  'กฎ': 169,
#  'เสียง': 170,
#  'แสง': 171,
#  'ของเล่น': 172,
#  'ลูก': 173,
#  'รูปแบบ': 174,
#  'เลือก': 175,
#  'แพ็ค': 176,
#  'อายุ': 177,
#  'ควบคุม': 178,
#  '24': 179,
#  'เคส': 180,
#  'วีค': 181,
#  'มือถือ': 182,
#  'l': 183,
#  'คุณสมบัติ': 184,
#  'เนื้อ': 185,
#  'นอน': 186,
#  'c': 187,
#  'กระจก': 188,
#  'พื้น': 189,
#  '40': 190,
#  'น้ำยา': 191,
#  'ความจุ': 192,
#  'บำรุง': 193,
#  'รส': 194,
#  'ฝุ่น': 195,
#  'ภาพ': 196,
#  '60': 197,
#  'แนะนำ': 198,
#  'ไม่ต้อง': 199,
#  'พี': 200,
#  'อัตโนมัติ': 201,
#  'งาน': 202,
#  'เซฟ': 203,
#  'ร้าน': 204,
#  'สุขภาพ': 205,
#  'd': 206,
#  'ทารก': 207,
#  'ล้าง': 208,
#  'ฉีด': 209,
#  'ปลอดภัย': 210,
#  'ได้ดี': 211,
#  'ใบ': 212,
#  'แขน': 213,
#  'ชอบ': 214,
#  'กางเกง': 215,
#  'ค': 216,
#  'เคลือบ': 217,
#  '16': 218,
#  'ออกกำลังกาย': 219,
#  'กาล': 220,
#  'ของแท้': 221,
#  'สแตนเลส': 222,
#  'พับ': 223,
#  'แถม': 224,
#  'วัตต์': 225,
#  'อุณหภูมิ': 226,
#  'ที': 227,
#  'ตัด': 228,
#  'ขวด': 229,
#  'เฟอร์นิเจอร์': 230,
#  'คอ': 231,
#  'ทีวี': 232,
#  'ขนาดใหญ่': 233,
#  'มม': 234,
#  'อาบน้ำ': 235,
#  'จัดเก็บ': 236,
#  'มาตรฐาน': 237,
#  'ขา': 238,
#  'ถอด': 239,
#  'เหล็ก': 240,
#  'นั่ง': 241,
#  'ซัก': 242,
#  'เย็น': 243,
#  'สวยงาม': 244,
#  'วาง': 245,
#  'ละเอียด': 246,
#  '25': 247,
#  'เบาะ': 248,
#  'แรง': 249,
#  'หญิง': 250,
#  'ผสม': 251,
#  'เล่น': 252,
#  'อากาศ': 253,
#  'พื้นที่': 254,
#  'ใส': 255,
#  'เลนส์': 256,
#  'มือ': 257,
#  'material': 258,
#  'อยาก': 259,
#  'วิ่ง': 260,
#  'เต': 261,
#  'ผ้าอ้อม': 262,
#  'baby': 263,
#  'ครีม': 264,
#  'การทำงาน': 265,
#  'สวย': 266,
#  'ของขวัญ': 267,
#  'เกม': 268,
#  'จับ': 269,
#  'ตีน': 270,
#  'ดีไซน์': 271,
#  'ห้องน้ำ': 272,
#  '11': 273,
#  'แขวน': 274,
#  'สมาร์ท': 275,
#  'หน้าจอ': 276,
#  'ไถล': 277,
#  'สภาพ': 278,
#  'ระบายลม': 279,
#  '18': 280,
#  'โทร': 281,
#  'ซี': 282,
#  '13': 283,
#  'วัด': 284,
#  'น่ารัก': 285,
#  'ธรรมชาติ': 286,
#  'โพ': 287,
#  'เครื่องสำอาง': 288,
#  'หน่วย': 289,
#  'ท': 290,
#  'คุณภาพดี': 291,
#  'ดูด': 292,
#  'แล็ปท็อป': 293,
#  'หมวก': 294,
#  'ในประเทศ': 295,
#  'ล้า': 296,
#  'oem': 297,
#  'k': 298,
#  'บริโภค': 299,
#  'แดง': 300,
#  'ลูกค้า': 301,
#  'รัด': 302,
#  'จุด': 303,
#  'ชั่วโมง': 304,
#  'นาที': 305,
#  'กระเป๋าเดินทาง': 306,
#  'ไม้': 307,
#  'anth': 308,
#  'h': 309,
#  '14': 310,
#  'ปั่น': 311,
#  '32': 312,
#  'ห้องนอน': 313,
#  'รูป': 314,
#  'น้ำหอม': 315,
#  'เอว': 316,
#  'hd': 317,
#  'ลี': 318,
#  'ไซส์': 319,
#  'power': 320,
#  'ขาย': 321,
#  'เชื่อมต่อ': 322,
#  'ผิวหน้า': 323,
#  'ความไว': 324,
#  'kg': 325,
#  'องศา': 326,
#  'ปกป้อง': 327,
#  'b': 328,
#  '120': 329,
#  'เครื่องมือ': 330,
#  'เนื้อผ้า': 331,
#  'type': 332,
#  'ขน': 333,
#  'ตรา': 334,
#  'อาร์': 335,
#  'ปุ่ม': 336,
#  'อุปโภค': 337,
#  'ตู้': 338,
#  'เส้นใย': 339,
#  'กระชับ': 340,
#  'ความปลอดภัย': 341,
#  'หอม': 342,
#  'ชมพู': 343,
#  'อะไหล่': 344,
#  'รอบ': 345,
#  'รี': 346,
#  'วิดีโอ': 347,
#  'บรรจุ': 348,
#  '80': 349,
#  'ข้อมูล': 350,
#  'โหมด': 351,
#  '200': 352,
#  'จัดส่ง': 353,
#  'เหมาะกับ': 354,
#  'วิ': 355,
#  'ตา': 356,
#  'มากขึ้น': 357,
#  'รอย': 358,
#  'กิน': 359,
#  'ขอบ': 360,
#  'เต็ม': 361,
#  'ขวดนม': 362,
#  'ซอง': 363,
#  'ลม': 364,
#  'พิมพ์': 365,
#  'ฐาน': 366,
#  '35': 367,
#  'แก้ว': 368,
#  'บ': 369,
#  'แรงดัน': 370,
#  'ทอง': 371,
#  'แตก': 372,
#  'สะดวกสบาย': 373,
#  'เติม': 374,
#  '45': 375,
#  'กด': 376,
#  'ไท': 377,
#  'ยืด': 378,
#  'โลหะ': 379,
#  'ครัว': 380,
#  'xiaomi': 381,
#  'คน': 382,
#  'จอ': 383,
#  'ฟ้า': 384,
#  'เงิน': 385,
#  'พัดลม': 386,
#  '500': 387,
#  'the': 388,
#  'กระดาษ': 389,
#  'ลำโพง': 390,
#  'เทคโนโลยี': 391,
#  '23': 392,
#  'ฟังก์ชั่น': 393,
#  'ซื้อ': 394,
#  'ผ้าฝ้าย': 395,
#  'หมอน': 396,
#  '2019': 397,
#  'เครื่องยนต์': 398,
#  'ซิป': 399,
#  'จีบ': 400,
#  'ขัด': 401,
#  'ทำงาน': 402,
#  'เช็ด': 403,
#  'อายุการใช้งาน': 404,
#  'คราบ': 405,
#  'บริการ': 406,
#  'ขึ้นไป': 407,
#  'เพศ': 408,
#  'black': 409,
#  'ไร้สาย': 410,
#  'ปั๊ม': 411,
#  '90': 412,
#  'การ์ด': 413,
#  'ป': 414,
#  'แปรง': 415,
#  'โคมไฟ': 416,
#  'แดด': 417,
#  'สกัด': 418,
#  'อาการ': 419,
#  'ร์': 420,
#  'รายละเอียด': 421,
#  'โค': 422,
#  'แพ': 423,
#  'เขียว': 424,
#  'แพคเกจ': 425,
#  'เซ': 426,
#  'จัด': 427,
#  'ของใช้ส่วนตัว': 428,
#  'ยึด': 429,
#  'อเนกประสงค์': 430,
#  'ซับ': 431,
#  'โอ': 432,
#  'สัตว์เลี้ยง': 433,
#  'ที่จะ': 434,
#  'น้ำมันเครื่อง': 435,
#  'สร้าง': 436,
#  'ดอก': 437,
#  'color': 438,
#  'หวย': 439,
#  'หมุน': 440,
#  '360': 441,
#  'เข็มขัด': 442,
#  'กาแฟ': 443,
#  'พัน': 444,
#  'ทั่วไป': 445,
#  'สะอาด': 446,
#  'ทรง': 447,
#  'xl': 448,
#  'ดิจิตอล': 449,
#  'wifi': 450,
#  'เงา': 451,
#  'f': 452,
#  'อบ': 453,
#  'เท': 454,
#  '400': 455,
#  'ประสิทธิภาพ': 456,
#  'car': 457,
#  'ทำอาหาร': 458,
#  '”': 459,
#  'ร้อน': 460,
#  'ถัง': 461,
#  'กระเป๋าสะพาย': 462,
#  'ผล': 463,
#  'พลังงาน': 464,
#  'ทันโลก': 465,
#  'โอกาส': 466,
#  'ซิลิโคน': 467,
#  'มอเตอร์': 468,
#  'แอร์': 469,
#  'หลอด': 470,
#  'ลิ': 471,
#  'mp': 472,
#  'บลูทูธ': 473,
#  'เครื่องดื่ม': 474,
#  'hz': 475,
#  'intel': 476,
#  'ห้อง': 477,
#  'style': 478,
#  'ยืดหยุ่น': 479,
#  'pu': 480,
#  'เค': 481,
#  'high': 482,
#  'ล็อค': 483,
#  'ฟ': 484,
#  'ปราศจาก': 485,
#  'พื้นผิว': 486,
#  '36': 487,
#  'แม่': 488,
#  'คัน': 489,
#  'ปกติ': 490,
#  'วิตามิน': 491,
#  '26': 492,
#  'รอ': 493,
#  'เช็ค': 494,
#  'หูฟัง': 495,
#  'ระบบเสียง': 496,
#  'mini': 497,
#  'pc': 498,
#  'ประตู': 499,
#  'เครื่องแต่งกาย': 500,
#  'ชา': 501,
#  'เก': 502,
#  'รัฐ': 503,
#  'หลัก': 504,
#  'รถเข็น': 505,
#  'สดใส': 506,
#  'เกาหลี': 507,
#  'plus': 508,
#  'อาหารเสริม': 509,
#  'ฟิล์ม': 510,
#  '21': 511,
#  'รองเท้าแตะ': 512,
#  'ลำลอง': 513,
#  'steel': 514,
#  'เกียร์': 515,
#  '300': 516,
#  'คาร์': 517,
#  'ส่วนผสม': 518,
#  'light': 519,
#  'เครื่องดูดฝุ่น': 520,
#  'e': 521,
#  'ชุดกีฬา': 522,
#  'เอสเตอร์': 523,
#  'มอเตอร์ไซค์': 524,
#  'อลูมิเนียม': 525,
#  'ซิก': 526,
#  'pcs': 527,
#  'สอด': 528,
#  '17': 529,
#  'bag': 530,
#  'อ่อนโยน': 531,
#  '1080': 532,
#  '250': 533,
#  'เบรค': 534,
#  '150': 535,
#  'ยุง': 536,
#  'รีโมท': 537,
#  'ใช้กับ': 538,
#  'มุม': 539,
#  'การ์ตูน': 540,
#  'นมผง': 541,
#  'รองเท้าผ้าใบ': 542,
#  'แหวน': 543,
#  'พรม': 544,
#  'เนียน': 545,
#  '–': 546,
#  '22': 547,
#  'รู': 548,
#  'กำจัด': 549,
#  'สิ่งแวดล้อม': 550,
#  'ไอ': 551,
#  'เ': 552,
#  'แน่น': 553,
#  'ฟิตเนส': 554,
#  'cotton': 555,
#  'โถ': 556,
#  'ไร้': 557,
#  'สด': 558,
#  'บัญชี': 559,
#  '27': 560,
#  'ผจญภัย': 561,
#  'ปัญหา': 562,
#  'ต': 563,
#  'core': 564,
#  '70': 565,
#  '75': 566,
#  'ของใช้': 567,
#  'ส้ม': 568,
#  'free': 569,
#  'ระบาย': 570,
#  'ไหล่': 571,
#  'super': 572,
#  'โต๊ะ': 573,
#  'bluetooth': 574,
#  'max': 575,
#  'บี': 576,
#  'หู': 577,
#  'นักกีฬา': 578,
#  '38': 579,
#  'ต่างกัน': 580,
#  'smart': 581,
#  'สกปรก': 582,
#  'นาม': 583,
#  'ลึก': 584,
#  'ฟุต': 585,
#  'เม็ด': 586,
#  'ต่ำ': 587,
#  'สิว': 588,
#  'uv': 589,
#  'แยก': 590,
#  'น้ำตาล': 591,
#  'ผิวกาย': 592,
#  'ท่อ': 593,
#  'วัน': 594,
#  'ของเหลว': 595,
#  'air': 596,
#  'เอ็น': 597,
#  'ประโยชน์': 598,
#  '48': 599,
#  'แม่เหล็ก': 600,
#  'design': 601,
#  'รักษา': 602,
#  'ทา': 603,
#  'home': 604,
#  'สากล': 605,
#  'ถ่าย': 606,
#  'สั่งของ': 607,
#  'full': 608,
#  'เป้': 609,
#  '34': 610,
#  'เหมือน': 611,
#  'โซโล่': 612,
#  'รีด': 613,
#  'android': 614,
#  'กล้ามเนื้อ': 615,
#  'ขับ': 616,
#  'ความสูง': 617,
#  'เข้มข้น': 618,
#  'can': 619,
#  '220': 620,
#  'ออ': 621,
#  'warranty': 622,
#  '55': 623,
#  'หุ้ม': 624,
#  'ไว': 625,
#  'ด้านหลัง': 626,
#  'honda': 627,
#  'intl': 628,
#  'อุ่น': 629,
#  'แพทเทิร์น': 630,
#  'เดิม': 631,
#  'เส้นผ่าศูนย์กลาง': 632,
#  'ddr': 633,
#  'ไส้': 634,
#  '®': 635,
#  '19': 636,
#  'ssd': 637,
#  'ปลาย': 638,
#  'ไป': 639,
#  'hdmi': 640,
#  '°': 641,
#  'ด': 642,
#  'เหลือง': 643,
#  'วิธี': 644,
#  'หลากหลาย': 645,
#  'กลาง': 646,
#  'อิน': 647,
#  'จ': 648,
#  'รี่': 649,
#  'ตก': 650,
#  'ให้อาหาร': 651,
#  'เปล': 652,
#  'ช่าง': 653,
#  'เก้าอี้': 654,
#  'เพลง': 655,
#  'แว่น': 656,
#  'หลอดไฟ': 657,
#  'white': 658,
#  'อะ': 659,
#  'ทิ้ง': 660,
#  'หนีบ': 661,
#  'stainless': 662,
#  'support': 663,
#  'นึ่ง': 664,
#  'lcd': 665,
#  'pro': 666,
#  'สะพาย': 667,
#  'สายไฟ': 668,
#  'battery': 669,
#  'ลา': 670,
#  '110': 671,
#  'ฟัง': 672,
#  'กาว': 673,
#  '28': 674,
#  'set': 675,
#  'โฟม': 676,
#  'แจ้ง': 677,
#  'ถุงมือ': 678,
#  'mah': 679,
#  'easy': 680,
#  'ความชื้น': 681,
#  'card': 682,
#  '600': 683,
#  'camera': 684,
#  'ด้านใน': 685,
#  'speed': 686,
#  'ถุงเท้า': 687,
#  'อ่าน': 688,
#  'กระแทก': 689,
#  'กระโปรง': 690,
#  'เก็บของ': 691,
#  'มั่นใจ': 692,
#  'บาร์': 693,
#  'วิทยุ': 694,
#  'กลิ่นหอม': 695,
#  'ไขมัน': 696,
#  'unisex': 697,
#  'จยย': 698,
#  'อัลลอย': 699,
#  'เด': 700,
#  'samsung': 701,
#  'abs': 702,
#  'ผง': 703,
#  'ส่วน': 704,
#  'ตาข่าย': 705,
#  'ดีไวซ์': 706,
#  'inch': 707,
#  'ความเสียหาย': 708,
#  'วอ': 709,
#  'ลักษณะ': 710,
#  'สัตว์': 711,
#  'อ่อน': 712,
#  'time': 713,
#  'สอง': 714,
#  'ซักผ้า': 715,
#  'กระจ่าง': 716,
#  'digital': 717,
#  'เป็นมิตร': 718,
#  'บรรจุภัณฑ์': 719,
#  'รู้สึก': 720,
#  'เหมาะสม': 721,
#  'ปรับระดับ': 722,
#  'รูปทรง': 723,
#  'ghz': 724,
#  'เจล': 725,
#  '01': 726,
#  'not': 727,
#  'อิเล็กทรอนิกส์': 728,
#  'ram': 729,
#  'สนับสนุน': 730,
#  'ร่ม': 731,
#  'ข้อมือ': 732,
#  'อย่างรวดเร็ว': 733,
#  'วาย': 734,
#  'คู่มือ': 735,
#  'case': 736,
#  'รังสี': 737,
#  'ขอบเขต': 738,
#  'cpu': 739,
#  'เตา': 740,
#  'port': 741,
#  '65': 742,
#  'oil': 743,
#  'เทียม': 744,
#  'ยีนส์': 745,
#  'ตะกร้า': 746,
#  'memory': 747,
#  'ญี่ปุ่น': 748,
#  'แว่นดำ': 749,
#  'จอแสดงผล': 750,
#  'หน่วยความจำ': 751,
#  'โป๊': 752,
#  'สะสม': 753,
#  'กระเป๋าเงิน': 754,
#  'body': 755,
#  'กรุ่น': 756,
#  'ทุ': 757,
#  'จุก': 758,
#  'บด': 759,
#  'คิว': 760,
#  'แป้ง': 761,
#  'วง': 762,
#  'ดีเยี่ยม': 763,
#  'quality': 764,
#  'ฝึก': 765,
#  'มีด': 766,
#  'ไม่ได้': 767,
#  'ข้าว': 768,
#  'คลิป': 769,
#  '64': 770,
#  'อ': 771,
#  'ไมโคร': 772,
#  '180': 773,
#  'มีระบบ': 774,
#  'นิ่ม': 775,
#  'เตือน': 776,
#  'วันหมดอายุ': 777,
#  'for': 778,
#  'yes': 779,
#  'ชัด': 780,
#  'tb': 781,
#  'ริ': 782,
#  '™': 783,
#  'ปาร์ตี้': 784,
#  'ด้านบน': 785,
#  'พรีเมี่ยม': 786,
#  '29': 787,
#  'ปาก': 788,
#  'งานฝีมือ': 789,
#  'shoes': 790,
#  'การผลิต': 791,
#  'หวาน': 792,
#  'พอร์ต': 793,
#  'เก็บข้อมูล': 794,
#  'ปรับปรุง': 795,
#  'บัตร': 796,
#  'micro': 797,
#  'สดชื่น': 798,
#  'กันกระแทก': 799,
#  'ทอด': 800,
#  'น้ำเงิน': 801,
#  'กล้องถ่ายภาพ': 802,
#  'คา': 803,
#  'โต': 804,
#  'ด์': 805,
#  '42': 806,
#  'รับ': 807,
#  'ค่ำมืด': 808,
#  'one': 809,
#  'กระจาย': 810,
#  'เรื่อง': 811,
#  'made': 812,
#  'ซักรีด': 813,
#  'shop': 814,
#  'sport': 815,
#  'พิกเซล': 816,
#  'สารพิษ': 817,
#  'การป้องกัน': 818,
#  'เคลื่อนย้าย': 819,
#  'กรุณา': 820,
#  'สังเคราะห์': 821,
#  'มุ้ง': 822,
#  'เด็กชาย': 823,
#  'หมายเหตุ': 824,
#  'เจาะ': 825,
#  'จาน': 826,
#  'ต่างหู': 827,
#  'ไซ': 828,
#  'เกาะ': 829,
#  'แพ้': 830,
#  'product': 831,
#  'thailand': 832,
#  'เย็บ': 833,
#  'ระคายเคือง': 834,
#  'ดาวรุ่ง': 835,
#  'ยู': 836,
#  'แบคทีเรีย': 837,
#  'เครื่องพิมพ์': 838,
#  'ย': 839,
#  'ไฟล์': 840,
#  'รับสัญญาณ': 841,
#  'สมบูรณ์แบบ': 842,
#  'นวด': 843,
#  'water': 844,
#  'เหงื่อ': 845,
#  'windows': 846,
#  'ย่าง': 847,
#  'dry': 848,
#  'กา': 849,
#  'fashion': 850,
#  'dc': 851,
#  'อิสระ': 852,
#  'spf': 853,
#  'โปรแกรม': 854,
#  'โดรน': 855,
#  'soft': 856,
#  'เชือก': 857,
#  'ลำ': 858,
#  'kids': 859,
#  'ยา': 860,
#  'เรต': 861,
#  '39': 862,
#  'เม': 863,
#  'เครื่องครัว': 864,
#  'รูขุมขน': 865,
#  'sata': 866,
#  'แชมพู': 867,
#  'ชม': 868,
#  'คล้อง': 869,
#  'ก้อน': 870,
#  'บันทึก': 871,
#  'specified': 872,
#  'ซิ': 873,
#  'vakind': 874,
#  'สามขา': 875,
#  '99': 876,
#  'กะทัดรัด': 877,
#  'ผ้าคลุม': 878,
#  'ผู้ผลิต': 879,
#  'หลักการ': 880,
#  'บริษัท': 881,
#  'บัง': 882,
#  'breathable': 883,
#  'ทาน': 884,
#  'ผืน': 885,
#  'wireless': 886,
#  'เร': 887,
#  'ความยืดหยุ่น': 888,
#  'คละ': 889,
#  'พ่น': 890,
#  'ถัก': 891,
#  'ลอก': 892,
#  'สีเทา': 893,
#  'ตุ๊กตา': 894,
#  'ว่ายน้ำ': 895,
#  'length': 896,
#  'ขนส่ง': 897,
#  'ลิ้น': 898,
#  'ปวด': 899,
#  'รอยขีดข่วน': 900,
#  'สมุนไพร': 901,
#  'ประกอบด้วย': 902,
#  'ฟองน้ำ': 903,
#  'ความแข็งแรง': 904,
#  'เซลล์': 905,
#  '：': 906,
#  'men': 907,
#  'เด็กแรกเกิด': 908,
#  '44': 909,
#  'สิ่งสกปรก': 910,
#  'ราว': 911,
#  'หลุด': 912,
#  'สร้อยคอ': 913,
#  'ปิ้ง': 914,
#  'ผัก': 915,
#  'บอร์ด': 916,
#  'ศูนย์': 917,
#  'ปลอด': 918,
#  'tv': 919,
#  'ซ่อม': 920,
#  'iphone': 921,
#  'อ่าง': 922,
#  'blue': 923,
#  'ป๋อง': 924,
#  'แมง': 925,
#  'db': 926,
#  'diy': 927,
#  'display': 928,
#  'บริษัทฯ': 929,
#  'อร่อย': 930,
#  'แอมป์': 931,
#  'drive': 932,
#  'สั่ง': 933,
#  'ริ้วรอย': 934,
#  'มีประสิทธิภาพ': 935,
#  'ความต้องการ': 936,
#  'คีย์': 937,
#  'ปู': 938,
#  'กึ่ง': 939,
#  'เจ': 940,
#  'เสริมสร้าง': 941,
#  'เล็บ': 942,
#  'ตกปลา': 943,
#  'สเก็ต': 944,
#  'ฮาร์ดแวร์': 945,
#  'คมชัด': 946,
#  'ฤดูร้อน': 947,
#  '33': 948,
#  'ถนอม': 949,
#  'เรียบง่าย': 950,
#  'z': 951,
#  '125': 952,
#  'to': 953,
#  'สบู่': 954,
#  'compatible': 955,
#  'ล่า': 956,
#  'ด้านหน้า': 957,
#  'weight': 958,
#  'นะคะ': 959,
#  'capacity': 960,
#  'หน้าปัด': 961,
#  'ที่นั่ง': 962,
#  'ด้านล่าง': 963,
#  'ตาม': 964,
#  'โครงสร้าง': 965,
#  'ครอบครัว': 966,
#  'คุ้ม': 967,
#  'ขจัด': 968,
#  'แช่': 969,
#  'ไดร์': 970,
#  'ทุกชนิด': 971,
#  'pa': 972,
#  'หรูหรา': 973,
#  'ธรรมดา': 974,
#  'ซ้ำ': 975,
#  '×': 976,
#  'แปลง': 977,
#  'watch': 978,
#  'โค้ง': 979,
#  'คาด': 980,
#  'โดยตรง': 981,
#  'ปากกา': 982,
#  'สติ๊กเกอร์': 983,
#  'ลิป': 984,
#  '31': 985,
#  'อก': 986,
#  'ขนม': 987,
#  'ประดับ': 988,
#  '95': 989,
#  'ขั้นตอน': 990,
#  'ความถี่': 991,
#  'มวน': 992,
#  'ช': 993,
#  'ห่อ': 994,
#  'ห้าม': 995,
#  'โซ่': 996,
#  'ถาด': 997,
#  'กันแดด': 998,
#  'long': 999,
#  'ฝักบัว': 1000,
#  ...}

# %%
len(tokenizer.word_index)
# Out:
# 99579

# %%
# Preprocess data function
def preprocess_fn(data):
    sequences = tokenizer.texts_to_sequences(data)
    padding_sequences = sequence.pad_sequences(sequences,maxlen = max_len)
    
    return padding_sequences,sequences

# %%
x_train_pad,x_seq = preprocess_fn(x_train_word)
x_val_pad,x_seq = preprocess_fn(x_val_word)
x_train_pad.shape
# Out:
# (700775, 30)

# %%
index_to_word = dict((i, w) for w, i in tokenizer.word_index.items())
" ".join([index_to_word[i] for i in x_seq[2]])
# Out:
# 'อุปกรณ์ กล่อง หัว ชาร์จ สาย usb typec'

# %%
seq_lens = [len(s) for s in x_seq]
print("average length: %0.1f" % np.mean(seq_lens))
print("max length: %d" % max(seq_lens))
# Out:
# average length: 4.8
# max length: 434

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.hist([l for l in seq_lens if l < 200], bins=100);

# %% [markdown]
# # Embedding with Thai2fit

# %%
from pythainlp.word_vector import sentence_vectorizer

sent_token = [sentence_vectorizer(sentence, use_mean=True) for sentence in clean_text]

# %%
x_sent = np.array(sent_token)
x_sent = np.squeeze(x_sent, axis=1)
x_sent
# Out:
# array([[ 0.        ,  0.        ,  0.        , ...,  0.        ,
#          0.        ,  0.        ],
#        [-0.030851  ,  0.025414  ,  0.12920238, ...,  0.05312146,
#         -0.07232962,  0.05345254],
#        [ 0.01986992, -0.01529075,  0.02124983, ..., -0.00371317,
#         -0.04483525, -0.03880025],
#        ...,
#        [-0.1612955 , -0.0947365 ,  0.064782  , ..., -0.052518  ,
#         -0.012282  , -0.0338025 ],
#        [-0.116644  ,  0.10576183,  0.140093  , ...,  0.02464033,
#         -0.039286  , -0.07064717],
#        [-0.0697385 , -0.0931615 ,  0.031465  , ...,  0.04723694,
#          0.05216337,  0.10509494]])

# %%
max_token = len(sent_token)+1

# %% [markdown]
# # Create model

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation
from keras.layers import Embedding
from keras.layers import LSTM
from keras.layers import Conv1D, MaxPooling1D

# %%
def plot_history(history):
    
    f, ax = plt.subplots(1, 2, figsize = (16, 7))
    
    acc = history.history['acc']
    val_acc = history.history['val_acc']
    loss = history.history['loss']
    val_loss = history.history['val_loss']

    epochs = range(1, len(acc) + 1)

    plt.sca(ax[0])
    plt.plot(epochs, acc, 'bo', label='Training acc')
    plt.plot(epochs, val_acc, 'b', label='Validation acc')
    plt.title('Training and validation accuracy')
    plt.legend()

    plt.sca(ax[1])
    plt.plot(epochs, loss, 'bo', label='Training loss')
    plt.plot(epochs, val_loss, 'b', label='Validation loss')
    plt.title('Training and validation loss')
    plt.legend()

    plt.show()

# %%
# Define model
lstm = models.Sequential()
lstm.add(layers.Embedding(max_word,50,input_length=max_len))
#lstm.add(layers.SpatialDropout1D(0.2))
lstm.add(layers.LSTM(128))
#lstm.add(layers.LeakyReLU(alpha=0.01))
lstm.add(layers.Dense(64,activation='relu'))
lstm.add(layers.Dropout(0.5))
lstm.add(layers.Dense(12,activation='softmax'))

# Compile model
lstm.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['acc'])
lstm.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_4 (Embedding)      (None, 30, 50)            4500000
# _________________________________________________________________
# lstm_4 (LSTM)                (None, 128)               91648
# _________________________________________________________________
# dense_7 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_8 (Dense)              (None, 12)                780
# =================================================================
# Total params: 4,600,684
# Trainable params: 4,600,684
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Fit model
his =  lstm.fit(x_train_pad,y_train,epochs=20,batch_size=32,validation_data=(x_val_pad,y_val))
# Out:
# C:\Users\super\Anaconda3\envs\tensorflow-gpu\lib\site-packages\tensorflow_core\python\framework\indexed_slices.py:424: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# Train on 700775 samples, validate on 36889 samples
# Epoch 1/20
# 163552/700775 [======>.......................] - ETA: 13:30 - loss: 1.4466 - acc: 0.5289
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-157-114cb06574bb> in <module>
#       1 # Fit model
# ----> 2 his =  lstm.fit(x_train_pad,y_train,epochs=20,batch_size=32,validation_data=(x_val_pad,y_val))
#
# ~\Anaconda3\envs\tensorflow-gpu\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#    1237                                         steps_per_epoch=steps_per_epoch,
#    1238                                         validation_steps=validation_steps,
# -> 1239                                         validation_freq=validation_freq)
#    1240
#    1241     def evaluate(self,
#
# ~\Anaconda3\envs\tensorflow-gpu\lib\site-packages\keras\engine\training_arrays.py in fit_loop(model, fit_function, fit_inputs, out_labels, batch_size, epochs, verbose, callbacks, val_function, val_inputs, shuffle, initial_epoch, steps_per_epoch, validation_steps, validation_freq)
#     194                     ins_batch[i] = ins_batch[i].toarray()
#     195
# --> 196                 outs = fit_function(ins_batch)
#     197                 outs = to_list(outs)
#     198                 for l, o in zip(out_labels, outs):
#
# ~\Anaconda3\envs\tensorflow-gpu\lib\site-packages\tensorflow_core\python\keras\backend.py in __call__(self, inputs)
#    3738         value = math_ops.cast(value, tensor.dtype)
#    3739       converted_inputs.append(value)
# -> 3740     outputs = self._graph_fn(*converted_inputs)
#    3741
#    3742     # EagerTensor.numpy() will often make a copy to ensure memory safety.
#
# ~\Anaconda3\envs\tensorflow-gpu\lib\site-packages\tensorflow_core\python\eager\function.py in __call__(self, *args, **kwargs)
#    1079       TypeError: For invalid positional/keyword argument combinations.
#    1080     """
# -> 1081     return self._call_impl(args, kwargs)
#    1082
#    1083   def _call_impl(self, args, kwargs, cancellation_manager=None):
#
# ~\Anaconda3\envs\tensorflow-gpu\lib\site-packages\tensorflow_core\python\eager\function.py in _call_impl(self, args, kwargs, cancellation_manager)
#    1119       raise TypeError("Keyword arguments {} unknown. Expected {}.".format(
#    1120           list(kwargs.keys()), list(self._arg_keywords)))
# -> 1121     return self._call_flat(args, self.captured_inputs, cancellation_manager)
#    1122
#    1123   def _filtered_call(self, args, kwargs):
#
# ~\Anaconda3\envs\tensorflow-gpu\lib\site-packages\tensorflow_core\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1222     if executing_eagerly:
#    1223       flat_outputs = forward_function.call(
# -> 1224           ctx, args, cancellation_manager=cancellation_manager)
#    1225     else:
#    1226       gradient_name = self._delayed_rewrite_functions.register()
#
# ~\Anaconda3\envs\tensorflow-gpu\lib\site-packages\tensorflow_core\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     509               inputs=args,
#     510               attrs=("executor_type", executor_type, "config_proto", config),
# --> 511               ctx=ctx)
#     512         else:
#     513           outputs = execute.execute_with_cancellation(
#
# ~\Anaconda3\envs\tensorflow-gpu\lib\site-packages\tensorflow_core\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      59     tensors = pywrap_tensorflow.TFE_Py_Execute(ctx._handle, device_name,
#      60                                                op_name, inputs, attrs,
# ---> 61                                                num_outputs)
#      62   except core._NotOkStatusException as e:
#      63     if name is not None:
#
# KeyboardInterrupt:

# %%
plot_history(his)

# %%
# Define an evaluation function to print the evaluation result
def evaluation_report(model,features,labels):
    
    # Calculate result
    result = model.evaluate(features,labels,verbose=False)
    
    # Predict and convert into a class
    pred_class = model.predict(features).argmax(axis=1)
    
    # Show report
    print(confusion_matrix(labels,pred_class))
    print(classification_report(labels,pred_class))
    print("Loss: %s Accuracy: %s" %(result[0],result[1]))
    
    return pred_class

# %%
evaluation_report(lstm,x_preprocess,y)
# Out:
# [[ 858   77   42]
#  [ 110  719   39]
#  [  22   12 1966]]
#               precision    recall  f1-score   support
#
#            0       0.87      0.88      0.87       977
#            1       0.89      0.83      0.86       868
#            2       0.96      0.98      0.97      2000
#
#     accuracy                           0.92      3845
#    macro avg       0.91      0.90      0.90      3845
# weighted avg       0.92      0.92      0.92      3845
#
# Loss: 0.17118681907109276 Accuracy: 0.9214564561843872
# array([0, 0, 0, ..., 2, 2, 2], dtype=int64)

# %%
text_test = ["หน้าจอ 6.4 นิ้ว ความละเอียด 3040x1440 Quad HD+ (550 ppi)กล้องหลัง 3 ตัว (16 MP f/2.2 (Ultra Wide),12 MP f/1.5 & 2.4 (Wide), 12 MP f/2.4 (Tele))กล้องหน้า 2 ตัว (10 MP f/1.9 (Main), 8 MP f/2.2 (Live Focus)หน่วยประมวลผล Octa-core Snapdragon 855, Octa-core Exynos9 9820Ram 8/512 GBแบตเตอรี่ 4,100 mAh (Typical)"]
text_test2 = ['กล้อง Motion Eye™ หลัง19 MP +หน้า 13 MP พร้อมสุดยอดสโลว์โมชั่น ซูม8เท่า RAM 4GB+ROM 64GB เพิ่มเมมสูงสุด 256GB กันน้ำตามมาตราฐาน IP68 ถ่ายรูปโดนน้ำสบายมาก*หน้าจอ 5.2 นิ้ว TRILUMINOS™ CPU Qualcomm® Snapdragon™ 820แบตเตอรี่ 2900mAh + Sony Quick Charge']
text_test3 = ["CPU Intel Core i3-2350M @2.30 GHz หน้าจอขนาด 15.6” Full HD (1920 x 1080) HDD : 250 GB RAM: DDR3 4 GB Port : USB 2.0 x 4,VGA/ LAN port USB WiFi, DVD-ROM Battery Li-ion การ์ดจอ : Intel HD Graphics 3000 on board Battery 1-2 ชม+- #ผลิตในประเทศญี่ปุ่น คุณภาพมากกว่า 95% ฟรีเกมส์ 200 เกมส์ เล่นได้เลยไม่ต้องต่อเน็ต รับประกันสภาพสินค้าทุกชิ้น 95%+ รับประกันสินค้า 3 เดือน Condition: สินค้าหมดสัญญาเช่า รีวิวเกมส์ออนไลน์ ROV Frefire, Call of duty: https://youtu.be/qKqpGk8Ni7w"]

def test_lstm(text_test):
    clean_text_test = [clean_msg(text) for text in text_test]
    word_list_test = ['|'.join(split_word(txt)) for txt in clean_text_test]
    x_preprocess_test,x_seq_test = preprocess_fn(word_list_test)

    labels = ['โทรศัพท์มือถือ','แท็บเล็ต','แล็ปท็อป','คอมพิวเตอร์แบบตั้งโต๊ะ','กล้อง DSLR','กล้องมิลเลอร์เลส','โดรน','โทรทัศน์และวิดิโอ','เครื่องใช้ไฟฟ้าขนาดเล็ก','เสื้อผ้าผู้ชาย','รองเท้าผู้ชาย','ห้องนอน','ห้องน้ำ']
    pred = lstm.predict(x_preprocess_test).argmax(axis=1)
    print(clean_text_test)
    print(pred,'-->',labels[int(pred)])

test_lstm(["ขนาดหน้าจอ 8.0 นิ้วความละเอียดหน้าจอ: 1280 x 800 พิกเซล ระบบปฏิบัติการ : Android 9.0 (Oreo) หน่วยประมวลผล : MTK MT8321 32 Bit /Quad Core ความเร็ว 1.3GHz แรม : 2GB / รอม : 32GB หน่วยความจำภายนอก : รองรับ SD Card การ์ดได้สูงสุดถึง 128GB รองรับสัญญาณ Dual WiFi 2.4GHz ความจุแบตเตอรี่: 5500mAh (Built-in)"])
# Out:
# ['ขนาดหน้าจอ 8.0 นิ้วความละเอียดหน้าจอ 1280 x 800 พิกเซล ระบบปฏิบัติการ Android 9.0 Oreo หน่วยประมวลผล MTK MT8321 32 Bit Quad Core ความเร็ว 1.3GHz แรม 2GB รอม 32GB หน่วยความจำภายนอก รองรับ SD Card การ์ดได้สูงสุดถึง 128GB รองรับสัญญาณ Dual WiFi 2.4GHz ความจุแบตเตอรี่ 5500mAh Builtin']
# [1] --> แท็บเล็ต

# %% [markdown]
# # Others model

# %% [markdown]
# # # CONV1D + LSTM

# %%
# Embedding
max_features = len(tokenizer.word_index)+1
max_len = 100
embedding_size = 128

# Convolution
kernel_size = 5
filters = 64
pool_size = 4

# LSTM
lstm_output_size = 70

# Training
batch_size = 30
epochs = 10

x_preprocess,x_seq = preprocess_fn(word_list)

# %%
# Define the model
lstm2 = Sequential()
lstm2.add(Embedding(max_features, embedding_size, input_length=maxlen))
lstm2.add(Dropout(0.25))
lstm2.add(Conv1D(filters, kernel_size, padding='valid', activation='relu', strides=1))
lstm2.add(MaxPooling1D(pool_size=pool_size))
lstm2.add(LSTM(lstm_output_size))
lstm2.add(layers.Dense(32,activation='elu'))
lstm2.add(layers.Dropout(0.5))
lstm2.add(layers.Dense(3,activation='softmax'))

# Complie the model
lstm2.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['sparse_categorical_accuracy'])
lstm2.summary()

his = lstm2.fit(x_preprocess, y,
          batch_size=batch_size,
          epochs=epochs)
# Out:
# Model: "sequential_17"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_17 (Embedding)     (None, 100, 128)          365696
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 100, 128)          0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 96, 64)            41024
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 24, 64)            0
# _________________________________________________________________
# lstm_16 (LSTM)               (None, 70)                37800
# _________________________________________________________________
# dense_23 (Dense)             (None, 32)                2272
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_24 (Dense)             (None, 3)                 99
# =================================================================
# Total params: 446,891
# Trainable params: 446,891
# Non-trainable params: 0
# _________________________________________________________________
# C:\Users\super\Anaconda3\envs\tensorflow-gpu\lib\site-packages\tensorflow_core\python\framework\indexed_slices.py:424: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# Epoch 1/10
# 3845/3845 [==============================] - 7s 2ms/step - loss: 0.9116 - sparse_categorical_accuracy: 0.5615
# Epoch 2/10
# 3845/3845 [==============================] - 5s 1ms/step - loss: 0.5029 - sparse_categorical_accuracy: 0.7740
# Epoch 3/10
# 3845/3845 [==============================] - 5s 1ms/step - loss: 0.3286 - sparse_categorical_accuracy: 0.8668
# Epoch 4/10
# 3845/3845 [==============================] - 5s 1ms/step - loss: 0.2456 - sparse_categorical_accuracy: 0.8980
# Epoch 5/10
# 3845/3845 [==============================] - 5s 1ms/step - loss: 0.2124 - sparse_categorical_accuracy: 0.9118
# Epoch 6/10
# 3845/3845 [==============================] - 5s 1ms/step - loss: 0.1914 - sparse_categorical_accuracy: 0.9137
# Epoch 7/10
# 3845/3845 [==============================] - 5s 1ms/step - loss: 0.1830 - sparse_categorical_accuracy: 0.9181
# Epoch 8/10
# 3845/3845 [==============================] - 5s 1ms/step - loss: 0.1757 - sparse_categorical_accuracy: 0.9186
# Epoch 9/10
# 3845/3845 [==============================] - 5s 1ms/step - loss: 0.1755 - sparse_categorical_accuracy: 0.9173
# Epoch 10/10
# 3845/3845 [==============================] - 5s 1ms/step - loss: 0.1589 - sparse_categorical_accuracy: 0.9261

# %%
evaluation_report(lstm2,x_preprocess,y)
# Out:
# [[ 797  100   80]
#  [  34  779   55]
#  [   3    7 1990]]
#               precision    recall  f1-score   support
#
#            0       0.96      0.82      0.88       977
#            1       0.88      0.90      0.89       868
#            2       0.94      0.99      0.96      2000
#
#     accuracy                           0.93      3845
#    macro avg       0.92      0.90      0.91      3845
# weighted avg       0.93      0.93      0.93      3845
#
# Loss: 0.14450620673805062 Accuracy: 0.9274382591247559
# array([0, 0, 0, ..., 2, 2, 2], dtype=int64)
