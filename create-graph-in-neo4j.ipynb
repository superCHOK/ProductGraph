# %%
import webbrowser
from py2neo import Node, Relationship, Graph

# %% [markdown]
# # 2 inputs

# %%
# Read triples from text file
file_name = 'category1'

with open ("Data/triples_{}.txt".format(file_name), "r", encoding='utf-8') as myfile:
    triples = myfile.read().splitlines()
for i in range(len(triples)):
    triples[i] = triples[i].split('\t')
    triples[i] = [m for m in triples[i] if not m =='']

# %%
with open('./Data/Product_names_{}.txt'.format(file_name), 'r', encoding='utf-8') as fn: 
    content = fn.read() 
    dic = eval(content)

# %%
triples
# Out:
# [['category_0_0', 'หมวดหมู่', ' โทรศัพท์มือถือและแท็บเล็ต'],
#  ['category_0_0', 'ประเภทย่อย', ' สมาร์ทโฟน'],
#  ['category_0_0',
#   'ความจุ',
#   ' 6000 mah และสามารถชาร์จแบตเร็ว ด้วย fast charging'],
#  ['category_0_0',
#   'กล้องหลัง',
#   ' 3 ตัว ที่มีกล้องชัดสูงสุดถึง 48ล้านพิกเซล มาพร้อมกับ'],
#  ['category_0_0', 'เลนส์', 'มุมกว้างพิเศษ ultra wide'],
#  ['category_0_0', 'ram', ' 4 gb '],
#  ['category_0_0', 'rom', ' 64 gb'],
#  ['category_0_0', 'หน้าจอ', 'แสดงผล super amoled infinity u '],
#  ['category_0_0', 'ขนาด', ' 6.4 inch '],
#  ['category_0_0', 'แบรนด์', ' samsung '],
#  ['category_0_0', 'sku', ' 480942616 th 870640886'],
#  ['category_0_0', 'โมเดล', ' galaxy m30s 4 64gb '],
#  ['category_0_0', 'ระยะเวลาการรับประกัน', ' 1 ปี'],
#  ['category_0_1', 'หมวดหมู่', ' โทรศัพท์มือถือและแท็บเล็ต'],
#  ['category_0_1', 'ประเภทย่อย', ' สมาร์ทโฟน'],
#  ['category_0_1', 'รองรับ', ' 2 ซิม nano sim'],
#  ['category_0_1', 'หน่วยประมวลผล', ' exynos 9610 quad 2.3 ghz quad 1.7 ghz'],
#  ['category_0_1', 'ระบบปฏิบัติการ', ' android'],
#  ['category_0_1', 'รองรับ', 'สูงสุด 512 gb'],
#  ['category_0_1', 'ram', ' 4 gb'],
#  ['category_0_1', 'หน้าจอ', ' 6.4 inch '],
#  ['category_0_1', 'ความละเอียด', ' 1080 x 2340 พิกเซล fhd '],
#  ['category_0_1', 'กล้องหลัง', ' 3 '],
#  ['category_0_1',
#   'เลนส์',
#   ' 48 ล้านพิกเซล f 2.0 5 ล้านพิกเซล f 2.2 bokeh 8 ล้านพิกเซล f 2.4 ultrawide แฟลช led'],
#  ['category_0_1', 'กล้องหน้า', ' 32 ล้านพิกเซล f 2.0'],
#  ['category_0_1', 'bluetooth', ' 5.0'],
#  ['category_0_1', 'แบตเตอรี่', ' 4000 mah'],
#  ['category_0_1', 'ขนาด', ' 158.5 x 74.5 x 7.7 mm'],
#  ['category_0_1', 'น้ำหนัก', ' 169 g'],
#  ['category_0_1', 'แบรนด์', ' samsung '],
#  ['category_0_1', 'sku', ' 593772364 th 1113954823'],
#  ['category_0_1', 'ระยะเวลาการรับประกัน', ' 1 ปี'],
#  ['category_0_1', 'กล้องหน้า', ' ล้านพิกเซล 7ล้านพิกเซล ขึ้นไป'],
#  ['category_0_1', 'ระบบปฏิบัติการ', 'เวอร์ชัน android 9.0 pie'],
#  ['category_0_1', 'โมเดล', ' a50s'],
#  ['category_0_1', 'ram', ' 512mb และน้อยกว่า'],
#  ['category_0_1', 'ขนาดหน้าจอ', ' นิ้ว 6.4'],
#  ['category_0_1', 'ความจุแบตเตอรี่', ' 1000 mah ถึง 5000 mah'],
#  ['category_0_1', 'สี', 'ยบแบบบาง คู่'],
#  ['category_0_2', 'หมวดหมู่', ' โทรศัพท์มือถือและแท็บเล็ต'],
#  ['category_0_2', 'ประเภทย่อย', ' สมาร์ทโฟน'],
#  ['category_0_2', 'จอแสดงผล', ' tft lcd 24 bit 16 ล้าน'],
#  ['category_0_2', 'สี', 'หน้าจอ'],
#  ['category_0_2',
#   'หน้าจอ',
#   'ทรงหยดน้ำ รูปตัว v infinity v กว้าง 6.2 inch แนวทะแยง '],
#  ['category_0_2', 'ความละเอียด', ' 1520 x 720 พิกเซล'],
#  ['category_0_2', 'rom', 'eter ระบบเซนเซอร์หมุนภาพ gyroscope '],
#  ['category_0_2', 'สี', 'ให้เลือก colors black red green blue'],
#  ['category_0_2', 'แบรนด์', ' samsung '],
#  ['category_0_2', 'sku', ' 404422189 th 784670279'],
#  ['category_0_2', 'ระยะเวลาการรับประกัน', ' 1 ปี'],
#  ['category_0_2', 'ระบบปฏิบัติการ', ' android 9.0 pie'],
#  ['category_0_2', 'กล้องหน้า', ' ล้านพิกเซล 7ล้านพิกเซล ขึ้นไป'],
#  ['category_0_2', 'ระบบปฏิบัติการ', 'เวอร์ชัน android 9.0 pie'],
#  ['category_0_2', 'โมเดล', ' samsung galaxy a10s '],
#  ['category_0_2', 'ram', '2gb '],
#  ['category_0_2', 'rom', '32gb '],
#  ['category_0_2', 'ram', ' 2gb'],
#  ['category_0_2', 'ขนาดหน้าจอ', ' นิ้ว 6.2'],
#  ['category_0_2', 'ความจุแบตเตอรี่', ' 1000 mah ถึง 5000 mah'],
#  ['category_0_2', 'สี', 'ยบแบบบาง เตียงเดี่ยว'],
#  ['category_0_3', 'หมวดหมู่', ' โทรศัพท์มือถือและแท็บเล็ต'],
#  ['category_0_3', 'ประเภทย่อย', ' สมาร์ทโฟน'],
#  ['category_0_3', 'ขนาดหน้าจอ', ' 6.8 inch '],
#  ['category_0_3', 'ram', ' 12 gb'],
#  ['category_0_3', 'ความจุ', 'ที่เก็บข้อมูล 256 gb'],
#  ['category_0_3', 'แบตเตอรี่', ' 4300 mah typical '],
#  ['category_0_3', 'มาตรฐานการกันน้ำและกันฝุ่น', ' ip68'],
#  ['category_0_3', 'แบรนด์', ' samsung '],
#  ['category_0_3', 'sku', ' 385536916 th 749070165'],
#  ['category_0_3', 'โมเดล', ' galaxy note 10 '],
#  ['category_0_3', 'ขนาดหน้าจอ', ' นิ้ว 6.8'],
#  ['category_0_3', 'ระยะเวลาการรับประกัน', ' 1 ปี'],
#  ['category_0_4', 'หมวดหมู่', ' โทรศัพท์มือถือและแท็บเล็ต'],
#  ['category_0_4', 'ประเภทย่อย', ' สมาร์ทโฟน'],
#  ['category_0_4', 'rom', 'eter ระบบเปิด ปิด'],
#  ['category_0_4',
#   'หน้าจอ',
#   'อัตโนมัติขณะสนทนา proximity ระบบตรวจจับคลื่นแม่เหล็ก geomagnetic ระบบเซนเซอร์หมุนภาพ gyroscope ระบบวัดความกดอากาศ ba'],
#  ['category_0_4', 'rom', 'eter '],
#  ['category_0_4', 'สี', 'ให้เลือก colors black pink gold bluelight'],
#  ['category_0_4', 'รองรับ', ' 2 ซิมการ์ด'],
#  ['category_0_4', 'ระบบปฏิบัติการ', ' android 6.0.1 marshmallow '],
#  ['category_0_4', 'หน่วยประมวลผล', ' octa core ความเร็ว 1.9 ghz'],
#  ['category_0_4', 'ram', ' 3gb'],
#  ['category_0_4',
#   'port',
#   'able wi fi hotspot เชื่อมต่อไร้สายระหว่างอุปกรณ์โดยตรง wi fi direct '],
#  ['category_0_4', 'bluetooth', ' 4.2 '],
#  ['category_0_4', 'รองรับ', 'ชุดหูฟังสเตอริโอ a2dp '],
#  ['category_0_4', 'bluetooth', ' stereo '],
#  ['category_0_4', 'รองรับ', ' nfc near field communication '],
#  ['category_0_4', 'usb', ' type c'],
#  ['category_0_4', 'สี', 'ยบชุดหูฟัง 3.5 mm '],
#  ['category_0_4',
#   'ขนาด',
#   ' 1.9 ไฟแฟลช led โฟกัสอัตโนมัติ auto focus แตะเลือกจุดโฟกัส touch focus ค้นหาใบหน้าอัตโนมัติ face detection โหมดถ่ายภาพพาโนราม่า pano'],
#  ['category_0_4', 'ram', 'a '],
#  ['category_0_4', 'กล้องหน้า', ' front camera '],
#  ['category_0_4', 'ความละเอียด', ' 16ล้านพิกเซล รูรับแสง'],
#  ['category_0_4', 'ขนาด', ' 1.9'],
#  ['category_0_4', 'รองรับ', 'วีดีโอจาก youtube '],
#  ['category_0_4', 'สนับสนุน', ' gmail google search'],
#  ['category_0_4', 'สี', 'ยงรบกวนการสนทนา'],
#  ['category_0_5', 'หมวดหมู่', ' โทรศัพท์มือถือและแท็บเล็ต'],
#  ['category_0_5', 'ประเภทย่อย', ' สมาร์ทโฟน'],
#  ['category_0_5', 'จอแสดงผล', ' super amoled 24 bit 16 ล้าน'],
#  ['category_0_5', 'สี', ' fullview '],
#  ['category_0_5', 'จอแสดงผล', ' กว้าง 6.3 inch '],
#  ['category_0_5', 'ขนาด', ' 1.7'],
#  ['category_0_5', 'กล้องหน้า', 'ความละเอียด'],
#  ['category_0_5', 'ความละเอียด', ' 24ล้านพิกเซล '],
#  ['category_0_5', 'ram', ' 6gb'],
#  ['category_0_5', 'แบรนด์', ' samsung '],
#  ['category_0_5', 'sku', ' 265390897 th 412154584'],
#  ['category_0_5', 'โมเดล', ' galaxy a9 2018 '],
#  ['category_0_5', 'ระยะเวลาการรับประกัน', ' 1 ปี'],
#  ['category_0_6', 'หมวดหมู่', ' โทรศัพท์มือถือและแท็บเล็ต'],
#  ['category_0_6', 'ประเภทย่อย', ' สมาร์ทโฟน'],
#  ['category_0_6', 'จอแสดงผล', ' super amoled 24 bit 16 ล้าน'],
#  ['category_0_6', 'ความละเอียด', ' 720 x 1560 พิกเซล 268 ppi '],
#  ['category_0_6', 'จอ', ' corning gorilla glass 3 '],
#  ['category_0_6',
#   'หน่วยประมวลผล',
#   ' exynos 7885 octa core ความเร็ว 1.8 mhz หน่วยความจำ'],
#  ['category_0_6', 'ram', ' 4gb '],
#  ['category_0_6', 'rom', ' 64gb การ์ดหน่วยความจำ'],
#  ['category_0_6', 'ขนาด', ' 1.7 ไฟแฟลช led โหมดถ่ายภาพช่วงการรับแสงสูง hdr '],
#  ['category_0_6', 'กล้องหน้า', ' front camera '],
#  ['category_0_6', 'ความละเอียด', ' 16ล้านพิกเซล รูรับแสง'],
#  ['category_0_6', 'ขนาด', ' 2.0'],
#  ['category_0_6', 'สี', 'ยงสเตอริโอ stereo speakers wifi 802.11 a b g n ac'],
#  ['category_0_6', 'port', 'able wi fi hotspot '],
#  ['category_0_6', 'bluetooth', ' 5.0 type c '],
#  ['category_0_6', 'usb', ' 2.0 ช่องเ'],
#  ['category_0_6', 'สี', 'ยบชุดหูฟัง 3.5 mm '],
#  ['category_0_6', 'รองรับ', ' 2 ซิมการ์ด'],
#  ['category_0_6', 'หน้าจอ', ' fingerprint under '],
#  ['category_0_6', 'จอแสดงผล', ' ตรวจจับความเคลื่อนไหวของตัวเครื่อง accele'],
#  ['category_0_6', 'rom', 'eter ระบบเปิด ปิด'],
#  ['category_0_6', 'หน้าจอ', 'อัตโนมัติขณะสนทนา proximity '],
#  ['category_0_6', 'แบตเตอรี่', 'มาตรฐาน li pol 4000 mah standard battery '],
#  ['category_0_6', 'สี', 'ให้เลือก colors ดำขาว เขียว'],
#  ['category_0_6', 'แบรนด์', ' samsung '],
#  ['category_0_6', 'sku', ' 594352438 th 1115888431'],
#  ['category_0_6', 'กล้องหน้า', ' ล้านพิกเซล 16ล้านพิกเซล '],
#  ['category_0_6', 'โมเดล', ' samsung a30s'],
#  ['category_0_6', 'ระยะเวลาการรับประกัน', ' 1 ปี'],
#  ['category_0_6', 'ความจุแบตเตอรี่', ' 1000 mah ถึง 5000 mah'],
#  ['category_0_7', 'หมวดหมู่', ' โทรศัพท์มือถือและแท็บเล็ต'],
#  ['category_0_7', 'ประเภทย่อย', ' สมาร์ทโฟน'],
#  ['category_0_7', 'แบรนด์', ' samsung '],
#  ['category_0_7', 'sku', ' 599364278 th 1176694583'],
#  ['category_0_7', 'ระบบปฏิบัติการ', 'เวอร์ชัน android 9.0 pie'],
#  ['category_0_7', 'โมเดล', ' samsung galaxy note10 plus'],
#  ['category_0_7', 'ขนาดหน้าจอ', ' นิ้ว 6.8'],
#  ['category_0_7', 'ระยะเวลาการรับประกัน', ' 1 ปี'],
#  ['category_0_7', 'สี', 'ยบแบบบาง เตียงเดี่ยว'],
#  ['category_0_8', 'หมวดหมู่', ' โทรศัพท์มือถือและแท็บเล็ต'],
#  ['category_0_8', 'ประเภทย่อย', ' สมาร์ทโฟน'],
#  ['category_0_8', 'หน้าจอ', 'กว้าง 6.7 แบบ infinity u '],
#  ['category_0_8', 'เลนส์', ' ultra wide'],
#  ['category_0_8', 'แบรนด์', ' samsung '],
#  ['category_0_8', 'sku', ' 309636084 th 547152150'],
#  ['category_0_8', 'โมเดล', ' a70 8 128gb '],
#  ['category_0_8', 'ระยะเวลาการรับประกัน', ' 1 ปี'],
#  ['category_0_9', 'หมวดหมู่', ' โทรศัพท์มือถือและแท็บเล็ต'],
#  ['category_0_9', 'ประเภทย่อย', ' สมาร์ทโฟน'],
#  ['category_0_9', 'แบรนด์', ' samsung '],
#  ['category_0_9', 'sku', ' 571250946 th 1048780375'],
#  ['category_0_9', 'ระยะเวลาการรับประกัน', ' 1 เดือน'],
#  ['category_0_9', 'แบตเตอรี่', 'แบตเตอรี่'],
#  ['category_0_9', 'แบตเตอรี่', 'ชาร์จใหม่ได้และถอดได้'],
#  ['category_0_9', 'กล้องหน้า', ' ล้านพิกเซล 7ล้านพิกเซล ขึ้นไป'],
#  ['category_0_9',
#   'โมเดล',
#   ' สมาร์ทโฟน โทรศัพท์มือถือ samsung galaxy a10s sm a107m '],
#  ['category_0_9', 'ขนาดหน้าจอ', ' 6.2 inch '],
#  ['category_0_9', 'ram', ' 2 '],
#  ['category_0_9', 'rom', ' 32 gb '],
#  ['category_0_9', 'สี', 'น้ำเงิน '],
#  ['category_0_9', 'หน้าจอ', ' lcd'],
#  ['category_0_9', 'ความละเอียด', 'วิดีโอ 1080p'],
#  ['category_0_9', 'ความละเอียด', ' full hd'],
#  ['category_0_9', 'ความจุแบตเตอรี่', ' 1000 mah ถึง 5000 mah'],
#  ['category_0_10', 'หมวดหมู่', ' โทรศัพท์มือถือและแท็บเล็ต'],
#  ['category_0_10', 'ประเภทย่อย', ' สมาร์ทโฟน'],
#  ['category_0_10', 'จอแสดงผล', ' super amoled 24 bit 16 ล้าน'],
#  ['category_0_10', 'สี', ' กว้าง 5.2 inch แนวทะแยง '],
#  ['category_0_10', 'ความละเอียด', ' 1080 x 1920 พิกเซล ประเภท'],
#  ['category_0_10', 'จอ', 'หน้าจอ'],
#  ['category_0_10', 'หน้าจอ', 'กระจกแข็ง ประเภท'],
#  ['category_0_10', 'จอ', ' ระบบป้องกัน ฝุ่นละออง resistance to dust '],
#  ['category_0_10', 'rom', 'eter ระบบเปิด ปิด'],
#  ['category_0_10',
#   'หน้าจอ',
#   'อัตโนมัติขณะสนทนา proximity ระบบตรวจจับคลื่นแม่เหล็ก geomagnetic ระบบเซนเซอร์หมุนภาพ gyroscope ระบบวัดความกดอากาศ ba'],
#  ['category_0_10', 'rom', 'eter '],
#  ['category_0_10', 'สี', 'ให้เลือก colors black pink gold bluelight'],
#  ['category_0_10', 'รองรับ', ' 2 ซิมการ์ด'],
#  ['category_0_10', 'ระบบปฏิบัติการ', ' android 6.0.1 marshmallow '],
#  ['category_0_10', 'หน่วยประมวลผล', ' octa core ความเร็ว 1.9 ghz'],
#  ['category_0_10', 'ram', ' 3gb'],
#  ['category_0_10',
#   'port',
#   'able wi fi hotspot เชื่อมต่อไร้สายระหว่างอุปกรณ์โดยตรง wi fi direct '],
#  ['category_0_10', 'bluetooth', ' 4.2 '],
#  ['category_0_10', 'รองรับ', 'ชุดหูฟังสเตอริโอ a2dp '],
#  ['category_0_10', 'bluetooth', ' stereo '],
#  ['category_0_10', 'รองรับ', ' nfc near field communication '],
#  ['category_0_10', 'usb', ' type c'],
#  ['category_0_10', 'สี', 'ยบชุดหูฟัง 3.5 mm '],
#  ['category_0_10',
#   'ขนาด',
#   ' 1.9 ไฟแฟลช led โฟกัสอัตโนมัติ auto focus แตะเลือกจุดโฟกัส touch focus โหมดถ่ายภาพพาโนราม่า pano'],
#  ['category_0_10', 'ram', 'a '],
#  ['category_0_10', 'กล้องหน้า', ' front camera '],
#  ['category_0_10', 'ความละเอียด', ' 16ล้านพิกเซล รูรับแสง'],
#  ['category_0_10', 'ขนาด', ' 1.9'],
#  ['category_0_10', 'รองรับ', 'วีดีโอจาก youtube '],
#  ['category_0_10', 'สนับสนุน', ' gmail google search'],
#  ['category_0_11', 'หมวดหมู่', ' โทรศัพท์มือถือและแท็บเล็ต'],
#  ['category_0_11', 'ประเภทย่อย', ' สมาร์ทโฟน'],
#  ['category_0_11', 'หน้าจอ', 'แสดงผลแบบ super amoled '],
#  ['category_0_11', 'ขนาด', ' 5.2 inch '],
#  ['category_0_11', 'ความละเอียด', 'ระดับ full hd 1080p 1080x1920 พิกเซล '],
#  ['category_0_11', 'ram', 'ขนาด'],
#  ['category_0_11', 'ขนาด', ' 3 gb'],
#  ['category_0_11', 'ขนาด', ' 32 gb'],
#  ['category_0_11', 'ความละเอียด', ' 16 ล้านพิกเซล'],
#  ['category_0_11', 'แบรนด์', ' samsung '],
#  ['category_0_11', 'sku', ' sa861elaa8nxs2anth 17866375'],
#  ['category_0_11', 'ระยะเวลาการรับประกัน', ' 1 ปี'],
#  ['category_0_11', 'ระบบปฏิบัติการ', ' android'],
#  ['category_0_11', 'กล้องหน้า', ' ล้านพิกเซล 7ล้านพิกเซล ขึ้นไป'],
#  ['category_0_11', 'ระบบปฏิบัติการ', 'เวอร์ชัน marshmallow'],
#  ['category_0_11', 'โมเดล', ' samsung galaxy a5 2017 gold'],
#  ['category_0_11', 'ram', ' 3gb'],
#  ['category_0_11', 'หน้าจอ', ' amoled'],
#  ['category_0_11', 'ขนาดหน้าจอ', ' นิ้ว 5.2'],
#  ['category_0_12', 'หมวดหมู่', ' โทรศัพท์มือถือและแท็บเล็ต'],
#  ['category_0_12', 'ประเภทย่อย', ' สมาร์ทโฟน'],
#  ['category_0_12', 'สี', 'สันและความคมชัดเสมือน'],
#  ['category_0_12', 'จอ', 'ทีวีระดับพรีเมี่ยม'],
#  ['category_0_12', 'กล้องหลัง', ' 2ตัวพร้อมระบบถ่ายภาพอัจฉริยะ'],
#  ['category_0_12', 'แบรนด์', ' samsung '],
#  ['category_0_12', 'sku', ' 526004055 th 942110374'],
#  ['category_0_12', 'โมเดล', ' s10e 6 128gb '],
#  ['category_0_12', 'ระยะเวลาการรับประกัน', ' 1 ปี'],
#  ['category_0_13', 'หมวดหมู่', ' โทรศัพท์มือถือและแท็บเล็ต'],
#  ['category_0_13', 'ประเภทย่อย', ' สมาร์ทโฟน'],
#  ['category_0_13', 'แบรนด์', ' samsung '],
#  ['category_0_13', 'sku', ' 571320012 th 1048806072'],
#  ['category_0_13', 'ระยะเวลาการรับประกัน', ' 1 เดือน'],
#  ['category_0_13', 'แบตเตอรี่', 'แบตเตอรี่'],
#  ['category_0_13', 'แบตเตอรี่', 'ชาร์จใหม่ได้และถอดได้'],
#  ['category_0_13', 'กล้องหน้า', ' ล้านพิกเซล 7ล้านพิกเซล ขึ้นไป'],
#  ['category_0_13',
#   'โมเดล',
#   ' สมาร์ทโฟน โทรศัพท์มือถือ samsung galaxy a10s sm a107m '],
#  ['category_0_13', 'ขนาดหน้าจอ', ' 6.2 inch '],
#  ['category_0_13', 'ram', ' 2 '],
#  ['category_0_13', 'rom', ' 32 gb '],
#  ['category_0_13', 'สี', 'เขียว '],
#  ['category_0_13', 'หน้าจอ', ' lcd'],
#  ['category_0_13', 'ความละเอียด', 'วิดีโอ 1080p'],
#  ['category_0_13', 'ความละเอียด', ' full hd'],
#  ['category_0_13', 'ความจุแบตเตอรี่', ' 1000 mah ถึง 5000 mah'],
#  ['category_0_14', 'หมวดหมู่', ' โทรศัพท์มือถือและแท็บเล็ต'],
#  ['category_0_14', 'ประเภทย่อย', ' สมาร์ทโฟน'],
#  ['category_0_14', 'ขนาด', 'เครื่อง 156.9 x 75.8 x 7.8 mm หนัก 168 กรัม '],
#  ['category_0_14', 'หน้าจอ', ' pls tft lcd '],
#  ['category_0_14', 'ความละเอียด', ' 720 x 1520 พิกเซล hd '],
#  ['category_0_14', 'ขนาด', ' 6.2 inch '],
#  ['category_0_14', 'gpu', ' powervr ge8320'],
#  ['category_0_14', 'ram', ' 2gb '],
#  ['category_0_14', 'rom', ' 32gb '],
#  ['category_0_14', 'รองรับ', 'หน่วยความจำเสริม microsd card สูงสุด 512gb'],
#  ['category_0_14', 'รองรับ', 'การบันทึกวีดีโอสูงสุด fhd 1920 x 1080 30fps'],
#  ['category_0_14', 'กล้องหน้า', ' 8 ล้านพิกเซล รูรับแสง f 2.0 '],
#  ['category_0_14', 'รองรับ', 'การทำงานสองซิม'],
#  ['category_0_14', 'รองรับ', ' 2g gsm 3g wcdma 4g lte fdd 4g lte tdd'],
#  ['category_0_14', 'รองรับ', ' wi fi 802.11 b g n 2.4ghz wi fi direct '],
#  ['category_0_14', 'สนับสนุน', 'bluetooth'],
#  ['category_0_14', 'bluetooth', ' 4.2'],
#  ['category_0_14', 'ระบบปฏิบัติการ', ' android 9 pie oneui '],
#  ['category_0_14', 'สี', 'ที่จำหน่ายในไทย เขียว ดำ แดง'],
#  ['category_0_14', 'แบรนด์', ' samsung '],
#  ['category_0_14', 'sku', ' 594306208 th 1115720937'],
#  ['category_0_14', 'กล้องหน้า', ' ล้านพิกเซล 7ล้านพิกเซล ขึ้นไป'],
#  ['category_0_14', 'โมเดล', ' samsung a10s'],
#  ['category_0_14', 'ระยะเวลาการรับประกัน', ' 1 ปี'],
#  ['category_0_14', 'ความจุแบตเตอรี่', ' 1000 mah ถึง 5000 mah'],
#  ['category_0_15', 'ram', ' 64 gb '],
#  ['category_0_15',
#   'rom',
#   ' 6.4 inch 3 กล้อง สูงสุด 16ล้านพิกเซล ff f2.0 โทรศัพท์มือถือ ฿ 5990.00 ฿ 7290.00 18เปอร์เซนต์ '],
#  ['category_0_15',
#   'รุ่น',
#   ' non slip soft 3d คาร์บอนไฟเบอร์ฝาหลังฟิล์มป้องกันด้านหลังสติกเกอร์ป้องกัน ฿ 55.00 ฿ 92.00 40เปอร์เซนต์ '],
#  ['category_0_15', 'ram', '6 '],
#  ['category_0_15', 'rom', '128 ฿ 7450.00 ฿ 11490.00 35เปอร์เซนต์ '],
#  ['category_0_16', 'หมวดหมู่', ' โทรศัพท์มือถือและแท็บเล็ต'],
#  ['category_0_16', 'ประเภทย่อย', ' สมาร์ทโฟน'],
#  ['category_0_16', 'หน้าจอ', ' 6.1 inch '],
#  ['category_0_16', 'ความละเอียด', '3040x1440 quad hd 550 ppi '],
#  ['category_0_16',
#   'กล้องหลัง',
#   ' 3 ตัว 16ล้านพิกเซล f 2.2 ultra wide 12ล้านพิกเซล f 1.5 และ 2.4 wide 12ล้านพิกเซล f 2.4 tele '],
#  ['category_0_16', 'กล้องหน้า', '10ล้านพิกเซล f 1.9'],
#  ['category_0_16',
#   'หน่วยประมวลผล',
#   'octa core snapdragon 855octa core exynos9 9820'],
#  ['category_0_16', 'ram', ' 8 128 gb'],
#  ['category_0_16', 'แบตเตอรี่', '3400 mah typical '],
#  ['category_0_16', 'แบรนด์', ' samsung '],
#  ['category_0_16', 'sku', ' 289434461 th 479544867'],
#  ['category_0_16', 'โมเดล', ' s10 128gb '],
#  ['category_0_16', 'ระยะเวลาการรับประกัน', ' 1 ปี'],
#  ['category_0_17', 'หมวดหมู่', ' โทรศัพท์มือถือและแท็บเล็ต'],
#  ['category_0_17', 'ประเภทย่อย', ' สมาร์ทโฟน'],
#  ['category_0_17', 'ขนาด', 'น้ำหนัก'],
#  ['category_0_17', 'น้ำหนัก', ' ยาว 163.3 กว้าง 77.5 หนา 8 mm '],
#  ['category_0_17', 'น้ำหนัก', ' 183 กรัม'],
#  ['category_0_17', 'จอ', 'ภาพ ชนิด'],
#  ['category_0_17', 'จอ', 'จอ'],
#  ['category_0_17', 'จอ', 'สัมผัส tft '],
#  ['category_0_17', 'ขนาด', 'ความละเอียด'],
#  ['category_0_17', 'ความละเอียด', ' 6.5 inch 264 ppi 720 1560 px'],
#  ['category_0_17', 'หน้าจอ', ' tft แบบ infinity u '],
#  ['category_0_17', 'จอแสดงผล', 'ขนาด'],
#  ['category_0_17', 'ขนาด', ' 6.5 inch '],
#  ['category_0_17', 'ความละเอียด', ' hd 720 x 1560 พิกเซล อัตราส่วน'],
#  ['category_0_17', 'หน้าจอ', ' 19.5 9'],
#  ['category_0_17', 'หน่วยประมวลผล', 'cpu'],
#  ['category_0_17', 'cpu', ' snapdragon 450 '],
#  ['category_0_17', 'หน่วยประมวลผล', 'gpu'],
#  ['category_0_17', 'gpu', ' adreno 506'],
#  ['category_0_17', 'ram', ' 3 gb '],
#  ['category_0_17', 'rom', ' 32 gb micro sd 512 gb '],
#  ['category_0_17', 'รองรับ', ' 2 ซิมการ์ด '],
#  ['category_0_17', 'รองรับ', 'การเพิ่มความจำด้วย microsd card สูงสุด 512 gb'],
#  ['category_0_17', 'กล้องหลัง', ' 3 ตัว ประกอบด้วย'],
#  ['category_0_17', 'เลนส์', 'หลัก '],
#  ['category_0_17', 'ความละเอียด', ' 13ล้านพิกเซล f 1.8 '],
#  ['category_0_17', 'เลนส์', ' ultra wide 120 องศา '],
#  ['category_0_17', 'ความละเอียด', ' 8ล้านพิกเซล f 2.2 '],
#  ['category_0_17', 'เลนส์', ' depth '],
#  ['category_0_17', 'ความละเอียด', ' 5ล้านพิกเซล f 2.2 '],
#  ['category_0_17', 'รองรับ', 'ระบบเ'],
#  ['category_0_17', 'สี', 'ยง dolby atmos เซ็นเซอร์ accele'],
#  ['category_0_17',
#   'rom',
#   'eter fingerprint sensor gyro sensor geomagnetic sensor light sensor proximity sensor การเชื่อมต่อ '],
#  ['category_0_17',
#   'bluetooth',
#   ' 4.2 wi fi 802.11 b g n 2.4ghz 3.5mm earjack '],
#  ['category_0_17',
#   'usb',
#   ' type c wi fi direct gps glonass beidou galileo pc sync. 2g gsm850 gsm900 dcs1800 pcs1900 3g b1 2100 b2 1900 b5 850 b8 900 4g lte '],
#  ['category_0_17',
#   'รองรับ',
#   ' 15w fast charging ระบบปฎิบัติการ android 9.0 pi'],
#  ['category_0_17', 'สี', 'ให้เลือก colors ดำ แดง เขียว'],
#  ['category_0_17', 'แบรนด์', ' samsung '],
#  ['category_0_17', 'sku', ' 594338092 th 1115814517'],
#  ['category_0_17', 'กล้องหน้า', ' ล้านพิกเซล 7ล้านพิกเซล ขึ้นไป'],
#  ['category_0_17', 'โมเดล', ' samsung a20s'],
#  ['category_0_17', 'ระยะเวลาการรับประกัน', ' 1 ปี'],
#  ['category_0_17', 'ความจุแบตเตอรี่', ' 1000 mah ถึง 5000 mah'],
#  ['category_0_18', 'หมวดหมู่', ' โทรศัพท์มือถือและแท็บเล็ต'],
#  ['category_0_18', 'ประเภทย่อย', ' สมาร์ทโฟน'],
#  ['category_0_18', 'หน้าจอ', ' super amoled '],
#  ['category_0_18', 'ขนาด', ' 6.7 inch '],
#  ['category_0_18', 'ความละเอียด', ' fhd 1080 x 2400 '],
#  ['category_0_18', 'cpu', ' snapdragon 730'],
#  ['category_0_18', 'ram', ' 8gb ddr4'],
#  ['category_0_18', 'ความจุ', ' 128gb ufs 2.1 ไม่'],
#  ['category_0_18', 'รองรับ', ' microsd card'],
#  ['category_0_18',
#   'กล้องหน้า',
#   ' หลัง 4ล้านพิกเซล f 2.0 imx586 ultra wide ล้านพิกเซล f 2.2 tof'],
#  ['category_0_18', 'แบตเตอรี่', ' 3700 mah '],
#  ['category_0_18', 'รองรับ', ' super fast charging 25w'],
#  ['category_0_18', 'แบรนด์', ' samsung '],
#  ['category_0_18', 'sku', ' 340860812 th 661136678'],
#  ['category_0_18', 'ระยะเวลาการรับประกัน', ' 1 ปี'],
#  ['category_0_18', 'ระบบปฏิบัติการ', ' android'],
#  ['category_0_18', 'ระบบปฏิบัติการ', 'เวอร์ชัน android 9.0 pie'],
#  ['category_0_18', 'โมเดล', ' a80'],
#  ['category_0_18', 'ram', ' 8gb'],
#  ['category_0_18', 'ขนาดหน้าจอ', ' นิ้ว 6.7'],
#  ['category_0_18', 'ความจุแบตเตอรี่', ' 3000 3999 mah'],
#  ['category_0_18', 'สี', 'ยบแบบบาง คู่'],
#  ['category_0_19', 'หมวดหมู่', ' โทรศัพท์มือถือและแท็บเล็ต'],
#  ['category_0_19', 'ประเภทย่อย', ' สมาร์ทโฟน'],
#  ['category_0_19', 'รองรับ', ' 2 ซิมการ์ด'],
#  ['category_0_19', 'จอแสดงผล', ' super amoled 24 bit 16 ล้าน'],
#  ['category_0_19', 'สี', ' ระบบสัมผัส multi touch กว้าง 6.4 inch แนวทะแยง '],
#  ['category_0_19',
#   'ความละเอียด',
#   ' 2960 x 1440 พิกเซล capacitive corning gorilla glass 5 ระบบป้องกัน ฝุ่นละออง resistance to dust '],
#  ['category_0_19', 'rom', 'eter ระบบเปิด ปิด'],
#  ['category_0_19',
#   'หน้าจอ',
#   'อัตโนมัติขณะสนทนา proximity ระบบเซนเซอร์หมุนภาพ gyroscope ระบบวัดความกดอากาศ ba'],
#  ['category_0_19', 'rom', 'eter '],
#  ['category_0_19', 'รองรับ', ' s pen ระบบปากกาอัจฉริยะ ระบบสแกนม่านตา'],
#  ['category_0_19', 'ระบบปฏิบัติการ', ' android 8.1 oreo'],
#  ['category_0_19', 'หน่วยประมวลผล', ' exynos 9810 octa core ความเร็ว 2.7 ghz'],
#  ['category_0_19', 'rom', ' 128gb '],
#  ['category_0_19', 'ram', ' 6gb'],
#  ['category_0_19', 'usb', ' type c'],
#  ['category_0_19', 'สี', 'ยบชุดหูฟัง 3.5 mm '],
#  ['category_0_19',
#   'ขนาด',
#   ' 1.5 ไฟแฟลช led ซูมออฟติคอล 2 เท่า 2x optical zoom โฟกัสอัตโนมัติ auto focus แตะเลือกจุดโฟกัส touch focus ระบบป้องกันภาพสั่นไหวแบบออปติคอล ois ค้นหาใบหน้าอัตโนมัติ face detection โหมดถ่ายภาพพาโนราม่า pano'],
#  ['category_0_19', 'ram', 'a '],
#  ['category_0_19', 'กล้องหน้า', ' front camera '],
#  ['category_0_19', 'ความละเอียด', ' 8ล้านพิกเซล รูรับแสง'],
#  ['category_0_19', 'ขนาด', ' 1.7'],
#  ['category_0_19', 'สี', 'ยง dolby atmos'],
#  ['category_0_19', 'สี', 'ยงรบกวนการสนทนา'],
#  ['category_0_19', 'แบตเตอรี่', 'มาตรฐาน 4000 mah standard battery '],
#  ['category_0_19', 'แบรนด์', ' samsung '],
#  ['category_0_19', 'sku', ' 283666353 th 461390461'],
#  ['category_0_19',
#   'โมเดล',
#   ' samsung galaxy note 9 6gb 128gb เครื่องศูนย์ มีประกัน ocean blue '],
#  ['category_0_19', 'ระยะเวลาการรับประกัน', ' 1 ปี'],
#  ['category_0_19', 'ระบบปฏิบัติการ', ' android'],
#  ['category_0_20', 'หมวดหมู่', ' โทรศัพท์มือถือและแท็บเล็ต'],
#  ['category_0_20', 'ประเภทย่อย', ' สมาร์ทโฟน'],
#  ['category_0_20', 'น้ำหนัก', ' 168 กรัม'],
#  ['category_0_20', 'หน้าจอ', 'แสดงผล tft lcd กว้าง 6.2 inch '],
#  ['category_0_20',
#   'ความละเอียด',
#   ' 1520x720 พิกเซล hd มีดีไซน์รอยแหว่งแบบ infinity v'],
#  ['category_0_20', 'ram', ' 2gb'],
#  ['category_0_20', 'rom', ' 32gb เพิ่ม microsd card ได้สูงสุด 512gb'],
#  ['category_0_20', 'ระบบปฏิบัติการ', ' one ui 1.1 บนพื้นฐาน android 9 pie'],
#  ['category_0_20', 'กล้องหลัง', ' 2 '],
#  ['category_0_20', 'เลนส์', ' พร้อมไฟแฟลช'],
#  ['category_0_20', 'เลนส์', 'หลัก '],
#  ['category_0_20', 'ความละเอียด', ' 13 ล้านพิกเซล รูรับแสง f 1.8'],
#  ['category_0_20', 'เลนส์', ' depth '],
#  ['category_0_20', 'ความละเอียด', ' 2 ล้านพิกเซล รูรับแสง f 2.4'],
#  ['category_0_20', 'กล้องหน้า', 'ความละเอียด'],
#  ['category_0_20', 'ความละเอียด', ' 8 ล้านพิกเซล รูรับแสง f 2.2'],
#  ['category_0_20', 'รองรับ', ' 2 ซิมแบบ nano sim'],
#  ['category_0_20', 'port', ' micro '],
#  ['category_0_20', 'usb', ' 2.0 ช่องเ'],
#  ['category_0_20', 'สี', 'ยบหูฟัง 3.5 mm '],
#  ['category_0_20', 'แบตเตอรี่', ' 4000mah'],
#  ['category_0_20', 'usb', ' 2.0'],
#  ['category_0_20', 'แบรนด์', ' samsung '],
#  ['category_0_20', 'sku', ' 616572478 th 1170962904'],
#  ['category_0_20', 'ระยะเวลาการรับประกัน', ' 1 ปี'],
#  ['category_0_20', 'แบตเตอรี่', ' built in rechargeable battery'],
#  ['category_0_20', 'กล้องหน้า', ' ล้านพิกเซล 7ล้านพิกเซล ขึ้นไป'],
#  ['category_0_20', 'ระบบปฏิบัติการ', 'เวอร์ชัน android 9.0 pie'],
#  ['category_0_20', 'โมเดล', ' samsung galaxy a10s sm a107f '],
#  ['category_0_21', 'หมวดหมู่', ' โทรศัพท์มือถือและแท็บเล็ต'],
#  ['category_0_21', 'ประเภทย่อย', ' สมาร์ทโฟน'],
#  ['category_0_21', 'แบรนด์', ' samsung '],
#  ['category_0_21', 'sku', ' 307684896 th 537048806'],
#  ['category_0_21', 'โมเดล', ' samsung galaxy j4 plus'],
#  ['category_0_21', 'ระยะเวลาการรับประกัน', ' 1 ปี'],
#  ['category_0_22', 'หมวดหมู่', ' โทรศัพท์มือถือและแท็บเล็ต'],
#  ['category_0_22', 'ประเภทย่อย', ' สมาร์ทโฟน'],
#  ['category_0_22', 'ขนาดหน้าจอ', ' 6.3 inch '],
#  ['category_0_22', 'ram', ' 8 gb'],
#  ['category_0_22', 'ความจุ', 'ที่เก็บข้อมูล 256 gb'],
#  ['category_0_22', 'แบตเตอรี่', ' 3500 mah typical '],
#  ['category_0_22', 'มาตรฐานการกันน้ำและกันฝุ่น', ' ip68'],
#  ['category_0_22', 'แบรนด์', ' samsung '],
#  ['category_0_22', 'sku', ' 373972071 th 728742055'],
#  ['category_0_22', 'โมเดล', ' 8 256gb'],
#  ['category_0_22', 'ระยะเวลาการรับประกัน', ' 1 ปี'],
#  ['category_0_23', 'หมวดหมู่', ' โทรศัพท์มือถือและแท็บเล็ต'],
#  ['category_0_23', 'ประเภทย่อย', ' สมาร์ทโฟน'],
#  ['category_0_23', 'หน้าจอ', 'กว้าง'],
#  ['category_0_23', 'ขนาด', ' 6.3 ใหญ่ที่สุดในตระกูล note'],
#  ['category_0_23', 'หน้าจอ', 'กว้างขึ้น ด้วย'],
#  ['category_0_23',
#   'ขนาด',
#   ' 6.3 ใหญ่ที่สุดในตระกูล note มอบภาพที่คมชัด แจ้มแจ้งในทุกรายละเอียด'],
#  ['category_0_23', 'หน้าจอ', 'ที่มาก ปรับแต่งรายการต่างๆ พร้อมขยับ'],
#  ['category_0_23', 'จอ', 'น้อยลง'],
#  ['category_0_23', 'แบรนด์', ' samsung '],
#  ['category_0_23', 'sku', ' 310302392 th 552106447'],
#  ['category_0_23', 'โมเดล', ' sm n950'],
#  ['category_0_23', 'ระยะเวลาการรับประกัน', ' 1 ปี'],
#  ['category_0_24', 'หมวดหมู่', ' โทรศัพท์มือถือและแท็บเล็ต'],
#  ['category_0_24', 'ประเภทย่อย', ' สมาร์ทโฟน'],
#  ['category_0_24', 'จอแสดงผล', ' super amoled 24 bit 16 ล้าน'],
#  ['category_0_24', 'สี', ' fullview '],
#  ['category_0_24', 'จอแสดงผล', ' กว้าง 6.3 inch '],
#  ['category_0_24', 'ขนาด', ' 1.7'],
#  ['category_0_24', 'กล้องหน้า', 'ความละเอียด'],
#  ['category_0_24', 'ความละเอียด', ' 24ล้านพิกเซล '],
#  ['category_0_24', 'ram', ' 6gb'],
#  ['category_0_24', 'แบรนด์', ' samsung '],
#  ['category_0_24', 'sku', ' 280354579 th 453591358'],
#  ['category_0_24', 'ระยะเวลาการรับประกัน', ' 5 วัน'],
#  ['category_0_24', 'ระบบปฏิบัติการ', ' android'],
#  ['category_0_24', 'กล้องหน้า', ' ล้านพิกเซล 7ล้านพิกเซล ขึ้นไป'],
#  ['category_0_24', 'ระบบปฏิบัติการ', 'เวอร์ชัน android 8.0 oreo'],
#  ['category_0_24',
#   'โมเดล',
#   ' samsung galaxy a9 2018 6 128gb เครื่องศูนย์ เคลียสตอคไม่มีประกัน caviar black '],
#  ['category_0_24', 'ram', ' 6gb'],
#  ['category_0_24', 'ขนาดหน้าจอ', ' นิ้ว 6.3'],
#  ['category_0_24', 'ความจุแบตเตอรี่', ' 1000 mah ถึง 5000 mah'],
#  ['category_0_24', 'สี', 'ยบแบบบาง คู่'],
#  ['category_0_25', 'หมวดหมู่', ' โทรศัพท์มือถือและแท็บเล็ต'],
#  ['category_0_25', 'ประเภทย่อย', ' สมาร์ทโฟน'],
#  ['category_0_25', 'จอแสดงผล', ' super amoled 24 bit 16 ล้าน'],
#  ['category_0_25', 'สี', 'หน้าจอ'],
#  ['category_0_25',
#   'หน้าจอ',
#   'ทรงหยดน้ำ รูปตัว u infinity u ระบบสัมผัส multi touch กว้าง 6.7 inch แนวทะแยง '],
#  ['category_0_25',
#   'ความละเอียด',
#   ' 1080 x 2400 พิกเซล capacitiveระบบเซ็นเซอร์ sensor ระบบสแกนลายนิ้วมือใต้'],
#  ['category_0_25', 'หน้าจอ', ' fingerprint under '],
#  ['category_0_25',
#   'จอแสดงผล',
#   ' ระบบจดจำใบหน้า face detection ระบบหมุนภาพอัตโนมัติ accele'],
#  ['category_0_25', 'rom', 'eter ตรวจจับแสงปรับ'],
#  ['category_0_25', 'ความสว่าง', 'อัตโนมัติ ambient light ระบบเปิด ปิด'],
#  ['category_0_25',
#   'หน้าจอ',
#   'อัตโนมัติขณะสนทนา proximity ระบบเซนเซอร์หมุนภาพ gyroscope ปรับมุมมองการแสดงผลอัตโนมัติ orientation '],
#  ['category_0_25', 'ระบบปฏิบัติการ', ' android 9 pie'],
#  ['category_0_25',
#   'หน่วยประมวลผล',
#   ' snapdragon 675 octa core ความเร็ว 2.0 ghzหน่วยความจำ '],
#  ['category_0_25', 'rom', ' 128gb '],
#  ['category_0_25',
#   'ram',
#   ' 8gbการ์ดหน่วยความจำ microsd สูงสุด 512 gb กล้องดิจิตอล 3ล้านพิกเซล 8 ultra wide 5 triple camera รูรับแสง'],
#  ['category_0_25',
#   'ขนาด',
#   ' 1.7 ไฟแฟลช led ค้นหาใบหน้าอัตโนมัติ face detection เทคโนโลยีถ่ายภาพอัจฉริยะ ai camera โหมดปรับหน้าสวยอัตโนมัติ ai face beauty โหมดเปลี่ยนภาพเซลฟี่เป็นอิโมจิ ar emoji โหมดเปลี่ยนภาพเซลฟี่เป็นสติกเกอร์ ar sticker โหมดถ่ายภาพพาโนราม่า pano'],
#  ['category_0_25', 'ram', 'a โหมดถ่ายภาพช่วงการรับแสงสูง hdr '],
#  ['category_0_25', 'กล้องหน้า', ' front camera '],
#  ['category_0_25', 'ความละเอียด', ' 32 รูรับแสง'],
#  ['category_0_25', 'ขนาด', ' 2.0 '],
#  ['category_0_25',
#   'กล้องหน้า',
#   ' hdr บันทึกวีดีโอ ภาพเคลื่อนไหว video recording รูปแบบไฟล์วีดีโอ ล้านพิกเซล eg 4 เครื่องเล่นวีดีโอ video player รูปแบบไฟล์ ล้านพิกเซล eg 4 '],
#  ['category_0_25',
#   'รองรับ',
#   'วีดีโอจาก youtube เครื่องเล่นเพลง music player รูปแบบไฟล์ ล้านพิกเซล 3 ระบบเ'],
#  ['category_0_25', 'สี', 'ยง dolby atmosเทคโนโลยีเพิ่มความเร็วในการชาร์จ'],
#  ['category_0_25', 'แบตเตอรี่', 'มาตรฐาน 4500 mah standard battery '],
#  ['category_0_25', 'แบรนด์', ' samsung '],
#  ['category_0_25', 'sku', ' 595150747 th 1117932783'],
#  ['category_0_25', 'โมเดล', ' samsung a70'],
#  ['category_0_26', 'หมวดหมู่', ' โทรศัพท์มือถือและแท็บเล็ต'],
#  ['category_0_26', 'ประเภทย่อย', ' สมาร์ทโฟน'],
#  ['category_0_26', 'จอ', 'คุณภาพสูงfull front '],
#  ['category_0_26', 'จอแสดงผล', ' samoled'],
#  ['category_0_26', 'กล้องหน้า', ' และ หลัง'],
#  ['category_0_26', 'ความละเอียด', 'เท่ากัน 16ล้านพิกเซล '],
#  ['category_0_26',
#   'กล้องหน้า',
#   'มาพร้อม3 step lighting ช่วยปรับแสงได้ 3 ระดับ และ'],
#  ['category_0_26', 'กล้องหลัง', ' รูรับแสงกว้าง f1.7'],
#  ['category_0_26', 'หน้าจอ', 'ในคลิ๊กเดียว'],
#  ['category_0_26', 'รองรับ', 'แอพsocial เยอะที่สุดถึง 18 แอพ'],
#  ['category_0_26', 'แบรนด์', ' samsung '],
#  ['category_0_26', 'sku', ' 264741378 th 411062149'],
#  ['category_0_26', 'โมเดล', ' galaxy a6 sm a605g ds '],
#  ['category_0_26', 'ram', ' 4gb'],
#  ['category_0_26', 'ขนาดหน้าจอ', ' นิ้ว 6'],
#  ['category_0_26', 'ระยะเวลาการรับประกัน', ' 1 ปี'],
#  ['category_0_27', 'หมวดหมู่', ' โทรศัพท์มือถือและแท็บเล็ต'],
#  ['category_0_27', 'ประเภทย่อย', ' สมาร์ทโฟน'],
#  ['category_0_27', 'ram', ' original set it is a '],
#  ['category_0_27',
#   'แบรนด์',
#   ' new original packaging undamaged unopened unused item it is original and packaging is the same as what is found in the retail store unless the item is handmade or was packaged by the manufacturer in non retail packaging such as an unprinted box or plastic bag '],
#  ['category_0_27', 'แบรนด์', ' samsung '],
#  ['category_0_27', 'sku', ' 617108827 th 1172618764'],
#  ['category_0_27', 'ระบบปฏิบัติการ', 'เวอร์ชัน android 9.0 pie'],
#  ['category_0_27', 'โมเดล', ' samsung galaxy a50s 128gb 6gb '],
#  ['category_0_27', 'ram', ' original set'],
#  ['category_0_27', 'ระยะเวลาการรับประกัน', ' 1 ปี'],
#  ['category_0_27', 'สี', 'ยบแบบบาง คู่'],
#  ['category_0_28', 'หมวดหมู่', ' โทรศัพท์มือถือและแท็บเล็ต'],
#  ['category_0_28', 'ประเภทย่อย', ' สมาร์ทโฟน'],
#  ['category_0_28', 'หน้าจอ', 'ใหญ่ที่เต็มตากว่าเดิม'],
#  ['category_0_28', 'แบรนด์', ' samsung '],
#  ['category_0_28', 'sku', ' 511068392 th 907938105'],
#  ['category_0_28', 'โมเดล', ' galaxy a20s 3 32gb '],
#  ['category_0_28', 'ระยะเวลาการรับประกัน', ' 1 ปี'],
#  ['category_0_29', 'หมวดหมู่', ' โทรศัพท์มือถือและแท็บเล็ต'],
#  ['category_0_29', 'ประเภทย่อย', ' สมาร์ทโฟน'],
#  ['category_0_29', 'หน้าจอ', 'ใหญ่ super amoled 5.6 inch สัดส่วน 18.5 9'],
#  ['category_0_29', 'rom', ' 32gb '],
#  ['category_0_29', 'ram', ' 4gb เพิ่ม microsd สูงสุด 256gb'],
#  ['category_0_29', 'ระบบปฏิบัติการ', 'แอนดรอยด์ 7.1 nougat '],
#  ['category_0_29', 'กล้องหน้า', 'แบบคู่ 16 และ 8 ล้านพิกเซล รูรับแสง f 1.9'],
#  ['category_0_29', 'หน้าจอ', 'ด้วยการสแกนใบหน้า'],
#  ['category_0_29', 'รองรับ', 'การใช้งาน secure folder'],
#  ['category_0_29', 'รองรับ', 'การสแกนลายนิ้วมือ'],
#  ['category_0_29', 'หน้าจอ', 'ใหญ่ super amoled 5.6 inch สัดส่วน 18.5 9'],
#  ['category_0_29', 'rom', ' 32gb '],
#  ['category_0_29', 'ram', ' 4gb เพิ่ม microsd สูงสุด 256gb'],
#  ['category_0_29', 'ระบบปฏิบัติการ', 'แอนดรอยด์ 7.1 nougat '],
#  ['category_0_29', 'กล้องหน้า', 'แบบคู่ 16 และ 8 ล้านพิกเซล รูรับแสง f 1.9'],
#  ['category_0_29', 'หน้าจอ', 'ด้วยการสแกนใบหน้า'],
#  ['category_0_29', 'รองรับ', 'การใช้งาน secure folder'],
#  ['category_0_29', 'รองรับ', 'การสแกนลายนิ้วมือ'],
#  ['category_0_29', 'แบรนด์', ' samsung '],
#  ['category_0_29', 'sku', ' 207916690 th 313021622'],
#  ['category_0_29', 'โมเดล', ' refurbish samsung galaxy a8 2018 gold'],
#  ['category_0_29', 'ระยะเวลาการรับประกัน', ' 3 เดือน'],
#  ['category_0_30', 'หมวดหมู่', ' โทรศัพท์มือถือและแท็บเล็ต'],
#  ['category_0_30', 'ประเภทย่อย', ' สมาร์ทโฟน'],
#  ['category_0_30', 'หน้าจอ', ' 6.4 inch '],
#  ['category_0_30', 'ความละเอียด', ' 3040x1440 quad hd 550 ppi '],
#  ['category_0_30',
#   'กล้องหลัง',
#   ' 3 ตัว 16ล้านพิกเซล f 2.2 ultra wide 12ล้านพิกเซล f 1.5 และ 2.4 wide 12ล้านพิกเซล f 2.4 tele '],
#  ['category_0_30',
#   'กล้องหน้า',
#   ' 2 ตัว 10ล้านพิกเซล f 1.9 main 8ล้านพิกเซล f 2.2 live focus '],
#  ['category_0_30',
#   'หน่วยประมวลผล',
#   ' octa core snapdragon 855 octa core exynos9 9820'],
#  ['category_0_30', 'ram', ' 8 128 gb'],
#  ['category_0_30', 'แบตเตอรี่', ' 4100 mah typical '],
#  ['category_0_30', 'แบรนด์', ' samsung '],
#  ['category_0_30', 'sku', ' 289426638 th 479560515'],
#  ['category_0_30', 'โมเดล', ' s10 128gb '],
#  ['category_0_30', 'ระยะเวลาการรับประกัน', ' 1 ปี'],
#  ['category_0_31', 'หมวดหมู่', ' โทรศัพท์มือถือและแท็บเล็ต'],
#  ['category_0_31', 'ประเภทย่อย', ' สมาร์ทโฟน'],
#  ['category_0_31', 'ระบบปฏิบัติการ', ' os '],
#  ['category_0_31', 'cpu', 'ระบบปฏิบัติการ'],
#  ['category_0_31', 'ระบบปฏิบัติการ', ' android 8.0 oreo '],
#  ['category_0_31', 'หน่วยประมวลผล', ' qualcomm snapdragon 450 octa core'],
#  ['category_0_31', 'ram', ' 3gb การ์ดหน่วยความจำ'],
#  ['category_0_31', 'แบรนด์', ' samsung '],
#  ['category_0_31', 'sku', ' 289402378 th 479508064'],
#  ['category_0_31', 'โมเดล', ' samsung j8 '],
#  ['category_0_31', 'ram', '3 32gb เครื่องศูนย์ประกันมีเดือน '],
#  ['category_0_31', 'สี', 'ทอง แถมฟรี เคสใส ฟิลม์กระจก'],
#  ['category_0_31', 'ระยะเวลาการรับประกัน', ' 3 เดือน'],
#  ['category_0_31', 'ระบบปฏิบัติการ', ' android'],
#  ['category_0_32', 'ความละเอียด', ' 48ล้านพิกเซล '],
#  ['category_0_32',
#   'จอ',
#   'กว้าง 6.3 inch fhd ชิปเซ็ต qualcomm sd 665 ฿ 4299.00 ฿ 4999.00 14เปอร์เซนต์ '],
#  ['category_0_32', 'ram', '6 '],
#  ['category_0_32',
#   'rom',
#   '128gb เครื่องนอกไม่มีประกัน ฿ 18880.00 ฿ 31900.00 41เปอร์เซนต์ '],
#  ['category_0_32', 'ram', '8gb '],
#  ['category_0_32',
#   'rom',
#   '256gb aura pink ฿ 24280.00 ฿ 29500.00 18เปอร์เซนต์ '],
#  ['category_0_32', 'ram', '8gb '],
#  ['category_0_32',
#   'rom',
#   '256gb aura glow ฿ 24280.00 ฿ 29500.00 18เปอร์เซนต์ '],
#  ['category_0_32', 'ram', ' 64 gb '],
#  ['category_0_32',
#   'rom',
#   ' 10.5 inch แท็บเล็ต ฿ 13990.00 ฿ 23900.00 41เปอร์เซนต์ '],
#  ['category_0_33', 'หมวดหมู่', ' โทรศัพท์มือถือและแท็บเล็ต'],
#  ['category_0_33', 'ประเภทย่อย', ' สมาร์ทโฟน'],
#  ['category_0_33', 'แบรนด์', ' new'],
#  ['category_0_33', 'แบรนด์', ' samsung '],
#  ['category_0_33', 'sku', ' 612014873 th 1155486191'],
#  ['category_0_33', 'ระบบปฏิบัติการ', 'เวอร์ชัน android 8.1 oreo'],
#  ['category_0_33', 'โมเดล', ' samsung galaxy note 10 plus'],
#  ['category_0_33', 'ระยะเวลาการรับประกัน', ' 1 ปี'],
#  ['category_0_33', 'สี', 'ยบแบบบาง คู่'],
#  ['category_0_34', 'หมวดหมู่', ' โทรศัพท์มือถือและแท็บเล็ต'],
#  ['category_0_34', 'ประเภทย่อย', ' สมาร์ทโฟน'],
#  ['category_0_34', 'รองรับ', ' 2 ซิมการ์ด'],
#  ['category_0_34', 'จอแสดงผล', ' super amoled 24 bit 16ล้าน'],
#  ['category_0_34', 'สี', ' ระบบสัมผัส multi touch กว้าง6.4 inch แนวทะแยง '],
#  ['category_0_34',
#   'ความละเอียด',
#   ' 2960x1440 พิกเซล capacitive corning gorilla glass5 ระบบป้องกันฝุ่นละออง resistance to dust '],
#  ['category_0_34', 'rom', 'eter ระบบเปิด ปิด'],
#  ['category_0_34',
#   'หน้าจอ',
#   'อัตโนมัติขณะสนทนา proximity ระบบเซ็นเซอร์หมุนภาพ gyroscope ระบบวัดความกดอากาศ ba'],
#  ['category_0_34', 'rom', 'eter '],
#  ['category_0_34', 'รองรับ', ' s pen ระบบปากกาอัจฉริยะ ระบบสแกนม่านตา'],
#  ['category_0_34', 'ระบบปฏิบัติการ', ' android 8.1 oreo'],
#  ['category_0_34', 'หน่วยประมวลผล', ' exynos 9810octa core ความเร็ว 2.7 ghz'],
#  ['category_0_34', 'rom', '128gb '],
#  ['category_0_34', 'ram', ' 6gb'],
#  ['category_0_34', 'รองรับ', 'ได้สูงสุด 512 gb'],
#  ['category_0_34', 'usb', ' type c'],
#  ['category_0_34', 'สี', 'ยบชุดหูฟัง 3.5 mm '],
#  ['category_0_34', 'ram', 'a '],
#  ['category_0_34', 'กล้องหน้า', ' front camera '],
#  ['category_0_34', 'ความละเอียด', ' 8ล้านพิกเซล '],
#  ['category_0_34', 'สี', 'ยง dolby atmos'],
#  ['category_0_34', 'สี', 'ยงรบกวนการสนทนา'],
#  ['category_0_34', 'wireless', ' charge '],
#  ['category_0_34', 'แบตเตอรี่', 'มาตรฐาน 4000 mah standard battery '],
#  ['category_0_34', 'แบรนด์', ' samsung '],
#  ['category_0_34', 'sku', ' 283658415 th 461387419'],
#  ['category_0_34',
#   'โมเดล',
#   ' samsung galaxy note 9 6gb 128gb เครื่องศูนย์ มีประกัน midnight black ระ'],
#  ['category_0_34', 'ระยะเวลาการรับประกัน', ' 1 ปี'],
#  ['category_0_34', 'ระบบปฏิบัติการ', ' android'],
#  ['category_0_35', 'หมวดหมู่', ' โทรศัพท์มือถือและแท็บเล็ต'],
#  ['category_0_35', 'ประเภทย่อย', ' สมาร์ทโฟน'],
#  ['category_0_35', 'แบรนด์', ' new'],
#  ['category_0_35', 'แบรนด์', ' samsung '],
#  ['category_0_35', 'sku', ' 610820644 th 1151996547'],
#  ['category_0_35', 'ระบบปฏิบัติการ', 'เวอร์ชัน android 8.0 oreo'],
#  ['category_0_35', 'โมเดล', ' samsung galaxy s10 plus'],
#  ['category_0_35', 'ระยะเวลาการรับประกัน', ' 1 ปี'],
#  ['category_0_35', 'สี', 'ยบแบบบาง คู่'],
#  ['category_0_36', 'หมวดหมู่', ' โทรศัพท์มือถือและแท็บเล็ต'],
#  ['category_0_36', 'ประเภทย่อย', ' สมาร์ทโฟน'],
#  ['category_0_36',
#   'แบรนด์',
#   ' new original packaging undamaged unopened unused item it is original and packaging is the same as what is found in the retail store unless the item is handmade or was packaged by the manufacturer in non retail packaging such as an unprinted box or plastic bag '],
#  ['category_0_36', 'แบรนด์', ' samsung '],
#  ['category_0_36', 'sku', ' 617168251 th 1172664402'],
#  ['category_0_36', 'ระบบปฏิบัติการ', 'เวอร์ชัน android 9.0 pie'],
#  ['category_0_36', 'โมเดล', ' samsung galaxy note 9 8gb 512gb '],
#  ['category_0_36', 'ระยะเวลาการรับประกัน', ' 1 ปี'],
#  ['category_0_36', 'สี', 'ยบแบบบาง คู่'],
#  ['category_0_37', 'ram', ' 64 gb '],
#  ['category_0_37',
#   'rom',
#   ' 6.4 inch 3 กล้อง สูงสุด 16ล้านพิกเซล ff f2.0 โทรศัพท์มือถือ ฿ 5990.00 ฿ 7290.00 18เปอร์เซนต์ '],
#  ['category_0_37', 'ram', '12gb '],
#  ['category_0_37',
#   'rom',
#   '256gb aura blue ฿ 29330.00 ฿ 35850.00 18เปอร์เซนต์ '],
#  ['category_0_37', 'รุ่น', ' s9 plus 256gb '],
#  ['category_0_37', 'สี', 'ฟ้า ฿ 7900.00 ฿ 13590.00 42เปอร์เซนต์ '],
#  ['category_0_37', 'ram', '6 '],
#  ['category_0_37', 'rom', '128 ฿ 7450.00 ฿ 11490.00 35เปอร์เซนต์ '],
#  ['category_0_38', 'หมวดหมู่', ' โทรศัพท์มือถือและแท็บเล็ต'],
#  ['category_0_38', 'ประเภทย่อย', ' สมาร์ทโฟน'],
#  ['category_0_38', 'หน้าจอ', ' samoled full '],
#  ['category_0_38',
#   'จอแสดงผล',
#   ' ไร้กรอบ ไร้ปุ่มโฮม เพิ่มมุมมองการเห็น ด้วยสัดส่วน 19.5 9 '],
#  ['category_0_38', 'จอ', 'กว้างขึ้น พร้อม'],
#  ['category_0_38', 'ความละเอียด', ' fhd เพื่อการชมภาพยนตร์ที่เต็มอิ่มมากขึ้น'],
#  ['category_0_38',
#   'เลนส์',
#   'หลัก 16ล้านพิกเซล tetra cell f1.7 ถ่ายภาพชัด ทั้งแสงน้อย และ แสงมาก และ scene optimizer กล้องอัจฉริยะ วิเคราะห์ฉาก และวัตถุได้ 19 ชนิด เพื่อปรับ'],
#  ['category_0_38',
#   'สี',
#   ' และคอนทราสให้เหมาะกับวัตถุและภาพที่ถ่ายแบบอัตโนมัติ'],
#  ['category_0_38',
#   'เลนส์',
#   ' ultra wide ล้านพิกเซล f2.2 ถ่ายภาพมุมกว้าง เก็บได้ครบถึง 123 องศา ได้เหมือนตามนุษย์ '],
#  ['category_0_38', 'sound', ' effect dolby atmos เมื่อใส่หูฟังเท่านั้น'],
#  ['category_0_38', 'แบรนด์', ' samsung '],
#  ['category_0_38', 'sku', ' 299990648 th 515722325'],
#  ['category_0_38', 'โมเดล', ' galaxy a30 4 64gb '],
#  ['category_0_38', 'ระยะเวลาการรับประกัน', ' 1 ปี'],
#  ['category_0_39', 'หมวดหมู่', ' โทรศัพท์มือถือและแท็บเล็ต'],
#  ['category_0_39', 'ประเภทย่อย', ' สมาร์ทโฟน'],
#  ['category_0_39', 'แบรนด์', ' samsung '],
#  ['category_0_39', 'sku', ' 408012228 th 792604544'],
#  ['category_0_39', 'โมเดล', ' galaxy a10s 2 32gb'],
#  ['category_0_39', 'ระยะเวลาการรับประกัน', ' 1 ปี'],
#  ['category_0_40', 'หมวดหมู่', ' โทรศัพท์มือถือและแท็บเล็ต'],
#  ['category_0_40', 'ประเภทย่อย', ' สมาร์ทโฟน'],
#  ['category_0_40', 'หน้าจอ', ' 5.45 inch '],
#  ['category_0_40', 'ความละเอียด', ' hd 1440 x 720 พิกเซล'],
#  ['category_0_40', 'ระบบปฏิบัติการ', ' android 9 pie ครอบทับด้วย miui 10'],
#  ['category_0_40', 'gpu', ' adreno 505'],
#  ['category_0_40', 'ram', ' 2gb'],
#  ['category_0_40', 'rom', ' 16gb '],
#  ['category_0_40', 'รองรับ', ' microsd 256gb '],
#  ['category_0_40', 'กล้องหลัง', ' 13ล้านพิกเซล f 2.2 1.12 m พร้อม led flash'],
#  ['category_0_40', 'กล้องหน้า', ' 5ล้านพิกเซล '],
#  ['category_0_40', 'รองรับ', ' face unlock'],
#  ['category_0_40', 'แบตเตอรี่', 'ความจุ'],
#  ['category_0_40', 'ความจุ', ' 4000 mah '],
#  ['category_0_40', 'รองรับ', 'การชาร์จ 5v 2a ผ่าน micro '],
#  ['category_0_40', 'รองรับ', ' dual sim4g lte'],
#  ['category_0_40', 'รองรับ', ' wi fi 802.11 b g n 2.4ghz wifi direct wifi '],
#  ['category_0_40', 'จอแสดงผล', ' hotspot'],
#  ['category_0_40', 'bluetooth', ' 4.2 a2dp ble'],
#  ['category_0_40', 'รองรับ', 'usb'],
#  ['category_0_40', 'usb', ' 2.0'],
#  ['category_0_40', 'usb', ' on the go'],
#  ['category_0_40',
#   'ขนาด',
#   'ตัวเครื่อง 146.30 x 70.41 x 9.55 mm หนัก 165 กรัม'],
#  ['category_0_40', 'แบรนด์', ' xiaomi'],
#  ['category_0_40', 'sku', ' 213755551 th 1138512951'],
#  ['category_0_40', 'กล้องหน้า', ' ล้านพิกเซล 5 6ล้านพิกเซล '],
#  ['category_0_40', 'ระบบปฏิบัติการ', 'เวอร์ชัน android 9.0 pie'],
#  ['category_0_40', 'โมเดล', ' xiaomi redmi 7a 2 32gb '],
#  ['category_0_40', 'ram', ' 2gb'],
#  ['category_0_40', 'ขนาดหน้าจอ', ' นิ้ว 5.45'],
#  ['category_0_40', 'ระยะเวลาการรับประกัน', ' 1 ปี'],
#  ['category_0_40', 'ระบบปฏิบัติการ', ' android'],
#  ['category_0_40', 'ความจุแบตเตอรี่', ' 1000 mah ถึง 5000 mah'],
#  ['category_0_41', 'หมวดหมู่', ' โทรศัพท์มือถือและแท็บเล็ต'],
#  ['category_0_41', 'ประเภทย่อย', ' สมาร์ทโฟน'],
#  ['category_0_41', 'ความละเอียด', ' 4ล้านพิกเซล '],
#  ['category_0_41', 'รองรับ', 'ระบบ'],
#  ['category_0_41', 'จอแสดงผล', ' dot drop'],
#  ['category_0_41', 'สี', 'ยงที่ดียิ่งขึ้น'],
#  ['category_0_41', 'แบรนด์', ' xiaomi'],
#  ['category_0_41', 'sku', ' 222527681 th 889412058'],
#  ['category_0_41', 'กล้องหน้า', ' ล้านพิกเซล 1ล้านพิกเซล '],
#  ['category_0_41', 'ระบบปฏิบัติการ', 'เวอร์ชัน android 9.0 pie'],
#  ['category_0_41', 'โมเดล', ' xiaomi redmi note 8'],
#  ['category_0_41', 'ram', ' 4gb'],
#  ['category_0_41', 'ระยะเวลาการรับประกัน', ' 1 ปี'],
#  ['category_0_41', 'ความจุแบตเตอรี่', ' 4000 4999 mah'],
#  ['category_0_41', 'สี', 'ยบแบบบาง คู่'],
#  ['category_0_42', 'หมวดหมู่', ' โทรศัพท์มือถือและแท็บเล็ต'],
#  ['category_0_42', 'ประเภทย่อย', ' สมาร์ทโฟน'],
#  ['category_0_42', 'แบรนด์', ' xiaomi'],
#  ['category_0_42', 'sku', ' 595884854 th 1119120013'],
#  ['category_0_42', 'ระบบปฏิบัติการ', 'เวอร์ชัน android 9.0 pie'],
#  ['category_0_42', 'โมเดล', ' mi note 10'],
#  ['category_0_42', 'ระยะเวลาการรับประกัน', ' 15 เดือน'],
#  ['category_0_42', 'สี', 'ยบแบบบาง เตียงเดี่ยว'],
#  ['category_0_43', 'หมวดหมู่', ' โทรศัพท์มือถือและแท็บเล็ต'],
#  ['category_0_43', 'ประเภทย่อย', ' สมาร์ทโฟน'],
#  ['category_0_43', 'ขนาด', ' 156.48x75.41x9.4 mm และมี'],
#  ['category_0_43', 'น้ำหนัก', ' 188 กรัม'],
#  ['category_0_43', 'หน้าจอ', 'แสดงผล dot notch '],
#  ['category_0_43', 'จอแสดงผล', 'ขนาด'],
#  ['category_0_43', 'ขนาด', ' 6.22 inch ในอัตราส่วน 19 9 '],
#  ['category_0_43',
#   'ความละเอียด',
#   'ระดับ hd 720x1520 พิกเซล 270 ppi ครอบทับด้วยกระจกขอบโค้งแบบ 2.5d corning gorilla glass 5'],
#  ['category_0_43', 'gpu', ' adreno 505'],
#  ['category_0_43', 'ram', 'ขนาด'],
#  ['category_0_43', 'ขนาด', ' 4gb'],
#  ['category_0_43', 'rom', 'ขนาด'],
#  ['category_0_43', 'ขนาด', ' 64gb พร้อม'],
#  ['category_0_43', 'รองรับ', 'การ์ดหน่วยความจำภายนอกแบบ microsd สูงสุดที่'],
#  ['category_0_43', 'ขนาด', ' 512gb'],
#  ['category_0_43',
#   'ความละเอียด',
#   ' 12 ล้านพิกเซล เซ็นเซอร์รับภาพ sony imx363 พิกเซล'],
#  ['category_0_43', 'ขนาด', ' 1.4 ไมครอน มี'],
#  ['category_0_43', 'ขนาด', 'รูรับแสง f 1.8 กล้องตัวที่สอง'],
#  ['category_0_43', 'เลนส์', ' depth '],
#  ['category_0_43', 'ความละเอียด', ' 2 ล้านพิกเซล '],
#  ['category_0_43', 'รองรับ', 'เทคโนโลยี dual pd ai '],
#  ['category_0_43',
#   'port',
#   'rait และ ai scene detection ในการตรวจจับซีนทั้งหมด 33 '],
#  ['category_0_43', 'ความละเอียด', ' 8 ล้านพิกเซล พิกเซล'],
#  ['category_0_43', 'ขนาด', ' 1.12 ไมครอน มี'],
#  ['category_0_43', 'ขนาด', 'รูรับแสง f 2.0 '],
#  ['category_0_43', 'รองรับ', 'เทคโนโลยี ai selfie '],
#  ['category_0_43', 'port', 'rait'],
#  ['category_0_43', 'ระบบปฏิบัติการ', ' android 9.0 pie'],
#  ['category_0_43', 'รองรับ', 'การใช้งานพร้อมกัน 2 ซิมการ์ด dual sim '],
#  ['category_0_43', 'รองรับ', 'ถาดใส่ซิมการ์ดแบบ triple slot'],
#  ['category_0_43', 'รองรับ', 'การใช้งานบนเครือข่าย 4g lte'],
#  ['category_0_43', 'รองรับ', 'การเชื่อมต่อ wi fi 802.11 b g n และ '],
#  ['category_0_43', 'bluetooth', ' 4.2'],
#  ['category_0_43', 'รองรับ', 'การเชื่อมต่อแบบ '],
#  ['category_0_43', 'usb', ' type c'],
#  ['category_0_43', 'แบรนด์', ' xiaomi'],
#  ['category_0_43', 'sku', ' 611154425 th 1152864043'],
#  ['category_0_43', 'กล้องหน้า', ' ล้านพิกเซล 7ล้านพิกเซล ขึ้นไป'],
#  ['category_0_43', 'ระบบปฏิบัติการ', 'เวอร์ชัน android 9.0 pie'],
#  ['category_0_43', 'โมเดล', ' xiaomi redmi 8 3 32gb '],
#  ['category_0_43', 'ram', ' 4gb'],
#  ['category_0_43', 'ขนาดหน้าจอ', ' นิ้ว 6.22'],
#  ['category_0_43', 'ระยะเวลาการรับประกัน', ' 15 เดือน'],
#  ['category_0_43', 'ความจุแบตเตอรี่', ' 1000 mah ถึง 5000 mah'],
#  ['category_0_43', 'สี', 'ยบแบบบาง คู่'],
#  ['category_0_44', 'หมวดหมู่', ' โทรศัพท์มือถือและแท็บเล็ต'],
#  ['category_0_44', 'ประเภทย่อย', ' สมาร์ทโฟน'],
#  ['category_0_44', 'จอแสดงผล', ' amoled 24 bit 16 ล้าน'],
#  ['category_0_44', 'สี', 'หน้าจอ'],
#  ['category_0_44',
#   'หน้าจอ',
#   'แสดงผล hdr ระบบสัมผัส multi touch กว้าง 6.39 inch แนวทะแยง '],
#  ['category_0_44',
#   'ความละเอียด',
#   ' 2340 x 1080 พิกเซล 403 ppi capacitive corning gorilla glass 5'],
#  ['category_0_44', 'หน้าจอ', ' fingerprint under '],
#  ['category_0_44', 'จอแสดงผล', ' ระบบหมุนภาพอัตโนมัติ accele'],
#  ['category_0_44', 'rom', 'eter ตรวจจับแสงปรับ'],
#  ['category_0_44', 'ความสว่าง', 'อัตโนมัติ ambient light ระบบเปิด ปิด'],
#  ['category_0_44',
#   'หน้าจอ',
#   'อัตโนมัติขณะสนทนา proximity ระบบเซนเซอร์หมุนภาพ gyroscope ปรับมุมมองการแสดงผลอัตโนมัติ orientation '],
#  ['category_0_44',
#   'สี',
#   'ให้เลือก colors carbon black flame red glacier blue'],
#  ['category_0_44', 'รองรับ', ' 2 ซิมการ์ด'],
#  ['category_0_44', 'ระบบปฏิบัติการ', ' miui 10 based on android 9.0 pie '],
#  ['category_0_44',
#   'หน่วยประมวลผล',
#   ' qualcomm snapdragon 855 octa core ความเร็ว 2.84 ghz'],
#  ['category_0_44', 'ram', ' 6 gb '],
#  ['category_0_44', 'rom', ' 64 gb'],
#  ['category_0_44', 'รองรับ', 'แอพพลิเคชั่น egps'],
#  ['category_0_44',
#   'port',
#   'able wi fi hotspot เชื่อมต่อไร้สายระหว่างอุปกรณ์โดยตรง wi fi direct '],
#  ['category_0_44', 'bluetooth', ' 5.0'],
#  ['category_0_44', 'รองรับ', ' nfc near field communication '],
#  ['category_0_44', 'usb', ' 3.1'],
#  ['category_0_44', 'รองรับ', 'การถ่ายโอนข้อมูลกับ flash drive โดยตรง '],
#  ['category_0_44', 'usb', ' on the go '],
#  ['category_0_44', 'สี', 'ยบชุดหูฟัง 3.5 mm '],
#  ['category_0_44',
#   'ขนาด',
#   ' 1.75 ไฟแฟลช dual led ซูมดิจิตอล 10 เท่า 10x digital zoom ซูมออฟติคอล 2 เท่า 2x optical zoom '],
#  ['category_0_44',
#   'ขนาด',
#   'ภาพสูงสุด 8000 x 6000 พิกเซล image size โฟกัสอัตโนมัติ auto focus โหมดฉาก บุคคล เวลากลางคืน ค้นหาใบหน้าอัตโนมัติ face detection เทคโนโลยีถ่ายภาพอัจฉริยะ ai camera โหมดปรับหน้าสวยอัตโนมัติ ai face beauty ตั้งเวลาถ่ายภาพอัตโนมัติ self timer โหมดถ่ายภาพพาโนราม่า pano'],
#  ['category_0_44', 'ram', 'a '],
#  ['category_0_44', 'กล้องหน้า', ' front camera '],
#  ['category_0_44', 'ความละเอียด', ' 20ล้านพิกเซล ไฟแฟลช led รูรับแสง'],
#  ['category_0_44', 'ขนาด', ' 2.2 '],
#  ['category_0_44', 'รองรับ', ' video call สนทนาแบบเห็นภาพ '],
#  ['category_0_44', 'กล้องหน้า', ' hdr '],
#  ['category_0_44', 'กล้องหน้า', 'port'],
#  ['category_0_44', 'port', 'rait '],
#  ['category_0_44', 'กล้องหน้า', 'แบบ pop up'],
#  ['category_0_44',
#   'ความละเอียด',
#   ' hd 3840 x 2160 พิกเซล บันทึกวีดีโอ 4k 60 เฟรมต่อวินาที slow motion'],
#  ['category_0_44', 'รองรับ', 'วีดีโอจาก youtube '],
#  ['category_0_44', 'รองรับ', 'ไฟล์รูปภาพ jpg jpeg bmp gif tiff'],
#  ['category_0_44', 'สี', 'ยงรบกวนการสนทนา'],
#  ['category_0_44', 'แบตเตอรี่', 'มาตรฐาน 4000 mah standard battery '],
#  ['category_0_45', 'ความละเอียด', ' 48ล้านพิกเซล '],
#  ['category_0_45',
#   'จอ',
#   'กว้าง 6.3 inch fhd ชิปเซ็ต qualcomm sd 665 ฿ 4299.00 ฿ 4999.00 14เปอร์เซนต์ '],
#  ['category_0_45', 'ram', ' 64 gb '],
#  ['category_0_45',
#   'rom',
#   ' 10.5 inch แท็บเล็ต ฿ 13990.00 ฿ 23900.00 41เปอร์เซนต์ '],
#  ['category_0_45', 'โมเดล', ' ฿ 11290.00 ฿ 11790.00 4เปอร์เซนต์ '],
#  ['category_0_45', 'ram', '8gb '],
#  ['category_0_45',
#   'rom',
#   '256gb aura glow ฿ 24280.00 ฿ 29500.00 18เปอร์เซนต์ '],
#  ['category_0_45', 'ram', ' 4 gb '],
#  ['category_0_45',
#   'rom',
#   ' 64 gb แบตอึด 5000 mah เครื่องศูนย์ รับประกัน 1 ปี ฿ 5090.00 ฿ 5990.00 15เปอร์เซนต์ '],
#  ['category_0_46', 'หมวดหมู่', ' โทรศัพท์มือถือและแท็บเล็ต'],
#  ['category_0_46', 'ประเภทย่อย', ' สมาร์ทโฟน'],
#  ['category_0_46', 'หน้าจอ', 'กว้าง 6.01 inch '],
#  ['category_0_46', 'หน้าจอ', ' และระบบจดจำใบหน้า face detection '],
#  ['category_0_46', 'ram', ' 4gb '],
#  ['category_0_46', 'rom', ' 64'],
#  ['category_0_46', 'กล้องหน้า', 'ความละเอียด'],
#  ['category_0_46', 'ความละเอียด', ' 32 ล้านพิกเซลรูรับแสง'],
#  ['category_0_46', 'ขนาด', ' 2.0'],
#  ['category_0_46', 'แบตเตอรี่', 'มาตรฐาน li ion 4030 mah'],
#  ['category_0_46', 'แบรนด์', ' xiaomi'],
#  ['category_0_46', 'sku', ' 533460461 th 963560027'],
#  ['category_0_46', 'กล้องหน้า', ' ล้านพิกเซล 7ล้านพิกเซล ขึ้นไป'],
#  ['category_0_46', 'ระบบปฏิบัติการ', 'เวอร์ชัน android 9.0 pie'],
#  ['category_0_46', 'โมเดล', ' mi a3 4gb 64gb '],
#  ['category_0_46', 'ram', ' 4gb'],
#  ['category_0_46', 'ขนาดหน้าจอ', ' นิ้ว 6.09'],
#  ['category_0_46', 'ระยะเวลาการรับประกัน', ' 18 เดือน'],
#  ['category_0_46', 'ความจุแบตเตอรี่', ' 1000 mah ถึง 5000 mah'],
#  ['category_0_46', 'สี', 'ยบแบบบาง คู่'],
#  ['category_0_47', 'หมวดหมู่', ' โทรศัพท์มือถือและแท็บเล็ต'],
#  ['category_0_47', 'ประเภทย่อย', ' สมาร์ทโฟน'],
#  ['category_0_47', 'แบรนด์', ' xiaomi'],
#  ['category_0_47', 'sku', ' 495988905 th 884338021'],
#  ['category_0_47', 'กล้องหน้า', ' ล้านพิกเซล 1ล้านพิกเซล '],
#  ['category_0_47', 'ระบบปฏิบัติการ', 'เวอร์ชัน android 9.0 pie'],
#  ['category_0_47', 'โมเดล', ' redmi note 8'],
#  ['category_0_47', 'ram', ' 3gb'],
#  ['category_0_47', 'ขนาดหน้าจอ', ' นิ้ว 6.3'],
#  ['category_0_47', 'ระยะเวลาการรับประกัน', ' 15 เดือน'],
#  ['category_0_47', 'ความจุแบตเตอรี่', ' 1000 mah ถึง 5000 mah'],
#  ['category_0_47', 'สี', 'ยบแบบบาง คู่'],
#  ['category_0_48', 'หมวดหมู่', ' โทรศัพท์มือถือและแท็บเล็ต'],
#  ['category_0_48', 'ประเภทย่อย', ' สมาร์ทโฟน'],
#  ['category_0_48', 'จอแสดงผล', ' ips lcd 24 bit 16 ล้าน'],
#  ['category_0_48', 'ความละเอียด', ' 1080 x 2340 พิกเซล 395 ppi '],
#  ['category_0_48', 'จอ', ' corning gorilla glass 5'],
#  ['category_0_48', 'rom', 'eter '],
#  ['category_0_48', 'หน้าจอ', 'อัตโนมัติขณะสนทนา proximity '],
#  ['category_0_48', 'สี', 'ให้เลือก colors black white green'],
#  ['category_0_48', 'รองรับ', ' 2 ซิมการ์ด'],
#  ['category_0_48', 'ระบบปฏิบัติการ', ' os '],
#  ['category_0_48', 'ระบบปฏิบัติการ', ' miui 10 based on android 9.0 pie '],
#  ['category_0_48', 'หน่วยประมวลผล', ' mediatek helio g90t octa core'],
#  ['category_0_48', 'ram', ' 6 8gb'],
#  ['category_0_48', 'rom', ' 128gb'],
#  ['category_0_49', 'หมวดหมู่', ' โทรศัพท์มือถือและแท็บเล็ต'],
#  ['category_0_49', 'ประเภทย่อย', ' สมาร์ทโฟน'],
#  ['category_0_49', 'แบรนด์', ' xiaomi'],
#  ['category_0_49', 'sku', ' 234902116 th 713640836'],
#  ['category_0_49', 'กล้องหน้า', ' ล้านพิกเซล 5 6ล้านพิกเซล '],
#  ['category_0_49', 'โมเดล', ' xiaomi mi redmi 7a'],
#  ['category_0_49', 'ระยะเวลาการรับประกัน', ' 1 ปี'],
#  ['category_0_49', 'ความจุแบตเตอรี่', ' 4000 4999 mah'],
#  ['category_0_50', 'หมวดหมู่', ' โทรศัพท์มือถือและแท็บเล็ต'],
#  ['category_0_50', 'ประเภทย่อย', ' สมาร์ทโฟน'],
#  ['category_0_50', 'แบรนด์', ' xiaomi'],
#  ['category_0_50', 'sku', ' 494026300 th 882746256'],
#  ['category_0_50', 'โมเดล', ' redmi note 8'],
#  ['category_0_50', 'ระยะเวลาการรับประกัน', ' 15 เดือน'],
#  ['category_0_51', 'หมวดหมู่', ' โทรศัพท์มือถือและแท็บเล็ต'],
#  ['category_0_51', 'ประเภทย่อย', ' สมาร์ทโฟน'],
#  ['category_0_51', 'หน่วยประมวลผล', ' qualcomm snapdragon 730g'],
#  ['category_0_51', 'ความจุ', 'ram'],
#  ['category_0_51', 'ram', ' 6gb '],
#  ['category_0_51', 'rom', ' 128gb'],
#  ['category_0_51', 'กล้องหลัง', ' 108ล้านพิกเซล ระบบ 5 '],
#  ['category_0_51', 'กล้องหลัง', ' ai'],
#  ['category_0_51',
#   'กล้องหน้า',
#   ' กล้องเซลฟี่ 32ล้านพิกเซล 1.6 m super pixel 4 in 1 รูรับแสง f 2.0'],
#  ['category_0_51', 'จอแสดงผล', ' amoled แบบโค้ง 3d 6.47 inch '],
#  ['category_0_51', 'ระบบปฏิบัติการ', ' miui 11'],
#  ['category_0_51', 'แบตเตอรี่', ' 5260 mah ทั่วไป 5170 mah ขั้นต่ำ '],
#  ['category_0_51', 'แบตเตอรี่', 'ลิเธียมไอออนโพลีเมอร์'],
#  ['category_0_51', 'port', 'usb'],
#  ['category_0_51', 'usb', ' type c แบบเ'],
#  ['category_0_51', 'สี', 'ยบกลับด้านได้'],
#  ['category_0_51', 'รองรับ', 'การชาร์จเร็ว 30 w ภายในกล่องมีที่ชาร์จ 30 w '],
#  ['category_0_51', 'รองรับ', ' 4g 4g 3g 2g'],
#  ['category_0_51', 'รองรับ', 'การโทร volte hd สองซิม'],
#  ['category_0_51', 'รองรับ', 'bluetooth'],
#  ['category_0_51', 'bluetooth', ' 5.0'],
#  ['category_0_51', 'รองรับ', ' google pay'],
#  ['category_0_51',
#   'ขนาด',
#   'ความสูง 157.8 mm ความกว้าง 74.2 mm ความหนา 9.67 mm '],
#  ['category_0_51', 'น้ำหนัก', ' 208 กรัม'],
#  ['category_0_51', 'สี', 'ยงดังที่เร้าใจยิ่งขึ้น'],
#  ['category_0_51', 'สี', 'ยง'],
#  ['category_0_51', 'ขนาด', 'ใหญ่ 1.0 cc'],
#  ['category_0_51', 'สี', 'ยบหูฟัง 3.5 mm คุณภาพเ'],
#  ['category_0_51', 'สี', 'ยงระดับ hifi รับรองเ'],
#  ['category_0_51', 'สี', 'ยง'],
#  ['category_0_51', 'ความละเอียด', 'สูง'],
#  ['category_0_51',
#   'หน้าจอ',
#   ' ตัววัดความเร่ง ไจโรสโคป เข็มทิศอิเล็กทรอนิกส์ เซ็นเซอร์เลเซอร์โฟกัส'],
#  ['category_0_51',
#   'usb',
#   ' type c x 1 เครื่องมือเปิดช่องใส่ซิม x 1 คู่มือผู้ใช้ x 1 ใบรับประกัน x 1'],
#  ['category_0_51', 'แบรนด์', ' xiaomi'],
#  ['category_0_51', 'sku', ' 604332862 th 1137128463'],
#  ['category_0_51', 'ระยะเวลาการรับประกัน', ' 15 เดือน'],
#  ['category_0_52', 'หมวดหมู่', ' โทรศัพท์มือถือและแท็บเล็ต'],
#  ['category_0_52', 'ประเภทย่อย', ' สมาร์ทโฟน'],
#  ['category_0_52', 'หน้าจอ', 'แสดงผล amoled '],
#  ['category_0_52', 'ขนาด', ' 6.47 inch '],
#  ['category_0_52', 'ความละเอียด', ' 2340 x 1080 พิกเซล fhd '],
#  ['category_0_52', 'cpu', ' snapdragon 730g'],
#  ['category_0_52', 'gpu', ' adreno 618'],
#  ['category_0_52', 'ram', ' 8gb'],
#  ['category_0_52', 'rom', ' 256gb'],
#  ['category_0_52',
#   'กล้องหลัง',
#   ' เซ็นเซอร์ samsung hmx 10ล้านพิกเซล 8p lens 1ล้านพิกเซล ล้านพิกเซล 2ล้านพิกเซล ล้านพิกเซล พร้อมไฟแฟลชคู่ led'],
#  ['category_0_52', 'กล้องหน้า', 'ความละเอียด'],
#  ['category_0_52', 'ความละเอียด', ' 3ล้านพิกเซล '],
#  ['category_0_52', 'รองรับ', ' dual 4g volte wifi 802.11 ac 2.4ghz 5ghz '],
#  ['category_0_52', 'bluetooth', ' 5 gps glonass nfc '],
#  ['category_0_52', 'usb', ' type c'],
#  ['category_0_52', 'ขนาด', 'ตัวเครื่อง 157.8 74.2 9.67 mm '],
#  ['category_0_52', 'น้ำหนัก', ' 208 กรัม'],
#  ['category_0_52', 'แบรนด์', ' xiaomi'],
#  ['category_0_52', 'sku', ' 611792752 th 1155040122'],
#  ['category_0_52', 'ประเภทหน่วยประมวลผล', ' octa core'],
#  ['category_0_52', 'ความละเอียด', 'วิดีโอ 4k'],
#  ['category_0_52', 'ความละเอียด', ' 4k uhd'],
#  ['category_0_52', 'สี', 'ยบแบบบาง คู่'],
#  ['category_0_52', 'ระยะเวลาการรับประกัน', ' 1 ปี'],
#  ['category_0_52', 'ระบบปฏิบัติการ', ' android 9.0 pie'],
#  ['category_0_52', 'แบตเตอรี่', ' built in rechargeable battery'],
#  ['category_0_52', 'กล้องหน้า', ' ล้านพิกเซล 7ล้านพิกเซล ขึ้นไป'],
#  ['category_0_52', 'ระบบปฏิบัติการ', 'เวอร์ชัน android 9.0 pie'],
#  ['category_0_53', 'หมวดหมู่', ' โทรศัพท์มือถือและแท็บเล็ต'],
#  ['category_0_53', 'ประเภทย่อย', ' สมาร์ทโฟน'],
#  ['category_0_53', 'ขนาด', ' 5.97 inch '],
#  ['category_0_53', 'แบรนด์', ' xiaomi'],
#  ['category_0_53', 'sku', ' 343546977 th 668396557'],
#  ['category_0_53', 'ระบบปฏิบัติการ', 'เวอร์ชัน android 9.0 pie'],
#  ['category_0_53', 'โมเดล', ' mi9 mi 9 se'],
#  ['category_0_53', 'ระยะเวลาการรับประกัน', ' 1 ปี'],
#  ['category_0_53', 'สี', 'ยบแบบบาง คู่'],
#  ['category_0_54',
#   'รุ่น',
#   ' non slip soft 3d คาร์บอนไฟเบอร์ฝาหลังฟิล์มป้องกันด้านหลังสติกเกอร์ป้องกัน ฿ 55.00 ฿ 92.00 40เปอร์เซนต์ '],
#  ['category_0_54', 'ram', '12gb '],
#  ['category_0_54',
#   'rom',
#   '256gb aura blue ฿ 29330.00 ฿ 35850.00 18เปอร์เซนต์ '],
#  ['category_0_54', 'รุ่น', ' s9 plus 256gb '],
#  ['category_0_54', 'สี', 'ฟ้า ฿ 7900.00 ฿ 13590.00 42เปอร์เซนต์ '],
#  ['category_0_54',
#   'หน้าจอ',
#   ' 6.26 inch tft lcd ips ฿ 9290.00 ฿ 10990.00 15เปอร์เซนต์ '],
#  ['category_0_54', 'ram', '6 '],
#  ['category_0_54',
#   'rom',
#   '128gb เครื่องนอกไม่มีประกัน ฿ 18880.00 ฿ 31900.00 41เปอร์เซนต์ '],
#  ['category_0_54',
#   'รุ่น',
#   ' l02 กุญแจล็อคประตูอัจฉริยะรักษาความปลอดภัย แบบสแกนลายนิ้วมือ กันน้ำ ชาร์จไฟได้ ใช้พลังงานต่ำ แข็งแรงทนทาน ความปลอดภัยสูง ฿ 745.00 ฿ 1566.00 52เปอร์เซนต์ '],
#  ['category_0_55', 'หมวดหมู่', ' โทรศัพท์มือถือและแท็บเล็ต'],
#  ['category_0_55', 'ประเภทย่อย', ' สมาร์ทโฟน'],
#  ['category_0_55', 'ความละเอียด', ' hd '],
#  ['category_0_55', 'ความจุ', ' 32 gb'],
#  ['category_0_55', 'กล้องหลัง', ' 2 ตัว'],
#  ['category_0_55', 'กล้องหน้า', ' 8 ล้านพิกเซล'],
#  ['category_0_55', 'port', 'usb'],
#  ['category_0_55', 'usb', ' type c'],
#  ['category_0_55', 'แบตเตอรี่', ' 5000 มิลลิแอมป์ '],
#  ['category_0_55', 'รองรับ', 'ชาร์จไว 18 วัตต์'],
#  ['category_0_55', 'แบรนด์', ' xiaomi'],
#  ['category_0_55', 'sku', ' 587988556 th 1092062042'],
#  ['category_0_55', 'ระบบปฏิบัติการ', 'เวอร์ชัน android 9.0 pie'],
#  ['category_0_55', 'โมเดล', ' redmi 8 3gb 32gb '],
#  ['category_0_55', 'ram', ' 3gb'],
#  ['category_0_55', 'ขนาดหน้าจอ', ' นิ้ว 6.22'],
#  ['category_0_55', 'ระยะเวลาการรับประกัน', ' 15 เดือน'],
#  ['category_0_55', 'ความจุแบตเตอรี่', ' 1000 mah ถึง 5000 mah'],
#  ['category_0_55', 'สี', 'ยบแบบบาง คู่'],
#  ['category_0_56', 'หมวดหมู่', ' โทรศัพท์มือถือและแท็บเล็ต'],
#  ['category_0_56', 'ประเภทย่อย', ' สมาร์ทโฟน'],
#  ['category_0_56', 'จอแสดงผล', ' ips lcd 24 bit 16 ล้าน'],
#  ['category_0_56', 'สี', ' กว้าง 6.21 inch แนวทะแยง '],
#  ['category_0_56', 'ความละเอียด', ' 720 x 1520 พิกเซล 271 ppi ประเภท'],
#  ['category_0_56', 'จอ', 'หน้าจอ'],
#  ['category_0_56', 'หน้าจอ', 'กระจกแข็ง ประเภท'],
#  ['category_0_56', 'จอ', ' corning gorilla glass 5'],
#  ['category_0_56', 'rom', 'eter ตรวจจับความเคลื่อนไหวของตัวเครื่อง accele'],
#  ['category_0_56', 'rom', 'eter ระบบเปิด ปิด'],
#  ['category_0_56', 'หน้าจอ', 'อัตโนมัติขณะสนทนา proximity '],
#  ['category_0_56', 'สี', 'ให้เลือก colors black red blue'],
#  ['category_0_56', 'รองรับ', ' 2 ซิมการ์ด'],
#  ['category_0_56', 'ระบบปฏิบัติการ', ' miui 9 based on android 9.0 pie '],
#  ['category_0_56',
#   'หน่วยประมวลผล',
#   ' qualcomm snapdragon 439 octa core ความเร็ว 2.0 ghz'],
#  ['category_0_56', 'ram', ' 4gb '],
#  ['category_0_56', 'rom', ' 64gb'],
#  ['category_0_56', 'แบรนด์', ' xiaomi'],
#  ['category_0_56', 'sku', ' 526910733 th 944832734'],
#  ['category_0_56', 'กล้องหน้า', ' ล้านพิกเซล 7ล้านพิกเซล ขึ้นไป'],
#  ...]

# %%
dic
# Out:
# {'category_0_0': 'samsung galaxy m30s (4/64gb) ( โทรศัพท์มือถือ )',
#  'category_0_1': 'โทรศัพท์มือถือ samsung galaxy a50s ram4/64gb (รับประกันศูนย์)by jaymart',
#  'category_0_2': 'samsung galaxy a10s (ram2gb/rom32gb)',
#  'category_0_3': 'samsung galaxy note 10 + (12/256 gb) ( โทรศัพท์มือถือ )',
#  'category_0_4': 'samsung galaxy a7 (2017)',
#  'category_0_5': 'samsung galaxy a9 (2018) 6 gb ram 128 gb rom 6.3 นิ้ว 5 กล้อง สูงสุด 24 mp tetra cell (f1.7) ( โทรศัพท์มือถือ )',
#  'category_0_6': 'samsung a30s (ram 4gb / rom 64 gb) มือ 1 ประกันศูนย์ 1 ปี',
#  'category_0_7': '(มือ1 ศูนย์ไทย) samsung galaxy note 10 plus note 10 + (12/256gb) ประกัน1ปี',
#  'category_0_8': 'samsung galaxy a70 (8/128gb) ( โทรศัพท์มือถือ )',
#  'category_0_9': 'smartphone โทรศัพท์มือถือ samsung galaxy a10s sm-a107m ขนาดหน้าจอ 6.2 นิ้ว ram 2 / rom 32 gb (สีน้ำเงิน)',
#  'category_0_10': 'samsung galaxy a5 (2017)',
#  'category_0_11': 'samsung galaxy a5 (2017) - gold',
#  'category_0_12': 'samsung galaxy s10e (6/128gb) ( โทรศัพท์มือถือ )',
#  'category_0_13': 'smartphone โทรศัพท์มือถือ samsung galaxy a10s sm-a107m ขนาดหน้าจอ 6.2 นิ้ว ram 2 / rom 32 gb (สีเขียว)',
#  'category_0_14': 'samsung a10s (ram 2 gb/rom 32gr) มือ 1 ประกันศูนย์ 1 ปี',
#  'category_0_15': 'samsung galaxy tab s6 6gb/128gb ( แท็บเล็ต ) ฿ 23,900.00 ฿ 25,900.00 -8%',
#  'category_0_16': 'samsung galaxy s10 8 gb ram 128 gb rom 6.1 นิ้ว 4 กล้อง สูงสุด 16 mp ff (f2.2) ( โทรศัพท์มือถือ )',
#  'category_0_17': 'samsung a20s (ram 3gb/rom 32 gb) มือ 1 ประกันศูนย์ 1 ปี',
#  'category_0_18': 'samsung galaxy a80 (8/128gb) - โทรศัพท์มือถือ -แถมฟรี หูฟัง akg y500 มูลค่า 3990 บาท + แถมเพิ่ม travel set มูลค่า 2990 บาท',
#  'category_0_19': 'samsung galaxy note 9 (6gb/128gb) (เครื่องศูนย์ มีประกัน) (ocean blue)',
#  'category_0_20': 'samsung galaxy a10s สมาร์ทโฟน กล้องหลังคู่ 13+2mp แบต 4,000mah ประกันศูนย์ 1 ปี แถมฟรีหูฟังซัมซุง มูลค่า 399 บาท',
#  'category_0_21': 'samsung galaxy j4 plus (ประกันศูนย์) (pink)',
#  'category_0_22': 'samsung galaxy note 10 (8/256gb) ( โทรศัพท์มือถือ )',
#  'category_0_23': 'samsung galaxy note 8 64gb midnightแถมฟรีฟิล์มใสติดเครื่อง+เคสใส',
#  'category_0_24': 'samsung galaxy a9 2018 6/128gb (เครื่องศูนย์ เคลียสตอคไม่มีประกัน) (caviar black)',
#  'category_0_25': 'samsung a70 ram8/128 เครื่องศูนย์เคลียร์สต๊อค',
#  'category_0_26': 'samsung galaxy a6+ 4/32gb',
#  'category_0_27': 'samsung galaxy a50s ( 128gb + 6gb ram ) original set',
#  'category_0_28': 'samsung galaxy a20s (3/32gb) ( โทรศัพท์มือถือ )',
#  'category_0_29': '(refurbish) samsung galaxy a8 2018 - gold',
#  'category_0_30': 'samsung galaxy s10+ 8 gb ram 128 gb rom 6.4 นิ้ว 5 กล้อง สูงสุด 16 mp ff (f2.2) ( โทรศัพท์มือถือ )',
#  'category_0_31': 'samsung j8 ram3/32gb (เครื่องศูนย์,ประกันมีเดือน) สีทอง แถมฟรี! เคสใส+ฟิลม์กระจก',
#  'category_0_32': 'samsung wireless battery pack 10,000 mah ( พาวเวอร์แบงค์ , แบตเตอรี่สำรอง ) ฿ 1,290.00 ฿ 1,590.00 -19%',
#  'category_0_33': 'samsung galaxy note 10 plus 512gb',
#  'category_0_34': 'samsung galaxy note 9 (6gb/128gb) (เครื่องศูนย์ มีประกัน) (midnight black)',
#  'category_0_35': 'แบรนด์ new samsung galaxy s10 plus 128gb',
#  'category_0_36': 'samsung galaxy note 9 [ 8gb+512gb ]',
#  'category_0_37': 'samsung galaxy buds ( หูฟังบลูทูธ , หูฟังไร้สาย ) ฿ 4,199.00 ฿ 4,990.00 -16%',
#  'category_0_38': 'samsung galaxy a30 4 gb ram 64 gb rom 6.4 นิ้ว 3 กล้อง สูงสุด 16 mp ff (f2.0) ( โทรศัพท์มือถือ )',
#  'category_0_39': 'samsung galaxy a10s 2/32gb ( โทรศัพท์มือถือ )',
#  'category_0_40': 'xiaomi redmi 7a (2/16gb) สินค้าใหม่ รับประกันศูนย์ไทย 1ปี #จัดส่งฟรี kerry express',
#  'category_0_41': 'xiaomi redmi note 8 (4+64/128g) รับประกันศูนย์ไทย 15เดือน (ซื้อ1ฟรี3 mi home security camera basic 1080p!!+ฟิล์ม+เคสใส)',
#  'category_0_42': '【สินค้าพร้อมส่ง】【ฟรี mi air purifier 2】xiaomi mi note 10 (6/128gb) สมาร์ทโฟน กล้อง 5 ตัว ความละเอียด 108mp【รับประกันศูนย์ไทย 15 เดือน】',
#  'category_0_43': 'xiaomi redmi 8 (4/64gb) สินค้าใหม่ [รับประกันศูนย์ไทย 15เดือน] #จัดส่งฟรี kerry express',
#  'category_0_44': 'xiaomi mi 9t pro - เสียวหมี่ ram6+rom64gb จอ6.39นิ้ว กล้องดิจิตอล 48mp + 8mp (telephoto) + 13mp( triple camera) แถมเคส ประกันศูนย์ไทย',
#  'category_0_45': 'samsung wireless battery pack 10,000 mah ( พาวเวอร์แบงค์ , แบตเตอรี่สำรอง ) ฿ 1,290.00 ฿ 1,590.00 -19%',
#  'category_0_46': 'โทรศัพท์มือถือ xiaomi mi a3 (4gb+64gb) สแกนนิ้วบนจอ ขนาดจอ 6.088 นิ้ว ความละเอียด hd+ ชิปเซ็ต qualcomm sd 665 กล้องหลังความละเอียด 48mp กล้องหน้าความละเอียด 32mp',
#  'category_0_47': 'xiaomi redmi note 8 (3gb + 32gb) สมาร์ตโฟน 4 กล้อง ai ความละเอียด 48 mp จอกว้าง 6.3 นิ้ว fhd+ ชิปเซ็ต qualcomm sd 665',
#  'category_0_48': 'xiaomi redmi note 8 pro 6+64/128g รับประกันศูนย์ 15 เดือน (ซื้อ1ฟรี2 mi band 4+หูฟังin ear)',
#  'category_0_49': 'xiaomi mi redmi 7a 2/16gb ประกันศูนย์ไทย1ปี snapdragon439 แบตเตอรี่ 4000mah พร้อม ai beauty',
#  'category_0_50': 'xiaomi redmi note 8 (ram 4gb) รับฟรี! mi compact bluetooth speaker 2 มูลค่า 299 บาท',
#  'category_0_51': 'ผ่อน 0% นาน 10 เดือน xiaomi note 10 ram 6 rom 128 gb สมาร์ทโฟน 5 กล้อง 108mp (ประกันศูนย์ไทย 15 เดือน)',
#  'category_0_52': 'xiaomi mi cc9 pro premium edition (mi note 10 pro) 8/256 (ประกัน1ปี)',
#  'category_0_53': 'xiaomi mi9 mi 9 se 5.97 นิ้ว 48mp triple กล้องมองหลัง nfc 6gb 64gb snapdragon 712 octa core 4g สมาร์ทโฟน',
#  'category_0_54': 'samsung galaxy buds ( หูฟังบลูทูธ , หูฟังไร้สาย ) ฿ 4,199.00 ฿ 4,990.00 -16%',
#  'category_0_55': 'redmi 8 (3gb + 32gb) sapphire blue',
#  'category_0_56': 'xiaomi redmi 8 - เสียวหมี่ จอ6.21 นิ้ว ram4+rom64gb ศุนย์ไทย',
#  'category_0_57': 'xiaomi redmi note 8 (4+64/128g) (ซื้อ1ฟรี4 ฟิล์ม+หูฟังin ear+แหวนติดเคส) รับประกันสูงสุด 15 เดือน',
#  'category_0_58': 'เครื่องเกาหลี นำเข้า note9 ฿ 4,299.00 ฿ 6,999.00 -39%',
#  'category_0_59': 'xiaomi note10 (6/128gb) แถมเคสในกล่อง[ประกันศูนย์ไทย]',
#  'category_0_60': 'redmi 8 - เสียวหมี่ จอ6.21 นิ้ว ram4+rom64gb ศุนย์ไทย รับประกัน1ปี กล่องมีการแกะซีนเพื่อเปืดประกีน',
#  'category_0_61': 'xiaomi redmi note 5a prime 5.5 นิ้ว 3gb ram 32gb rom dualcameras snapdragon 425 สมาร์ทโฟน octa core',
#  'category_0_62': 'xiaomi redmi 8a - เสียวหมี่ จอ6.2 นิ้ว ram2+rom32gb ศุนย์ไทย แถมเคส ฟิล์ม',
#  'category_0_63': 'xiaomi mi note 10 (ram 6gb / rom 128gb) เครื่องใหม่ ประกันศูนย์ประเทศไทย 15 เดือน',
#  'category_0_64': 'samsung galaxy note10+ (ram12gb/rom256gb) -aura blue ฿ 29,330.00 ฿ 35,850.00 -18%',
#  'category_0_65': 'redmi note 8 pro 6+64/128g รับประกันศูนย์ไทย15เดือน',
#  'category_0_66': 'xiaomi mi note 10 6+128gb ฟรี3 amazfit bip lite watch+ mi true wireless earbuds+rock selfie stick with light!! global version！รับประกันศูนย์ 15 เดือน',
#  'category_0_67': 'apple iphone 7 32gb โทรศัพท์ second hand สภาพใหม่ 90% ไม่ผ่านการซ่อมบำรุง ฿ 5,199.00 ฿ 9,999.00 -48%',
#  'category_0_68': 'xiaomi mi note 10 6gb+128gb ฟรี mi band 4 global version!! รับประกันศูนย์ 15 เดือน',
#  'category_0_69': 'xiaomi mi9 (ram6/128gb)เครื่องศูนย์ไทยมีประกันศูนย์,ซีพียู snapdragon 855 มาพร้อมหน้าจอ amoled 6.39 นิ้ว',
#  'category_0_70': 'xiaomi redmi 7a - เรดหมี่ จอ5.45นิ้ว 2+16gb แถมเคส ฟิล์ม',
#  'category_0_71': 'xiaomi redmi 8a[2/32gb][global version] หน้าจอกว้าง 6.2 นิ้ว , แบตเตอรี่ 5,000 mah , snapdragon 439 [รับประกัน 1 ปี]',
#  'category_0_72': 'xiaomi redmi note 8 3+32gb รับประกันศูนย์ไทย',
#  'category_0_73': 'xiaomi mi9 (ram6/128gb)เครื่องศูนย์ไทยมีประกันศูนย์,ซีพียู snapdragon 855 มาพร้อมหน้าจอ amoled 6.39 นิ้ว',
#  'category_0_74': 'โทรศัพท์มือถือ xiaomi mi 9t (6gb + 128gb) glacier blue หน้าจอขนาดใหญ่ 6.39 นิ้ว ความละเอียด fhd+ กล้องหลัง 3 ตัว ความละเอียด 48 mp กล้องหน้าแบบ pop-up',
#  'category_0_75': 'xiaomi mi 9t (6+128gb) ซื้อ1ฟรี2 ฟิล์มกระจก+เคสใส รับประกันร้าน 1 ปี',
#  'category_0_76': 'samsung galaxy note10+ (ram12gb/rom256gb) -aura blue ฿ 29,330.00 ฿ 35,850.00 -18%',
#  'category_0_77': '[global version] xiaomi redmi 7a [2/32gb] snapdragon 439 / 4000 mah [รับประกันร้าน 1 ปี] แถม แหวนติดเคส',
#  'category_0_78': 'xiaomi redmi note 8 pro [128gb rom/ 8gb ram]',
#  'category_0_79': '[พร้อมส่ง] xiaomi mi 9 [6/64gb][6/128gb][global version] 6.39 นิ้ว , snapdragon 855 , 3,300 mah [รับประกัน 15 เดือน]',
#  'category_0_80': '【original】 a5 2020 3 + 64 gb + กล้องหลัง 4 ตัว + แบตเตอร์รี่ 5,000 mah',
#  'category_0_81': 'oppo a7 [4+64gb]6.2hd+/4230mah/octa-core/dual camera/warranty 1year',
#  'category_0_82': 'oppo k3 (8gb+128gb) ผ่อน 0% 10 เดือน, รับฟรี! หูฟัง jbl t450',
#  'category_0_83': '(ผ่อน 0% ฟรีของแถม) oppo a5s 4+64 gb แบตเตอรี่ 4230 mah+ดีไซน์หยดน้ำ+กล้องหลังคู่+สีแดง+สีน้ำเงิน',
#  'category_0_84': 'ผ่อนได้สูงสุด 6 เดือน oppo a5 2020 กล้อง 4 ตัว ram 3 rom 64 แบต 5000mah จอหยดน้ำ 6.5 นิ้ว',
#  'category_0_85': 'oppo f7 (6+128gb) + กล้องหน้า 25 ล้าน ai beauty + ปลดล็อกด้วยใบหน้า + ดีไซน์มันวาว',
#  'category_0_86': 'oppo a5 2020 เครื่องแท้ศูนย์ไทยรับประกันสินค้า 1 ปี ประกันร้าน 7 วันมีปัญหาเปลี่ยนได้ทันที **สินค้าและของแถมครบ พร้อมส่ง**',
#  'category_0_87': '【ผ่อน 0% 10 เดือน】oppo a5 2020 （4 + 128 gb） + กล้องหลัง 4 ตัว + แบตเตอร์รี่ 5,000 mah',
#  'category_0_88': '[ผ่อน 0% 10 เดือน] โทรศัพท์มือถือ oppo a9 2020 quad camera รับฟรี! หูฟัง jbl t450bt',
#  'category_0_89': '[ผ่อน 0%] oppo a5s 3+32 gb แบตเตอรี่ 4230 mah+ดีไซน์หยดน้ำ+กล้องหลังคู่+สีแดง+สีน้ำเงิน',
#  'category_0_90': 'ผ่อน 0% 10เดือน oppo a9 2020 quad camera กล้อง 4 ตัว ram 8 rom 128 แบต 5000 mah จอ 6.5 นิ้ว',
#  'category_0_91': '(ผ่อน 0% ฟรีของแถม) oppo a5 2020 3 + 64 gb + กล้องหลัง 4 ตัว + แบตเตอร์รี่ 5,000 mah',
#  'category_0_92': 'apple iphone 7 32gb โทรศัพท์ second hand สภาพใหม่ 90% ไม่ผ่านการซ่อมบำรุง ฿ 5,199.00 ฿ 9,999.00 -48%',
#  'category_0_93': 'oppo a3s - ใช้ได้ทุกเครือข่าย',
#  'category_0_94': 'oppo a3s (2/16gb)',
#  'category_0_95': '(free gift) r15 pro 6+128gb + ai กล้องหลังคู่ + ชาร์จไว + cpu snapdragon 660 + สีดำ + สีแดง',
#  'category_0_96': 'โทรศัพท์มือถือ oppo a5 2020 ram3/64gb (รับประกันศูนย์) by jaymart',
#  'category_0_97': 'oppo a5 2020 3/64 gb ประกันศูนย์ 1ปี แถมหูฟัง',
#  'category_0_98': '100% สำหรับ xiaomi mi 9 หน้าจอ lcd จอแสดงผล 10 แผงสัมผัสหน้าจอสำหรับ xiaomi mi9 super amoled ดิจิไทเซอร์จอแอลซีดี asembbly เปลี่ยนอะไหล่ซ่อมสำรอง + กระจกเทมเปอร์ + ซ่อมเครื่องมือเครื่องมือ ฿ 9,624.00 ฿ 19,247.00 -50%',
#  'category_0_99': 'oppo a5s (ram3+32gb) แถมหูฟัง ประกันศูนย์1ปั',
#  'category_0_100': 'oppo reno (ram6/256gb) snapdragon 710 เครื่องศูนย์ไทย,มีประกันศูนย์ แถมฟรี! เคสและฟิลม์กระจก',
#  'category_0_101': '(ผ่อน 0% ฟรีของแถม) oppo a5s 3+32 gb แบตเตอรี่ 4230 mah+ดีไซน์หยดน้ำ+กล้องหลังคู่+สีดำ+สีแดง+สีน้ำเงิน',
#  'category_0_102': '[ผ่อน 0% มีของพร้อมส่ง] oppo reno ace 40th gundam edition จำนวนจำกัด ผลิตแค่ 30,000 เครื่องเท่านั้น 8+256 gb',
#  'category_0_103': 'oppo a9 2020 แรม8 รอม128 (( ประกันศูนย์ 1ปี ))',
#  'category_0_104': 'apple iphone 7 32gb โทรศัพท์ second hand สภาพใหม่ 90% ไม่ผ่านการซ่อมบำรุง ฿ 5,199.00 ฿ 9,999.00 -48%',
#  'category_0_105': 'oppo f9',
#  'category_0_106': 'โทรศัพท์มือถือ oppo a5 2020（3 + 64 gb）ผ่อน 0% 6 เดือน + กล้องหลัง 4 ตัว + แบตเตอร์รี่ 5,000 mah',
#  'category_0_107': 'oppo a5 2020 ram3/64 เครื่องใหม่ประกันศูนย์',
#  'category_0_108': 'oppo f11 ram4/128gb (สินค้าราคาพิเศษลดเคลียสตอค,เครื่องศูนย์ไทยมีประกัน3เดือน) แถมฟรี! เคสใส+ฟิลม์กระจก',
#  'category_0_109': 'vivo y11 2020 (3+32gb) แถม เคส+ฟิล์ม ฿ 3,526.00 ฿ 3,999.00 -12%',
#  'category_0_110': 'apple iphone 7 32gb โทรศัพท์ second hand สภาพใหม่ 90% ไม่ผ่านการซ่อมบำรุง ฿ 5,199.00 ฿ 9,999.00 -48%',
#  'category_0_111': 'vivo y11 2020 (3+32gb) แถม เคส+ฟิล์ม ฿ 3,526.00 ฿ 3,999.00 -12%',
#  'category_0_112': '【oppo】 realme x สมาร์ทโฟน 6.53 นิ้ว 4gb + 64gb 3765mah pop-up selfie 16mp กล้อง และ dual กล้องหลัง 48mp + 5mp dual sim card',
#  'category_0_113': '【10 inch tablet android 9.0】【แถมฟรี หูฟังไร้สาย+ตุ๊กตาหมี】แท็บเล็ต ระบบแอนดรอยด์andorid ข้อเสนอที่ดีที่สุด（จัดส่งฟรี ）รับประกันหนึ่งปี แท็ปเล็ต 10นิ้ว octa core 6gb ram 128gb rom 3g 4g fdd lte wifi bluetooth gps phone call glass screen tablet pc ฿ 3,832.00 ฿ 7,999.00 -52%',
#  'category_0_114': 'oppo a5s (4/64',
#  'category_0_115': 'oppo a7 จอ6.2 4/64 รับประกันศูนย์ 1 ปี',
#  'category_0_116': 'a5 2020 ram3/rom64 (เครื่องแท้ศุนย์ ประกัน 1 ปี) แถม+ฟรี ฟิล์มกระจก/หูฟัง',
#  'category_0_117': '[ผ่อน 0%] oppo a5s 4+64 gb แบตเตอรี่ 4230 mah+ดีไซน์หยดน้ำ+กล้องหลังคู่',
#  'category_0_118': 'oppo a1k ram2/32gb เครื่องศูนย์ไทย,มีประกัน(lcd ขนาด 6.1 นิ้ว,แบต4000mah รองรับชาร์จไว 10w)',
#  'category_0_119': 'oppo reno 10x ocean blue (12gb+256gb) by banana it',
#  'category_0_120': 'vivo y11 2020 (3+32gb) แถม เคส+ฟิล์ม',
#  'category_0_121': 'vivo y95(ram4 rom64)เครื่องศูนย์ เครื่องโชว์สภาพสวยกริบ‼️แถมฟรี(ติดฟิล์ม+เคส)‼️',
#  'category_0_122': '100% สำหรับ xiaomi mi 9 หน้าจอ lcd จอแสดงผล 10 แผงสัมผัสหน้าจอสำหรับ xiaomi mi9 super amoled ดิจิไทเซอร์จอแอลซีดี asembbly เปลี่ยนอะไหล่ซ่อมสำรอง + กระจกเทมเปอร์ + ซ่อมเครื่องมือเครื่องมือ ฿ 9,624.00 ฿ 19,247.00 -50%',
#  'category_0_123': 'vivo s1 pro * ประกันศูนย์ 1 ปี * ram 8 gb / rom 128 gb * แถมฟรี powerbank 10,000 mah / true-wireless / sport watch / ลำโพง bluetooth',
#  'category_0_124': 'โทรศัพท์มือถือ vivo v15 pro (8gb + 128gb) หน้าจอ ultra fullview super amoled 6.39 นิ้ว ชิปเซ็ต sd 675 aie กล้องหน้า pop-up 32mp กล้องหลัง ai triple camera 48mp',
#  'category_0_125': 'ใหม่ล่าสุด!! vivo s1 pro (ram 8gb / rom 128gb) เครื่องใหม่ ประกันศูนย์ไทย พร้อมของแถม',
#  'category_0_126': 'new vivo y9s mobile phone 8gb 128gb snapdragon 665 oct core 4500mah 18w 6.38 32.0mp+48.0mp 4 rear cameras android cell phones',
#  'category_0_127': 'vivo s1 pro 8gb ram + 128gb rom เครื่องใหม่ เครื่องศูนย์แท้รับประกัน 1 ปี แถมboxset',
#  'category_0_128': 'vivo s1 pro (ram 8gb/rom 128gb) - ประกันศูนย์ ฟรี ฟิล์ม + เคส',
#  'category_0_129': '【ผ่อน 0% 10 เดือน】vivo y19 (6gb + 128gb) หน้าจอ halo fullview display 6.53 นิ้ว, แบตเตอรี่ 5,000 mah, cpr helio p65',
#  'category_0_130': '【10 inch tablet android 9.0】【แถมฟรี หูฟังไร้สาย+ตุ๊กตาหมี】แท็บเล็ต ระบบแอนดรอยด์andorid ข้อเสนอที่ดีที่สุด（จัดส่งฟรี ）รับประกันหนึ่งปี แท็ปเล็ต 10นิ้ว octa core 6gb ram 128gb rom 3g 4g fdd lte wifi bluetooth gps phone call glass screen tablet pc ฿ 3,832.00 ฿ 7,999.00 -52%',
#  'category_0_131': '100% สำหรับ xiaomi mi 9 หน้าจอ lcd จอแสดงผล 10 แผงสัมผัสหน้าจอสำหรับ xiaomi mi9 super amoled ดิจิไทเซอร์จอแอลซีดี asembbly เปลี่ยนอะไหล่ซ่อมสำรอง + กระจกเทมเปอร์ + ซ่อมเครื่องมือเครื่องมือ ฿ 9,624.00 ฿ 19,247.00 -50%',
#  'category_0_132': 'vivo y91c ram2/rom32 ใช้ได้ทุกเครือข่าย ฟรี หูฟัง ประกันศูนย์ 1ปี',
#  'category_0_133': 'original vivo z5x celular mobile phone 6.53 screen 6g 64g snapdragon710 octa core android 9 5000mah big battery smartphone',
#  'category_0_134': 'ใหม่ล่าสุด!! vivo s1 pro (ram 8gb / rom 128gb) เครื่องใหม่ ประกันศูนย์ไทย พร้อมของแถมตามรูป',
#  'category_0_135': 'original vivo z5 amoled screen mobile phone 6gb 64gb snapdragon712 48mp+32mp camera 4500mah battery celulares 22.5w charging smartphone',
#  'category_0_136': 'vivo โทรศัพท์มือถือ สมาร์ทโฟน รุ่น s1 pro ram 8gb rom 128gb ใช้งาน 2 sim รับประกันศูนย์ 1ปี กล่องมีการแกะซีนเพื่อเปิดประกัน',
#  'category_0_137': 'vivo y17 สมาร์ทโฟน กล้อง ai 3 ตัว จอใหญ่6.35 แบต5,000mah ชาร์จไวรับประกันศูนย์ 1 ปี ฟรีgift set สุดคุ้ม',
#  'category_0_138': 'original vivo z5x celular mobile phone 6.53 screen 8g 128g snapdragon710 octa core android 9 5000mah big battery smartphone',
#  'category_0_139': 'ใหม่ล่าสุด!! vivo y15 2020 (ram 4gb / rom 64gb) เครื่องใหม่ ประกันศูนย์ไทย',
#  'category_0_140': 'vivo วีโว่ mobile โทรศัพท์มือถือ สมาร์ทโฟน รุ่น s1 pro ram 8gb rom 128gb หน้าจอขนาด 6.38 นิ้ว ใช้งาน 2 sim (ประกันตัวเครื่อง 2 ปี ประกันจอแตก 6 เดือน)',
#  'category_0_141': 'new original vivo u3x celular 6.35inch screen 3g 32g snapdragon665 5000mah battery cellphones 18w charging mobile phone android',
#  'category_0_142': 'original vivo z5 amoled screen mobile phone 6gb 256gb snapdragon712 48mp+32mp camera 4500mah battery celulares 22.5w charging smartphone',
#  'category_0_143': '{พร้อมส่ง} vivo iqoo neo 855 เร็ว แรง คอเกมส์ต้องจัด! [snapdragon 855] เมนูไทย | ชาร์จเร็ว vooc flash charge 33w ประกันศูนย์',
#  'category_0_144': 'vivo iqoo neo 855 snapdragon 855 6gb 128gb 4500mah battery 33w fast charging 6.38” celular mobile phone al triple cameras cell phones',
#  'category_0_145': 'original vivo nex 3 5g mobile phone 8gb 256gb snapdragon 855 plus 6.89-inch screen 64mp camera celular nfc android 9 smartphone',
#  'category_0_146': 'original new vivo s5 smartphone celular snapdragon 712 8gb 128gb 4100mah big battery 32.0mp+48.0mp 4 cameras android cell phones',
#  'category_0_147': 'vivo s1 (rom128gb/ram6gb)',
#  'category_0_148': 'vivo v15 - วีโว่ 6+128gb 3 กล้อง แถมเคส ฟิล์ม',
#  'category_0_149': 'vivo x21 128gb (เครื่องศูนย์ไทยเคลียสตอค,ไม่มีประกันศูนย์) ฿ 7,480.00 ฿ 16,900.00 -56%',
#  'category_0_150': 'original vivo z5x celular mobile phone 6.53 screen 6g 128g snapdragon710 octa core android 9 5000mah big battery smartphone',
#  'category_0_151': 'original vivo u3 celular cell phones snapdragon 675 6gb 64gb 16.0mp 3 cameras 5000mah battery 18w fast charging mobile phone',
#  'category_0_152': 'vivo y17',
#  'category_0_153': 'vivo mobile วีโว่ โทรศัพท์มือถือ สมาร์ทโฟน รุ่น y15 2020 ram 4gb rom 64gb หน้าจอขนาด 6.35 นิ้ว ใช้งาน 2 sim (รับประกันตัวเครื่อง 2ปี)',
#  'category_0_154': 'original vivo iqoo pro 4g mobile phone snapdragon855 plus 8gb 128gb 4500mah 44w 6.41 screen 48mp camera 12gb 128gb celular cell phone',
#  'category_0_155': 'original vivo u3 celular cell phones snapdragon 675 6gb 64gb 16.0mp 3 cameras 5000mah battery 18w fast charging mobile phone',
#  'category_0_156': 'vivo v11 6+128gb (ผ่อน 0% 10 เดือน)',
#  'category_0_157': 'vivo iqoo neo 855 snapdragon 855 8gb 256gb 4500mah battery 33w fast charging 6.38” celular mobile phone al triple cameras cell phones',
#  'category_0_158': 'vivo s1 pro หน้าจอไร้ขอบ กว้าง 6.38 นิ้ว ram 8gb /rom 128gb รับประกันศูนย์ 1 ปี',
#  'category_0_159': 'vivo y11 (เครื่องประกันศูนย์ 1 ปี)',
#  'category_0_160': 'huawei y6s ( ram3 rom64 ) แถมหูฟัง ประกันศูนย์ 1ปี',
#  'category_0_161': 'huawei y9s รับประกันศูนย์ 1 ปี ram6 rom 128',
#  'category_0_162': 'โทรศัพท์มือถือ huawei y9s (6gb+128gb) พร้อมผ่อน 0% นาน 10 เดือน แถมฟรี huawei y-series gift bundle box มูลค่า 990.-',
#  'category_0_163': 'โทรศัพท์มือถือ huawei y6s (3gb+64gb) พร้อมผ่อน 0% 3 เดือน',
#  'category_0_164': 'huawei y9s * ประกันศูนย์ 1 ปี * ram 6 gb / rom 128 gb * แถมฟรี mini speaker / true-wireless / case',
#  'category_0_165': '【ผ่อน 0% 3 เดือน】huawei y7 pro 2019 * หน่วยความจำ ram: 3 gb rom: 32 gb l หน้าจอ dewdrop 6.26 นิ้ว',
#  'category_0_166': '【ผ่อน 0% 10 เดือน】huawei nova 5t หน่วยความจำ (8+128g) l หน้าจอ 6.26 นิ้ว tft lcd (ips)',
#  'category_0_167': '【ผ่อน 0% 10 เดือน】huawei mate20 pro 6+128gb (android 10 update) 6.39 2k+ oled screen, water resistant ip68, leica triple camera, 40w huawei super charge, 15w wireless charging mate20pro,',
#  'category_0_168': 'สินค้าใหม่ ของแท้ โทรศัพท์มือถือ huawei y9s [6+128gb] 48mp triple camera/dual-sim/gpu turbo/android9.0/ประกันศูนย์ไทย1ปี',
#  'category_0_169': 'huawei y6s ram 3 rom 64 รับประกันศูนย์ 1 ปี',
#  'category_0_170': 'huawei y9s หน้าจอแบบ ultra fullview กล้องหน้าแบบป๊อปอัพ automatic และกล้องหลัง ai ถึง 3 ตัวพร้อมเลนส์ ultra wide',
#  'category_0_171': '[แท้ ใหม่ ศูนย์ไทย] โทรศัพท์มือถือ/สมาร์ทโฟน/แอนดรอยด์ /huawei y6s [3+64gb] 6.09 hd+/dual-sim/4g lte/octa-core/warranty 1year',
#  'category_0_172': 'โทรศัพท์มือถือ huawei y6s ram3/64gb (รับประกันศูนย์)by jaymart',
#  'category_0_173': 'huawei y7 pro 2019 - แถมหูฟัง rom 32gb ram 3gb ประกันศูนย์',
#  'category_0_174': 'huawei y5 2019 สินค้าประกันศูนย์ 1 ปี แถม เคส ฟิล์ม แหวน+ที่วางโทรศัพท์',
#  'category_0_175': 'vivo มือถือ สมาร์ทโฟน 6.22 hd+ รุ่น y95 ram4 rom64 สีแดง (สินค้าตัวโชว์) / มือถือราคาไม่แพง/ มือถือสเปคแรงราคาไม่แพง thaimartmobile ฿ 4,590.00 ฿ 7,499.00 -39%',
#  'category_0_176': 'huawei y9s ( ram 6gb/rom 128gb) มือ 1 ประกันศูนย์ 1 ปี',
#  'category_0_177': 'huawei y9s ram 6/rom 128 *แถมเคสใส+ฟิล์มใส ติดตั้งบนตัวเครื่อง+นาฬิกาsmart wacth',
#  'category_0_178': 'huawei y9 prime 2019 มือ 1 ประกันศูนย์ 1 ปี',
#  'category_0_179': 'huawei y6s (ram3gb/rom64gb)',
#  'category_0_180': '[แท้ ใหม่ ศูนย์ไทย] โทรศัพท์มือถือ/แอนดรอยด์/มือถือ/huawei y9s [6+128gb] 48mp triple camera/dual-sim/gpu turbo/android9.0/ประกันศูนย์ไทย1ปี',
#  'category_0_181': 'huawei y9 prime 2019 (ram4/rom128)',
#  'category_0_182': 'huawei nova 2i ram4 /64gb เครื่องใหม่ศูนย์เคลียสตอค(ไม่มีประกัน)',
#  'category_0_183': 'huawei y5 2019 แรม 2 รอม32 (ประกันศูนย์ 1 ปี)',
#  'category_0_184': 'huawei y6s / จอ 6.09 / ram 3 gb rom 64 gb/ กล้องหน้า 8 mp กล้องหลัง13 mp / ประกันศูนย์ 1 ปี /แถมฟรี i-ring 1 อัน',
#  'category_0_185': 'huawei nova 2i 64gb (ลดclearstock ไม่มีประกัน) (aurora blue)',
#  'category_0_186': 'new!! huawei y9s ram6/128gb (แถมฟรี 3 ชิ้น)โปรฯจากช้อปมาเอง',
#  'category_0_187': 'huawei p30 pro ram8/512gb (เครื่องศูนย์,รับประกันศูนย์1ปีเต็ม) สีใหม่! amber sunrise (limited edition)',
#  'category_0_188': 'huawei nova 2i 64gb (ลดclearstock ไม่มีประกัน) (graphite black)',
#  'category_0_189': 'huawei y5 lite หน้าจอกว้างไร้ขอบขนาด 5.45 นิ้ว / ram : 1 gb / rom :16 gb',
#  'category_0_190': 'vivo x21 128gb (เครื่องศูนย์ไทยเคลียสตอค,ไม่มีประกันศูนย์) ฿ 7,480.00 ฿ 16,900.00 -56%',
#  'category_0_191': 'huawei y9 2019',
#  'category_0_192': '[สามารถใช้งาน google service ได้]pre-order โทรศัพท์มือถือ huawei y9s (6gb+128gb) แถมฟรี jbl t450bt bluetooth headphones และ huawei mini speaker มูลค่ารวม 3,580.- พร้อมผ่อน 0% นาน 10 เดือน เริ่มส่งสินค้าวันที่ 4 ธ.ค.เป็นต้นไป',
#  'category_0_193': '【ผ่อน 0% 10 เดือน】huawei y9 prime 2019 * หน่วยความจำ ram: 4 gb rom: 128 gb l หน้าจอ 6.59 นิ้ว',
#  'category_0_194': 'huawei y9 2019จอ6.5 นิ้วrom 64gb ram 4gb{ประกันศูนย์1ปี}',
#  'category_0_195': '[ผ่อน 0% + มีgoogle playstore] huawei mate 30 pro 5g ram 8gb rom 512gb',
#  'category_0_196': '[ผ่อน 0% 3 เดือน] huawei y6s *รับประกันเพิ่มปีที่ 2',
#  'category_0_197': '【ผ่อน 0% 10 เดือน】huawei nova 5t หน่วยความจำ ram: 8 gb rom: 128 gb l หน้าจอ 6.26 นิ้ว tft lcd (ips)',
#  'category_0_198': 'huawei mate 20 x 6/128gb with m-pen',
#  'category_0_199': 'huawei nova 4 8/128gb (เครื่องศูนย์ไทย มีประกัน 3 เดือน) (crush blue)',
#  'category_0_200': 'realme 5 pro 4/128gb เครื่องแท้ศูนย์ไทยรับประกันสินค้า 1 ปี ประกันร้าน 7 วันมีปัญหาเปลี่ยนได้ทันที สามารถออกใบกำกับภาษีได้',
#  'category_0_201': 'realme x2 pro x 2 12g+256g',
#  'category_0_202': 'realme 5 pro (4/128gb) สินค้าเครื่องแท้ศูนย์ไทยรับประกัน 1 ปี สินค้าของแถมครบพร้อมส่ง',
#  'category_0_203': 'realme 5s 4gb/128gb 4 เลนส์ ai 48mp พลังอึด สินค้ารับประกันศูนย์ 1 ปี',
#  'category_0_204': 'realme 5s (ram 4/rom 128gb)เครื่องเเท้รับประกันศูนย์ 1ปี*แถมฟรีเคสใส+ฟิล์มโรงงาน(ติดตั้งบนเครื่อง)+หูฟัง',
#  'category_0_205': 'realme 5s 4gb/128gb 4 เลนส์ ai 48mp พลังอึด สินค้ารับประกันศูนย์ 1 ปี',
#  'category_0_206': 'realme 5 ram 3 / rom 64 แถมฟรีเคสใส+ฟิล์ม และ หูฟังsamsung พร้อมลงทะเบียนรับประกัน',
#  'category_0_207': '【ผ่อน 0% 10 เดือน】realme x2 pro (12+256gb) แรงเต็มขั้น พลังเรือธง, snapdragon 855+, กล้องหลัง 4 เลนส์ 64 mp, super vooc flash charge',
#  'category_0_208': '【สินค้าพร้อมส่ง】realme 5s (4/128gb) กล้องหลัง 4 ตัว 48 ล้านพิกเซล【รับประกันศูนย์ไทย 2 ปี】',
#  'category_0_209': '【มีเมนูไทย+gms】realme x2 pro 6.5นิ้ว fhd+ samsung 90hz fluid super amoled nfc 64mp quad กล้องด้านหลัง 8gb ram 128/256gb รอม snapdragon 855 plus smartphone 50w super vooc fast charger',
#  'category_0_210': 'realme x2 pro x 2 6g+64g',
#  'category_0_211': '[ผ่อน 0%] มือถือ realme 3 pro (4+64gb) กล้องถ่ายกลางคืน nightscape, ชิปประมวลผล snapdragon 710 aie , ชาร์จเร็ว vooc flash charge 3 โทรศัพท์มือถือ',
#  'category_0_212': '[ผ่อน 0%]มือถือ realme 2 pro (4+64gb) กล้อง ai beauty, หน้าจอใหญ่ 6.3 , ชิปประมวลผล snapdragon 660 aie',
#  'category_0_213': 'vivo มือถือ สมาร์ทโฟน 6.22 hd+ รุ่น y95 ram4 rom64 สีแดง (สินค้าตัวโชว์) / มือถือราคาไม่แพง/ มือถือสเปคแรงราคาไม่แพง thaimartmobile ฿ 4,590.00 ฿ 7,499.00 -39%',
#  'category_0_214': '【ผ่อน 0% 6 เดือน】มือถือ realme 5 (3+64gb) 4 เลนส์ พลังแบตเกินพิกัด 5000 mah',
#  'category_0_215': 'realme 5 (ram 3/rom64gb) 4 เลนส์ cpu snapdragon 665aie เเบตอึด 5000 mah เครื่องเเท้รับประกันศูนย์ 1ปี*แถมฟรีเคสใส+หูฟัง+ฟิล์มโรงงาน(ติดตั้งบนเครื่อง)',
#  'category_0_216': 'realme 5s แรม4 รอม 128 (( ประกันศูนย์ 1ปี ))',
#  'category_0_217': '100% สำหรับ huawei y9 2019 จอแสดงผล lcd สัมผัสขอบจอสำหรับ huawei เพลิดเพลินไปกับ 9 plus ตัวแปลงเป็นดิจิตอลสำหรับหน้าจอ lcd เปลี่ยนอะไหล่ซ่อมสำรอง + กระจกเทมเปอร์ + ซ่อมเครื่องมือเครื่องมือ 6.5 นิ้ว ฿ 3,302.79 ฿ 6,941.00 -52%',
#  'category_0_218': '【ผ่อน 0% 10 เดือน】realme 5s (4gb + 128gb) 4 เลนส์ ai 48mp พลังอึด',
#  'category_0_219': 'realme 5s - เรียวมี ram4+rom128gb จอ6.51นิ้ว fingerprint กล้องดิจิตอล 48mp + 8mp (ultrawide) แถมเคส ฟิล์ม',
#  'category_0_220': 'realme 5 pro - เรียวมี ram4+rom128gb จอ 6.3นิ้ว กล้อง 4ตัว แถมเคส ฟิล์ม',
#  'category_0_221': 'realme 5 ( ram 3 gb / rom 32 gb) มือ 1 ประกัศูนย์ 1 ปี',
#  'category_0_222': 'เครื่องเกาหลี นำเข้า note9 ฿ 4,299.00 ฿ 6,999.00 -39%',
#  'category_0_223': 'realme 5s (ram 4gb / rom 128gb )เครื่องใหม่ ประกันศูนย์ไทย พร้อมติดฟิล์มกันรอย',
#  'category_0_224': '【ผ่อน 0% 10 เดือน】มือถือ realme 5 pro (4+128gb) 4 เลนส์ สเปคแรง snapdragon 712',
#  'category_0_225': '【ผ่อน 0% 10 เดือน】มือถือ realme 5 pro (4+128gb) 4 เลนส์ สเปคแรง snapdragon 712 ฟรี! sandisk micro sd card และลำโพง jbl go มูลค่ากว่า 2,180 บาท',
#  'category_0_226': 'realme 5 (ram3/rom64)',
#  'category_0_227': '【ผ่อน 0% 10 เดือน】มือถือ realme 5 pro (8+128gb) 4 เลนส์ สเปคแรง snapdragon 712',
#  'category_0_228': 'vivo x21 128gb (เครื่องศูนย์ไทยเคลียสตอค,ไม่มีประกันศูนย์) ฿ 7,480.00 ฿ 16,900.00 -56%',
#  'category_0_229': '【ผ่อน 0% 10 เดือน】 มือถือ realme xt (8+128gb) 4 เลนส์ สเปคสุดล้ำ กล้อง 64 mp',
#  'category_0_230': '【พร้อมส่ง】realme 5s (4/128gb) 4 เลนส์ ai 48mp พลังอึด [ประกันศูนยไทย 2 ปี]',
#  'category_0_231': 'realme 5 เครื่องใหม่ ประกันศูนย์ไทย พร้อมติดฟิล์มกันรอย',
#  'category_0_232': 'realme c2 / จอ 6.1 นิ้ว / ram 3 gb rom 32 gb/ กล้องหน้า 5 mp กล้องหลัง 13+2 mp/ เครื่องใหม่ ประกันศูนย์ 1 ปี / มีหน้าร้าน ติดต่อง่าย แถมฟรี ที่ตั้งมือถือ i-ring คละสี 1อัน',
#  'category_0_233': 'realme x2 pro snapdragon 855+ global rom แท้จากโรงงาน',
#  'category_0_234': 'realme 5 pro (ram 4gb rom 128gb) เครื่องศูนย์ไทยแท้ 100%',
#  'category_0_235': 'realme 3 ram4/64gb เครื่องใหม่มือ 1 รับประกันศูนย์ไทย 1 ปี เข้าศูนย์บริการ oppo ได้ทั่วประเทศ',
#  'category_0_236': 'realme 5s (4/128gb) แถม เคสในกล่อง[ประกันศูนย์ไทย]',
#  'category_0_237': 'realme 5s [4+128gb] 48mp quad-camera /4g lte / dual-sim/5000mah/รับประกันศูนย์ไทย 1ปี',
#  'category_0_238': 'realme c2 3gb+32gb เครื่องแท้ ประกันศูนย์ 1 ปี',
#  'category_0_239': 'realme 5 pro - เรียวมี ram8+rom128gb จอ 6.3นิ้ว กล้อง 4ตัว แถมเคส',
#  'category_0_240': 'haixu star (edit) หน้าจอใหญ่ 5.5 นิ้ว 16gb รองรับระบบ3g/4g เครื่องศูนย์แท้ รับประกัน 1 ปี ราคาถูกสุด best seller',
#  'category_0_241': 'new!!! haixu v14 หน้าจอ 5.5 นิ้ว 2sim ram2 rom 16 รองรับระบบ 3g/4g สเปคแท้/ราคาถูก เครื่องแท้ ประกันศูนย์ 1 ปี',
#  'category_0_242': 'haixu v21 หน้าจอใหญ่ 6.3 นิ้ว ram2 rom32gb สามารสแกนนิ้วมือได้ รองรับระบบ3g/4g เครื่องศูนย์แท้ รับประกัน 1 ปี ราคาถูกสุด',
#  'category_0_243': 'haixu v21 หน้าจอใหญ่ 6.3 นิ้ว ram2 rom32gb สามารสแกนนิ้วมือได้ รองรับระบบ3g/4g เครื่องศูนย์แท้ รับประกัน 1 ปี ราคาถูกสุด',
#  'category_0_244': 'haixu v17 หน้าจอใหญ่ถึง 6.1 นิ้ว 2sim ram 2 rom 16gb รองรับระบบ 3g/4g สเปคแท้/ราคาถูก เครื่องแท้ ประกันศูนย์ 1 ปี',
#  'category_0_245': 'haixu v21 หน้าจอใหญ่ 6.3 นิ้ว 32gb รองรับระบบ3g/4g เครื่องศูนย์แท้ รับประกัน 1 ปี ราคาถูกสุด',
#  'category_0_246': 'haixu star 5.5" 16gb /battery 3200mah/camera 13mp/สเปคแท้/เครื่องแท้ ประกันศูนย์1ปี',
#  'category_0_247': 'haixu v17 หน้าจอใหญ่ถึง 6.1 นิ้ว 2sim รองรับระบบ 3g/4g สเปคแท้/ราคาถูก เครื่องแท้ ประกันศูนย์ 1 ปี',
#  'category_0_248': 'haixu v11 หน้าจอใหญ่ 6.1 นิ้ว ram2 rom32gb สามารสแกนนิ้วมือได้ รองรับระบบ3g/4g เครื่องศูนย์แท้ รับประกัน 1 ปี ราคาถูกสุด',
#  'category_0_249': 'haixu v20 หน้าจอใหญ่ 6.3 นิ้ว 2sim ram 2gb/rom 16gb สามารสแกนนิ้วมือได้ รองรับ3g/4g สเปคแท้/เครื่องแท้ ประกันศูนย์1ปี',
#  'category_0_250': 'haixu v21 หน้าจอใหญ่ 6.3 นิ้ว ram2 rom32gb สามารสแกนนิ้วมือได้ รองรับระบบ3g/4g เครื่องศูนย์แท้ รับประกัน 1 ปี ราคาถูกสุด',
#  'category_0_251': 'haixu 5.5นิ้ว 16gb /แบตเตอรี่ 3200mah/กล้อง13ล้าน ถ่ายรูปสวย คมชัด สมจริง/สเปคแท้/เครื่องแท้ ประกันศูนย์1ปี/ โทรศัพท์ มือถือ new smartphone star',
#  'category_0_252': 'haixu v21 หน้าจอใหญ่ 6.3 นิ้ว ram2 rom32gb สามารสแกนนิ้วมือได้ รองรับระบบ3g/4g เครื่องศูนย์แท้ รับประกัน 1 ปี ราคาถูกสุด',
#  'category_0_253': 'haixu v13 หน้าจอใหญ่ถึง 5.5 นิ้ว 2sim ram2 rom16 รองรับระบบ 3g/4g สเปคแท้/ราคาถูก เครื่องแท้ ประกันศูนย์ 1 ปี',
#  'category_0_254': 'haixu star 16gb สเปคแท้/เครื่องแท้ ประกันศูนย์1ปี best seller',
#  'category_0_255': 'haixu star smartphone 5.5 16gb 2 sim',
#  'category_0_256': 'haixu v21 หน้าจอใหญ่ 6.3 นิ้ว ram2 rom32gb สามารสแกนนิ้วมือได้ รองรับระบบ3g/4g เครื่องศูนย์แท้ รับประกัน 1 ปี ราคาถูกสุด',
#  'category_0_257': 'oppo a5 2020 ประกันศูนย์oppo1ปี ฿ 4,690.00',
#  'category_0_258': 'new!!! haixu v17pro หน้าจอใหญ่ถึง 6.3 นิ้ว ram2+rom16gb 2sim สามารสแกนนิ้วมือได้ รองรับระบบ 3g/4g สเปคแท้/ราคาถูก ฝาหลังอะลูมิเนียมกระจก เครื่องแท้ ประกันศูนย์ 1 ปี',
#  'category_0_259': 'โทรศัพท์มือถือ สมาร์ทโฟน รุ่น haixu v14 2gb rom 16gb ใช้งาน 2 sim (ประกันตัวเครื่อง 1 ปี)',
#  'category_0_260': 'ไฮซู หน้าจอใหญ่ 6.3นิ้ว/ram 2gb/rom 16gb/camera 16mp ถ่ายรูปสวย คมชัด สมจริง/แบตเตอรี่: 3400mah แบตอึก ทนสุดๆ #ราคาถูก #smartphone โทรศัพท์ มือถือ haixu 6.3',
#  'category_0_261': 'haixu star edit หน้าจอใหญ่ 5.5 นิ้ว 16gb รองรับระบบ3g/4g เครื่องศูนย์แท้ รับประกัน 1 ปี ฝาหลังอลูมิเนียม',
#  'category_0_262': 'vivo x21 128gb (เครื่องศูนย์ไทยเคลียสตอค,ไม่มีประกันศูนย์) ฿ 7,480.00 ฿ 16,900.00 -56%',
#  'category_0_263': 'ฟรีค่าส่งทั้งร้าน haixu star หน้าจอใหญ่ 5.5 นิ้ว 16gb รองรับระบบ3g/4g เครื่องศูนย์แท้ รับประกัน 1 ปี ราคาถูกสุด best seller',
#  'category_0_264': 'haixu v14, สมาร์ทโฟน, หน่วยความจำ g + 32g, 5.5 นิ้ว hd เต็มหน้าจอ, ปลดล็อกลายนิ้วมือ, หน่วยประมวลผลแปดหลัก, แบตเตอรี่ 3200mah, ถ่ายภาพ, ชมภาพยนตร์, ฟังเพลง',
#  'category_0_265': 'oppo a5 2020 ประกันศูนย์oppo1ปี ฿ 4,690.00',
#  'category_0_266': 'haixu v14 smartphone 5.5 ram 2gb + rom 16gb สเปคแท้/ราคาถูก เครื่องแท้ ประกันศูนย์ 1 ปี',
#  'category_0_267': 'จอ lcd.vivo v11i,1806,y97+ทัชสกรีน ฿ 1,585.00 ฿ 2,500.00 -37%',
#  'category_0_268': 'haixu v17 หน้าจอใหญ่ถึง 6.1 นิ้ว 2sim ram 2 rom 16gb รองรับระบบ 3g/4g สเปคแท้/ราคาถูก เครื่องแท้ ประกันศูนย์ 1 ปี',
#  'category_0_269': '【haixu v17】 หน้าจอใหญ่ถึง 6.1 นิ้ว 2sim ram 2 rom 16gb รองรับระบบ 3g/4g สเปคแท้/ราคาถูก เครื่องแท้ ประกันศูนย์ 1 ปี',
#  'category_0_270': 'new!!! haixu v14 หน้าจอ 5.5 นิ้ว 2sim ram2 rom 16 รองรับระบบ 3g/4g สเปคแท้/ราคาถูก เครื่องแท้ ประกันศูนย์ 1 ปี',
#  'category_0_271': 'oppo a5 2020 ประกันศูนย์oppo1ปี ฿ 4,690.00',
#  'category_0_272': 'ฟรีค่าส่งทั้งร้าน haixu star หน้าจอใหญ่ 5.5 นิ้ว 16gb รองรับระบบ3g/4g เครื่องศูนย์แท้ รับประกัน 1 ปี ราคาถูกสุด best seller',
#  'category_0_273': 'haixu star edit หน้าจอใหญ่ 5.5 นิ้ว 16gb รองรับระบบ3g/4g เครื่องศูนย์แท้ รับประกัน 1 ปี ฝาหลังอลูมิเนียม',
#  'category_0_274': 'haixu v11 หน้าจอใหญ่ 6.1 นิ้ว ram2 rom32gb สามารสแกนนิ้วมือได้ รองรับระบบ3g/4g เครื่องศูนย์แท้ รับประกัน 1 ปี ราคาถูกสุด',
#  'category_0_275': 'haixu-star 16gb หน้าจอใหญ่ 5.5" /battery 3200mah/camera 13mp/สเปคแท้/เครื่องแท้ ประกันศูนย์1ปี/ โทรศัพท์ มือถือ ราคาถูก ราคาถูกที่สุด haixu',
#  'category_0_276': 'haixu (ram 2gb/rom 16gb) ชุดพิเศษ /camera 13mp ถ่ายรูปสวย คมชัด สมจริง/หน้าจอ 5.5นิ้ว/แบตเตอรี่: 3200mah แบตอึก ทนสุดๆ #ราคาถูก #smartphone โทรศัพท์ มือถือ ไฮซู 5.5นิ้ว v13 5.5"',
#  'category_0_277': 'haixu 6.3 (ram 2gb/rom 32gb)เครื่องศูนย์แท้ รับประกัน 1 ปี/สเปคแท้/หน้าจอใหญ่ 6.3 นิ้ว/รองรับระบบ3g/4g ราคาถูกสุด v21',
#  'category_0_278': 'haixu star edit หน้าจอใหญ่ 5.5 นิ้ว 16gb 2sim/1sd card เครื่องศูนย์แท้ ประกัน1ปี ราคาถูกสุด สินค้าขายดี',
#  'category_0_279': 'haixu star หน้าจอใหญ่ 5.5 นิ้ว /ความจำเครื่อง 16gb /battery 3200mah / ของแท้',
#  'category_1_0': 'samsung galaxy tab s6 10.5 6+128gb มี s pen [sm-t865]',
#  'category_1_1': 'samsung galaxy tab s4 10.5 4 gb ram 64 gb rom 10.5 นิ้ว ( แท็บเล็ต )',
#  'category_1_2': 'จอ lcd.vivo v11i,1806,y97+ทัชสกรีน ฿ 1,585.00 ฿ 2,500.00 -37%',
#  'category_1_3': 'apple 7 plus/8 plus โทรศัพท์มือถือ anti - ลายนิ้วมือ frosted เคสโทรศัพท์ iphone 7 plus/8 plus frosted tpu เคสโทรศัพท์ ฿ 800.00 ฿ 1,200.00 -33%',
#  'category_1_4': 'samsung galaxy tab a 10.5 3 gb ram 32 gb rom 10.5 นิ้ว ( แท็บเล็ต )',
#  'category_1_5': 'แบรนด์ new samsung-galaxy-note10',
#  'category_1_6': 'samsung galaxy tab s5e 10.5 ( แท็บเล็ต )',
#  'category_1_7': 'samsung tab a plus 2019 8.0 p205 ram3/rom32 with- s-pen (ผ่อน 0% 10เดือน)',
#  'category_1_8': 'แท็บเลต tab 3 v',
#  'category_1_9': "samsung galaxy tab a 2016 7''",
#  'category_1_10': 'samsung galaxy tab a with s pen 10.1″ รุ่น sm-p585yzwathl',
#  'category_1_11': 'samsung galaxy (t865) tab s6 10.5 (ram 6gb rom 128gb) เครื่องศูนย์ไทยแท้ 100%',
#  'category_1_12': 'samsung galaxy tab (t725) s5e 10.5 (ram 4gb rom 64gb) เครื่องศูนย์ไทยแท้ 100% แกะกล่องโชว์หน้าตู้เท่านั้นไม่ผ่านการใช้งาน',
#  'category_1_13': 'samsung galaxy tab a 8.0 , 2019 lte เครื่องศูนย์ไทยประกัน 1 ปีเต็ม',
#  'category_1_14': 'galaxy tab a 8.0" , 2019 lte sm-t295 2+32gb ประกันศูนย์ 1 ปี',
#  'category_1_15': 'galaxy tab a with s pen 8.0" (2019) ram3/32gb (เครื่องศูนย์,รับประกัน1ปีเต็ม) แถมฟรี! ฟิลม์กระจกเต็มจอ',
#  'category_1_16': 'samsung galaxy tab a 2016 7.0" (black)',
#  'category_1_17': 'samsung galaxy tab a 10.1 2019 t515 (ram3gb/rom32gb)-black',
#  'category_1_18': 'samsung tab a plus 2019 8.0 p205 ram3/rom32 with- s-pen',
#  'category_1_19': 'refuebished samsung galaxy tab a with s pen 8.0" (sm-p355) (white)',
#  'category_1_20': 'samsung galaxy tab s6 (ram6/128gb) lte เครื่องศูนย์ไทย,มีประกันศูนย์ แถมฟรี! ฟิลม์กระจก',
#  'category_1_21': 'galaxy tab a with s pen จอขนาด8.0" (2019) ram3/32gb (เครื่องศูนย์ไทย,รับประกัน1ปีเต็ม) แถมฟรี! ฟิลม์กระจกเต็มจอ',
#  'category_1_22': 'samsung galaxy tab a 8.0" with s pen (sandy white)',
#  'category_1_23': 'samsung galaxy tab s6',
#  'category_1_24': 'samsung galaxy tab s6 [รับฟรี smile 6 shape bag มูลค่า 990 บาท]',
#  'category_1_25': 'samsung galaxy tab a 10.1(2019) ram3/32gb (เครื่องศูนย์ไทย,มีประกันศูนย์) แบต 6,150 mah แถมฟรี! ฟิลม์กระจก',
#  'category_1_26': 'samsung galaxy tab s 5e 10.5 ram4/64gb (เครื่องศูนย์ไทย,มีประกัน1ปีเต็ม) แถมฟรี! ฟิลม์กระจก',
#  'category_1_27': 'samsung tablet galaxy tab a 7.0 (sm-t285nzwathl)',
#  'category_1_28': 'samsung galaxy tab s5e 10.5 ram4/64gb (เครื่องศูนย์ไทย,มีประกัน1ปีเต็ม) แถมฟรี! ฟิลม์กระจก',
#  'category_1_29': 'samsung galaxy tab a 10.1(2019) ram3/32gb (เครื่องศูนย์ไทย,มีประกันศูนย์) แบต 6,150 mah แถมฟรี! ฟิลม์กระจก',
#  'category_1_30': 'galaxy tab a with s pen 8.0" (2019) ram3/32gb (เครื่องศูนย์,รับประกัน1ปีเต็ม) แถมฟรี! ฟิลม์กระจกเต็มจอ',
#  'category_1_31': 'samsung galaxy tab s4 10.5”',
#  'category_1_32': 'samsung galaxy tab s6 (รับประกันศูนย์ไทย 1 ปี)',
#  'category_1_33': 'samsung galaxy tab a 10.1 ram3/16gb แบต 7,300 mah (ลดล้างสตอค,ไม่มีประกัน) สีขาว',
#  'category_1_34': 'samsung galaxy tab a 2016 7.0" (black) ประกันศูนย์ 1 ปี',
#  'category_1_35': 'samsung galaxy tab a 10.1(2019) ram3/32gb (เครื่องศูนย์ไทย,มีประกันศูนย์) แบต 6,150 mah แถมฟรี! ฟิลม์กระจก',
#  'category_1_36': 'เทปกาวสองหน้านาโน ล้างทำความสะอาดได้ เทปใสสารพัดประโยชน์ ติดเเน่น ติดหนึบ ติดนาน ขนาดต่างๆ ฿ 15.84 ฿ 75.00 -79%',
#  'category_1_37': 'samsung galaxy (t595 )tab a 10.5 แบตจุใจ 7300 mah, ระบบเสียง dolby atmos และลำโพง 4 ตัว บน (แกะโชว์หน้าตู้เท่านั้นไม่ผ่านการใช้งาน100%)',
#  'category_1_38': 'samsung galaxy tab s6 (ram6/128gb) lte เครื่องศูนย์ไทย,มีประกันศูนย์ แถมฟรี! ฟิลม์กระจก',
#  'category_1_39': 'samsung galaxy tab s 5e 10.5 ram4/64gb (เครื่องศูนย์ไทย,มีประกัน1ปีเต็ม) แถมฟรี! ฟิลม์กระจก',
#  'category_1_40': '【ผ่อน 0% 10 เดือน】 huawei mediapad m5 lite 10 ram 4 gb l rom 64 gb ที่มาพร้อมลำโพง 4 ตัว และปากกา m-pen lite',
#  'category_1_41': 'huawei mediapad m5 lite 10.1″ with m-pen (ram 4gb rom 64gb) เครื่องศูนย์ไทยแท้100%',
#  'category_1_42': "【ผ่อน 0% 10 เดือน】 huawei mediapad t5 tablet 10.1'' wifi 2gb +16gb*",
#  'category_1_43': "【ผ่อน 0% 10 เดือนได้】huawei mediapad t5 tablet 10.1'' 3gb + 32gb / cellular / nano sim",
#  'category_1_44': 'apple ipad 10.2-inch wi-fi (ipad 7th gen 2019) ฿ 10,500.00 ฿ 10,900.00 -4%',
#  'category_1_45': '【ผ่อน 0% 10 เดือน】huawei mediapad m5 lite 8 / 3 gb+32 gb',
#  'category_1_46': 'original กล่อง huawei m5 เยาวชน 64gb jdn2-w09 hisilicon kirin 710 octa core 8 นิ้ว android 9.0 แท็บเล็ต',
#  'category_1_47': '【10 inch tablet android 9.0】【แถมฟรี หูฟังไร้สาย+ตุ๊กตาหมี】แท็บเล็ต ระบบแอนดรอยด์andorid ข้อเสนอที่ดีที่สุด（จัดส่งฟรี ）รับประกันหนึ่งปี แท็ปเล็ต 10นิ้ว octa core 6gb ram 128gb rom 3g 4g fdd lte wifi bluetooth gps phone call glass screen tablet pc ฿ 3,832.00 ฿ 7,999.00 -52%',
#  'category_1_48': 'แท็บเล็ต huawei mediapad m5 lite (8 นิ้ว) / 3 gb+32 gb (space grey)',
#  'category_1_49': 'original huawei mediapad m6 8.4 นิ้ว kirin 980 octa core android 9.0 หน้าจอ ips 2560x1600 6100mah ประเภท-c 13.0mp กล้อง',
#  'category_1_50': 'huawei mediapad t3 7 เครื่องศูนย์ไทย ประกัน 1 ปี [แถมฟรี huawei original flip cover+ฟิล์ม รวมมูลค่า 690 บาท]',
#  'category_1_51': '11.6 touchscreen 2-in-1 แล็ปท็อปและแท็บเล็ต 4gb + 128gb dual core win 10',
#  'category_1_52': 'huawei media pad t5 10.1 นิ้ว ram3gb/rom32gb โทรได้',
#  'category_1_53': 'huawei honor แท็บเล็ต 8 นิ้ว ips หน้าจอสัมผัส android 7.0 3g + 32g qualcomm snapdragon 425 quad แท็บเล็ตพีซีคอร์',
#  'category_1_54': 'original กล่อง huawei m5 เยาวชน 32gb jdn2-w09 hisilicon kirin 710 octa core 8 นิ้ว android 9.0 แท็บเล็ต',
#  'category_1_55': 'huawei mediapad m5 lite 10.1นิ้ว (( ประกันศูนย์ 1 ปี ))',
#  'category_1_56': 'original กล่อง huawei honor 5 cn rom 32gb hisilicon kirin 710 octa core 8 นิ้ว android 9.0 แท็บเล็ต',
#  'category_1_57': "huawei mediapad t5 10.1'' 4g lte 3gb + 32gb *พร้อมของแถม ลำโพงบลูทูธ มูลค่า 1,290.-",
#  'category_1_58': 'siamtv huawei mediapad รุ่น t5104gbksyn',
#  'category_1_59': 'huawei mediapad m5 lite',
#  'category_1_60': 'huawei mediapad t3 7 ประกันศูนย์ 1 ปี',
#  'category_1_61': 'huawei mediapad t5 10.1"',
#  'category_1_62': '[ผ่อน 0% 10 เดือน] huawei mediapad t5 10.1 4g ram 3gb rom 32gb *พิเศษรับประกันเพิ่มปีที่ 2* *ฟรี shoulder bag usb *ของแถมมีจำนวนจำกัด nsquared',
#  'category_1_63': 'huawei m6 android 9.0 แท็บเล็ต 4gb 64gb kirin 980 octa core 8.4 นิ้ว 6100mah mediapad',
#  'category_1_64': "huawei mediapad t5 10.1'' wifi black ประกันศูนย์ไทย 1 ปี [แถมฟรี original flip cover แท้ มูลค่า 690 บาท]",
#  'category_1_65': 'huawei mediapad m5 pro ram4/64gb (หน้าจอใหญ่ 10.8 นิ้ว) เครื่องใหม่ศูนย์มีประกัน 6 เดือน แถมฟรี! เคสหนังแท้+ปากกา',
#  'category_1_66': "huawei mediapad t5 (tablet 10.1'' lte) ram3gb/32gb เครื่องศูนย์,มีประกันศูนย์1ปี สีดำ",
#  'category_1_67': 'huawei mediapad m5 [[ประกันศูนย์ไทย 1ปี]] ฟรีเคสแท้ huawei',
#  'category_1_68': 'huawei mediapad t5 10 (wifi+cellular ram 3gb + ความจุ 32gb รองรับ nanosim โทรออกได้) - แถมฟรี เคส+ฟิล์มกันรอยในกล่อง',
#  'category_1_69': 'huawei mediapad m5 pro',
#  'category_1_70': 'huawei mediapad t3 7.0 ram 2gb/rom 16gb (ใช้โทรได้)*แถมฟรีเคสหนัง huawei(ในกล่อง)',
#  'category_1_71': 'huawei mediapad m5 pro ram4/64gb (หน้าจอใหญ่ 10.8 นิ้ว) เครื่องใหม่ศูนย์มีประกัน 6 เดือน แถมฟรี! ปากกา+เคสหนังแท้',
#  'category_1_72': 'huawei mediapad m5 lite 8.0 (( ประกันศูนย์ 1 ปี ))',
#  'category_1_73': 'huawei mediapad m5 lite 8″ เครื่องศูนย์ไทย ประกัน 1 ปี [แถมฟรี huawei original flip cover รวมมูลค่า 690 บาท]',
#  'category_1_74': '[แท้ ใหม่ ศูนย์ไทย] huawei mediapad m5 lite 10.1นิ้ว [4+64gb] 4g lte',
#  'category_1_75': 'huawei mediapad m5 pro ram4/64gb (หน้าจอใหญ่ 10.8 นิ้ว) เครื่องใหม่ศูนย์มีประกัน แถมฟรี! เคสหนังแท้พร้อมปากกา',
#  'category_1_76': 'huawei mediapad m5 (แถมฟรี เคส+ หูฟังบลูทูธ huawei sport bluetooth headphones lite)',
#  'category_1_77': "huawei mediapad t5 10.1'' 4g,wifi แถมเคสแท้ + ฟิล์มกันรอยใสในกล่อง ((ประกันศูนย์1ปี))",
#  'category_1_78': 'huawei mediapad m5 lite 3/32gb[เครื่องศูนย์ไทยรับประกัน1ปี]',
#  'category_1_79': 'huawei mediapad m5 pro ram4/64gb (หน้าจอใหญ่ 10.8 นิ้ว) เครื่องใหม่ศูนย์มีประกัน 6 เดือน แถมฟรี! เคสหนังแท้+ปากกา',
#  'category_1_80': 'apple ipad pro 10.5 inch wifi 256gb rose gold',
#  'category_1_81': "lenovo tab 4 10plus x704l tablet 10'' 4+64gb แถม folio case/film ฿ 7,999.00 ฿ 11,990.00 -33%",
#  'category_1_82': 'apple ipad pro 10.5 inch wifi + cellular 256gb space gray',
#  'category_1_83': 'apple ipad air wifi+cellular - silver',
#  'category_1_84': 'แท็บเล็ตรุ่นใหม่ล่าสุดปี2019 !! แท็บเล็ตราคาประหยัด alldocube iplay8 pro จอ8นิ้ว แอนดรอยด์9 แรม2 รอม32 แท็บเล็ตโทรได้ แท็บเล็ตใส่ซิมได้ รองรับ3g แถมฟรีสายชาร์จ รับประกันหนึ่งปี (สีเงิน)',
#  'category_1_85': "alldocube (cube) iplay10 pro (u1006) รุ่น 2019 android 9.0 จอ 10.1'' แบบ ips mtk 8163a quad core 1.5ghz 3gb/32gb gps, hdmi",
#  'category_1_86': 'alldocube (cube) iplay8 (u78) tablets 7.85" ips android 6.0 mtk8163 quad core hdmi gps dual wifi 2.4g/5g 1g/16g',
#  'category_1_87': 'กล่อง original alldocube m8 32 gb mt6797x helio x27 deca core 8 นิ้ว android 8.0 แท็บเล็ตแบบ dual 4g',
#  'category_1_88': 'alldocube x แท็บเล็ต pc 4gb ram 64gb rom, 10.5 นิ้ว android 8.1 mtk 8176 hexa core 1.7 ghz-eu plug',
#  'category_1_89': 'alldocube power m3 รองรับ 4g แบต 8000mah ชาร์จเร็ว 10.1นิ้ว 1920*1200 ips แอนดรอยด์ 8.1 mt6753 octa core 2gb/32gb',
#  'category_1_90': 'original กล่องลูกบาศก์ mix plus 128 กิกะไบต์ intel kaby lake 7y30 dual core 10.6 หน้าต่างนิ้ว 10 แท็บเล็ต pc',
#  'category_1_91': '64gb + 4gb huawei tab 5 10.1 นิ้ว dual sim แท็บเล็ต wi-fi (import) ฿ 4,975.00 ฿ 6,560.00 -24%',
#  'category_1_92': 'original กล่องลูกบาศก์ mix plus 128 gb intel kaby lake 7y30 dual core 10.6 หน้าต่างนิ้ว 10 แท็บเล็ต pc',
#  'category_1_93': 'แท็บเล็ตแอนดรอยด์ราคาถูก alldocube iplay 7t แท็บเล็ตใส่ซิม รองรับ2ซิม โทรได้รองรับ4g หน้าจอ7นิ้ว รับประกัน1ปี พร้อมแถม !! อะเดปเตอร์ และสายชาร์จ (สีเงิน)',
#  'category_1_94': 'กล่อง original alldocube m5x 64 gb mt6797x helio x27 deca core 10.1 นิ้ว android 8.0 แท็บเล็ตแบบ dual 4g',
#  'category_1_95': 'alldocube กล่อง original alldocube x 64 gb mt8176 hexa core 10.5 นิ้ว amoled android 8.1 แท็บเล็ตลายนิ้วมือ',
#  'category_1_96': 'กล่อง original alldocube m8 32 gb mt6797x helio x27 deca core 8 นิ้ว android 8.0 แท็บเล็ตแบบ dual 4g',
#  'category_1_97': 'alldocube iplay 7t android 9.0 6.98 นิ้วแท็บเล็ต mini pad 2gb ram 16gb rom แท็บเล็ต- eu plug',
#  'category_1_98': 'alldocube iwork10 pro windows10 + android5.1 แท็บเล็ต 2 ระบบ intel atom x5 z8350 quad core 4gb ram 64gb rom จอ 10.1 นิ้ว แบบ ips 1920*1200',
#  'category_1_99': 'alldocube m8 mt6797x helio x27 deca core ใส่ได้ 2 ซิม โทรได้ รองรับ 4g 8 นิ้ว 1920*1200 แอนดรอยด์ 8.0 3gb ram 32gb rom',
#  'category_1_100': 'alldocube m5xs phablet 10.1 inch android 8.0 4g lte mtkx27 10 core phone call tablets pc 1920*1200 fhd ips 3gb ram 32gb rom gps',
#  'category_1_101': 'แท็บเล็ตรุ่นใหม่ล่าสุดปี2019 !! tablets-android -10.1 tablet ใหม่! จอกว้าง 10.1 นิ้ว ใช้งานง่าย , 13 ล้านพิกเซล,wps office,gps+wifi,ram 4gb ความจุ 64gb ราคาถูก แปลภาษาไทย',
#  'category_1_102': '2019 รุ่นใหม่ล่าสุด !! แท็บเล็ตราคาประหยัด alldocube iplay10 pro หน้าจอขนาดใหญ่ 10.1 นิ้ว จอสวยระดับhd รองรับโหมดการอ่านหนังสือ รับประกันหนึ่งปี แถมฟรี อแดปเตอร์ สายชาร์จ (สีดำ)',
#  'category_1_103': 'แท็บเล็ตทำงาน alldocube nuvision ระบบ windows 10 ทำงาน microsoft office ได้ ลงโปรแกรมได้เหมือน notebook รับประกัน1ปี แถมฟรี !! คีย์บอร์ด และอะแดปเตอร์พร้อมสายชาร์จหัวกลม (สีเงิน)',
#  'category_1_104': 'alldocube m5 10.1 นิ้ว 4g ใส่ซิม โทรได้ จอ 2560*1600 ips android 8.0 mtk x20 deca core 4gb ram 64gb rom',
#  'category_1_105': 'alldocube iplay 7t android 9.0 6.98 นิ้วแท็บเล็ต mini pad 2gb ram 16gb rom-eu ปลั๊ก',
#  'category_1_106': '[tablet window] แท็บเล็ตทำงาน alldocube knote go ระบบ windows 10 ทำงาน microsoft office ได้ลงโปรแกรมได้เหมือน notebook แถมฟรี คีย์บอร์ด ,อะแดปเตอร์พร้อมสายชาร์จ และสาย micro otg(สีเงิน)',
#  'category_1_107': '[tablet android] แท็บเล็ตราคาประหยัด alldocube iplay8 ระบบ android 6.0 รองรับ wifi เล่น facebook , youtube , line ได้ มีรับประกัน พร้อมแถมสายชาร์จ (สีเทา)',
#  'category_1_108': 'alldocube iplay 7t จอ 6.98 นิ้ว 1280x720 ips ใส่ซิม โทรได้ 4g lte android 9.0 pie quad core 2/16gb gps',
#  'category_1_109': 'alldocube m5 10.1 inch 4g phone tablet pc android 8.0 4gb/64gb (gray)',
#  'category_1_110': 'alldocube m5x tablet phone 4g 10.1" ips screen mtk mt6797x deca core android 8.0 4gb/64gb (silver)',
#  'category_1_111': 'alldocube power m3 10.1 inch 4g phone tablet pc android 7.0 2gb/32gb (grey)',
#  'category_1_112': 'แท็บเล็ตรุ่นใหม่ล่าสุดปี2019 !! แท็บเล็ตราคาประหยัด alldocube iplay8 pro จอ8นิ้ว แอนดรอยด์9 แรม2 รอม32 แท็บเล็ตโทรได้ แท็บเล็ตใส่ซิมได้ รองรับ3g แถมฟรีอะแดปเอตร์ และสายชาร์จ รับประกันหนึ่งปี (สีเงิน)',
#  'category_1_113': 'alldocube (cube) knote5 (i1102/i1102s) 2 in 1 laptop+tablet pc 11.6 inch fhd 1920*1080 win10 64-bit intel gemini lake n4000 2.6ghz 4gb ram 64/128gb ssd 2.4/5ghz wifi',
#  'category_1_114': 'แท็บเล็ตทำงาน alldocube iwork10 pro windows10 ทำงานmicrosoftofficeได้ ลงโปรแกรมได้เหมือนnotebook รับประกันหนึ่งปี แถมฟรี !! dockingคีย์บอร์ด ,อะแดปเตอร์ ,สายชาร์จtype-c',
#  'category_1_115': '2019 ข้อเสนอที่ดีที่สุด [alldocube m5xs ] (จัดส่งฟรี) รับประกัน 6 เดือน แท็บเล็ต adroid 8.0 10.1 นิ้ว, 3gb ram, ความจุ 32gb, ราคาถูก, สามารถตั้งค่าภาษาไทยได้',
#  'category_1_116': 'alldocube knote 5 2 in 1 tablet 11.6" intel gemini lake n4000 windows 10 home 4gb/128gb (silver)',
#  'category_1_117': "lenovo tab 4 10plus x704l tablet 10'' 4+64gb แถม folio case/film ฿ 7,999.00 ฿ 11,990.00 -33%",
#  'category_1_118': '64gb + 4gb huawei tab 5 10.1 นิ้ว dual sim แท็บเล็ต wi-fi (import) ฿ 4,975.00 ฿ 6,560.00 -24%',
#  'category_1_119': 'แท็บเล็ตทำงาน alldocube iwork10 pro windows10 ทำงานmicrosoftofficeได้ ลงโปรแกรมได้เหมือนnotebook รับประกันหนึ่งปี แถมฟรี !! อะแดปเตอร์ ,สายชาร์จtype-c',
#  'category_1_120': 'แท็บเล็ตทำงาน alldocube knote x หน้าจอ13.3นิ้ว ความละเอียด2k intel celeron n4100 แรม8gb พื้นที่เก็บข้อมูล128gb ssd แถมฟรี !! อะแดปเตอร์พร้อมสายชาร์จ รับประกัน1ปี(สีเงิน)',
#  'category_1_121': 'android 2019 10.1แท็บเล็ต 2019 tablet android 10.1 แท็บเล็ตที่ได้รับความนิยมล่าสุด alldocube iplay10 pro 10.1 นิ้วหน้าจอขนาดใหญ่, ลำโพง 3d สองทิศทางล้อมรอบด้วยเสียง dolby, รองรับโหมดการอ่าน, ดูวิดีโอ 1080p ที่ราบรื่น, สแตนด์บายครึ่งเดือน, นำทาง gps',
#  'category_1_122': 'alldocube iplay8 pro iplay 8 android 9.0 แท็บเล็ต pc 3g phablet 8 นิ้ว 800x1280 mt8321 quad core 2gb ram 32gb เด็กแท็บเล็ต gps-eu plug',
#  'category_1_123': '(ซื้อ 1 แถม 1 ฟรี) สำหรับ vivo v9 v11 v11i v7 y15pro y12 หลายรุ่น non-slip soft 3d คาร์บอนไฟเบอร์ฝาหลังฟิล์มป้องกันด้านหลังสติกเกอร์ป้องกัน ฿ 55.00 ฿ 92.00 -40%',
#  'category_1_124': 'แท็บเล็ตแอนดรอยด์ teclast p10hd ใส่ซิมได้ โทรได้ dual sim รองรับ4g หน้าจอ10.1 ความชัดระดับfull hd แอนดรอยด์9.0 แรม3 รอม32 แถมฟรี หัวชาร์จ และสายชาร์จ รับประกัน1ปี (สีดำ)',
#  'category_1_125': 'teclast p10hd โทรได้ รองรับ 4g จอ ips 1920*1200 ขนาด 10.1 นิ้ว android 9.0octa core แรม 3gb ความจุ 32g gps แบต 6000mah',
#  'category_1_126': 'teclast m16 จอ 11.6 นิ้ว ใส่ซิม โทรได้ รองรับ 4g mt6797x helio x27 deca core android 8.0 แรม 4gb ความจุ 128gb รองรับคีย์บอร์ด hdmi',
#  'category_1_127': 'teclast/a10s แท็บเล็ต pc 10.1 นิ้ว ips หน้าจอ android smart hd มือถือแบบบางพิเศษจอยเกมส์ audio play สเตอริโอ android เต็มรูปแบบ',
#  'category_1_128': 'teclast m30 android 8.0 2560x1600 10.1 นิ้วแท็บเล็ต pc 4gb ram 128gb rom, mt6797 x27 deca core 7500mah gps-eu plug',
#  'category_1_129': 'teclast p80x จอ8นิ้ว 1280x800 ips ใส่ซิม โทรได้ 4g android 9.0 pie octa core ram2gb rom32gb รับประกัน1ปี พร้อมแถม อะแดปเอตร์ และสายชาร์จ (สีดำ)',
#  'category_1_130': 'teclast p80 pro 3gb 32gb 8 นิ้ว android 7.0 mtk8163 quad core 1.3 กิ๊กกะเฮิร์ตซ์แท็ปเล็ตพีซีกล้องคู่ wifi 1920*1200 gps eu ปลั๊กสีขาว',
#  'category_1_131': "teclast p80h 8'' android7.0 dual wifi gps otg 8g mtk8163 64bit quad-coretable pc",
#  'category_1_132': '【การจัดส่ง + super deal + จำกัด offer】teclast x4 intel gemini lake n4100 quad core 2.4ghz ram 8g 128gb ssd 11.6 หน้าต่างนิ้ว 10 แท็บเล็ต',
#  'category_1_133': '【การจัดส่ง + super deal + จำกัด offer】teclast x4 intel gemini lake n4100 quad core 2.4 ghz ram 8g 128 gb ssd 11.6 หน้าต่างนิ้ว 10 แท็บเล็ต',
#  'category_1_134': 'teclast m30 android 8.0 2560x1600 10.1 นิ้วแท็บเล็ต pc 4gb ram 128gb rom, mt6797 x27 deca core 7500mah gps-eu plug',
#  'category_1_135': 'teclast/a10s แท็บเล็ต pc 10.1 นิ้ว ips หน้าจอ android smart hd มือถือแบบบางพิเศษจอยเกมส์ audio play สเตอริโอ android เต็มรูปแบบ',
#  'category_1_136': 'teclast p80 pro mt8163 quad core 3g ram 32g 8 นิ้ว android 7.0 แท็บเล็ต pc',
#  'category_1_137': '[tablet android] รุ่นอัพเกรด teclast รุ่น p80 pro หน้าจอ 8 นิ้ว ความละเอียด 1920x1200 android 7.0 แรม3 รอม32 รับประกัน 1 ปี แถมฟรี หัวชาร์จ ,สายmicro usb (สีทอง)',
#  'category_1_138': 'teclast a10s รุ่นใหม่ จอ 10.1 นิ้ว fhd ips ogs quad core 2gb ram 32gb rom มี gps, hdmi dc2.5, free case!',
# ...
#  'category_4_28': 'asus gaming notebook rog strix gl504gv (es036t ) core i7-8750h 8th gen 15.6 -inch (8 gb/512 gb ssd/windows 10 home/nvidia geforce rtx 2060 6 gb/2 years asus warranty) ผ่อน 0% สูงสุด10เดือน โน้ตบุ๊คถูก เกมมิ่ง ฿ 35,900.00 ฿ 54,990.00 -35%',
#  'category_4_29': 'asus notebook (โน้ตบุ๊ค) rog strix g702vmk-gc339 / i7-7700hq/8 gb/ 1tb+128 gb ssd/17.3 fhd ips/gtx 1060 (3gb)/os : endless/black/clear stock',
#  'category_4_30': 'notebook (โน้ตบุ๊ค) asus a1-gl504gv-es036t+bag',
#  'category_4_31': 'notebook (โน้ตบุ๊ค) asus a1-gl504gv-es036t+bag',
#  'category_4_32': 'asus rog strix g g531gv-az158t i5-9300h/8gb/512gb ssd/rtx2060 6gb/15.6/win10 (black)',
#  'category_4_33': 'microsoft tablet surface go intel pentium gold processor 4415y/4gb/64gb/10inch ฿ 14,990.00',
#  'category_4_34': 'asus rog zephyrus s gx502gv-az035t (ฟรี steam 300) (รบกวนสอบถาม trakool store ก่อนกดสั่งซื้อ)',
#  'category_4_35': 'asus fx505dt-al106t [ tuf gaming ][ 15.6 inch ips ][ metal ][ rgb ]',
#  'category_4_36': 'asus tuf gaming fx505dt al043t',
#  'category_4_37': 'asus rog strix g g531gt-al003t (ฟรี steam 300) (รบกวนสอบถาม trakool store ก่อนกดสั่งซื้อ)',
#  'category_4_38': 'asus rog strix g g531gv-al096t (ฟรี steam 300) (รบกวนสอบถาม trakool store ก่อนกดสั่งซื้อ)',
#  'category_4_39': 'asus notebook rog g502vm-fy398 (black)',
#  'category_4_40': 'โน๊ตบุ๊ค /notebook acer nitro an515-52-53tu /(nh.q3mst.012) / 15.6 inch ips fhd/ intel i5-8300h / ram 8gb ddr4/ ssd 512gb/ gtx 1050 (4gb)/no dvd/ win10/ รับประกันศูนย์ acer 3ปี/ black /คอมพิวเตอร์ pc /เกมมิ่งโน้ตบุ๊ค ผ่อน 0% สูงสุด 10 เดือน ส่งเร็ว',
#  'category_4_41': 'acer aspire nitro 5 an515-43-r2pm(nh.q5xst.002)/amd ryzen 5 3550h/8 gb/512 gb ssd pcie//rx560x 4gb /15.6 fhd ips 144hz/win10/warranty 1year/0%',
#  'category_4_42': 'asus gaming notebook rog strix gl504gv (es036t ) core i7-8750h 8th gen 15.6 -inch (8 gb/512 gb ssd/windows 10 home/nvidia geforce rtx 2060 6 gb/2 years asus warranty) ผ่อน 0% สูงสุด10เดือน โน้ตบุ๊คถูก เกมมิ่ง ฿ 35,900.00 ฿ 54,990.00 -35%',
#  'category_4_43': 'acer aspire nitro 5 an515-54-546a (nh.q59st.026) i5-9300h/8gb/512gb ssd/geforce gtx1650 4gb/15.6 fhd ips 144hz/win10/obsidian black/0%',
#  'category_4_44': 'acer nitro an515-54-53rw intel core i5-9300h/8gb/512gb ssd/gtx 1050/15.6/win10 (black)',
#  'category_4_45': 'โน๊ตบุ๊ค /notebook acer nitro an515-52-53tu /(nh.q3mst.012) / 15.6 inch ips fhd/ intel i5-8300h / ram 8gb ddr4/ ssd 512gb/ gtx 1050 (4gb)/no dvd/ win10/ รับประกันศูนย์ acer 3ปี/ black /คอมพิวเตอร์ pc /เกมมิ่งโน้ตบุ๊ค ผ่อน 0% สูงสุด 10 เดือน ส่งเร็ว',
#  'category_4_46': 'acer nitro an515-54-53dg intel core i5-9300h/8gb/1tb/gtx 1050/15.6/win10 (black)',
#  'category_4_47': 'notebook (โน้ตบุ๊ค) acer nitro an715-51-76sy (black)',
#  'category_4_48': 'acer notebook nitro an515-54-76th (nh.q5ast.001) i7-9750h/8gb/1tb hdd/geforce gtx1050 3gb/15.6 fhd/win10home/obsidian black',
#  'category_4_49': 'microsoft tablet surface go intel pentium gold processor 4415y/4gb/64gb/10inch ฿ 14,990.00',
#  'category_4_50': 'ลดล้างสต็อก 70% notebook dell latitude 2100-2120 เครื่องแท้100% สินค้ามีจำนวนจำกัด ฿ 2,840.00 ฿ 7,990.00 -64%',
#  'category_4_51': 'acer nitro an515-43-r1n1 amd ryzen 5 3550h/8gb/512gb ssd/amd radeon/15.6/win10 (black)',
#  'category_4_52': 'acer nitro an515-52-783e (black)',
#  'category_4_53': 'acer aspire nitro 5 an515-54-76th/i7-9750h/8gb/1tb hdd/geforce gtx1050 3gb/15.6 fhd/win10home/obsidian black/top computer',
#  'category_4_54': 'microsoft tablet surface go intel pentium gold processor 4415y/4gb/64gb/10inch ฿ 14,990.00',
#  'category_4_55': 'acer notebook nitro an515-54-76th (nh.q5ast.001) i7-9750h/8gb/1tb hdd/geforce gtx1050 3gb/15.6"fhd/win10home/obsidian black 0%',
#  'category_4_56': 'notebook (โน้ตบุ๊ค) acer nitro an515-52-72vd (black)',
#  'category_4_57': 'acer nitro an515-54-72lw',
#  'category_4_58': 'acer aspire 5 14 a514-51g-5028',
#  'category_4_59': 'acer notebook nitro an515-54-76th (nh.q5ast.001) i7-9750h/8gb/1tb hdd/geforce gtx1050 3gb/15.6 fhd/win10home/obsidian black/ตำหนิ',
#  'category_4_60': 'ลดล้างสต็อก 70% notebook dell latitude 2100-2120 เครื่องแท้100% สินค้ามีจำนวนจำกัด ฿ 2,840.00 ฿ 7,990.00 -64%',
#  'category_4_61': 'acer aspire nitro 5 an515-43-r2pm(nh.q5xst.002)/amd ryzen 5 3550h/8 gb/512 gb ssd pcie//rx560x 4gb /15.6 fhd ips 144hz/win10',
#  'category_4_62': 'แล็ปท็อปโน้ตบุ๊คคอมพิวเตอร์โน๊ตบุ๊ค slim สีดำของขวัญทำงาน supply ฿ 12,115.00 ฿ 40,383.00 -70%',
#  'category_4_63': 'asus gaming notebook rog strix gl504gv (es036t ) core i7-8750h 8th gen 15.6 -inch (8 gb/512 gb ssd/windows 10 home/nvidia geforce rtx 2060 6 gb/2 years asus warranty) ผ่อน 0% สูงสุด10เดือน โน้ตบุ๊คถูก เกมมิ่ง ฿ 35,900.00 ฿ 54,990.00 -35%',
#  'category_4_64': 'notebook acer aspire a715-72g-72y9/t002 (black)',
#  'category_4_65': 'lenovo gaming notebook ideapad l340-15irh i5-9300h ram8g ssd512g gtx1050 3g w10 3y(81lk00mlta) ฿ 18,590.00 ฿ 18,990.00 -2%',
#  'category_4_66': 'notebook (โน้ตบุ๊ค) acer nitro an515-54-72fn (black)',
#  'category_4_67': 'acer notebook nitro an515-51-79sg/t025 (black)',
#  'category_4_68': 'acer nitro an515-52-71xg (black)',
#  'category_4_69': 'asus gaming notebook rog strix gl504gv (es036t ) core i7-8750h 8th gen 15.6 -inch (8 gb/512 gb ssd/windows 10 home/nvidia geforce rtx 2060 6 gb/2 years asus warranty) ผ่อน 0% สูงสุด10เดือน โน้ตบุ๊คถูก เกมมิ่ง ฿ 35,900.00 ฿ 54,990.00 -35%',
#  'category_4_70': 'lenovo gaming notebook ideapad l340-15irh i5-9300h ram8g ssd512g gtx1050 3g w10 3y(81lk00mlta) ฿ 18,590.00 ฿ 18,990.00 -2%',
#  'category_4_71': 'acer gaming notebook nitro 5 an515-54-51jf',
#  'category_4_72': 'acer nitro 5 an515-54-51jf/t006 i5-9300h/8gb/1tb/gtx1650 4gb/15.6/win10 (black)',
#  'category_4_73': 'acer predator helios 700 ph717-71-76we (black) (ฟรี steam 300) (รบกวนสอบถาม trakool store ก่อนกดสั่งซื้อ)',
#  'category_4_74': 'acer predator ph317-53-77zx (black)(รบกวนสอบถาม trakool store ก่อนกดสั่งซื้อ)',
#  'category_4_75': 'acer a715-72g-53we :ci5-8300h/ 8gb/1tb/gt1050 4gb/15.6/win10 :3y on-site',
#  'category_4_76': 'acer aspire nitro 5 an515-43-r2pm',
#  'category_4_77': 'notebook acer nitro an5 15-51 7004',
#  'category_4_78': 'acer nitro an515-54-70z5 (black)(ฟรี steam 300)(รบกวนสอบถาม trakool store ก่อนกดสั่งซื้อ)',
#  'category_4_79': 'acer nitro notebook an515-52-5069/t002 (black)',
#  'category_4_80': 'notebook (โน้ตบุ๊ค) msi gf63 thin 9rcx-486th',
#  'category_4_81': 'asus gaming notebook rog strix gl504gv (es036t ) core i7-8750h 8th gen 15.6 -inch (8 gb/512 gb ssd/windows 10 home/nvidia geforce rtx 2060 6 gb/2 years asus warranty) ผ่อน 0% สูงสุด10เดือน โน้ตบุ๊คถูก เกมมิ่ง ฿ 35,900.00 ฿ 54,990.00 -35%',
#  'category_4_82': 'msi gl63 8sd-471th 15.6"/i5-8300h/geforce gtx 1660 ti/8 gb ddr4/512 gb ssd pcie m.2/windows 10 home >>ประกัน 2 ปี<< (แถมกระเป๋า) black',
#  'category_4_83': 'โน๊ตบุ๊ค notebook acer nitro an515-54-566m (nh.q5ast.003)/ 15.6 ips fhd/ i5-9300h/ ram 8gb ddr4 /hdd 1tb 7200rpm/ gtx 1050 3gb gddr5/ no dvd/ win10/รับประกันศูนย์acer 3ปี/ black/ คอมพิวเตอร์/โน๊ตบุ๊คถูกๆ เกมมิ่งโน้ตบุ๊ค ผ่อน 0% สูงสุด 10 เดือน ส่งเร็ว ฿ 20,789.00 ฿ 25,990.00 -20%',
#  'category_4_84': 'msi gf75 thin 9sd-009th (ฟรี steam 300)(รบกวนสอบถาม trakool store ก่อนกดสั่งซื้อ)',
#  'category_4_85': 'msi gl65 9sdk-072th core i7-9750h/16gb/512gb ssd/gtx1660ti/15.6/win10 (black)',
#  'category_4_86': 'notebook msi gaming gl65 9sek-072th',
#  'category_4_87': 'msi gp75 leopard 9se-464th 17.3"/i7-9750h/geforce rtx 2060 (6gb gddr6)/16gb ddr4 (8gb*2)/512 gb ssd pcie m.2/windows 10 home >>ประกัน 2 ปี<< (แถมกระเป๋า) black',
#  'category_4_88': 'msi ge62 6qd-1020xth apache pro i7-6700hq/8gb/1tb/gtx 960m 4gb 15.6"',
#  'category_4_89': 'โน๊ตบุ๊ค notebook acer aspire a515-53g-59m2 (nx.hcfst.001)/15.6 full hd/i5-8265u/ ram 4 gb ddr4/ hdd1 tb 5400 rpm + 16 gb intel optane memory/ geforce mx230 2 gb gddr5/ win 10/dvd/รับประกันศูนย์ acer 2ปี silver โน๊ตบุ๊คถูกๆ ผ่อน 0% สูงสุด 10 เดือน ส่งเร็ว ฿ 13,990.00 ฿ 19,990.00 -30%',
#  'category_4_90': 'asus notebook(โน้ตบุ๊คเล่นเกมส์) rog zephyrus g ga502du-al005t/amd ryzen 7 3750h /8gb/512gb pcie/gtx 1660ti 6gb/15.6 fhd ips 120hz/win10home/black/warranty 2 year ฿ 26,890.00 ฿ 36,990.00 -27%',
#  'category_4_91': 'msi gl75 9sck-003th 17.3"/i7-9750h/gtx 1650 with 4gb gddr5/8gb ddr4 2666mhz/512gb ssd pcie m.2/windows 10 home >>ประกัน 2 ปี<< (แถมกระเป๋า) black',
#  'category_4_92': 'msi gs75 stealth 8sf 006th/intel core i7-8750h/16 gb (8gb x2) ddr4 2666mhz/512 gb pcie/nvme m.2 ssd/17.3 full hd ips 144hz/nvidia geforce rtx2070 8 gb gddr6/windows 10 home/by top computer',
#  'category_4_93': 'notebook (โน้ตบุ๊ค) msi gl63 8se (n18e-g1 ,gddr6 6gb) (9s7-16p732-201)',
#  'category_4_94': 'msi gf63 thin 9sc-296th(ฟรี ram 8 gb) (รบกวนสอบถาม trakool store ก่อนกดสั่งซื้อ)',
#  'category_4_95': 'notebook (โน้ตบุ๊ค) msi gp73 8re-647th leopard (9s7-17c522-647)',
#  'category_4_96': 'notebook (โน้ตบุ๊ค) msi gs75 stealth 8sf (n18e-g2 ,gddr6 8gb) (gs75-stealth-8sf-006)',
#  'category_4_97': 'msi gl75 9sek-013th (ฟรี ram 8 gb) (รบกวนสอบถาม trakool store ก่อนกดสั่งซื้อ)',
#  'category_4_98': 'notebook msi workstation ws65 8sk-461th',
#  'category_4_99': 'notebook (โน้ตบุ๊ค) msi gp63 leopard 8re (geforce® gtx 1060, 6gb gddr5) (gp63-leopard-8re-652)',
#  'category_4_100': 'notebook (โน้ตบุ๊ค) msi gs65 8se-203th stealth (9s7-16q411-203)',
#  'category_4_101': 'msi gs75 stealth 9sf-635th (ฟรี steam 1000) (รบกวนสอบถาม trakool store ก่อนกดสั่งซื้อ)',
#  'category_4_102': 'notebook msi prestige ps42 8rb-095th',
#  'category_4_103': 'notebook msi gp73 8re-646th (black)',
#  'category_4_104': 'โน้ตบุ๊ค hp notebook gaming pavilion 15-ec0010ax (green)/ 15.6 full hd/ amd ryzen 5 3550h/ 8 gb ddr4/ 512 gb ssd/nvidia geforce gtx1650 4 gb gddr5/ win10 /รับประกันศูนย์ hp 2 ปี ฿ 18,900.00 ฿ 21,900.00 -14%',
#  'category_4_105': 'โน๊ตบุ๊ค notebook acer nitro an515-54-566m (nh.q5ast.003)/ 15.6 ips fhd/ i5-9300h/ ram 8gb ddr4 /hdd 1tb 7200rpm/ gtx 1050 3gb gddr5/ no dvd/ win10/รับประกันศูนย์acer 3ปี/ black/ คอมพิวเตอร์/โน๊ตบุ๊คถูกๆ เกมมิ่งโน้ตบุ๊ค ผ่อน 0% สูงสุด 10 เดือน ส่งเร็ว ฿ 20,789.00 ฿ 25,990.00 -20%',
#  'category_4_106': 'msi p65 creator 9se-1016th',
#  'category_4_107': 'msi gs75 stealth 8sg 003th',
#  'category_4_108': 'msi gf63 thin 9rcx-483th(ฟรี ram 8 gb) (รบกวนสอบถาม trakool store ก่อนกดสั่งซื้อ)',
#  'category_4_109': 'msi gl65 9sek-071th(ฟรี ram 8 gb) (รบกวนสอบถาม trakool store ก่อนกดสั่งซื้อ)',
#  'category_4_110': 'msi ps42 modern 8ra-270th(ฟรี steam 300)(รบกวนสอบถาม trakool store ก่อนกดสั่งซื้อ)',
#  'category_4_111': 'msi gl65 9sdk-072th(ฟรี steam 300)(รบกวนสอบถาม trakool store ก่อนกดสั่งซื้อ)',
#  'category_4_112': 'msi modern 14 a10rb-675th (silver) (ฟรี steam 300) (รบกวนสอบถาม trakool store ก่อนกดสั่งซื้อ)',
#  'category_4_113': 'โน้ตบุ๊ค hp notebook gaming pavilion 15-ec0010ax (green)/ 15.6 full hd/ amd ryzen 5 3550h/ 8 gb ddr4/ 512 gb ssd/nvidia geforce gtx1650 4 gb gddr5/ win10 /รับประกันศูนย์ hp 2 ปี ฿ 18,900.00 ฿ 21,900.00 -14%',
#  'category_4_114': 'msi gf63 thin 9sc 297th',
#  'category_4_115': 'msi gs75 stealth 9sf-635th (ฟรี steam 300)(รบกวนสอบถาม trakool store ก่อนกดสั่งซื้อ)',
#  'category_4_116': 'msi gp75 leopard 9se-464th(ฟรี steam 300)(รบกวนสอบถาม trakool store ก่อนกดสั่งซื้อ)',
#  'category_4_117': 'โน๊ตบุ๊ค notebook acer nitro an515-54-566m (nh.q5ast.003)/ 15.6 ips fhd/ i5-9300h/ ram 8gb ddr4 /hdd 1tb 7200rpm/ gtx 1050 3gb gddr5/ no dvd/ win10/รับประกันศูนย์acer 3ปี/ black/ คอมพิวเตอร์/โน๊ตบุ๊คถูกๆ เกมมิ่งโน้ตบุ๊ค ผ่อน 0% สูงสุด 10 เดือน ส่งเร็ว ฿ 20,789.00 ฿ 25,990.00 -20%',
#  'category_4_118': 'notebook (โน้ตบุ๊ค) msi gl65 9sdk-072th',
#  'category_4_119': 'msi gf75 thin 9sc-225th(ฟรี steam 300)(รบกวนสอบถาม trakool store ก่อนกดสั่งซื้อ)',
#  'category_4_120': 'chaikamol : lenovo gaming notebook l340 81lk00mlta 15.6 full hd / i5-9300h / gtx 1050 / 8gb / ssd 512gb / win10 / 3y onsite',
#  'category_4_121': 'lenovo legion y545-81q6001ata',
#  'category_4_122': 'lenovo legion y540-81sx0025ta/i7-9750h/6gb /16 gb/15.6 (1920x1080)/1 tb/w10/top computer',
#  'category_4_123': 'lenovo notebook y520-80wk014qta (black)',
#  'category_4_124': 'lenovo notebook l340-15irh 81lk00mmta by banana it',
#  'category_4_125': 'lenovo ideapad l340-15irh-81lk00mlta/ i5-9300h/8 gb /15.6 full hd ips /512 gb ssd/w10/3y/black/by notebook store',
#  'category_4_126': 'lenovo ideapad l340 gaming-81ll006yta/i7-9750h/8gb/256gb m.2 ssd/geforce gtx1650 4gb/17.3 fhd/win10home/black/top computer',
#  'category_4_127': 'lenovo legion y530-15ich i5-8300h ram8g rom512g gtx1050 4g w10 3y(โน๊ตบุ๊คเกมมิ่ง)',
#  'category_4_128': 'lenovo ideapad c340-14iwl-81n4007pta (ฟรี steam 300) (รบกวนสอบถาม trakool store ก่อนกดสั่งซื้อ)',
#  'category_4_129': 'lenovo 330-15ich-81fk005uta (ฟรี steam 300) (รบกวนสอบถาม trakool store ก่อนกดสั่งซื้อ)',
#  'category_4_130': 'lenovo y530-15ich-81fv015wta (ฟรี steam 300) (รบกวนสอบถาม trakool store ก่อนกดสั่งซื้อ)',
#  'category_4_131': 'lenovo ideapad l340-15irh (81lk00mmta)',
#  'category_4_132': 'โน้ตบุ๊ค hp notebook gaming pavilion 15-ec0010ax (green)/ 15.6 full hd/ amd ryzen 5 3550h/ 8 gb ddr4/ 512 gb ssd/nvidia geforce gtx1650 4 gb gddr5/ win10 /รับประกันศูนย์ hp 2 ปี ฿ 18,900.00 ฿ 21,900.00 -14%',
#  'category_4_133': 'lenovo ideapad l340 gaming-81lk00mlta/i5-9300h/8gb/512gb m.2 ssd/geforce gtx1050 3gb/15.6 fhd/win10home/black/top computer',
#  'category_4_134': 'lenovo gaming notebook ideapad l340-15irh i5-9300h ram8g ssd512g gtx1050 3g w10 3y(81lk00mlta)',
#  'category_4_135': 'lenovo legion y530 81fv01cpta/i5-8300h/ 8 gb ddr4/512 gb ssd/15.6 full hd/gtx1050 4 gb/w10/top computer',
#  'category_4_136': 'lenovo legion y540-81sy00arta',
#  'category_4_137': 'chaikamol : lenovo gaming notebook l340 81lk00mmta 15.6 full hd / i5-9300h / gtx 1650 / 8gb / ssd 512gb / win10 / 3y onsite',
#  'category_4_138': 'lenovo legion y540-81sy00aqta/i7-9750h/8gb/1tb hdd+256gb m.2 ssd/geforce gtx1650 4gb/15.6 fhd/win10home/black/top computer',
#  'category_4_139': 'lenovo legion y740-15irhg-81uh0075ta/i7-9750h/16gb/512gb m.2 ssd/geforce rtx 2070 maxq 8gb/15.6 fhd/win10home/black/top computer',
#  'category_4_140': 'lenovo legion y540-15irh-pg0 (81sy00arta) gaming notebook 15.6" i5-9300h ram8gb hdd1tb+ssd256gb gtx1650 w10',
#  'category_4_141': 'lenovo legion y7000 se (81t00011ta) i7-9750h/8gb/512gb ssd/gtx1650 4gb/15.6/win10 (black)',
#  'category_4_142': 'lenovo ideapad l340-15irh (81lk00mlta) i5-9300h/8gb/512gb ssd/gtx1050/15.6/win10 (black)',
#  'category_4_143': 'lenovo legion y740-17irhg (81uj005dta) gaming notebook',
#  'category_4_144': 'lenovo legion y740 17-81uj005dta',
#  'category_4_145': 'lenovo gaming notebook ideapad l340-15irh i5-9300h8g512g gtx1050 3g w10 3y(โน๊ตบุ๊ค)',
#  'category_4_146': 'โน๊ตบุ๊ค lenovo notebook gaming legion y530-15ich (81lb006vta)/ 15.6" full hd ips/core i7-8750h/ram 8 gb ddr4 2666/ssd 512gb/win 10/nvidia geforce gtx1060 6 gb gddr5/ no dvd/ black/ รับประกันศูนย์ lenovo 2 ปี) ผ่อน 0% สูงสุด 10 เดือน ส่งเร็ว',
#  'category_4_147': 'lenovo legion y530-15ich (81fv01cpta) i5-8300h/8gb/512gb ssd/gtx1050/15.6/win10 (black)',
#  'category_4_148': 'lenovo legion y7000se (81t00011ta) i7-9750h/8gb/512gb ssd/gtx1650 4gb/15.6/win10 (black)',
#  'category_4_149': 'lenovo notebook notebook y series legiony530-15ich (81fv015wta) i5-8300h/8gb/1tb 7mm 5400rpm/gtx 1050ti 4gb/15.6" fhd/win10 home/black/2 year on site/0%',
#  'category_4_150': 'lenovo ideapad l340-15irh (81lk00mmta) i5-9300h/8gb/512gb ssd/gtx1650/15.6/win10 (black)',
#  'category_4_151': 'lenovo legion y7000 2019 pg0 (81t00011ta) gaming notebook 15.6" i7-9750h ram8gb ssd512gb gtx1650 w10 (black)',
#  'category_4_152': 'lenovo legion y740 17-81uj005dta/i7-9750h/32gb/1tb m.2 ssd/geforce rtx2070 maxq 8gb/17.3 fhd/win10home/black/top computer',
#  'category_4_153': 'lenovo ideapad l340-15irh (81lk00mlta) i5-9300h/8gb/512gb ssd/gtx1050/15.6/win10 (black)',
#  'category_4_154': 'lenovo notebook notebook y series legion y530-15ich (81fv000lta) i7-8750h/8gb/1tb+128gb ssd/gtx 1050ti 4gb/15.6 fhd ips/win10home/black',
#  'category_4_155': 'lenovo legion y540-81sy00arta/i5-9300h/8gb/1tb+256gb m.2 ssd/geforce gtx1650 4gb/15.6 fhd/win10home/black/top computer',
#  ...}

# %%
## Creating Nodes
nodes_e = []
nodes_c = []
relationships = []
for i in range(len(triples)):
    product = 0
    for n in nodes_e:
        if dict(n)['name'] == dic[triples[i][0]]:
            product = n
            break
    if product==0:
        product = Node('Product',name = dic[triples[i][0]])
        nodes_e.append(product)
    
    attr = 0
    for n in nodes_c:
        if dict(n)['name'] == triples[i][2]:
            attr = n 
            break
    if attr==0:
        attr = Node('Attribute',name = triples[i][2])
        nodes_c.append(attr)  
    
    relationship = Relationship(product,triples[i][1],attr)
    relationships.append(relationship)

# %%
host = 'localhost'
user = 'neo4j'
password = '1234'

# %%
# Creating the graph
graph =Graph(host=host, user=user, password=password) # initial graph from the data
#graph = Graph('bolt://neo4j:test@127.0.0.1:7687/db/data')
tx = graph.begin()

for node in nodes_e:
    tx.create(node)
for node in nodes_c:
    tx.create(node)
for relationship in relationships:
    tx.create(relationship)
    
tx.commit()

url = 'http://localhost:7474'
webbrowser.open(url, new=2) # new=2 opens a new tab
# Out:
# True

# %%
# Creating the graph
#graph =Graph(host=host, user=user, password=password) # initial graph from the data
#tx = graph.begin()
#tx = graph.delete_all()
