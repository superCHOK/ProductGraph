# %%
import pandas as pd
import csv
import re
import string
import nltk

from pythainlp.tokenize import Tokenizer
from pythainlp import word_tokenize
from pythainlp.corpus import thai_stopwords
from pythainlp.tokenize import dict_trie
from pythainlp.tag import pos_tag

from nltk.corpus import words
from stop_words import get_stop_words

# %% [markdown]
# # Function

# %%
# clean the text
def clean_text(msg): 

    msg = str(msg).lower()
    
    regex_na = re.compile("n/a")
    if re.findall(regex_na, msg):
        msg = " "
    
    else:
        msg = re.sub(r"\,", "", str(msg))
        msg = re.sub(r"[^a-z0-9ก-๙\.\%\:]", " ", str(msg))
        msg = re.sub(r"\s+", " ", str(msg))
    # Delete punctuation
   # str_punc = string.punctuation.replace(".","")
   # for c in str_punc:
    #    msg = re.sub(r'\{}'.format(c),'',str(msg))
    
    # ลบ separator เช่น \n \t
    msg = ' '.join(msg.split())
    
    return msg

# %% [markdown]
# # Load data

# %% [markdown]
# ## Product details

# %%
def get_data_from_csv(file_name, idx_col):
    
    FILE = './Data/{}.csv'.format(file_name)
    df_1 = pd.read_csv(FILE, index_col=idx_col)
    return df_1

# %%
# Load data from csv 

file_name = 'data_jib_1'
file_name_2 = 'data_jib_2'
prod_name = 'productname'
prod_name_2 = 'mistake_get_data'

df_1 = get_data_from_csv(file_name, 0)
df_2 = get_data_from_csv(file_name_2, 0)
prod_name_df = get_data_from_csv(prod_name, 1)
prod_name_df_2 = get_data_from_csv(prod_name_2, 3)

# %%
df_1.head()
# Out:
#           P_0Q               P_0A         P_1Q                  P_1A  \
# 0    CPU Brand                AMD    CPU Brand                 Intel
# 1    CPU Model  AMD Ryzen 5 3500U    CPU Model  Intel Core i5-10210U
# 2   Base Clock           2.00 GHz   Base Clock              1.60 GHz
# 3  Boost Clock           3.60 GHz  Boost Clock              4.20 GHz
# 4        Cache               4 MB        Cache                  6 MB
#
#           P_2Q               P_2A         P_3Q                  P_3A  \
# 0    CPU Brand                AMD    CPU Brand                 Intel
# 1    CPU Model  AMD Ryzen 5 3500U    CPU Model  Intel Core i5-1035G1
# 2   Base Clock           2.10 GHz   Base Clock              1.00 GHz
# 3  Boost Clock           3.70 GHz  Boost Clock              3.60 GHz
# 4        Cache               4 MB        Cache                  6 MB
#
#           P_4Q                 P_4A  ...              P_3882Q  \
# 0    CPU Brand                Intel  ...                Model
# 1    CPU Model  Intel Core i5-9300H  ...    CPU Core / Thread
# 2   Base Clock             2.40 GHz  ...  Integrated Graphics
# 3  Boost Clock             4.10 GHz  ...                Model
# 4        Cache                 8 MB  ...              Chipset
#
#                              P_3882A              P_3883Q  \
# 0  INTEL 1151 CORE I5-9400F 2.90 GHz                Model
# 1                                6/6    CPU Core / Thread
# 2                                  -  Integrated Graphics
# 3        GIGABYTE B365 M AORUS ELITE                Model
# 4                               B365                Model
#
#                               P_3883A              P_3884Q  \
# 0  INTEL 1151 CORE I5-9600KF 3.70 GHz                Model
# 1                                 6/6    CPU Core / Thread
# 2                                   -  Integrated Graphics
# 3       ID COOLING AURAFLOW X 240 RGB                Model
# 4                      MSI Z390-A PRO              Chipset
#
#                        P_3884A              P_3885Q  \
# 0  AMD AM4 RYZEN 5 3600 3.6GHz                Model
# 1                         6/12    CPU Core / Thread
# 2                            -  Integrated Graphics
# 3     ASROCK B450 STEEL LEGEND                Model
# 4                         B450                Model
#
#                          P_3885A              P_3886Q  \
# 0  CPU INTEL 1151 CORE I7-9700KF                Model
# 1                            8/8    CPU Core / Thread
# 2                              -  Integrated Graphics
# 3       DEEPCOOL CASTLE 280 ARGB                Model
# 4      GIGABYTE Z390 AORUS ELITE              Chipset
#
#                         P_3886A
# 0  AMD AM4 RYZEN 7 3700X 3.6GHz
# 1                          8/16
# 2                             -
# 3     GIGABYTE B450 AORUS ELITE
# 4                          B450
#
# [5 rows x 1306 columns]

# %%
df_2.head()
# Out:
#    P_101Q                      P_101A  P_102Q  \
# 0  Detail  Spin Speed : 2200+/-10 RPM  Detail
# 1     NaN                         NaN     NaN
# 2     NaN                         NaN     NaN
# 3     NaN                         NaN     NaN
# 4     NaN                         NaN     NaN
#
#                                               P_102A  P_103Q  \
# 0  Dimension : 128.5 x 140 x 168.3 mm<end line>Fa...  Detail
# 1                                                NaN     NaN
# 2                                                NaN     NaN
# 3                                                NaN     NaN
# 4                                                NaN     NaN
#
#                                               P_103A  P_104Q  \
# 0  Spin Speed : 2200 RPM<end line>Dimensions : 11...  Detail
# 1                                                NaN     NaN
# 2                                                NaN     NaN
# 3                                                NaN     NaN
# 4                                                NaN     NaN
#
#                                               P_104A  P_105Q  \
# 0  Product Name : Wraith Ripper<end line>Product ...  Detail
# 1                                                NaN     NaN
# 2                                                NaN     NaN
# 3                                                NaN     NaN
# 4                                                NaN     NaN
#
#                                               P_105A  ... P_4060Q  \
# 0  Max. Rotational Speed (+/- 10%) 1500 RPM<end l...  ...  Detail
# 1                                                NaN  ...     NaN
# 2                                                NaN  ...     NaN
# 3                                                NaN  ...     NaN
# 4                                                NaN  ...     NaN
#
#                                              P_4060A P_4061Q  \
# 0  รูปแบบ : WD DRPP-UPGRADE TO 3 Year<end line>อุ...  Detail
# 1                                                NaN     NaN
# 2                                                NaN     NaN
# 3                                                NaN     NaN
# 4                                                NaN     NaN
#
#                                              P_4061A P_4062Q  \
# 0  รูปแบบ : DRPP-FULL 3 Year<end line>อุปกรณ์ : L...  Detail
# 1                                                NaN     NaN
# 2                                                NaN     NaN
# 3                                                NaN     NaN
# 4                                                NaN     NaN
#
#                                              P_4062A P_4063Q  \
# 0  รูปแบบ : DRPP-LITE 1 Year<end line>อุปกรณ์ : L...  Detail
# 1                                                NaN     NaN
# 2                                                NaN     NaN
# 3                                                NaN     NaN
# 4                                                NaN     NaN
#
#                                              P_4063A P_4064Q  \
# 0  รูปแบบ : DRPP-FULL 1 Year<end line>อุปกรณ์ : L...  Detail
# 1                                                NaN     NaN
# 2                                                NaN     NaN
# 3                                                NaN     NaN
# 4                                                NaN     NaN
#
#                                              P_4064A
# 0  รูปแบบ : DRPP-LITE 3 Year<end line>อุปกรณ์ : L...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 6816 columns]

# %%
df_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23 entries, 0 to 22
# Columns: 6816 entries, P_101Q to P_4064A
# dtypes: float64(36), object(6780)
# memory usage: 1.2+ MB

# %% [markdown]
# ## Product names

# %%
prod_name_df.head()
# Out:
#        Unnamed: 0                                       Product_Name
# index
# 0               0  NOTEBOOK (โน้ตบุ๊ค) ASUS VIVOBOOK 15 X512DA-EJ...
# 1               0  NOTEBOOK (โน้ตบุ๊ค) ACER ASPIRE 3 A315-55G-53C...
# 2               0  NOTEBOOK (โน้ตบุ๊ค) ASUS VIVOBOOK 15 X512DA-EJ...
# 3               0       NOTEBOOK (โน้ตบุ๊ค) HP 15S-FQ1012TU (SILVER)
# 4               0  NOTEBOOK (โน้ตบุ๊ค) DELL INSPIRON 7591-W567015...

# %%
prod_name_df['Product_Name'][0]
# Out:
# 'NOTEBOOK (โน้ตบุ๊ค) ASUS VIVOBOOK 15 X512DA-EJ139T (TRANSPARENT SILVER)'

# %%
prod_name_df_2.head()
# Out:
#      Unnamed: 0  Unnamed: 0.1  \
# No.
# 101           0             0
# 102           1             0
# 103           2             0
# 104           3             0
# 105           4             0
#
#                                                   Name  \
# No.
# 101  CPU AIR COOLER (พัดลมซีพียู) DEEPCOOL ICEEDGE ...
# 102  CPU AIR COOLER (พัดลมซีพียู) CRYORIG R1 UNIVERSAL
# 103     CPU AIR COOLER (พัดลมซีพียู) ID COOLING SE-802
# 104  CPU AIR COOLER (พัดลมซีพียู) COOLER MASTER WRA...
# 105        CPU AIR COOLER (พัดลมซีพียู) NOCTUA NH-D15S
#
#                                                   link
# No.
# 101  https://www.jib.co.th/web/product/readProduct/...
# 102  https://www.jib.co.th/web/product/readProduct/...
# 103  https://www.jib.co.th/web/product/readProduct/...
# 104  https://www.jib.co.th/web/product/readProduct/...
# 105  https://www.jib.co.th/web/product/readProduct/...

# %% [markdown]
# # Extract attributes from dataframe

# %%
def extract_attr_df_1(df):
    attr_val_dict = {}
    relations = []

    regex_attr = re.compile("P\_\d+Q")
    regex_val = re.compile("P\_\d+A")
    regex_idx = re.compile("\d+")
    regex_detail = re.compile("Detail")
    
    for idx in df:
        idx_prod = re.findall(regex_idx, idx)[0]
        
        if re.match(regex_attr, idx):
            tmp_list = []
            if not re.match("Detail", df[idx][0]):
                for attr in df[idx]:
                    if not pd.isna(attr):
                        tmp_list.append(attr)
                        relations.append(attr)
                
        elif re.match(regex_val, idx):
            attr_val_dict[idx_prod] = []
            tmp_list_2 = []
            # If attributes and values are in 1 row or 2 rows
            if not pd.isna(df[idx][3]):
                for val in df[idx]:
                    if not pd.isna(val):
                        tmp_list_2.append(val)
                for i in range(len(tmp_list_2)-1):
                    attr_val_dict[idx_prod].append([tmp_list[i],tmp_list_2[i]])
            # If attributes and values are in several rows
            else:
                for v in df[idx]:
                    tmp = [str(v).split('<end line>')]
                    # Split attribute and value by ':'
                    attr_val = []
                    for l in tmp:
                        attr_val.extend([clean_text(s).split(':') for s in l])
                    attr_val_dict[idx_prod].extend(attr_val)
                
    return attr_val_dict, relations

# %%
attr_val_1, relations_1 = extract_attr_df_1(df_1)
attr_val_2, relations_2 = extract_attr_df_1(df_2)

# %%
attr_val_2
# Out:
# {'101': [['spin speed ', ' 2200 10 rpm'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan']],
#  '102': [['dimension ', ' 128.5 x 140 x 168.3 mm'],
#   ['fan speed ', ' 700 1300 rpm 10 %'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan']],
#  '103': [['spin speed ', ' 2200 rpm'],
#   ['dimensions ', ' 117 x 64 x 116 mm'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan']],
#  '104': [['product name ', ' wraith ripper'],
#   ['product number ', ' mam d7pn dwrps t1'],
#   ['cpu socket ', ' amd tr4'],
#   ['dimensions ', ' 150 l x 132.3 w x 160.5 h mm'],
#   ['5.9 l x 5.2 w x 6.3 h inch'],
#   ['heatsink material ', ' 7 heat pipes aluminum fins'],
#   ['lighting led type ', ' addressable rgb'],
#   ['lighting control method ', ' wraith ripper rgb software'],
#   ['lighting power connector ', ' sata power'],
#   ['lighting interface ', ' usb connector 9 pin'],
#   ['fan dimensions ', ' 120 x 120 x 25 mm 4.7 x 4.7 x 1 inch'],
#   ['fan quantity ', ' 1 pcs'],
#   ['fan speed ', ' 0 2750 pwm 10%'],
#   ['fan air flow ', ' 76.4 cfm max'],
#   ['fan mttf ', ' 490000 hours'],
#   ['fan noise level ', ' 0 38 dba'],
#   ['fan power connector ', ' 4 pin pwm'],
#   ['fan rated voltage ', ' 12 vdc'],
#   ['fan rated current ', ' 0.45 a'],
#   ['fan safety current ', ' 0.6 a'],
#   ['ean code ', ' 4719512075074'],
#   ['upc code ', ' 884102047565'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan']],
#  '105': [['max. rotational speed 10% 1500 rpm'],
#   ['max. rotational speed with l.n.a. 10% 1200 rpm'],
#   ['min. rotational speed pwm 20% 300 rpm'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan']],
#  '106': [['max. rotational speed 10% 2000 rpm'],
#   ['max. rotational speed with l.n.a. 10% 1550 rpm'],
#   ['min. rotational speed pwm 20% 400 rpm'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan']],
#  '107': [['application for'],
#   ['amd 250w'],
#   ['tr4 am4 am3 am3 am2 am2 fm2 fm2 fm1'],
#   ['ryzen'],
#   ['apu a12 a10 a8 a6 a4'],
#   ['fx 8 6 4 core'],
#   ['phenom ii x6 x4 x3 x2'],
#   ['athlon ii x4 x3 x2'],
#   ['athlon x4'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan']],
#  '109': [['product number ', ' mam d6pn 120pa r1'],
#   ['cpu socket ',
#    ' lga2066 lga2011 v3 lga2011 lga1151 lga1150 lga1155 lga1156 am4 am3 am3 am2 am2 fm2 fm2 fm1'],
#   ['dimensions l x w x h ', ' 135 x 125 x 165 mm 5.3 x 4.9 x 6.5 inch'],
#   ['heat sink material ', ' 6 heat pipes aluminum fins'],
#   ['fan dimensions l x w x h ', ' 120 x 120 x 25 mm 4.7 x 4.7 x 1 inch'],
#   ['fan quantity ', ' 1 pcs'],
#   ['fan speed ', ' 650 2000 rpm pwm 10%'],
#   ['fan airflow ', ' 57.3 cfm max'],
#   ['fan air pressure ', ' 2.0 mmh2o max'],
#   ['fan mttf ', ' 160000 hours'],
#   ['fan noise level ', ' 8 30 dba'],
#   ['fan power connector ', ' 4 pin pwm'],
#   ['fan rated voltage ', ' 12v dc'],
#   ['fan rated current ', ' 0.16 a'],
#   ['fan safety current ', ' 0.37a'],
#   ['fan power consumption ', ' 1.92 w'],
#   ['serie ', ' masterair'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan']],
#  '110': [['product name ', ''],
#   ['masterair ma410m tuf gaming edition'],
#   ['model ', ''],
#   ['mam t4pn afnpc r1'],
#   ['cpu socket ', ''],
#   ['intel lga 2066 2011 v3 2011 1366 1156 1155 1151 1150 socket'],
#   [''],
#   ['amd am4 am3 am3 am2 am2 fm2 fm2 fm1 socket'],
#   ['dimensions lxwxh ', ''],
#   ['111.8 x 130.9 x 165.1 mm 4.4 x 5.1 x 6.5 inch'],
#   ['heat sink material ', ''],
#   ['4 heat pipes cdc 2.0 aluminum fins'],
#   ['heat sink weight ', ''],
#   ['820g 1.8 lb.'],
#   ['heat pipe dimensions ', ''],
#   ['6 mm'],
#   ['fan dimensions ', ''],
#   ['120 x 120 x 25 mm 4.7 x 4.7 x 1 inch'],
#   ['fan speed ', ''],
#   ['600 1800 rpm pwm 10%'],
#   ['fan air flow ', ''],
#   ['53.38 cfm max'],
#   ['fan air pressure ', ''],
#   ['1.65mm h2o max'],
#   ['fan mttf ', ''],
#   ['40000 hours'],
#   ['fan noise level ', ''],
#   ['6 31 dba'],
#   ['fan connector ', ''],
#   ['4 pin pwm'],
#   ['fan rated voltage ', ''],
#   ['12 vdc'],
#   ['fan rated current ', ''],
#   ['0.3 a'],
#   ['fan safety current ', ''],
#   ['0.37 a'],
#   ['fan power consumption ', ''],
#   ['3.6 w'],
#   ['warranty ', ''],
#   ['5 years'],
#   ['ean code ', ''],
#   ['4719512071076'],
#   ['upc code ', ''],
#   ['884102043574'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan']],
#  '111': [['compatibility', ''],
#   ['intel',
#    ' socket lga775 lga1150 lga1151 lga1155 lga1156 lga1366 lga2066 2011 v3 square ilm'],
#   ['amd', ' socket am2 am3 am4 fm1 fm2'],
#   ['dimensions', ' 136 x 154 x 85 mm'],
#   ['weight', ' 645 g 22.8 oz including fan'],
#   ['accessory',
#    ' mounting parts for intel and amd sockets fan fan clips thermal grease installation manual.'],
#   ['fan specifications'],
#   ['model name', ' kaze flex 120 pwm'],
#   ['fan size', ' 120 x 120 x 27 mm 4.72 x 4.72 x 1.06 mm'],
#   ['noise level', ' 4.0 24.9 dba'],
#   ['air flow', ' 16.6 51.17 cfm'],
#   ['fan speed', ' 300 rpm 200 1200 rpm 10%'],
#   ['voltage current', ' dc 12v 013a'],
#   ['static pressure', ' 0.75 10.3 pa 0.076 1.5 mmh o'],
#   ['bearing type', ' sealed precision fdb'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan']],
#  '112': [['model cr 1000 tower radiator'],
#   ['dimensions 128mm l 76mm w 158mm h'],
#   ['size of fan 120mm 120mm 25mm'],
#   ['number of heat pipe 4 pcs'],
#   ['voltage 12v'],
#   ['connector pwm 4pin'],
#   ['fan speed 700 1800rpm 10%'],
#   ['noise level 20.55 37.2dba max'],
#   ['fan airflow 26.1 66.81cfm'],
#   ['platform support intel lga775 1150 1151 1155 1156amd am2 am2 am3 am3 am4 fm1 fm2 fm2'],
#   ['total net weight 610g'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan']],
#  '113': [['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan']],
#  '114': [['intel ', ' lga20xx 1151 1150 1155 lga775 lga1366'],
#   ['amd ', ' am4 am3 am3 am2 am2 fm2 fm2 fm1'],
#   ['product dimensions ', ' 126 134 158 mm'],
#   ['heatsink dimensions ', ' 120 108 158 mm'],
#   ['net weight ', ' 1123 g'],
#   ['heatpipe ', ' 6 mm 6 pcs'],
#   ['fan dimensions ', ' 120 120 25 mm'],
#   ['fan speed ', ' 500 1500 rpm 10%'],
#   ['fan airflow ', ' 56.5 cfm'],
#   ['fan air pressure ', ' 1.66 mmaq'],
#   ['fan noise ', ' 27 db a'],
#   ['fan connector ', ' 4 pin pwm'],
#   ['bearing type ', ' hydro bearing'],
#   ['fan rated voltage ', ' 12 vdc'],
#   ['fan rated current ', ' 0.11 a'],
#   ['fan power consumption ', ' 1.32 w'],
#   ['led type ', ' rgb led'],
#   ['led connector ', ' 4 pin 12v g r b'],
#   ['led rated voltage ', ' 12 vdc'],
#   ['led power consumption ', ' 1.44 w'],
#   [''],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan']],
#  '115': [['application for'],
#   ['intel lga2066 2011 v3 2011 1151 1150 1155 1366'],
#   ['amd am4 am3 am3 am2 am2 fm2 fm2 fm1'],
#   ['technical spec'],
#   ['product dimensions ', ' 129 77 157.5 mm'],
#   ['heatsink dimensions ', ' 127 50 155 mm'],
#   ['net weight ', ' 676 g'],
#   ['heatpipe ', ' 6 mm 4 pcs'],
#   ['fan dimensions ', ' 120 120 25mm'],
#   ['fan speed ', ' 500 1650 rpm 10%'],
#   ['fan airflow ', ' 64.5 cfm'],
#   ['fan air pressure ', ' 2.1 mmaq'],
#   ['fan noise ', ' 27.8 db a'],
#   ['fan connector ', ' 4 pin pwm'],
#   ['bearing type ', ' hydro bearing'],
#   ['fan rated voltage ', ' 12 vdc'],
#   ['fan rated current ', ' 0.14 a'],
#   ['fan power consumption ', ' 1.68 w'],
#   ['led type ', ' addressable rgb led'],
#   ['led connector ', ' 3 pin 5v d g'],
#   ['led rated voltage ', ' 5 vdc'],
#   ['led power consumption ', ' 2.4 w'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan']],
#  '116': [['compatibility', ''],
#   ['intel lga1151 1150 1155 1156 775'],
#   ['amd am4 fm2 fm2 fm1 am3 am3'],
#   ['tdp', ''],
#   ['130w'],
#   ['overall dimension', ''],
#   ['99 85 122mm l w h'],
#   ['heatsink material', ''],
#   ['3 6mm heatpipe direct touch aluminum fin'],
#   ['weight', ''],
#   ['575g'],
#   ['fan dimension', ''],
#   ['92 92 25mm'],
#   ['fan speed', ''],
#   ['600 2200rpm'],
#   ['max. air flow', ''],
#   ['38.5cfm'],
#   ['max. static pressure', ''],
#   ['1.92mmh2o'],
#   ['noise max. ', ''],
#   ['23.8db a'],
#   ['rated voltage', ''],
#   ['12vdc'],
#   ['operating voltage', ''],
#   ['10.8 13.2vdc'],
#   ['started voltage', ''],
#   ['7vdc'],
#   ['rated current', ''],
#   ['0.2a'],
#   ['power input', ''],
#   ['2.4w'],
#   ['bearing type', ''],
#   ['hydraulic bearing'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan']],
#  '117': [['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan']],
#  '118': [['pwm', ' yes'],
#   ['heatsink dimensions', ' 137mm x 169mm x 103mm'],
#   ['corsair icue compatibility', ' no'],
#   ['heatsink dimensions w fan', ' 144mm x 169mm x 171mm'],
#   ['cold plate type', ' direct contact heatpipe'],
#   ['fan dimensions', ' 120mm x 120mm x 25mm'],
#   ['fan speed', ' 2400 rpm'],
#   ['weight', ' 1460g'],
#   ['number of fans', ' 2'],
#   ['cooling socket support', ''],
#   ['intel 1150 1151 1155 1156'],
#   ['intel 2011 2011 3 2066'],
#   ['amd am4'],
#   ['amd am3 am2'],
#   ['lighting', ' none'],
#   ['fan model', ' ml series'],
#   ['heatpipe material', ' copper'],
#   ['heatsink material', ' aluminum'],
#   ['maximum ram height stock fan position ', ' 45mm'],
#   ['maximum ram height mitx motherboard ', ' 45mm'],
#   ['fan airflow', ' 75 cfm'],
#   ['noise level', ' 36 dba'],
#   ['fan static pressure', ' 4.2 mm h2o'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan']],
#  '119': [['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan']],
#  '120': [['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan']],
#  '121': [['compatibility'],
#   ['intel lga2066 2011 1151 1150 1155 1156'],
#   ['amd am4'],
#   ['tdp ', ' 180w'],
#   ['overall dimension ', ' 120 73 154mm l w h'],
#   ['heatsink material ', ' 4 6mm heatpipe direct touch aluminum fin'],
#   ['weight ', ' 810g'],
#   ['fan dimension ', ' 120 120 25mm'],
#   ['fan speed ', ' 700 200 1800 10%rpm pwm rgb'],
#   ['max. air flow ', ' 76.16cfm'],
#   ['max. static pressure ', ' 2.16mmh2o'],
#   ['noise ', ' 15.2 32.5db a'],
#   ['rated voltage ', ' 12vdc'],
#   ['operating voltage ', ' 10.8 13.2vdc'],
#   ['started voltage ', ' 7vdc'],
#   ['rated current ', ' 0.2a'],
#   ['power input ', ' 2.4w'],
#   ['bearing type ', ' hydraulic bearing'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan']],
#  '122': [['keyboard logitech k120 black'],
#   ['usb'],
#   ['104 key'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan']],
#  '123': [['interface ', ' usb 2.0'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan']],
#  '124': [['model ', ' usb keyboard md tech kb 338'],
#   ['interface ', ' usb'],
#   ['keys windows layout ', ' 104 keys'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan']],
#  '125': [['คีย์บอร์ดรับเบอร์โอม สวิชต์'],
#   ['กดได้มากถึง 10 ล้านครั้ง'],
#   ['12 ปุ่มมัลติมีเดีย'],
#   ['window lock'],
#   ['led light 3 mode'],
#   ['เพิ่้มและลดแสงไฟได้'],
#   ['เชื่อมต่อด้วย usb'],
#   ['สายยาง ยาว 1.5 ม.'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan']],
#  '126': [['อินเตอร์เฟซ', ' รองรับ usb'],
#   ['อายุการใช้งานของปุ่ม', ' รับการกดได้ 5000000 ครั้ง ไม่นับปุ่มล็อคตัวเลข'],
#   ['ชนิดของปุ่ม', ' ทรงเตี้ย กันน้ำหก1'],
#   ['ฮอตคีย์ 8 ปุ่ม',
#    ' เล่น หยุดเพลง ปิดเสียง ลดเสียง เพิ่มเสียง หน้าเริ่มต้นในอินเทอร์เน็ต เปิดโปรแกรมอีเมล์ตั้งต้น เข้าโหมด sleepเปิดโปรแกรมเครื่องคิดเลข'],
#   ['อายุปุ่มฮอตคีย์', ' รับการกด 500000 ครั้ง'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan']],
#  '127': [['ปุ่ม mechanical switch blue brown red'],
#   ['knob function design ปุ่มหมุนที่สามารถปรับตั้งค่าโหมดไฟ และ ปรับ volume เพิ่ม ลดเสียงได้'],
#   ['ตั้งค่ามาโครได้ถึง 104 ปุ่ม ช่วยให้คุณสนุก และเพิ่มประสิทธิภาพยิ่งขึ้น'],
#   ['anti ghosting'],
#   ['ออกแบบมาเพื่อใช้รูปแบบการสลับระหว่างโหมดไฟและโหมดมัลติมีเดีย'],
#   ['แผ่นรองข้อมือแบบแม่เหล็กที่ถอดเข้า ออกได้'],
#   ['มีปุ่มคีย์ลัดมัลติมีเดีย'],
#   ['ปุ่มมีอายุการใช้งานถึง 50 ล้านคลิก'],
#   ['ปุ่ม สีไม่ลอกง่าย บอดี้ ผลิตจากวัสดุที่แข็งแรง ทนทานสูง'],
#   ['รองรับ windows 10 8 7 และอื่นๆ'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan']],
#  '128': [['device type', ' keyboard'],
#   ['interface', ' usb'],
#   ['keys style', ' chiclet'],
#   ['color', ' black'],
#   ['dimensions wxdxh ', ' 17.4 in x 5 in x 1 in'],
#   ['weight', ' 17.74 oz'],
#   ['warranty', ' 1 year'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan']],
#  '129': [['3 buttons'],
#   ['resolution 800 dpi'],
#   ['port usb wheel scroll'],
#   ['support windows 8 7 vista xp mac os x v10.1 10.4 x'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan']],
#  '130': [['corded mouse'],
#   ['3 buttons'],
#   ['usb connectivity'],
#   ['optical tracking'],
#   ['800 dpi resolution'],
#   ['cable', ' 5 ft 9 in 180 cm approx'],
#   ['works with windows vista windows 7 windows 8 windows 10'],
#   ['chrome os'],
#   ['linux kernel 2.4'],
#   ['mac os x 10.3.9 or later'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan']],
#  '131': [['6 buttons'],
#   ['resolution 400 800 1600 2400 dpi'],
#   ['usb port'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan']],
#  '132': [['3 buttons'],
#   ['resolution 800 dpi'],
#   ['port usb wheel scroll'],
#   ['support windows 8 7 vista xp mac os x v10.1 10.4x'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan']],
#  '133': [['interface usb 2.0 full speed compatible'],
#   ['buttons 5 buttons 3 customisable including left and right click and scroll wheel button'],
#   ['scrolling vertical scrolling'],
#   ['mouse report rate 1000 reports per second'],
#   ['tracking technology microsoft bluetrack enables tracking on glass'],
#   ['compatibility windows 10 8.1 8 7 customisation of buttons only available on windows 10 8.1 8 7 but is not supported on windows 10 s'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan']],
#  '134': [['sensor ', ' paw3327db'],
#   ['dpi ', ' 6 adjust dpi 800 10000'],
#   ['led ', ' rgb lighting'],
#   ['button ', ' 11 buttons'],
#   ['key life ', ' 50 million times'],
#   ['cable length ', ' 190 cm'],
#   ['dimension ', ' 124 l x 78 w x 42 h mm.'],
#   ['weight ', ' 150 g'],
#   ['system support ', ' windows 10 8 7 mac os'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan']],
#  '135': [['เซ็นเซอร์ ', ' ออพติคัล'],
#   ['ชื่อรุ่น ', ' lucien ลูเชียน'],
#   ['รูปแบบ ', ' มีสาย'],
#   ['สี ', ' ดำ แดงดำ เทาดำ'],
#   ['จำนวนปุ่ม ', ' 3'],
#   ['ปุ่มปรับระดับ dpi ', ' ไม่มี'],
#   ['ระดับ dpi ', ' 2400'],
#   ['ชนิดของสาย ', ' สายไฟเบอร์'],
#   ['พอร์ตการเชื่อมต่อ ', ' usb'],
#   ['คุณสมบัติพิเศษ ', ' ไฟ 7 สี'],
#   ['รหัสสินค้า ', ' nm 10'],
#   ['รับประกัน ', ' 1 ปี'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan']],
#  '136': [['connection interface'],
#   ['wired usb 2.0 full speed type a'],
#   ['compatibility1'],
#   ['microsoft windows 10 8.1 7'],
#   ['dimensions'],
#   ['117.5 76.3 42.3 mm'],
#   ['weight'],
#   ['104 g including cable 75 g mouse only'],
#   ['colour'],
#   ['black'],
#   ['technology details'],
#   ['mouse tracking system', ' microsoft bluetrack technology'],
#   ['imaging rate', ' dynamically adaptable to 3000 frames per second'],
#   ['x y resolution', ' 1000 points per inch 39.4 points per millimetre'],
#   ['tracking speed', ' up to 30 inches 762 millimetres per second'],
#   ['product feature performance'],
#   ['mouse button features',
#    ' 5 buttons',
#    ' left right wheel side button 2 press and hold to pair'],
#   ['scrolling features',
#    ' metal wheel for vertical scrolling and wheel button clicking'],
#   ['customisable features',
#    '1 x y resolution adjusting wheel button function reassignment left and right click swap wheel customisation'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan']],
#  '137': [['แผ่นรองเม้าส์ nubwo มีฐานยางที่ป้องกันการลื่นไม่ให้แผ่นเคลื่อนย้ายในระหว่างการใช้'],
#   ['ด้านล่างยางยังให้ความสะดวกสบายเพิ่มสำหรับมือและข้อมือป้องกันการเคลื่อนไหวของคุณตลอดเวลา'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan']],
#  '138': [['แผ่นรองเมาส์ nubwo มีฐานยางที่ป้องกันการลื่นไม่ให้แผ่นเคลื่อนย้ายในระหว่างการใช้'],
#   ['ด้านล่างยางยังให้ความสะดวกสบายเพิ่มสำหรับมือและข้อมือป้องกันการเคลื่อนไหวของคุณตลอดเวลา'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan']],
#  '139': [['dimension 300 x 250 x 2 mm'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan']],
#  '140': [['mouse pad gv zodiac pisces v.2'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan']],
#  '141': [['mouse pad gv zodiac capricorn v.2'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan']],
#  '142': [['hac hfw1200t'],
#   ['2mp hdcvi ir bullet camera'],
#   ['max 30fps 1080p'],
#   ['hd and sd output switchable'],
#   ['3.6mm fixed lens 2.8mm 6mm optional'],
#   ['max. ir length 30m smart ir'],
#   ['ip67 dc12v'],
#   [''],
#   ['xvr1a04'],
#   ['4 channel penta brid 1080n 720p cooper 1u digital video recorder'],
#   ['h.264 video compression'],
#   ['supports hdcvi ahd tvi cvbs ip video inputs'],
#   ['max 5 10 channels ip camera inputs each channel up to 2mp 5mp max 20 40mbps incoming bandwidth'],
#   ['long transmission distance over coax cable'],
#   ['supports 1 sata hdd up to 6tb'],
#   [''],
#   ['1 tb hdd wd purple 5400rpm sata3 wd10purz'],
#   ['support for up to 64 cameras per drive'],
#   ['allframetm technology'],
#   [''],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan']],
#  '143': [['hac hfw1200t'],
#   ['2mp hdcvi ir bullet camera'],
#   ['max 30fps 1080p'],
#   ['hd and sd output switchable'],
#   ['3.6mm fixed lens 2.8mm 6mm optional'],
#   ['max. ir length 30m smart ir'],
#   ['ip67 dc12v'],
#   ['xvr4116hs x'],
#   ['16 channel penta brid 720p compact 1u digital video recorder'],
#   ['h.265 video compression'],
#   ['supports hdcvi ahd tvi cvbs ip video inputs'],
#   ['max 18 channels ip camera inputs each channel up to 6mp max 72mbps incoming bandwidth'],
#   ['long transmission distance over coax cable'],
#   ['4 tb hdd wd purple 5400rpm sata3 wd40purz'],
#   ['support for up to 64 cameras per drive'],
#   ['allframetm technology'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan']],
#  '181': [['cpu socket compatibility intel lga 2066 2011 v3 2011 1151 1150 1155 1156 1366 775 socket'],
#   [''],
#   ['amd am4 am3 am3 am2 am2 fm2 fm2 fm1 socket'],
#   ['radiator material ', ' aluminum'],
#   ['dimensions ', ' 277 x 119.6 x 27mm 10.9 x 4.7 x 1.1'],
#   ['fan dimensions ', ' 120 x 120 x 25 mm 4.7 x 4.7 x 1'],
#   ['speed ', ' 650 2000 rpm pwm 10%'],
#   ['air flow ', ' 66.7 cfm max'],
#   ['air pressure ', ' 2.34 mmh2o max'],
#   ['mttf ', ' 160000 hours'],
#   ['noise level ', ' 6 30 dba'],
#   ['connector ', ' 4 pin pwm'],
#   ['rated voltage ', ' 12 vdc'],
#   ['pump dimensions ', ' 80.3 x 76 x 42.2 mm 3.2 x 3.0 x 1.7'],
#   ['mttf ', ' 70000 hours'],
#   ['noise level ', ' 15 dba'],
#   ['connector ', ' 3 pin'],
#   ['rated voltage ', ' 12 vdc'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan']],
#  '182': [['compatibility ',
#    ' intel lga 2066 2011 3 2011 1366 1156 1155 1151 1150 amd am4 fm2 fm1 am3 am3 am2 am2'],
#   ['water block ', ' material copper'],
#   ['pump ',
#    ' rated voltage ',
#    '12 v 5v rated current',
#    '325 ma 0.4a motor speed',
#    '3600 r.p.m'],
#   ['fan ',
#    ' dimension ',
#    ' 120 x 120 x 25 mm speed',
#    '500 1400 rpm noise level',
#    '19.8 24.7 db a rated voltage',
#    '12 v max. air flow',
#    '14.2 42.34 cfm'],
#   ['max. pressure', '0.17 1.54 mm h2o connector', '5 pin'],
#   ['tube ', ' length', '326 mm material', 'rubber'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan']],
#  '183': [['model ', ' angel eye tw2 240 standard version'],
#   ['product type ', ' aio liquid cooler'],
#   ['dimensions ',
#    ' water pump 70mm 70mm 48mm radiator 274mm 120mm 27mm fans 120mm 120mm 25mm'],
#   ['fan air flow ', ' 21.6cfm 50.4cfm each'],
#   ['fan bearing type ', ' hydraulic bearing'],
#   ['fan rotational speed 800rpm 1500rpm 10%'],
#   ['fan interface small 4pin pwm'],
#   ['pump interface small 3pin'],
#   ['fan noise level 25dba'],
#   ['pump power 3.1w'],
#   ['pump noise level 25dba'],
#   ['pump voltage 12v'],
#   ['platform support intel lga115x 1366 lga2011 lga2011 v3 amd am4 am3 am3 am2 am2 fm2 fm2 fm1'],
#   ['pump service life 70000 hrs'],
#   ['radiator metarial aluminum'],
#   ['pipe size 310mm'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan']],
#  '184': [['dimensions', ' radiator', ' 152 x 120 x 32mm'],
#   ['cpu water block', ' 65 x 65 x 48mm'],
#   ['material s ',
#    ' aluminum copper plastic ultra low evaporation rubber nylon sleeving'],
#   ['weight', ' 0.88kg'],
#   ['cpu socket', ' intel socket 1151 1150 1155 1156 1366 2011 2011 3 2066'],
#   ['core i9 core i7 core i5 core i3 pentium celeron'],
#   [''],
#   ['amd am4 fm2 fm2 fm1 am3 am3 am2 am2'],
#   ['ryzen fx athlon x4 athlon x2 a series apu phenom phenom ii athlon athlon ii sempron'],
#   ['tube length', ' 400mm'],
#   ['pump speed', ' 3000 300rpm'],
#   ['fan model', ' aer p120'],
#   ['fan noise level', ' 21 36dba'],
#   ['fan speed', ' 500 2000 300rpm'],
#   ['control method', ' software with cam'],
#   ['number of fans', ' 1'],
#   ['led modes',
#    ' preset modes',
#    ' fixed breathing fading marquee covering marquee pulse spectrum wave alternating tai chi water cooler loading'],
#   ['reactive modes', ' smart and audio'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan']],
#  '185': [['water block'],
#   ['water block dimension', ' 80 x 80 x 45 mm'],
#   ['block material cpu plate ', ' copper'],
#   ['cpu socket support',
#    ' intel',
#    ' lga 115x1366 2011 2011 3 2066 amd',
#    ' am4 tr4'],
#   ['radiator'],
#   ['radiator dimension', ' 272 x 121 x 27 mm'],
#   ['radiator material', ' aluminum'],
#   ['tube', ' sleeved rubber tube'],
#   ['fan'],
#   ['fan', ' 2 x rog ryuo fan model 12'],
#   ['fan size', ' 2 fan slots 120mm'],
#   ['fan dimension', ' 120 x 120 x 25 mm'],
#   ['fan speed', ' 800 2500 rpm 10 %'],
#   ['fan static pressure', ' 5.0 mmh2o'],
#   ['fan air flow', ' 80.95 cfm'],
#   ['fan noise', ' 37 db a'],
#   ['control mode', ' pwm'],
#   ['special features'],
#   ['oled display', ' 1.77 full color oled'],
#   ['aura sync support', ' yes'],
#   ['compatibility'],
#   ['intel', ' lga 1150 1151 1152 1155 1156 1366 2011 2011 3 2066'],
#   ['amd', ' am4 tr4'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan']],
#  '186': [['cpu socket compatibility intel lga 2066 2011 v3 2011 1151 1150 1155 1156 1366 775 socket'],
#   [''],
#   ['amd am4 am3 am3 am2 am2 fm2 fm2 fm1 socket'],
#   ['radiator material aluminum'],
#   ['dimensions 157 x 119.6 x 27mm 6.2 x 4.7 x 1.1'],
#   ['fan dimensions 120 x 120 x 25 mm 4.7 x 4.7 x 1'],
#   ['quantity 2 pcs'],
#   ['speed 650 2000 rpm pwm 10%'],
#   ['air flow 66.7 cfm max'],
#   ['air pressure 2.34 mmh2o max'],
#   ['mttf 160000 hours'],
#   ['noise level 6 30 dba'],
#   ['connector 4 pin pwm'],
#   ['rated voltage 12 vdc'],
#   ['pump dimensions 83.6 x 71.8 x 52.7 mm 3.3 x 2.8 x 2.1'],
#   ['mttf 70000 hours'],
#   ['noise level 15 dba'],
#   ['connector 3 pin'],
#   ['rated voltage 12 vdc'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan']],
#  '187': [['cold plate material copper'],
#   ['radiator material aluminum'],
#   ['pwm yes'],
#   ['corsair icue compatibility yes'],
#   ['radiator dimensions 322mm x 137mm x 27mm'],
#   ['fan dimensions'],
#   ['140mm x 25mm'],
#   ['fan speed 2000 rpm'],
#   ['number of fans 2'],
#   ['cooling socket support intel 115x intel 2011 2066 amd am3 am2 amd am4 amd tr4'],
#   ['lighting'],
#   ['rgb'],
#   ['radiator size 280mm'],
#   ['fan model'],
#   ['ml series'],
#   ['fan airflow'],
#   ['97 cfm'],
#   ['noise level 37 dba'],
#   ['fan static pressure 3.0 mm h2o'],
#   [''],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan']],
#  '188': [['pump dimensions 91 79 71mm l w h'],
#   ['radiator dimensions 323 146 27mm l w h'],
#   ['radiator material aluminum'],
#   ['fan dimensions 140 140 26mm 2pcs'],
#   ['fan speed 500 200 1800 10%rpm'],
#   ['fan air flow 96.7cfm'],
#   ['fan air pressure 2.83mmh2o'],
#   ['fan life expectancy 40000 hours'],
#   ['fan noise level 19.8 35.4db a'],
#   ['fan bearing type hydro bearing'],
#   ['fan connector 4pin'],
#   ['fan rated voltage 12vdc'],
#   ['fan rated current 0.02 15%a 20% 0.32 10%a'],
#   ['fan power consumption 3.84w'],
#   ['pump life expectancy 120000 hours'],
#   ['pump connector 3pin'],
#   ['pump operating voltage 10.8 13.2vdc'],
#   ['pump rated voltage 12vdc'],
#   ['pump speed 2550 10%rpm'],
#   ['pump load current 0.21 10%a'],
#   ['pump power consumption 2.52w'],
#   ['net weight 1559 10g'],
#   ['led type addressable rgb led'],
#   ['led rated voltage 5vdc'],
#   ['led rated current 0.48 10%a'],
#   ['led rated power 2.4w'],
#   ['led connector 3pin 5v d g'],
#   ['led control m b with 5v add rgb header'],
#   ['ean 6933412726494'],
#   ['p n dp gs h12l csl280rgb'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan']],
#  '189': [['compatibility'],
#   ['intel lga2066 2011 1366 1151 1150 1155 1156'],
#   ['amd tr4 am4 fm2 fm2 fm1 am3 am3 am2 am2'],
#   ['tdp'],
#   ['250w'],
#   ['radiator dimension'],
#   ['276 120 27mm'],
#   ['radiator material'],
#   ['aluminum'],
#   ['tube material'],
#   ['premium sleeved tubing'],
#   ['tube length'],
#   ['400mm'],
#   ['waterblock dimension'],
#   ['72x72x47.3mm'],
#   ['cold plate material'],
#   ['copper'],
#   ['pump current'],
#   ['0.36a'],
#   ['pump speed'],
#   ['2100 10%rpm'],
#   ['pump bearing'],
#   ['ceramic bearing'],
#   ['pump life expectancy'],
#   ['50000 hrs'],
#   ['pump noise level'],
#   ['25db a'],
#   ['fan dimension'],
#   ['120 120 25mm'],
#   ['included fans'],
#   ['2pcs'],
#   ['fan speed'],
#   ['700 1800 10%rpm'],
#   ['max. air flow'],
#   ['74.5cfm'],
#   ['max. static pressure'],
#   ['2.15mmh2o'],
#   ['noise'],
#   ['18 35.2db a'],
#   ['rated voltage'],
#   ['12vdc'],
#   ['operating voltage'],
#   ['10.8 13.2vdc'],
#   ['started voltage'],
#   ['7vdc'],
#   ['rated current'],
#   ['0.2a'],
#   ['power input'],
#   ['2.4w'],
#   ['bearing type'],
#   ['hydraulic bearing'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan']],
#  '190': [['compatibility intel ',
#    ' lga 2066 20113 2011 1366 1156 1155 1151 1150'],
#   ['amd ', ' fm2 fm1 am4 am3 am3 am2 am2'],
#   ['cpu socket'],
#   ['water block material ', ' copper'],
#   ['pump motor speed ', ' 3600 rpm'],
#   ['rated voltage ', ' 12 v 5v'],
#   ['power input ', ' 12v 3.9 w 5v 1.06 w'],
#   ['fan dimension ', ' 120 x 120 x 25 mm'],
#   ['speed ', ' pwm 500 1500 r.p.m 2510 4pin'],
#   ['noise level ', ' 25.8 db a'],
#   ['rated voltage ', ' 12 v 5v'],
#   ['power input ', ' 12v 1.44 w 5v 1.6w one fan'],
#   ['max. air flow ', ' 56.45 cfm'],
#   ['max. pressure ', ' 1.59 mm h2o'],
#   ['led control ',
#    ' argb controller or 5v addressable rgb header on motherboard'],
#   ['radiator dimension ', ' 270 x 120 x 27 mm'],
#   ['tube length ', ' 326mm'],
#   ['material ', ' rubber'],
#   ['weight 1230 g'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan']],
#  '191': [['cpu socket compatibility'],
#   ['intel lga 2066 2011 v3 2011 1151 1150 1155 1156 1366 775 socket'],
#   ['amd am4 am3 am3 am2 am2 fm2 fm2 fm1 socket'],
#   ['radiator material aluminum'],
#   ['dimensions 157 x 119.6 x 27mm 6.2 x 4.7 x 1.1'],
#   ['fan dimensions 120 x 120 x 25 mm 4.7 x 4.7 x 1'],
#   ['speed 650 2000 rpm pwm 10%'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan']],
#  '192': [['compatibility'],
#   ['intel lga2066 2011 1366 1151 1150 1155 1156'],
#   ['amd tr4 am4 fm2 fm2 fm1 am3 am3 am2 am2'],
#   ['tdp'],
#   ['250w'],
#   ['radiator dimension'],
#   ['276 120 27mm'],
#   ['radiator material'],
#   ['aluminum'],
#   ['tube material'],
#   ['premium sleeved tubing'],
#   ['tube length'],
#   ['400mm'],
#   ['waterblock dimension'],
#   ['72x72x47.3mm'],
#   ['cold plate material'],
#   ['copper'],
#   ['pump current'],
#   ['0.36a'],
#   ['pump speed'],
#   ['2100 10%rpm'],
#   ['pump bearing'],
#   ['ceramic bearing'],
#   ['pump life expectancy'],
#   ['50000 hrs'],
#   ['pump noise level'],
#   ['25db a'],
#   ['fan dimension'],
#   ['120 120 25mm'],
#   ['included fans'],
#   ['2pcs'],
#   ['fan speed'],
#   ['700 1800 10%rpm'],
#   ['max. air flow'],
#   ['74.5cfm'],
#   ['max. static pressure'],
#   ['2.15mmh2o'],
#   ['noise'],
#   ['18 35.2db a'],
#   ['rated voltage'],
#   ['12vdc'],
#   ['operating voltage'],
#   ['10.8 13.2vdc'],
#   ['started voltage'],
#   ['7vdc'],
#   ['rated current'],
#   ['0.2a'],
#   ['power input'],
#   ['2.4w'],
#   ['bearing type'],
#   ['hydraulic bearing'],
#   [''],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan']],
#  '193': [['compatibility ', ''],
#   ['intel lga2066 2011 3 2011 1366 1151 1150 1155 1156'],
#   ['amd am4 fm2 fm2 fm1 am3 am3 am2 am2'],
#   ['tdp ', ''],
#   ['350w'],
#   ['radiator dimension ', ''],
#   ['274 120 27mm'],
#   ['radiator material ', ''],
#   ['aluminum'],
#   ['tube material ', ''],
#   ['premium sleeved tubing'],
#   ['tube length ', ''],
#   ['350mm'],
#   ['waterblock dimension ', ''],
#   ['84 84 46.5mm'],
#   ['cold plate material ', ''],
#   ['copper'],
#   ['pump current ', ''],
#   ['0.45a'],
#   ['pump speed ', ''],
#   ['2400rpm'],
#   ['pump bearing ', ''],
#   ['ceramic bearing'],
#   ['pump life expectancy ', ''],
#   ['50000 hrs'],
#   ['pump noise level ', ''],
#   ['25db a'],
#   ['fan dimension ', ''],
#   ['120 120 25mm'],
#   ['included fans ', ''],
#   ['2pcs'],
#   ['fan speed ', ''],
#   ['900 2000rpm'],
#   ['max. air flow ', ''],
#   ['56.5cfm 1 fan'],
#   ['max. static pressure ', ''],
#   ['1.99mmh2o'],
#   ['noise ', ''],
#   ['16 31.5db a'],
#   ['rated voltage ', ''],
#   ['12vdc'],
#   ['operating voltage ', ''],
#   ['10.8 13.2vdc'],
#   ['started voltage ', ''],
#   ['7vdc'],
#   ['rated current ', ''],
#   ['0.25a'],
#   ['power input ', ''],
#   ['3w'],
#   ['bearing type ', ''],
#   ['2ball bearing'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan']],
#  '194': [['cold plate material copper'],
#   ['radiator material'],
#   ['aluminum'],
#   ['pwm'],
#   ['yes'],
#   ['corsair icue compatibility'],
#   ['yes'],
#   ['radiator dimensions 277mm x 120mm x 27mm'],
#   ['fan dimensions 120mm x 25mm'],
#   ['fan speed 2200 rpm'],
#   ['number of fans 2'],
#   ['cooling socket support'],
#   ['intel 115x intel 2011 2066 amd am3 am2 amd am4 amd tr4'],
#   ['lighting rgb'],
#   ['radiator size 240mm'],
#   ['fan model ll series'],
#   ['fan airflow 63 cfm'],
#   ['noise level'],
#   ['36 dba'],
#   ['fan static pressure 3.0 mm h2o'],
#   [''],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan']],
#  '195': [['product name', ' masterliquid ml360 rgb tr4 edition'],
#   ['model', ' mlx d36m a20pc t1'],
#   ['cpu socket compatibility', ' amd socket tr4'],
#   ['radiator material', ' aluminum'],
#   ['dimensions', ' 394 x 119 x 27.2mm 15.5 x 4.7 x 1.1'],
#   ['fan dimensions', ' 120 x 120 x 25 mm 4.7 x 4.7 x 1'],
#   ['quantity', ' 3 pcs'],
#   ['speed', ' 650 2000 rpm pwm 10%'],
#   ['air flow', ' 66.7 cfm max'],
#   ['air pressure', ' 2.34 mmh2o max'],
#   ['mttf', ' 160000 hours'],
#   ['noise level', ' 6 30 dba'],
#   ['connector', ' 4 pin pwm'],
#   ['rated voltage', ' 12 vdc'],
#   ['pump dimensions', ' 86 x 70 x 49 mm 3.4 x 2.8 x 1.9'],
#   ['mttf', ' 70000 hours'],
#   ['noise level', ' 15 dba'],
#   ['connector', ' 3 pin'],
#   ['rated voltage', ' 12 vdc'],
#   ['warranty', ' 2 years'],
#   ['ean code', ' 4719512064870'],
#   ['upc code', ' 884102037542'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan']],
#  '196': [['water block'],
#   ['water block dimension', ' 80 x 80 x 45 mm'],
#   ['block material cpu plate ', ' copper'],
#   ['cpu socket support',
#    ' intel',
#    ' lga 115x1366 2011 2011 3 2066 amd',
#    ' am4 tr4'],
#   ['radiator'],
#   ['radiator dimension', ' 272 x 121 x 27 mm'],
#   ['radiator material', ' aluminum'],
#   ['tube', ' sleeved rubber tube'],
#   ['tube length', ' 380 mm'],
#   ['fan'],
#   ['fan', ' 2 x rog designed radiator fan'],
#   ['fan size', ' 2 fan slots 120mm'],
#   ['fan dimension', ' 120 x 120 x 25 mm'],
#   ['fan speed', ' 800 2500 rpm 10 %'],
#   ['fan static pressure', ' 5.0 mmh2o'],
#   ['fan air flow', ' 80.95 cfm 137.5 m3h'],
#   ['fan noise', ' 37.6 db a'],
#   ['control mode', ' pwm'],
#   ['special features'],
#   ['aura sync support', ' yes'],
#   ['the tr4 socket mounting bracket is bundled with tr4 cpu package not in the rog strix lc s package'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan']],
#  '197': [['cpu socket'],
#   ['lga2066 lga2011 v3 lga2011 lga1151 lga1150 lga1155 lga1156 lga1366 lga775 tr4 am4 am3 am3 am2 am2 fm2 fm2 fm1'],
#   ['waterblock dimensions 85 x 80 x 41.7 mm'],
#   ['radiator dimensions 277 x 120 x 27 mm'],
#   ['radiator material aluminum'],
#   ['fan dimensions l x w x h 120 x 120 x 26 mm 4.7 x 4.7 x 1 inch'],
#   ['fan speed 2000 10% rpm max'],
#   ['fan airflow 60.95 cfm max'],
#   ['fan air pressure 2.33 mm h2o max'],
#   ['fan mttf 160000 hours'],
#   ['fan noise level 27dba 1m'],
#   ['fan power connector 4 pin pwm argb 3 pin'],
#   ['fan rated voltage 12v dc'],
#   ['fan rated current 0.30 a'],
#   ['fan power consumption 3.60w'],
#   ['fan led color argb'],
#   ['pump mttf 160000 hours'],
#   ['pump noise level 20 dba 1m'],
#   ['pump rated voltage 12 vdc'],
#   ['pump power consumption 3.96w'],
#   ['connector 4 pin'],
#   [''],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan']],
#  '198': [['compatibility ', ''],
#   ['intel lga2066 2011 3 2011 1366 1151 1150 1155 1156'],
#   ['amd am4 fm2 fm2 fm1 am3 am3 am2 am2'],
#   ['tdp ', ''],
#   ['400w'],
#   ['radiator dimension ', ''],
#   ['396 120 27mm'],
#   ['radiator material ', ''],
#   ['aluminum'],
#   ['tube material ', ''],
#   ['premium sleeved tubing'],
#   ['tube length ', ''],
#   ['465mm'],
#   ['waterblock dimension ', ''],
#   ['84 84 46.5mm'],
#   ['cold plate material ', ''],
#   ['copper'],
#   ['pump current ', ''],
#   ['0.45a'],
#   ['pump speed ', ''],
#   ['2400rpm'],
#   ['pump bearing ', ''],
#   ['ceramic bearing'],
#   ['pump life expectancy ', ''],
#   ['50000 hrs'],
#   ['pump noise level ', ''],
#   ['25db a'],
#   ['fan dimension ', ''],
#   ['120 120 25mm'],
#   ['included fans ', ''],
#   ['3pcs'],
#   ['fan speed ', ''],
#   ['900 2000rpm'],
#   ['max. air flow ', ''],
#   ['56.5cfm 1 fan'],
#   ['max. static pressure ', ''],
#   ['1.99mmh2o'],
#   ['noise ', ''],
#   ['16 31.5db a'],
#   ['rated voltage ', ''],
#   ['12vdc'],
#   ['operating voltage ', ''],
#   ['10.8 13.2vdc'],
#   ['started voltage ', ''],
#   ['7vdc'],
#   ['rated current ', ''],
#   ['0.25a'],
#   ['power input ', ''],
#   ['3w'],
#   ['bearing type ', ''],
#   ['2ball bearing'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan']],
#  '199': [['intel 165w ', ' lga20xx lga1366 lga115x'],
#   ['amd 250w ', ' am4 am3 am3 am2 am2 fm2 fm2 fm1'],
#   ['net weight ', ' 1293 g'],
#   ['radiator dimensions ', ' 282 120 27 mm'],
#   ['radiator material ', ' aluminum'],
#   ['tube length ', ' 310 mm'],
#   ['pump dimensions ', ' 91 79 47 mm'],
#   ['pump speed ', ' 2400 rpm 10%'],
#   ['pump noise ', ' 17.8 db a'],
#   ['pump connector ', ' 3 pin'],
#   ['pump rated voltage ', ' 12 vdc'],
#   ['pump rated current ', ' 0.2 a'],
#   ['pump power consumption ', ' 2.4 w'],
#   ['fan dimension ', ' 120 120 25 mm'],
#   ['fan speed ', ' 500 1800 rpm 10%'],
#   ['fan airflow ', ' 69.34 cfm'],
#   ['fan air pressure ', ' 2.42 mmaq'],
#   ['fan noise ', ' 30 db a'],
#   ['fan connector ', ' 4 pin'],
#   ['bearing type ', ' hydro bearing'],
#   ['fan rated voltage ', ' 12 vdc'],
#   ['fan rated current ', ' 0.17 a'],
#   ['fan power consumption ', ' 2.04 w'],
#   ['led type ', ' rgb led'],
#   ['led connector ', ' 4 pin 12v g r b'],
#   ['led rated voltage ', ' 12 vdc'],
#   ['led power consumption ', ' 0.84 w pump 2.88 w fan 2'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan']],
#  '200': [['compatibility'],
#   ['intel lga2066 2011 1366 1151 1150 1155 1156'],
#   ['amd tr4 am4 fm2 fm2 fm1 am3 am3 am2 am2'],
#   ['tdp'],
#   ['350w'],
#   ['radiator dimension'],
#   ['397 120 27mm'],
#   ['radiator material'],
#   ['aluminum'],
#   ['tube material'],
#   ['premium sleeved tubing'],
#   ['tube length'],
#   ['465mm'],
#   ['waterblock dimension'],
#   ['72x72x47.3mm'],
#   ['cold plate material'],
#   ['copper'],
#   ['pump current'],
#   ['0.36a'],
#   ['pump speed'],
#   ['2100 10%rpm'],
#   ['pump bearing'],
#   ['ceramic bearing'],
#   ['pump life expectancy'],
#   ['50000 hrs'],
#   ['pump noise level'],
#   ['25db a'],
#   ['fan dimension'],
#   ['120 120 25mm'],
#   ['included fans'],
#   ['3pcs'],
#   ['fan speed'],
#   ['700 1800 10%rpm'],
#   ['max. air flow'],
#   ['74.5cfm'],
#   ['max. static pressure'],
#   ['2.15mmh2o'],
#   ['noise'],
#   ['18 35.2db a'],
#   ['rated voltage'],
#   ['12vdc'],
#   ['operating voltage'],
#   ['10.8 13.2vdc'],
#   ['started voltage'],
#   ['7vdc'],
#   ['rated current'],
#   ['0.2a'],
#   ['power input'],
#   ['2.4w'],
#   ['bearing type'],
#   ['hydraulic bearing'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan']],
#  '201': [['pump rated voltage ', ' 12 v 5v'],
#   ['rated current ', ' 325 ma 0.4a'],
#   ['motor speed ', ' 3600 r.p.m'],
#   ['water block material ', ' copper'],
#   ['fan dimension ', ' 120 x 120 x 25 mm'],
#   ['speed ', ' 500 1500 rpm'],
#   ['noise level ', ' 19 23.9 db a'],
#   ['rated voltage ', ' 12 v'],
#   ['max. air flow ', ' 42.45 cfm'],
#   ['max. pressure ', ' 1.45 mm h2o'],
#   ['connector ', ' 9 pin'],
#   ['tube length ', ' 326 mm'],
#   ['material ', ' rubber'],
#   ['radiator dimension ', ' 270x 120 x 27 mm'],
#   ['compatibility intel lga 2066 2011 3 20112066 2011 3 2011 1366 1156 1155 1151 1150'],
#   ['amd am4 fm2 fm1 am3 am3 am2 am2'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan']],
#  '202': [['compatibility', ''],
#   ['intel lga2066 2011 1366 1151 1150 1155 1156'],
#   ['amd tr4 am4 fm2 fm2 fm1 am3 am3 am2 am2'],
#   ['tdp', ''],
#   ['250w'],
# ...
#   ['Interface', 'SATA 3.0']],
#  '1512': [['Brand', 'SEAGATE'],
#   ['Model', 'SKYHAWK AI'],
#   ['ความจุ', '10 TB'],
#   ['Form Factor', '3.5'],
#   ['RPM', '-'],
#   ['Interface', 'SATA 3.0']],
#  '1513': [['Brand', 'WD'],
#   ['Model', 'WDS500G1R0A-RED'],
#   ['ความจุ', '500 GB'],
#   ['Form Factor', '2.5'],
#   ['RPM', '-'],
#   ['Interface', 'SATA 3.0']],
#  '1514': [['Brand', 'WD'],
#   ['Model', 'WDS500G1R0B-RED'],
#   ['ความจุ', '500 GB'],
#   ['Form Factor', 'M.2'],
#   ['RPM', '-'],
#   ['Interface', 'SATA 3.0']],
#  '1515': [['Brand', 'WD'],
#   ['Model', 'RED'],
#   ['ความจุ', '10 TB'],
#   ['Form Factor', '3.5'],
#   ['RPM', '5400'],
#   ['Interface', 'SATA 3.0']],
#  '1516': [['Brand', 'SEAGATE'],
#   ['Model', 'SkyHawk'],
#   ['ความจุ', '8 TB'],
#   ['Form Factor', '3.5'],
#   ['RPM', '-'],
#   ['Interface', 'SATA 3.0']],
#  '1517': [['Brand', 'WD'],
#   ['Model', 'WD102PURZ'],
#   ['ความจุ', '10 TB'],
#   ['Form Factor', '3.5'],
#   ['RPM', '7200'],
#   ['Interface', 'SATA 3.0']],
#  '1518': [['Brand', 'SEAGATE'],
#   ['Model', 'IronWolf Pro (ST14000NE0008)'],
#   ['ความจุ', '14 TB'],
#   ['Form Factor', '3.5'],
#   ['RPM', '7200'],
#   ['Interface', 'SATA 3.0']],
#  '1519': [['Brand', 'WD'],
#   ['Model', 'ELEMENTS ( WDBUZG0010BBK )'],
#   ['ความจุ', '1 TB'],
#   ['Form Factor', '2.5'],
#   ['RPM', '-'],
#   ['Interface', 'USB 3.0']],
#  '1520': [['Brand', 'WD'],
#   ['Model', 'ELEMENTS ( WDBU6Y0020BBK )'],
#   ['ความจุ', '2 TB'],
#   ['Form Factor', '2.5'],
#   ['RPM', '-'],
#   ['Interface', 'USB 3.0']],
#  '1521': [['Brand', 'WD'],
#   ['Model', 'ELEMENTS ( WDBUZG5000ABK )'],
#   ['ความจุ', '500 GB'],
#   ['Form Factor', '2.5'],
#   ['RPM', '-'],
#   ['Interface', 'USB 3.0']],
#  '1522': [['Brand', 'SEAGATE'],
#   ['Model', 'EXPANSION ( STEB3000300 )'],
#   ['ความจุ', '3 TB'],
#   ['Form Factor', '3.5'],
#   ['RPM', '-'],
#   ['Interface', 'USB 3.0']],
#  '1523': [['Brand', 'WD'],
#   ['Model', 'MY BOOK ( WDBBGB0040HBK )'],
#   ['ความจุ', '4 TB'],
#   ['Form Factor', '3.5'],
#   ['RPM', '-'],
#   ['Interface', 'USB 3.0']],
#  '1524': [['Brand', 'SEAGATE'],
#   ['Model', 'BACKUP PLUS HUB ( STEL4000300 )'],
#   ['ความจุ', '4 TB'],
#   ['Form Factor', '3.5'],
#   ['RPM', '-'],
#   ['Interface', 'USB 3.0']],
#  '1525': [['Brand', 'SAMSUNG'],
#   ['Model', 'Portable T5 (MU-PA1T0B/WW)'],
#   ['ความจุ', '1 TB'],
#   ['Form Factor', 'Portable SSD'],
#   ['RPM', '-'],
#   ['Interface', 'USB 3.1 Gen 2']],
#  '1526': [['Brand', 'WD'],
#   ['Model', 'MY BOOK ( WDBBGB0060HBK )'],
#   ['ความจุ', '6 TB'],
#   ['Form Factor', '3.5'],
#   ['RPM', '-'],
#   ['Interface', 'USB 3.0']],
#  '1527': [['Brand', 'WD'],
#   ['Model', 'MY BOOK ( WDBBGB0080HBK )'],
#   ['ความจุ', '8 TB'],
#   ['Form Factor', '3.5'],
#   ['RPM', '-'],
#   ['Interface', 'USB 3.0']],
#  '1528': [['Brand', 'SANDISK'],
#   ['Model', 'Sandisk Extreme Portable SSD'],
#   ['ความจุ', '250 GB'],
#   ['Form Factor', 'Portable SSD'],
#   ['RPM', '-'],
#   ['Interface', 'USB 3.1 Gen 2']],
#  '1529': [['Brand', 'SAMSUNG'],
#   ['Model', 'Portable T5 (MU-PA250B/WW)'],
#   ['ความจุ', '250 GB'],
#   ['Form Factor', 'Portable SSD'],
#   ['RPM', '-'],
#   ['Interface', 'USB 3.1 Gen 2']],
#  '1530': [['Brand', 'SAMSUNG'],
#   ['Model', 'Portable T5 (MU-PA500B/WW)'],
#   ['ความจุ', '500 GB'],
#   ['Form Factor', 'Portable SSD'],
#   ['RPM', '-'],
#   ['Interface', 'USB 3.1 Gen 2']],
#  '1531': [['Brand', 'SEAGATE'],
#   ['Model', 'BACKUP PLUS HUB ( STEL8000300 )'],
#   ['ความจุ', '8 TB'],
#   ['Form Factor', '3.5'],
#   ['RPM', '-'],
#   ['Interface', 'USB 3.0']],
#  '1532': [['Brand', 'SEAGATE'],
#   ['Model', 'SEAGATE BACKUP PLUS HUB ( STEL10000400 )'],
#   ['ความจุ', '10 TB'],
#   ['Form Factor', '3.5'],
#   ['RPM', '-'],
#   ['Interface', 'USB 3.0']],
#  '1533': [['Brand', 'SANDISK'],
#   ['Model', 'Sandisk Extreme Portable SSD'],
#   ['ความจุ', '1 TB'],
#   ['Form Factor', 'Portable SSD'],
#   ['RPM', '-'],
#   ['Interface', 'USB 3.1 Gen 2']],
#  '1534': [['Brand', 'WD'],
#   ['Model', 'ELEMENTS DESKTOP ( WDBBKG0040HBK )'],
#   ['ความจุ', '4 TB'],
#   ['Form Factor', '3.5'],
#   ['RPM', '-'],
#   ['Interface', 'USB 3.0']],
#  '1535': [['Brand', 'WD'],
#   ['Model', 'ELEMENTS DESKTOP ( WDBBKG0020HBK )'],
#   ['ความจุ', '2 TB'],
#   ['Form Factor', '3.5'],
#   ['RPM', '-'],
#   ['Interface', 'USB 3.0']],
#  '1536': [['Brand', 'WD'],
#   ['Model', 'MY PASSPORT WIRELESS PRO ( WDBSMT0040BBK )'],
#   ['ความจุ', '4 TB'],
#   ['Form Factor', 'Wireless Portable HDD'],
#   ['RPM', '-'],
#   ['Interface', 'USB 3.0 , Wi-Fi']],
#  '1537': [['Brand', 'WD'],
#   ['Model', 'MY PASSPORT WIRELESS SSD ( WDBAMJ5000AGY-PESN )'],
#   ['ความจุ', '500 GB'],
#   ['Form Factor', 'Wireless Portable SSD'],
#   ['RPM', '-'],
#   ['Interface', 'USB 3.0 , Wi-Fi']],
#  '1538': [['Brand', 'SEAGATE'],
#   ['Model', 'BACKUP PLUS HUB (STEL6000300)'],
#   ['ความจุ', '6 TB'],
#   ['Form Factor', '3.5'],
#   ['RPM', '-'],
#   ['Interface', 'USB 3.0']],
#  '1539': [['Brand', 'WD'],
#   ['Model', 'MY PASSPORT SSD ( WDBKVX2560PSL )'],
#   ['ความจุ', '256 GB'],
#   ['Form Factor', 'Portable SSD'],
#   ['RPM', '-'],
#   ['Interface', 'USB 3.1 Gen 2']],
#  '1540': [['Brand', 'WD'],
#   ['Model', 'MY PASSPORT SSD ( WDBKVX0010PSL )'],
#   ['ความจุ', '1 TB'],
#   ['Form Factor', 'Portable SSD'],
#   ['RPM', '-'],
#   ['Interface', 'USB 3.1 Gen 2']],
#  '1541': [['Brand', 'WD'],
#   ['Model', 'MY PASSPORT SSD ( WDBKVX5120PSL )'],
#   ['ความจุ', '512 GB'],
#   ['Form Factor', 'Portable SSD'],
#   ['RPM', '-'],
#   ['Interface', 'USB 3.1 Gen 2']],
#  '1542': [['Brand', 'SANDISK'],
#   ['Model', 'Sandisk Extreme Portable SSD'],
#   ['ความจุ', '2 TB'],
#   ['Form Factor', 'Portable SSD'],
#   ['RPM', '-'],
#   ['Interface', 'USB 3.1 Gen 2']],
#  '1543': [['Brand', 'SEAGATE'],
#   ['Model', 'FAST SSD (STCM1000400)'],
#   ['ความจุ', '1 TB'],
#   ['Form Factor', 'Portable SSD'],
#   ['RPM', '-'],
#   ['Interface', 'USB 3.0']],
#  '1544': [['Brand', 'SEAGATE'],
#   ['Model', 'FAST SSD (STCM500401)'],
#   ['ความจุ', '500 GB'],
#   ['Form Factor', 'Portable SSD'],
#   ['RPM', '-'],
#   ['Interface', 'USB 3.0']],
#  '1545': [['Brand', 'WD'],
#   ['Model', 'WD MY PASSPORT WIRELESS SSD ( WDBAMJ0020BGY-PESN )'],
#   ['ความจุ', '2 TB'],
#   ['Form Factor', 'Wireless Portable SSD'],
#   ['RPM', '-'],
#   ['Interface', 'USB 3.0 , Wi-Fi']],
#  '1546': [['Brand', 'WD'],
#   ['Model', 'MY PASSPORT ULTRA'],
#   ['ความจุ', '2 TB'],
#   ['Form Factor', '2.5'],
#   ['RPM', 'USB 3.0']],
#  '1547': [['Brand', 'WD'],
#   ['Model', 'P10'],
#   ['ความจุ', '2 TB'],
#   ['Form Factor', '2.5'],
#   ['RPM', 'USB 3.2 Gen 1']],
#  '1548': [['Brand', 'WD'],
#   ['Model', 'My Passport Ultra'],
#   ['ความจุ', '4 TB'],
#   ['Form Factor', '2.5'],
#   ['RPM', '-'],
#   ['Interface', 'Type-C']],
#  '1549': [['Brand', 'SEAGATE'],
#   ['Model', 'SEAGATE NEW BACKUP PLUS SLIM (BLACK) (STHN2000400)'],
#   ['ความจุ', '2 TB'],
#   ['Form Factor', '2.5'],
#   ['RPM', '-'],
#   ['Interface', 'USB 3.0']],
#  '1550': [['Brand', 'SEAGATE'],
#   ['Model', 'Backup Plus Ultra Touch (STHH2000300)'],
#   ['ความจุ', '2 TB'],
#   ['Form Factor', '2.5'],
#   ['RPM', 'USB 3.0']],
#  '1551': [['Brand', 'WD'],
#   ['Model', 'My Passport Go'],
#   ['ความจุ', '500 GB'],
#   ['Form Factor', 'Portable SSD'],
#   ['RPM', '-'],
#   ['Interface', 'USB 3.0']],
#  '1552': [['Brand', 'WD'],
#   ['Model', 'My Passport Ultra'],
#   ['ความจุ', '1 TB'],
#   ['Form Factor', '2.5'],
#   ['RPM', '-'],
#   ['Interface', 'Type-C']],
#  '1553': [['Brand', 'WD'],
#   ['Model', 'My Passport Go'],
#   ['ความจุ', '500 GB'],
#   ['Form Factor', 'Portable SSD'],
#   ['RPM', '-'],
#   ['Interface', 'USB 3.0']],
#  '1554': [['Brand', 'SEAGATE'],
#   ['Model', 'Backup Plus Ultra Touch (STHH2000301)'],
#   ['ความจุ', '2 TB'],
#   ['Form Factor', '2.5'],
#   ['RPM', '-'],
#   ['Interface', 'USB 3.0']],
#  '1555': [['Brand', 'WD'],
#   ['Model', 'My Passport Ultra'],
#   ['ความจุ', '4 TB'],
#   ['Form Factor', '2.5'],
#   ['RPM', '-'],
#   ['Interface', 'Type-C']],
#  '1556': [['Brand', 'WD'],
#   ['Model', 'MY PASSPORT ULTRA'],
#   ['ความจุ', '2 TB'],
#   ['Form Factor', '2.5'],
#   ['RPM', 'USB 3.0']],
#  '1557': [['Brand', 'SEAGATE'],
#   ['Model', 'NEW BACKUP PLUS SLIM BLACK (STHN1000400)'],
#   ['ความจุ', '1 TB'],
#   ['Form Factor', '2.5'],
#   ['RPM', '-'],
#   ['Interface', 'USB 3.0']],
#  '1558': [['Brand', 'WD'],
#   ['Model', 'My Passport (WDBYVG0020BBK)'],
#   ['ความจุ', '2 TB'],
#   ['Form Factor', '2.5'],
#   ['RPM', '-'],
#   ['Interface', 'USB 3.2 Gen 1']],
#  '1559': [['Brand', 'WD'],
#   ['Model', 'My Passport Go'],
#   ['ความจุ', '1 TB'],
#   ['Form Factor', 'Portable SSD'],
#   ['RPM', '-'],
#   ['Interface', 'USB 3.0']],
#  '1560': [['Brand', 'SANDISK'],
#   ['Model', 'Sandisk Extreme Pro Portable SSD'],
#   ['ความจุ', '500 GB'],
#   ['Form Factor', 'Portable SSD'],
#   ['RPM', '-'],
#   ['Interface', 'Type-C']],
#  '1561': [['Brand', 'SEAGATE'],
#   ['Model', 'Seagate Backup Plus Portable Drives (STHP4000400)'],
#   ['ความจุ', '4 TB'],
#   ['Form Factor', '2.5'],
#   ['RPM', 'USB 3.0']],
#  '1562': [['Brand', 'SEAGATE'],
#   ['Model', 'NEW BACKUP PLUS SLIM (BLUE) (STHN2000402)'],
#   ['ความจุ', '2 TB'],
#   ['Form Factor', '2.5'],
#   ['RPM', '-'],
#   ['Interface', 'USB 3.0']],
#  '1563': [['Brand', 'SEAGATE'],
#   ['Model', 'NEW BACKUP PLUS SLIM (SILVER) (STHN2000401)'],
#   ['ความจุ', '2 TB'],
#   ['Form Factor', '2.5'],
#   ['RPM', '-'],
#   ['Interface', 'USB 3.0']],
#  '1564': [['Brand', 'WD'],
#   ['Model', 'MY PASSPORT SSD ( WDBKVX0020PSL )'],
#   ['ความจุ', '2 TB'],
#   ['Form Factor', 'Portable SSD'],
#   ['RPM', '-'],
#   ['Interface', 'PCIe 3.1']],
#  '1565': [['Brand', 'WD'],
#   ['Model', 'My Passport Go'],
#   ['ความจุ', '1 TB'],
#   ['Form Factor', 'Portable SSD'],
#   ['RPM', '-'],
#   ['Interface', 'USB 3.0']],
#  '1566': [['Brand', 'SEAGATE'],
#   ['Model', 'NEW BACKUP PLUS SLIM (RED) (STHN1000403)'],
#   ['ความจุ', '1 TB'],
#   ['Form Factor', '2.5'],
#   ['RPM', '-'],
#   ['Interface', 'USB 3.0']],
#  '1567': [['Brand', 'SEAGATE'],
#   ['Model', 'SEAGATE NEW BACKUP PLUS SLIM (GRAY) (STHN1000405)'],
#   ['ความจุ', '1 TB'],
#   ['Form Factor', '2.5'],
#   ['RPM', '-'],
#   ['Interface', 'SATA 3.0']],
#  '1568': [['Brand', 'SEAGATE'],
#   ['Model', 'SEAGATE NEW BACKUP PLUS SLIM (ROSE GOLD) (STHN2000405)'],
#   ['ความจุ', '2 TB'],
#   ['Form Factor', '2.5'],
#   ['RPM', '-'],
#   ['Interface', 'USB 3.0']],
#  '1569': [['Brand', 'WD'],
#   ['Model', 'D10'],
#   ['ความจุ', '8 TB'],
#   ['Form Factor', '3.5'],
#   ['RPM', '7200'],
#   ['Interface', 'USB 3.2 Gen 1']],
#  '1570': [['Brand', 'WD'],
#   ['Model', 'My Passport (WDBPKJ0050BBK)'],
#   ['ความจุ', '5 TB'],
#   ['Form Factor', '2.5'],
#   ['RPM', '-'],
#   ['Interface', 'USB 3.2 Gen 1']],
#  '1571': [['Brand', 'SEAGATE'],
#   ['Model', 'NEW BACKUP PLUS SLIM (BLUE) (STHN1000402)'],
#   ['ความจุ', '1 TB'],
#   ['Form Factor', '2.5'],
#   ['RPM', '-'],
#   ['Interface', 'USB 3.0']],
#  '1572': [['Brand', 'SEAGATE'],
#   ['Model', 'NEW BACKUP PLUS SLIM (GOLD) (STHN1000404)'],
#   ['ความจุ', '1 TB'],
#   ['Form Factor', '2.5'],
#   ['RPM', '-'],
#   ['Interface', 'USB 3.0']],
#  '1573': [['Brand', 'SEAGATE'],
#   ['Model', 'STHP5000400'],
#   ['ความจุ', '5 TB'],
#   ['Form Factor', '2.5'],
#   ['RPM', 'USB 3.0']],
#  '1574': [['Brand', 'WD'],
#   ['Model', 'My Passport (WDBPKJ0040BBK)'],
#   ['ความจุ', '4 TB'],
#   ['Form Factor', '2.5'],
#   ['RPM', '-'],
#   ['Interface', 'USB 3.2 Gen 1']],
#  '1575': [['Brand', 'WD'],
#   ['Model', 'My Passport (WDBYVG0010BBK)'],
#   ['ความจุ', '1 TB'],
#   ['Form Factor', '2.5'],
#   ['RPM', '-'],
#   ['Interface', 'USB 3.2 Gen 1']],
#  '1576': [['Brand', 'WD'],
#   ['Model', 'My Passport (WDBYVG0020BRD)'],
#   ['ความจุ', '2 TB'],
#   ['Form Factor', '2.5'],
#   ['RPM', '-'],
#   ['Interface', 'USB 3.2 Gen 1']],
#  '1577': [['Brand', 'SEAGATE'],
#   ['Model', 'Seagate Backup Plus Portable Drives (STHP4000402)'],
#   ['ความจุ', '4 TB'],
#   ['Form Factor', '2.5'],
#   ['RPM', 'USB 3.0']],
#  '1578': [['Brand', 'SANDISK'],
#   ['Model', 'Extreme Pro Portable SSD'],
#   ['ความจุ', '1 TB'],
#   ['Form Factor', 'Portable SSD'],
#   ['RPM', '-'],
#   ['Interface', 'USB 3.1 Gen 2']],
#  '1579': [['Brand', 'WD'],
#   ['Model', 'P10'],
#   ['ความจุ', '4 TB'],
#   ['Form Factor', '2.5'],
#   ['RPM', 'USB 3.2 Gen 1']],
#  '1580': [['Brand', 'SEAGATE'],
#   ['Model', 'NEW BACKUP PLUS SLIM (SILVER) (STHN1000401)'],
#   ['ความจุ', '1 TB'],
#   ['Form Factor', '2.5'],
#   ['RPM', '-'],
#   ['Interface', 'USB 3.0']],
#  '1581': [['Brand', 'WD'],
#   ['Model', 'MY PASSPORT WIRELESS SSD (WDBAMJ2500AGY)'],
#   ['ความจุ', '250 GB'],
#   ['Form Factor', 'Wireless Portable SSD'],
#   ['RPM', '-'],
#   ['Interface', 'USB 3.0 , Wi-Fi']],
#  '1582': [['Brand', 'SEAGATE'],
#   ['Model', 'STHP5000401'],
#   ['ความจุ', '5 TB'],
#   ['Form Factor', '2.5'],
#   ['RPM', 'USB 3.0']],
#  '1583': [['Brand', 'SEAGATE'],
#   ['Model', 'NEW BACKUP PLUS SLIM (GOLD) (STHN2000404)'],
#   ['ความจุ', '2 TB'],
#   ['Form Factor', '2.5'],
#   ['RPM', '-'],
#   ['Interface', 'USB 3.0']],
#  '1584': [['Brand', 'WD'],
#   ['Model', 'P10'],
#   ['ความจุ', '5 TB'],
#   ['Form Factor', '2.5'],
#   ['RPM', 'USB 3.2 Gen 1']],
#  '1585': [['Brand', 'SEAGATE'],
#   ['Model', 'Seagate Backup Plus Portable Drives (STHP4000401)'],
#   ['ความจุ', '4 TB'],
#   ['Form Factor', '2.5'],
#   ['RPM', 'USB 3.0']],
#  '1586': [['Brand', 'SEAGATE'],
#   ['Model', 'STHP5000403'],
#   ['ความจุ', '5 TB'],
#   ['Form Factor', '2.5'],
#   ['RPM', 'USB 3.0']],
#  '1587': [['Brand', 'WD'],
#   ['Model', 'My Passport (WDBYVG0020BBL)'],
#   ['ความจุ', '2 TB'],
#   ['Form Factor', '2.5'],
#   ['RPM', '-'],
#   ['Interface', 'USB 3.2 Gen 1']],
#  '1588': [['Brand', 'HP'],
#   ['Model', 'Portable SSD P500'],
#   ['ความจุ', '250 GB'],
#   ['Form Factor', '-'],
#   ['RPM', '-'],
#   ['Interface', 'USB 3.1 Gen 2']],
#  '1589': [['Brand', 'WD'],
#   ['Model', 'My Passport Ultra 2TB (WDBC3C0020BGD)'],
#   ['ความจุ', '2 TB'],
#   ['Form Factor', '2.5'],
#   ['RPM', '-'],
#   ['Interface', 'Type-C']],
#  '1590': [['Brand', 'SEAGATE'],
#   ['Model', 'STHP5000402'],
#   ['ความจุ', '5 TB'],
#   ['Form Factor', '2.5'],
#   ['RPM', 'USB 3.0']],
#  '1591': [['Brand', 'WD'],
#   ['Model', 'BLACK P50 Game Drive SSD'],
#   ['ความจุ', '500 GB'],
#   ['Form Factor', '-'],
#   ['RPM', '-'],
#   ['Interface', 'USB 3.2 Gen 2x2']],
#  '1592': [['seagate'],
#   ['fast ssd'],
#   ['2 tb'],
#   ['nan'],
#   ['nan'],
#   ['usb 3.0'],
#   ['3 years'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan'],
#   ['nan']],
#  '1593': [['Brand', 'WD'],
#   ['Model', 'BLACK P50 Game Drive SSD'],
#   ['ความจุ', '1 TB'],
#   ['Form Factor', '-'],
#   ['RPM', '-'],
#   ['Interface', 'USB 3.2 Gen 2x2']],
#  '1594': [['Brand', 'SEAGATE'],
#   ['Model', 'One Touch SSD'],
#   ['ความจุ', '500 GB'],
#   ['Form Factor', 'Portable SSD'],
#   ['RPM', '-'],
#   ['Interface', 'USB 3.0']],
#  '1595': [['Brand', 'HP'],
#   ['Model', 'Portable SSD P500'],
#   ['ความจุ', '250 GB'],
#   ['Form Factor', '-'],
#   ['RPM', '-'],
#   ['Interface', 'USB 3.1 Gen 2']],
#  '1596': [['Brand', 'SEAGATE'],
#   ['Model', 'One Touch SSD'],
#   ['ความจุ', '1 TB'],
#   ['Form Factor', 'Portable SSD'],
#   ['RPM', '-'],
#   ['Interface', 'USB 3.0']],
#  '1597': [['Brand', 'SEAGATE'],
#   ['Model', 'Seagate Backup Plus Portable Drives (STHP4000403)'],
#   ['ความจุ', '4 TB'],
#   ['Form Factor', '2.5'],
#   ['RPM', 'USB 3.0']],
#  '1598': [['Brand', 'SEAGATE'],
#   ['Model', 'Seagate Backup Plus Portable Drives (STHP4000404)'],
#   ['ความจุ', '4 TB'],
#   ['Form Factor', '2.5'],
#   ['RPM', 'USB 3.0']],
#  '1599': [['Brand', 'WD'],
#   ['Model', 'My Passport (WDBPKJ0040BBL)'],
#   ['ความจุ', '4 TB'],
#   ['Form Factor', '2.5'],
#   ['RPM', '-'],
#   ['Interface', 'USB 3.2 Gen 1']],
#  '1600': [['Brand', 'HP'],
#   ['Model', 'Portable SSD P500'],
#   ['ความจุ', '250 GB'],
#   ['Form Factor', '-'],
#   ['RPM', '-'],
#   ['Interface', 'USB 3.1 Gen 2']],
#  '1601': [['Brand', 'SAMSUNG'],
#   ['Model', 'Portable T5 (MU-PA500R/WW)'],
#   ['ความจุ', '500 GB'],
#   ['Form Factor', 'Portable SSD'],
#   ['RPM', '-'],
#   ['Interface', 'Type-C']],
#  '1602': [['Brand', 'WD'],
#   ['Model', 'My Passport Ultra'],
#   ['ความจุ', '4 TB'],
#   ['Form Factor', '2.5'],
#   ['RPM', '-'],
#   ['Interface', 'USB 3.0']],
#  '1603': [['Brand', 'HP'],
#   ['Model', 'Portable SSD P500'],
#   ['ความจุ', '250 GB'],
#   ['Form Factor', '-'],
#   ['RPM', '-'],
#   ['Interface', 'USB 3.1 Gen 2']],
#  '1604': [['Brand', 'HP'],
#   ['Model', 'P500 (7NL53AA#UUF)'],
#   ['ความจุ', '500 GB'],
#   ['Form Factor', 'Portable SSD'],
#   ['RPM', '-'],
#   ['Interface', 'Type-C']],
#  '1605': [['Brand', 'WD'],
#   ['Model', 'WD MY PASSPORT SKY (WDBYVG0010BBL)'],
#   ['ความจุ', '1 TB'],
#   ['Form Factor', '2.5'],
#   ['RPM', '-'],
#   ['Interface', 'USB 3.2 Gen 1']],
#  ...}

# %% [markdown]
# # Keep attributes and values in triples form

# %%
triples = []
regex_none = re.compile("\s|0|^$")
for key,val in attr_val_1.items():
    for v in val:
        tmp_triples = []
        if not re.match(regex_none, clean_text(v[1])):
            tmp_triples.extend([clean_text(prod_name_df['Product_Name'][int(key)]), clean_text(v[0]), clean_text(v[1])])
            triples.append(tmp_triples)

# %%
triples[:20]
# Out:
# [['notebook โน้ตบุ๊ค asus vivobook 15 x512da ej139t transparent silver',
#   'cpu brand',
#   'amd'],
#  ['notebook โน้ตบุ๊ค asus vivobook 15 x512da ej139t transparent silver',
#   'cpu model',
#   'amd ryzen 5 3500u'],
#  ['notebook โน้ตบุ๊ค asus vivobook 15 x512da ej139t transparent silver',
#   'base clock',
#   '2.00 ghz'],
#  ['notebook โน้ตบุ๊ค asus vivobook 15 x512da ej139t transparent silver',
#   'boost clock',
#   '3.60 ghz'],
#  ['notebook โน้ตบุ๊ค asus vivobook 15 x512da ej139t transparent silver',
#   'cache',
#   '4 mb'],
#  ['notebook โน้ตบุ๊ค asus vivobook 15 x512da ej139t transparent silver',
#   'graphic chip',
#   'amd radeon vega 8'],
#  ['notebook โน้ตบุ๊ค asus vivobook 15 x512da ej139t transparent silver',
#   'brand',
#   'amd'],
#  ['notebook โน้ตบุ๊ค asus vivobook 15 x512da ej139t transparent silver',
#   'display size',
#   '15.60'],
#  ['notebook โน้ตบุ๊ค asus vivobook 15 x512da ej139t transparent silver',
#   'display resolution',
#   '1920 x 1080'],
#  ['notebook โน้ตบุ๊ค asus vivobook 15 x512da ej139t transparent silver',
#   'display type',
#   'full hd'],
#  ['notebook โน้ตบุ๊ค asus vivobook 15 x512da ej139t transparent silver',
#   'touchscreen',
#   'no'],
#  ['notebook โน้ตบุ๊ค asus vivobook 15 x512da ej139t transparent silver',
#   'ram',
#   '8 gb'],
#  ['notebook โน้ตบุ๊ค asus vivobook 15 x512da ej139t transparent silver',
#   'ram type',
#   'ddr4'],
#  ['notebook โน้ตบุ๊ค asus vivobook 15 x512da ej139t transparent silver',
#   'hdd 1 capacity',
#   '512 gb'],
#  ['notebook โน้ตบุ๊ค asus vivobook 15 x512da ej139t transparent silver',
#   'hdd 1 type',
#   'm.2 ssd pcie nvme'],
#  ['notebook โน้ตบุ๊ค asus vivobook 15 x512da ej139t transparent silver',
#   'optical disk drive',
#   'no'],
#  ['notebook โน้ตบุ๊ค asus vivobook 15 x512da ej139t transparent silver',
#   'wi fi',
#   'wi fi 5 802.11ac'],
#  ['notebook โน้ตบุ๊ค asus vivobook 15 x512da ej139t transparent silver',
#   'bluetooth',
#   '4.1'],
#  ['notebook โน้ตบุ๊ค asus vivobook 15 x512da ej139t transparent silver',
#   'sim card cellular data',
#   'no'],
#  ['notebook โน้ตบุ๊ค asus vivobook 15 x512da ej139t transparent silver',
#   'os',
#   'windows 10']]

# %%
# Write the triples to text file
with open('./Data/triples_{}.txt'.format(file_name), 'w', encoding='utf-8') as f:
    for _list in triples:
        for _string in _list:
            #f.seek(0)
            f.write(str(_string) + '\t')
        f.write('\n')
