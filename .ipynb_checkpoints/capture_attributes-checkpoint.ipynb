# %%
import pandas as pd
import csv
import re
import string
import nltk

from pythainlp.tokenize import Tokenizer
from pythainlp import word_tokenize
from pythainlp.corpus import thai_stopwords
from pythainlp.tokenize import dict_trie
from pythainlp.tag import pos_tag

from nltk.corpus import words
from stop_words import get_stop_words

# %%
# import data from csv
file_name = 'category1'

FILE = './Data/{}.csv'.format(file_name)
df = pd.read_csv(FILE)

# %%
df.head()
# Out:
#    Unnamed: 0                                       category_0_0  \
# 0           0                          โทรศัพท์มือถือและแท็บเล็ต
# 1           1                                        Smartphones
# 2           2    Samsung Galaxy M30s (4/64GB) ( โทรศัพท์มือถือ )
# 3           3  แบตอึดอยู่นาน สนุกได้ทั้งวัน กับความจุ 6000 mA...
# 4           4  ระบบกล้องหลัง 3 ตัว ที่มีกล้องชัดสูงสุดถึง 48 ...
#
#                                         category_0_1  \
# 0                          โทรศัพท์มือถือและแท็บเล็ต
# 1                                        Smartphones
# 2  โทรศัพท์มือถือ Samsung Galaxy A50s Ram4/64GB (...
# 3                           GSM 850/900/1800/1900MHz
# 4                      3G WCDMA 850/900/1900/2100MHz
#
#                                         category_0_2  \
# 0                          โทรศัพท์มือถือและแท็บเล็ต
# 1                                        Smartphones
# 2               Samsung Galaxy A10s (RAM2GB/ROM32GB)
# 3      สมาร์ทโฟน (โทรศัพท์มือถือพร้อมระบบปฏิบัติการ)
# 4  จอแสดงผล TFT-LCD 24-bit (16 ล้านสี)- หน้าจอทรง...
#
#                                         category_0_3  \
# 0                          โทรศัพท์มือถือและแท็บเล็ต
# 1                                        Smartphones
# 2  Samsung Galaxy Note 10 + (12/256 GB) ( โทรศัพท...
# 3                                ขนาดหน้าจอ 6.8 นิ้ว
# 4                                          Ram 12 GB
#
#                                         category_0_4  \
# 0                          โทรศัพท์มือถือและแท็บเล็ต
# 1                                        Smartphones
# 2                           Samsung Galaxy A7 (2017)
# 3  ระบบเซ็นเซอร์ (Sensor)\r\n- ระบบตรวจสอบลายนิ้ว...
# 4  คุณสมบัติการกันน้ำ (Waterproof)\r\n- กันน้ำได้...
#
#                                         category_0_5  \
# 0                          โทรศัพท์มือถือและแท็บเล็ต
# 1                                        Smartphones
# 2  Samsung Galaxy A9 (2018) 6 GB RAM 128 GB ROM 6...
# 3  จอแสดงผล Super AMOLED 24-bit (16 ล้านสี)Fullvi...
# 4  ระบบตรวจสอบลายนิ้วมือ (Fingerprint)ระบบจดจำใบห...
#
#                                         category_0_6  \
# 0                          โทรศัพท์มือถือและแท็บเล็ต
# 1                                        Smartphones
# 2  Samsung A30S (RAM 4GB / ROM 64 GB) มือ 1 ประกั...
# 3                             คุณสมบัติ Samsung A30S
# 4           จอแสดงผล Super AMOLED 24-bit (16 ล้านสี)
#
#                                         category_0_7  \
# 0                          โทรศัพท์มือถือและแท็บเล็ต
# 1                                        Smartphones
# 2  (มือ1 ศูนย์ไทย) Samsung Galaxy Note 10 Plus No...
# 3  Samsung Galaxy Note10 plus TH ประกันศูนย์ไทย 1...
# 4                                      แบรนด์ ซัมซุง
#
#                                       category_0_8  ...  \
# 0                        โทรศัพท์มือถือและแท็บเล็ต  ...
# 1                                      Smartphones  ...
# 2  Samsung Galaxy A70 (8/128GB) ( โทรศัพท์มือถือ )  ...
# 3                      Galaxy A70 (SM-A705FZBGTHL)  ...
# 4                               สเปคเทพของเกมเมอร์  ...
#
#                                      category_33_234  \
# 0                                   สมาร์ทดีไวซ์ New
# 1                                           แก็ดเจ็ต
# 2                           เครื่องเล่นเกมคอมโซล New
# 3                                         คอนโซล New
# 4  GloryStar BASEUS PUBG ไฟฟรีเกมที่วางโทรศัพท์แผ...
#
#                                      category_33_235  \
# 0                                   สมาร์ทดีไวซ์ New
# 1                                           แก็ดเจ็ต
# 2                           เครื่องเล่นเกมคอมโซล New
# 3                                         คอนโซล New
# 4  GloryStar นาฬิกาติดตามตำแหน่งอัจฉริยะเด็กนาฬิก...
#
#                                      category_33_236  \
# 0                                   สมาร์ทดีไวซ์ New
# 1                                           แก็ดเจ็ต
# 2                           เครื่องเล่นเกมคอมโซล New
# 3                                         คอนโซล New
# 4  GloryStar Joy-CON ตัวควบคุมเกมแป้นเกมส์จอยเกมส...
#
#                                      category_33_237  \
# 0                                   สมาร์ทดีไวซ์ New
# 1                                           แก็ดเจ็ต
# 2                           เครื่องเล่นเกมคอมโซล New
# 3                                         คอนโซล New
# 4  GloryStar คอนโซลเกมคลาสสิก 8 BitsProfessional ...
#
#                                      category_33_238  \
# 0                                   สมาร์ทดีไวซ์ New
# 1                                           แก็ดเจ็ต
# 2                           เครื่องเล่นเกมคอมโซล New
# 3                                         คอนโซล New
# 4  GloryStar สีน้ำเงินแปรงเกมควบคุมเครื่องรับสัญญ...
#
#                                      category_33_239  \
# 0                                   สมาร์ทดีไวซ์ New
# 1                                           แก็ดเจ็ต
# 2                           เครื่องเล่นเกมคอมโซล New
# 3                                         คอนโซล New
# 4  GloryStar Flysky รีโมทคอนโทรล FS-IT4S + IA4B 4...
#
#                                 category_33_240  \
# 0                              สมาร์ทดีไวซ์ New
# 1                                      แก็ดเจ็ต
# 2                      เครื่องเล่นเกมคอมโซล New
# 3                                    คอนโซล New
# 4  Top-Sky PlayStation 2 PS2 Memory Card - 32MB
#
#                                  category_33_241  \
# 0                               สมาร์ทดีไวซ์ New
# 1                                       แก็ดเจ็ต
# 2                       เครื่องเล่นเกมคอมโซล New
# 3                                     คอนโซล New
# 4  Top-Sky PlayStation 2 PS2 Memory Card - 256MB
#
#                                  category_33_242  \
# 0                               สมาร์ทดีไวซ์ New
# 1                                       แก็ดเจ็ต
# 2                       เครื่องเล่นเกมคอมโซล New
# 3                                     คอนโซล New
# 4  Top-Sky PlayStation 2 PS2 Memory Card - 128MB
#
#                                      category_33_243
# 0                                   สมาร์ทดีไวซ์ New
# 1                                           แก็ดเจ็ต
# 2                           เครื่องเล่นเกมคอมโซล New
# 3                                         คอนโซล New
# 4  Top - Sky 3 - in - 1 PS4/PS4 Slim/PS4 เกมโปรที...
#
# [5 rows x 5619 columns]

# %%
# Drop a column that not use
data = df.drop(columns=['Unnamed: 0'])

# Drop column that all equal to NaN
data = data.dropna(axis=1, how='all')

# Fill NaN with "-"
data = data.fillna('-')

# %%
data.head(10)
# Out:
#                                         category_0_0  \
# 0                          โทรศัพท์มือถือและแท็บเล็ต
# 1                                        Smartphones
# 2    Samsung Galaxy M30s (4/64GB) ( โทรศัพท์มือถือ )
# 3  แบตอึดอยู่นาน สนุกได้ทั้งวัน กับความจุ 6000 mA...
# 4  ระบบกล้องหลัง 3 ตัว ที่มีกล้องชัดสูงสุดถึง 48 ...
# 5  ใช้ Exynos 9611 สเป็กแรงขึ้นเล่นเกมส์ได้ไม่มีส...
# 6  หน้าจอแสดงผล Super AMOLED Infinity-U ขนาด 6.4 ...
# 7                                      แบรนด์ ซัมซุง
# 8                         SKU 480942616_TH-870640886
# 9               ประเภทของการรับประกัน มีการรับประกัน
#
#                                         category_0_1  \
# 0                          โทรศัพท์มือถือและแท็บเล็ต
# 1                                        Smartphones
# 2  โทรศัพท์มือถือ Samsung Galaxy A50s Ram4/64GB (...
# 3                           GSM 850/900/1800/1900MHz
# 4                      3G WCDMA 850/900/1900/2100MHz
# 5  4G FDD LTE B1(2100), B3(1800), B5(850), B7(260...
# 6         4G TDD LTE B38(2600), B40(2300), B41(2500)
# 7                              รองรับ 2 ซิม Nano-SIM
# 8  หน่วยประมวลผล Exynos 9610 Quad 2.3 GHz + Quad ...
# 9                             ระบบปฏิบัติการ Android
#
#                                         category_0_2  \
# 0                          โทรศัพท์มือถือและแท็บเล็ต
# 1                                        Smartphones
# 2               Samsung Galaxy A10s (RAM2GB/ROM32GB)
# 3      สมาร์ทโฟน (โทรศัพท์มือถือพร้อมระบบปฏิบัติการ)
# 4  จอแสดงผล TFT-LCD 24-bit (16 ล้านสี)- หน้าจอทรง...
# 5  ระบบเซ็นเซอร์ (Sensor)- ระบบตรวจสอบลายนิ้วมือ ...
# 6    มีสีให้เลือก (Colors) : Black, Red, Green, Blue
# 7                                      แบรนด์ ซัมซุง
# 8                         SKU 404422189_TH-784670279
# 9                                  มือถือ Smartphone
#
#                                         category_0_3  \
# 0                          โทรศัพท์มือถือและแท็บเล็ต
# 1                                        Smartphones
# 2  Samsung Galaxy Note 10 + (12/256 GB) ( โทรศัพท...
# 3                                ขนาดหน้าจอ 6.8 นิ้ว
# 4                                          Ram 12 GB
# 5                            ความจุ (Storage) 256 GB
# 6                       แบตเตอรี่ 4300 mAh (typical)
# 7                    มาตรฐานการกันน้ำและกันฝุ่น IP68
# 8                                      แบรนด์ ซัมซุง
# 9                         SKU 385536916_TH-749070165
#
#                                         category_0_4  \
# 0                          โทรศัพท์มือถือและแท็บเล็ต
# 1                                        Smartphones
# 2                           Samsung Galaxy A7 (2017)
# 3  ระบบเซ็นเซอร์ (Sensor)\r\n- ระบบตรวจสอบลายนิ้ว...
# 4  คุณสมบัติการกันน้ำ (Waterproof)\r\n- กันน้ำได้...
# 5  มีสีให้เลือก (Colors) : Black, Pink, Gold, Blu...
# 6  เทคโนโลยีการรับ/ส่งข้อมูล\r\n- 2G: EDGE/GPRS\r...
# 7                                    ใช้งาน Nano-SIM
# 8                                  รองรับ 2 ซิมการ์ด
# 9        ระบบปฏิบัติการ: Android 6.0.1 (Marshmallow)
#
#                                         category_0_5  \
# 0                          โทรศัพท์มือถือและแท็บเล็ต
# 1                                        Smartphones
# 2  Samsung Galaxy A9 (2018) 6 GB RAM 128 GB ROM 6...
# 3  จอแสดงผล Super AMOLED 24-bit (16 ล้านสี)Fullvi...
# 4  ระบบตรวจสอบลายนิ้วมือ (Fingerprint)ระบบจดจำใบห...
# 5  กล้องดิจิตอล (Main Camera) 24MP + (Ultra Wide ...
# 6                        กล้องหน้า ความละเอียด 24 MP
# 7                                            RAM 6GB
# 8                        หน่วยความจำตัวเครื่อง128 GB
# 9                                      แบรนด์ ซัมซุง
#
#                                         category_0_6  \
# 0                          โทรศัพท์มือถือและแท็บเล็ต
# 1                                        Smartphones
# 2  Samsung A30S (RAM 4GB / ROM 64 GB) มือ 1 ประกั...
# 3                             คุณสมบัติ Samsung A30S
# 4           จอแสดงผล Super AMOLED 24-bit (16 ล้านสี)
# 5  กว้าง 6.4 นิ้ว (แนวทะแยง) - ความละเอียด 720 x ...
# 6    ประเภทจอ Corning Gorilla Glass 3 ระบบปฏิบัติการ
# 7  Android 9.0 (Pie) หน่วยประมวลผล : Exynos 7885 ...
# 8                RAM 4GB - ROM 64GB การ์ดหน่วยความจำ
# 9                                microSD สูงสุด 1 TB
#
#                                         category_0_7  \
# 0                          โทรศัพท์มือถือและแท็บเล็ต
# 1                                        Smartphones
# 2  (มือ1 ศูนย์ไทย) Samsung Galaxy Note 10 Plus No...
# 3  Samsung Galaxy Note10 plus TH ประกันศูนย์ไทย 1...
# 4                                      แบรนด์ ซัมซุง
# 5                        SKU 599364278_TH-1176694583
# 6               ประเภทของการรับประกัน มีการรับประกัน
# 7             ระบบปฏิบัติการเวอร์ชัน Android 9.0 Pie
# 8                   Model samsung galaxy note10 plus
# 9                              ขนาดหน้าจอ (นิ้ว) 6.8
#
#                                       category_0_8  \
# 0                        โทรศัพท์มือถือและแท็บเล็ต
# 1                                      Smartphones
# 2  Samsung Galaxy A70 (8/128GB) ( โทรศัพท์มือถือ )
# 3                      Galaxy A70 (SM-A705FZBGTHL)
# 4                               สเปคเทพของเกมเมอร์
# 5          หน้าจอกว้าง 6.7" แบบ Infinity-U display
# 6                    3 กล้อง พร้อมเลนส์ Ultra Wide
# 7                                    แบรนด์ ซัมซุง
# 8                       SKU 309636084_TH-547152150
# 9             ประเภทของการรับประกัน มีการรับประกัน
#
#                                         category_0_9  ...  \
# 0                          โทรศัพท์มือถือและแท็บเล็ต  ...
# 1                                        Smartphones  ...
# 2  Smartphone โทรศัพท์มือถือ Samsung Galaxy A10S ...  ...
# 3                                      แบรนด์ ซัมซุง  ...
# 4                        SKU 571250946_TH-1048780375  ...
# 5                                  มือถือ Smartphone  ...
# 6                       ระยะเวลาการรับประกัน 1 เดือน  ...
# 7      ประเภทของการรับประกัน มีการรับประกันจากผู้ขาย  ...
# 8  ประเภทของแบตเตอรี่ แบตเตอรี่ชาร์จใหม่ได้และถอดได้  ...
# 9                                    สภาพสินค้า ใหม่  ...
#
#                                      category_33_234  \
# 0                                   สมาร์ทดีไวซ์ New
# 1                                           แก็ดเจ็ต
# 2                           เครื่องเล่นเกมคอมโซล New
# 3                                         คอนโซล New
# 4  GloryStar BASEUS PUBG ไฟฟรีเกมที่วางโทรศัพท์แผ...
# 5  แหล่งจ่ายไฟมือถือ 2000 mAh รองรับการชาร์จมือถื...
# 6  ใช้ได้กับ Xiaomi Huawei LG เกมที่วางโทรศัพท์ใน...
# 7             อุปกรณ์คอมพาทิเบิล: 4 "~ 6.5" มาร์ทโฟน
# 8                                   แบรนด์ GloryStar
# 9                         SKU 388218384_TH-754088901
#
#                                      category_33_235  \
# 0                                   สมาร์ทดีไวซ์ New
# 1                                           แก็ดเจ็ต
# 2                           เครื่องเล่นเกมคอมโซล New
# 3                                         คอนโซล New
# 4  GloryStar นาฬิกาติดตามตำแหน่งอัจฉริยะเด็กนาฬิก...
# 5                     1.3 นิ้ว HD IPS จอแสดงผลสีจริง
# 6  SOS โทรฉุกเฉิน, GPS, AGPS, LBS, กล้อง, gsensor...
# 7  นาฬิกาปลุกนาฬกิกาข้อมือ, การวางตำแหน่งออนไลน์,...
# 8  พยากรณ์อากาศ, การปิดระบบระยะไกล, App รองรับ An...
# 9                                   แบรนด์ GloryStar
#
#                                      category_33_236  \
# 0                                   สมาร์ทดีไวซ์ New
# 1                                           แก็ดเจ็ต
# 2                           เครื่องเล่นเกมคอมโซล New
# 3                                         คอนโซล New
# 4  GloryStar Joy-CON ตัวควบคุมเกมแป้นเกมส์จอยเกมส...
# 5  รุ่นนี้สำหรับคอนโซลเปลี่ยนค่ะ ตัวควบคุมมีฟังก์...
# 6  ตัวควบคุมประกอบด้วย 24 ปุ่มและ 2 3D ความแม่นยำ...
# 7                                   แบรนด์ GloryStar
# 8                         SKU 366718052_TH-716248719
# 9               ประเภทของการรับประกัน ไม่มีการประกัน
#
#                                      category_33_237  \
# 0                                   สมาร์ทดีไวซ์ New
# 1                                           แก็ดเจ็ต
# 2                           เครื่องเล่นเกมคอมโซล New
# 3                                         คอนโซล New
# 4  GloryStar คอนโซลเกมคลาสสิก 8 BitsProfessional ...
# 5  คอนโซลเกมคลาสสิก: 8 - bit เกมคอนโซล, เกมคลาสสิ...
# 6  การควบคุมแบบ Dual: จับเก้าหลุม, ใช้งานง่าย, เห...
# 7  620 เกมในตัว: 620 คลาสสิกในวัยเด็กทีวีวิดีโอเก...
# 8        ออกแบบสำหรับ: ระบบ Professional สำหรับ NES.
# 9  ภายในบรรจุภัณฑ์ประกอบด้วย: คอนโซลเกม + Dual + ...
#
#                                      category_33_238  \
# 0                                   สมาร์ทดีไวซ์ New
# 1                                           แก็ดเจ็ต
# 2                           เครื่องเล่นเกมคอมโซล New
# 3                                         คอนโซล New
# 4  GloryStar สีน้ำเงินแปรงเกมควบคุมเครื่องรับสัญญ...
# 5                    ปรับความกว้าง 50-85 มม. ช่วง ..
# 6  ความเข้ากันได้กว้างเหมาะสำหรับ Xiaomi Controll...
# 7                                   แบรนด์ GloryStar
# 8                         SKU 322894357_TH-613796747
# 9               ประเภทของการรับประกัน ไม่มีการประกัน
#
#                                      category_33_239  \
# 0                                   สมาร์ทดีไวซ์ New
# 1                                           แก็ดเจ็ต
# 2                           เครื่องเล่นเกมคอมโซล New
# 3                                         คอนโซล New
# 4  GloryStar Flysky รีโมทคอนโทรล FS-IT4S + IA4B 4...
# 5  2.4055 GHz ถึง 2.475 GHz กว้างแถบความถี่และ 14...
# 6  รอบทิศทางเสาอากาศกำลังส่งสูงครอบคลุมทุก frequn...
# 7  ID พิเศษ,ปรับปรุงเสถียรภาพของความถี่อัตโนมัติก...
# 8  Comsumption พลังงานต่ำชิ้นส่วนอิเล็กทรอนิกส์,ช...
# 9  การแสดงข้อมูลเรียลไทม์ของรุ่นเช่น voltadge ควา...
#
#                                      category_33_240  \
# 0                                   สมาร์ทดีไวซ์ New
# 1                                           แก็ดเจ็ต
# 2                           เครื่องเล่นเกมคอมโซล New
# 3                                         คอนโซล New
# 4       Top-Sky PlayStation 2 PS2 Memory Card - 32MB
# 5  Can be used to save game data for any PS2 game...
# 6  The memory card stores the character in a dura...
# 7  This portable memory card allows you to pause ...
# 8        Store all custom profiles/data on this card
# 9  Designed for the PS2, this memory card provide...
#
#                                      category_33_241  \
# 0                                   สมาร์ทดีไวซ์ New
# 1                                           แก็ดเจ็ต
# 2                           เครื่องเล่นเกมคอมโซล New
# 3                                         คอนโซล New
# 4      Top-Sky PlayStation 2 PS2 Memory Card - 256MB
# 5  Can be used to save game data for any PS2 game...
# 6  The memory card stores the character in a dura...
# 7  This portable memory card allows you to pause ...
# 8        Store all custom profiles/data on this card
# 9  Designed for the PS2, this memory card provide...
#
#                                      category_33_242  \
# 0                                   สมาร์ทดีไวซ์ New
# 1                                           แก็ดเจ็ต
# 2                           เครื่องเล่นเกมคอมโซล New
# 3                                         คอนโซล New
# 4      Top-Sky PlayStation 2 PS2 Memory Card - 128MB
# 5  Can be used to save game data for any PS2 game...
# 6  The memory card stores the character in a dura...
# 7  This portable memory card allows you to pause ...
# 8        Store all custom profiles/data on this card
# 9  Designed for the PS2, this memory card provide...
#
#                                      category_33_243
# 0                                   สมาร์ทดีไวซ์ New
# 1                                           แก็ดเจ็ต
# 2                           เครื่องเล่นเกมคอมโซล New
# 3                                         คอนโซล New
# 4  Top - Sky 3 - in - 1 PS4/PS4 Slim/PS4 เกมโปรที...
# 5  ที่ขาตั้งรองรับสำหรับ PS4 โฮสต์, และพอร์ตระบาย...
# 6  คู่ชาร์จที่ด้านบนของที่ยึดผู้ถือสามารถเรียกเก็...
# 7  ประหยัดพื้นที่ช่วยให้สามารถ PS4 ด้วย Dual ควบค...
# 8  ช่วยให้มั่นใจได้ว่าประหยัดพื้นที่และสำหรับ PS4...
# 9  จอยควบคุมเกม, แผ่นดิสก์เกมและโฮสต์จะรวม, หลีกเ...
#
# [10 rows x 5617 columns]

# %%
# Filter
data_01 = data.filter(regex ='category_[01]_[0-9]+')

# %% [markdown]
# # Clean text

# %%
file_name2 = './Data/attributes_category1.txt'
with open(file_name2, 'r', encoding='utf-8') as f:
    attr_fix = f.read().splitlines()

# %%
# clean the text and prepre some attribute
def clean_text_category1(msg):
    msg = str(msg).lower()
    msg = re.sub(r"smartphone[s]?","สมาร์ทโฟน",str(msg))
    
    if str(msg)=='โทรศัพท์มือถือและแท็บเล็ต':
        msg = re.sub(r"(โทรศัพท์มือถือและแท็บเล็ต)",r"ประเภท \1",str(msg))
    elif (str(msg)=='สมาร์ทโฟน') | (str(msg)=='แท็บเล็ต'):
        msg = re.sub(r"(สมาร์ทโฟน|แท็บเล็ต)",r"ประเภทย่อย \1",str(msg))
    elif re.match("[0-9]\*[0-9]",str(msg)):
        msg = re.sub(r"\*","x",str(msg))
    
    msg = re.sub(r"\&","และ",str(msg))
    msg = re.sub(r"sku","sku ",str(msg))
    msg = re.sub(r"\%","เปอร์เซนต์ ",str(msg))
    msg = re.sub(r"brand","แบรนด์ ",str(msg))
    msg = re.sub(r"model","โมเดล ",str(msg))
    msg = re.sub(r"[\W]จอแสดงผล\s","หน้าจอแสดงผล ",str(msg))
    msg = re.sub(r"\sos\:?\s","ระบบปฏิบัติการ ",str(msg))
    msg = re.sub(r"ความจุ\s*\(storage\)","ความจุที่เก็บข้อมูล ",str(msg))
    msg = re.sub(r"[\d+\s+]mp|เมกะพิกเซล\s?","ล้านพิกเซล ",str(msg))
    msg = re.sub(r"\s+แรม\s?"," ram ",str(msg))
    msg = re.sub(r"\s+รอม\s?"," rom ",str(msg))
    msg = re.sub(r"ฮาร์ดดิสก์\s?|hard\s?disk\s?"," hdd ",str(msg))
    msg = re.sub(r"display","จอแสดงผล ",str(msg))
    msg = re.sub(r"weight?","น้ำหนัก ",str(msg))
    msg = re.sub(r"[b]attery\s?[c]apacity","ความจุแบตเตอรี่ ",str(msg))
    msg = re.sub(r"แบต\s?^เตอรี่","แบตเตอรี่ ",str(msg))
    msg = re.sub(r"\฿,"," บาท ",str(msg))
    msg = re.sub(r"[\d\s]*มิลลิเมตร|\smm\.?|millimeter\.?"," มม. ",str(msg))
    msg = re.sub(r"[\d\s]*เซนติเมตร|\scm\.?|centimeter\.?"," ซม. ",str(msg))
    msg = re.sub(r"[\,]","",str(msg))
    msg = re.sub(r"[^a-z0-9ก-๙\.\s]"," ", str(msg))
    msg = re.sub(r"\s+"," ",str(msg))
    if any(ext in msg for ext in attr_fix):
        return msg
    else:
        return

# %%
# function for defining attribute of product
def define_attr(txt):
    p = re.compile('(ประเภท\s|ประเภทย่อย|แบรนด์|รุ่น|กล้องหน้า|กล้องหลัง|โมเดล|รูรับแสงขนาด|\
                ขนาดหน้าจอ|หน่วยประมวลผล|แบตเตอรี่|น้ำหนัก|sku|ระยะเวลาการรับประกัน|\
                ระบบปฏิบัติการ|ความจุแบตเตอรี่|หน้าจอแสดงผล|ram|rom|ความจุ|\
                มาตรฐานการกันน้ำและกันฝุ่น|รองรับ|gpu|cpu|ความละเอียด|หน้าจอ|ขนาด)', re.VERBOSE)
    #match = re.match(r"", str(txt))
    txt = re.sub(p,r"|\1|",str(txt))
    
    return txt

# %%
# Cleaning text with clean_text function and keep in dict
data_clean = {}
for key,value in data_01.iteritems():
    tmp = [clean_text_category1(txt) for txt in value if not txt == '-']
    tmp = [i for i in tmp if i] 
    data_clean[key] = tmp

# %%
# Show some of data in dict
dict(list(data_clean.items())[0:10])
# Out:
# {'category_0_0': ['ประเภท โทรศัพท์มือถือและแท็บเล็ต',
#   'ประเภทย่อย สมาร์ทโฟน',
#   'แบตอึดอยู่นาน สนุกได้ทั้งวัน กับความจุ 6000 mah และสามารถชาร์จแบตเร็ว ด้วย fast charging',
#   'ระบบกล้องหลัง 3 ตัว ที่มีกล้องชัดสูงสุดถึง 48ล้านพิกเซล มาพร้อมกับเลนส์มุมกว้างพิเศษ ultra wide',
#   'หน้าจอแสดงผล super amoled infinity u ขนาด 6.4 นิ้ว',
#   'แบรนด์ ซัมซุง',
#   'sku 480942616 th 870640886',
#   'โมเดล galaxy m30s 4 64gb ',
#   'ระยะเวลาการรับประกัน 1 ปี'],
#  'category_0_1': ['ประเภท โทรศัพท์มือถือและแท็บเล็ต',
#   'ประเภทย่อย สมาร์ทโฟน',
#   'รองรับ 2 ซิม nano sim',
#   'หน่วยประมวลผล exynos 9610 quad 2.3 ghz quad 1.7 ghz',
#   'ระบบปฏิบัติการ android',
#   'หน่วยความจำภายใน 64gb เพิ่ม micro sd รองรับสูงสุด 512 gb',
#   'หน้าจอ 6.4 นิ้ว ความละเอียด 1080 x 2340 พิกเซล fhd ',
#   'กล้องหลัง 3 เลนส์ 48 ล้านพิกเซล f 2.0 5 ล้านพิกเซล f 2.2 bokeh 8 ล้านพิกเซล f 2.4 ultrawide แฟลช led',
#   'กล้องหน้า 32 ล้านพิกเซล f 2.0',
#   'แบตเตอรี่ 4000 mah',
#   'ขนาด 158.5 x 74.5 x 7.7 มม. ',
#   'น้ำหนัก 169 g',
#   'แบรนด์ ซัมซุง',
#   'sku 593772364 th 1113954823',
#   'ระยะเวลาการรับประกัน 1 ปี',
#   'กล้องหน้า ล้านพิกเซล 7ล้านพิกเซล ขึ้นไป',
#   'ระบบปฏิบัติการเวอร์ชัน android 9.0 pie',
#   'โมเดล a50s',
#   'ขนาดหน้าจอ นิ้ว 6.4',
#   'กล้องด้านหลัง 2ล้านพิกเซล ขึ้นไป',
#   'ความจุแบตเตอรี่ 1000 mah ถึง 5000 mah'],
#  'category_0_2': ['ประเภท โทรศัพท์มือถือและแท็บเล็ต',
#   'ประเภทย่อย สมาร์ทโฟน',
#   'สมาร์ทโฟน โทรศัพท์มือถือพร้อมระบบปฏิบัติการ ',
#   'จอแสดงผล tft lcd 24 bit 16 ล้านสี หน้าจอทรงหยดน้ำ รูปตัว v infinity v กว้าง 6.2 นิ้ว แนวทะแยง ความละเอียด 1520 x 720 พิกเซล',
#   'แบรนด์ ซัมซุง',
#   'sku 404422189 th 784670279',
#   'มือถือ สมาร์ทโฟน',
#   'ระยะเวลาการรับประกัน 1 ปี',
#   'ระบบปฏิบัติการ android 9.0 pie',
#   'กล้องหน้า ล้านพิกเซล 7ล้านพิกเซล ขึ้นไป',
#   'ระบบปฏิบัติการเวอร์ชัน android 9.0 pie',
#   'โมเดล samsung galaxy a10s ram2gb rom32gb ',
#   'ขนาดหน้าจอ นิ้ว 6.2',
#   'กล้องด้านหลัง 11 1ล้านพิกเซล ',
#   'ความจุแบตเตอรี่ 1000 mah ถึง 5000 mah'],
#  'category_0_3': ['ประเภท โทรศัพท์มือถือและแท็บเล็ต',
#   'ประเภทย่อย สมาร์ทโฟน',
#   'ขนาดหน้าจอ 6.8 นิ้ว',
#   'ความจุที่เก็บข้อมูล 256 gb',
#   'แบตเตอรี่ 4300 mah typical ',
#   'มาตรฐานการกันน้ำและกันฝุ่น ip68',
#   'แบรนด์ ซัมซุง',
#   'sku 385536916 th 749070165',
#   'โมเดล galaxy note 10 ',
#   'ขนาดหน้าจอ นิ้ว 6.8',
#   'ระยะเวลาการรับประกัน 1 ปี'],
#  'category_0_4': ['ประเภท โทรศัพท์มือถือและแท็บเล็ต',
#   'ประเภทย่อย สมาร์ทโฟน',
#   'ระบบเซ็นเซอร์ sensor ระบบตรวจสอบลายนิ้วมือ fingerprint ระบบหมุนภาพอัตโนมัติ accelerometer ระบบเปิด ปิดหน้าจออัตโนมัติขณะสนทนา proximity ระบบตรวจจับคลื่นแม่เหล็ก geomagnetic ระบบเซนเซอร์หมุนภาพ gyroscope ระบบวัดความกดอากาศ barometer ',
#   'รองรับ 2 ซิมการ์ด',
#   'ระบบปฏิบัติการ android 6.0.1 marshmallow ',
#   'หน่วยประมวลผล octa core ความเร็ว 1.9 ghz',
#   'bluetooth 4.2 รองรับชุดหูฟังสเตอริโอ a2dp bluetooth stereo ',
#   'รองรับ nfc near field communication ',
#   'usb type c',
#   'กล้องดิจิตอล 16 ล้านพิกเซล digital camera รูรับแสงขนาด 1.9 ไฟแฟลช led โฟกัสอัตโนมัติ auto focus แตะเลือกจุดโฟกัส touch focus ค้นหาใบหน้าอัตโนมัติ face detection โหมดถ่ายภาพพาโนราม่า panorama ',
#   'กล้องหน้า front camera ความละเอียด 16ล้านพิกเซล รูรับแสงขนาด 1.9',
#   'เครื่องเล่นวีดีโอ video player รูปแบบไฟล์ ล้านพิกเซล eg 4 wmv h.264 h.263 รองรับวีดีโอจาก youtube ',
#   'สนับสนุน gmail google search'],
#  'category_0_5': ['ประเภท โทรศัพท์มือถือและแท็บเล็ต',
#   'ประเภทย่อย สมาร์ทโฟน',
#   'samsung galaxy a9 2018 6 gb ram 128 gb rom 6.3 นิ้ว 5 กล้อง สูงสุด 24ล้านพิกเซล tetra cell f1.7 โทรศัพท์มือถือ ',
#   'จอแสดงผล super amoled 24 bit 16 ล้านสี fullview จอแสดงผล กว้าง 6.3 นิ้ว',
#   'กล้องดิจิตอล main camera 2ล้านพิกเซล ultra wide camera ล้านพิกเซล telephoto camera 1ล้านพิกเซล depth camera ล้านพิกเซล fourth camera รูรับแสงขนาด 1.7',
#   'กล้องหน้า ความละเอียด 24ล้านพิกเซล ',
#   'แบรนด์ ซัมซุง',
#   'sku 265390897 th 412154584',
#   'โมเดล galaxy a9 2018 ',
#   'ระยะเวลาการรับประกัน 1 ปี'],
#  'category_0_6': ['ประเภท โทรศัพท์มือถือและแท็บเล็ต',
#   'ประเภทย่อย สมาร์ทโฟน',
#   'จอแสดงผล super amoled 24 bit 16 ล้านสี ',
#   'กว้าง 6.4 นิ้ว แนวทะแยง ความละเอียด 720 x 1560 พิกเซล 268 ppi ',
#   'ประเภทจอ corning gorilla glass 3 ระบบปฏิบัติการ',
#   'android 9.0 pie หน่วยประมวลผล exynos 7885 octa core ความเร็ว 1.8 mhz หน่วยความจำ',
#   'กล้องดิจิตอล 2ล้านพิกเซล 8ล้านพิกเซล ultrawide 5ล้านพิกเซล depth sensor triple camera รูรับแสงขนาด 1.7 ไฟแฟลช led โหมดถ่ายภาพช่วงการรับแสงสูง hdr ',
#   'กล้องหน้า front camera ความละเอียด 16ล้านพิกเซล รูรับแสงขนาด 2.0',
#   'เชื่อมต่อไร้สายระหว่างอุปกรณ์โดยตรง wi fi direct bluetooth 5.0 type c usb 2.0 ช่องเสียบชุดหูฟัง 3. มม. ',
#   'ใช้งาน nano sim รองรับ 2 ซิมการ์ด',
#   'ระบบเซ็นเซอร์ sensor ระบบสแกนลายนิ้วมือใต้หน้าจอ fingerprint under จอแสดงผล ตรวจจับความเคลื่อนไหวของตัวเครื่อง accelerometer ระบบเปิด ปิดหน้าจออัตโนมัติขณะสนทนา proximity ',
#   'แบตเตอรี่มาตรฐาน li pol 4000 mah standard battery ',
#   'แบรนด์ ซัมซุง',
#   'sku 594352438 th 1115888431',
#   'กล้องหน้า ล้านพิกเซล 16ล้านพิกเซล ',
#   'โมเดล samsung a30s',
#   'กล้องด้านหลัง 2ล้านพิกเซล ขึ้นไป',
#   'ระยะเวลาการรับประกัน 1 ปี',
#   'ความจุแบตเตอรี่ 1000 mah ถึง 5000 mah'],
#  'category_0_7': ['ประเภท โทรศัพท์มือถือและแท็บเล็ต',
#   'ประเภทย่อย สมาร์ทโฟน',
#   'แบรนด์ ซัมซุง',
#   'sku 599364278 th 1176694583',
#   'ระบบปฏิบัติการเวอร์ชัน android 9.0 pie',
#   'โมเดล samsung galaxy note10 plus',
#   'ขนาดหน้าจอ นิ้ว 6.8',
#   'ระยะเวลาการรับประกัน 1 ปี'],
#  'category_0_8': ['ประเภท โทรศัพท์มือถือและแท็บเล็ต',
#   'ประเภทย่อย สมาร์ทโฟน',
#   'หน้าจอกว้าง 6.7 แบบ infinity u จอแสดงผล ',
#   '3 กล้อง พร้อมเลนส์ ultra wide',
#   'แบรนด์ ซัมซุง',
#   'sku 309636084 th 547152150',
#   'โมเดล a70 8 128gb ',
#   'ระยะเวลาการรับประกัน 1 ปี'],
#  'category_0_9': ['ประเภท โทรศัพท์มือถือและแท็บเล็ต',
#   'ประเภทย่อย สมาร์ทโฟน',
#   'สมาร์ทโฟน โทรศัพท์มือถือ samsung galaxy a10s sm a107m ขนาดหน้าจอ 6.2 นิ้ว ram 2 rom 32 gb สีน้ำเงิน ',
#   'แบรนด์ ซัมซุง',
#   'sku 571250946 th 1048780375',
#   'มือถือ สมาร์ทโฟน',
#   'ระยะเวลาการรับประกัน 1 เดือน',
#   'ประเภทของแบตเตอรี่ แบตเตอรี่ชาร์จใหม่ได้และถอดได้',
#   'กล้องหน้า ล้านพิกเซล 7ล้านพิกเซล ขึ้นไป',
#   'โมเดล สมาร์ทโฟน โทรศัพท์มือถือ samsung galaxy a10s sm a107m ขนาดหน้าจอ 6.2 นิ้ว ram 2 rom 32 gb สีน้ำเงิน ',
#   'ประเภทหน้าจอ lcd',
#   'กล้องด้านหลัง 11 1ล้านพิกเซล ',
#   'ความละเอียดวิดีโอ 1080p',
#   'ความจุแบตเตอรี่ 1000 mah ถึง 5000 mah']}

# %%
# Mark attribute with '|'
attr_mark = {}
for key,value in data_clean.items():
    tmp = [define_attr(txt) for txt in value] 
    tmp = [re.sub(r"\|\|","",str(t)) for t in tmp]
    tmp = [i for i in tmp if re.search(r"\|",i)] 
    attr_mark[key] = tmp

# %%
attr_mark
# Out:
# {'category_0_0': ['|ประเภท |โทรศัพท์มือถือและแท็บเล็ต',
#   '|ประเภทย่อย| สมาร์ทโฟน',
#   'แบตอึดอยู่นาน สนุกได้ทั้งวัน กับ|ความจุ| 6000 mah และสามารถชาร์จแบตเร็ว ด้วย fast charging',
#   'ระบบ|กล้องหลัง| 3 ตัว ที่มีกล้องชัดสูงสุดถึง 48ล้านพิกเซล มาพร้อมกับเลนส์มุมกว้างพิเศษ ultra wide',
#   '|หน้าจอแสดงผล| super amoled infinity u |ขนาด| 6.4 นิ้ว',
#   '|แบรนด์| ซัมซุง',
#   '|sku| 480942616 th 870640886',
#   '|โมเดล| galaxy m30s 4 64gb ',
#   '|ระยะเวลาการรับประกัน| 1 ปี'],
#  'category_0_1': ['|ประเภท |โทรศัพท์มือถือและแท็บเล็ต',
#   '|ประเภทย่อย| สมาร์ทโฟน',
#   '|รองรับ| 2 ซิม nano sim',
#   '|หน่วยประมวลผล| exynos 9610 quad 2.3 ghz quad 1.7 ghz',
#   '|ระบบปฏิบัติการ| android',
#   'หน่วยความจำภายใน 64gb เพิ่ม micro sd |รองรับ|สูงสุด 512 gb',
#   '|หน้าจอ| 6.4 นิ้ว |ความละเอียด| 1080 x 2340 พิกเซล fhd ',
#   '|กล้องหลัง| 3 เลนส์ 48 ล้านพิกเซล f 2.0 5 ล้านพิกเซล f 2.2 bokeh 8 ล้านพิกเซล f 2.4 ultrawide แฟลช led',
#   '|กล้องหน้า| 32 ล้านพิกเซล f 2.0',
#   '|แบตเตอรี่| 4000 mah',
#   '|ขนาด| 158.5 x 74.5 x 7.7 มม. ',
#   '|น้ำหนัก| 169 g',
#   '|แบรนด์| ซัมซุง',
#   '|sku| 593772364 th 1113954823',
#   '|ระยะเวลาการรับประกัน| 1 ปี',
#   '|กล้องหน้า| ล้านพิกเซล 7ล้านพิกเซล ขึ้นไป',
#   '|ระบบปฏิบัติการ|เวอร์ชัน android 9.0 pie',
#   '|โมเดล| a50s',
#   '|ขนาดหน้าจอ| นิ้ว 6.4',
#   '|ความจุแบตเตอรี่| 1000 mah ถึง 5000 mah'],
#  'category_0_2': ['|ประเภท |โทรศัพท์มือถือและแท็บเล็ต',
#   '|ประเภทย่อย| สมาร์ทโฟน',
#   'สมาร์ทโฟน โทรศัพท์มือถือพร้อม|ระบบปฏิบัติการ| ',
#   'จอแสดงผล tft lcd 24 bit 16 ล้านสี |หน้าจอ|ทรงหยดน้ำ รูปตัว v infinity v กว้าง 6.2 นิ้ว แนวทะแยง |ความละเอียด| 1520 x 720 พิกเซล',
#   '|แบรนด์| ซัมซุง',
#   '|sku| 404422189 th 784670279',
#   '|ระยะเวลาการรับประกัน| 1 ปี',
#   '|ระบบปฏิบัติการ| android 9.0 pie',
#   '|กล้องหน้า| ล้านพิกเซล 7ล้านพิกเซล ขึ้นไป',
#   '|ระบบปฏิบัติการ|เวอร์ชัน android 9.0 pie',
#   '|โมเดล| samsung galaxy a10s |ram|2gb |rom|32gb ',
#   '|ขนาดหน้าจอ| นิ้ว 6.2',
#   '|ความจุแบตเตอรี่| 1000 mah ถึง 5000 mah'],
#  'category_0_3': ['|ประเภท |โทรศัพท์มือถือและแท็บเล็ต',
#   '|ประเภทย่อย| สมาร์ทโฟน',
#   '|ขนาดหน้าจอ| 6.8 นิ้ว',
#   '|ความจุ|ที่เก็บข้อมูล 256 gb',
#   '|แบตเตอรี่| 4300 mah typical ',
#   '|มาตรฐานการกันน้ำและกันฝุ่น| ip68',
#   '|แบรนด์| ซัมซุง',
#   '|sku| 385536916 th 749070165',
#   '|โมเดล| galaxy note 10 ',
#   '|ขนาดหน้าจอ| นิ้ว 6.8',
#   '|ระยะเวลาการรับประกัน| 1 ปี'],
#  'category_0_4': ['|ประเภท |โทรศัพท์มือถือและแท็บเล็ต',
#   '|ประเภทย่อย| สมาร์ทโฟน',
#   'ระบบเซ็นเซอร์ sensor ระบบตรวจสอบลายนิ้วมือ fingerprint ระบบหมุนภาพอัตโนมัติ accele|rom|eter ระบบเปิด ปิด|หน้าจอ|อัตโนมัติขณะสนทนา proximity ระบบตรวจจับคลื่นแม่เหล็ก geomagnetic ระบบเซนเซอร์หมุนภาพ gyroscope ระบบวัดความกดอากาศ ba|rom|eter ',
#   '|รองรับ| 2 ซิมการ์ด',
#   '|ระบบปฏิบัติการ| android 6.0.1 marshmallow ',
#   '|หน่วยประมวลผล| octa core ความเร็ว 1.9 ghz',
#   'bluetooth 4.2 |รองรับ|ชุดหูฟังสเตอริโอ a2dp bluetooth stereo ',
#   '|รองรับ| nfc near field communication ',
#   'กล้องดิจิตอล 16 ล้านพิกเซล digital camera |รูรับแสงขนาด| 1.9 ไฟแฟลช led โฟกัสอัตโนมัติ auto focus แตะเลือกจุดโฟกัส touch focus ค้นหาใบหน้าอัตโนมัติ face detection โหมดถ่ายภาพพาโนราม่า pano|ram|a ',
#   '|กล้องหน้า| front camera |ความละเอียด| 16ล้านพิกเซล |รูรับแสงขนาด| 1.9',
#   'เครื่องเล่นวีดีโอ video player รูปแบบไฟล์ ล้านพิกเซล eg 4 wmv h.264 h.263 |รองรับ|วีดีโอจาก youtube '],
#  'category_0_5': ['|ประเภท |โทรศัพท์มือถือและแท็บเล็ต',
#   '|ประเภทย่อย| สมาร์ทโฟน',
#   'samsung galaxy a9 2018 6 gb |ram| 128 gb |rom| 6.3 นิ้ว 5 กล้อง สูงสุด 24ล้านพิกเซล tetra cell f1.7 โทรศัพท์มือถือ ',
#   'กล้องดิจิตอล main camera 2ล้านพิกเซล ultra wide camera ล้านพิกเซล telephoto camera 1ล้านพิกเซล depth camera ล้านพิกเซล fourth camera |รูรับแสงขนาด| 1.7',
#   '|กล้องหน้า| |ความละเอียด| 24ล้านพิกเซล ',
#   '|แบรนด์| ซัมซุง',
#   '|sku| 265390897 th 412154584',
#   '|โมเดล| galaxy a9 2018 ',
#   '|ระยะเวลาการรับประกัน| 1 ปี'],
#  'category_0_6': ['|ประเภท |โทรศัพท์มือถือและแท็บเล็ต',
#   '|ประเภทย่อย| สมาร์ทโฟน',
#   'กว้าง 6.4 นิ้ว แนวทะแยง |ความละเอียด| 720 x 1560 พิกเซล 268 ppi ',
#   'ประเภทจอ corning gorilla glass 3 |ระบบปฏิบัติการ|',
#   'android 9.0 pie |หน่วยประมวลผล| exynos 7885 octa core ความเร็ว 1.8 mhz หน่วยความจำ',
#   'กล้องดิจิตอล 2ล้านพิกเซล 8ล้านพิกเซล ultrawide 5ล้านพิกเซล depth sensor triple camera |รูรับแสงขนาด| 1.7 ไฟแฟลช led โหมดถ่ายภาพช่วงการรับแสงสูง hdr ',
#   '|กล้องหน้า| front camera |ความละเอียด| 16ล้านพิกเซล |รูรับแสงขนาด| 2.0',
#   'ใช้งาน nano sim |รองรับ| 2 ซิมการ์ด',
#   'ระบบเซ็นเซอร์ sensor ระบบสแกนลายนิ้วมือใต้|หน้าจอ| fingerprint under จอแสดงผล ตรวจจับความเคลื่อนไหวของตัวเครื่อง accele|rom|eter ระบบเปิด ปิด|หน้าจอ|อัตโนมัติขณะสนทนา proximity ',
#   '|แบตเตอรี่|มาตรฐาน li pol 4000 mah standard battery ',
#   '|แบรนด์| ซัมซุง',
#   '|sku| 594352438 th 1115888431',
#   '|กล้องหน้า| ล้านพิกเซล 16ล้านพิกเซล ',
#   '|โมเดล| samsung a30s',
#   '|ระยะเวลาการรับประกัน| 1 ปี',
#   '|ความจุแบตเตอรี่| 1000 mah ถึง 5000 mah'],
#  'category_0_7': ['|ประเภท |โทรศัพท์มือถือและแท็บเล็ต',
#   '|ประเภทย่อย| สมาร์ทโฟน',
#   '|แบรนด์| ซัมซุง',
#   '|sku| 599364278 th 1176694583',
#   '|ระบบปฏิบัติการ|เวอร์ชัน android 9.0 pie',
#   '|โมเดล| samsung galaxy note10 plus',
#   '|ขนาดหน้าจอ| นิ้ว 6.8',
#   '|ระยะเวลาการรับประกัน| 1 ปี'],
#  'category_0_8': ['|ประเภท |โทรศัพท์มือถือและแท็บเล็ต',
#   '|ประเภทย่อย| สมาร์ทโฟน',
#   '|หน้าจอ|กว้าง 6.7 แบบ infinity u จอแสดงผล ',
#   '|แบรนด์| ซัมซุง',
#   '|sku| 309636084 th 547152150',
#   '|โมเดล| a70 8 128gb ',
#   '|ระยะเวลาการรับประกัน| 1 ปี'],
#  'category_0_9': ['|ประเภท |โทรศัพท์มือถือและแท็บเล็ต',
#   '|ประเภทย่อย| สมาร์ทโฟน',
#   'สมาร์ทโฟน โทรศัพท์มือถือ samsung galaxy a10s sm a107m |ขนาดหน้าจอ| 6.2 นิ้ว |ram| 2 |rom| 32 gb สีน้ำเงิน ',
#   '|แบรนด์| ซัมซุง',
#   '|sku| 571250946 th 1048780375',
#   '|ระยะเวลาการรับประกัน| 1 เดือน',
#   'ประเภทของ|แบตเตอรี่| |แบตเตอรี่|ชาร์จใหม่ได้และถอดได้',
#   '|กล้องหน้า| ล้านพิกเซล 7ล้านพิกเซล ขึ้นไป',
#   '|โมเดล| สมาร์ทโฟน โทรศัพท์มือถือ samsung galaxy a10s sm a107m |ขนาดหน้าจอ| 6.2 นิ้ว |ram| 2 |rom| 32 gb สีน้ำเงิน ',
#   'ประเภท|หน้าจอ| lcd',
#   '|ความละเอียด|วิดีโอ 1080p',
#   '|ความจุแบตเตอรี่| 1000 mah ถึง 5000 mah'],
#  'category_0_10': ['|ประเภท |โทรศัพท์มือถือและแท็บเล็ต',
#   '|ประเภทย่อย| สมาร์ทโฟน',
#   'สมาร์ทโฟน โทรศัพท์มือถือพร้อม|ระบบปฏิบัติการ| ',
#   'จอแสดงผล super amoled 24 bit 16 ล้านสี กว้าง 5.2 นิ้ว แนวทะแยง |ความละเอียด| 1080 x 1920 พิกเซล ประเภทจอ |หน้าจอ|กระจกแข็ง ประเภทจอ ระบบป้องกัน ฝุ่นละออง resistance to dust ',
#   'ระบบเซ็นเซอร์ sensor ระบบตรวจสอบลายนิ้วมือ fingerprint ระบบหมุนภาพอัตโนมัติ accele|rom|eter ระบบเปิด ปิด|หน้าจอ|อัตโนมัติขณะสนทนา proximity ระบบตรวจจับคลื่นแม่เหล็ก geomagnetic ระบบเซนเซอร์หมุนภาพ gyroscope ระบบวัดความกดอากาศ ba|rom|eter ',
#   '|รองรับ| 2 ซิมการ์ด',
#   '|ระบบปฏิบัติการ| android 6.0.1 marshmallow ',
#   '|หน่วยประมวลผล| octa core ความเร็ว 1.9 ghz',
#   'bluetooth 4.2 |รองรับ|ชุดหูฟังสเตอริโอ a2dp bluetooth stereo ',
#   '|รองรับ| nfc near field communication ',
#   'กล้องดิจิตอล 16 ล้านพิกเซล digital camera |รูรับแสงขนาด| 1.9 ไฟแฟลช led โฟกัสอัตโนมัติ auto focus แตะเลือกจุดโฟกัส touch focus โหมดถ่ายภาพพาโนราม่า pano|ram|a ',
#   '|กล้องหน้า| front camera |ความละเอียด| 16ล้านพิกเซล |รูรับแสงขนาด| 1.9',
#   'เครื่องเล่นวีดีโอ video player รูปแบบไฟล์ ล้านพิกเซล eg 4 wmv h.264 h.263 |รองรับ|วีดีโอจาก youtube '],
#  'category_0_11': ['|ประเภท |โทรศัพท์มือถือและแท็บเล็ต',
#   '|ประเภทย่อย| สมาร์ทโฟน',
#   '|หน้าจอแสดงผล|แบบ super amoled |ขนาด| 5.2 นิ้ว',
#   '|ความละเอียด|ระดับ full hd 1080p 1080x1920 พิกเซล ',
#   'หน่วยความจำแรม |ram| |ขนาด| 3 gb',
#   'หน่วยความจำภายใน|ขนาด| 32 gb',
#   'กล้องด้านหลัง|ความละเอียด| 16 ล้านพิกเซล',
#   '|แบรนด์| ซัมซุง',
#   '|sku| sa861elaa8nxs2anth 17866375',
#   '|ระยะเวลาการรับประกัน| 1 ปี',
#   '|ระบบปฏิบัติการ| android',
#   '|กล้องหน้า| ล้านพิกเซล 7ล้านพิกเซล ขึ้นไป',
#   '|ระบบปฏิบัติการ|เวอร์ชัน marshmallow',
#   '|โมเดล| samsung galaxy a5 2017 gold',
#   'ประเภท|หน้าจอ| amoled',
#   '|ขนาดหน้าจอ| นิ้ว 5.2'],
#  'category_0_12': ['|ประเภท |โทรศัพท์มือถือและแท็บเล็ต',
#   '|ประเภทย่อย| สมาร์ทโฟน',
#   '|หน้าจอความละเอียด|สูงระดับ dynamic amoled ให้สีสันและความคมชัดเสมือนจอทีวีระดับพรีเมี่ยม',
#   '|กล้องหลัง| 2ตัวพร้อมระบบถ่ายภาพอัจฉริยะ',
#   '|แบรนด์| ซัมซุง',
#   '|sku| 526004055 th 942110374',
#   '|โมเดล| s10e 6 128gb ',
#   '|ระยะเวลาการรับประกัน| 1 ปี'],
#  'category_0_13': ['|ประเภท |โทรศัพท์มือถือและแท็บเล็ต',
#   '|ประเภทย่อย| สมาร์ทโฟน',
#   'สมาร์ทโฟน โทรศัพท์มือถือ samsung galaxy a10s sm a107m |ขนาดหน้าจอ| 6.2 นิ้ว |ram| 2 |rom| 32 gb สีเขียว ',
#   '|แบรนด์| ซัมซุง',
#   '|sku| 571320012 th 1048806072',
#   '|ระยะเวลาการรับประกัน| 1 เดือน',
#   'ประเภทของ|แบตเตอรี่| |แบตเตอรี่|ชาร์จใหม่ได้และถอดได้',
#   '|กล้องหน้า| ล้านพิกเซล 7ล้านพิกเซล ขึ้นไป',
#   '|โมเดล| สมาร์ทโฟน โทรศัพท์มือถือ samsung galaxy a10s sm a107m |ขนาดหน้าจอ| 6.2 นิ้ว |ram| 2 |rom| 32 gb สีเขียว ',
#   'ประเภท|หน้าจอ| lcd',
#   '|ความละเอียด|วิดีโอ 1080p',
#   '|ความจุแบตเตอรี่| 1000 mah ถึง 5000 mah'],
#  'category_0_14': ['|ประเภท |โทรศัพท์มือถือและแท็บเล็ต',
#   '|ประเภทย่อย| สมาร์ทโฟน',
#   '|ขนาด|เครื่อง 156.9 x 75.8 x 7.8 มม. หนัก 168 กรัม |หน้าจอ| pls tft lcd |ความละเอียด| 720 x 1520 พิกเซล hd |ขนาด| 6.2 นิ้ว',
#   'ชิปเซต mediatek mt6762 helio p22 ประมวลผล octa core 2.0ghz cortex a53 ใช้ |gpu| powervr ge8320',
#   'หน่วยความจำ |ram| 2gb |rom| 32gb |รองรับ|หน่วยความจำเสริม microsd card สูงสุด 512gb',
#   '|กล้องหลัง|เลนส์คู่ กล้องหลัก 13 ล้านพิกเซล รูรับแสง f 1.8 มีระบบออโต้โฟกัส',
#   '|รองรับ|การบันทึกวีดีโอสูงสุด fhd 1920 x 1080 30fps',
#   '|กล้องหน้า| 8 ล้านพิกเซล รูรับแสง f 2.0 |รองรับ|การทำงานสองซิม',
#   'สัญญานเครือข่ายที่|รองรับ| 2g gsm 3g wcdma 4g lte fdd 4g lte tdd',
#   '|รองรับ| wi fi 802.11 b g n 2.4ghz wi fi direct สนับสนุน bluetooth 4.2',
#   '|แบตเตอรี่ขนาด| 4000mah',
#   '|ระบบปฏิบัติการ| android 9 pie oneui ',
#   '|แบรนด์| ซัมซุง',
#   '|sku| 594306208 th 1115720937',
#   '|กล้องหน้า| ล้านพิกเซล 7ล้านพิกเซล ขึ้นไป',
#   '|โมเดล| samsung a10s',
#   '|ระยะเวลาการรับประกัน| 1 ปี',
#   '|ความจุแบตเตอรี่| 1000 mah ถึง 5000 mah'],
#  'category_0_15': ['samsung galaxy a30 4 gb |ram| 64 gb |rom| 6.4 นิ้ว 3 กล้อง สูงสุด 16ล้านพิกเซล ff f2.0 โทรศัพท์มือถือ ฿ 5990.00 ฿ 7290.00 18เปอร์เซนต์ ',
#   ' ซื้อ 1 แถม 1 ฟรี สำหรับ vivo v9 v11 v11i v7 y15pro y12 หลาย|รุ่น| non slip soft 3d คาร์บอนไฟเบอร์ฝาหลังฟิล์มป้องกันด้านหลังสติกเกอร์ป้องกัน ฿ 55.00 ฿ 92.00 40เปอร์เซนต์ '],
#  'category_0_16': ['|ประเภท |โทรศัพท์มือถือและแท็บเล็ต',
#   '|ประเภทย่อย| สมาร์ทโฟน',
#   'samsung galaxy s10 8 gb |ram| 128 gb |rom| 6.1 นิ้ว 4 กล้อง สูงสุด 16ล้านพิกเซล ff f2.2 โทรศัพท์มือถือ ',
#   '|หน้าจอ| 6.1 นิ้ว |ความละเอียด|3040x1440 quad hd 550 ppi ',
#   '|กล้องหลัง| 3 ตัว 16ล้านพิกเซล f 2.2 ultra wide 12ล้านพิกเซล f 1.5 และ 2.4 wide 12ล้านพิกเซล f 2.4 tele ',
#   '|กล้องหน้า|10ล้านพิกเซล f 1.9',
#   '|หน่วยประมวลผล|octa core snapdragon 855octa core exynos9 9820',
#   '|แบตเตอรี่|3400 mah typical ',
#   '|แบรนด์| ซัมซุง',
#   '|sku| 289434461 th 479544867',
#   '|โมเดล| s10 128gb ',
#   '|ระยะเวลาการรับประกัน| 1 ปี'],
#  'category_0_17': ['|ประเภท |โทรศัพท์มือถือและแท็บเล็ต',
#   '|ประเภทย่อย| สมาร์ทโฟน',
#   '|ขนาด| |น้ำหนัก| ยาว 163.3 กว้าง 77.5 หนา 8 มม. |น้ำหนัก| 183 กรัม',
#   'จอภาพ ชนิดจอ จอสัมผัส tft |ขนาด| |ความละเอียด| 6.5 นิ้ว 264 ppi 720 1560 px',
#   '|หน้าจอ| tft แบบ infinity u จอแสดงผล |ขนาด| 6.5 นิ้ว |ความละเอียด| hd 720 x 1560 พิกเซล อัตราส่วน|หน้าจอ| 19.5 9',
#   '|หน่วยประมวลผล| |cpu| snapdragon 450 |หน่วยประมวลผล| |gpu| adreno 506',
#   'หน่วยความจำ |ram| 3 gb |rom| 32 gb micro sd 512 gb |รองรับ| 2 ซิมการ์ด |รองรับ|การเพิ่มความจำด้วย microsd card สูงสุด 512 gb',
#   '|กล้องหลัง| 3 ตัว ประกอบด้วย',
#   'เลนส์หลัก |ความละเอียด| 13ล้านพิกเซล f 1.8 เลนส์ ultra wide 120 องศา |ความละเอียด| 8ล้านพิกเซล f 2.2 เลนส์ depth |ความละเอียด| 5ล้านพิกเซล f 2.2 ',
#   '|กล้องหน้าความละเอียด| 8ล้านพิกเซล f 2.0 ',
#   '|รองรับ|ระบบเสียง dolby atmos เซ็นเซอร์ accele|rom|eter fingerprint sensor gyro sensor geomagnetic sensor light sensor proximity sensor การเชื่อมต่อ bluetooth 4.2 wi fi 802.11 b g n 2.4ghz 3.5mm earjack usb type c wi fi direct gps glonass beidou galileo pc sync. 2g gsm850 gsm900 dcs1800 pcs1900 3g b1 2100 b2 1900 b5 850 b8 900 4g lte ',
#   '|แบตเตอรี่ความจุ| 4000 mah |รองรับ| 15w fast charging ระบบปฎิบัติการ android 9.0 pi',
#   '|แบรนด์| ซัมซุง',
#   '|sku| 594338092 th 1115814517',
#   '|กล้องหน้า| ล้านพิกเซล 7ล้านพิกเซล ขึ้นไป',
#   '|โมเดล| samsung a20s',
#   '|ระยะเวลาการรับประกัน| 1 ปี',
#   '|ความจุแบตเตอรี่| 1000 mah ถึง 5000 mah'],
#  'category_0_18': ['|ประเภท |โทรศัพท์มือถือและแท็บเล็ต',
#   '|ประเภทย่อย| สมาร์ทโฟน',
#   '|หน้าจอ| super amoled |ขนาด| 6.7 นิ้ว |ความละเอียด| fhd 1080 x 2400 ',
#   '|cpu| snapdragon 730',
#   '|ความจุ| 128gb ufs 2.1 ไม่|รองรับ| microsd card',
#   '|กล้องหน้า| หลัง 4ล้านพิกเซล f 2.0 imx586 ultra wide ล้านพิกเซล f 2.2 tof',
#   'สแกนนิ้วมือบน|หน้าจอ|',
#   '|แบตเตอรี่| 3700 mah |รองรับ| super fast charging 25w',
#   '|แบรนด์| ซัมซุง',
#   '|sku| 340860812 th 661136678',
#   '|ระยะเวลาการรับประกัน| 1 ปี',
#   '|ระบบปฏิบัติการ| android',
#   '|ระบบปฏิบัติการ|เวอร์ชัน android 9.0 pie',
#   '|โมเดล| a80',
#   '|ขนาดหน้าจอ| นิ้ว 6.7',
#   '|ความจุแบตเตอรี่| 3000 3999 mah'],
#  'category_0_19': ['|ประเภท |โทรศัพท์มือถือและแท็บเล็ต',
#   '|ประเภทย่อย| สมาร์ทโฟน',
#   '|รองรับ| 2 ซิมการ์ด',
#   'จอแสดงผล super amoled 24 bit 16 ล้านสี ระบบสัมผัส multi touch กว้าง 6.4 นิ้ว แนวทะแยง |ความละเอียด| 2960 x 1440 พิกเซล capacitive corning gorilla glass 5 ระบบป้องกัน ฝุ่นละออง resistance to dust ',
#   'ระบบเซ็นเซอร์ sensor ระบบตรวจสอบลายนิ้วมือ finger print ระบบจดจำใบหน้า face detection ระบบหมุนภาพอัตโนมัติ accele|rom|eter ระบบเปิด ปิด|หน้าจอ|อัตโนมัติขณะสนทนา proximity ระบบเซนเซอร์หมุนภาพ gyroscope ระบบวัดความกดอากาศ ba|rom|eter |รองรับ| s pen ระบบปากกาอัจฉริยะ ระบบสแกนม่านตา',
#   '|ระบบปฏิบัติการ| android 8.1 oreo',
#   '|หน่วยประมวลผล| exynos 9810 octa core ความเร็ว 2.7 ghz',
#   'กล้องดิจิตอล 12 12 ล้านพิกเซล dual camera |รูรับแสงขนาด| 1.5 ไฟแฟลช led ซูมออฟติคอล 2 เท่า 2x optical zoom โฟกัสอัตโนมัติ auto focus แตะเลือกจุดโฟกัส touch focus ระบบป้องกันภาพสั่นไหวแบบออปติคอล ois ค้นหาใบหน้าอัตโนมัติ face detection โหมดถ่ายภาพพาโนราม่า pano|ram|a ',
#   '|กล้องหน้า| front camera |ความละเอียด| 8ล้านพิกเซล |รูรับแสงขนาด| 1.7',
#   '|แบตเตอรี่|มาตรฐาน 4000 mah standard battery ',
#   '|แบรนด์| ซัมซุง',
#   '|sku| 283666353 th 461390461',
#   '|โมเดล| samsung galaxy note 9 6gb 128gb เครื่องศูนย์ มีประกัน ocean blue ',
#   '|ระยะเวลาการรับประกัน| 1 ปี',
#   '|ระบบปฏิบัติการ| android'],
#  'category_0_20': ['|ประเภท |โทรศัพท์มือถือและแท็บเล็ต',
#   '|ประเภทย่อย| สมาร์ทโฟน',
#   'samsung galaxy a10s สมาร์ทโฟน |กล้องหลัง|คู่ 13 ล้านพิกเซล แบต 4000mah ประกันศูนย์ 1 ปี แถมฟรีหูฟังซัมซุง มูลค่า 399 บาท',
#   '|น้ำหนัก| 168 กรัม',
#   '|หน้าจอแสดงผล| tft lcd กว้าง 6.2 นิ้ว |ความละเอียด| 1520x720 พิกเซล hd มีดีไซน์รอยแหว่งแบบ infinity v',
#   '|ระบบปฏิบัติการ| one ui 1.1 บนพื้นฐาน android 9 pie',
#   '|กล้องหลัง| 2 เลนส์ พร้อมไฟแฟลชเลนส์หลัก |ความละเอียด| 13 ล้านพิกเซล รูรับแสง f 1.8',
#   'เลนส์ depth |ความละเอียด| 2 ล้านพิกเซล รูรับแสง f 2.4',
#   '|กล้องหน้า| |ความละเอียด| 8 ล้านพิกเซล รูรับแสง f 2.2',
#   'ซิมการ์ด|รองรับ| 2 ซิมแบบ nano sim',
#   '|แบตเตอรี่| 4000mah',
#   '|แบรนด์| ซัมซุง',
#   '|sku| 616572478 th 1170962904',
#   '|ระยะเวลาการรับประกัน| 1 ปี',
#   'ประเภทของ|แบตเตอรี่| built in rechargeable battery',
#   '|กล้องหน้า| ล้านพิกเซล 7ล้านพิกเซล ขึ้นไป',
#   '|ระบบปฏิบัติการ|เวอร์ชัน android 9.0 pie',
#   '|โมเดล| samsung galaxy a10s sm a107f '],
#  'category_0_21': ['|ประเภท |โทรศัพท์มือถือและแท็บเล็ต',
#   '|ประเภทย่อย| สมาร์ทโฟน',
#   '|แบรนด์| ซัมซุง',
#   '|sku| 307684896 th 537048806',
#   '|โมเดล| samsung galaxy j4 plus',
#   '|ระยะเวลาการรับประกัน| 1 ปี'],
#  'category_0_22': ['|ประเภท |โทรศัพท์มือถือและแท็บเล็ต',
#   '|ประเภทย่อย| สมาร์ทโฟน',
#   '|ขนาดหน้าจอ| 6.3 นิ้ว',
#   '|ความจุ|ที่เก็บข้อมูล 256 gb',
#   '|แบตเตอรี่| 3500 mah typical ',
#   '|มาตรฐานการกันน้ำและกันฝุ่น| ip68',
#   '|แบรนด์| ซัมซุง',
#   '|sku| 373972071 th 728742055',
#   '|โมเดล| 8 256gb',
#   '|ระยะเวลาการรับประกัน| 1 ปี'],
#  'category_0_23': ['|ประเภท |โทรศัพท์มือถือและแท็บเล็ต',
#   '|ประเภทย่อย| สมาร์ทโฟน',
#   '|หน้าจอ|กว้าง|ขนาด| 6.3 ใหญ่ที่สุดในตระกูล note',
#   '|หน้าจอ|กว้างขึ้น ด้วย|ขนาด| 6.3 ใหญ่ที่สุดในตระกูล note มอบภาพที่คมชัด แจ้มแจ้งในทุกรายละเอียด',
#   'อัตราส่วน|หน้าจอขนาด| 18 5 9 ช่วยให้คุณเห็นรายละเอียดบน|หน้าจอ|ที่มาก ปรับแต่งรายการต่างๆ พร้อมขยับจอน้อยลง',
#   '|แบรนด์| ซัมซุง',
#   '|sku| 310302392 th 552106447',
#   '|โมเดล| sm n950',
#   '|ระยะเวลาการรับประกัน| 1 ปี'],
#  'category_0_24': ['|ประเภท |โทรศัพท์มือถือและแท็บเล็ต',
#   '|ประเภทย่อย| สมาร์ทโฟน',
#   'กล้องดิจิตอล main camera 2ล้านพิกเซล ultra wide camera ล้านพิกเซล telephoto camera 1ล้านพิกเซล depth camera ล้านพิกเซล fourth camera |รูรับแสงขนาด| 1.7',
#   '|กล้องหน้า| |ความละเอียด| 24ล้านพิกเซล ',
#   '|แบรนด์| ซัมซุง',
#   '|sku| 280354579 th 453591358',
#   '|ระยะเวลาการรับประกัน| 5 วัน',
#   '|ระบบปฏิบัติการ| android',
#   '|กล้องหน้า| ล้านพิกเซล 7ล้านพิกเซล ขึ้นไป',
#   '|ระบบปฏิบัติการ|เวอร์ชัน android 8.0 oreo',
#   '|โมเดล| samsung galaxy a9 2018 6 128gb เครื่องศูนย์ เคลียสตอคไม่มีประกัน caviar black ',
#   '|ขนาดหน้าจอ| นิ้ว 6.3',
#   '|ความจุแบตเตอรี่| 1000 mah ถึง 5000 mah'],
#  'category_0_25': ['|ประเภท |โทรศัพท์มือถือและแท็บเล็ต',
#   '|ประเภทย่อย| สมาร์ทโฟน',
#   'จอแสดงผล super amoled 24 bit 16 ล้านสี |หน้าจอ|ทรงหยดน้ำ รูปตัว u infinity u ระบบสัมผัส multi touch กว้าง 6.7 นิ้ว แนวทะแยง |ความละเอียด| 1080 x 2400 พิกเซล capacitiveระบบเซ็นเซอร์ sensor ระบบสแกนลายนิ้วมือใต้|หน้าจอ| fingerprint under จอแสดงผล ระบบจดจำใบหน้า face detection ระบบหมุนภาพอัตโนมัติ accele|rom|eter ตรวจจับแสงปรับความสว่างอัตโนมัติ ambient light ระบบเปิด ปิด|หน้าจอ|อัตโนมัติขณะสนทนา proximity ระบบเซนเซอร์หมุนภาพ gyroscope ปรับมุมมองการแสดงผลอัตโนมัติ orientation |ระบบปฏิบัติการ| android 9 pie|หน่วยประมวลผล| snapdragon 675 octa core ความเร็ว 2.0 ghzหน่วยความจำ |rom| 128gb |ram| 8gbการ์ดหน่วยความจำ microsd สูงสุด 512 gb กล้องดิจิตอล 3ล้านพิกเซล 8 ultra wide 5 triple camera |รูรับแสงขนาด| 1.7 ไฟแฟลช led ค้นหาใบหน้าอัตโนมัติ face detection เทคโนโลยีถ่ายภาพอัจฉริยะ ai camera โหมดปรับหน้าสวยอัตโนมัติ ai face beauty โหมดเปลี่ยนภาพเซลฟี่เป็นอิโมจิ ar emoji โหมดเปลี่ยนภาพเซลฟี่เป็นสติกเกอร์ ar sticker โหมดถ่ายภาพพาโนราม่า pano|ram|a โหมดถ่ายภาพช่วงการรับแสงสูง hdr |กล้องหน้า| front camera |ความละเอียด| 32 |รูรับแสงขนาด| 2.0 |กล้องหน้า| hdr บันทึกวีดีโอ ภาพเคลื่อนไหว video recording รูปแบบไฟล์วีดีโอ ล้านพิกเซล eg 4 เครื่องเล่นวีดีโอ video player รูปแบบไฟล์ ล้านพิกเซล eg 4 |รองรับ|วีดีโอจาก youtube เครื่องเล่นเพลง music player รูปแบบไฟล์ ล้านพิกเซล 3 ระบบเสียง dolby atmosเทคโนโลยีเพิ่มความเร็วในการชาร์จ|แบตเตอรี่|มาตรฐาน 4500 mah standard battery ',
#   '|แบรนด์| ซัมซุง',
#   '|sku| 595150747 th 1117932783',
#   '|โมเดล| samsung a70'],
#  'category_0_26': ['|ประเภท |โทรศัพท์มือถือและแท็บเล็ต',
#   '|ประเภทย่อย| สมาร์ทโฟน',
#   '|กล้องหน้า| และ หลัง|ความละเอียด|เท่ากัน 16ล้านพิกเซล ',
#   '|กล้องหน้า|มาพร้อม3 step lighting ช่วยปรับแสงได้ 3 ระดับ และ|กล้องหลัง| รูรับแสงกว้าง f1.7',
#   'app pair สามารถเปิด 2 แอพที่ชอบได้พร้อมกัน2 |หน้าจอ|ในคลิ๊กเดียว',
#   'แชทได้พร้อมกัน 2 บัญชีในเครื่องเดียว |รองรับ|แอพsocial เยอะที่สุดถึง 18 แอพ',
#   '|แบรนด์| ซัมซุง',
#   '|sku| 264741378 th 411062149',
#   '|โมเดล| galaxy a6 sm a605g ds ',
#   '|ขนาดหน้าจอ| นิ้ว 6',
#   '|ระยะเวลาการรับประกัน| 1 ปี'],
#  'category_0_27': ['|ประเภท |โทรศัพท์มือถือและแท็บเล็ต',
#   '|ประเภทย่อย| สมาร์ทโฟน',
#   'samsung galaxy a50s 128gb 6gb |ram| original set it is a |แบรนด์| new original packaging undamaged unopened unused item it is original and packaging is the same as what is found in the retail store unless the item is handmade or was packaged by the manufacturer in non retail packaging such as an unprinted box or plastic bag ',
#   '|แบรนด์| ซัมซุง',
#   '|sku| 617108827 th 1172618764',
#   '|ระบบปฏิบัติการ|เวอร์ชัน android 9.0 pie',
#   '|โมเดล| samsung galaxy a50s 128gb 6gb |ram| original set',
#   '|ระยะเวลาการรับประกัน| 1 ปี'],
#  'category_0_28': ['|ประเภท |โทรศัพท์มือถือและแท็บเล็ต',
#   '|ประเภทย่อย| สมาร์ทโฟน',
#   'สนุกทุกประสบการณ์กับ|หน้าจอ|ใหญ่ที่เต็มตากว่าเดิม',
#   '|แบรนด์| ซัมซุง',
#   '|sku| 511068392 th 907938105',
#   '|โมเดล| galaxy a20s 3 32gb ',
#   '|ระยะเวลาการรับประกัน| 1 ปี'],
#  'category_0_29': ['|ประเภท |โทรศัพท์มือถือและแท็บเล็ต',
#   '|ประเภทย่อย| สมาร์ทโฟน',
#   '|หน้าจอ|ใหญ่ super amoled 5.6 นิ้ว สัดส่วน 18.5 9',
#   '|ระบบปฏิบัติการ|แอนดรอยด์ 7.1 nougat ',
#   '|กล้องหน้า|แบบคู่ 16 และ 8 ล้านพิกเซล รูรับแสง f 1.9',
#   '|กล้องหน้ารองรับ| live focus ปรับฉากหลังละลายได้',
#   'ปลดล็อค|หน้าจอ|ด้วยการสแกนใบหน้า',
#   '|รองรับ|การใช้งาน secure folder',
#   '|รองรับ|การสแกนลายนิ้วมือ',
#   '|หน้าจอ|ใหญ่ super amoled 5.6 นิ้ว สัดส่วน 18.5 9',
#   '|ระบบปฏิบัติการ|แอนดรอยด์ 7.1 nougat ',
#   '|กล้องหน้า|แบบคู่ 16 และ 8 ล้านพิกเซล รูรับแสง f 1.9',
#   '|กล้องหน้ารองรับ| live focus ปรับฉากหลังละลายได้',
#   'ปลดล็อค|หน้าจอ|ด้วยการสแกนใบหน้า',
#   '|รองรับ|การใช้งาน secure folder',
#   '|รองรับ|การสแกนลายนิ้วมือ',
#   '|แบรนด์| ซัมซุง',
#   '|sku| 207916690 th 313021622',
#   '|โมเดล| refurbish samsung galaxy a8 2018 gold',
#   '|ระยะเวลาการรับประกัน| 3 เดือน'],
#  'category_0_30': ['|ประเภท |โทรศัพท์มือถือและแท็บเล็ต',
#   '|ประเภทย่อย| สมาร์ทโฟน',
#   'samsung galaxy s10 8 gb |ram| 128 gb |rom| 6.4 นิ้ว 5 กล้อง สูงสุด 16ล้านพิกเซล ff f2.2 โทรศัพท์มือถือ ',
#   '|หน้าจอ| 6.4 นิ้ว |ความละเอียด| 3040x1440 quad hd 550 ppi ',
#   '|กล้องหลัง| 3 ตัว 16ล้านพิกเซล f 2.2 ultra wide 12ล้านพิกเซล f 1.5 และ 2.4 wide 12ล้านพิกเซล f 2.4 tele ',
#   '|กล้องหน้า| 2 ตัว 10ล้านพิกเซล f 1.9 main 8ล้านพิกเซล f 2.2 live focus ',
#   '|หน่วยประมวลผล| octa core snapdragon 855 octa core exynos9 9820',
#   '|แบตเตอรี่| 4100 mah typical ',
#   '|แบรนด์| ซัมซุง',
#   '|sku| 289426638 th 479560515',
#   '|โมเดล| s10 128gb ',
#   '|ระยะเวลาการรับประกัน| 1 ปี'],
#  'category_0_31': ['|ประเภท |โทรศัพท์มือถือและแท็บเล็ต',
#   '|ประเภทย่อย| สมาร์ทโฟน',
#   '|ระบบปฏิบัติการ| os |cpu| |ระบบปฏิบัติการ| android 8.0 oreo ',
#   '|หน่วยประมวลผล| qualcomm snapdragon 450 octa core',
#   '|แบรนด์| ซัมซุง',
#   '|sku| 289402378 th 479508064',
#   '|โมเดล| samsung j8 |ram|3 32gb เครื่องศูนย์ประกันมีเดือน สีทอง แถมฟรี เคสใส ฟิลม์กระจก',
#   '|ระยะเวลาการรับประกัน| 3 เดือน',
#   '|ระบบปฏิบัติการ| android'],
#  'category_0_32': ['xiaomi redmi note 8 3gb 32gb สมาร์ตโฟน 4 กล้อง ai |ความละเอียด| 48ล้านพิกเซล จอกว้าง 6.3 นิ้ว fhd ชิปเซ็ต qualcomm sd 665 ฿ 4299.00 ฿ 4999.00 14เปอร์เซนต์ ',
#   'samsung wireless battery pack 10000 mah พาวเวอร์แบงค์ |แบตเตอรี่|สำรอง ฿ 1290.00 ฿ 1590.00 19เปอร์เซนต์ ',
#   'samsung galaxy tab s4 10.5 4 gb |ram| 64 gb |rom| 10.5 นิ้ว แท็บเล็ต ฿ 13990.00 ฿ 23900.00 41เปอร์เซนต์ '],
#  'category_0_33': ['|ประเภท |โทรศัพท์มือถือและแท็บเล็ต',
#   '|ประเภทย่อย| สมาร์ทโฟน',
#   ' |แบรนด์| new',
#   '|แบรนด์| ซัมซุง',
#   '|sku| 612014873 th 1155486191',
#   '|ระบบปฏิบัติการ|เวอร์ชัน android 8.1 oreo',
#   '|โมเดล| samsung galaxy note 10 plus',
#   '|ระยะเวลาการรับประกัน| 1 ปี'],
#  'category_0_34': ['|ประเภท |โทรศัพท์มือถือและแท็บเล็ต',
#   '|ประเภทย่อย| สมาร์ทโฟน',
#   '|รองรับ| 2 ซิมการ์ด',
#   'จอแสดงผล super amoled 24 bit 16ล้านสี ระบบสัมผัส multi touch กว้าง6.4 นิ้ว แนวทะแยง |ความละเอียด| 2960x1440 พิกเซล capacitive corning gorilla glass5 ระบบป้องกันฝุ่นละออง resistance to dust ',
#   'ระบบเซ็นเซอร์ sensor ระบบตรวจสอบลายนิ้วมือ finger print ระบบจดจำใบหน้า face detection ระบบหมุนภาพอัติโนมัติ accele|rom|eter ระบบเปิด ปิด|หน้าจอ|อัตโนมัติขณะสนทนา proximity ระบบเซ็นเซอร์หมุนภาพ gyroscope ระบบวัดความกดอากาศ ba|rom|eter |รองรับ| s pen ระบบปากกาอัจฉริยะ ระบบสแกนม่านตา',
#   '|ระบบปฏิบัติการ| android 8.1 oreo',
#   '|หน่วยประมวลผล| exynos 9810octa core ความเร็ว 2.7 ghz',
#   'การ์ดหน่วยความจำ |รองรับ|ได้สูงสุด 512 gb',
#   'กล้องดิจิตอล 12 12 ล้านพิกเซล dual camera ซูมออฟติคอล 2 เท่า 2x optical zoom โฟกัสอัตโนมัติ auto focus แตะเลือกจุดโฟกัส touch focus ระบบป้องกัยภาพสั่นไหวแบบออปติคอล ols ค้นหาใบหน้าแบบอัตโนมัติ face detection โหมดถ่ายภาพพาโนรามา pano|ram|a ',
#   '|กล้องหน้า| front camera |ความละเอียด| 8ล้านพิกเซล ',
#   '|แบตเตอรี่|มาตรฐาน 4000 mah standard battery ',
#   '|แบรนด์| ซัมซุง',
#   '|sku| 283658415 th 461387419',
#   '|โมเดล| samsung galaxy note 9 6gb 128gb เครื่องศูนย์ มีประกัน midnight black ระ',
#   '|ระยะเวลาการรับประกัน| 1 ปี',
#   '|ระบบปฏิบัติการ| android'],
#  'category_0_35': ['|ประเภท |โทรศัพท์มือถือและแท็บเล็ต',
#   '|ประเภทย่อย| สมาร์ทโฟน',
#   '|แบรนด์| new samsung galaxy s10 plus 128gb',
#   ' |แบรนด์| new',
#   '|แบรนด์| ซัมซุง',
#   '|sku| 610820644 th 1151996547',
#   '|ระบบปฏิบัติการ|เวอร์ชัน android 8.0 oreo',
#   '|โมเดล| samsung galaxy s10 plus',
#   '|ระยะเวลาการรับประกัน| 1 ปี'],
#  'category_0_36': ['|ประเภท |โทรศัพท์มือถือและแท็บเล็ต',
#   '|ประเภทย่อย| สมาร์ทโฟน',
#   'samsung galaxy note 9 8gb 512gb it is a |แบรนด์| new original packaging undamaged unopened unused item it is original and packaging is the same as what is found in the retail store unless the item is handmade or was packaged by the manufacturer in non retail packaging such as an unprinted box or plastic bag ',
#   '|แบรนด์| ซัมซุง',
#   '|sku| 617168251 th 1172664402',
#   '|ระบบปฏิบัติการ|เวอร์ชัน android 9.0 pie',
#   '|โมเดล| samsung galaxy note 9 8gb 512gb ',
#   '|ระยะเวลาการรับประกัน| 1 ปี'],
#  'category_0_37': ['samsung galaxy a30 4 gb |ram| 64 gb |rom| 6.4 นิ้ว 3 กล้อง สูงสุด 16ล้านพิกเซล ff f2.0 โทรศัพท์มือถือ ฿ 5990.00 ฿ 7290.00 18เปอร์เซนต์ ',
#   'โทรศัพท์ซัมซุง galaxy |รุ่น| s9 plus 256gb สีฟ้า ฿ 7900.00 ฿ 13590.00 42เปอร์เซนต์ '],
#  'category_0_38': ['|ประเภท |โทรศัพท์มือถือและแท็บเล็ต',
#   '|ประเภทย่อย| สมาร์ทโฟน',
#   'samsung galaxy a30 4 gb |ram| 64 gb |rom| 6.4 นิ้ว 3 กล้อง สูงสุด 16ล้านพิกเซล ff f2.0 โทรศัพท์มือถือ ',
#   '|หน้าจอ| samoled full จอแสดงผล ไร้กรอบ ไร้ปุ่มโฮม เพิ่มมุมมองการเห็น ด้วยสัดส่วน 19.5 9 จอกว้างขึ้น พร้อม|ความละเอียด| fhd เพื่อการชมภาพยนตร์ที่เต็มอิ่มมากขึ้น',
#   '|แบรนด์| ซัมซุง',
#   '|sku| 299990648 th 515722325',
#   '|โมเดล| galaxy a30 4 64gb ',
#   '|ระยะเวลาการรับประกัน| 1 ปี'],
#  'category_0_39': ['|ประเภท |โทรศัพท์มือถือและแท็บเล็ต',
#   '|ประเภทย่อย| สมาร์ทโฟน',
#   '|แบรนด์| ซัมซุง',
#   '|sku| 408012228 th 792604544',
#   '|โมเดล| galaxy a10s 2 32gb',
#   '|ระยะเวลาการรับประกัน| 1 ปี'],
#  'category_0_40': ['|ประเภท |โทรศัพท์มือถือและแท็บเล็ต',
#   '|ประเภทย่อย| สมาร์ทโฟน',
#   '|หน้าจอ| 5.45 นิ้ว |ความละเอียด| hd 1440 x 720 พิกเซล',
#   '|ระบบปฏิบัติการ| android 9 pie ครอบทับด้วย miui 10',
#   '|gpu| adreno 505',
#   '|rom| 16gb |รองรับ| microsd 256gb ',
#   '|กล้องหลัง| 13ล้านพิกเซล f 2.2 1.12 m พร้อม led flash',
#   '|กล้องหน้า| 5ล้านพิกเซล ',
#   '|รองรับ| face unlock',
#   '|แบตเตอรี่| |ความจุ| 4000 mah |รองรับ|การชาร์จ 5v 2a ผ่าน micro usb',
#   '|รองรับ| dual sim4g lte',
#   '|รองรับ| wi fi 802.11 b g n 2.4ghz wifi direct wifi จอแสดงผล hotspot',
#   '|รองรับ| usb 2.0usb on the go',
#   '|ขนาด|ตัวเครื่อง 146.30 x 70.41 x 9.55 มม. หนัก 165 กรัม',
#   '|แบรนด์| xiaomi',
#   '|sku| 213755551 th 1138512951',
#   '|กล้องหน้า| ล้านพิกเซล 5 6ล้านพิกเซล ',
#   '|ระบบปฏิบัติการ|เวอร์ชัน android 9.0 pie',
#   '|โมเดล| xiaomi redmi 7a 2 32gb ',
#   '|ขนาดหน้าจอ| นิ้ว 5.45',
#   '|ระยะเวลาการรับประกัน| 1 ปี',
#   '|ระบบปฏิบัติการ| android',
#   '|ความจุแบตเตอรี่| 1000 mah ถึง 5000 mah'],
#  'category_0_41': ['|ประเภท |โทรศัพท์มือถือและแท็บเล็ต',
#   '|ประเภทย่อย| สมาร์ทโฟน',
#   '4 กล้อง ai |ความละเอียด| 4ล้านพิกเซล ',
#   '|แบตเตอรี่ความจุ| 4000 mah',
#   '|รองรับ|ระบบ',
#   '|แบรนด์| xiaomi',
#   '|sku| 222527681 th 889412058',
#   '|กล้องหน้า| ล้านพิกเซล 1ล้านพิกเซล ',
#   '|ระบบปฏิบัติการ|เวอร์ชัน android 9.0 pie',
#   '|โมเดล| xiaomi redmi note 8',
#   '|ระยะเวลาการรับประกัน| 1 ปี',
#   '|ความจุแบตเตอรี่| 4000 4999 mah'],
#  'category_0_42': ['|ประเภท |โทรศัพท์มือถือและแท็บเล็ต',
#   '|ประเภทย่อย| สมาร์ทโฟน',
#   ' สินค้าพร้อมส่ง ฟรี mi air purifier 2 xiaomi mi note 10 6 128gb สมาร์ทโฟน กล้อง 5 ตัว |ความละเอียด| 10ล้านพิกเซล รับประกันศูนย์ไทย 15 เดือน ',
#   '|แบรนด์| xiaomi',
#   '|sku| 595884854 th 1119120013',
#   '|ระบบปฏิบัติการ|เวอร์ชัน android 9.0 pie',
#   '|โมเดล| mi note 10',
#   '|ระยะเวลาการรับประกัน| 15 เดือน'],
#  'category_0_43': ['|ประเภท |โทรศัพท์มือถือและแท็บเล็ต',
#   '|ประเภทย่อย| สมาร์ทโฟน',
#   ' ตัวเครื่องมี|ขนาด| 156.48x75.41x9. มม. และมี|น้ำหนัก| 188 กรัม',
#   ' |หน้าจอแสดงผล| dot notch จอแสดงผล |ขนาด| 6.22 นิ้ว ในอัตราส่วน 19 9 |ความละเอียด|ระดับ hd 720x1520 พิกเซล 270 ppi ครอบทับด้วยกระจกขอบโค้งแบบ 2.5d corning gorilla glass 5',
#   ' |หน่วยประมวลผล|กราฟิก |gpu| adreno 505',
#   ' หน่วยความจำแรม |ram| |ขนาด| 4gb',
#   ' หน่วยความจำภายใน |rom| |ขนาด| 64gb พร้อม|รองรับ|การ์ดหน่วยความจำภายนอกแบบ microsd สูงสุดที่|ขนาด| 512gb',
#   ' กล้องดิจิทัลด้านหลังแบบคู่ ai dual camera |ความละเอียด| 12 ล้านพิกเซล เซ็นเซอร์รับภาพ sony imx363 พิกเซล|ขนาด| 1.4 ไมครอน มี|ขนาด|รูรับแสง f 1.8 กล้องตัวที่สองเลนส์ depth |ความละเอียด| 2 ล้านพิกเซล |รองรับ|เทคโนโลยี dual pd ai portrait และ ai scene detection ในการตรวจจับซีนทั้งหมด 33 หมวดหมู่',
#   ' กล้องดิจิทัลด้านหน้า ai |ความละเอียด| 8 ล้านพิกเซล พิกเซล|ขนาด| 1.12 ไมครอน มี|ขนาด|รูรับแสง f 2.0 |รองรับ|เทคโนโลยี ai selfie portrait',
#   ' |แบตเตอรี่ความจุ| 5000 mah พร้อมเทคโนโลยีชาร์จไว 18w fast charging',
#   ' |ระบบปฏิบัติการ| android 9.0 pie',
#   ' |รองรับ|การใช้งานพร้อมกัน 2 ซิมการ์ด dual sim ',
#   ' |รองรับ|ถาดใส่ซิมการ์ดแบบ triple slot',
#   ' |รองรับ|การใช้งานบนเครือข่าย 4g lte',
#   ' |รองรับ|การเชื่อมต่อ wi fi 802.11 b g n และ bluetooth 4.2',
#   ' |รองรับ|การเชื่อมต่อแบบ usb type c',
#   '|แบรนด์| xiaomi',
#   '|sku| 611154425 th 1152864043',
#   '|กล้องหน้า| ล้านพิกเซล 7ล้านพิกเซล ขึ้นไป',
#   '|ระบบปฏิบัติการ|เวอร์ชัน android 9.0 pie',
#   '|โมเดล| xiaomi redmi 8 3 32gb ',
#   '|ขนาดหน้าจอ| นิ้ว 6.22',
#   '|ระยะเวลาการรับประกัน| 15 เดือน',
#   '|ความจุแบตเตอรี่| 1000 mah ถึง 5000 mah'],
#  'category_0_44': ['|ประเภท |โทรศัพท์มือถือและแท็บเล็ต',
#   '|ประเภทย่อย| สมาร์ทโฟน',
#   'xiaomi mi 9t pro เสียวหมี่ |ram|6 |rom|64gb จอ6.39นิ้ว กล้องดิจิตอล 4ล้านพิกเซล ล้านพิกเซล telephoto 1ล้านพิกเซล triple camera แถมเคส ประกันศูนย์ไทย',
#   'สมาร์ทโฟน โทรศัพท์มือถือพร้อม|ระบบปฏิบัติการ| ',
#   'จอแสดงผล amoled 24 bit 16 ล้านสี |หน้าจอแสดงผล| hdr ระบบสัมผัส multi touch กว้าง 6.39 นิ้ว แนวทะแยง |ความละเอียด| 2340 x 1080 พิกเซล 403 ppi capacitive corning gorilla glass 5',
#   'ระบบเซ็นเซอร์ sensor ระบบสแกนลายนิ้วมือใต้|หน้าจอ| fingerprint under จอแสดงผล ระบบหมุนภาพอัตโนมัติ accele|rom|eter ตรวจจับแสงปรับความสว่างอัตโนมัติ ambient light ระบบเปิด ปิด|หน้าจอ|อัตโนมัติขณะสนทนา proximity ระบบเซนเซอร์หมุนภาพ gyroscope ปรับมุมมองการแสดงผลอัตโนมัติ orientation ',
#   '|รองรับ| 2 ซิมการ์ด',
#   '|ระบบปฏิบัติการ| miui 10 based on android 9.0 pie ',
#   '|หน่วยประมวลผล| qualcomm snapdragon 855 octa core ความเร็ว 2.84 ghz',
#   'การหาตำแหน่ง assisted gps |รองรับ|แอพพลิเคชั่น egps',
#   '|รองรับ| nfc near field communication ',
#   '|รองรับ|การถ่ายโอนข้อมูลกับ flash drive โดยตรง usb on the go ',
#   'กล้องดิจิตอล 4ล้านพิกเซล ล้านพิกเซล telephoto 1ล้านพิกเซล ultra wide angle triple camera |รูรับแสงขนาด| 1.75 ไฟแฟลช dual led ซูมดิจิตอล 10 เท่า 10x digital zoom ซูมออฟติคอล 2 เท่า 2x optical zoom |ขนาด|ภาพสูงสุด 8000 x 6000 พิกเซล image size โฟกัสอัตโนมัติ auto focus โหมดฉาก บุคคล เวลากลางคืน ค้นหาใบหน้าอัตโนมัติ face detection เทคโนโลยีถ่ายภาพอัจฉริยะ ai camera โหมดปรับหน้าสวยอัตโนมัติ ai face beauty ตั้งเวลาถ่ายภาพอัตโนมัติ self timer โหมดถ่ายภาพพาโนราม่า pano|ram|a ',
#   '|กล้องหน้า| front camera |ความละเอียด| 20ล้านพิกเซล ไฟแฟลช led |รูรับแสงขนาด| 2.2 |รองรับ| video call สนทนาแบบเห็นภาพ |กล้องหน้า| hdr |กล้องหน้า| portrait |กล้องหน้า|แบบ pop up',
#   'บันทึกวีดีโอ ภาพเคลื่อนไหว video recording |ความละเอียด| hd 3840 x 2160 พิกเซล บันทึกวีดีโอ 4k 60 เฟรมต่อวินาที slow motion',
#   'เครื่องเล่นวีดีโอ video player รูปแบบไฟล์ ล้านพิกเซล eg 4 h.264 xvid m4v mkv วีดีโอสตรีมมิ่ง 3gp aviล้านพิกเซล 4 rm |รองรับ|วีดีโอจาก youtube ',
#   '|รองรับ|ไฟล์รูปภาพ jpg jpeg bmp gif tiff',
#   '|แบตเตอรี่|มาตรฐาน 4000 mah standard battery '],
#  'category_0_45': ['xiaomi redmi note 8 3gb 32gb สมาร์ตโฟน 4 กล้อง ai |ความละเอียด| 48ล้านพิกเซล จอกว้าง 6.3 นิ้ว fhd ชิปเซ็ต qualcomm sd 665 ฿ 4299.00 ฿ 4999.00 14เปอร์เซนต์ ',
#   'samsung wireless battery pack 10000 mah พาวเวอร์แบงค์ |แบตเตอรี่|สำรอง ฿ 1290.00 ฿ 1590.00 19เปอร์เซนต์ ',
#   'samsung galaxy tab s4 10.5 4 gb |ram| 64 gb |rom| 10.5 นิ้ว แท็บเล็ต ฿ 13990.00 ฿ 23900.00 41เปอร์เซนต์ ',
#   'apple ipad 9.7 inch with wifi 32gb 2018 |โมเดล| ฿ 11290.00 ฿ 11790.00 4เปอร์เซนต์ '],
#  'category_0_46': ['|ประเภท |โทรศัพท์มือถือและแท็บเล็ต',
#   '|ประเภทย่อย| สมาร์ทโฟน',
#   'โทรศัพท์มือถือ xiaomi mi a3 4gb 64gb สแกนนิ้วบนจอ |ขนาด|จอ 6.088 นิ้ว |ความละเอียด| hd ชิปเซ็ต qualcomm sd 665 |กล้องหลังความละเอียด| 4ล้านพิกเซล |กล้องหน้าความละเอียด| 3ล้านพิกเซล ',
#   '|หน้าจอ|กว้าง 6.01 นิ้ว',
#   'ระบบสแกนลายนิ้วมือใต้|หน้าจอ| และระบบจดจำใบหน้า face detection ',
#   '|กล้องหน้า| |ความละเอียด| 32 ล้านพิกเซล|รูรับแสงขนาด| 2.0',
#   '|แบตเตอรี่|มาตรฐาน li ion 4030 mah',
#   '|แบรนด์| xiaomi',
#   '|sku| 533460461 th 963560027',
#   '|กล้องหน้า| ล้านพิกเซล 7ล้านพิกเซล ขึ้นไป',
#   '|ระบบปฏิบัติการ|เวอร์ชัน android 9.0 pie',
#   '|โมเดล| mi a3 4gb 64gb ',
#   '|ขนาดหน้าจอ| นิ้ว 6.09',
#   '|ระยะเวลาการรับประกัน| 18 เดือน',
#   '|ความจุแบตเตอรี่| 1000 mah ถึง 5000 mah'],
#  'category_0_47': ['|ประเภท |โทรศัพท์มือถือและแท็บเล็ต',
#   '|ประเภทย่อย| สมาร์ทโฟน',
#   'xiaomi redmi note 8 3gb 32gb สมาร์ตโฟน 4 กล้อง ai |ความละเอียด| 48ล้านพิกเซล จอกว้าง 6.3 นิ้ว fhd ชิปเซ็ต qualcomm sd 665',
#   '|แบรนด์| xiaomi',
#   '|sku| 495988905 th 884338021',
#   '|กล้องหน้า| ล้านพิกเซล 1ล้านพิกเซล ',
#   '|ระบบปฏิบัติการ|เวอร์ชัน android 9.0 pie',
#   '|โมเดล| redmi note 8',
#   '|ขนาดหน้าจอ| นิ้ว 6.3',
#   '|ระยะเวลาการรับประกัน| 15 เดือน',
#   '|ความจุแบตเตอรี่| 1000 mah ถึง 5000 mah'],
#  'category_0_48': ['|ประเภท |โทรศัพท์มือถือและแท็บเล็ต',
#   '|ประเภทย่อย| สมาร์ทโฟน',
#   'สมาร์ทโฟน โทรศัพท์มือถือพร้อม|ระบบปฏิบัติการ| ',
#   ' |ความละเอียด| 1080 x 2340 พิกเซล 395 ppi ',
#   ' ระบบเปิด ปิด|หน้าจอ|อัตโนมัติขณะสนทนา proximity ',
#   '|รองรับ| 2 ซิมการ์ด',
#   '|ระบบปฏิบัติการ| os |cpu| ',
#   '|ระบบปฏิบัติการ| miui 10 based on android 9.0 pie ',
#   '|หน่วยประมวลผล| mediatek helio g90t octa core'],
#  'category_0_49': ['|ประเภท |โทรศัพท์มือถือและแท็บเล็ต',
#   '|ประเภทย่อย| สมาร์ทโฟน',
#   'xiaomi mi redmi 7a 2 16gb ประกันศูนย์ไทย1ปี snapdragon439 |แบตเตอรี่| 4000mah พร้อม ai beauty',
#   '|แบรนด์| xiaomi',
#   '|sku| 234902116 th 713640836',
#   '|กล้องหน้า| ล้านพิกเซล 5 6ล้านพิกเซล ',
#   '|โมเดล| xiaomi mi redmi 7a',
#   '|ระยะเวลาการรับประกัน| 1 ปี',
#   '|ความจุแบตเตอรี่| 4000 4999 mah'],
#  'category_0_50': ['|ประเภท |โทรศัพท์มือถือและแท็บเล็ต',
#   '|ประเภทย่อย| สมาร์ทโฟน',
#   '|แบรนด์| xiaomi',
#   '|sku| 494026300 th 882746256',
#   '|โมเดล| redmi note 8',
#   '|ระยะเวลาการรับประกัน| 15 เดือน'],
#  'category_0_51': ['|ประเภท |โทรศัพท์มือถือและแท็บเล็ต',
#   '|ประเภทย่อย| สมาร์ทโฟน',
#   'ผ่อน 0เปอร์เซนต์ นาน 10 เดือน xiaomi note 10 |ram| 6 |rom| 128 gb สมาร์ทโฟน 5 กล้อง 10ล้านพิกเซล ประกันศูนย์ไทย 15 เดือน ',
#   '|หน่วยประมวลผล| qualcomm snapdragon 730g',
#   '|ความจุ| |ram| 6gb |rom| 128gb',
#   '|กล้องหลัง| 108ล้านพิกเซล ระบบ 5 |กล้องหลัง| ai',
#   '|กล้องหน้า| กล้องเซลฟี่ 32ล้านพิกเซล 1.6 m super pixel 4 in 1 รูรับแสง f 2.0',
#   'ระบบปลดล็อกด้วยลายนิ้วมือบน|หน้าจอ|',
#   '|ระบบปฏิบัติการ| miui 11',
#   '|แบตเตอรี่| 5260 mah ทั่วไป 5170 mah ขั้นต่ำ ',
#   '|แบตเตอรี่|ลิเธียมไอออนโพลีเมอร์',
#   '|รองรับ|การชาร์จเร็ว 30 w ภายในกล่องมีที่ชาร์จ 30 w ',
#   '|รองรับ| 4g 4g 3g 2g',
#   '|รองรับ|การโทร volte hd สองซิม',
#   '|รองรับ| bluetooth 5.0',
#   'nfc มัลติฟังชัน |รองรับ| google pay',
#   '|ขนาด|ความสูง 157.8 มม. ความกว้าง 74.2 มม. ความหนา 9.67 มม.',
#   '|น้ำหนัก| 208 กรัม',
#   'ดีไซน์ช่องเสียง|ขนาด|ใหญ่ 1.0 cc',
#   'ช่องเสียบหูฟัง 3.5 มม. คุณภาพเสียงระดับ hifi รับรองเสียง|ความละเอียด|สูง',
#   'เซ็นเซอร์วัดแสงรอบข้างบน|หน้าจอ| ตัววัดความเร่ง ไจโรสโคป เข็มทิศอิเล็กทรอนิกส์ เซ็นเซอร์เลเซอร์โฟกัส',
#   '|แบรนด์| xiaomi',
#   '|sku| 604332862 th 1137128463',
#   '|ระยะเวลาการรับประกัน| 15 เดือน'],
#  'category_0_52': ['|ประเภท |โทรศัพท์มือถือและแท็บเล็ต',
#   '|ประเภทย่อย| สมาร์ทโฟน',
#   'สเปคเครื่องเบื้องต้นของ xiaomi mi cc9 pro priemiu edition มีดังนี้ |หน้าจอแสดงผล| amoled |ขนาด| 6.47 นิ้ว',
#   ' |ความละเอียด| 2340 x 1080 พิกเซล fhd ',
#   ' |cpu| snapdragon 730g',
#   ' |gpu| adreno 618',
#   ' |กล้องหลัง| เซ็นเซอร์ samsung hmx 10ล้านพิกเซล 8p lens 1ล้านพิกเซล ล้านพิกเซล 2ล้านพิกเซล ล้านพิกเซล พร้อมไฟแฟลชคู่ led',
#   ' |กล้องหน้า| |ความละเอียด| 3ล้านพิกเซล ',
#   ' มีเซ็นเซอร์สแกนลายนิ้วมือบน|หน้าจอ|',
#   ' |รองรับ| dual 4g volte wifi 802.11 ac 2.4ghz 5ghz bluetooth 5 gps glonass nfc usb type c',
#   ' |แบตเตอรี่ความจุ| 5260 mah พร้อมระบบชาร์จเร็ว 30w',
#   ' |ขนาด|ตัวเครื่อง 157.8 74.2 9.67 มม.',
#   ' |น้ำหนัก| 208 กรัม',
#   '|แบรนด์| xiaomi',
#   '|sku| 611792752 th 1155040122',
#   'ประเภท|หน่วยประมวลผล| octa core',
#   '|ความละเอียด|วิดีโอ 4k',
#   '|ระยะเวลาการรับประกัน| 1 ปี',
#   '|ระบบปฏิบัติการ| android 9.0 pie',
#   'ประเภทของ|แบตเตอรี่| built in rechargeable battery',
#   '|กล้องหน้า| ล้านพิกเซล 7ล้านพิกเซล ขึ้นไป',
#   '|ระบบปฏิบัติการ|เวอร์ชัน android 9.0 pie'],
#  'category_0_53': ['|ประเภท |โทรศัพท์มือถือและแท็บเล็ต',
#   '|ประเภทย่อย| สมาร์ทโฟน',
#   'amoled |ขนาด| 5.97 นิ้ว',
#   '|แบรนด์| xiaomi',
#   '|sku| 343546977 th 668396557',
#   '|ระบบปฏิบัติการ|เวอร์ชัน android 9.0 pie',
#   '|โมเดล| mi9 mi 9 se',
#   '|ระยะเวลาการรับประกัน| 1 ปี'],
#  'category_0_54': [' ซื้อ 1 แถม 1 ฟรี สำหรับ vivo v9 v11 v11i v7 y15pro y12 หลาย|รุ่น| non slip soft 3d คาร์บอนไฟเบอร์ฝาหลังฟิล์มป้องกันด้านหลังสติกเกอร์ป้องกัน ฿ 55.00 ฿ 92.00 40เปอร์เซนต์ ',
#   'โทรศัพท์ซัมซุง galaxy |รุ่น| s9 plus 256gb สีฟ้า ฿ 7900.00 ฿ 13590.00 42เปอร์เซนต์ ',
#   ' ผ่อน 0เปอร์เซนต์ 10 เดือน huawei nova 5t หน่วยความจำ 8 128g l |หน้าจอ| 6.26 นิ้ว tft lcd ips ฿ 9290.00 ฿ 10990.00 15เปอร์เซนต์ ',
#   ' daytech สมาร์ทกุญแจ |รุ่น| l02 กุญแจล็อคประตูอัจฉริยะรักษาความปลอดภัย แบบสแกนลายนิ้วมือ กันน้ำ ชาร์จไฟได้ ใช้พลังงานต่ำ แข็งแรงทนทาน ความปลอดภัยสูง ฿ 745.00 ฿ 1566.00 52เปอร์เซนต์ '],
#  'category_0_55': ['|ประเภท |โทรศัพท์มือถือและแท็บเล็ต',
#   '|ประเภทย่อย| สมาร์ทโฟน',
#   '|หน้าจอขนาด| 6.21 นิ้ว |ความละเอียด| hd ',
#   'แรม 3gb |ความจุ| 32 gb',
#   '|กล้องหลัง| 2 ตัว',
#   '|กล้องหน้า| 8 ล้านพิกเซล',
#   '|แบตเตอรี่| 5000 มิลลิแอมป์ |รองรับ|ชาร์จไว 18 วัตต์',
#   '|แบรนด์| xiaomi',
#   '|sku| 587988556 th 1092062042',
#   '|ระบบปฏิบัติการ|เวอร์ชัน android 9.0 pie',
#   '|โมเดล| redmi 8 3gb 32gb ',
#   '|ขนาดหน้าจอ| นิ้ว 6.22',
#   '|ระยะเวลาการรับประกัน| 15 เดือน',
#   '|ความจุแบตเตอรี่| 1000 mah ถึง 5000 mah'],
#  'category_0_56': ['|ประเภท |โทรศัพท์มือถือและแท็บเล็ต',
#   '|ประเภทย่อย| สมาร์ทโฟน',
#   'xiaomi redmi 8 เสียวหมี่ จอ6.21 นิ้ว |ram|4 |rom|64gb ศุนย์ไทย',
#   'สมาร์ทโฟน โทรศัพท์มือถือพร้อม|ระบบปฏิบัติการ| ',
#   'จอแสดงผล ips lcd 24 bit 16 ล้านสี กว้าง 6.21 นิ้ว แนวทะแยง |ความละเอียด| 720 x 1520 พิกเซล 271 ppi ประเภทจอ |หน้าจอ|กระจกแข็ง ประเภทจอ corning gorilla glass 5',
#   'ระบบเซ็นเซอร์ sensor ระบบตรวจสอบลายนิ้วมือ fingerprint ระบบหมุนภาพอัตโนมัติ accele|rom|eter ตรวจจับความเคลื่อนไหวของตัวเครื่อง accele|rom|eter ระบบเปิด ปิด|หน้าจอ|อัตโนมัติขณะสนทนา proximity ',
#   '|รองรับ| 2 ซิมการ์ด',
#   '|ระบบปฏิบัติการ| miui 9 based on android 9.0 pie ',
#   '|หน่วยประมวลผล| qualcomm snapdragon 439 octa core ความเร็ว 2.0 ghz',
#   '|แบรนด์| xiaomi',
#   '|sku| 526910733 th 944832734',
#   '|กล้องหน้า| ล้านพิกเซล 7ล้านพิกเซล ขึ้นไป',
#   '|โมเดล| redmi 8',
#   '|ขนาดหน้าจอ| นิ้ว 6.21',
#   '|ระยะเวลาการรับประกัน| 15 เดือน',
#   '|ระบบปฏิบัติการ| android',
#   '|ความจุแบตเตอรี่| 1000 mah ถึง 5000 mah'],
#  'category_0_57': ['|ประเภท |โทรศัพท์มือถือและแท็บเล็ต',
#   '|ประเภทย่อย| สมาร์ทโฟน',
#   '4 กล้อง ai |ความละเอียด| 4ล้านพิกเซล ',
#   '|แบตเตอรี่ความจุ| 4000 mah',
#   '|รองรับ|ระบบ',
#   '|แบรนด์| xiaomi',
#   '|sku| 221761904 th 931764445',
#   '|ระยะเวลาการรับประกัน| 15 เดือน',
#   '|ระบบปฏิบัติการ| android 8.1 oreo',
#   'ประเภทของ|แบตเตอรี่| built in rechargeable battery',
#   '|กล้องหน้า| ล้านพิกเซล 1ล้านพิกเซล ',
#   '|ระบบปฏิบัติการ|เวอร์ชัน android 8.1 oreo',
#   '|โมเดล| xiaomi redmi note 8',
#   'ประเภท|หน้าจอ| ips lcd',
#   '|ขนาดหน้าจอ| นิ้ว 6.3',
#   'ประเภท|หน่วยประมวลผล| octa core',
#   '|ความละเอียด|วิดีโอ 1080p',
#   '|ความจุแบตเตอรี่| 4000 4999 mah'],
#  'category_0_58': [' 10 inch tablet android 9.0 แถมฟรี หูฟังไร้สาย ตุ๊กตาหมี แท็บเล็ต ระบบแอนดรอยด์andorid ข้อเสนอที่ดีที่สุด จัดส่งฟรี รับประกันหนึ่งปี แท็ปเล็ต 10นิ้ว octa core 6gb |ram| 128gb |rom| 3g 4g fdd lte wifi bluetooth gps phone call glass screen tablet pc ฿ 3832.00 ฿ 7999.00 52เปอร์เซนต์ ',
#   'samsung wireless battery pack 10000 mah พาวเวอร์แบงค์ |แบตเตอรี่|สำรอง ฿ 1290.00 ฿ 1590.00 19เปอร์เซนต์ ',
#   'samsung galaxy tab s4 10.5 4 gb |ram| 64 gb |rom| 10.5 นิ้ว แท็บเล็ต ฿ 13990.00 ฿ 23900.00 41เปอร์เซนต์ ',
#   'apple ipad 9.7 inch with wifi 32gb 2018 |โมเดล| ฿ 11290.00 ฿ 11790.00 4เปอร์เซนต์ '],
#  'category_0_59': ['|ประเภท |โทรศัพท์มือถือและแท็บเล็ต',
#   '|ประเภทย่อย| สมาร์ทโฟน',
#   '|หน้าจอ| 6.47 fhd 2340 x 1080px 398 ppi',
#   'ใช้ |cpu| qualcomm snapdragon 730g octa core ความเร็ว2.2ghz',
#   '|กล้องหลัง| 10ล้านพิกเซล 1ล้านพิกเซล 2ล้านพิกเซล ล้านพิกเซล ล้านพิกเซล f 1.69 f 2.0 f 2.2 f 2.4',
#   '|กล้องหน้า| 3ล้านพิกเซล f 2.0',
#   '|แบตเตอรี่| 5260mah',
#   ' |cpu| qualcomm snapdragon 730g octa core 2.2ghz',
#   '|แบรนด์| xiaomi',
#   '|sku| 595984523 th 1119224437',
#   'ประเภท|หน่วยประมวลผล| octa core',
#   '|ความละเอียด|วิดีโอ 4k',
#   '|ระยะเวลาการรับประกัน| 1 ปี',
#   '|ระบบปฏิบัติการ| android',
#   'ประเภทของ|แบตเตอรี่| built in rechargeable battery'],
#  'category_0_60': ['|ประเภท |โทรศัพท์มือถือและแท็บเล็ต',
#   '|ประเภทย่อย| สมาร์ทโฟน',
#   'redmi 8 เสียวหมี่ จอ6.21 นิ้ว |ram|4 |rom|64gb ศุนย์ไทย รับประกัน1ปี กล่องมีการแกะซีนเพื่อเปืดประกีน',
#   'สมาร์ทโฟน โทรศัพท์มือถือพร้อม|ระบบปฏิบัติการ| ',
#   'จอแสดงผล ips lcd 24 bit 16 ล้านสี |หน้าจอ|หยดน้ำ waterdrop จอแสดงผล กว้าง 6.21 นิ้ว แนวทะแยง |ความละเอียด| 720 x 1520 พิกเซล 271 ppi ประเภทจอ |หน้าจอ|กระจกแข็ง ประเภทจอ',
#   'ระบบเซ็นเซอร์ sensor ระบบตรวจสอบลายนิ้วมือ fingerprint ระบบหมุนภาพอัตโนมัติ accele|rom|eter ตรวจจับความเคลื่อนไหวของตัวเครื่อง accele|rom|eter ระบบเปิด ปิด|หน้าจอ|อัตโนมัติขณะสนทนา proximity ',
#   '|รองรับ| 2 ซิมการ์ด',
#   '|ระบบปฏิบัติการ| miui 9 based on android 9.0 pie ',
#   '|หน่วยประมวลผล| qualcomm snapdragon 439 octa core ความเร็ว 2.0 ghz',
#   'กล้องดิจิตอล 12 ล้านพิกเซล depth sensor ล้านพิกเซล dual camera |รูรับแสงขนาด| 2.2 ไฟแฟลช led',
#   '|กล้องหน้า| front camera |ความละเอียด| ล้านพิกเซล |รูรับแสงขนาด| 2.0 |กล้องหน้า| hdr',
#   '|แบตเตอรี่|มาตรฐาน li pol 5000 mah standard battery ',
#   '|แบรนด์| xiaomi',
#   '|sku| 612338298 th 1156318935',
#   '|ระยะเวลาการรับประกัน| 1 ปี',
#   '|ระบบปฏิบัติการ| android',
#   'ประเภทของ|แบตเตอรี่| built in rechargeable battery'],
#  'category_0_61': ['|ประเภท |โทรศัพท์มือถือและแท็บเล็ต',
#   '|ประเภทย่อย| สมาร์ทโฟน',
#   'xiaomi redmi note 5a prime 5.5 นิ้ว 3gb |ram| 32gb |rom| dualcameras snapdragon 425 สมาร์ทโฟน octa core',
#   'กล้อง dualcameras frontcamera16.ล้านพิกเซล backcamera13.ล้านพิกเซล capacitive |หน้าจอ|สัมผัสคู่ซิมการ์ดสแตนด์บายคู่นาโนซิม',
#   '|แบรนด์| xiaomi',
#   '|sku| 615188295 th 1166414603',
#   '|ระยะเวลาการรับประกัน| 1 ปี',
#   '|ระบบปฏิบัติการ| android',
#   'ประเภทของ|แบตเตอรี่| built in rechargeable battery',
#   '|กล้องหน้า| ล้านพิกเซล 16ล้านพิกเซล ',
#   '|ระบบปฏิบัติการ|เวอร์ชัน android 8.0 oreo',
#   '|โมเดล| xiaomi redmi note 5a',
#   '|ขนาดหน้าจอ| นิ้ว 5.5',
#   '|ความละเอียด|วิดีโอ 1080p',
#   '|ความจุแบตเตอรี่| 3000 3999 mah'],
#  'category_0_62': ['|ประเภท |โทรศัพท์มือถือและแท็บเล็ต',
#   '|ประเภทย่อย| สมาร์ทโฟน',
#   'xiaomi redmi 8a เสียวหมี่ จอ6.2 นิ้ว |ram|2 |rom|32gb ศุนย์ไทย แถมเคส ฟิล์ม',
#   'สมาร์ทโฟน โทรศัพท์มือถือพร้อม|ระบบปฏิบัติการ| ',
#   'จอแสดงผล ips lcd 24 bit 16 ล้านสี กว้าง 6.2 นิ้ว แนวทะแยง |ความละเอียด| 720 x 1520 พิกเซล 271 ppi ประเภทจอ |หน้าจอ|กระจกแข็ง ประเภทจอ corning gorilla glass 5',
#   'ระบบเซ็นเซอร์ sensor ระบบหมุนภาพอัตโนมัติ accele|rom|eter ตรวจจับความเคลื่อนไหวของตัวเครื่อง accele|rom|eter ระบบเปิด ปิด|หน้าจอ|อัตโนมัติขณะสนทนา proximity ',
#   '|รองรับ| 2 ซิมการ์ด',
#   '|ระบบปฏิบัติการ| miui 10 based on android 9.0 pie ',
#   '|หน่วยประมวลผล| qualcomm snapdragon 439 octa core ความเร็ว 1.95 ghz',
#   'กล้องดิจิตอล 12 ล้านพิกเซล digital camera |รูรับแสงขนาด| 1.8 ไฟแฟลช led',
#   '|กล้องหน้า| front camera |ความละเอียด| ล้านพิกเซล |รูรับแสงขนาด| 2.0 |กล้องหน้า| hdr',
#   '|แบตเตอรี่|มาตรฐาน li pol 5000 mah standard battery ',
#   '|แบรนด์| xiaomi',
#   '|sku| 524454971 th 937876465',
#   '|ระยะเวลาการรับประกัน| 15 เดือน',
#   '|ระบบปฏิบัติการ| android',
#   '|กล้องหน้า| ล้านพิกเซล 7ล้านพิกเซล ขึ้นไป'],
#  'category_0_63': ['|ประเภท |โทรศัพท์มือถือและแท็บเล็ต',
#   '|ประเภทย่อย| สมาร์ทโฟน',
#   'แรม 6gb |rom| 128gb',
#   '108ล้านพิกเซล ระบบ 5 |กล้องหลัง| ai',
#   '|กล้องหน้า| เซลฟี่ 32ล้านพิกเซล รูรับแสง f 2.0',
#   'จอแสดงผล amoled แบบโค้ง 3d 6.47 นิ้ว |ความละเอียด| 2340 x 1080 fhd 398 ppi',
#   '|แบตเตอรี่| 5260mah มาตรฐานชาร์จเร็ว 30w พอร์ตการชาร์จเชื่อมต่อแบบใหม่ usb type c',
#   '|รองรับ|ระบบ fast charge 30w ภายในกล่องมีที่ชาร์จ 30 w',
#   '|แบรนด์| xiaomi',
#   '|sku| 600264311 th 1129088854',
#   'ประเภท|หน่วยประมวลผล| octa core',
#   '|ความละเอียด|วิดีโอ 4k',
#   '|ระยะเวลาการรับประกัน| 15 เดือน',
#   '|ระบบปฏิบัติการ| android 9.0 pie',
#   'ประเภทของ|แบตเตอรี่| built in rechargeable battery',
#   '|กล้องหน้า| ล้านพิกเซล 7ล้านพิกเซล ขึ้นไป',
#   '|ระบบปฏิบัติการ|เวอร์ชัน android 9.0 pie',
#   '|โมเดล| xiaomi mi note 10',
#   'ประเภท|หน้าจอ| amoled',
#   '|ขนาดหน้าจอ| นิ้ว 6.47',
#   '|ความจุแบตเตอรี่| 5000 mah หรือมากกว่า'],
#  'category_0_64': [' ซื้อ 1 แถม 1 ฟรี สำหรับ vivo v9 v11 v11i v7 y15pro y12 หลาย|รุ่น| non slip soft 3d คาร์บอนไฟเบอร์ฝาหลังฟิล์มป้องกันด้านหลังสติกเกอร์ป้องกัน ฿ 55.00 ฿ 92.00 40เปอร์เซนต์ ',
#   ' ผ่อน 0เปอร์เซนต์ 10 เดือน huawei nova 5t หน่วยความจำ 8 128g l |หน้าจอ| 6.26 นิ้ว tft lcd ips ฿ 9290.00 ฿ 10990.00 15เปอร์เซนต์ ',
#   'โทรศัพท์ซัมซุง galaxy |รุ่น| s9 plus 256gb สีฟ้า ฿ 7900.00 ฿ 13590.00 42เปอร์เซนต์ ',
#   '100เปอร์เซนต์ สำหรับ huawei y9 2019|หน้าจอแสดงผล| lcd สัมผัสขอบจอสำหรับ huawei เพลิดเพลินไปกับ 9 plus ตัวแปลงเป็นดิจิตอลสำหรับ|หน้าจอ| lcd เปลี่ยนอะไหล่ซ่อมสำรอง กระจกเทมเปอร์ ซ่อมเครื่องมือเครื่องมือ 6.5 นิ้ว ฿ 3302.79 ฿ 6941.00 52เปอร์เซนต์ ',
#   '100เปอร์เซนต์ สำหรับ xiaomi mi 9 |หน้าจอ| lcd|หน้าจอแสดงผล| 10 แผงสัมผัส|หน้าจอ|สำหรับ xiaomi mi9 super amoled ดิจิไทเซอร์จอแอลซีดี asembbly เปลี่ยนอะไหล่ซ่อมสำรอง กระจกเทมเปอร์ ซ่อมเครื่องมือเครื่องมือ ฿ 9624.00 ฿ 19247.00 50เปอร์เซนต์ ',
#   'กระจก lenuo สำหรับ xiaomi redmi note 8 หมายเหตุ 8 pro หมายเหตุ 7 redmi 7a ป้องกันการระเบิดเต็มรูปแบบปกป้อง|หน้าจอ|ฟิล์มกระจกเทมเปอร์ ฿ 83.98 ฿ 120.00 30เปอร์เซนต์ '],
#  'category_0_65': ['|ประเภท |โทรศัพท์มือถือและแท็บเล็ต',
#   '|ประเภทย่อย| สมาร์ทโฟน',
#   ' |หน้าจอขนาด| 6.53 นิ้ว |ความละเอียด| fhd 2340 x 1080 อัตราส่วน 19.5 9',
#   ' |cpu| helio g90t',
#   ' |gpu| mali g76',
#   ' |ความจุ| 64gb 128gb',
#   ' |กล้องหลัง| 6ล้านพิกเซล ล้านพิกเซล ล้านพิกเซล ล้านพิกเซล ',
#   ' |กล้องหน้า| 2ล้านพิกเซล ',
#   ' |รองรับ| nfc',
#   ' |แบตเตอรี่| 4500 mah |รองรับ|ชาร์จไว 18w',
#   '|แบรนด์| xiaomi',
#   '|sku| 273675979 th 909150212',
#   '|กล้องหน้า| ล้านพิกเซล 20ล้านพิกเซล ',
#   '|ระบบปฏิบัติการ|เวอร์ชัน android 9.0 pie',
#   '|โมเดล| redmi note 8 pro',
#   '|ระยะเวลาการรับประกัน| 1 ปี',
#   '|ความจุแบตเตอรี่| 4000 4999 mah'],
#  'category_0_66': ['|ประเภท |โทรศัพท์มือถือและแท็บเล็ต',
#   '|ประเภทย่อย| สมาร์ทโฟน',
#   '|แบรนด์| xiaomi',
#   '|sku| 602338133 th 1134472444',
#   '|กล้องหน้า| ล้านพิกเซล 20ล้านพิกเซล ',
#   '|ระบบปฏิบัติการ|เวอร์ชัน android 9.0 pie',
#   '|โมเดล| xiaomi mi note 10',
#   '|ขนาดหน้าจอ| นิ้ว 6.5',
#   '|ระยะเวลาการรับประกัน| 15 เดือน',
#   '|ความจุแบตเตอรี่| 4000 4999 mah'],
#  'category_0_67': [' 10 inch tablet android 9.0 แถมฟรี หูฟังไร้สาย ตุ๊กตาหมี แท็บเล็ต ระบบแอนดรอยด์andorid ข้อเสนอที่ดีที่สุด จัดส่งฟรี รับประกันหนึ่งปี แท็ปเล็ต 10นิ้ว octa core 6gb |ram| 128gb |rom| 3g 4g fdd lte wifi bluetooth gps phone call glass screen tablet pc ฿ 3832.00 ฿ 7999.00 52เปอร์เซนต์ ',
#   'samsung wireless battery pack 10000 mah พาวเวอร์แบงค์ |แบตเตอรี่|สำรอง ฿ 1290.00 ฿ 1590.00 19เปอร์เซนต์ ',
#   'samsung galaxy tab s4 10.5 4 gb |ram| 64 gb |rom| 10.5 นิ้ว แท็บเล็ต ฿ 13990.00 ฿ 23900.00 41เปอร์เซนต์ '],
#  'category_0_68': ['|ประเภท |โทรศัพท์มือถือและแท็บเล็ต',
#   '|ประเภทย่อย| สมาร์ทโฟน',
#   '|แบรนด์| xiaomi',
#   '|sku| 602306922 th 1134540658',
#   '|กล้องหน้า| ล้านพิกเซล 20ล้านพิกเซล ',
#   '|ระบบปฏิบัติการ|เวอร์ชัน android 9.0 pie',
#   '|โมเดล| xiaomi mi note 10',
#   '|ขนาดหน้าจอ| นิ้ว 6.5',
#   '|ระยะเวลาการรับประกัน| 15 เดือน',
#   '|ความจุแบตเตอรี่| 4000 4999 mah'],
#  'category_0_69': ['|ประเภท |โทรศัพท์มือถือและแท็บเล็ต',
#   '|ประเภทย่อย| สมาร์ทโฟน',
#   'xiaomi mi9 |ram|6 128gb เครื่องศูนย์ไทยมีประกันศูนย์ซีพียู snapdragon 855 มาพร้อม|หน้าจอ| amoled 6.39 นิ้ว',
#   'จอแสดงผล hdr กว้าง 6.3 นิ้ว |ความละเอียด| 1080 x 2340 พิกเซล 403 ppi ',
#   'ระบบสแกนลายนิ้วมือใต้|หน้าจอ| และ จดจำใบหน้า face detection ',
#   '|ระบบปฏิบัติการ| android 9.0 pie ',
#   '|หน่วยประมวลผล| qualcomm snapdragon 855 octa core ความเร็ว 2.84 ghz',
#   'กล้องดิจิตอล 4ล้านพิกเซล 12 1ล้านพิกเซล triple camera |รูรับแสงขนาด| 1.75',
#   '|หน้าจอ| amoled 6.39 นิ้ว |ความละเอียด| fhd 19.5 9 ',
#   '|ความจุ| 128gb',
#   '|แบตเตอรี่| 3300 mah',
#   '|รองรับ|ชาร์จไว qc 4.0 27w ',
#   '|รองรับ|ชาร์จไวแบบไร้สาย 20w',
#   '|กล้องหน้า| 20 ล้านพิกเซล f 2.0',
#   '|กล้องหลัง| 3 ตัว 48 16 12 ล้านพิกเซล f 1.8 f 2.2 f 2.2',
#   '|รองรับ|ระบบสแกนลายนิ้วมือบน|หน้าจอ|',
#   '|รองรับ|ระบบสแกนใบหน้า',
#   '|รองรับ| 2 ซิม',
#   '|แบรนด์| xiaomi',
#   '|sku| 594522639 th 1116438503',
#   '|กล้องหน้า| ล้านพิกเซล 20ล้านพิกเซล ',
# ...
#   '|sku| 616432298 th 1170674039',
#   '|ขนาดหน้าจอ| นิ้ว 7',
#   '|รุ่น| tab4 7104i za410083th ',
#   '|ระยะเวลาการรับประกัน| 1 ปี',
#   '|ระบบปฏิบัติการ| android 8.0'],
#  'category_1_206': ['|ประเภท |โทรศัพท์มือถือและแท็บเล็ต',
#   '|ประเภทย่อย| แท็บเล็ต',
#   '|แบรนด์| เลโนโว่',
#   '|sku| 616388832 th 1170652433',
#   '|กล้องหน้า| ล้านพิกเซล 1 2ล้านพิกเซล ',
#   '|ขนาดหน้าจอ| นิ้ว 10.1',
#   '|รุ่น| tab m10 x505l za4h0069th ',
#   '|ระยะเวลาการรับประกัน| 1 ปี',
#   '|ระบบปฏิบัติการ| android 9.0 pie',
#   '|ความละเอียด| hd'],
#  'category_1_207': ['|ประเภท |โทรศัพท์มือถือและแท็บเล็ต',
#   '|ประเภทย่อย| แท็บเล็ต',
#   '|แบรนด์| เลโนโว่',
#   '|sku| 505022151 th 895278817',
#   '|ระยะเวลาการรับประกัน| 1 ปี',
#   '|ระบบปฏิบัติการ| android 7.0 nougat',
#   '|กล้องหน้า| ล้านพิกเซล 1 2ล้านพิกเซล ',
#   '|ขนาดหน้าจอ| นิ้ว 8',
#   '|รุ่น| tab4 8hd 8504x za2d0078th ',
#   '|ความละเอียด| hd'],
#  'category_1_208': ['|ประเภท |โทรศัพท์มือถือและแท็บเล็ต',
#   '|ประเภทย่อย| แท็บเล็ต',
#   '|แบรนด์| เลโนโว่',
#   '|sku| 587746754 th 1091566194',
#   '|รุ่น| tab m10 x505l za4h0069th ',
#   '|ระยะเวลาการรับประกัน| 1 ปี',
#   '|ระบบปฏิบัติการ| android'],
#  'category_1_209': ['|ประเภท |โทรศัพท์มือถือและแท็บเล็ต',
#   '|ประเภทย่อย| แท็บเล็ต',
#   'กล้องดิจิตอล 5 ล้านพิกเซล digital camera หน่วยความจำ16 gb ตัวเครื่อง |ram| 2gbจอกว้าง 8 นิ้ว แนวทะแยง ',
#   '|ประเภทย่อย| แท็บเล็ต',
#   '|ระบบปฏิบัติการ| os |cpu| ',
#   '|ระบบปฏิบัติการ| android 7.1 nougat ',
#   '|หน่วยประมวลผล| qualcomm msm8917 snapdragon 425 quad core',
#   '|กล้องหน้า| front camera ',
#   '|แบรนด์| เลโนโว่',
#   '|sku| le611elaatacyganth 59998412',
#   '|ขนาดหน้าจอ| นิ้ว 8',
#   '|รุ่น| tb4 8504x 2 16gb',
#   '|ระยะเวลาการรับประกัน| 1 ปี',
#   '|ระบบปฏิบัติการ| android'],
#  'category_1_210': ['|ประเภท |โทรศัพท์มือถือและแท็บเล็ต',
#   '|ประเภทย่อย| แท็บเล็ต',
#   '|ระบบปฏิบัติการ| os ',
#   '|หน้าจอแสดงผล| จอแสดงผล '],
#  'category_1_211': ['|ประเภท |โทรศัพท์มือถือและแท็บเล็ต',
#   '|ประเภทย่อย| แท็บเล็ต',
#   '|รองรับ| 3g with voice โทรได้ ',
#   '|แบรนด์| เลโนโว่',
#   '|sku| 616450213 th 1170652707',
#   '|กล้องหน้า| ล้านพิกเซล 0 1ล้านพิกเซล ',
#   '|ขนาดหน้าจอ| นิ้ว 7',
#   '|รุ่น| tab4 7104i za410083th ',
#   '|ระยะเวลาการรับประกัน| 1 ปี',
#   '|ระบบปฏิบัติการ| android 8.0'],
#  'category_1_212': ['|ประเภท |โทรศัพท์มือถือและแท็บเล็ต',
#   '|ประเภทย่อย| แท็บเล็ต',
#   '|แบรนด์| เลโนโว่',
#   '|sku| 616470088 th 1170736144',
#   '|กล้องหน้า| ล้านพิกเซล 1 2ล้านพิกเซล ',
#   '|ขนาดหน้าจอ| นิ้ว 10.1',
#   '|รุ่น| lenovo tab m10 x505l za4h0069th ',
#   '|ระยะเวลาการรับประกัน| 1 ปี',
#   '|ระบบปฏิบัติการ| android 9.0 pie',
#   '|ความละเอียด| hd'],
#  'category_1_213': ['|ประเภท |โทรศัพท์มือถือและแท็บเล็ต',
#   '|ประเภทย่อย| แท็บเล็ต',
#   'osandroid 8.1 oreoconnectivitywifi 3gcellularcomm standardsgsm hspatechnology2g 4g2g networkgsm 850 900 1800 19003g networkhsdpa 2100จอแสดงผล screen size7 inchesresolutionhd 1024x600 multitouch5 point multi touchfeatureschipsetmediatek mt8167a d 4c 4x a35 1.3ghz |gpu|integrated img ge8300 graphicsmemory และ storageinternal memory16 gb|ram|1 gbcamerarear front camera2ล้านพิกเซล 0.3ล้านพิกเซล connectivitywifi type802.11 b g nbluetoothbluetooth 4.0audiomicrophonemonauralbattery|ความจุแบตเตอรี่| 2750 mahusage timeup to 8 hours',
#   '|แบรนด์| เลโนโว่',
#   '|sku| 267260291 th 417588813',
#   '|รุ่น| e7 tb 7104i',
#   '|ระยะเวลาการรับประกัน| 1 ปี',
#   '|ระบบปฏิบัติการ| android'],
#  'category_1_214': ['|ประเภท |โทรศัพท์มือถือและแท็บเล็ต',
#   '|ประเภทย่อย| แท็บเล็ต',
#   '|แบรนด์| เลโนโว่',
#   '|sku| 616410628 th 1170652391',
#   '|กล้องหน้า| ล้านพิกเซล 0 1ล้านพิกเซล ',
#   '|ขนาดหน้าจอ| นิ้ว 7',
#   '|รุ่น| tab4 7104i za410083th ',
#   '|ระยะเวลาการรับประกัน| 1 ปี',
#   '|ระบบปฏิบัติการ| android 8.0'],
#  'category_1_215': ['|ประเภท |โทรศัพท์มือถือและแท็บเล็ต',
#   '|ประเภทย่อย| แท็บเล็ต',
#   '|รองรับ| 3g with voice โทรได้ ',
#   '|แบรนด์| เลโนโว่',
#   '|sku| 616462030 th 1170676586',
#   '|กล้องหน้า| ล้านพิกเซล 0 1ล้านพิกเซล ',
#   '|ขนาดหน้าจอ| นิ้ว 7',
#   '|รุ่น| tab4 7104i za410083th ',
#   '|ระยะเวลาการรับประกัน| 1 ปี',
#   '|ระบบปฏิบัติการ| android 8.0'],
#  'category_1_216': ['|ประเภท |โทรศัพท์มือถือและแท็บเล็ต',
#   '|ประเภทย่อย| แท็บเล็ต',
#   '|แบรนด์| เลโนโว่',
#   '|sku| 616444557 th 1170684894',
#   '|กล้องหน้า| ล้านพิกเซล 1 2ล้านพิกเซล ',
#   '|ขนาดหน้าจอ| นิ้ว 10.1',
#   '|รุ่น| lenovo tab m10 x505l za4h0069th ',
#   '|ระยะเวลาการรับประกัน| 1 ปี',
#   '|ระบบปฏิบัติการ| android 9.0 pie',
#   '|ความละเอียด| hd'],
#  'category_1_217': ['|ประเภท |โทรศัพท์มือถือและแท็บเล็ต',
#   '|ประเภทย่อย| แท็บเล็ต',
#   '|cpu| quad core 1.3ghz',
#   '|แบรนด์| เลโนโว่',
#   '|sku| 271949397 th 427884556',
#   '|รุ่น| tab4 7104i ',
#   '|ระยะเวลาการรับประกัน| 1 ปี'],
#  'category_1_218': ['|ประเภท |โทรศัพท์มือถือและแท็บเล็ต',
#   '|ประเภทย่อย| แท็บเล็ต',
#   '|หน้าจอ| 7 hd 1024 x 600 ',
#   'ใช้ |cpu| mediatek mt6735 quad core ความเร็ว 1.1ghz',
#   '|ram| 1gb |rom| 16gb |รองรับ| micro sd card สูงสุด 128 gb',
#   '|กล้องหลัง| ล้านพิกเซล ',
#   '|กล้องหน้า| ล้านพิกเซล ',
#   '|แบตเตอรี่| 3450 mah',
#   '|ระบบปฏิบัติการ|เวอร์ชั่น android 7.0 nougat ',
#   '|หน้าจอ| 7 hd 1024 x 600 ',
#   'ใช้ |cpu| mediatek mt6735 quad core ความเร็ว 1.1ghz',
#   '|ram| 1gb |rom| 16gb |รองรับ| micro sd card สูงสุด 128 gb',
#   '|กล้องหลัง| ล้านพิกเซล ',
#   '|กล้องหน้า| ล้านพิกเซล ',
#   '|แบตเตอรี่| 3450 mah',
#   '|ระบบปฏิบัติการ|เวอร์ชั่น android 7.0 nougat ',
#   '|แบรนด์| เลโนโว่',
#   '|sku| 454626123 th 838876875',
#   '|ระยะเวลาการรับประกัน| 1 ปี',
#   '|ระบบปฏิบัติการ| android 7.0 nougat',
#   '|กล้องหน้า| ล้านพิกเซล 1 2ล้านพิกเซล ',
#   '|ขนาดหน้าจอ| นิ้ว 7',
#   '|รุ่น| tb 7304x'],
#  'category_1_219': ['|ประเภท |โทรศัพท์มือถือและแท็บเล็ต',
#   '|ประเภทย่อย| แท็บเล็ต',
#   '|น้ำหนัก| 0.26 kg',
#   '|แบรนด์| เลโนโว่',
#   '|sku| 564446979 th 1034898602',
#   '|รุ่น| tb 7504x',
#   '|ระยะเวลาการรับประกัน| 1 ปี',
#   '|ระบบปฏิบัติการ| android'],
#  'category_1_220': [' 10 inch tablet android 9.0 แถมฟรี หูฟังไร้สาย ตุ๊กตาหมี แท็บเล็ต ระบบแอนดรอยด์andorid ข้อเสนอที่ดีที่สุด จัดส่งฟรี รับประกันหนึ่งปี แท็ปเล็ต 10นิ้ว octa core 6gb |ram| 128gb |rom| 3g 4g fdd lte wifi bluetooth gps phone call glass screen tablet pc ฿ 3832.00 ฿ 7999.00 52เปอร์เซนต์ ',
#   'แท็บเล็ต pad 2019 ใส่ซิมได้ 2 ซิม จอใหญ่สุดคุ้ม |ขนาด|10.5นิ้ว มีระบบ 3g ทุกระบบ มีไวไฟ เล่นเน็ตสุดคุ้ม โทรเข้าออกเหมือนมือถือ ฿ 3250.00 ฿ 5990.00 46เปอร์เซนต์ ',
#   'all new kindle paperwhite 4 |รุ่น|ใหม่ล่าสุด ปี 2019 10th gen e book reader 8gb black ฿ 4099.00',
#   'ใหม่ 10.1 นิ้ว android 8.1 10 แท็บเล็ตพีซีคอร์ 128gb wifi bluetooth hd |หน้าจอ|สัมผัส ฿ 1272.30 ฿ 2205.00 42เปอร์เซนต์ '],
#  'category_1_221': ['|ประเภท |โทรศัพท์มือถือและแท็บเล็ต',
#   '|ประเภทย่อย| แท็บเล็ต',
#   '|หน้าจอ| 7 hd 1024 x 600 ',
#   'ใช้ |cpu| mediatek mt6735 quad core ความเร็ว 1.1ghz',
#   '|ram| 1gb |rom| 16gb |รองรับ| micro sd card สูงสุด 128 gb',
#   '|กล้องหลัง| ล้านพิกเซล ',
#   '|กล้องหน้า| ล้านพิกเซล ',
#   '|แบตเตอรี่| 3450 mah',
#   '|ระบบปฏิบัติการ|เวอร์ชั่น android 7.0 nougat ',
#   '|หน้าจอ| 7 hd 1024 x 600 ',
#   'ใช้ |cpu| mediatek mt6735 quad core ความเร็ว 1.1ghz',
#   '|ram| 1gb |rom| 16gb |รองรับ| micro sd card สูงสุด 128 gb',
#   '|กล้องหลัง| ล้านพิกเซล ',
#   '|กล้องหน้า| ล้านพิกเซล ',
#   '|แบตเตอรี่| 3450 mah',
#   '|ระบบปฏิบัติการ|เวอร์ชั่น android 7.0 nougat ',
#   '|แบรนด์| เลโนโว่',
#   '|sku| 448778270 th 828394561',
#   '|รุ่น| tb 7304x',
#   '|ระยะเวลาการรับประกัน| 1 ปี',
#   '|ระบบปฏิบัติการ| android 7.0 nougat'],
#  'category_1_222': ['|ประเภท |โทรศัพท์มือถือและแท็บเล็ต',
#   '|ประเภทย่อย| แท็บเล็ต',
#   '|น้ำหนัก| 0.32 kg',
#   '|แบรนด์| เลโนโว่'],
#  'category_1_223': ['|ประเภท |โทรศัพท์มือถือและแท็บเล็ต',
#   '|ประเภทย่อย| แท็บเล็ต',
#   'lenovo tab4 7 แท็บเล็ตจอ ips 7 นิ้ว|รองรับ| 4g โทรได้ ใช้งานได้ทุกที่ทุกเวลา ตามที่คุณต้องการ สะดวกพกพาง่าย ประหยัด คุ้มค่า',
#   '|แบรนด์| เลโนโว่',
#   '|sku| 527686316 th 946952842',
#   '|รุ่น| tab4 za380137th',
#   '|ระยะเวลาการรับประกัน| 1 ปี',
#   '|ระบบปฏิบัติการ| android 7.0 nougat'],
#  'category_1_224': ['|ประเภท |โทรศัพท์มือถือและแท็บเล็ต',
#   '|ประเภทย่อย| แท็บเล็ต',
#   '|แบรนด์| เลโนโว่',
#   '|sku| 297482165 th 508638091',
#   '|กล้องหน้า| ล้านพิกเซล 0 1ล้านพิกเซล ',
#   '|ขนาดหน้าจอ| นิ้ว 7',
#   '|รุ่น| za410083th',
#   '|ระยะเวลาการรับประกัน| 1 ปี',
#   '|ระบบปฏิบัติการ| android 8.1 oreo'],
#  'category_1_225': ['|ประเภท |โทรศัพท์มือถือและแท็บเล็ต',
#   '|ประเภทย่อย| แท็บเล็ต',
#   'lenovo tablet tab4 8 |โมเดล| tb 8504x black แถมฟรี เคสของแท้พร้อมฟิล์ม',
#   '|cpu| quad core 1.4ghz',
#   '|แบรนด์| เลโนโว่',
#   '|sku| 479414707 th 869558314',
#   '|รุ่น| tb 8504x',
#   '|ระยะเวลาการรับประกัน| 1 ปี',
#   '|ระบบปฏิบัติการ| android 7.0 nougat'],
#  'category_1_226': ['|ประเภท |โทรศัพท์มือถือและแท็บเล็ต',
#   '|ประเภทย่อย| แท็บเล็ต',
#   '|cpu| octa core 1.4ghz',
#   '|แบรนด์| เลโนโว่',
#   '|sku| 295768242 th 500194997',
#   '|รุ่น| lenovo k6 note |ram|4 32gb ลดclearstock ไม่มีประกัน grey ',
#   '|ระบบปฏิบัติการ| android'],
#  'category_1_227': ['|ประเภท |โทรศัพท์มือถือและแท็บเล็ต',
#   '|ประเภทย่อย| แท็บเล็ต',
#   'lenovo tab4 x704l 10plus 10.1 fhd กล้อง ล้านพิกเซล ล้านพิกเซล |ram| 4gb |rom| 64gb lte ',
#   'จอ 10.1 fhd |ความละเอียด|',
#   'android 7.0 nougat |รองรับ| 4g',
#   '|แบรนด์| เลโนโว่',
#   '|sku| le611elaasgg63anth 58279737',
#   '|กล้องหน้า| ล้านพิกเซล 5 6ล้านพิกเซล ',
#   '|ขนาดหน้าจอ| นิ้ว 10.1',
#   '|รุ่น| tab4 10plus x704l',
#   '|ระยะเวลาการรับประกัน| 1 ปี',
#   '|ระบบปฏิบัติการ| android',
#   '|ความละเอียด| full hd'],
#  'category_1_228': ['|ประเภท |โทรศัพท์มือถือและแท็บเล็ต',
#   '|ประเภทย่อย| แท็บเล็ต',
#   '|cpu| quad core 1.1ghz',
#   '|แบรนด์| เลโนโว่',
#   '|sku| le954elabkir8janth 126890450',
#   '|ขนาดหน้าจอ| นิ้ว 7',
#   '|รุ่น| lenovo tablet 7 4g call tab4 essential 7304x black',
#   '|ระยะเวลาการรับประกัน| 1 ปี',
#   '|ระบบปฏิบัติการ| android'],
#  'category_1_229': ['|ประเภท |โทรศัพท์มือถือและแท็บเล็ต',
#   '|ประเภทย่อย| แท็บเล็ต',
#   'lenovo tb 8504xprocessor qualcomm msm8917 snapdragon quad core 1.4 ghz|ram| 2gb|rom| 16gbmemory card up to 128gbจอแสดงผล 8 inch ipsresolution 1280 x 800 pxfront camera ล้านพิกเซล fixed focusback camera ล้านพิกเซล auto focusi o interfaces 3.5mm combo audio jack',
#   'micro usb connector for power charger and data syncaudio dolby atmos 2 x front facing speakersnetwork wi fi 802.11 b g n single channel 2.4 ghz bluetooth bluetooth 4.0sensor g sensor p sensor l sensor vibratorระบบแผนที่ดาวเทียม gps gps glonassoperating system android 7.0 nougatbattery 4850 mah li ion polymerdimensions 211x124x8.3 มม. 8.31x4.88.0.22 inches|น้ำหนัก| 320g 0.7 lbs function calls yesfrequency support gsm b2 3 5 8',
#   '|แบรนด์| เลโนโว่',
#   '|sku| le634elabk0menanth 125919785',
#   '|ขนาดหน้าจอ| นิ้ว 8',
#   '|รุ่น| tab4 8504x',
#   '|ระยะเวลาการรับประกัน| 1 ปี',
#   '|ระบบปฏิบัติการ| android'],
#  'category_1_230': ['|ประเภท |โทรศัพท์มือถือและแท็บเล็ต',
#   '|ประเภทย่อย| แท็บเล็ต',
#   '|cpu| octa core 1.4ghz',
#   '|แบรนด์| เลโนโว่',
#   '|sku| 295764269 th 500218143',
#   '|รุ่น| lenovo k6 note |ram|4 32gb ลดclearstock ไม่มีประกัน gold ',
#   '|ระบบปฏิบัติการ| android'],
#  'category_1_231': ['|ประเภท |โทรศัพท์มือถือและแท็บเล็ต',
#   '|ประเภทย่อย| แท็บเล็ต',
#   '|cpu| quad core 1.1gh',
#   '|แบรนด์| เลโนโว่',
#   '|sku| le611elabgdkr5anth 117213539',
#   '|ขนาดหน้าจอ| นิ้ว 7',
#   '|รุ่น| tab4 essential 7304x',
#   '|ระยะเวลาการรับประกัน| 1 ปี',
#   '|ระบบปฏิบัติการ| android'],
#  'category_1_232': ['|ประเภท |โทรศัพท์มือถือและแท็บเล็ต',
#   '|ประเภทย่อย| แท็บเล็ต',
#   '|แบรนด์| เลโนโว่',
#   '|sku| 224964566 th 343772150',
#   '|รุ่น| psmartitplus a0080561'],
#  'category_1_233': ['|ประเภท |โทรศัพท์มือถือและแท็บเล็ต',
#   '|ประเภทย่อย| แท็บเล็ต',
#   '|หน้าจอ| 8 นิ้ว |ความละเอียด| 1280x800 พิกเซล',
#   '|cpu| octa core 1.0ghz',
#   '|กล้องหลัง| 5 ล้านพิกเซล',
#   '|กล้องหน้า| 2 ล้านพิกเซล',
#   '|แบตเตอรี่| 4290mah',
#   '|รองรับ|การเชือมต่อ wifi 802.11 b g n bluetooth 4.0',
#   '|แบรนด์| เลโนโว่',
#   '|sku| le611elaae2m7lanth 28482262',
#   '|กล้องหน้า| ล้านพิกเซล 1 2ล้านพิกเซล ',
#   '|ขนาดหน้าจอ| นิ้ว 8',
#   '|รุ่น| tablet 8 4gcall lenovo tab3 850 black',
#   '|ระยะเวลาการรับประกัน| 1 ปี',
#   '|ระบบปฏิบัติการ| android'],
#  'category_1_234': ['|ประเภท |โทรศัพท์มือถือและแท็บเล็ต',
#   '|ประเภทย่อย| แท็บเล็ต',
#   '|cpu| octa core 2.0ghz',
#   '|แบรนด์| เลโนโว่',
#   '|sku| 333478869 th 644516097',
#   '|รุ่น| tab4 10 plus x704l ',
#   '|ระยะเวลาการรับประกัน| 1 ปี',
#   '|ระบบปฏิบัติการ| android 7.0 nougat'],
#  'category_1_235': ['|ประเภท |โทรศัพท์มือถือและแท็บเล็ต',
#   '|ประเภทย่อย| แท็บเล็ต',
#   '|หน้าจอ| 7 นิ้ว |ความละเอียด| 1024 x 600 พิกเซล',
#   '|cpu| quad core 1.3 ghz',
#   '|รองรับ| microsd card สูงสุด 32 gb',
#   '|กล้องหน้า| 0.3 ล้านพิกเซล',
#   '|กล้องหลัง| 2.0 ล้านพิกเซล',
#   '|แบตเตอรี่| 3450 mah',
#   '|รองรับ|การเชือมต่อ wifi 802.11b g n bluetooth 4.0',
#   '|แบรนด์| เลโนโว่',
#   '|sku| le611elaa4mwvianth 9960417',
#   '|ระยะเวลาการรับประกัน| 1 ปี',
#   '|ระบบปฏิบัติการ| android os v4.4 kitkat ',
#   '|กล้องหน้า| ล้านพิกเซล 0 1ล้านพิกเซล ',
#   '|ขนาดหน้าจอ| นิ้ว 7',
#   '|รุ่น| anusra computer tablet 7 wifi lenovo tab2 a7 20 8gb. black '],
#  'category_1_236': ['|ประเภท |โทรศัพท์มือถือและแท็บเล็ต',
#   '|ประเภทย่อย| แท็บเล็ต',
#   '|cpu| quad core 1.3ghz',
#   '|แบรนด์| เลโนโว่',
#   '|sku| le611elaa7ywwkanth 16584510',
#   '|ขนาดหน้าจอ| นิ้ว 7',
#   '|รุ่น| lenovo tab4 7104i ',
#   '|ระยะเวลาการรับประกัน| 1 ปี',
#   '|ระบบปฏิบัติการ| android'],
#  'category_1_237': ['|ประเภท |โทรศัพท์มือถือและแท็บเล็ต',
#   '|ประเภทย่อย| แท็บเล็ต',
#   'lenovo tab e7|หน้าจอ| lcd tn panel |ขนาด| 7.0 นิ้ว |ความละเอียด| 1200 x 600 px',
#   '|cpu| mediatek mt8167 chipset quad core 1.3ghz ',
#   '|ram| 1 gb storage 16 gb |รองรับ| microsd card ',
#   '|กล้องหน้าความละเอียด| 0.2ล้านพิกเซล และ|กล้องหลังความละเอียด| 2ล้านพิกเซล ',
#   '|แบตเตอรี่ขนาด| 2750 mah ทางเลอโนเวอเคลมไว้ว่าสามารถดูวีดีโอได้นานถึง 5 ชั่วโมงเลยทีเดียว',
#   'รันบน|ระบบปฏิบัติการ| android 8.1 oreo go edition lenovo tab e7',
#   '|แบรนด์| เลโนโว่',
#   '|sku| 523078318 th 933300133',
#   '|รุ่น| tab e7',
#   '|ระบบปฏิบัติการ| android'],
#  'category_1_238': ['|ประเภท |โทรศัพท์มือถือและแท็บเล็ต',
#   '|ประเภทย่อย| แท็บเล็ต',
#   'tablet 10.1 4g lenovo tab4 10 plus x704l ebony black |cpu| octa core 2.0 ghz ประกัน 1y',
#   '|cpu| octacore 2.0ghz',
#   '|แบรนด์| เลโนโว่',
#   '|sku| 254158707 th 392325427',
#   '|ขนาดหน้าจอ| นิ้ว 10',
#   '|กล้องหน้า| ล้านพิกเซล 5 6ล้านพิกเซล ',
#   '|รุ่น| tab4 10 plus x704l ',
#   '|ระยะเวลาการรับประกัน| 1 ปี',
#   '|ระบบปฏิบัติการ| android 7.0 nougat'],
#  'category_1_239': ['|ประเภท |โทรศัพท์มือถือและแท็บเล็ต',
#   '|ประเภทย่อย| แท็บเล็ต',
#   '|แบรนด์| เลโนโว่',
#   '|sku| 332512941 th 641144040',
#   '|รุ่น| tb 7104l',
#   '|ระยะเวลาการรับประกัน| 1 ปี'],
#  'category_1_240': ['|ประเภท |โทรศัพท์มือถือและแท็บเล็ต',
#   '|ประเภทย่อย| แท็บเล็ต',
#   '|แบรนด์| เลโนโว่',
#   '|sku| 487584299 th 875784181',
#   '|ระยะเวลาการรับประกัน| 1 ปี',
#   '|ระบบปฏิบัติการ| android',
#   '|กล้องหน้า| ล้านพิกเซล 0 1ล้านพิกเซล ',
#   '|ขนาดหน้าจอ| นิ้ว 7',
#   '|รุ่น| tab4 7104i za410083th ',
#   '|ความละเอียด| hd'],
#  'category_1_241': ['|ประเภท |โทรศัพท์มือถือและแท็บเล็ต',
#   '|ประเภทย่อย| แท็บเล็ต',
#   '|หน้าจอ| 8 นิ้ว |ความละเอียด| 1280x800 พิกเซล',
#   '|cpu| octa core 1.0ghz',
#   '|กล้องหลัง| 5 ล้านพิกเซล',
#   '|กล้องหน้า| 2 ล้านพิกเซล',
#   '|แบตเตอรี่| 4290mah',
#   '|รองรับ|การเชือมต่อ wifi 802.11 b g n bluetooth 4.0',
#   '|แบรนด์| เลโนโว่',
#   '|sku| le611elaal4zmjanth 42868896',
#   '|กล้องหน้า| ล้านพิกเซล 1 2ล้านพิกเซล ',
#   '|ขนาดหน้าจอ| นิ้ว 8',
#   '|รุ่น| tablet 8 4gcall lenovo tab3 850 black',
#   '|ระยะเวลาการรับประกัน| 1 ปี',
#   '|ระบบปฏิบัติการ| android v4.4'],
#  'category_1_242': ['chuwi hi10 air 2 in 1 tablet laptop pc 10.1 นิ้ว จอ fhd ogs วินโดร์ 10 แท้ intel quad core 1.92ghz |ram| 4gb |ความจุ| 64gb type c ฿ 6290.00 ฿ 9990.00 37เปอร์เซนต์ ',
#   'โน้ตบุ๊คและแท็บเล็ต lenovo 2 in 1 ideapad d330 10igm 81h3005ata wifi celeron n4000 10.1 inch |ram| 4gb lpddr4 2133 integrated graphic 64gb emmc win 10 รับประกันศูนย์ lenovo 1 ปี mineral gray free active pen โน๊ตบุ๊คถูก ผ่อน 0เปอร์เซนต์ สูงสุด 10 เดือน ส่งเร็ว ฿ 9490.00 ฿ 12990.00 27เปอร์เซนต์ ',
#   'chuwi hi9 plus helio x27 deca core แอนดรอยด์ 8.0 10.8 นิ้ว จอละเอียด 2560x1600 |ram| 4gb |ความจุ| 64 128gb ใส่ได้ 2 ซิม โทรได้|รองรับ| 4g |รองรับ|คีย์บอร์ด ปากกา ฿ 6990.00 ฿ 12990.00 46เปอร์เซนต์ ',
#   'jy teclast p80h แท็บเล็ต pc 8 wxga ips |หน้าจอ| android 8 กิกะไบต์ |rom| otg hdmi aus ฿ 2278.80 ฿ 4147.40 45เปอร์เซนต์ '],
#  'category_1_243': ['|ประเภท |โทรศัพท์มือถือและแท็บเล็ต',
#   '|ประเภทย่อย| แท็บเล็ต',
#   '|แบรนด์| เลโนโว่',
#   '|sku| 404360545 th 784536408',
#   '|รุ่น| tb 7504x',
#   '|ระยะเวลาการรับประกัน| 1 ปี']}

# %% [markdown]
# # Capture attribute manual

# %%
# Split attribute
def cap_attr(text):
    text = text.split("|")
    
    return text

# %%
# capture attribute by split the marker
attr = {}
for i,v in attr_mark.items():
    tmp_list = []
    for txt in v:
        match = cap_attr(txt)
        match = [m for m in match if not m =='' and not m == ' ']
        tmp_list.append(match)
    attr[i] = tmp_list

# %%
attr
# Out:
# {'category_0_0': [['ประเภท ', 'โทรศัพท์มือถือและแท็บเล็ต'],
#   ['ประเภทย่อย', ' สมาร์ทโฟน'],
#   ['แบตอึดอยู่นาน สนุกได้ทั้งวัน กับ',
#    'ความจุ',
#    ' 6000 mah และสามารถชาร์จแบตเร็ว ด้วย fast charging'],
#   ['ระบบ',
#    'กล้องหลัง',
#    ' 3 ตัว ที่มีกล้องชัดสูงสุดถึง 48ล้านพิกเซล มาพร้อมกับเลนส์มุมกว้างพิเศษ ultra wide'],
#   ['หน้าจอแสดงผล', ' super amoled infinity u ', 'ขนาด', ' 6.4 นิ้ว'],
#   ['แบรนด์', ' ซัมซุง'],
#   ['sku', ' 480942616 th 870640886'],
#   ['โมเดล', ' galaxy m30s 4 64gb '],
#   ['ระยะเวลาการรับประกัน', ' 1 ปี']],
#  'category_0_1': [['ประเภท ', 'โทรศัพท์มือถือและแท็บเล็ต'],
#   ['ประเภทย่อย', ' สมาร์ทโฟน'],
#   ['รองรับ', ' 2 ซิม nano sim'],
#   ['หน่วยประมวลผล', ' exynos 9610 quad 2.3 ghz quad 1.7 ghz'],
#   ['ระบบปฏิบัติการ', ' android'],
#   ['หน่วยความจำภายใน 64gb เพิ่ม micro sd ', 'รองรับ', 'สูงสุด 512 gb'],
#   ['หน้าจอ', ' 6.4 นิ้ว ', 'ความละเอียด', ' 1080 x 2340 พิกเซล fhd '],
#   ['กล้องหลัง',
#    ' 3 เลนส์ 48 ล้านพิกเซล f 2.0 5 ล้านพิกเซล f 2.2 bokeh 8 ล้านพิกเซล f 2.4 ultrawide แฟลช led'],
#   ['กล้องหน้า', ' 32 ล้านพิกเซล f 2.0'],
#   ['แบตเตอรี่', ' 4000 mah'],
#   ['ขนาด', ' 158.5 x 74.5 x 7.7 มม. '],
#   ['น้ำหนัก', ' 169 g'],
#   ['แบรนด์', ' ซัมซุง'],
#   ['sku', ' 593772364 th 1113954823'],
#   ['ระยะเวลาการรับประกัน', ' 1 ปี'],
#   ['กล้องหน้า', ' ล้านพิกเซล 7ล้านพิกเซล ขึ้นไป'],
#   ['ระบบปฏิบัติการ', 'เวอร์ชัน android 9.0 pie'],
#   ['โมเดล', ' a50s'],
#   ['ขนาดหน้าจอ', ' นิ้ว 6.4'],
#   ['ความจุแบตเตอรี่', ' 1000 mah ถึง 5000 mah']],
#  'category_0_2': [['ประเภท ', 'โทรศัพท์มือถือและแท็บเล็ต'],
#   ['ประเภทย่อย', ' สมาร์ทโฟน'],
#   ['สมาร์ทโฟน โทรศัพท์มือถือพร้อม', 'ระบบปฏิบัติการ'],
#   ['จอแสดงผล tft lcd 24 bit 16 ล้านสี ',
#    'หน้าจอ',
#    'ทรงหยดน้ำ รูปตัว v infinity v กว้าง 6.2 นิ้ว แนวทะแยง ',
#    'ความละเอียด',
#    ' 1520 x 720 พิกเซล'],
#   ['แบรนด์', ' ซัมซุง'],
#   ['sku', ' 404422189 th 784670279'],
#   ['ระยะเวลาการรับประกัน', ' 1 ปี'],
#   ['ระบบปฏิบัติการ', ' android 9.0 pie'],
#   ['กล้องหน้า', ' ล้านพิกเซล 7ล้านพิกเซล ขึ้นไป'],
#   ['ระบบปฏิบัติการ', 'เวอร์ชัน android 9.0 pie'],
#   ['โมเดล', ' samsung galaxy a10s ', 'ram', '2gb ', 'rom', '32gb '],
#   ['ขนาดหน้าจอ', ' นิ้ว 6.2'],
#   ['ความจุแบตเตอรี่', ' 1000 mah ถึง 5000 mah']],
#  'category_0_3': [['ประเภท ', 'โทรศัพท์มือถือและแท็บเล็ต'],
#   ['ประเภทย่อย', ' สมาร์ทโฟน'],
#   ['ขนาดหน้าจอ', ' 6.8 นิ้ว'],
#   ['ความจุ', 'ที่เก็บข้อมูล 256 gb'],
#   ['แบตเตอรี่', ' 4300 mah typical '],
#   ['มาตรฐานการกันน้ำและกันฝุ่น', ' ip68'],
#   ['แบรนด์', ' ซัมซุง'],
#   ['sku', ' 385536916 th 749070165'],
#   ['โมเดล', ' galaxy note 10 '],
#   ['ขนาดหน้าจอ', ' นิ้ว 6.8'],
#   ['ระยะเวลาการรับประกัน', ' 1 ปี']],
#  'category_0_4': [['ประเภท ', 'โทรศัพท์มือถือและแท็บเล็ต'],
#   ['ประเภทย่อย', ' สมาร์ทโฟน'],
#   ['ระบบเซ็นเซอร์ sensor ระบบตรวจสอบลายนิ้วมือ fingerprint ระบบหมุนภาพอัตโนมัติ accele',
#    'rom',
#    'eter ระบบเปิด ปิด',
#    'หน้าจอ',
#    'อัตโนมัติขณะสนทนา proximity ระบบตรวจจับคลื่นแม่เหล็ก geomagnetic ระบบเซนเซอร์หมุนภาพ gyroscope ระบบวัดความกดอากาศ ba',
#    'rom',
#    'eter '],
#   ['รองรับ', ' 2 ซิมการ์ด'],
#   ['ระบบปฏิบัติการ', ' android 6.0.1 marshmallow '],
#   ['หน่วยประมวลผล', ' octa core ความเร็ว 1.9 ghz'],
#   ['bluetooth 4.2 ', 'รองรับ', 'ชุดหูฟังสเตอริโอ a2dp bluetooth stereo '],
#   ['รองรับ', ' nfc near field communication '],
#   ['กล้องดิจิตอล 16 ล้านพิกเซล digital camera ',
#    'รูรับแสงขนาด',
#    ' 1.9 ไฟแฟลช led โฟกัสอัตโนมัติ auto focus แตะเลือกจุดโฟกัส touch focus ค้นหาใบหน้าอัตโนมัติ face detection โหมดถ่ายภาพพาโนราม่า pano',
#    'ram',
#    'a '],
#   ['กล้องหน้า',
#    ' front camera ',
#    'ความละเอียด',
#    ' 16ล้านพิกเซล ',
#    'รูรับแสงขนาด',
#    ' 1.9'],
#   ['เครื่องเล่นวีดีโอ video player รูปแบบไฟล์ ล้านพิกเซล eg 4 wmv h.264 h.263 ',
#    'รองรับ',
#    'วีดีโอจาก youtube ']],
#  'category_0_5': [['ประเภท ', 'โทรศัพท์มือถือและแท็บเล็ต'],
#   ['ประเภทย่อย', ' สมาร์ทโฟน'],
#   ['samsung galaxy a9 2018 6 gb ',
#    'ram',
#    ' 128 gb ',
#    'rom',
#    ' 6.3 นิ้ว 5 กล้อง สูงสุด 24ล้านพิกเซล tetra cell f1.7 โทรศัพท์มือถือ '],
#   ['กล้องดิจิตอล main camera 2ล้านพิกเซล ultra wide camera ล้านพิกเซล telephoto camera 1ล้านพิกเซล depth camera ล้านพิกเซล fourth camera ',
#    'รูรับแสงขนาด',
#    ' 1.7'],
#   ['กล้องหน้า', 'ความละเอียด', ' 24ล้านพิกเซล '],
#   ['แบรนด์', ' ซัมซุง'],
#   ['sku', ' 265390897 th 412154584'],
#   ['โมเดล', ' galaxy a9 2018 '],
#   ['ระยะเวลาการรับประกัน', ' 1 ปี']],
#  'category_0_6': [['ประเภท ', 'โทรศัพท์มือถือและแท็บเล็ต'],
#   ['ประเภทย่อย', ' สมาร์ทโฟน'],
#   ['กว้าง 6.4 นิ้ว แนวทะแยง ', 'ความละเอียด', ' 720 x 1560 พิกเซล 268 ppi '],
#   ['ประเภทจอ corning gorilla glass 3 ', 'ระบบปฏิบัติการ'],
#   ['android 9.0 pie ',
#    'หน่วยประมวลผล',
#    ' exynos 7885 octa core ความเร็ว 1.8 mhz หน่วยความจำ'],
#   ['กล้องดิจิตอล 2ล้านพิกเซล 8ล้านพิกเซล ultrawide 5ล้านพิกเซล depth sensor triple camera ',
#    'รูรับแสงขนาด',
#    ' 1.7 ไฟแฟลช led โหมดถ่ายภาพช่วงการรับแสงสูง hdr '],
#   ['กล้องหน้า',
#    ' front camera ',
#    'ความละเอียด',
#    ' 16ล้านพิกเซล ',
#    'รูรับแสงขนาด',
#    ' 2.0'],
#   ['ใช้งาน nano sim ', 'รองรับ', ' 2 ซิมการ์ด'],
#   ['ระบบเซ็นเซอร์ sensor ระบบสแกนลายนิ้วมือใต้',
#    'หน้าจอ',
#    ' fingerprint under จอแสดงผล ตรวจจับความเคลื่อนไหวของตัวเครื่อง accele',
#    'rom',
#    'eter ระบบเปิด ปิด',
#    'หน้าจอ',
#    'อัตโนมัติขณะสนทนา proximity '],
#   ['แบตเตอรี่', 'มาตรฐาน li pol 4000 mah standard battery '],
#   ['แบรนด์', ' ซัมซุง'],
#   ['sku', ' 594352438 th 1115888431'],
#   ['กล้องหน้า', ' ล้านพิกเซล 16ล้านพิกเซล '],
#   ['โมเดล', ' samsung a30s'],
#   ['ระยะเวลาการรับประกัน', ' 1 ปี'],
#   ['ความจุแบตเตอรี่', ' 1000 mah ถึง 5000 mah']],
#  'category_0_7': [['ประเภท ', 'โทรศัพท์มือถือและแท็บเล็ต'],
#   ['ประเภทย่อย', ' สมาร์ทโฟน'],
#   ['แบรนด์', ' ซัมซุง'],
#   ['sku', ' 599364278 th 1176694583'],
#   ['ระบบปฏิบัติการ', 'เวอร์ชัน android 9.0 pie'],
#   ['โมเดล', ' samsung galaxy note10 plus'],
#   ['ขนาดหน้าจอ', ' นิ้ว 6.8'],
#   ['ระยะเวลาการรับประกัน', ' 1 ปี']],
#  'category_0_8': [['ประเภท ', 'โทรศัพท์มือถือและแท็บเล็ต'],
#   ['ประเภทย่อย', ' สมาร์ทโฟน'],
#   ['หน้าจอ', 'กว้าง 6.7 แบบ infinity u จอแสดงผล '],
#   ['แบรนด์', ' ซัมซุง'],
#   ['sku', ' 309636084 th 547152150'],
#   ['โมเดล', ' a70 8 128gb '],
#   ['ระยะเวลาการรับประกัน', ' 1 ปี']],
#  'category_0_9': [['ประเภท ', 'โทรศัพท์มือถือและแท็บเล็ต'],
#   ['ประเภทย่อย', ' สมาร์ทโฟน'],
#   ['สมาร์ทโฟน โทรศัพท์มือถือ samsung galaxy a10s sm a107m ',
#    'ขนาดหน้าจอ',
#    ' 6.2 นิ้ว ',
#    'ram',
#    ' 2 ',
#    'rom',
#    ' 32 gb สีน้ำเงิน '],
#   ['แบรนด์', ' ซัมซุง'],
#   ['sku', ' 571250946 th 1048780375'],
#   ['ระยะเวลาการรับประกัน', ' 1 เดือน'],
#   ['ประเภทของ', 'แบตเตอรี่', 'แบตเตอรี่', 'ชาร์จใหม่ได้และถอดได้'],
#   ['กล้องหน้า', ' ล้านพิกเซล 7ล้านพิกเซล ขึ้นไป'],
#   ['โมเดล',
#    ' สมาร์ทโฟน โทรศัพท์มือถือ samsung galaxy a10s sm a107m ',
#    'ขนาดหน้าจอ',
#    ' 6.2 นิ้ว ',
#    'ram',
#    ' 2 ',
#    'rom',
#    ' 32 gb สีน้ำเงิน '],
#   ['ประเภท', 'หน้าจอ', ' lcd'],
#   ['ความละเอียด', 'วิดีโอ 1080p'],
#   ['ความจุแบตเตอรี่', ' 1000 mah ถึง 5000 mah']],
#  'category_0_10': [['ประเภท ', 'โทรศัพท์มือถือและแท็บเล็ต'],
#   ['ประเภทย่อย', ' สมาร์ทโฟน'],
#   ['สมาร์ทโฟน โทรศัพท์มือถือพร้อม', 'ระบบปฏิบัติการ'],
#   ['จอแสดงผล super amoled 24 bit 16 ล้านสี กว้าง 5.2 นิ้ว แนวทะแยง ',
#    'ความละเอียด',
#    ' 1080 x 1920 พิกเซล ประเภทจอ ',
#    'หน้าจอ',
#    'กระจกแข็ง ประเภทจอ ระบบป้องกัน ฝุ่นละออง resistance to dust '],
#   ['ระบบเซ็นเซอร์ sensor ระบบตรวจสอบลายนิ้วมือ fingerprint ระบบหมุนภาพอัตโนมัติ accele',
#    'rom',
#    'eter ระบบเปิด ปิด',
#    'หน้าจอ',
#    'อัตโนมัติขณะสนทนา proximity ระบบตรวจจับคลื่นแม่เหล็ก geomagnetic ระบบเซนเซอร์หมุนภาพ gyroscope ระบบวัดความกดอากาศ ba',
#    'rom',
#    'eter '],
#   ['รองรับ', ' 2 ซิมการ์ด'],
#   ['ระบบปฏิบัติการ', ' android 6.0.1 marshmallow '],
#   ['หน่วยประมวลผล', ' octa core ความเร็ว 1.9 ghz'],
#   ['bluetooth 4.2 ', 'รองรับ', 'ชุดหูฟังสเตอริโอ a2dp bluetooth stereo '],
#   ['รองรับ', ' nfc near field communication '],
#   ['กล้องดิจิตอล 16 ล้านพิกเซล digital camera ',
#    'รูรับแสงขนาด',
#    ' 1.9 ไฟแฟลช led โฟกัสอัตโนมัติ auto focus แตะเลือกจุดโฟกัส touch focus โหมดถ่ายภาพพาโนราม่า pano',
#    'ram',
#    'a '],
#   ['กล้องหน้า',
#    ' front camera ',
#    'ความละเอียด',
#    ' 16ล้านพิกเซล ',
#    'รูรับแสงขนาด',
#    ' 1.9'],
#   ['เครื่องเล่นวีดีโอ video player รูปแบบไฟล์ ล้านพิกเซล eg 4 wmv h.264 h.263 ',
#    'รองรับ',
#    'วีดีโอจาก youtube ']],
#  'category_0_11': [['ประเภท ', 'โทรศัพท์มือถือและแท็บเล็ต'],
#   ['ประเภทย่อย', ' สมาร์ทโฟน'],
#   ['หน้าจอแสดงผล', 'แบบ super amoled ', 'ขนาด', ' 5.2 นิ้ว'],
#   ['ความละเอียด', 'ระดับ full hd 1080p 1080x1920 พิกเซล '],
#   ['หน่วยความจำแรม ', 'ram', 'ขนาด', ' 3 gb'],
#   ['หน่วยความจำภายใน', 'ขนาด', ' 32 gb'],
#   ['กล้องด้านหลัง', 'ความละเอียด', ' 16 ล้านพิกเซล'],
#   ['แบรนด์', ' ซัมซุง'],
#   ['sku', ' sa861elaa8nxs2anth 17866375'],
#   ['ระยะเวลาการรับประกัน', ' 1 ปี'],
#   ['ระบบปฏิบัติการ', ' android'],
#   ['กล้องหน้า', ' ล้านพิกเซล 7ล้านพิกเซล ขึ้นไป'],
#   ['ระบบปฏิบัติการ', 'เวอร์ชัน marshmallow'],
#   ['โมเดล', ' samsung galaxy a5 2017 gold'],
#   ['ประเภท', 'หน้าจอ', ' amoled'],
#   ['ขนาดหน้าจอ', ' นิ้ว 5.2']],
#  'category_0_12': [['ประเภท ', 'โทรศัพท์มือถือและแท็บเล็ต'],
#   ['ประเภทย่อย', ' สมาร์ทโฟน'],
#   ['หน้าจอความละเอียด',
#    'สูงระดับ dynamic amoled ให้สีสันและความคมชัดเสมือนจอทีวีระดับพรีเมี่ยม'],
#   ['กล้องหลัง', ' 2ตัวพร้อมระบบถ่ายภาพอัจฉริยะ'],
#   ['แบรนด์', ' ซัมซุง'],
#   ['sku', ' 526004055 th 942110374'],
#   ['โมเดล', ' s10e 6 128gb '],
#   ['ระยะเวลาการรับประกัน', ' 1 ปี']],
#  'category_0_13': [['ประเภท ', 'โทรศัพท์มือถือและแท็บเล็ต'],
#   ['ประเภทย่อย', ' สมาร์ทโฟน'],
#   ['สมาร์ทโฟน โทรศัพท์มือถือ samsung galaxy a10s sm a107m ',
#    'ขนาดหน้าจอ',
#    ' 6.2 นิ้ว ',
#    'ram',
#    ' 2 ',
#    'rom',
#    ' 32 gb สีเขียว '],
#   ['แบรนด์', ' ซัมซุง'],
#   ['sku', ' 571320012 th 1048806072'],
#   ['ระยะเวลาการรับประกัน', ' 1 เดือน'],
#   ['ประเภทของ', 'แบตเตอรี่', 'แบตเตอรี่', 'ชาร์จใหม่ได้และถอดได้'],
#   ['กล้องหน้า', ' ล้านพิกเซล 7ล้านพิกเซล ขึ้นไป'],
#   ['โมเดล',
#    ' สมาร์ทโฟน โทรศัพท์มือถือ samsung galaxy a10s sm a107m ',
#    'ขนาดหน้าจอ',
#    ' 6.2 นิ้ว ',
#    'ram',
#    ' 2 ',
#    'rom',
#    ' 32 gb สีเขียว '],
#   ['ประเภท', 'หน้าจอ', ' lcd'],
#   ['ความละเอียด', 'วิดีโอ 1080p'],
#   ['ความจุแบตเตอรี่', ' 1000 mah ถึง 5000 mah']],
#  'category_0_14': [['ประเภท ', 'โทรศัพท์มือถือและแท็บเล็ต'],
#   ['ประเภทย่อย', ' สมาร์ทโฟน'],
#   ['ขนาด',
#    'เครื่อง 156.9 x 75.8 x 7.8 มม. หนัก 168 กรัม ',
#    'หน้าจอ',
#    ' pls tft lcd ',
#    'ความละเอียด',
#    ' 720 x 1520 พิกเซล hd ',
#    'ขนาด',
#    ' 6.2 นิ้ว'],
#   ['ชิปเซต mediatek mt6762 helio p22 ประมวลผล octa core 2.0ghz cortex a53 ใช้ ',
#    'gpu',
#    ' powervr ge8320'],
#   ['หน่วยความจำ ',
#    'ram',
#    ' 2gb ',
#    'rom',
#    ' 32gb ',
#    'รองรับ',
#    'หน่วยความจำเสริม microsd card สูงสุด 512gb'],
#   ['กล้องหลัง',
#    'เลนส์คู่ กล้องหลัก 13 ล้านพิกเซล รูรับแสง f 1.8 มีระบบออโต้โฟกัส'],
#   ['รองรับ', 'การบันทึกวีดีโอสูงสุด fhd 1920 x 1080 30fps'],
#   ['กล้องหน้า', ' 8 ล้านพิกเซล รูรับแสง f 2.0 ', 'รองรับ', 'การทำงานสองซิม'],
#   ['สัญญานเครือข่ายที่', 'รองรับ', ' 2g gsm 3g wcdma 4g lte fdd 4g lte tdd'],
#   ['รองรับ', ' wi fi 802.11 b g n 2.4ghz wi fi direct สนับสนุน bluetooth 4.2'],
#   ['แบตเตอรี่ขนาด', ' 4000mah'],
#   ['ระบบปฏิบัติการ', ' android 9 pie oneui '],
#   ['แบรนด์', ' ซัมซุง'],
#   ['sku', ' 594306208 th 1115720937'],
#   ['กล้องหน้า', ' ล้านพิกเซล 7ล้านพิกเซล ขึ้นไป'],
#   ['โมเดล', ' samsung a10s'],
#   ['ระยะเวลาการรับประกัน', ' 1 ปี'],
#   ['ความจุแบตเตอรี่', ' 1000 mah ถึง 5000 mah']],
#  'category_0_15': [['samsung galaxy a30 4 gb ',
#    'ram',
#    ' 64 gb ',
#    'rom',
#    ' 6.4 นิ้ว 3 กล้อง สูงสุด 16ล้านพิกเซล ff f2.0 โทรศัพท์มือถือ ฿ 5990.00 ฿ 7290.00 18เปอร์เซนต์ '],
#   [' ซื้อ 1 แถม 1 ฟรี สำหรับ vivo v9 v11 v11i v7 y15pro y12 หลาย',
#    'รุ่น',
#    ' non slip soft 3d คาร์บอนไฟเบอร์ฝาหลังฟิล์มป้องกันด้านหลังสติกเกอร์ป้องกัน ฿ 55.00 ฿ 92.00 40เปอร์เซนต์ ']],
#  'category_0_16': [['ประเภท ', 'โทรศัพท์มือถือและแท็บเล็ต'],
#   ['ประเภทย่อย', ' สมาร์ทโฟน'],
#   ['samsung galaxy s10 8 gb ',
#    'ram',
#    ' 128 gb ',
#    'rom',
#    ' 6.1 นิ้ว 4 กล้อง สูงสุด 16ล้านพิกเซล ff f2.2 โทรศัพท์มือถือ '],
#   ['หน้าจอ', ' 6.1 นิ้ว ', 'ความละเอียด', '3040x1440 quad hd 550 ppi '],
#   ['กล้องหลัง',
#    ' 3 ตัว 16ล้านพิกเซล f 2.2 ultra wide 12ล้านพิกเซล f 1.5 และ 2.4 wide 12ล้านพิกเซล f 2.4 tele '],
#   ['กล้องหน้า', '10ล้านพิกเซล f 1.9'],
#   ['หน่วยประมวลผล', 'octa core snapdragon 855octa core exynos9 9820'],
#   ['แบตเตอรี่', '3400 mah typical '],
#   ['แบรนด์', ' ซัมซุง'],
#   ['sku', ' 289434461 th 479544867'],
#   ['โมเดล', ' s10 128gb '],
#   ['ระยะเวลาการรับประกัน', ' 1 ปี']],
#  'category_0_17': [['ประเภท ', 'โทรศัพท์มือถือและแท็บเล็ต'],
#   ['ประเภทย่อย', ' สมาร์ทโฟน'],
#   ['ขนาด',
#    'น้ำหนัก',
#    ' ยาว 163.3 กว้าง 77.5 หนา 8 มม. ',
#    'น้ำหนัก',
#    ' 183 กรัม'],
#   ['จอภาพ ชนิดจอ จอสัมผัส tft ',
#    'ขนาด',
#    'ความละเอียด',
#    ' 6.5 นิ้ว 264 ppi 720 1560 px'],
#   ['หน้าจอ',
#    ' tft แบบ infinity u จอแสดงผล ',
#    'ขนาด',
#    ' 6.5 นิ้ว ',
#    'ความละเอียด',
#    ' hd 720 x 1560 พิกเซล อัตราส่วน',
#    'หน้าจอ',
#    ' 19.5 9'],
#   ['หน่วยประมวลผล',
#    'cpu',
#    ' snapdragon 450 ',
#    'หน่วยประมวลผล',
#    'gpu',
#    ' adreno 506'],
#   ['หน่วยความจำ ',
#    'ram',
#    ' 3 gb ',
#    'rom',
#    ' 32 gb micro sd 512 gb ',
#    'รองรับ',
#    ' 2 ซิมการ์ด ',
#    'รองรับ',
#    'การเพิ่มความจำด้วย microsd card สูงสุด 512 gb'],
#   ['กล้องหลัง', ' 3 ตัว ประกอบด้วย'],
#   ['เลนส์หลัก ',
#    'ความละเอียด',
#    ' 13ล้านพิกเซล f 1.8 เลนส์ ultra wide 120 องศา ',
#    'ความละเอียด',
#    ' 8ล้านพิกเซล f 2.2 เลนส์ depth ',
#    'ความละเอียด',
#    ' 5ล้านพิกเซล f 2.2 '],
#   ['กล้องหน้าความละเอียด', ' 8ล้านพิกเซล f 2.0 '],
#   ['รองรับ',
#    'ระบบเสียง dolby atmos เซ็นเซอร์ accele',
#    'rom',
#    'eter fingerprint sensor gyro sensor geomagnetic sensor light sensor proximity sensor การเชื่อมต่อ bluetooth 4.2 wi fi 802.11 b g n 2.4ghz 3.5mm earjack usb type c wi fi direct gps glonass beidou galileo pc sync. 2g gsm850 gsm900 dcs1800 pcs1900 3g b1 2100 b2 1900 b5 850 b8 900 4g lte '],
#   ['แบตเตอรี่ความจุ',
#    ' 4000 mah ',
#    'รองรับ',
#    ' 15w fast charging ระบบปฎิบัติการ android 9.0 pi'],
#   ['แบรนด์', ' ซัมซุง'],
#   ['sku', ' 594338092 th 1115814517'],
#   ['กล้องหน้า', ' ล้านพิกเซล 7ล้านพิกเซล ขึ้นไป'],
#   ['โมเดล', ' samsung a20s'],
#   ['ระยะเวลาการรับประกัน', ' 1 ปี'],
#   ['ความจุแบตเตอรี่', ' 1000 mah ถึง 5000 mah']],
#  'category_0_18': [['ประเภท ', 'โทรศัพท์มือถือและแท็บเล็ต'],
#   ['ประเภทย่อย', ' สมาร์ทโฟน'],
#   ['หน้าจอ',
#    ' super amoled ',
#    'ขนาด',
#    ' 6.7 นิ้ว ',
#    'ความละเอียด',
#    ' fhd 1080 x 2400 '],
#   ['cpu', ' snapdragon 730'],
#   ['ความจุ', ' 128gb ufs 2.1 ไม่', 'รองรับ', ' microsd card'],
#   ['กล้องหน้า',
#    ' หลัง 4ล้านพิกเซล f 2.0 imx586 ultra wide ล้านพิกเซล f 2.2 tof'],
#   ['สแกนนิ้วมือบน', 'หน้าจอ'],
#   ['แบตเตอรี่', ' 3700 mah ', 'รองรับ', ' super fast charging 25w'],
#   ['แบรนด์', ' ซัมซุง'],
#   ['sku', ' 340860812 th 661136678'],
#   ['ระยะเวลาการรับประกัน', ' 1 ปี'],
#   ['ระบบปฏิบัติการ', ' android'],
#   ['ระบบปฏิบัติการ', 'เวอร์ชัน android 9.0 pie'],
#   ['โมเดล', ' a80'],
#   ['ขนาดหน้าจอ', ' นิ้ว 6.7'],
#   ['ความจุแบตเตอรี่', ' 3000 3999 mah']],
#  'category_0_19': [['ประเภท ', 'โทรศัพท์มือถือและแท็บเล็ต'],
#   ['ประเภทย่อย', ' สมาร์ทโฟน'],
#   ['รองรับ', ' 2 ซิมการ์ด'],
#   ['จอแสดงผล super amoled 24 bit 16 ล้านสี ระบบสัมผัส multi touch กว้าง 6.4 นิ้ว แนวทะแยง ',
#    'ความละเอียด',
#    ' 2960 x 1440 พิกเซล capacitive corning gorilla glass 5 ระบบป้องกัน ฝุ่นละออง resistance to dust '],
#   ['ระบบเซ็นเซอร์ sensor ระบบตรวจสอบลายนิ้วมือ finger print ระบบจดจำใบหน้า face detection ระบบหมุนภาพอัตโนมัติ accele',
#    'rom',
#    'eter ระบบเปิด ปิด',
#    'หน้าจอ',
#    'อัตโนมัติขณะสนทนา proximity ระบบเซนเซอร์หมุนภาพ gyroscope ระบบวัดความกดอากาศ ba',
#    'rom',
#    'eter ',
#    'รองรับ',
#    ' s pen ระบบปากกาอัจฉริยะ ระบบสแกนม่านตา'],
#   ['ระบบปฏิบัติการ', ' android 8.1 oreo'],
#   ['หน่วยประมวลผล', ' exynos 9810 octa core ความเร็ว 2.7 ghz'],
#   ['กล้องดิจิตอล 12 12 ล้านพิกเซล dual camera ',
#    'รูรับแสงขนาด',
#    ' 1.5 ไฟแฟลช led ซูมออฟติคอล 2 เท่า 2x optical zoom โฟกัสอัตโนมัติ auto focus แตะเลือกจุดโฟกัส touch focus ระบบป้องกันภาพสั่นไหวแบบออปติคอล ois ค้นหาใบหน้าอัตโนมัติ face detection โหมดถ่ายภาพพาโนราม่า pano',
#    'ram',
#    'a '],
#   ['กล้องหน้า',
#    ' front camera ',
#    'ความละเอียด',
#    ' 8ล้านพิกเซล ',
#    'รูรับแสงขนาด',
#    ' 1.7'],
#   ['แบตเตอรี่', 'มาตรฐาน 4000 mah standard battery '],
#   ['แบรนด์', ' ซัมซุง'],
#   ['sku', ' 283666353 th 461390461'],
#   ['โมเดล',
#    ' samsung galaxy note 9 6gb 128gb เครื่องศูนย์ มีประกัน ocean blue '],
#   ['ระยะเวลาการรับประกัน', ' 1 ปี'],
#   ['ระบบปฏิบัติการ', ' android']],
#  'category_0_20': [['ประเภท ', 'โทรศัพท์มือถือและแท็บเล็ต'],
#   ['ประเภทย่อย', ' สมาร์ทโฟน'],
#   ['samsung galaxy a10s สมาร์ทโฟน ',
#    'กล้องหลัง',
#    'คู่ 13 ล้านพิกเซล แบต 4000mah ประกันศูนย์ 1 ปี แถมฟรีหูฟังซัมซุง มูลค่า 399 บาท'],
#   ['น้ำหนัก', ' 168 กรัม'],
#   ['หน้าจอแสดงผล',
#    ' tft lcd กว้าง 6.2 นิ้ว ',
#    'ความละเอียด',
#    ' 1520x720 พิกเซล hd มีดีไซน์รอยแหว่งแบบ infinity v'],
#   ['ระบบปฏิบัติการ', ' one ui 1.1 บนพื้นฐาน android 9 pie'],
#   ['กล้องหลัง',
#    ' 2 เลนส์ พร้อมไฟแฟลชเลนส์หลัก ',
#    'ความละเอียด',
#    ' 13 ล้านพิกเซล รูรับแสง f 1.8'],
#   ['เลนส์ depth ', 'ความละเอียด', ' 2 ล้านพิกเซล รูรับแสง f 2.4'],
#   ['กล้องหน้า', 'ความละเอียด', ' 8 ล้านพิกเซล รูรับแสง f 2.2'],
#   ['ซิมการ์ด', 'รองรับ', ' 2 ซิมแบบ nano sim'],
#   ['แบตเตอรี่', ' 4000mah'],
#   ['แบรนด์', ' ซัมซุง'],
#   ['sku', ' 616572478 th 1170962904'],
#   ['ระยะเวลาการรับประกัน', ' 1 ปี'],
#   ['ประเภทของ', 'แบตเตอรี่', ' built in rechargeable battery'],
#   ['กล้องหน้า', ' ล้านพิกเซล 7ล้านพิกเซล ขึ้นไป'],
#   ['ระบบปฏิบัติการ', 'เวอร์ชัน android 9.0 pie'],
#   ['โมเดล', ' samsung galaxy a10s sm a107f ']],
#  'category_0_21': [['ประเภท ', 'โทรศัพท์มือถือและแท็บเล็ต'],
#   ['ประเภทย่อย', ' สมาร์ทโฟน'],
#   ['แบรนด์', ' ซัมซุง'],
#   ['sku', ' 307684896 th 537048806'],
#   ['โมเดล', ' samsung galaxy j4 plus'],
#   ['ระยะเวลาการรับประกัน', ' 1 ปี']],
#  'category_0_22': [['ประเภท ', 'โทรศัพท์มือถือและแท็บเล็ต'],
#   ['ประเภทย่อย', ' สมาร์ทโฟน'],
#   ['ขนาดหน้าจอ', ' 6.3 นิ้ว'],
#   ['ความจุ', 'ที่เก็บข้อมูล 256 gb'],
#   ['แบตเตอรี่', ' 3500 mah typical '],
#   ['มาตรฐานการกันน้ำและกันฝุ่น', ' ip68'],
#   ['แบรนด์', ' ซัมซุง'],
#   ['sku', ' 373972071 th 728742055'],
#   ['โมเดล', ' 8 256gb'],
#   ['ระยะเวลาการรับประกัน', ' 1 ปี']],
#  'category_0_23': [['ประเภท ', 'โทรศัพท์มือถือและแท็บเล็ต'],
#   ['ประเภทย่อย', ' สมาร์ทโฟน'],
#   ['หน้าจอ', 'กว้าง', 'ขนาด', ' 6.3 ใหญ่ที่สุดในตระกูล note'],
#   ['หน้าจอ',
#    'กว้างขึ้น ด้วย',
#    'ขนาด',
#    ' 6.3 ใหญ่ที่สุดในตระกูล note มอบภาพที่คมชัด แจ้มแจ้งในทุกรายละเอียด'],
#   ['อัตราส่วน',
#    'หน้าจอขนาด',
#    ' 18 5 9 ช่วยให้คุณเห็นรายละเอียดบน',
#    'หน้าจอ',
#    'ที่มาก ปรับแต่งรายการต่างๆ พร้อมขยับจอน้อยลง'],
#   ['แบรนด์', ' ซัมซุง'],
#   ['sku', ' 310302392 th 552106447'],
#   ['โมเดล', ' sm n950'],
#   ['ระยะเวลาการรับประกัน', ' 1 ปี']],
#  'category_0_24': [['ประเภท ', 'โทรศัพท์มือถือและแท็บเล็ต'],
#   ['ประเภทย่อย', ' สมาร์ทโฟน'],
#   ['กล้องดิจิตอล main camera 2ล้านพิกเซล ultra wide camera ล้านพิกเซล telephoto camera 1ล้านพิกเซล depth camera ล้านพิกเซล fourth camera ',
#    'รูรับแสงขนาด',
#    ' 1.7'],
#   ['กล้องหน้า', 'ความละเอียด', ' 24ล้านพิกเซล '],
#   ['แบรนด์', ' ซัมซุง'],
#   ['sku', ' 280354579 th 453591358'],
#   ['ระยะเวลาการรับประกัน', ' 5 วัน'],
#   ['ระบบปฏิบัติการ', ' android'],
#   ['กล้องหน้า', ' ล้านพิกเซล 7ล้านพิกเซล ขึ้นไป'],
#   ['ระบบปฏิบัติการ', 'เวอร์ชัน android 8.0 oreo'],
#   ['โมเดล',
#    ' samsung galaxy a9 2018 6 128gb เครื่องศูนย์ เคลียสตอคไม่มีประกัน caviar black '],
#   ['ขนาดหน้าจอ', ' นิ้ว 6.3'],
#   ['ความจุแบตเตอรี่', ' 1000 mah ถึง 5000 mah']],
#  'category_0_25': [['ประเภท ', 'โทรศัพท์มือถือและแท็บเล็ต'],
#   ['ประเภทย่อย', ' สมาร์ทโฟน'],
#   ['จอแสดงผล super amoled 24 bit 16 ล้านสี ',
#    'หน้าจอ',
#    'ทรงหยดน้ำ รูปตัว u infinity u ระบบสัมผัส multi touch กว้าง 6.7 นิ้ว แนวทะแยง ',
#    'ความละเอียด',
#    ' 1080 x 2400 พิกเซล capacitiveระบบเซ็นเซอร์ sensor ระบบสแกนลายนิ้วมือใต้',
#    'หน้าจอ',
#    ' fingerprint under จอแสดงผล ระบบจดจำใบหน้า face detection ระบบหมุนภาพอัตโนมัติ accele',
#    'rom',
#    'eter ตรวจจับแสงปรับความสว่างอัตโนมัติ ambient light ระบบเปิด ปิด',
#    'หน้าจอ',
#    'อัตโนมัติขณะสนทนา proximity ระบบเซนเซอร์หมุนภาพ gyroscope ปรับมุมมองการแสดงผลอัตโนมัติ orientation ',
#    'ระบบปฏิบัติการ',
#    ' android 9 pie',
#    'หน่วยประมวลผล',
#    ' snapdragon 675 octa core ความเร็ว 2.0 ghzหน่วยความจำ ',
#    'rom',
#    ' 128gb ',
#    'ram',
#    ' 8gbการ์ดหน่วยความจำ microsd สูงสุด 512 gb กล้องดิจิตอล 3ล้านพิกเซล 8 ultra wide 5 triple camera ',
#    'รูรับแสงขนาด',
#    ' 1.7 ไฟแฟลช led ค้นหาใบหน้าอัตโนมัติ face detection เทคโนโลยีถ่ายภาพอัจฉริยะ ai camera โหมดปรับหน้าสวยอัตโนมัติ ai face beauty โหมดเปลี่ยนภาพเซลฟี่เป็นอิโมจิ ar emoji โหมดเปลี่ยนภาพเซลฟี่เป็นสติกเกอร์ ar sticker โหมดถ่ายภาพพาโนราม่า pano',
#    'ram',
#    'a โหมดถ่ายภาพช่วงการรับแสงสูง hdr ',
#    'กล้องหน้า',
#    ' front camera ',
#    'ความละเอียด',
#    ' 32 ',
#    'รูรับแสงขนาด',
#    ' 2.0 ',
#    'กล้องหน้า',
#    ' hdr บันทึกวีดีโอ ภาพเคลื่อนไหว video recording รูปแบบไฟล์วีดีโอ ล้านพิกเซล eg 4 เครื่องเล่นวีดีโอ video player รูปแบบไฟล์ ล้านพิกเซล eg 4 ',
#    'รองรับ',
#    'วีดีโอจาก youtube เครื่องเล่นเพลง music player รูปแบบไฟล์ ล้านพิกเซล 3 ระบบเสียง dolby atmosเทคโนโลยีเพิ่มความเร็วในการชาร์จ',
#    'แบตเตอรี่',
#    'มาตรฐาน 4500 mah standard battery '],
#   ['แบรนด์', ' ซัมซุง'],
#   ['sku', ' 595150747 th 1117932783'],
#   ['โมเดล', ' samsung a70']],
#  'category_0_26': [['ประเภท ', 'โทรศัพท์มือถือและแท็บเล็ต'],
#   ['ประเภทย่อย', ' สมาร์ทโฟน'],
#   ['กล้องหน้า', ' และ หลัง', 'ความละเอียด', 'เท่ากัน 16ล้านพิกเซล '],
#   ['กล้องหน้า',
#    'มาพร้อม3 step lighting ช่วยปรับแสงได้ 3 ระดับ และ',
#    'กล้องหลัง',
#    ' รูรับแสงกว้าง f1.7'],
#   ['app pair สามารถเปิด 2 แอพที่ชอบได้พร้อมกัน2 ', 'หน้าจอ', 'ในคลิ๊กเดียว'],
#   ['แชทได้พร้อมกัน 2 บัญชีในเครื่องเดียว ',
#    'รองรับ',
#    'แอพsocial เยอะที่สุดถึง 18 แอพ'],
#   ['แบรนด์', ' ซัมซุง'],
#   ['sku', ' 264741378 th 411062149'],
#   ['โมเดล', ' galaxy a6 sm a605g ds '],
#   ['ขนาดหน้าจอ', ' นิ้ว 6'],
#   ['ระยะเวลาการรับประกัน', ' 1 ปี']],
#  'category_0_27': [['ประเภท ', 'โทรศัพท์มือถือและแท็บเล็ต'],
#   ['ประเภทย่อย', ' สมาร์ทโฟน'],
#   ['samsung galaxy a50s 128gb 6gb ',
#    'ram',
#    ' original set it is a ',
#    'แบรนด์',
#    ' new original packaging undamaged unopened unused item it is original and packaging is the same as what is found in the retail store unless the item is handmade or was packaged by the manufacturer in non retail packaging such as an unprinted box or plastic bag '],
#   ['แบรนด์', ' ซัมซุง'],
#   ['sku', ' 617108827 th 1172618764'],
#   ['ระบบปฏิบัติการ', 'เวอร์ชัน android 9.0 pie'],
#   ['โมเดล', ' samsung galaxy a50s 128gb 6gb ', 'ram', ' original set'],
#   ['ระยะเวลาการรับประกัน', ' 1 ปี']],
#  'category_0_28': [['ประเภท ', 'โทรศัพท์มือถือและแท็บเล็ต'],
#   ['ประเภทย่อย', ' สมาร์ทโฟน'],
#   ['สนุกทุกประสบการณ์กับ', 'หน้าจอ', 'ใหญ่ที่เต็มตากว่าเดิม'],
#   ['แบรนด์', ' ซัมซุง'],
#   ['sku', ' 511068392 th 907938105'],
#   ['โมเดล', ' galaxy a20s 3 32gb '],
#   ['ระยะเวลาการรับประกัน', ' 1 ปี']],
#  'category_0_29': [['ประเภท ', 'โทรศัพท์มือถือและแท็บเล็ต'],
#   ['ประเภทย่อย', ' สมาร์ทโฟน'],
#   ['หน้าจอ', 'ใหญ่ super amoled 5.6 นิ้ว สัดส่วน 18.5 9'],
#   ['ระบบปฏิบัติการ', 'แอนดรอยด์ 7.1 nougat '],
#   ['กล้องหน้า', 'แบบคู่ 16 และ 8 ล้านพิกเซล รูรับแสง f 1.9'],
#   ['กล้องหน้ารองรับ', ' live focus ปรับฉากหลังละลายได้'],
#   ['ปลดล็อค', 'หน้าจอ', 'ด้วยการสแกนใบหน้า'],
#   ['รองรับ', 'การใช้งาน secure folder'],
#   ['รองรับ', 'การสแกนลายนิ้วมือ'],
#   ['หน้าจอ', 'ใหญ่ super amoled 5.6 นิ้ว สัดส่วน 18.5 9'],
#   ['ระบบปฏิบัติการ', 'แอนดรอยด์ 7.1 nougat '],
#   ['กล้องหน้า', 'แบบคู่ 16 และ 8 ล้านพิกเซล รูรับแสง f 1.9'],
#   ['กล้องหน้ารองรับ', ' live focus ปรับฉากหลังละลายได้'],
#   ['ปลดล็อค', 'หน้าจอ', 'ด้วยการสแกนใบหน้า'],
#   ['รองรับ', 'การใช้งาน secure folder'],
#   ['รองรับ', 'การสแกนลายนิ้วมือ'],
#   ['แบรนด์', ' ซัมซุง'],
#   ['sku', ' 207916690 th 313021622'],
#   ['โมเดล', ' refurbish samsung galaxy a8 2018 gold'],
#   ['ระยะเวลาการรับประกัน', ' 3 เดือน']],
#  'category_0_30': [['ประเภท ', 'โทรศัพท์มือถือและแท็บเล็ต'],
#   ['ประเภทย่อย', ' สมาร์ทโฟน'],
#   ['samsung galaxy s10 8 gb ',
#    'ram',
#    ' 128 gb ',
#    'rom',
#    ' 6.4 นิ้ว 5 กล้อง สูงสุด 16ล้านพิกเซล ff f2.2 โทรศัพท์มือถือ '],
#   ['หน้าจอ', ' 6.4 นิ้ว ', 'ความละเอียด', ' 3040x1440 quad hd 550 ppi '],
#   ['กล้องหลัง',
#    ' 3 ตัว 16ล้านพิกเซล f 2.2 ultra wide 12ล้านพิกเซล f 1.5 และ 2.4 wide 12ล้านพิกเซล f 2.4 tele '],
#   ['กล้องหน้า',
#    ' 2 ตัว 10ล้านพิกเซล f 1.9 main 8ล้านพิกเซล f 2.2 live focus '],
#   ['หน่วยประมวลผล', ' octa core snapdragon 855 octa core exynos9 9820'],
#   ['แบตเตอรี่', ' 4100 mah typical '],
#   ['แบรนด์', ' ซัมซุง'],
#   ['sku', ' 289426638 th 479560515'],
#   ['โมเดล', ' s10 128gb '],
#   ['ระยะเวลาการรับประกัน', ' 1 ปี']],
#  'category_0_31': [['ประเภท ', 'โทรศัพท์มือถือและแท็บเล็ต'],
#   ['ประเภทย่อย', ' สมาร์ทโฟน'],
#   ['ระบบปฏิบัติการ', ' os ', 'cpu', 'ระบบปฏิบัติการ', ' android 8.0 oreo '],
#   ['หน่วยประมวลผล', ' qualcomm snapdragon 450 octa core'],
#   ['แบรนด์', ' ซัมซุง'],
#   ['sku', ' 289402378 th 479508064'],
#   ['โมเดล',
#    ' samsung j8 ',
#    'ram',
#    '3 32gb เครื่องศูนย์ประกันมีเดือน สีทอง แถมฟรี เคสใส ฟิลม์กระจก'],
#   ['ระยะเวลาการรับประกัน', ' 3 เดือน'],
#   ['ระบบปฏิบัติการ', ' android']],
#  'category_0_32': [['xiaomi redmi note 8 3gb 32gb สมาร์ตโฟน 4 กล้อง ai ',
#    'ความละเอียด',
#    ' 48ล้านพิกเซล จอกว้าง 6.3 นิ้ว fhd ชิปเซ็ต qualcomm sd 665 ฿ 4299.00 ฿ 4999.00 14เปอร์เซนต์ '],
#   ['samsung wireless battery pack 10000 mah พาวเวอร์แบงค์ ',
#    'แบตเตอรี่',
#    'สำรอง ฿ 1290.00 ฿ 1590.00 19เปอร์เซนต์ '],
#   ['samsung galaxy tab s4 10.5 4 gb ',
#    'ram',
#    ' 64 gb ',
#    'rom',
#    ' 10.5 นิ้ว แท็บเล็ต ฿ 13990.00 ฿ 23900.00 41เปอร์เซนต์ ']],
#  'category_0_33': [['ประเภท ', 'โทรศัพท์มือถือและแท็บเล็ต'],
#   ['ประเภทย่อย', ' สมาร์ทโฟน'],
#   ['แบรนด์', ' new'],
#   ['แบรนด์', ' ซัมซุง'],
#   ['sku', ' 612014873 th 1155486191'],
#   ['ระบบปฏิบัติการ', 'เวอร์ชัน android 8.1 oreo'],
#   ['โมเดล', ' samsung galaxy note 10 plus'],
#   ['ระยะเวลาการรับประกัน', ' 1 ปี']],
#  'category_0_34': [['ประเภท ', 'โทรศัพท์มือถือและแท็บเล็ต'],
#   ['ประเภทย่อย', ' สมาร์ทโฟน'],
#   ['รองรับ', ' 2 ซิมการ์ด'],
#   ['จอแสดงผล super amoled 24 bit 16ล้านสี ระบบสัมผัส multi touch กว้าง6.4 นิ้ว แนวทะแยง ',
#    'ความละเอียด',
#    ' 2960x1440 พิกเซล capacitive corning gorilla glass5 ระบบป้องกันฝุ่นละออง resistance to dust '],
#   ['ระบบเซ็นเซอร์ sensor ระบบตรวจสอบลายนิ้วมือ finger print ระบบจดจำใบหน้า face detection ระบบหมุนภาพอัติโนมัติ accele',
#    'rom',
#    'eter ระบบเปิด ปิด',
#    'หน้าจอ',
#    'อัตโนมัติขณะสนทนา proximity ระบบเซ็นเซอร์หมุนภาพ gyroscope ระบบวัดความกดอากาศ ba',
#    'rom',
#    'eter ',
#    'รองรับ',
#    ' s pen ระบบปากกาอัจฉริยะ ระบบสแกนม่านตา'],
#   ['ระบบปฏิบัติการ', ' android 8.1 oreo'],
#   ['หน่วยประมวลผล', ' exynos 9810octa core ความเร็ว 2.7 ghz'],
#   ['การ์ดหน่วยความจำ ', 'รองรับ', 'ได้สูงสุด 512 gb'],
#   ['กล้องดิจิตอล 12 12 ล้านพิกเซล dual camera ซูมออฟติคอล 2 เท่า 2x optical zoom โฟกัสอัตโนมัติ auto focus แตะเลือกจุดโฟกัส touch focus ระบบป้องกัยภาพสั่นไหวแบบออปติคอล ols ค้นหาใบหน้าแบบอัตโนมัติ face detection โหมดถ่ายภาพพาโนรามา pano',
#    'ram',
#    'a '],
#   ['กล้องหน้า', ' front camera ', 'ความละเอียด', ' 8ล้านพิกเซล '],
#   ['แบตเตอรี่', 'มาตรฐาน 4000 mah standard battery '],
#   ['แบรนด์', ' ซัมซุง'],
#   ['sku', ' 283658415 th 461387419'],
#   ['โมเดล',
#    ' samsung galaxy note 9 6gb 128gb เครื่องศูนย์ มีประกัน midnight black ระ'],
#   ['ระยะเวลาการรับประกัน', ' 1 ปี'],
#   ['ระบบปฏิบัติการ', ' android']],
#  'category_0_35': [['ประเภท ', 'โทรศัพท์มือถือและแท็บเล็ต'],
#   ['ประเภทย่อย', ' สมาร์ทโฟน'],
#   ['แบรนด์', ' new samsung galaxy s10 plus 128gb'],
#   ['แบรนด์', ' new'],
#   ['แบรนด์', ' ซัมซุง'],
#   ['sku', ' 610820644 th 1151996547'],
#   ['ระบบปฏิบัติการ', 'เวอร์ชัน android 8.0 oreo'],
#   ['โมเดล', ' samsung galaxy s10 plus'],
#   ['ระยะเวลาการรับประกัน', ' 1 ปี']],
#  'category_0_36': [['ประเภท ', 'โทรศัพท์มือถือและแท็บเล็ต'],
#   ['ประเภทย่อย', ' สมาร์ทโฟน'],
#   ['samsung galaxy note 9 8gb 512gb it is a ',
#    'แบรนด์',
#    ' new original packaging undamaged unopened unused item it is original and packaging is the same as what is found in the retail store unless the item is handmade or was packaged by the manufacturer in non retail packaging such as an unprinted box or plastic bag '],
#   ['แบรนด์', ' ซัมซุง'],
#   ['sku', ' 617168251 th 1172664402'],
#   ['ระบบปฏิบัติการ', 'เวอร์ชัน android 9.0 pie'],
#   ['โมเดล', ' samsung galaxy note 9 8gb 512gb '],
#   ['ระยะเวลาการรับประกัน', ' 1 ปี']],
#  'category_0_37': [['samsung galaxy a30 4 gb ',
#    'ram',
#    ' 64 gb ',
#    'rom',
#    ' 6.4 นิ้ว 3 กล้อง สูงสุด 16ล้านพิกเซล ff f2.0 โทรศัพท์มือถือ ฿ 5990.00 ฿ 7290.00 18เปอร์เซนต์ '],
#   ['โทรศัพท์ซัมซุง galaxy ',
#    'รุ่น',
#    ' s9 plus 256gb สีฟ้า ฿ 7900.00 ฿ 13590.00 42เปอร์เซนต์ ']],
#  'category_0_38': [['ประเภท ', 'โทรศัพท์มือถือและแท็บเล็ต'],
#   ['ประเภทย่อย', ' สมาร์ทโฟน'],
#   ['samsung galaxy a30 4 gb ',
#    'ram',
#    ' 64 gb ',
#    'rom',
#    ' 6.4 นิ้ว 3 กล้อง สูงสุด 16ล้านพิกเซล ff f2.0 โทรศัพท์มือถือ '],
#   ['หน้าจอ',
#    ' samoled full จอแสดงผล ไร้กรอบ ไร้ปุ่มโฮม เพิ่มมุมมองการเห็น ด้วยสัดส่วน 19.5 9 จอกว้างขึ้น พร้อม',
#    'ความละเอียด',
#    ' fhd เพื่อการชมภาพยนตร์ที่เต็มอิ่มมากขึ้น'],
#   ['แบรนด์', ' ซัมซุง'],
#   ['sku', ' 299990648 th 515722325'],
#   ['โมเดล', ' galaxy a30 4 64gb '],
#   ['ระยะเวลาการรับประกัน', ' 1 ปี']],
#  'category_0_39': [['ประเภท ', 'โทรศัพท์มือถือและแท็บเล็ต'],
#   ['ประเภทย่อย', ' สมาร์ทโฟน'],
#   ['แบรนด์', ' ซัมซุง'],
#   ['sku', ' 408012228 th 792604544'],
#   ['โมเดล', ' galaxy a10s 2 32gb'],
#   ['ระยะเวลาการรับประกัน', ' 1 ปี']],
#  'category_0_40': [['ประเภท ', 'โทรศัพท์มือถือและแท็บเล็ต'],
#   ['ประเภทย่อย', ' สมาร์ทโฟน'],
#   ['หน้าจอ', ' 5.45 นิ้ว ', 'ความละเอียด', ' hd 1440 x 720 พิกเซล'],
#   ['ระบบปฏิบัติการ', ' android 9 pie ครอบทับด้วย miui 10'],
#   ['gpu', ' adreno 505'],
#   ['rom', ' 16gb ', 'รองรับ', ' microsd 256gb '],
#   ['กล้องหลัง', ' 13ล้านพิกเซล f 2.2 1.12 m พร้อม led flash'],
#   ['กล้องหน้า', ' 5ล้านพิกเซล '],
#   ['รองรับ', ' face unlock'],
#   ['แบตเตอรี่',
#    'ความจุ',
#    ' 4000 mah ',
#    'รองรับ',
#    'การชาร์จ 5v 2a ผ่าน micro usb'],
#   ['รองรับ', ' dual sim4g lte'],
#   ['รองรับ', ' wi fi 802.11 b g n 2.4ghz wifi direct wifi จอแสดงผล hotspot'],
#   ['รองรับ', ' usb 2.0usb on the go'],
#   ['ขนาด', 'ตัวเครื่อง 146.30 x 70.41 x 9.55 มม. หนัก 165 กรัม'],
#   ['แบรนด์', ' xiaomi'],
#   ['sku', ' 213755551 th 1138512951'],
#   ['กล้องหน้า', ' ล้านพิกเซล 5 6ล้านพิกเซล '],
#   ['ระบบปฏิบัติการ', 'เวอร์ชัน android 9.0 pie'],
#   ['โมเดล', ' xiaomi redmi 7a 2 32gb '],
#   ['ขนาดหน้าจอ', ' นิ้ว 5.45'],
#   ['ระยะเวลาการรับประกัน', ' 1 ปี'],
#   ['ระบบปฏิบัติการ', ' android'],
#   ['ความจุแบตเตอรี่', ' 1000 mah ถึง 5000 mah']],
#  'category_0_41': [['ประเภท ', 'โทรศัพท์มือถือและแท็บเล็ต'],
#   ['ประเภทย่อย', ' สมาร์ทโฟน'],
#   ['4 กล้อง ai ', 'ความละเอียด', ' 4ล้านพิกเซล '],
#   ['แบตเตอรี่ความจุ', ' 4000 mah'],
#   ['รองรับ', 'ระบบ'],
#   ['แบรนด์', ' xiaomi'],
#   ['sku', ' 222527681 th 889412058'],
#   ['กล้องหน้า', ' ล้านพิกเซล 1ล้านพิกเซล '],
#   ['ระบบปฏิบัติการ', 'เวอร์ชัน android 9.0 pie'],
#   ['โมเดล', ' xiaomi redmi note 8'],
#   ['ระยะเวลาการรับประกัน', ' 1 ปี'],
#   ['ความจุแบตเตอรี่', ' 4000 4999 mah']],
#  'category_0_42': [['ประเภท ', 'โทรศัพท์มือถือและแท็บเล็ต'],
#   ['ประเภทย่อย', ' สมาร์ทโฟน'],
#   [' สินค้าพร้อมส่ง ฟรี mi air purifier 2 xiaomi mi note 10 6 128gb สมาร์ทโฟน กล้อง 5 ตัว ',
#    'ความละเอียด',
#    ' 10ล้านพิกเซล รับประกันศูนย์ไทย 15 เดือน '],
#   ['แบรนด์', ' xiaomi'],
#   ['sku', ' 595884854 th 1119120013'],
#   ['ระบบปฏิบัติการ', 'เวอร์ชัน android 9.0 pie'],
#   ['โมเดล', ' mi note 10'],
#   ['ระยะเวลาการรับประกัน', ' 15 เดือน']],
#  'category_0_43': [['ประเภท ', 'โทรศัพท์มือถือและแท็บเล็ต'],
#   ['ประเภทย่อย', ' สมาร์ทโฟน'],
#   [' ตัวเครื่องมี',
#    'ขนาด',
#    ' 156.48x75.41x9. มม. และมี',
#    'น้ำหนัก',
#    ' 188 กรัม'],
#   ['หน้าจอแสดงผล',
#    ' dot notch จอแสดงผล ',
#    'ขนาด',
#    ' 6.22 นิ้ว ในอัตราส่วน 19 9 ',
#    'ความละเอียด',
#    'ระดับ hd 720x1520 พิกเซล 270 ppi ครอบทับด้วยกระจกขอบโค้งแบบ 2.5d corning gorilla glass 5'],
#   ['หน่วยประมวลผล', 'กราฟิก ', 'gpu', ' adreno 505'],
#   [' หน่วยความจำแรม ', 'ram', 'ขนาด', ' 4gb'],
#   [' หน่วยความจำภายใน ',
#    'rom',
#    'ขนาด',
#    ' 64gb พร้อม',
#    'รองรับ',
#    'การ์ดหน่วยความจำภายนอกแบบ microsd สูงสุดที่',
#    'ขนาด',
#    ' 512gb'],
#   [' กล้องดิจิทัลด้านหลังแบบคู่ ai dual camera ',
#    'ความละเอียด',
#    ' 12 ล้านพิกเซล เซ็นเซอร์รับภาพ sony imx363 พิกเซล',
#    'ขนาด',
#    ' 1.4 ไมครอน มี',
#    'ขนาด',
#    'รูรับแสง f 1.8 กล้องตัวที่สองเลนส์ depth ',
#    'ความละเอียด',
#    ' 2 ล้านพิกเซล ',
#    'รองรับ',
#    'เทคโนโลยี dual pd ai portrait และ ai scene detection ในการตรวจจับซีนทั้งหมด 33 หมวดหมู่'],
#   [' กล้องดิจิทัลด้านหน้า ai ',
#    'ความละเอียด',
#    ' 8 ล้านพิกเซล พิกเซล',
#    'ขนาด',
#    ' 1.12 ไมครอน มี',
#    'ขนาด',
#    'รูรับแสง f 2.0 ',
#    'รองรับ',
#    'เทคโนโลยี ai selfie portrait'],
#   ['แบตเตอรี่ความจุ', ' 5000 mah พร้อมเทคโนโลยีชาร์จไว 18w fast charging'],
#   ['ระบบปฏิบัติการ', ' android 9.0 pie'],
#   ['รองรับ', 'การใช้งานพร้อมกัน 2 ซิมการ์ด dual sim '],
#   ['รองรับ', 'ถาดใส่ซิมการ์ดแบบ triple slot'],
#   ['รองรับ', 'การใช้งานบนเครือข่าย 4g lte'],
#   ['รองรับ', 'การเชื่อมต่อ wi fi 802.11 b g n และ bluetooth 4.2'],
#   ['รองรับ', 'การเชื่อมต่อแบบ usb type c'],
#   ['แบรนด์', ' xiaomi'],
#   ['sku', ' 611154425 th 1152864043'],
#   ['กล้องหน้า', ' ล้านพิกเซล 7ล้านพิกเซล ขึ้นไป'],
#   ['ระบบปฏิบัติการ', 'เวอร์ชัน android 9.0 pie'],
#   ['โมเดล', ' xiaomi redmi 8 3 32gb '],
#   ['ขนาดหน้าจอ', ' นิ้ว 6.22'],
#   ['ระยะเวลาการรับประกัน', ' 15 เดือน'],
#   ['ความจุแบตเตอรี่', ' 1000 mah ถึง 5000 mah']],
#  'category_0_44': [['ประเภท ', 'โทรศัพท์มือถือและแท็บเล็ต'],
#   ['ประเภทย่อย', ' สมาร์ทโฟน'],
#   ['xiaomi mi 9t pro เสียวหมี่ ',
#    'ram',
#    '6 ',
#    'rom',
#    '64gb จอ6.39นิ้ว กล้องดิจิตอล 4ล้านพิกเซล ล้านพิกเซล telephoto 1ล้านพิกเซล triple camera แถมเคส ประกันศูนย์ไทย'],
#   ['สมาร์ทโฟน โทรศัพท์มือถือพร้อม', 'ระบบปฏิบัติการ'],
#   ['จอแสดงผล amoled 24 bit 16 ล้านสี ',
#    'หน้าจอแสดงผล',
#    ' hdr ระบบสัมผัส multi touch กว้าง 6.39 นิ้ว แนวทะแยง ',
#    'ความละเอียด',
#    ' 2340 x 1080 พิกเซล 403 ppi capacitive corning gorilla glass 5'],
#   ['ระบบเซ็นเซอร์ sensor ระบบสแกนลายนิ้วมือใต้',
#    'หน้าจอ',
#    ' fingerprint under จอแสดงผล ระบบหมุนภาพอัตโนมัติ accele',
#    'rom',
#    'eter ตรวจจับแสงปรับความสว่างอัตโนมัติ ambient light ระบบเปิด ปิด',
#    'หน้าจอ',
#    'อัตโนมัติขณะสนทนา proximity ระบบเซนเซอร์หมุนภาพ gyroscope ปรับมุมมองการแสดงผลอัตโนมัติ orientation '],
#   ['รองรับ', ' 2 ซิมการ์ด'],
#   ['ระบบปฏิบัติการ', ' miui 10 based on android 9.0 pie '],
#   ['หน่วยประมวลผล', ' qualcomm snapdragon 855 octa core ความเร็ว 2.84 ghz'],
#   ['การหาตำแหน่ง assisted gps ', 'รองรับ', 'แอพพลิเคชั่น egps'],
#   ['รองรับ', ' nfc near field communication '],
#   ['รองรับ', 'การถ่ายโอนข้อมูลกับ flash drive โดยตรง usb on the go '],
#   ['กล้องดิจิตอล 4ล้านพิกเซล ล้านพิกเซล telephoto 1ล้านพิกเซล ultra wide angle triple camera ',
#    'รูรับแสงขนาด',
#    ' 1.75 ไฟแฟลช dual led ซูมดิจิตอล 10 เท่า 10x digital zoom ซูมออฟติคอล 2 เท่า 2x optical zoom ',
#    'ขนาด',
#    'ภาพสูงสุด 8000 x 6000 พิกเซล image size โฟกัสอัตโนมัติ auto focus โหมดฉาก บุคคล เวลากลางคืน ค้นหาใบหน้าอัตโนมัติ face detection เทคโนโลยีถ่ายภาพอัจฉริยะ ai camera โหมดปรับหน้าสวยอัตโนมัติ ai face beauty ตั้งเวลาถ่ายภาพอัตโนมัติ self timer โหมดถ่ายภาพพาโนราม่า pano',
#    'ram',
#    'a '],
#   ['กล้องหน้า',
#    ' front camera ',
#    'ความละเอียด',
#    ' 20ล้านพิกเซล ไฟแฟลช led ',
#    'รูรับแสงขนาด',
#    ' 2.2 ',
#    'รองรับ',
#    ' video call สนทนาแบบเห็นภาพ ',
#    'กล้องหน้า',
#    ' hdr ',
#    'กล้องหน้า',
#    ' portrait ',
#    'กล้องหน้า',
#    'แบบ pop up'],
#   ['บันทึกวีดีโอ ภาพเคลื่อนไหว video recording ',
#    'ความละเอียด',
#    ' hd 3840 x 2160 พิกเซล บันทึกวีดีโอ 4k 60 เฟรมต่อวินาที slow motion'],
#   ['เครื่องเล่นวีดีโอ video player รูปแบบไฟล์ ล้านพิกเซล eg 4 h.264 xvid m4v mkv วีดีโอสตรีมมิ่ง 3gp aviล้านพิกเซล 4 rm ',
#    'รองรับ',
#    'วีดีโอจาก youtube '],
#   ['รองรับ', 'ไฟล์รูปภาพ jpg jpeg bmp gif tiff'],
#   ['แบตเตอรี่', 'มาตรฐาน 4000 mah standard battery ']],
#  'category_0_45': [['xiaomi redmi note 8 3gb 32gb สมาร์ตโฟน 4 กล้อง ai ',
#    'ความละเอียด',
#    ' 48ล้านพิกเซล จอกว้าง 6.3 นิ้ว fhd ชิปเซ็ต qualcomm sd 665 ฿ 4299.00 ฿ 4999.00 14เปอร์เซนต์ '],
#   ['samsung wireless battery pack 10000 mah พาวเวอร์แบงค์ ',
#    'แบตเตอรี่',
#    'สำรอง ฿ 1290.00 ฿ 1590.00 19เปอร์เซนต์ '],
#   ['samsung galaxy tab s4 10.5 4 gb ',
#    'ram',
#    ' 64 gb ',
#    'rom',
#    ' 10.5 นิ้ว แท็บเล็ต ฿ 13990.00 ฿ 23900.00 41เปอร์เซนต์ '],
#   ['apple ipad 9.7 inch with wifi 32gb 2018 ',
#    'โมเดล',
#    ' ฿ 11290.00 ฿ 11790.00 4เปอร์เซนต์ ']],
#  'category_0_46': [['ประเภท ', 'โทรศัพท์มือถือและแท็บเล็ต'],
#   ['ประเภทย่อย', ' สมาร์ทโฟน'],
#   ['โทรศัพท์มือถือ xiaomi mi a3 4gb 64gb สแกนนิ้วบนจอ ',
#    'ขนาด',
#    'จอ 6.088 นิ้ว ',
#    'ความละเอียด',
#    ' hd ชิปเซ็ต qualcomm sd 665 ',
#    'กล้องหลังความละเอียด',
#    ' 4ล้านพิกเซล ',
#    'กล้องหน้าความละเอียด',
#    ' 3ล้านพิกเซล '],
#   ['หน้าจอ', 'กว้าง 6.01 นิ้ว'],
#   ['ระบบสแกนลายนิ้วมือใต้', 'หน้าจอ', ' และระบบจดจำใบหน้า face detection '],
#   ['กล้องหน้า', 'ความละเอียด', ' 32 ล้านพิกเซล', 'รูรับแสงขนาด', ' 2.0'],
#   ['แบตเตอรี่', 'มาตรฐาน li ion 4030 mah'],
#   ['แบรนด์', ' xiaomi'],
#   ['sku', ' 533460461 th 963560027'],
#   ['กล้องหน้า', ' ล้านพิกเซล 7ล้านพิกเซล ขึ้นไป'],
#   ['ระบบปฏิบัติการ', 'เวอร์ชัน android 9.0 pie'],
#   ['โมเดล', ' mi a3 4gb 64gb '],
#   ['ขนาดหน้าจอ', ' นิ้ว 6.09'],
#   ['ระยะเวลาการรับประกัน', ' 18 เดือน'],
#   ['ความจุแบตเตอรี่', ' 1000 mah ถึง 5000 mah']],
#  'category_0_47': [['ประเภท ', 'โทรศัพท์มือถือและแท็บเล็ต'],
#   ['ประเภทย่อย', ' สมาร์ทโฟน'],
#   ['xiaomi redmi note 8 3gb 32gb สมาร์ตโฟน 4 กล้อง ai ',
#    'ความละเอียด',
#    ' 48ล้านพิกเซล จอกว้าง 6.3 นิ้ว fhd ชิปเซ็ต qualcomm sd 665'],
#   ['แบรนด์', ' xiaomi'],
#   ['sku', ' 495988905 th 884338021'],
#   ['กล้องหน้า', ' ล้านพิกเซล 1ล้านพิกเซล '],
#   ['ระบบปฏิบัติการ', 'เวอร์ชัน android 9.0 pie'],
#   ['โมเดล', ' redmi note 8'],
#   ['ขนาดหน้าจอ', ' นิ้ว 6.3'],
#   ['ระยะเวลาการรับประกัน', ' 15 เดือน'],
#   ['ความจุแบตเตอรี่', ' 1000 mah ถึง 5000 mah']],
#  'category_0_48': [['ประเภท ', 'โทรศัพท์มือถือและแท็บเล็ต'],
#   ['ประเภทย่อย', ' สมาร์ทโฟน'],
#   ['สมาร์ทโฟน โทรศัพท์มือถือพร้อม', 'ระบบปฏิบัติการ'],
#   ['ความละเอียด', ' 1080 x 2340 พิกเซล 395 ppi '],
#   [' ระบบเปิด ปิด', 'หน้าจอ', 'อัตโนมัติขณะสนทนา proximity '],
#   ['รองรับ', ' 2 ซิมการ์ด'],
#   ['ระบบปฏิบัติการ', ' os ', 'cpu'],
#   ['ระบบปฏิบัติการ', ' miui 10 based on android 9.0 pie '],
#   ['หน่วยประมวลผล', ' mediatek helio g90t octa core']],
#  'category_0_49': [['ประเภท ', 'โทรศัพท์มือถือและแท็บเล็ต'],
#   ['ประเภทย่อย', ' สมาร์ทโฟน'],
#   ['xiaomi mi redmi 7a 2 16gb ประกันศูนย์ไทย1ปี snapdragon439 ',
#    'แบตเตอรี่',
#    ' 4000mah พร้อม ai beauty'],
#   ['แบรนด์', ' xiaomi'],
#   ['sku', ' 234902116 th 713640836'],
#   ['กล้องหน้า', ' ล้านพิกเซล 5 6ล้านพิกเซล '],
#   ['โมเดล', ' xiaomi mi redmi 7a'],
#   ['ระยะเวลาการรับประกัน', ' 1 ปี'],
#   ['ความจุแบตเตอรี่', ' 4000 4999 mah']],
#  'category_0_50': [['ประเภท ', 'โทรศัพท์มือถือและแท็บเล็ต'],
#   ['ประเภทย่อย', ' สมาร์ทโฟน'],
#   ['แบรนด์', ' xiaomi'],
#   ['sku', ' 494026300 th 882746256'],
#   ['โมเดล', ' redmi note 8'],
#   ['ระยะเวลาการรับประกัน', ' 15 เดือน']],
#  'category_0_51': [['ประเภท ', 'โทรศัพท์มือถือและแท็บเล็ต'],
#   ['ประเภทย่อย', ' สมาร์ทโฟน'],
#   ['ผ่อน 0เปอร์เซนต์ นาน 10 เดือน xiaomi note 10 ',
#    'ram',
#    ' 6 ',
#    'rom',
#    ' 128 gb สมาร์ทโฟน 5 กล้อง 10ล้านพิกเซล ประกันศูนย์ไทย 15 เดือน '],
#   ['หน่วยประมวลผล', ' qualcomm snapdragon 730g'],
#   ['ความจุ', 'ram', ' 6gb ', 'rom', ' 128gb'],
#   ['กล้องหลัง', ' 108ล้านพิกเซล ระบบ 5 ', 'กล้องหลัง', ' ai'],
#   ['กล้องหน้า',
#    ' กล้องเซลฟี่ 32ล้านพิกเซล 1.6 m super pixel 4 in 1 รูรับแสง f 2.0'],
#   ['ระบบปลดล็อกด้วยลายนิ้วมือบน', 'หน้าจอ'],
#   ['ระบบปฏิบัติการ', ' miui 11'],
#   ['แบตเตอรี่', ' 5260 mah ทั่วไป 5170 mah ขั้นต่ำ '],
#   ['แบตเตอรี่', 'ลิเธียมไอออนโพลีเมอร์'],
#   ['รองรับ', 'การชาร์จเร็ว 30 w ภายในกล่องมีที่ชาร์จ 30 w '],
#   ['รองรับ', ' 4g 4g 3g 2g'],
#   ['รองรับ', 'การโทร volte hd สองซิม'],
#   ['รองรับ', ' bluetooth 5.0'],
#   ['nfc มัลติฟังชัน ', 'รองรับ', ' google pay'],
#   ['ขนาด', 'ความสูง 157.8 มม. ความกว้าง 74.2 มม. ความหนา 9.67 มม.'],
#   ['น้ำหนัก', ' 208 กรัม'],
#   ['ดีไซน์ช่องเสียง', 'ขนาด', 'ใหญ่ 1.0 cc'],
#   ['ช่องเสียบหูฟัง 3.5 มม. คุณภาพเสียงระดับ hifi รับรองเสียง',
#    'ความละเอียด',
#    'สูง'],
#   ['เซ็นเซอร์วัดแสงรอบข้างบน',
#    'หน้าจอ',
#    ' ตัววัดความเร่ง ไจโรสโคป เข็มทิศอิเล็กทรอนิกส์ เซ็นเซอร์เลเซอร์โฟกัส'],
#   ['แบรนด์', ' xiaomi'],
#   ['sku', ' 604332862 th 1137128463'],
#   ['ระยะเวลาการรับประกัน', ' 15 เดือน']],
#  'category_0_52': [['ประเภท ', 'โทรศัพท์มือถือและแท็บเล็ต'],
#   ['ประเภทย่อย', ' สมาร์ทโฟน'],
#   ['สเปคเครื่องเบื้องต้นของ xiaomi mi cc9 pro priemiu edition มีดังนี้ ',
#    'หน้าจอแสดงผล',
#    ' amoled ',
#    'ขนาด',
#    ' 6.47 นิ้ว'],
#   ['ความละเอียด', ' 2340 x 1080 พิกเซล fhd '],
#   ['cpu', ' snapdragon 730g'],
#   ['gpu', ' adreno 618'],
#   ['กล้องหลัง',
#    ' เซ็นเซอร์ samsung hmx 10ล้านพิกเซล 8p lens 1ล้านพิกเซล ล้านพิกเซล 2ล้านพิกเซล ล้านพิกเซล พร้อมไฟแฟลชคู่ led'],
#   ['กล้องหน้า', 'ความละเอียด', ' 3ล้านพิกเซล '],
#   [' มีเซ็นเซอร์สแกนลายนิ้วมือบน', 'หน้าจอ'],
#   ['รองรับ',
#    ' dual 4g volte wifi 802.11 ac 2.4ghz 5ghz bluetooth 5 gps glonass nfc usb type c'],
#   ['แบตเตอรี่ความจุ', ' 5260 mah พร้อมระบบชาร์จเร็ว 30w'],
#   ['ขนาด', 'ตัวเครื่อง 157.8 74.2 9.67 มม.'],
#   ['น้ำหนัก', ' 208 กรัม'],
#   ['แบรนด์', ' xiaomi'],
#   ['sku', ' 611792752 th 1155040122'],
#   ['ประเภท', 'หน่วยประมวลผล', ' octa core'],
#   ['ความละเอียด', 'วิดีโอ 4k'],
#   ['ระยะเวลาการรับประกัน', ' 1 ปี'],
#   ['ระบบปฏิบัติการ', ' android 9.0 pie'],
#   ['ประเภทของ', 'แบตเตอรี่', ' built in rechargeable battery'],
#   ['กล้องหน้า', ' ล้านพิกเซล 7ล้านพิกเซล ขึ้นไป'],
#   ['ระบบปฏิบัติการ', 'เวอร์ชัน android 9.0 pie']],
#  'category_0_53': [['ประเภท ', 'โทรศัพท์มือถือและแท็บเล็ต'],
#   ['ประเภทย่อย', ' สมาร์ทโฟน'],
#   ['amoled ', 'ขนาด', ' 5.97 นิ้ว'],
#   ['แบรนด์', ' xiaomi'],
#   ['sku', ' 343546977 th 668396557'],
#   ['ระบบปฏิบัติการ', 'เวอร์ชัน android 9.0 pie'],
#   ['โมเดล', ' mi9 mi 9 se'],
#   ['ระยะเวลาการรับประกัน', ' 1 ปี']],
#  'category_0_54': [[' ซื้อ 1 แถม 1 ฟรี สำหรับ vivo v9 v11 v11i v7 y15pro y12 หลาย',
#    'รุ่น',
#    ' non slip soft 3d คาร์บอนไฟเบอร์ฝาหลังฟิล์มป้องกันด้านหลังสติกเกอร์ป้องกัน ฿ 55.00 ฿ 92.00 40เปอร์เซนต์ '],
#   ['โทรศัพท์ซัมซุง galaxy ',
#    'รุ่น',
#    ' s9 plus 256gb สีฟ้า ฿ 7900.00 ฿ 13590.00 42เปอร์เซนต์ '],
#   [' ผ่อน 0เปอร์เซนต์ 10 เดือน huawei nova 5t หน่วยความจำ 8 128g l ',
#    'หน้าจอ',
#    ' 6.26 นิ้ว tft lcd ips ฿ 9290.00 ฿ 10990.00 15เปอร์เซนต์ '],
#   [' daytech สมาร์ทกุญแจ ',
#    'รุ่น',
#    ' l02 กุญแจล็อคประตูอัจฉริยะรักษาความปลอดภัย แบบสแกนลายนิ้วมือ กันน้ำ ชาร์จไฟได้ ใช้พลังงานต่ำ แข็งแรงทนทาน ความปลอดภัยสูง ฿ 745.00 ฿ 1566.00 52เปอร์เซนต์ ']],
#  'category_0_55': [['ประเภท ', 'โทรศัพท์มือถือและแท็บเล็ต'],
#   ['ประเภทย่อย', ' สมาร์ทโฟน'],
#   ['หน้าจอขนาด', ' 6.21 นิ้ว ', 'ความละเอียด', ' hd '],
#   ['แรม 3gb ', 'ความจุ', ' 32 gb'],
#   ['กล้องหลัง', ' 2 ตัว'],
#   ['กล้องหน้า', ' 8 ล้านพิกเซล'],
#   ['แบตเตอรี่', ' 5000 มิลลิแอมป์ ', 'รองรับ', 'ชาร์จไว 18 วัตต์'],
#   ['แบรนด์', ' xiaomi'],
#   ['sku', ' 587988556 th 1092062042'],
#   ['ระบบปฏิบัติการ', 'เวอร์ชัน android 9.0 pie'],
#   ['โมเดล', ' redmi 8 3gb 32gb '],
#   ['ขนาดหน้าจอ', ' นิ้ว 6.22'],
#   ['ระยะเวลาการรับประกัน', ' 15 เดือน'],
#   ['ความจุแบตเตอรี่', ' 1000 mah ถึง 5000 mah']],
#  'category_0_56': [['ประเภท ', 'โทรศัพท์มือถือและแท็บเล็ต'],
#   ['ประเภทย่อย', ' สมาร์ทโฟน'],
#   ['xiaomi redmi 8 เสียวหมี่ จอ6.21 นิ้ว ',
#    'ram',
#    '4 ',
#    'rom',
#    '64gb ศุนย์ไทย'],
#   ['สมาร์ทโฟน โทรศัพท์มือถือพร้อม', 'ระบบปฏิบัติการ'],
#   ['จอแสดงผล ips lcd 24 bit 16 ล้านสี กว้าง 6.21 นิ้ว แนวทะแยง ',
#    'ความละเอียด',
#    ' 720 x 1520 พิกเซล 271 ppi ประเภทจอ ',
#    'หน้าจอ',
#    'กระจกแข็ง ประเภทจอ corning gorilla glass 5'],
#   ['ระบบเซ็นเซอร์ sensor ระบบตรวจสอบลายนิ้วมือ fingerprint ระบบหมุนภาพอัตโนมัติ accele',
#    'rom',
#    'eter ตรวจจับความเคลื่อนไหวของตัวเครื่อง accele',
#    'rom',
#    'eter ระบบเปิด ปิด',
#    'หน้าจอ',
#    'อัตโนมัติขณะสนทนา proximity '],
#   ['รองรับ', ' 2 ซิมการ์ด'],
#   ['ระบบปฏิบัติการ', ' miui 9 based on android 9.0 pie '],
#   ['หน่วยประมวลผล', ' qualcomm snapdragon 439 octa core ความเร็ว 2.0 ghz'],
#   ['แบรนด์', ' xiaomi'],
#   ['sku', ' 526910733 th 944832734'],
#   ['กล้องหน้า', ' ล้านพิกเซล 7ล้านพิกเซล ขึ้นไป'],
#   ['โมเดล', ' redmi 8'],
#   ['ขนาดหน้าจอ', ' นิ้ว 6.21'],
#   ['ระยะเวลาการรับประกัน', ' 15 เดือน'],
#   ['ระบบปฏิบัติการ', ' android'],
#   ['ความจุแบตเตอรี่', ' 1000 mah ถึง 5000 mah']],
#  'category_0_57': [['ประเภท ', 'โทรศัพท์มือถือและแท็บเล็ต'],
#   ['ประเภทย่อย', ' สมาร์ทโฟน'],
#   ['4 กล้อง ai ', 'ความละเอียด', ' 4ล้านพิกเซล '],
#   ['แบตเตอรี่ความจุ', ' 4000 mah'],
#   ['รองรับ', 'ระบบ'],
#   ['แบรนด์', ' xiaomi'],
#   ['sku', ' 221761904 th 931764445'],
#   ['ระยะเวลาการรับประกัน', ' 15 เดือน'],
#   ['ระบบปฏิบัติการ', ' android 8.1 oreo'],
#   ['ประเภทของ', 'แบตเตอรี่', ' built in rechargeable battery'],
#   ['กล้องหน้า', ' ล้านพิกเซล 1ล้านพิกเซล '],
#   ['ระบบปฏิบัติการ', 'เวอร์ชัน android 8.1 oreo'],
#   ['โมเดล', ' xiaomi redmi note 8'],
#   ['ประเภท', 'หน้าจอ', ' ips lcd'],
#   ['ขนาดหน้าจอ', ' นิ้ว 6.3'],
#   ['ประเภท', 'หน่วยประมวลผล', ' octa core'],
#   ['ความละเอียด', 'วิดีโอ 1080p'],
#   ['ความจุแบตเตอรี่', ' 4000 4999 mah']],
#  'category_0_58': [[' 10 inch tablet android 9.0 แถมฟรี หูฟังไร้สาย ตุ๊กตาหมี แท็บเล็ต ระบบแอนดรอยด์andorid ข้อเสนอที่ดีที่สุด จัดส่งฟรี รับประกันหนึ่งปี แท็ปเล็ต 10นิ้ว octa core 6gb ',
#    'ram',
#    ' 128gb ',
#    'rom',
#    ' 3g 4g fdd lte wifi bluetooth gps phone call glass screen tablet pc ฿ 3832.00 ฿ 7999.00 52เปอร์เซนต์ '],
#   ['samsung wireless battery pack 10000 mah พาวเวอร์แบงค์ ',
#    'แบตเตอรี่',
#    'สำรอง ฿ 1290.00 ฿ 1590.00 19เปอร์เซนต์ '],
#   ['samsung galaxy tab s4 10.5 4 gb ',
#    'ram',
#    ' 64 gb ',
#    'rom',
#    ' 10.5 นิ้ว แท็บเล็ต ฿ 13990.00 ฿ 23900.00 41เปอร์เซนต์ '],
#   ['apple ipad 9.7 inch with wifi 32gb 2018 ',
#    'โมเดล',
#    ' ฿ 11290.00 ฿ 11790.00 4เปอร์เซนต์ ']],
#  'category_0_59': [['ประเภท ', 'โทรศัพท์มือถือและแท็บเล็ต'],
#   ['ประเภทย่อย', ' สมาร์ทโฟน'],
#   ['หน้าจอ', ' 6.47 fhd 2340 x 1080px 398 ppi'],
#   ['ใช้ ', 'cpu', ' qualcomm snapdragon 730g octa core ความเร็ว2.2ghz'],
#   ['กล้องหลัง',
#    ' 10ล้านพิกเซล 1ล้านพิกเซล 2ล้านพิกเซล ล้านพิกเซล ล้านพิกเซล f 1.69 f 2.0 f 2.2 f 2.4'],
#   ['กล้องหน้า', ' 3ล้านพิกเซล f 2.0'],
#   ['แบตเตอรี่', ' 5260mah'],
#   ['cpu', ' qualcomm snapdragon 730g octa core 2.2ghz'],
#   ['แบรนด์', ' xiaomi'],
#   ['sku', ' 595984523 th 1119224437'],
#   ['ประเภท', 'หน่วยประมวลผล', ' octa core'],
#   ['ความละเอียด', 'วิดีโอ 4k'],
#   ['ระยะเวลาการรับประกัน', ' 1 ปี'],
#   ['ระบบปฏิบัติการ', ' android'],
#   ['ประเภทของ', 'แบตเตอรี่', ' built in rechargeable battery']],
#  'category_0_60': [['ประเภท ', 'โทรศัพท์มือถือและแท็บเล็ต'],
#   ['ประเภทย่อย', ' สมาร์ทโฟน'],
#   ['redmi 8 เสียวหมี่ จอ6.21 นิ้ว ',
#    'ram',
#    '4 ',
#    'rom',
#    '64gb ศุนย์ไทย รับประกัน1ปี กล่องมีการแกะซีนเพื่อเปืดประกีน'],
#   ['สมาร์ทโฟน โทรศัพท์มือถือพร้อม', 'ระบบปฏิบัติการ'],
#   ['จอแสดงผล ips lcd 24 bit 16 ล้านสี ',
#    'หน้าจอ',
#    'หยดน้ำ waterdrop จอแสดงผล กว้าง 6.21 นิ้ว แนวทะแยง ',
#    'ความละเอียด',
#    ' 720 x 1520 พิกเซล 271 ppi ประเภทจอ ',
#    'หน้าจอ',
#    'กระจกแข็ง ประเภทจอ'],
#   ['ระบบเซ็นเซอร์ sensor ระบบตรวจสอบลายนิ้วมือ fingerprint ระบบหมุนภาพอัตโนมัติ accele',
#    'rom',
#    'eter ตรวจจับความเคลื่อนไหวของตัวเครื่อง accele',
#    'rom',
#    'eter ระบบเปิด ปิด',
#    'หน้าจอ',
#    'อัตโนมัติขณะสนทนา proximity '],
#   ['รองรับ', ' 2 ซิมการ์ด'],
#   ['ระบบปฏิบัติการ', ' miui 9 based on android 9.0 pie '],
#   ['หน่วยประมวลผล', ' qualcomm snapdragon 439 octa core ความเร็ว 2.0 ghz'],
#   ['กล้องดิจิตอล 12 ล้านพิกเซล depth sensor ล้านพิกเซล dual camera ',
#    'รูรับแสงขนาด',
#    ' 2.2 ไฟแฟลช led'],
#   ['กล้องหน้า',
#    ' front camera ',
#    'ความละเอียด',
#    ' ล้านพิกเซล ',
#    'รูรับแสงขนาด',
#    ' 2.0 ',
#    'กล้องหน้า',
#    ' hdr'],
#   ['แบตเตอรี่', 'มาตรฐาน li pol 5000 mah standard battery '],
#   ['แบรนด์', ' xiaomi'],
#   ['sku', ' 612338298 th 1156318935'],
#   ['ระยะเวลาการรับประกัน', ' 1 ปี'],
#   ['ระบบปฏิบัติการ', ' android'],
#   ['ประเภทของ', 'แบตเตอรี่', ' built in rechargeable battery']],
#  'category_0_61': [['ประเภท ', 'โทรศัพท์มือถือและแท็บเล็ต'],
#   ['ประเภทย่อย', ' สมาร์ทโฟน'],
#   ['xiaomi redmi note 5a prime 5.5 นิ้ว 3gb ',
#    'ram',
#    ' 32gb ',
#    'rom',
#    ' dualcameras snapdragon 425 สมาร์ทโฟน octa core'],
#   ['กล้อง dualcameras frontcamera16.ล้านพิกเซล backcamera13.ล้านพิกเซล capacitive ',
#    'หน้าจอ',
#    'สัมผัสคู่ซิมการ์ดสแตนด์บายคู่นาโนซิม'],
#   ['แบรนด์', ' xiaomi'],
#   ['sku', ' 615188295 th 1166414603'],
#   ['ระยะเวลาการรับประกัน', ' 1 ปี'],
#   ['ระบบปฏิบัติการ', ' android'],
#   ['ประเภทของ', 'แบตเตอรี่', ' built in rechargeable battery'],
#   ['กล้องหน้า', ' ล้านพิกเซล 16ล้านพิกเซล '],
#   ['ระบบปฏิบัติการ', 'เวอร์ชัน android 8.0 oreo'],
#   ['โมเดล', ' xiaomi redmi note 5a'],
#   ['ขนาดหน้าจอ', ' นิ้ว 5.5'],
#   ['ความละเอียด', 'วิดีโอ 1080p'],
#   ['ความจุแบตเตอรี่', ' 3000 3999 mah']],
#  'category_0_62': [['ประเภท ', 'โทรศัพท์มือถือและแท็บเล็ต'],
#   ['ประเภทย่อย', ' สมาร์ทโฟน'],
#   ['xiaomi redmi 8a เสียวหมี่ จอ6.2 นิ้ว ',
#    'ram',
#    '2 ',
#    'rom',
#    '32gb ศุนย์ไทย แถมเคส ฟิล์ม'],
# ...
#   ['ระบบปฏิบัติการ', ' os '],
#   ['หน้าจอแสดงผล', ' จอแสดงผล ']],
#  'category_1_211': [['ประเภท ', 'โทรศัพท์มือถือและแท็บเล็ต'],
#   ['ประเภทย่อย', ' แท็บเล็ต'],
#   ['รองรับ', ' 3g with voice โทรได้ '],
#   ['แบรนด์', ' เลโนโว่'],
#   ['sku', ' 616450213 th 1170652707'],
#   ['กล้องหน้า', ' ล้านพิกเซล 0 1ล้านพิกเซล '],
#   ['ขนาดหน้าจอ', ' นิ้ว 7'],
#   ['รุ่น', ' tab4 7104i za410083th '],
#   ['ระยะเวลาการรับประกัน', ' 1 ปี'],
#   ['ระบบปฏิบัติการ', ' android 8.0']],
#  'category_1_212': [['ประเภท ', 'โทรศัพท์มือถือและแท็บเล็ต'],
#   ['ประเภทย่อย', ' แท็บเล็ต'],
#   ['แบรนด์', ' เลโนโว่'],
#   ['sku', ' 616470088 th 1170736144'],
#   ['กล้องหน้า', ' ล้านพิกเซล 1 2ล้านพิกเซล '],
#   ['ขนาดหน้าจอ', ' นิ้ว 10.1'],
#   ['รุ่น', ' lenovo tab m10 x505l za4h0069th '],
#   ['ระยะเวลาการรับประกัน', ' 1 ปี'],
#   ['ระบบปฏิบัติการ', ' android 9.0 pie'],
#   ['ความละเอียด', ' hd']],
#  'category_1_213': [['ประเภท ', 'โทรศัพท์มือถือและแท็บเล็ต'],
#   ['ประเภทย่อย', ' แท็บเล็ต'],
#   ['osandroid 8.1 oreoconnectivitywifi 3gcellularcomm standardsgsm hspatechnology2g 4g2g networkgsm 850 900 1800 19003g networkhsdpa 2100จอแสดงผล screen size7 inchesresolutionhd 1024x600 multitouch5 point multi touchfeatureschipsetmediatek mt8167a d 4c 4x a35 1.3ghz ',
#    'gpu',
#    'integrated img ge8300 graphicsmemory และ storageinternal memory16 gb',
#    'ram',
#    '1 gbcamerarear front camera2ล้านพิกเซล 0.3ล้านพิกเซล connectivitywifi type802.11 b g nbluetoothbluetooth 4.0audiomicrophonemonauralbattery',
#    'ความจุแบตเตอรี่',
#    ' 2750 mahusage timeup to 8 hours'],
#   ['แบรนด์', ' เลโนโว่'],
#   ['sku', ' 267260291 th 417588813'],
#   ['รุ่น', ' e7 tb 7104i'],
#   ['ระยะเวลาการรับประกัน', ' 1 ปี'],
#   ['ระบบปฏิบัติการ', ' android']],
#  'category_1_214': [['ประเภท ', 'โทรศัพท์มือถือและแท็บเล็ต'],
#   ['ประเภทย่อย', ' แท็บเล็ต'],
#   ['แบรนด์', ' เลโนโว่'],
#   ['sku', ' 616410628 th 1170652391'],
#   ['กล้องหน้า', ' ล้านพิกเซล 0 1ล้านพิกเซล '],
#   ['ขนาดหน้าจอ', ' นิ้ว 7'],
#   ['รุ่น', ' tab4 7104i za410083th '],
#   ['ระยะเวลาการรับประกัน', ' 1 ปี'],
#   ['ระบบปฏิบัติการ', ' android 8.0']],
#  'category_1_215': [['ประเภท ', 'โทรศัพท์มือถือและแท็บเล็ต'],
#   ['ประเภทย่อย', ' แท็บเล็ต'],
#   ['รองรับ', ' 3g with voice โทรได้ '],
#   ['แบรนด์', ' เลโนโว่'],
#   ['sku', ' 616462030 th 1170676586'],
#   ['กล้องหน้า', ' ล้านพิกเซล 0 1ล้านพิกเซล '],
#   ['ขนาดหน้าจอ', ' นิ้ว 7'],
#   ['รุ่น', ' tab4 7104i za410083th '],
#   ['ระยะเวลาการรับประกัน', ' 1 ปี'],
#   ['ระบบปฏิบัติการ', ' android 8.0']],
#  'category_1_216': [['ประเภท ', 'โทรศัพท์มือถือและแท็บเล็ต'],
#   ['ประเภทย่อย', ' แท็บเล็ต'],
#   ['แบรนด์', ' เลโนโว่'],
#   ['sku', ' 616444557 th 1170684894'],
#   ['กล้องหน้า', ' ล้านพิกเซล 1 2ล้านพิกเซล '],
#   ['ขนาดหน้าจอ', ' นิ้ว 10.1'],
#   ['รุ่น', ' lenovo tab m10 x505l za4h0069th '],
#   ['ระยะเวลาการรับประกัน', ' 1 ปี'],
#   ['ระบบปฏิบัติการ', ' android 9.0 pie'],
#   ['ความละเอียด', ' hd']],
#  'category_1_217': [['ประเภท ', 'โทรศัพท์มือถือและแท็บเล็ต'],
#   ['ประเภทย่อย', ' แท็บเล็ต'],
#   ['cpu', ' quad core 1.3ghz'],
#   ['แบรนด์', ' เลโนโว่'],
#   ['sku', ' 271949397 th 427884556'],
#   ['รุ่น', ' tab4 7104i '],
#   ['ระยะเวลาการรับประกัน', ' 1 ปี']],
#  'category_1_218': [['ประเภท ', 'โทรศัพท์มือถือและแท็บเล็ต'],
#   ['ประเภทย่อย', ' แท็บเล็ต'],
#   ['หน้าจอ', ' 7 hd 1024 x 600 '],
#   ['ใช้ ', 'cpu', ' mediatek mt6735 quad core ความเร็ว 1.1ghz'],
#   ['ram', ' 1gb ', 'rom', ' 16gb ', 'รองรับ', ' micro sd card สูงสุด 128 gb'],
#   ['กล้องหลัง', ' ล้านพิกเซล '],
#   ['กล้องหน้า', ' ล้านพิกเซล '],
#   ['แบตเตอรี่', ' 3450 mah'],
#   ['ระบบปฏิบัติการ', 'เวอร์ชั่น android 7.0 nougat '],
#   ['หน้าจอ', ' 7 hd 1024 x 600 '],
#   ['ใช้ ', 'cpu', ' mediatek mt6735 quad core ความเร็ว 1.1ghz'],
#   ['ram', ' 1gb ', 'rom', ' 16gb ', 'รองรับ', ' micro sd card สูงสุด 128 gb'],
#   ['กล้องหลัง', ' ล้านพิกเซล '],
#   ['กล้องหน้า', ' ล้านพิกเซล '],
#   ['แบตเตอรี่', ' 3450 mah'],
#   ['ระบบปฏิบัติการ', 'เวอร์ชั่น android 7.0 nougat '],
#   ['แบรนด์', ' เลโนโว่'],
#   ['sku', ' 454626123 th 838876875'],
#   ['ระยะเวลาการรับประกัน', ' 1 ปี'],
#   ['ระบบปฏิบัติการ', ' android 7.0 nougat'],
#   ['กล้องหน้า', ' ล้านพิกเซล 1 2ล้านพิกเซล '],
#   ['ขนาดหน้าจอ', ' นิ้ว 7'],
#   ['รุ่น', ' tb 7304x']],
#  'category_1_219': [['ประเภท ', 'โทรศัพท์มือถือและแท็บเล็ต'],
#   ['ประเภทย่อย', ' แท็บเล็ต'],
#   ['น้ำหนัก', ' 0.26 kg'],
#   ['แบรนด์', ' เลโนโว่'],
#   ['sku', ' 564446979 th 1034898602'],
#   ['รุ่น', ' tb 7504x'],
#   ['ระยะเวลาการรับประกัน', ' 1 ปี'],
#   ['ระบบปฏิบัติการ', ' android']],
#  'category_1_220': [[' 10 inch tablet android 9.0 แถมฟรี หูฟังไร้สาย ตุ๊กตาหมี แท็บเล็ต ระบบแอนดรอยด์andorid ข้อเสนอที่ดีที่สุด จัดส่งฟรี รับประกันหนึ่งปี แท็ปเล็ต 10นิ้ว octa core 6gb ',
#    'ram',
#    ' 128gb ',
#    'rom',
#    ' 3g 4g fdd lte wifi bluetooth gps phone call glass screen tablet pc ฿ 3832.00 ฿ 7999.00 52เปอร์เซนต์ '],
#   ['แท็บเล็ต pad 2019 ใส่ซิมได้ 2 ซิม จอใหญ่สุดคุ้ม ',
#    'ขนาด',
#    '10.5นิ้ว มีระบบ 3g ทุกระบบ มีไวไฟ เล่นเน็ตสุดคุ้ม โทรเข้าออกเหมือนมือถือ ฿ 3250.00 ฿ 5990.00 46เปอร์เซนต์ '],
#   ['all new kindle paperwhite 4 ',
#    'รุ่น',
#    'ใหม่ล่าสุด ปี 2019 10th gen e book reader 8gb black ฿ 4099.00'],
#   ['ใหม่ 10.1 นิ้ว android 8.1 10 แท็บเล็ตพีซีคอร์ 128gb wifi bluetooth hd ',
#    'หน้าจอ',
#    'สัมผัส ฿ 1272.30 ฿ 2205.00 42เปอร์เซนต์ ']],
#  'category_1_221': [['ประเภท ', 'โทรศัพท์มือถือและแท็บเล็ต'],
#   ['ประเภทย่อย', ' แท็บเล็ต'],
#   ['หน้าจอ', ' 7 hd 1024 x 600 '],
#   ['ใช้ ', 'cpu', ' mediatek mt6735 quad core ความเร็ว 1.1ghz'],
#   ['ram', ' 1gb ', 'rom', ' 16gb ', 'รองรับ', ' micro sd card สูงสุด 128 gb'],
#   ['กล้องหลัง', ' ล้านพิกเซล '],
#   ['กล้องหน้า', ' ล้านพิกเซล '],
#   ['แบตเตอรี่', ' 3450 mah'],
#   ['ระบบปฏิบัติการ', 'เวอร์ชั่น android 7.0 nougat '],
#   ['หน้าจอ', ' 7 hd 1024 x 600 '],
#   ['ใช้ ', 'cpu', ' mediatek mt6735 quad core ความเร็ว 1.1ghz'],
#   ['ram', ' 1gb ', 'rom', ' 16gb ', 'รองรับ', ' micro sd card สูงสุด 128 gb'],
#   ['กล้องหลัง', ' ล้านพิกเซล '],
#   ['กล้องหน้า', ' ล้านพิกเซล '],
#   ['แบตเตอรี่', ' 3450 mah'],
#   ['ระบบปฏิบัติการ', 'เวอร์ชั่น android 7.0 nougat '],
#   ['แบรนด์', ' เลโนโว่'],
#   ['sku', ' 448778270 th 828394561'],
#   ['รุ่น', ' tb 7304x'],
#   ['ระยะเวลาการรับประกัน', ' 1 ปี'],
#   ['ระบบปฏิบัติการ', ' android 7.0 nougat']],
#  'category_1_222': [['ประเภท ', 'โทรศัพท์มือถือและแท็บเล็ต'],
#   ['ประเภทย่อย', ' แท็บเล็ต'],
#   ['น้ำหนัก', ' 0.32 kg'],
#   ['แบรนด์', ' เลโนโว่']],
#  'category_1_223': [['ประเภท ', 'โทรศัพท์มือถือและแท็บเล็ต'],
#   ['ประเภทย่อย', ' แท็บเล็ต'],
#   ['lenovo tab4 7 แท็บเล็ตจอ ips 7 นิ้ว',
#    'รองรับ',
#    ' 4g โทรได้ ใช้งานได้ทุกที่ทุกเวลา ตามที่คุณต้องการ สะดวกพกพาง่าย ประหยัด คุ้มค่า'],
#   ['แบรนด์', ' เลโนโว่'],
#   ['sku', ' 527686316 th 946952842'],
#   ['รุ่น', ' tab4 za380137th'],
#   ['ระยะเวลาการรับประกัน', ' 1 ปี'],
#   ['ระบบปฏิบัติการ', ' android 7.0 nougat']],
#  'category_1_224': [['ประเภท ', 'โทรศัพท์มือถือและแท็บเล็ต'],
#   ['ประเภทย่อย', ' แท็บเล็ต'],
#   ['แบรนด์', ' เลโนโว่'],
#   ['sku', ' 297482165 th 508638091'],
#   ['กล้องหน้า', ' ล้านพิกเซล 0 1ล้านพิกเซล '],
#   ['ขนาดหน้าจอ', ' นิ้ว 7'],
#   ['รุ่น', ' za410083th'],
#   ['ระยะเวลาการรับประกัน', ' 1 ปี'],
#   ['ระบบปฏิบัติการ', ' android 8.1 oreo']],
#  'category_1_225': [['ประเภท ', 'โทรศัพท์มือถือและแท็บเล็ต'],
#   ['ประเภทย่อย', ' แท็บเล็ต'],
#   ['lenovo tablet tab4 8 ',
#    'โมเดล',
#    ' tb 8504x black แถมฟรี เคสของแท้พร้อมฟิล์ม'],
#   ['cpu', ' quad core 1.4ghz'],
#   ['แบรนด์', ' เลโนโว่'],
#   ['sku', ' 479414707 th 869558314'],
#   ['รุ่น', ' tb 8504x'],
#   ['ระยะเวลาการรับประกัน', ' 1 ปี'],
#   ['ระบบปฏิบัติการ', ' android 7.0 nougat']],
#  'category_1_226': [['ประเภท ', 'โทรศัพท์มือถือและแท็บเล็ต'],
#   ['ประเภทย่อย', ' แท็บเล็ต'],
#   ['cpu', ' octa core 1.4ghz'],
#   ['แบรนด์', ' เลโนโว่'],
#   ['sku', ' 295768242 th 500194997'],
#   ['รุ่น', ' lenovo k6 note ', 'ram', '4 32gb ลดclearstock ไม่มีประกัน grey '],
#   ['ระบบปฏิบัติการ', ' android']],
#  'category_1_227': [['ประเภท ', 'โทรศัพท์มือถือและแท็บเล็ต'],
#   ['ประเภทย่อย', ' แท็บเล็ต'],
#   ['lenovo tab4 x704l 10plus 10.1 fhd กล้อง ล้านพิกเซล ล้านพิกเซล ',
#    'ram',
#    ' 4gb ',
#    'rom',
#    ' 64gb lte '],
#   ['จอ 10.1 fhd ', 'ความละเอียด'],
#   ['android 7.0 nougat ', 'รองรับ', ' 4g'],
#   ['แบรนด์', ' เลโนโว่'],
#   ['sku', ' le611elaasgg63anth 58279737'],
#   ['กล้องหน้า', ' ล้านพิกเซล 5 6ล้านพิกเซล '],
#   ['ขนาดหน้าจอ', ' นิ้ว 10.1'],
#   ['รุ่น', ' tab4 10plus x704l'],
#   ['ระยะเวลาการรับประกัน', ' 1 ปี'],
#   ['ระบบปฏิบัติการ', ' android'],
#   ['ความละเอียด', ' full hd']],
#  'category_1_228': [['ประเภท ', 'โทรศัพท์มือถือและแท็บเล็ต'],
#   ['ประเภทย่อย', ' แท็บเล็ต'],
#   ['cpu', ' quad core 1.1ghz'],
#   ['แบรนด์', ' เลโนโว่'],
#   ['sku', ' le954elabkir8janth 126890450'],
#   ['ขนาดหน้าจอ', ' นิ้ว 7'],
#   ['รุ่น', ' lenovo tablet 7 4g call tab4 essential 7304x black'],
#   ['ระยะเวลาการรับประกัน', ' 1 ปี'],
#   ['ระบบปฏิบัติการ', ' android']],
#  'category_1_229': [['ประเภท ', 'โทรศัพท์มือถือและแท็บเล็ต'],
#   ['ประเภทย่อย', ' แท็บเล็ต'],
#   ['lenovo tb 8504xprocessor qualcomm msm8917 snapdragon quad core 1.4 ghz',
#    'ram',
#    ' 2gb',
#    'rom',
#    ' 16gbmemory card up to 128gbจอแสดงผล 8 inch ipsresolution 1280 x 800 pxfront camera ล้านพิกเซล fixed focusback camera ล้านพิกเซล auto focusi o interfaces 3.5mm combo audio jack'],
#   ['micro usb connector for power charger and data syncaudio dolby atmos 2 x front facing speakersnetwork wi fi 802.11 b g n single channel 2.4 ghz bluetooth bluetooth 4.0sensor g sensor p sensor l sensor vibratorระบบแผนที่ดาวเทียม gps gps glonassoperating system android 7.0 nougatbattery 4850 mah li ion polymerdimensions 211x124x8.3 มม. 8.31x4.88.0.22 inches',
#    'น้ำหนัก',
#    ' 320g 0.7 lbs function calls yesfrequency support gsm b2 3 5 8'],
#   ['แบรนด์', ' เลโนโว่'],
#   ['sku', ' le634elabk0menanth 125919785'],
#   ['ขนาดหน้าจอ', ' นิ้ว 8'],
#   ['รุ่น', ' tab4 8504x'],
#   ['ระยะเวลาการรับประกัน', ' 1 ปี'],
#   ['ระบบปฏิบัติการ', ' android']],
#  'category_1_230': [['ประเภท ', 'โทรศัพท์มือถือและแท็บเล็ต'],
#   ['ประเภทย่อย', ' แท็บเล็ต'],
#   ['cpu', ' octa core 1.4ghz'],
#   ['แบรนด์', ' เลโนโว่'],
#   ['sku', ' 295764269 th 500218143'],
#   ['รุ่น', ' lenovo k6 note ', 'ram', '4 32gb ลดclearstock ไม่มีประกัน gold '],
#   ['ระบบปฏิบัติการ', ' android']],
#  'category_1_231': [['ประเภท ', 'โทรศัพท์มือถือและแท็บเล็ต'],
#   ['ประเภทย่อย', ' แท็บเล็ต'],
#   ['cpu', ' quad core 1.1gh'],
#   ['แบรนด์', ' เลโนโว่'],
#   ['sku', ' le611elabgdkr5anth 117213539'],
#   ['ขนาดหน้าจอ', ' นิ้ว 7'],
#   ['รุ่น', ' tab4 essential 7304x'],
#   ['ระยะเวลาการรับประกัน', ' 1 ปี'],
#   ['ระบบปฏิบัติการ', ' android']],
#  'category_1_232': [['ประเภท ', 'โทรศัพท์มือถือและแท็บเล็ต'],
#   ['ประเภทย่อย', ' แท็บเล็ต'],
#   ['แบรนด์', ' เลโนโว่'],
#   ['sku', ' 224964566 th 343772150'],
#   ['รุ่น', ' psmartitplus a0080561']],
#  'category_1_233': [['ประเภท ', 'โทรศัพท์มือถือและแท็บเล็ต'],
#   ['ประเภทย่อย', ' แท็บเล็ต'],
#   ['หน้าจอ', ' 8 นิ้ว ', 'ความละเอียด', ' 1280x800 พิกเซล'],
#   ['cpu', ' octa core 1.0ghz'],
#   ['กล้องหลัง', ' 5 ล้านพิกเซล'],
#   ['กล้องหน้า', ' 2 ล้านพิกเซล'],
#   ['แบตเตอรี่', ' 4290mah'],
#   ['รองรับ', 'การเชือมต่อ wifi 802.11 b g n bluetooth 4.0'],
#   ['แบรนด์', ' เลโนโว่'],
#   ['sku', ' le611elaae2m7lanth 28482262'],
#   ['กล้องหน้า', ' ล้านพิกเซล 1 2ล้านพิกเซล '],
#   ['ขนาดหน้าจอ', ' นิ้ว 8'],
#   ['รุ่น', ' tablet 8 4gcall lenovo tab3 850 black'],
#   ['ระยะเวลาการรับประกัน', ' 1 ปี'],
#   ['ระบบปฏิบัติการ', ' android']],
#  'category_1_234': [['ประเภท ', 'โทรศัพท์มือถือและแท็บเล็ต'],
#   ['ประเภทย่อย', ' แท็บเล็ต'],
#   ['cpu', ' octa core 2.0ghz'],
#   ['แบรนด์', ' เลโนโว่'],
#   ['sku', ' 333478869 th 644516097'],
#   ['รุ่น', ' tab4 10 plus x704l '],
#   ['ระยะเวลาการรับประกัน', ' 1 ปี'],
#   ['ระบบปฏิบัติการ', ' android 7.0 nougat']],
#  'category_1_235': [['ประเภท ', 'โทรศัพท์มือถือและแท็บเล็ต'],
#   ['ประเภทย่อย', ' แท็บเล็ต'],
#   ['หน้าจอ', ' 7 นิ้ว ', 'ความละเอียด', ' 1024 x 600 พิกเซล'],
#   ['cpu', ' quad core 1.3 ghz'],
#   ['รองรับ', ' microsd card สูงสุด 32 gb'],
#   ['กล้องหน้า', ' 0.3 ล้านพิกเซล'],
#   ['กล้องหลัง', ' 2.0 ล้านพิกเซล'],
#   ['แบตเตอรี่', ' 3450 mah'],
#   ['รองรับ', 'การเชือมต่อ wifi 802.11b g n bluetooth 4.0'],
#   ['แบรนด์', ' เลโนโว่'],
#   ['sku', ' le611elaa4mwvianth 9960417'],
#   ['ระยะเวลาการรับประกัน', ' 1 ปี'],
#   ['ระบบปฏิบัติการ', ' android os v4.4 kitkat '],
#   ['กล้องหน้า', ' ล้านพิกเซล 0 1ล้านพิกเซล '],
#   ['ขนาดหน้าจอ', ' นิ้ว 7'],
#   ['รุ่น', ' anusra computer tablet 7 wifi lenovo tab2 a7 20 8gb. black ']],
#  'category_1_236': [['ประเภท ', 'โทรศัพท์มือถือและแท็บเล็ต'],
#   ['ประเภทย่อย', ' แท็บเล็ต'],
#   ['cpu', ' quad core 1.3ghz'],
#   ['แบรนด์', ' เลโนโว่'],
#   ['sku', ' le611elaa7ywwkanth 16584510'],
#   ['ขนาดหน้าจอ', ' นิ้ว 7'],
#   ['รุ่น', ' lenovo tab4 7104i '],
#   ['ระยะเวลาการรับประกัน', ' 1 ปี'],
#   ['ระบบปฏิบัติการ', ' android']],
#  'category_1_237': [['ประเภท ', 'โทรศัพท์มือถือและแท็บเล็ต'],
#   ['ประเภทย่อย', ' แท็บเล็ต'],
#   ['lenovo tab e7',
#    'หน้าจอ',
#    ' lcd tn panel ',
#    'ขนาด',
#    ' 7.0 นิ้ว ',
#    'ความละเอียด',
#    ' 1200 x 600 px'],
#   ['cpu', ' mediatek mt8167 chipset quad core 1.3ghz '],
#   ['ram', ' 1 gb storage 16 gb ', 'รองรับ', ' microsd card '],
#   ['กล้องหน้าความละเอียด',
#    ' 0.2ล้านพิกเซล และ',
#    'กล้องหลังความละเอียด',
#    ' 2ล้านพิกเซล '],
#   ['แบตเตอรี่ขนาด',
#    ' 2750 mah ทางเลอโนเวอเคลมไว้ว่าสามารถดูวีดีโอได้นานถึง 5 ชั่วโมงเลยทีเดียว'],
#   ['รันบน', 'ระบบปฏิบัติการ', ' android 8.1 oreo go edition lenovo tab e7'],
#   ['แบรนด์', ' เลโนโว่'],
#   ['sku', ' 523078318 th 933300133'],
#   ['รุ่น', ' tab e7'],
#   ['ระบบปฏิบัติการ', ' android']],
#  'category_1_238': [['ประเภท ', 'โทรศัพท์มือถือและแท็บเล็ต'],
#   ['ประเภทย่อย', ' แท็บเล็ต'],
#   ['tablet 10.1 4g lenovo tab4 10 plus x704l ebony black ',
#    'cpu',
#    ' octa core 2.0 ghz ประกัน 1y'],
#   ['cpu', ' octacore 2.0ghz'],
#   ['แบรนด์', ' เลโนโว่'],
#   ['sku', ' 254158707 th 392325427'],
#   ['ขนาดหน้าจอ', ' นิ้ว 10'],
#   ['กล้องหน้า', ' ล้านพิกเซล 5 6ล้านพิกเซล '],
#   ['รุ่น', ' tab4 10 plus x704l '],
#   ['ระยะเวลาการรับประกัน', ' 1 ปี'],
#   ['ระบบปฏิบัติการ', ' android 7.0 nougat']],
#  'category_1_239': [['ประเภท ', 'โทรศัพท์มือถือและแท็บเล็ต'],
#   ['ประเภทย่อย', ' แท็บเล็ต'],
#   ['แบรนด์', ' เลโนโว่'],
#   ['sku', ' 332512941 th 641144040'],
#   ['รุ่น', ' tb 7104l'],
#   ['ระยะเวลาการรับประกัน', ' 1 ปี']],
#  'category_1_240': [['ประเภท ', 'โทรศัพท์มือถือและแท็บเล็ต'],
#   ['ประเภทย่อย', ' แท็บเล็ต'],
#   ['แบรนด์', ' เลโนโว่'],
#   ['sku', ' 487584299 th 875784181'],
#   ['ระยะเวลาการรับประกัน', ' 1 ปี'],
#   ['ระบบปฏิบัติการ', ' android'],
#   ['กล้องหน้า', ' ล้านพิกเซล 0 1ล้านพิกเซล '],
#   ['ขนาดหน้าจอ', ' นิ้ว 7'],
#   ['รุ่น', ' tab4 7104i za410083th '],
#   ['ความละเอียด', ' hd']],
#  'category_1_241': [['ประเภท ', 'โทรศัพท์มือถือและแท็บเล็ต'],
#   ['ประเภทย่อย', ' แท็บเล็ต'],
#   ['หน้าจอ', ' 8 นิ้ว ', 'ความละเอียด', ' 1280x800 พิกเซล'],
#   ['cpu', ' octa core 1.0ghz'],
#   ['กล้องหลัง', ' 5 ล้านพิกเซล'],
#   ['กล้องหน้า', ' 2 ล้านพิกเซล'],
#   ['แบตเตอรี่', ' 4290mah'],
#   ['รองรับ', 'การเชือมต่อ wifi 802.11 b g n bluetooth 4.0'],
#   ['แบรนด์', ' เลโนโว่'],
#   ['sku', ' le611elaal4zmjanth 42868896'],
#   ['กล้องหน้า', ' ล้านพิกเซล 1 2ล้านพิกเซล '],
#   ['ขนาดหน้าจอ', ' นิ้ว 8'],
#   ['รุ่น', ' tablet 8 4gcall lenovo tab3 850 black'],
#   ['ระยะเวลาการรับประกัน', ' 1 ปี'],
#   ['ระบบปฏิบัติการ', ' android v4.4']],
#  'category_1_242': [['chuwi hi10 air 2 in 1 tablet laptop pc 10.1 นิ้ว จอ fhd ogs วินโดร์ 10 แท้ intel quad core 1.92ghz ',
#    'ram',
#    ' 4gb ',
#    'ความจุ',
#    ' 64gb type c ฿ 6290.00 ฿ 9990.00 37เปอร์เซนต์ '],
#   ['โน้ตบุ๊คและแท็บเล็ต lenovo 2 in 1 ideapad d330 10igm 81h3005ata wifi celeron n4000 10.1 inch ',
#    'ram',
#    ' 4gb lpddr4 2133 integrated graphic 64gb emmc win 10 รับประกันศูนย์ lenovo 1 ปี mineral gray free active pen โน๊ตบุ๊คถูก ผ่อน 0เปอร์เซนต์ สูงสุด 10 เดือน ส่งเร็ว ฿ 9490.00 ฿ 12990.00 27เปอร์เซนต์ '],
#   ['chuwi hi9 plus helio x27 deca core แอนดรอยด์ 8.0 10.8 นิ้ว จอละเอียด 2560x1600 ',
#    'ram',
#    ' 4gb ',
#    'ความจุ',
#    ' 64 128gb ใส่ได้ 2 ซิม โทรได้',
#    'รองรับ',
#    ' 4g ',
#    'รองรับ',
#    'คีย์บอร์ด ปากกา ฿ 6990.00 ฿ 12990.00 46เปอร์เซนต์ '],
#   ['jy teclast p80h แท็บเล็ต pc 8 wxga ips ',
#    'หน้าจอ',
#    ' android 8 กิกะไบต์ ',
#    'rom',
#    ' otg hdmi aus ฿ 2278.80 ฿ 4147.40 45เปอร์เซนต์ ']],
#  'category_1_243': [['ประเภท ', 'โทรศัพท์มือถือและแท็บเล็ต'],
#   ['ประเภทย่อย', ' แท็บเล็ต'],
#   ['แบรนด์', ' เลโนโว่'],
#   ['sku', ' 404360545 th 784536408'],
#   ['รุ่น', ' tb 7504x'],
#   ['ระยะเวลาการรับประกัน', ' 1 ปี']]}

# %%
# Construct triples of product
triples = []
for i,v in attr.items():
    for l in v:
        idx=0
        for idx in range(len(l)-1):
            tmp_list = [i]
            if l[idx] in attr_fix:
                tmp_list.extend([l[idx],l[idx+1]])
                triples.append(tmp_list)
            idx += 1

# %%
triples
# Out:
# [['category_0_0',
#   'ความจุ',
#   ' 6000 mah และสามารถชาร์จแบตเร็ว ด้วย fast charging'],
#  ['category_0_0',
#   'กล้องหลัง',
#   ' 3 ตัว ที่มีกล้องชัดสูงสุดถึง 48ล้านพิกเซล มาพร้อมกับเลนส์มุมกว้างพิเศษ ultra wide'],
#  ['category_0_0', 'ขนาด', ' 6.4 นิ้ว'],
#  ['category_0_0', 'แบรนด์', ' ซัมซุง'],
#  ['category_0_0', 'sku', ' 480942616 th 870640886'],
#  ['category_0_0', 'โมเดล', ' galaxy m30s 4 64gb '],
#  ['category_0_0', 'ระยะเวลาการรับประกัน', ' 1 ปี'],
#  ['category_0_1', 'รองรับ', ' 2 ซิม nano sim'],
#  ['category_0_1', 'หน่วยประมวลผล', ' exynos 9610 quad 2.3 ghz quad 1.7 ghz'],
#  ['category_0_1', 'ระบบปฏิบัติการ', ' android'],
#  ['category_0_1', 'รองรับ', 'สูงสุด 512 gb'],
#  ['category_0_1', 'หน้าจอ', ' 6.4 นิ้ว '],
#  ['category_0_1', 'ความละเอียด', ' 1080 x 2340 พิกเซล fhd '],
#  ['category_0_1',
#   'กล้องหลัง',
#   ' 3 เลนส์ 48 ล้านพิกเซล f 2.0 5 ล้านพิกเซล f 2.2 bokeh 8 ล้านพิกเซล f 2.4 ultrawide แฟลช led'],
#  ['category_0_1', 'กล้องหน้า', ' 32 ล้านพิกเซล f 2.0'],
#  ['category_0_1', 'แบตเตอรี่', ' 4000 mah'],
#  ['category_0_1', 'ขนาด', ' 158.5 x 74.5 x 7.7 มม. '],
#  ['category_0_1', 'น้ำหนัก', ' 169 g'],
#  ['category_0_1', 'แบรนด์', ' ซัมซุง'],
#  ['category_0_1', 'sku', ' 593772364 th 1113954823'],
#  ['category_0_1', 'ระยะเวลาการรับประกัน', ' 1 ปี'],
#  ['category_0_1', 'กล้องหน้า', ' ล้านพิกเซล 7ล้านพิกเซล ขึ้นไป'],
#  ['category_0_1', 'ระบบปฏิบัติการ', 'เวอร์ชัน android 9.0 pie'],
#  ['category_0_1', 'โมเดล', ' a50s'],
#  ['category_0_1', 'ขนาดหน้าจอ', ' นิ้ว 6.4'],
#  ['category_0_1', 'ความจุแบตเตอรี่', ' 1000 mah ถึง 5000 mah'],
#  ['category_0_2',
#   'หน้าจอ',
#   'ทรงหยดน้ำ รูปตัว v infinity v กว้าง 6.2 นิ้ว แนวทะแยง '],
#  ['category_0_2', 'ความละเอียด', ' 1520 x 720 พิกเซล'],
#  ['category_0_2', 'แบรนด์', ' ซัมซุง'],
#  ['category_0_2', 'sku', ' 404422189 th 784670279'],
#  ['category_0_2', 'ระยะเวลาการรับประกัน', ' 1 ปี'],
#  ['category_0_2', 'ระบบปฏิบัติการ', ' android 9.0 pie'],
#  ['category_0_2', 'กล้องหน้า', ' ล้านพิกเซล 7ล้านพิกเซล ขึ้นไป'],
#  ['category_0_2', 'ระบบปฏิบัติการ', 'เวอร์ชัน android 9.0 pie'],
#  ['category_0_2', 'โมเดล', ' samsung galaxy a10s '],
#  ['category_0_2', 'ขนาดหน้าจอ', ' นิ้ว 6.2'],
#  ['category_0_2', 'ความจุแบตเตอรี่', ' 1000 mah ถึง 5000 mah'],
#  ['category_0_3', 'ขนาดหน้าจอ', ' 6.8 นิ้ว'],
#  ['category_0_3', 'ความจุ', 'ที่เก็บข้อมูล 256 gb'],
#  ['category_0_3', 'แบตเตอรี่', ' 4300 mah typical '],
#  ['category_0_3', 'มาตรฐานการกันน้ำและกันฝุ่น', ' ip68'],
#  ['category_0_3', 'แบรนด์', ' ซัมซุง'],
#  ['category_0_3', 'sku', ' 385536916 th 749070165'],
#  ['category_0_3', 'โมเดล', ' galaxy note 10 '],
#  ['category_0_3', 'ขนาดหน้าจอ', ' นิ้ว 6.8'],
#  ['category_0_3', 'ระยะเวลาการรับประกัน', ' 1 ปี'],
#  ['category_0_4',
#   'หน้าจอ',
#   'อัตโนมัติขณะสนทนา proximity ระบบตรวจจับคลื่นแม่เหล็ก geomagnetic ระบบเซนเซอร์หมุนภาพ gyroscope ระบบวัดความกดอากาศ ba'],
#  ['category_0_4', 'รองรับ', ' 2 ซิมการ์ด'],
#  ['category_0_4', 'ระบบปฏิบัติการ', ' android 6.0.1 marshmallow '],
#  ['category_0_4', 'หน่วยประมวลผล', ' octa core ความเร็ว 1.9 ghz'],
#  ['category_0_4', 'รองรับ', 'ชุดหูฟังสเตอริโอ a2dp bluetooth stereo '],
#  ['category_0_4', 'รองรับ', ' nfc near field communication '],
#  ['category_0_4', 'กล้องหน้า', ' front camera '],
#  ['category_0_4', 'ความละเอียด', ' 16ล้านพิกเซล '],
#  ['category_0_4', 'รองรับ', 'วีดีโอจาก youtube '],
#  ['category_0_5', 'กล้องหน้า', 'ความละเอียด'],
#  ['category_0_5', 'ความละเอียด', ' 24ล้านพิกเซล '],
#  ['category_0_5', 'แบรนด์', ' ซัมซุง'],
#  ['category_0_5', 'sku', ' 265390897 th 412154584'],
#  ['category_0_5', 'โมเดล', ' galaxy a9 2018 '],
#  ['category_0_5', 'ระยะเวลาการรับประกัน', ' 1 ปี'],
#  ['category_0_6', 'ความละเอียด', ' 720 x 1560 พิกเซล 268 ppi '],
#  ['category_0_6',
#   'หน่วยประมวลผล',
#   ' exynos 7885 octa core ความเร็ว 1.8 mhz หน่วยความจำ'],
#  ['category_0_6', 'กล้องหน้า', ' front camera '],
#  ['category_0_6', 'ความละเอียด', ' 16ล้านพิกเซล '],
#  ['category_0_6', 'รองรับ', ' 2 ซิมการ์ด'],
#  ['category_0_6',
#   'หน้าจอ',
#   ' fingerprint under จอแสดงผล ตรวจจับความเคลื่อนไหวของตัวเครื่อง accele'],
#  ['category_0_6', 'หน้าจอ', 'อัตโนมัติขณะสนทนา proximity '],
#  ['category_0_6', 'แบตเตอรี่', 'มาตรฐาน li pol 4000 mah standard battery '],
#  ['category_0_6', 'แบรนด์', ' ซัมซุง'],
#  ['category_0_6', 'sku', ' 594352438 th 1115888431'],
#  ['category_0_6', 'กล้องหน้า', ' ล้านพิกเซล 16ล้านพิกเซล '],
#  ['category_0_6', 'โมเดล', ' samsung a30s'],
#  ['category_0_6', 'ระยะเวลาการรับประกัน', ' 1 ปี'],
#  ['category_0_6', 'ความจุแบตเตอรี่', ' 1000 mah ถึง 5000 mah'],
#  ['category_0_7', 'แบรนด์', ' ซัมซุง'],
#  ['category_0_7', 'sku', ' 599364278 th 1176694583'],
#  ['category_0_7', 'ระบบปฏิบัติการ', 'เวอร์ชัน android 9.0 pie'],
#  ['category_0_7', 'โมเดล', ' samsung galaxy note10 plus'],
#  ['category_0_7', 'ขนาดหน้าจอ', ' นิ้ว 6.8'],
#  ['category_0_7', 'ระยะเวลาการรับประกัน', ' 1 ปี'],
#  ['category_0_8', 'หน้าจอ', 'กว้าง 6.7 แบบ infinity u จอแสดงผล '],
#  ['category_0_8', 'แบรนด์', ' ซัมซุง'],
#  ['category_0_8', 'sku', ' 309636084 th 547152150'],
#  ['category_0_8', 'โมเดล', ' a70 8 128gb '],
#  ['category_0_8', 'ระยะเวลาการรับประกัน', ' 1 ปี'],
#  ['category_0_9', 'ขนาดหน้าจอ', ' 6.2 นิ้ว '],
#  ['category_0_9', 'แบรนด์', ' ซัมซุง'],
#  ['category_0_9', 'sku', ' 571250946 th 1048780375'],
#  ['category_0_9', 'ระยะเวลาการรับประกัน', ' 1 เดือน'],
#  ['category_0_9', 'แบตเตอรี่', 'แบตเตอรี่'],
#  ['category_0_9', 'แบตเตอรี่', 'ชาร์จใหม่ได้และถอดได้'],
#  ['category_0_9', 'กล้องหน้า', ' ล้านพิกเซล 7ล้านพิกเซล ขึ้นไป'],
#  ['category_0_9',
#   'โมเดล',
#   ' สมาร์ทโฟน โทรศัพท์มือถือ samsung galaxy a10s sm a107m '],
#  ['category_0_9', 'ขนาดหน้าจอ', ' 6.2 นิ้ว '],
#  ['category_0_9', 'หน้าจอ', ' lcd'],
#  ['category_0_9', 'ความละเอียด', 'วิดีโอ 1080p'],
#  ['category_0_9', 'ความจุแบตเตอรี่', ' 1000 mah ถึง 5000 mah'],
#  ['category_0_10', 'ความละเอียด', ' 1080 x 1920 พิกเซล ประเภทจอ '],
#  ['category_0_10',
#   'หน้าจอ',
#   'กระจกแข็ง ประเภทจอ ระบบป้องกัน ฝุ่นละออง resistance to dust '],
#  ['category_0_10',
#   'หน้าจอ',
#   'อัตโนมัติขณะสนทนา proximity ระบบตรวจจับคลื่นแม่เหล็ก geomagnetic ระบบเซนเซอร์หมุนภาพ gyroscope ระบบวัดความกดอากาศ ba'],
#  ['category_0_10', 'รองรับ', ' 2 ซิมการ์ด'],
#  ['category_0_10', 'ระบบปฏิบัติการ', ' android 6.0.1 marshmallow '],
#  ['category_0_10', 'หน่วยประมวลผล', ' octa core ความเร็ว 1.9 ghz'],
#  ['category_0_10', 'รองรับ', 'ชุดหูฟังสเตอริโอ a2dp bluetooth stereo '],
#  ['category_0_10', 'รองรับ', ' nfc near field communication '],
#  ['category_0_10', 'กล้องหน้า', ' front camera '],
#  ['category_0_10', 'ความละเอียด', ' 16ล้านพิกเซล '],
#  ['category_0_10', 'รองรับ', 'วีดีโอจาก youtube '],
#  ['category_0_11', 'ขนาด', ' 5.2 นิ้ว'],
#  ['category_0_11', 'ความละเอียด', 'ระดับ full hd 1080p 1080x1920 พิกเซล '],
#  ['category_0_11', 'ขนาด', ' 3 gb'],
#  ['category_0_11', 'ขนาด', ' 32 gb'],
#  ['category_0_11', 'ความละเอียด', ' 16 ล้านพิกเซล'],
#  ['category_0_11', 'แบรนด์', ' ซัมซุง'],
#  ['category_0_11', 'sku', ' sa861elaa8nxs2anth 17866375'],
#  ['category_0_11', 'ระยะเวลาการรับประกัน', ' 1 ปี'],
#  ['category_0_11', 'ระบบปฏิบัติการ', ' android'],
#  ['category_0_11', 'กล้องหน้า', ' ล้านพิกเซล 7ล้านพิกเซล ขึ้นไป'],
#  ['category_0_11', 'ระบบปฏิบัติการ', 'เวอร์ชัน marshmallow'],
#  ['category_0_11', 'โมเดล', ' samsung galaxy a5 2017 gold'],
#  ['category_0_11', 'หน้าจอ', ' amoled'],
#  ['category_0_11', 'ขนาดหน้าจอ', ' นิ้ว 5.2'],
#  ['category_0_12', 'กล้องหลัง', ' 2ตัวพร้อมระบบถ่ายภาพอัจฉริยะ'],
#  ['category_0_12', 'แบรนด์', ' ซัมซุง'],
#  ['category_0_12', 'sku', ' 526004055 th 942110374'],
#  ['category_0_12', 'โมเดล', ' s10e 6 128gb '],
#  ['category_0_12', 'ระยะเวลาการรับประกัน', ' 1 ปี'],
#  ['category_0_13', 'ขนาดหน้าจอ', ' 6.2 นิ้ว '],
#  ['category_0_13', 'แบรนด์', ' ซัมซุง'],
#  ['category_0_13', 'sku', ' 571320012 th 1048806072'],
#  ['category_0_13', 'ระยะเวลาการรับประกัน', ' 1 เดือน'],
#  ['category_0_13', 'แบตเตอรี่', 'แบตเตอรี่'],
#  ['category_0_13', 'แบตเตอรี่', 'ชาร์จใหม่ได้และถอดได้'],
#  ['category_0_13', 'กล้องหน้า', ' ล้านพิกเซล 7ล้านพิกเซล ขึ้นไป'],
#  ['category_0_13',
#   'โมเดล',
#   ' สมาร์ทโฟน โทรศัพท์มือถือ samsung galaxy a10s sm a107m '],
#  ['category_0_13', 'ขนาดหน้าจอ', ' 6.2 นิ้ว '],
#  ['category_0_13', 'หน้าจอ', ' lcd'],
#  ['category_0_13', 'ความละเอียด', 'วิดีโอ 1080p'],
#  ['category_0_13', 'ความจุแบตเตอรี่', ' 1000 mah ถึง 5000 mah'],
#  ['category_0_14', 'ขนาด', 'เครื่อง 156.9 x 75.8 x 7.8 มม. หนัก 168 กรัม '],
#  ['category_0_14', 'หน้าจอ', ' pls tft lcd '],
#  ['category_0_14', 'ความละเอียด', ' 720 x 1520 พิกเซล hd '],
#  ['category_0_14', 'ขนาด', ' 6.2 นิ้ว'],
#  ['category_0_14', 'gpu', ' powervr ge8320'],
#  ['category_0_14', 'รองรับ', 'หน่วยความจำเสริม microsd card สูงสุด 512gb'],
#  ['category_0_14',
#   'กล้องหลัง',
#   'เลนส์คู่ กล้องหลัก 13 ล้านพิกเซล รูรับแสง f 1.8 มีระบบออโต้โฟกัส'],
#  ['category_0_14', 'รองรับ', 'การบันทึกวีดีโอสูงสุด fhd 1920 x 1080 30fps'],
#  ['category_0_14', 'กล้องหน้า', ' 8 ล้านพิกเซล รูรับแสง f 2.0 '],
#  ['category_0_14', 'รองรับ', 'การทำงานสองซิม'],
#  ['category_0_14', 'รองรับ', ' 2g gsm 3g wcdma 4g lte fdd 4g lte tdd'],
#  ['category_0_14',
#   'รองรับ',
#   ' wi fi 802.11 b g n 2.4ghz wi fi direct สนับสนุน bluetooth 4.2'],
#  ['category_0_14', 'ระบบปฏิบัติการ', ' android 9 pie oneui '],
#  ['category_0_14', 'แบรนด์', ' ซัมซุง'],
#  ['category_0_14', 'sku', ' 594306208 th 1115720937'],
#  ['category_0_14', 'กล้องหน้า', ' ล้านพิกเซล 7ล้านพิกเซล ขึ้นไป'],
#  ['category_0_14', 'โมเดล', ' samsung a10s'],
#  ['category_0_14', 'ระยะเวลาการรับประกัน', ' 1 ปี'],
#  ['category_0_14', 'ความจุแบตเตอรี่', ' 1000 mah ถึง 5000 mah'],
#  ['category_0_15',
#   'รุ่น',
#   ' non slip soft 3d คาร์บอนไฟเบอร์ฝาหลังฟิล์มป้องกันด้านหลังสติกเกอร์ป้องกัน ฿ 55.00 ฿ 92.00 40เปอร์เซนต์ '],
#  ['category_0_16', 'หน้าจอ', ' 6.1 นิ้ว '],
#  ['category_0_16', 'ความละเอียด', '3040x1440 quad hd 550 ppi '],
#  ['category_0_16',
#   'กล้องหลัง',
#   ' 3 ตัว 16ล้านพิกเซล f 2.2 ultra wide 12ล้านพิกเซล f 1.5 และ 2.4 wide 12ล้านพิกเซล f 2.4 tele '],
#  ['category_0_16', 'กล้องหน้า', '10ล้านพิกเซล f 1.9'],
#  ['category_0_16',
#   'หน่วยประมวลผล',
#   'octa core snapdragon 855octa core exynos9 9820'],
#  ['category_0_16', 'แบตเตอรี่', '3400 mah typical '],
#  ['category_0_16', 'แบรนด์', ' ซัมซุง'],
#  ['category_0_16', 'sku', ' 289434461 th 479544867'],
#  ['category_0_16', 'โมเดล', ' s10 128gb '],
#  ['category_0_16', 'ระยะเวลาการรับประกัน', ' 1 ปี'],
#  ['category_0_17', 'ขนาด', 'น้ำหนัก'],
#  ['category_0_17', 'น้ำหนัก', ' ยาว 163.3 กว้าง 77.5 หนา 8 มม. '],
#  ['category_0_17', 'น้ำหนัก', ' 183 กรัม'],
#  ['category_0_17', 'ขนาด', 'ความละเอียด'],
#  ['category_0_17', 'ความละเอียด', ' 6.5 นิ้ว 264 ppi 720 1560 px'],
#  ['category_0_17', 'หน้าจอ', ' tft แบบ infinity u จอแสดงผล '],
#  ['category_0_17', 'ขนาด', ' 6.5 นิ้ว '],
#  ['category_0_17', 'ความละเอียด', ' hd 720 x 1560 พิกเซล อัตราส่วน'],
#  ['category_0_17', 'หน้าจอ', ' 19.5 9'],
#  ['category_0_17', 'หน่วยประมวลผล', 'cpu'],
#  ['category_0_17', 'cpu', ' snapdragon 450 '],
#  ['category_0_17', 'หน่วยประมวลผล', 'gpu'],
#  ['category_0_17', 'gpu', ' adreno 506'],
#  ['category_0_17', 'รองรับ', ' 2 ซิมการ์ด '],
#  ['category_0_17', 'รองรับ', 'การเพิ่มความจำด้วย microsd card สูงสุด 512 gb'],
#  ['category_0_17', 'กล้องหลัง', ' 3 ตัว ประกอบด้วย'],
#  ['category_0_17',
#   'ความละเอียด',
#   ' 13ล้านพิกเซล f 1.8 เลนส์ ultra wide 120 องศา '],
#  ['category_0_17', 'ความละเอียด', ' 8ล้านพิกเซล f 2.2 เลนส์ depth '],
#  ['category_0_17', 'ความละเอียด', ' 5ล้านพิกเซล f 2.2 '],
#  ['category_0_17', 'รองรับ', 'ระบบเสียง dolby atmos เซ็นเซอร์ accele'],
#  ['category_0_17',
#   'รองรับ',
#   ' 15w fast charging ระบบปฎิบัติการ android 9.0 pi'],
#  ['category_0_17', 'แบรนด์', ' ซัมซุง'],
#  ['category_0_17', 'sku', ' 594338092 th 1115814517'],
#  ['category_0_17', 'กล้องหน้า', ' ล้านพิกเซล 7ล้านพิกเซล ขึ้นไป'],
#  ['category_0_17', 'โมเดล', ' samsung a20s'],
#  ['category_0_17', 'ระยะเวลาการรับประกัน', ' 1 ปี'],
#  ['category_0_17', 'ความจุแบตเตอรี่', ' 1000 mah ถึง 5000 mah'],
#  ['category_0_18', 'หน้าจอ', ' super amoled '],
#  ['category_0_18', 'ขนาด', ' 6.7 นิ้ว '],
#  ['category_0_18', 'ความละเอียด', ' fhd 1080 x 2400 '],
#  ['category_0_18', 'cpu', ' snapdragon 730'],
#  ['category_0_18', 'ความจุ', ' 128gb ufs 2.1 ไม่'],
#  ['category_0_18', 'รองรับ', ' microsd card'],
#  ['category_0_18',
#   'กล้องหน้า',
#   ' หลัง 4ล้านพิกเซล f 2.0 imx586 ultra wide ล้านพิกเซล f 2.2 tof'],
#  ['category_0_18', 'แบตเตอรี่', ' 3700 mah '],
#  ['category_0_18', 'รองรับ', ' super fast charging 25w'],
#  ['category_0_18', 'แบรนด์', ' ซัมซุง'],
#  ['category_0_18', 'sku', ' 340860812 th 661136678'],
#  ['category_0_18', 'ระยะเวลาการรับประกัน', ' 1 ปี'],
#  ['category_0_18', 'ระบบปฏิบัติการ', ' android'],
#  ['category_0_18', 'ระบบปฏิบัติการ', 'เวอร์ชัน android 9.0 pie'],
#  ['category_0_18', 'โมเดล', ' a80'],
#  ['category_0_18', 'ขนาดหน้าจอ', ' นิ้ว 6.7'],
#  ['category_0_18', 'ความจุแบตเตอรี่', ' 3000 3999 mah'],
#  ['category_0_19', 'รองรับ', ' 2 ซิมการ์ด'],
#  ['category_0_19',
#   'ความละเอียด',
#   ' 2960 x 1440 พิกเซล capacitive corning gorilla glass 5 ระบบป้องกัน ฝุ่นละออง resistance to dust '],
#  ['category_0_19',
#   'หน้าจอ',
#   'อัตโนมัติขณะสนทนา proximity ระบบเซนเซอร์หมุนภาพ gyroscope ระบบวัดความกดอากาศ ba'],
#  ['category_0_19', 'รองรับ', ' s pen ระบบปากกาอัจฉริยะ ระบบสแกนม่านตา'],
#  ['category_0_19', 'ระบบปฏิบัติการ', ' android 8.1 oreo'],
#  ['category_0_19', 'หน่วยประมวลผล', ' exynos 9810 octa core ความเร็ว 2.7 ghz'],
#  ['category_0_19', 'กล้องหน้า', ' front camera '],
#  ['category_0_19', 'ความละเอียด', ' 8ล้านพิกเซล '],
#  ['category_0_19', 'แบตเตอรี่', 'มาตรฐาน 4000 mah standard battery '],
#  ['category_0_19', 'แบรนด์', ' ซัมซุง'],
#  ['category_0_19', 'sku', ' 283666353 th 461390461'],
#  ['category_0_19',
#   'โมเดล',
#   ' samsung galaxy note 9 6gb 128gb เครื่องศูนย์ มีประกัน ocean blue '],
#  ['category_0_19', 'ระยะเวลาการรับประกัน', ' 1 ปี'],
#  ['category_0_19', 'ระบบปฏิบัติการ', ' android'],
#  ['category_0_20',
#   'กล้องหลัง',
#   'คู่ 13 ล้านพิกเซล แบต 4000mah ประกันศูนย์ 1 ปี แถมฟรีหูฟังซัมซุง มูลค่า 399 บาท'],
#  ['category_0_20', 'น้ำหนัก', ' 168 กรัม'],
#  ['category_0_20',
#   'ความละเอียด',
#   ' 1520x720 พิกเซล hd มีดีไซน์รอยแหว่งแบบ infinity v'],
#  ['category_0_20', 'ระบบปฏิบัติการ', ' one ui 1.1 บนพื้นฐาน android 9 pie'],
#  ['category_0_20', 'กล้องหลัง', ' 2 เลนส์ พร้อมไฟแฟลชเลนส์หลัก '],
#  ['category_0_20', 'ความละเอียด', ' 13 ล้านพิกเซล รูรับแสง f 1.8'],
#  ['category_0_20', 'ความละเอียด', ' 2 ล้านพิกเซล รูรับแสง f 2.4'],
#  ['category_0_20', 'กล้องหน้า', 'ความละเอียด'],
#  ['category_0_20', 'ความละเอียด', ' 8 ล้านพิกเซล รูรับแสง f 2.2'],
#  ['category_0_20', 'รองรับ', ' 2 ซิมแบบ nano sim'],
#  ['category_0_20', 'แบตเตอรี่', ' 4000mah'],
#  ['category_0_20', 'แบรนด์', ' ซัมซุง'],
#  ['category_0_20', 'sku', ' 616572478 th 1170962904'],
#  ['category_0_20', 'ระยะเวลาการรับประกัน', ' 1 ปี'],
#  ['category_0_20', 'แบตเตอรี่', ' built in rechargeable battery'],
#  ['category_0_20', 'กล้องหน้า', ' ล้านพิกเซล 7ล้านพิกเซล ขึ้นไป'],
#  ['category_0_20', 'ระบบปฏิบัติการ', 'เวอร์ชัน android 9.0 pie'],
#  ['category_0_20', 'โมเดล', ' samsung galaxy a10s sm a107f '],
#  ['category_0_21', 'แบรนด์', ' ซัมซุง'],
#  ['category_0_21', 'sku', ' 307684896 th 537048806'],
#  ['category_0_21', 'โมเดล', ' samsung galaxy j4 plus'],
#  ['category_0_21', 'ระยะเวลาการรับประกัน', ' 1 ปี'],
#  ['category_0_22', 'ขนาดหน้าจอ', ' 6.3 นิ้ว'],
#  ['category_0_22', 'ความจุ', 'ที่เก็บข้อมูล 256 gb'],
#  ['category_0_22', 'แบตเตอรี่', ' 3500 mah typical '],
#  ['category_0_22', 'มาตรฐานการกันน้ำและกันฝุ่น', ' ip68'],
#  ['category_0_22', 'แบรนด์', ' ซัมซุง'],
#  ['category_0_22', 'sku', ' 373972071 th 728742055'],
#  ['category_0_22', 'โมเดล', ' 8 256gb'],
#  ['category_0_22', 'ระยะเวลาการรับประกัน', ' 1 ปี'],
#  ['category_0_23', 'หน้าจอ', 'กว้าง'],
#  ['category_0_23', 'ขนาด', ' 6.3 ใหญ่ที่สุดในตระกูล note'],
#  ['category_0_23', 'หน้าจอ', 'กว้างขึ้น ด้วย'],
#  ['category_0_23',
#   'ขนาด',
#   ' 6.3 ใหญ่ที่สุดในตระกูล note มอบภาพที่คมชัด แจ้มแจ้งในทุกรายละเอียด'],
#  ['category_0_23', 'หน้าจอ', 'ที่มาก ปรับแต่งรายการต่างๆ พร้อมขยับจอน้อยลง'],
#  ['category_0_23', 'แบรนด์', ' ซัมซุง'],
#  ['category_0_23', 'sku', ' 310302392 th 552106447'],
#  ['category_0_23', 'โมเดล', ' sm n950'],
#  ['category_0_23', 'ระยะเวลาการรับประกัน', ' 1 ปี'],
#  ['category_0_24', 'กล้องหน้า', 'ความละเอียด'],
#  ['category_0_24', 'ความละเอียด', ' 24ล้านพิกเซล '],
#  ['category_0_24', 'แบรนด์', ' ซัมซุง'],
#  ['category_0_24', 'sku', ' 280354579 th 453591358'],
#  ['category_0_24', 'ระยะเวลาการรับประกัน', ' 5 วัน'],
#  ['category_0_24', 'ระบบปฏิบัติการ', ' android'],
#  ['category_0_24', 'กล้องหน้า', ' ล้านพิกเซล 7ล้านพิกเซล ขึ้นไป'],
#  ['category_0_24', 'ระบบปฏิบัติการ', 'เวอร์ชัน android 8.0 oreo'],
#  ['category_0_24',
#   'โมเดล',
#   ' samsung galaxy a9 2018 6 128gb เครื่องศูนย์ เคลียสตอคไม่มีประกัน caviar black '],
#  ['category_0_24', 'ขนาดหน้าจอ', ' นิ้ว 6.3'],
#  ['category_0_24', 'ความจุแบตเตอรี่', ' 1000 mah ถึง 5000 mah'],
#  ['category_0_25',
#   'หน้าจอ',
#   'ทรงหยดน้ำ รูปตัว u infinity u ระบบสัมผัส multi touch กว้าง 6.7 นิ้ว แนวทะแยง '],
#  ['category_0_25',
#   'ความละเอียด',
#   ' 1080 x 2400 พิกเซล capacitiveระบบเซ็นเซอร์ sensor ระบบสแกนลายนิ้วมือใต้'],
#  ['category_0_25',
#   'หน้าจอ',
#   ' fingerprint under จอแสดงผล ระบบจดจำใบหน้า face detection ระบบหมุนภาพอัตโนมัติ accele'],
#  ['category_0_25',
#   'หน้าจอ',
#   'อัตโนมัติขณะสนทนา proximity ระบบเซนเซอร์หมุนภาพ gyroscope ปรับมุมมองการแสดงผลอัตโนมัติ orientation '],
#  ['category_0_25', 'ระบบปฏิบัติการ', ' android 9 pie'],
#  ['category_0_25',
#   'หน่วยประมวลผล',
#   ' snapdragon 675 octa core ความเร็ว 2.0 ghzหน่วยความจำ '],
#  ['category_0_25', 'กล้องหน้า', ' front camera '],
#  ['category_0_25', 'ความละเอียด', ' 32 '],
#  ['category_0_25',
#   'กล้องหน้า',
#   ' hdr บันทึกวีดีโอ ภาพเคลื่อนไหว video recording รูปแบบไฟล์วีดีโอ ล้านพิกเซล eg 4 เครื่องเล่นวีดีโอ video player รูปแบบไฟล์ ล้านพิกเซล eg 4 '],
#  ['category_0_25',
#   'รองรับ',
#   'วีดีโอจาก youtube เครื่องเล่นเพลง music player รูปแบบไฟล์ ล้านพิกเซล 3 ระบบเสียง dolby atmosเทคโนโลยีเพิ่มความเร็วในการชาร์จ'],
#  ['category_0_25', 'แบตเตอรี่', 'มาตรฐาน 4500 mah standard battery '],
#  ['category_0_25', 'แบรนด์', ' ซัมซุง'],
#  ['category_0_25', 'sku', ' 595150747 th 1117932783'],
#  ['category_0_25', 'โมเดล', ' samsung a70'],
#  ['category_0_26', 'กล้องหน้า', ' และ หลัง'],
#  ['category_0_26', 'ความละเอียด', 'เท่ากัน 16ล้านพิกเซล '],
#  ['category_0_26',
#   'กล้องหน้า',
#   'มาพร้อม3 step lighting ช่วยปรับแสงได้ 3 ระดับ และ'],
#  ['category_0_26', 'กล้องหลัง', ' รูรับแสงกว้าง f1.7'],
#  ['category_0_26', 'หน้าจอ', 'ในคลิ๊กเดียว'],
#  ['category_0_26', 'รองรับ', 'แอพsocial เยอะที่สุดถึง 18 แอพ'],
#  ['category_0_26', 'แบรนด์', ' ซัมซุง'],
#  ['category_0_26', 'sku', ' 264741378 th 411062149'],
#  ['category_0_26', 'โมเดล', ' galaxy a6 sm a605g ds '],
#  ['category_0_26', 'ขนาดหน้าจอ', ' นิ้ว 6'],
#  ['category_0_26', 'ระยะเวลาการรับประกัน', ' 1 ปี'],
#  ['category_0_27',
#   'แบรนด์',
#   ' new original packaging undamaged unopened unused item it is original and packaging is the same as what is found in the retail store unless the item is handmade or was packaged by the manufacturer in non retail packaging such as an unprinted box or plastic bag '],
#  ['category_0_27', 'แบรนด์', ' ซัมซุง'],
#  ['category_0_27', 'sku', ' 617108827 th 1172618764'],
#  ['category_0_27', 'ระบบปฏิบัติการ', 'เวอร์ชัน android 9.0 pie'],
#  ['category_0_27', 'โมเดล', ' samsung galaxy a50s 128gb 6gb '],
#  ['category_0_27', 'ระยะเวลาการรับประกัน', ' 1 ปี'],
#  ['category_0_28', 'หน้าจอ', 'ใหญ่ที่เต็มตากว่าเดิม'],
#  ['category_0_28', 'แบรนด์', ' ซัมซุง'],
#  ['category_0_28', 'sku', ' 511068392 th 907938105'],
#  ['category_0_28', 'โมเดล', ' galaxy a20s 3 32gb '],
#  ['category_0_28', 'ระยะเวลาการรับประกัน', ' 1 ปี'],
#  ['category_0_29', 'หน้าจอ', 'ใหญ่ super amoled 5.6 นิ้ว สัดส่วน 18.5 9'],
#  ['category_0_29', 'ระบบปฏิบัติการ', 'แอนดรอยด์ 7.1 nougat '],
#  ['category_0_29', 'กล้องหน้า', 'แบบคู่ 16 และ 8 ล้านพิกเซล รูรับแสง f 1.9'],
#  ['category_0_29', 'หน้าจอ', 'ด้วยการสแกนใบหน้า'],
#  ['category_0_29', 'รองรับ', 'การใช้งาน secure folder'],
#  ['category_0_29', 'รองรับ', 'การสแกนลายนิ้วมือ'],
#  ['category_0_29', 'หน้าจอ', 'ใหญ่ super amoled 5.6 นิ้ว สัดส่วน 18.5 9'],
#  ['category_0_29', 'ระบบปฏิบัติการ', 'แอนดรอยด์ 7.1 nougat '],
#  ['category_0_29', 'กล้องหน้า', 'แบบคู่ 16 และ 8 ล้านพิกเซล รูรับแสง f 1.9'],
#  ['category_0_29', 'หน้าจอ', 'ด้วยการสแกนใบหน้า'],
#  ['category_0_29', 'รองรับ', 'การใช้งาน secure folder'],
#  ['category_0_29', 'รองรับ', 'การสแกนลายนิ้วมือ'],
#  ['category_0_29', 'แบรนด์', ' ซัมซุง'],
#  ['category_0_29', 'sku', ' 207916690 th 313021622'],
#  ['category_0_29', 'โมเดล', ' refurbish samsung galaxy a8 2018 gold'],
#  ['category_0_29', 'ระยะเวลาการรับประกัน', ' 3 เดือน'],
#  ['category_0_30', 'หน้าจอ', ' 6.4 นิ้ว '],
#  ['category_0_30', 'ความละเอียด', ' 3040x1440 quad hd 550 ppi '],
#  ['category_0_30',
#   'กล้องหลัง',
#   ' 3 ตัว 16ล้านพิกเซล f 2.2 ultra wide 12ล้านพิกเซล f 1.5 และ 2.4 wide 12ล้านพิกเซล f 2.4 tele '],
#  ['category_0_30',
#   'กล้องหน้า',
#   ' 2 ตัว 10ล้านพิกเซล f 1.9 main 8ล้านพิกเซล f 2.2 live focus '],
#  ['category_0_30',
#   'หน่วยประมวลผล',
#   ' octa core snapdragon 855 octa core exynos9 9820'],
#  ['category_0_30', 'แบตเตอรี่', ' 4100 mah typical '],
#  ['category_0_30', 'แบรนด์', ' ซัมซุง'],
#  ['category_0_30', 'sku', ' 289426638 th 479560515'],
#  ['category_0_30', 'โมเดล', ' s10 128gb '],
#  ['category_0_30', 'ระยะเวลาการรับประกัน', ' 1 ปี'],
#  ['category_0_31', 'ระบบปฏิบัติการ', ' os '],
#  ['category_0_31', 'cpu', 'ระบบปฏิบัติการ'],
#  ['category_0_31', 'ระบบปฏิบัติการ', ' android 8.0 oreo '],
#  ['category_0_31', 'หน่วยประมวลผล', ' qualcomm snapdragon 450 octa core'],
#  ['category_0_31', 'แบรนด์', ' ซัมซุง'],
#  ['category_0_31', 'sku', ' 289402378 th 479508064'],
#  ['category_0_31', 'โมเดล', ' samsung j8 '],
#  ['category_0_31', 'ระยะเวลาการรับประกัน', ' 3 เดือน'],
#  ['category_0_31', 'ระบบปฏิบัติการ', ' android'],
#  ['category_0_32',
#   'ความละเอียด',
#   ' 48ล้านพิกเซล จอกว้าง 6.3 นิ้ว fhd ชิปเซ็ต qualcomm sd 665 ฿ 4299.00 ฿ 4999.00 14เปอร์เซนต์ '],
#  ['category_0_32', 'แบตเตอรี่', 'สำรอง ฿ 1290.00 ฿ 1590.00 19เปอร์เซนต์ '],
#  ['category_0_33', 'แบรนด์', ' new'],
#  ['category_0_33', 'แบรนด์', ' ซัมซุง'],
#  ['category_0_33', 'sku', ' 612014873 th 1155486191'],
#  ['category_0_33', 'ระบบปฏิบัติการ', 'เวอร์ชัน android 8.1 oreo'],
#  ['category_0_33', 'โมเดล', ' samsung galaxy note 10 plus'],
#  ['category_0_33', 'ระยะเวลาการรับประกัน', ' 1 ปี'],
#  ['category_0_34', 'รองรับ', ' 2 ซิมการ์ด'],
#  ['category_0_34',
#   'ความละเอียด',
#   ' 2960x1440 พิกเซล capacitive corning gorilla glass5 ระบบป้องกันฝุ่นละออง resistance to dust '],
#  ['category_0_34',
#   'หน้าจอ',
#   'อัตโนมัติขณะสนทนา proximity ระบบเซ็นเซอร์หมุนภาพ gyroscope ระบบวัดความกดอากาศ ba'],
#  ['category_0_34', 'รองรับ', ' s pen ระบบปากกาอัจฉริยะ ระบบสแกนม่านตา'],
#  ['category_0_34', 'ระบบปฏิบัติการ', ' android 8.1 oreo'],
#  ['category_0_34', 'หน่วยประมวลผล', ' exynos 9810octa core ความเร็ว 2.7 ghz'],
#  ['category_0_34', 'รองรับ', 'ได้สูงสุด 512 gb'],
#  ['category_0_34', 'กล้องหน้า', ' front camera '],
#  ['category_0_34', 'ความละเอียด', ' 8ล้านพิกเซล '],
#  ['category_0_34', 'แบตเตอรี่', 'มาตรฐาน 4000 mah standard battery '],
#  ['category_0_34', 'แบรนด์', ' ซัมซุง'],
#  ['category_0_34', 'sku', ' 283658415 th 461387419'],
#  ['category_0_34',
#   'โมเดล',
#   ' samsung galaxy note 9 6gb 128gb เครื่องศูนย์ มีประกัน midnight black ระ'],
#  ['category_0_34', 'ระยะเวลาการรับประกัน', ' 1 ปี'],
#  ['category_0_34', 'ระบบปฏิบัติการ', ' android'],
#  ['category_0_35', 'แบรนด์', ' new samsung galaxy s10 plus 128gb'],
#  ['category_0_35', 'แบรนด์', ' new'],
#  ['category_0_35', 'แบรนด์', ' ซัมซุง'],
#  ['category_0_35', 'sku', ' 610820644 th 1151996547'],
#  ['category_0_35', 'ระบบปฏิบัติการ', 'เวอร์ชัน android 8.0 oreo'],
#  ['category_0_35', 'โมเดล', ' samsung galaxy s10 plus'],
#  ['category_0_35', 'ระยะเวลาการรับประกัน', ' 1 ปี'],
#  ['category_0_36',
#   'แบรนด์',
#   ' new original packaging undamaged unopened unused item it is original and packaging is the same as what is found in the retail store unless the item is handmade or was packaged by the manufacturer in non retail packaging such as an unprinted box or plastic bag '],
#  ['category_0_36', 'แบรนด์', ' ซัมซุง'],
#  ['category_0_36', 'sku', ' 617168251 th 1172664402'],
#  ['category_0_36', 'ระบบปฏิบัติการ', 'เวอร์ชัน android 9.0 pie'],
#  ['category_0_36', 'โมเดล', ' samsung galaxy note 9 8gb 512gb '],
#  ['category_0_36', 'ระยะเวลาการรับประกัน', ' 1 ปี'],
#  ['category_0_37',
#   'รุ่น',
#   ' s9 plus 256gb สีฟ้า ฿ 7900.00 ฿ 13590.00 42เปอร์เซนต์ '],
#  ['category_0_38',
#   'หน้าจอ',
#   ' samoled full จอแสดงผล ไร้กรอบ ไร้ปุ่มโฮม เพิ่มมุมมองการเห็น ด้วยสัดส่วน 19.5 9 จอกว้างขึ้น พร้อม'],
#  ['category_0_38', 'ความละเอียด', ' fhd เพื่อการชมภาพยนตร์ที่เต็มอิ่มมากขึ้น'],
#  ['category_0_38', 'แบรนด์', ' ซัมซุง'],
#  ['category_0_38', 'sku', ' 299990648 th 515722325'],
#  ['category_0_38', 'โมเดล', ' galaxy a30 4 64gb '],
#  ['category_0_38', 'ระยะเวลาการรับประกัน', ' 1 ปี'],
#  ['category_0_39', 'แบรนด์', ' ซัมซุง'],
#  ['category_0_39', 'sku', ' 408012228 th 792604544'],
#  ['category_0_39', 'โมเดล', ' galaxy a10s 2 32gb'],
#  ['category_0_39', 'ระยะเวลาการรับประกัน', ' 1 ปี'],
#  ['category_0_40', 'หน้าจอ', ' 5.45 นิ้ว '],
#  ['category_0_40', 'ความละเอียด', ' hd 1440 x 720 พิกเซล'],
#  ['category_0_40', 'ระบบปฏิบัติการ', ' android 9 pie ครอบทับด้วย miui 10'],
#  ['category_0_40', 'gpu', ' adreno 505'],
#  ['category_0_40', 'รองรับ', ' microsd 256gb '],
#  ['category_0_40', 'กล้องหลัง', ' 13ล้านพิกเซล f 2.2 1.12 m พร้อม led flash'],
#  ['category_0_40', 'กล้องหน้า', ' 5ล้านพิกเซล '],
#  ['category_0_40', 'รองรับ', ' face unlock'],
#  ['category_0_40', 'แบตเตอรี่', 'ความจุ'],
#  ['category_0_40', 'ความจุ', ' 4000 mah '],
#  ['category_0_40', 'รองรับ', 'การชาร์จ 5v 2a ผ่าน micro usb'],
#  ['category_0_40', 'รองรับ', ' dual sim4g lte'],
#  ['category_0_40',
#   'รองรับ',
#   ' wi fi 802.11 b g n 2.4ghz wifi direct wifi จอแสดงผล hotspot'],
#  ['category_0_40', 'รองรับ', ' usb 2.0usb on the go'],
#  ['category_0_40',
#   'ขนาด',
#   'ตัวเครื่อง 146.30 x 70.41 x 9.55 มม. หนัก 165 กรัม'],
#  ['category_0_40', 'แบรนด์', ' xiaomi'],
#  ['category_0_40', 'sku', ' 213755551 th 1138512951'],
#  ['category_0_40', 'กล้องหน้า', ' ล้านพิกเซล 5 6ล้านพิกเซล '],
#  ['category_0_40', 'ระบบปฏิบัติการ', 'เวอร์ชัน android 9.0 pie'],
#  ['category_0_40', 'โมเดล', ' xiaomi redmi 7a 2 32gb '],
#  ['category_0_40', 'ขนาดหน้าจอ', ' นิ้ว 5.45'],
#  ['category_0_40', 'ระยะเวลาการรับประกัน', ' 1 ปี'],
#  ['category_0_40', 'ระบบปฏิบัติการ', ' android'],
#  ['category_0_40', 'ความจุแบตเตอรี่', ' 1000 mah ถึง 5000 mah'],
#  ['category_0_41', 'ความละเอียด', ' 4ล้านพิกเซล '],
#  ['category_0_41', 'รองรับ', 'ระบบ'],
#  ['category_0_41', 'แบรนด์', ' xiaomi'],
#  ['category_0_41', 'sku', ' 222527681 th 889412058'],
#  ['category_0_41', 'กล้องหน้า', ' ล้านพิกเซล 1ล้านพิกเซล '],
#  ['category_0_41', 'ระบบปฏิบัติการ', 'เวอร์ชัน android 9.0 pie'],
#  ['category_0_41', 'โมเดล', ' xiaomi redmi note 8'],
#  ['category_0_41', 'ระยะเวลาการรับประกัน', ' 1 ปี'],
#  ['category_0_41', 'ความจุแบตเตอรี่', ' 4000 4999 mah'],
#  ['category_0_42', 'ความละเอียด', ' 10ล้านพิกเซล รับประกันศูนย์ไทย 15 เดือน '],
#  ['category_0_42', 'แบรนด์', ' xiaomi'],
#  ['category_0_42', 'sku', ' 595884854 th 1119120013'],
#  ['category_0_42', 'ระบบปฏิบัติการ', 'เวอร์ชัน android 9.0 pie'],
#  ['category_0_42', 'โมเดล', ' mi note 10'],
#  ['category_0_42', 'ระยะเวลาการรับประกัน', ' 15 เดือน'],
#  ['category_0_43', 'ขนาด', ' 156.48x75.41x9. มม. และมี'],
#  ['category_0_43', 'น้ำหนัก', ' 188 กรัม'],
#  ['category_0_43', 'ขนาด', ' 6.22 นิ้ว ในอัตราส่วน 19 9 '],
#  ['category_0_43',
#   'ความละเอียด',
#   'ระดับ hd 720x1520 พิกเซล 270 ppi ครอบทับด้วยกระจกขอบโค้งแบบ 2.5d corning gorilla glass 5'],
#  ['category_0_43', 'หน่วยประมวลผล', 'กราฟิก '],
#  ['category_0_43', 'gpu', ' adreno 505'],
#  ['category_0_43', 'ขนาด', ' 4gb'],
#  ['category_0_43', 'ขนาด', ' 64gb พร้อม'],
#  ['category_0_43', 'รองรับ', 'การ์ดหน่วยความจำภายนอกแบบ microsd สูงสุดที่'],
#  ['category_0_43', 'ขนาด', ' 512gb'],
#  ['category_0_43',
#   'ความละเอียด',
#   ' 12 ล้านพิกเซล เซ็นเซอร์รับภาพ sony imx363 พิกเซล'],
#  ['category_0_43', 'ขนาด', ' 1.4 ไมครอน มี'],
#  ['category_0_43', 'ขนาด', 'รูรับแสง f 1.8 กล้องตัวที่สองเลนส์ depth '],
#  ['category_0_43', 'ความละเอียด', ' 2 ล้านพิกเซล '],
#  ['category_0_43',
#   'รองรับ',
#   'เทคโนโลยี dual pd ai portrait และ ai scene detection ในการตรวจจับซีนทั้งหมด 33 หมวดหมู่'],
#  ['category_0_43', 'ความละเอียด', ' 8 ล้านพิกเซล พิกเซล'],
#  ['category_0_43', 'ขนาด', ' 1.12 ไมครอน มี'],
#  ['category_0_43', 'ขนาด', 'รูรับแสง f 2.0 '],
#  ['category_0_43', 'รองรับ', 'เทคโนโลยี ai selfie portrait'],
#  ['category_0_43', 'ระบบปฏิบัติการ', ' android 9.0 pie'],
#  ['category_0_43', 'รองรับ', 'การใช้งานพร้อมกัน 2 ซิมการ์ด dual sim '],
#  ['category_0_43', 'รองรับ', 'ถาดใส่ซิมการ์ดแบบ triple slot'],
#  ['category_0_43', 'รองรับ', 'การใช้งานบนเครือข่าย 4g lte'],
#  ['category_0_43',
#   'รองรับ',
#   'การเชื่อมต่อ wi fi 802.11 b g n และ bluetooth 4.2'],
#  ['category_0_43', 'รองรับ', 'การเชื่อมต่อแบบ usb type c'],
#  ['category_0_43', 'แบรนด์', ' xiaomi'],
#  ['category_0_43', 'sku', ' 611154425 th 1152864043'],
#  ['category_0_43', 'กล้องหน้า', ' ล้านพิกเซล 7ล้านพิกเซล ขึ้นไป'],
#  ['category_0_43', 'ระบบปฏิบัติการ', 'เวอร์ชัน android 9.0 pie'],
#  ['category_0_43', 'โมเดล', ' xiaomi redmi 8 3 32gb '],
#  ['category_0_43', 'ขนาดหน้าจอ', ' นิ้ว 6.22'],
#  ['category_0_43', 'ระยะเวลาการรับประกัน', ' 15 เดือน'],
#  ['category_0_43', 'ความจุแบตเตอรี่', ' 1000 mah ถึง 5000 mah'],
#  ['category_0_44',
#   'ความละเอียด',
#   ' 2340 x 1080 พิกเซล 403 ppi capacitive corning gorilla glass 5'],
#  ['category_0_44',
#   'หน้าจอ',
#   ' fingerprint under จอแสดงผล ระบบหมุนภาพอัตโนมัติ accele'],
#  ['category_0_44',
#   'หน้าจอ',
#   'อัตโนมัติขณะสนทนา proximity ระบบเซนเซอร์หมุนภาพ gyroscope ปรับมุมมองการแสดงผลอัตโนมัติ orientation '],
#  ['category_0_44', 'รองรับ', ' 2 ซิมการ์ด'],
#  ['category_0_44', 'ระบบปฏิบัติการ', ' miui 10 based on android 9.0 pie '],
#  ['category_0_44',
#   'หน่วยประมวลผล',
#   ' qualcomm snapdragon 855 octa core ความเร็ว 2.84 ghz'],
#  ['category_0_44', 'รองรับ', 'แอพพลิเคชั่น egps'],
#  ['category_0_44', 'รองรับ', ' nfc near field communication '],
#  ['category_0_44',
#   'รองรับ',
#   'การถ่ายโอนข้อมูลกับ flash drive โดยตรง usb on the go '],
#  ['category_0_44',
#   'ขนาด',
#   'ภาพสูงสุด 8000 x 6000 พิกเซล image size โฟกัสอัตโนมัติ auto focus โหมดฉาก บุคคล เวลากลางคืน ค้นหาใบหน้าอัตโนมัติ face detection เทคโนโลยีถ่ายภาพอัจฉริยะ ai camera โหมดปรับหน้าสวยอัตโนมัติ ai face beauty ตั้งเวลาถ่ายภาพอัตโนมัติ self timer โหมดถ่ายภาพพาโนราม่า pano'],
#  ['category_0_44', 'กล้องหน้า', ' front camera '],
#  ['category_0_44', 'ความละเอียด', ' 20ล้านพิกเซล ไฟแฟลช led '],
#  ['category_0_44', 'รองรับ', ' video call สนทนาแบบเห็นภาพ '],
#  ['category_0_44', 'กล้องหน้า', ' hdr '],
#  ['category_0_44', 'กล้องหน้า', ' portrait '],
#  ['category_0_44', 'กล้องหน้า', 'แบบ pop up'],
#  ['category_0_44',
#   'ความละเอียด',
#   ' hd 3840 x 2160 พิกเซล บันทึกวีดีโอ 4k 60 เฟรมต่อวินาที slow motion'],
#  ['category_0_44', 'รองรับ', 'วีดีโอจาก youtube '],
#  ['category_0_44', 'รองรับ', 'ไฟล์รูปภาพ jpg jpeg bmp gif tiff'],
#  ['category_0_44', 'แบตเตอรี่', 'มาตรฐาน 4000 mah standard battery '],
#  ['category_0_45',
#   'ความละเอียด',
#   ' 48ล้านพิกเซล จอกว้าง 6.3 นิ้ว fhd ชิปเซ็ต qualcomm sd 665 ฿ 4299.00 ฿ 4999.00 14เปอร์เซนต์ '],
#  ['category_0_45', 'แบตเตอรี่', 'สำรอง ฿ 1290.00 ฿ 1590.00 19เปอร์เซนต์ '],
#  ['category_0_45', 'โมเดล', ' ฿ 11290.00 ฿ 11790.00 4เปอร์เซนต์ '],
#  ['category_0_46', 'ขนาด', 'จอ 6.088 นิ้ว '],
#  ['category_0_46', 'ความละเอียด', ' hd ชิปเซ็ต qualcomm sd 665 '],
#  ['category_0_46', 'หน้าจอ', 'กว้าง 6.01 นิ้ว'],
#  ['category_0_46', 'หน้าจอ', ' และระบบจดจำใบหน้า face detection '],
#  ['category_0_46', 'กล้องหน้า', 'ความละเอียด'],
#  ['category_0_46', 'ความละเอียด', ' 32 ล้านพิกเซล'],
#  ['category_0_46', 'แบตเตอรี่', 'มาตรฐาน li ion 4030 mah'],
#  ['category_0_46', 'แบรนด์', ' xiaomi'],
#  ['category_0_46', 'sku', ' 533460461 th 963560027'],
#  ['category_0_46', 'กล้องหน้า', ' ล้านพิกเซล 7ล้านพิกเซล ขึ้นไป'],
#  ['category_0_46', 'ระบบปฏิบัติการ', 'เวอร์ชัน android 9.0 pie'],
#  ['category_0_46', 'โมเดล', ' mi a3 4gb 64gb '],
#  ['category_0_46', 'ขนาดหน้าจอ', ' นิ้ว 6.09'],
#  ['category_0_46', 'ระยะเวลาการรับประกัน', ' 18 เดือน'],
#  ['category_0_46', 'ความจุแบตเตอรี่', ' 1000 mah ถึง 5000 mah'],
#  ['category_0_47',
#   'ความละเอียด',
#   ' 48ล้านพิกเซล จอกว้าง 6.3 นิ้ว fhd ชิปเซ็ต qualcomm sd 665'],
#  ['category_0_47', 'แบรนด์', ' xiaomi'],
#  ['category_0_47', 'sku', ' 495988905 th 884338021'],
#  ['category_0_47', 'กล้องหน้า', ' ล้านพิกเซล 1ล้านพิกเซล '],
#  ['category_0_47', 'ระบบปฏิบัติการ', 'เวอร์ชัน android 9.0 pie'],
#  ['category_0_47', 'โมเดล', ' redmi note 8'],
#  ['category_0_47', 'ขนาดหน้าจอ', ' นิ้ว 6.3'],
#  ['category_0_47', 'ระยะเวลาการรับประกัน', ' 15 เดือน'],
#  ['category_0_47', 'ความจุแบตเตอรี่', ' 1000 mah ถึง 5000 mah'],
#  ['category_0_48', 'ความละเอียด', ' 1080 x 2340 พิกเซล 395 ppi '],
#  ['category_0_48', 'หน้าจอ', 'อัตโนมัติขณะสนทนา proximity '],
#  ['category_0_48', 'รองรับ', ' 2 ซิมการ์ด'],
#  ['category_0_48', 'ระบบปฏิบัติการ', ' os '],
#  ['category_0_48', 'ระบบปฏิบัติการ', ' miui 10 based on android 9.0 pie '],
#  ['category_0_48', 'หน่วยประมวลผล', ' mediatek helio g90t octa core'],
#  ['category_0_49', 'แบตเตอรี่', ' 4000mah พร้อม ai beauty'],
#  ['category_0_49', 'แบรนด์', ' xiaomi'],
#  ['category_0_49', 'sku', ' 234902116 th 713640836'],
#  ['category_0_49', 'กล้องหน้า', ' ล้านพิกเซล 5 6ล้านพิกเซล '],
#  ['category_0_49', 'โมเดล', ' xiaomi mi redmi 7a'],
#  ['category_0_49', 'ระยะเวลาการรับประกัน', ' 1 ปี'],
#  ['category_0_49', 'ความจุแบตเตอรี่', ' 4000 4999 mah'],
#  ['category_0_50', 'แบรนด์', ' xiaomi'],
#  ['category_0_50', 'sku', ' 494026300 th 882746256'],
#  ['category_0_50', 'โมเดล', ' redmi note 8'],
#  ['category_0_50', 'ระยะเวลาการรับประกัน', ' 15 เดือน'],
#  ['category_0_51', 'หน่วยประมวลผล', ' qualcomm snapdragon 730g'],
#  ['category_0_51', 'ความจุ', 'ram'],
#  ['category_0_51', 'กล้องหลัง', ' 108ล้านพิกเซล ระบบ 5 '],
#  ['category_0_51', 'กล้องหลัง', ' ai'],
#  ['category_0_51',
#   'กล้องหน้า',
#   ' กล้องเซลฟี่ 32ล้านพิกเซล 1.6 m super pixel 4 in 1 รูรับแสง f 2.0'],
#  ['category_0_51', 'ระบบปฏิบัติการ', ' miui 11'],
#  ['category_0_51', 'แบตเตอรี่', ' 5260 mah ทั่วไป 5170 mah ขั้นต่ำ '],
#  ['category_0_51', 'แบตเตอรี่', 'ลิเธียมไอออนโพลีเมอร์'],
#  ['category_0_51', 'รองรับ', 'การชาร์จเร็ว 30 w ภายในกล่องมีที่ชาร์จ 30 w '],
#  ['category_0_51', 'รองรับ', ' 4g 4g 3g 2g'],
#  ['category_0_51', 'รองรับ', 'การโทร volte hd สองซิม'],
#  ['category_0_51', 'รองรับ', ' bluetooth 5.0'],
#  ['category_0_51', 'รองรับ', ' google pay'],
#  ['category_0_51',
#   'ขนาด',
#   'ความสูง 157.8 มม. ความกว้าง 74.2 มม. ความหนา 9.67 มม.'],
#  ['category_0_51', 'น้ำหนัก', ' 208 กรัม'],
#  ['category_0_51', 'ขนาด', 'ใหญ่ 1.0 cc'],
#  ['category_0_51', 'ความละเอียด', 'สูง'],
#  ['category_0_51',
#   'หน้าจอ',
#   ' ตัววัดความเร่ง ไจโรสโคป เข็มทิศอิเล็กทรอนิกส์ เซ็นเซอร์เลเซอร์โฟกัส'],
#  ['category_0_51', 'แบรนด์', ' xiaomi'],
#  ['category_0_51', 'sku', ' 604332862 th 1137128463'],
#  ['category_0_51', 'ระยะเวลาการรับประกัน', ' 15 เดือน'],
#  ['category_0_52', 'ขนาด', ' 6.47 นิ้ว'],
#  ['category_0_52', 'ความละเอียด', ' 2340 x 1080 พิกเซล fhd '],
#  ['category_0_52', 'cpu', ' snapdragon 730g'],
#  ['category_0_52', 'gpu', ' adreno 618'],
#  ['category_0_52',
#   'กล้องหลัง',
#   ' เซ็นเซอร์ samsung hmx 10ล้านพิกเซล 8p lens 1ล้านพิกเซล ล้านพิกเซล 2ล้านพิกเซล ล้านพิกเซล พร้อมไฟแฟลชคู่ led'],
#  ['category_0_52', 'กล้องหน้า', 'ความละเอียด'],
#  ['category_0_52', 'ความละเอียด', ' 3ล้านพิกเซล '],
#  ['category_0_52',
#   'รองรับ',
#   ' dual 4g volte wifi 802.11 ac 2.4ghz 5ghz bluetooth 5 gps glonass nfc usb type c'],
#  ['category_0_52', 'ขนาด', 'ตัวเครื่อง 157.8 74.2 9.67 มม.'],
#  ['category_0_52', 'น้ำหนัก', ' 208 กรัม'],
#  ['category_0_52', 'แบรนด์', ' xiaomi'],
#  ['category_0_52', 'sku', ' 611792752 th 1155040122'],
#  ['category_0_52', 'หน่วยประมวลผล', ' octa core'],
#  ['category_0_52', 'ความละเอียด', 'วิดีโอ 4k'],
#  ['category_0_52', 'ระยะเวลาการรับประกัน', ' 1 ปี'],
#  ['category_0_52', 'ระบบปฏิบัติการ', ' android 9.0 pie'],
#  ['category_0_52', 'แบตเตอรี่', ' built in rechargeable battery'],
#  ['category_0_52', 'กล้องหน้า', ' ล้านพิกเซล 7ล้านพิกเซล ขึ้นไป'],
#  ['category_0_52', 'ระบบปฏิบัติการ', 'เวอร์ชัน android 9.0 pie'],
#  ['category_0_53', 'ขนาด', ' 5.97 นิ้ว'],
#  ['category_0_53', 'แบรนด์', ' xiaomi'],
#  ['category_0_53', 'sku', ' 343546977 th 668396557'],
#  ['category_0_53', 'ระบบปฏิบัติการ', 'เวอร์ชัน android 9.0 pie'],
#  ['category_0_53', 'โมเดล', ' mi9 mi 9 se'],
#  ['category_0_53', 'ระยะเวลาการรับประกัน', ' 1 ปี'],
#  ['category_0_54',
#   'รุ่น',
#   ' non slip soft 3d คาร์บอนไฟเบอร์ฝาหลังฟิล์มป้องกันด้านหลังสติกเกอร์ป้องกัน ฿ 55.00 ฿ 92.00 40เปอร์เซนต์ '],
#  ['category_0_54',
#   'รุ่น',
#   ' s9 plus 256gb สีฟ้า ฿ 7900.00 ฿ 13590.00 42เปอร์เซนต์ '],
#  ['category_0_54',
#   'หน้าจอ',
#   ' 6.26 นิ้ว tft lcd ips ฿ 9290.00 ฿ 10990.00 15เปอร์เซนต์ '],
#  ['category_0_54',
#   'รุ่น',
#   ' l02 กุญแจล็อคประตูอัจฉริยะรักษาความปลอดภัย แบบสแกนลายนิ้วมือ กันน้ำ ชาร์จไฟได้ ใช้พลังงานต่ำ แข็งแรงทนทาน ความปลอดภัยสูง ฿ 745.00 ฿ 1566.00 52เปอร์เซนต์ '],
#  ['category_0_55', 'ความละเอียด', ' hd '],
#  ['category_0_55', 'ความจุ', ' 32 gb'],
#  ['category_0_55', 'กล้องหลัง', ' 2 ตัว'],
#  ['category_0_55', 'กล้องหน้า', ' 8 ล้านพิกเซล'],
#  ['category_0_55', 'แบตเตอรี่', ' 5000 มิลลิแอมป์ '],
#  ['category_0_55', 'รองรับ', 'ชาร์จไว 18 วัตต์'],
#  ['category_0_55', 'แบรนด์', ' xiaomi'],
#  ['category_0_55', 'sku', ' 587988556 th 1092062042'],
#  ['category_0_55', 'ระบบปฏิบัติการ', 'เวอร์ชัน android 9.0 pie'],
#  ['category_0_55', 'โมเดล', ' redmi 8 3gb 32gb '],
#  ['category_0_55', 'ขนาดหน้าจอ', ' นิ้ว 6.22'],
#  ['category_0_55', 'ระยะเวลาการรับประกัน', ' 15 เดือน'],
#  ['category_0_55', 'ความจุแบตเตอรี่', ' 1000 mah ถึง 5000 mah'],
#  ['category_0_56', 'ความละเอียด', ' 720 x 1520 พิกเซล 271 ppi ประเภทจอ '],
#  ['category_0_56', 'หน้าจอ', 'กระจกแข็ง ประเภทจอ corning gorilla glass 5'],
#  ['category_0_56', 'หน้าจอ', 'อัตโนมัติขณะสนทนา proximity '],
#  ['category_0_56', 'รองรับ', ' 2 ซิมการ์ด'],
#  ['category_0_56', 'ระบบปฏิบัติการ', ' miui 9 based on android 9.0 pie '],
#  ['category_0_56',
#   'หน่วยประมวลผล',
#   ' qualcomm snapdragon 439 octa core ความเร็ว 2.0 ghz'],
#  ['category_0_56', 'แบรนด์', ' xiaomi'],
#  ['category_0_56', 'sku', ' 526910733 th 944832734'],
#  ['category_0_56', 'กล้องหน้า', ' ล้านพิกเซล 7ล้านพิกเซล ขึ้นไป'],
#  ['category_0_56', 'โมเดล', ' redmi 8'],
#  ['category_0_56', 'ขนาดหน้าจอ', ' นิ้ว 6.21'],
#  ['category_0_56', 'ระยะเวลาการรับประกัน', ' 15 เดือน'],
#  ['category_0_56', 'ระบบปฏิบัติการ', ' android'],
#  ['category_0_56', 'ความจุแบตเตอรี่', ' 1000 mah ถึง 5000 mah'],
#  ['category_0_57', 'ความละเอียด', ' 4ล้านพิกเซล '],
#  ['category_0_57', 'รองรับ', 'ระบบ'],
#  ['category_0_57', 'แบรนด์', ' xiaomi'],
#  ['category_0_57', 'sku', ' 221761904 th 931764445'],
#  ['category_0_57', 'ระยะเวลาการรับประกัน', ' 15 เดือน'],
#  ['category_0_57', 'ระบบปฏิบัติการ', ' android 8.1 oreo'],
#  ['category_0_57', 'แบตเตอรี่', ' built in rechargeable battery'],
#  ['category_0_57', 'กล้องหน้า', ' ล้านพิกเซล 1ล้านพิกเซล '],
#  ['category_0_57', 'ระบบปฏิบัติการ', 'เวอร์ชัน android 8.1 oreo'],
#  ['category_0_57', 'โมเดล', ' xiaomi redmi note 8'],
#  ['category_0_57', 'หน้าจอ', ' ips lcd'],
#  ['category_0_57', 'ขนาดหน้าจอ', ' นิ้ว 6.3'],
#  ['category_0_57', 'หน่วยประมวลผล', ' octa core'],
#  ['category_0_57', 'ความละเอียด', 'วิดีโอ 1080p'],
#  ['category_0_57', 'ความจุแบตเตอรี่', ' 4000 4999 mah'],
#  ['category_0_58', 'แบตเตอรี่', 'สำรอง ฿ 1290.00 ฿ 1590.00 19เปอร์เซนต์ '],
#  ['category_0_58', 'โมเดล', ' ฿ 11290.00 ฿ 11790.00 4เปอร์เซนต์ '],
#  ['category_0_59', 'หน้าจอ', ' 6.47 fhd 2340 x 1080px 398 ppi'],
#  ['category_0_59',
#   'cpu',
#   ' qualcomm snapdragon 730g octa core ความเร็ว2.2ghz'],
#  ['category_0_59',
#   'กล้องหลัง',
#   ' 10ล้านพิกเซล 1ล้านพิกเซล 2ล้านพิกเซล ล้านพิกเซล ล้านพิกเซล f 1.69 f 2.0 f 2.2 f 2.4'],
#  ['category_0_59', 'กล้องหน้า', ' 3ล้านพิกเซล f 2.0'],
#  ['category_0_59', 'แบตเตอรี่', ' 5260mah'],
#  ['category_0_59', 'cpu', ' qualcomm snapdragon 730g octa core 2.2ghz'],
#  ['category_0_59', 'แบรนด์', ' xiaomi'],
#  ['category_0_59', 'sku', ' 595984523 th 1119224437'],
#  ['category_0_59', 'หน่วยประมวลผล', ' octa core'],
#  ['category_0_59', 'ความละเอียด', 'วิดีโอ 4k'],
#  ['category_0_59', 'ระยะเวลาการรับประกัน', ' 1 ปี'],
#  ['category_0_59', 'ระบบปฏิบัติการ', ' android'],
#  ['category_0_59', 'แบตเตอรี่', ' built in rechargeable battery'],
#  ['category_0_60',
#   'หน้าจอ',
#   'หยดน้ำ waterdrop จอแสดงผล กว้าง 6.21 นิ้ว แนวทะแยง '],
#  ['category_0_60', 'ความละเอียด', ' 720 x 1520 พิกเซล 271 ppi ประเภทจอ '],
#  ['category_0_60', 'หน้าจอ', 'กระจกแข็ง ประเภทจอ'],
#  ['category_0_60', 'หน้าจอ', 'อัตโนมัติขณะสนทนา proximity '],
#  ['category_0_60', 'รองรับ', ' 2 ซิมการ์ด'],
#  ['category_0_60', 'ระบบปฏิบัติการ', ' miui 9 based on android 9.0 pie '],
#  ['category_0_60',
#   'หน่วยประมวลผล',
#   ' qualcomm snapdragon 439 octa core ความเร็ว 2.0 ghz'],
#  ['category_0_60', 'กล้องหน้า', ' front camera '],
#  ['category_0_60', 'ความละเอียด', ' ล้านพิกเซล '],
#  ['category_0_60', 'กล้องหน้า', ' hdr'],
#  ['category_0_60', 'แบตเตอรี่', 'มาตรฐาน li pol 5000 mah standard battery '],
#  ['category_0_60', 'แบรนด์', ' xiaomi'],
#  ['category_0_60', 'sku', ' 612338298 th 1156318935'],
#  ['category_0_60', 'ระยะเวลาการรับประกัน', ' 1 ปี'],
#  ['category_0_60', 'ระบบปฏิบัติการ', ' android'],
#  ['category_0_60', 'แบตเตอรี่', ' built in rechargeable battery'],
#  ['category_0_61', 'หน้าจอ', 'สัมผัสคู่ซิมการ์ดสแตนด์บายคู่นาโนซิม'],
#  ['category_0_61', 'แบรนด์', ' xiaomi'],
#  ['category_0_61', 'sku', ' 615188295 th 1166414603'],
#  ['category_0_61', 'ระยะเวลาการรับประกัน', ' 1 ปี'],
#  ['category_0_61', 'ระบบปฏิบัติการ', ' android'],
#  ['category_0_61', 'แบตเตอรี่', ' built in rechargeable battery'],
#  ['category_0_61', 'กล้องหน้า', ' ล้านพิกเซล 16ล้านพิกเซล '],
#  ['category_0_61', 'ระบบปฏิบัติการ', 'เวอร์ชัน android 8.0 oreo'],
#  ['category_0_61', 'โมเดล', ' xiaomi redmi note 5a'],
#  ['category_0_61', 'ขนาดหน้าจอ', ' นิ้ว 5.5'],
#  ['category_0_61', 'ความละเอียด', 'วิดีโอ 1080p'],
#  ['category_0_61', 'ความจุแบตเตอรี่', ' 3000 3999 mah'],
#  ['category_0_62', 'ความละเอียด', ' 720 x 1520 พิกเซล 271 ppi ประเภทจอ '],
#  ['category_0_62', 'หน้าจอ', 'กระจกแข็ง ประเภทจอ corning gorilla glass 5'],
#  ['category_0_62', 'หน้าจอ', 'อัตโนมัติขณะสนทนา proximity '],
#  ['category_0_62', 'รองรับ', ' 2 ซิมการ์ด'],
#  ['category_0_62', 'ระบบปฏิบัติการ', ' miui 10 based on android 9.0 pie '],
#  ['category_0_62',
#   'หน่วยประมวลผล',
#   ' qualcomm snapdragon 439 octa core ความเร็ว 1.95 ghz'],
#  ['category_0_62', 'กล้องหน้า', ' front camera '],
#  ['category_0_62', 'ความละเอียด', ' ล้านพิกเซล '],
#  ['category_0_62', 'กล้องหน้า', ' hdr'],
#  ['category_0_62', 'แบตเตอรี่', 'มาตรฐาน li pol 5000 mah standard battery '],
#  ['category_0_62', 'แบรนด์', ' xiaomi'],
#  ['category_0_62', 'sku', ' 524454971 th 937876465'],
#  ['category_0_62', 'ระยะเวลาการรับประกัน', ' 15 เดือน'],
#  ['category_0_62', 'ระบบปฏิบัติการ', ' android'],
#  ['category_0_62', 'กล้องหน้า', ' ล้านพิกเซล 7ล้านพิกเซล ขึ้นไป'],
#  ['category_0_63', 'กล้องหลัง', ' ai'],
#  ['category_0_63', 'กล้องหน้า', ' เซลฟี่ 32ล้านพิกเซล รูรับแสง f 2.0'],
#  ['category_0_63', 'ความละเอียด', ' 2340 x 1080 fhd 398 ppi'],
#  ['category_0_63',
#   'แบตเตอรี่',
#   ' 5260mah มาตรฐานชาร์จเร็ว 30w พอร์ตการชาร์จเชื่อมต่อแบบใหม่ usb type c'],
#  ['category_0_63', 'รองรับ', 'ระบบ fast charge 30w ภายในกล่องมีที่ชาร์จ 30 w'],
#  ['category_0_63', 'แบรนด์', ' xiaomi'],
#  ['category_0_63', 'sku', ' 600264311 th 1129088854'],
#  ['category_0_63', 'หน่วยประมวลผล', ' octa core'],
#  ['category_0_63', 'ความละเอียด', 'วิดีโอ 4k'],
#  ['category_0_63', 'ระยะเวลาการรับประกัน', ' 15 เดือน'],
#  ['category_0_63', 'ระบบปฏิบัติการ', ' android 9.0 pie'],
#  ['category_0_63', 'แบตเตอรี่', ' built in rechargeable battery'],
#  ['category_0_63', 'กล้องหน้า', ' ล้านพิกเซล 7ล้านพิกเซล ขึ้นไป'],
#  ['category_0_63', 'ระบบปฏิบัติการ', 'เวอร์ชัน android 9.0 pie'],
#  ['category_0_63', 'โมเดล', ' xiaomi mi note 10'],
#  ['category_0_63', 'หน้าจอ', ' amoled'],
#  ['category_0_63', 'ขนาดหน้าจอ', ' นิ้ว 6.47'],
#  ['category_0_63', 'ความจุแบตเตอรี่', ' 5000 mah หรือมากกว่า'],
#  ['category_0_64',
#   'รุ่น',
#   ' non slip soft 3d คาร์บอนไฟเบอร์ฝาหลังฟิล์มป้องกันด้านหลังสติกเกอร์ป้องกัน ฿ 55.00 ฿ 92.00 40เปอร์เซนต์ '],
#  ['category_0_64',
#   'หน้าจอ',
#   ' 6.26 นิ้ว tft lcd ips ฿ 9290.00 ฿ 10990.00 15เปอร์เซนต์ '],
#  ['category_0_64',
#   'รุ่น',
#   ' s9 plus 256gb สีฟ้า ฿ 7900.00 ฿ 13590.00 42เปอร์เซนต์ '],
#  ['category_0_64',
#   'หน้าจอ',
#   ' lcd เปลี่ยนอะไหล่ซ่อมสำรอง กระจกเทมเปอร์ ซ่อมเครื่องมือเครื่องมือ 6.5 นิ้ว ฿ 3302.79 ฿ 6941.00 52เปอร์เซนต์ '],
#  ['category_0_64', 'หน้าจอ', ' lcd'],
#  ['category_0_64',
#   'หน้าจอ',
#   'สำหรับ xiaomi mi9 super amoled ดิจิไทเซอร์จอแอลซีดี asembbly เปลี่ยนอะไหล่ซ่อมสำรอง กระจกเทมเปอร์ ซ่อมเครื่องมือเครื่องมือ ฿ 9624.00 ฿ 19247.00 50เปอร์เซนต์ '],
#  ['category_0_64',
#   'หน้าจอ',
#   'ฟิล์มกระจกเทมเปอร์ ฿ 83.98 ฿ 120.00 30เปอร์เซนต์ '],
#  ['category_0_65', 'ความละเอียด', ' fhd 2340 x 1080 อัตราส่วน 19.5 9'],
#  ['category_0_65', 'cpu', ' helio g90t'],
#  ['category_0_65', 'gpu', ' mali g76'],
#  ['category_0_65', 'ความจุ', ' 64gb 128gb'],
#  ['category_0_65',
#   'กล้องหลัง',
#   ' 6ล้านพิกเซล ล้านพิกเซล ล้านพิกเซล ล้านพิกเซล '],
#  ['category_0_65', 'กล้องหน้า', ' 2ล้านพิกเซล '],
#  ['category_0_65', 'รองรับ', ' nfc'],
#  ['category_0_65', 'แบตเตอรี่', ' 4500 mah '],
#  ['category_0_65', 'รองรับ', 'ชาร์จไว 18w'],
#  ['category_0_65', 'แบรนด์', ' xiaomi'],
#  ['category_0_65', 'sku', ' 273675979 th 909150212'],
#  ['category_0_65', 'กล้องหน้า', ' ล้านพิกเซล 20ล้านพิกเซล '],
#  ['category_0_65', 'ระบบปฏิบัติการ', 'เวอร์ชัน android 9.0 pie'],
#  ['category_0_65', 'โมเดล', ' redmi note 8 pro'],
#  ['category_0_65', 'ระยะเวลาการรับประกัน', ' 1 ปี'],
#  ['category_0_65', 'ความจุแบตเตอรี่', ' 4000 4999 mah'],
#  ['category_0_66', 'แบรนด์', ' xiaomi'],
#  ['category_0_66', 'sku', ' 602338133 th 1134472444'],
#  ['category_0_66', 'กล้องหน้า', ' ล้านพิกเซล 20ล้านพิกเซล '],
#  ['category_0_66', 'ระบบปฏิบัติการ', 'เวอร์ชัน android 9.0 pie'],
#  ['category_0_66', 'โมเดล', ' xiaomi mi note 10'],
#  ['category_0_66', 'ขนาดหน้าจอ', ' นิ้ว 6.5'],
#  ['category_0_66', 'ระยะเวลาการรับประกัน', ' 15 เดือน'],
#  ['category_0_66', 'ความจุแบตเตอรี่', ' 4000 4999 mah'],
#  ['category_0_67', 'แบตเตอรี่', 'สำรอง ฿ 1290.00 ฿ 1590.00 19เปอร์เซนต์ '],
#  ['category_0_68', 'แบรนด์', ' xiaomi'],
#  ['category_0_68', 'sku', ' 602306922 th 1134540658'],
#  ['category_0_68', 'กล้องหน้า', ' ล้านพิกเซล 20ล้านพิกเซล '],
#  ['category_0_68', 'ระบบปฏิบัติการ', 'เวอร์ชัน android 9.0 pie'],
#  ['category_0_68', 'โมเดล', ' xiaomi mi note 10'],
#  ['category_0_68', 'ขนาดหน้าจอ', ' นิ้ว 6.5'],
#  ['category_0_68', 'ระยะเวลาการรับประกัน', ' 15 เดือน'],
#  ['category_0_68', 'ความจุแบตเตอรี่', ' 4000 4999 mah'],
#  ['category_0_69', 'หน้าจอ', ' amoled 6.39 นิ้ว'],
#  ['category_0_69', 'ความละเอียด', ' 1080 x 2340 พิกเซล 403 ppi '],
#  ['category_0_69', 'หน้าจอ', ' และ จดจำใบหน้า face detection '],
#  ['category_0_69', 'ระบบปฏิบัติการ', ' android 9.0 pie '],
#  ['category_0_69',
#   'หน่วยประมวลผล',
#   ' qualcomm snapdragon 855 octa core ความเร็ว 2.84 ghz'],
#  ['category_0_69', 'หน้าจอ', ' amoled 6.39 นิ้ว '],
#  ['category_0_69', 'ความละเอียด', ' fhd 19.5 9 '],
#  ['category_0_69', 'ความจุ', ' 128gb'],
#  ['category_0_69', 'แบตเตอรี่', ' 3300 mah'],
#  ['category_0_69', 'รองรับ', 'ชาร์จไว qc 4.0 27w '],
#  ['category_0_69', 'รองรับ', 'ชาร์จไวแบบไร้สาย 20w'],
#  ['category_0_69', 'กล้องหน้า', ' 20 ล้านพิกเซล f 2.0'],
#  ['category_0_69',
#   'กล้องหลัง',
#   ' 3 ตัว 48 16 12 ล้านพิกเซล f 1.8 f 2.2 f 2.2'],
#  ['category_0_69', 'รองรับ', 'ระบบสแกนลายนิ้วมือบน'],
#  ['category_0_69', 'รองรับ', 'ระบบสแกนใบหน้า'],
#  ['category_0_69', 'รองรับ', ' 2 ซิม'],
#  ['category_0_69', 'แบรนด์', ' xiaomi'],
#  ['category_0_69', 'sku', ' 594522639 th 1116438503'],
#  ['category_0_69', 'กล้องหน้า', ' ล้านพิกเซล 20ล้านพิกเซล '],
#  ['category_0_69', 'โมเดล', ' xiaomi mi9 '],
#  ['category_0_69', 'หน้าจอ', ' amoled 6.39 นิ้ว'],
#  ['category_0_69', 'ระยะเวลาการรับประกัน', ' 6 เดือน'],
#  ['category_0_69', 'ความจุแบตเตอรี่', ' 3000 3999 mah'],
#  ['category_0_70', 'ความละเอียด', ' 1440 x 720 พิกเซล 295 ppi '],
#  ['category_0_70', 'หน้าจอ', 'อัตโนมัติขณะสนทนา proximity '],
#  ['category_0_70', 'รองรับ', ' 2 ซิมการ์ด'],
#  ['category_0_70', 'ระบบปฏิบัติการ', ' os '],
#  ['category_0_70', 'ระบบปฏิบัติการ', ' miui 10 based on android 9 pie'],
#  ['category_0_70', 'หน่วยประมวลผล', ' qualcomm snapdrafon 439 octa core'],
#  ['category_0_71', 'หน้าจอ', 'กว้าง 6.2 นิ้ว '],
#  ['category_0_71', 'แบตเตอรี่', ' 5000 mah snapdragon 439 รับประกัน 1 ปี '],
#  ['category_0_71', 'ความละเอียด', ' 720 x 1520 พิกเซล 271 ppi '],
#  ['category_0_71', 'หน้าจอ', 'กระจกแข็ง'],
#  ['category_0_71', 'หน้าจอ', 'อัตโนมัติขณะสนทนา proximity '],
#  ['category_0_71', 'รองรับ', ' 2 ซิมการ์ด'],
#  ['category_0_71', 'ระบบปฏิบัติการ', ' os '],
#  ['category_0_71', 'ระบบปฏิบัติการ', ' miui 10 based on android 9.0 pie '],
#  ['category_0_71', 'หน่วยประมวลผล', ' qualcomm snapdragon 439 octa core'],
#  ['category_0_72', 'ความละเอียด', ' 1080 x 2340 พิกเซล 409 ppi '],
#  ['category_0_72',
#   'หน้าจอ',
#   'อัตโนมัติขณะสนทนา proximity ระบบเซนเซอร์หมุนภาพ gyroscope '],
#  ['category_0_72', 'รองรับ', ' 2 ซิมการ์ด'],
#  ['category_0_72', 'ระบบปฏิบัติการ', ' miui 10 based on android 9.0 pie '],
#  ['category_0_72',
#   'หน่วยประมวลผล',
#   ' qualcomm snapdragon 665 octa core ความเร็ว 2.0 ghz'],
#  ['category_0_72', 'กล้องหน้า', ' front camera '],
#  ['category_0_72', 'ความละเอียด', ' 13ล้านพิกเซล '],
#  ['category_0_72', 'กล้องหน้า', ' hdr'],
#  ['category_0_72', 'แบตเตอรี่', 'มาตรฐาน li pol 4000 mah standard battery '],
#  ['category_0_72', 'แบรนด์', ' xiaomi'],
#  ['category_0_72', 'sku', ' 477810714 th 868398689'],
#  ['category_0_72', 'กล้องหน้า', ' ล้านพิกเซล 1ล้านพิกเซล '],
#  ['category_0_72', 'ระบบปฏิบัติการ', 'เวอร์ชัน android 9.0 pie'],
#  ['category_0_72', 'โมเดล', ' redmi note 8 3gb '],
#  ['category_0_73', 'หน้าจอ', ' amoled 6.39 นิ้ว'],
#  ['category_0_73', 'ความละเอียด', ' 1080 x 2340 พิกเซล 403 ppi '],
#  ['category_0_73', 'หน้าจอ', ' และ จดจำใบหน้า face detection '],
#  ['category_0_73', 'ระบบปฏิบัติการ', ' android 9.0 pie '],
#  ['category_0_73',
#   'หน่วยประมวลผล',
#   ' qualcomm snapdragon 855 octa core ความเร็ว 2.84 ghz'],
#  ['category_0_73', 'หน้าจอ', ' amoled 6.39 นิ้ว '],
#  ['category_0_73', 'ความละเอียด', ' fhd 19.5 9 '],
#  ['category_0_73', 'ความจุ', ' 128gb'],
#  ['category_0_73', 'แบตเตอรี่', ' 3300 mah'],
#  ['category_0_73', 'รองรับ', 'ชาร์จไว qc 4.0 27w '],
#  ['category_0_73', 'รองรับ', 'ชาร์จไวแบบไร้สาย 20w'],
#  ['category_0_73', 'กล้องหน้า', ' 20 ล้านพิกเซล f 2.0'],
#  ['category_0_73',
#   'กล้องหลัง',
#   ' 3 ตัว 48 16 12 ล้านพิกเซล f 1.8 f 2.2 f 2.2'],
#  ['category_0_73', 'รองรับ', 'ระบบสแกนลายนิ้วมือบน'],
#  ['category_0_73', 'รองรับ', 'ระบบสแกนใบหน้า'],
#  ['category_0_73', 'รองรับ', ' 2 ซิม'],
#  ['category_0_73', 'แบรนด์', ' xiaomi'],
#  ['category_0_73', 'sku', ' 594600147 th 1116542821'],
#  ['category_0_73', 'กล้องหน้า', ' ล้านพิกเซล 20ล้านพิกเซล '],
#  ['category_0_73', 'โมเดล', ' xiaomi mi9 '],
#  ['category_0_73', 'หน้าจอ', ' amoled 6.39 นิ้ว'],
#  ['category_0_73', 'ระยะเวลาการรับประกัน', ' 6 เดือน'],
#  ['category_0_73', 'ความจุแบตเตอรี่', ' 3000 3999 mah'],
#  ['category_0_74', 'ความละเอียด', ' fhd '],
#  ['category_0_74', 'กล้องหลัง', ' 3 ตัว '],
#  ['category_0_74', 'ความละเอียด', ' 48ล้านพิกเซล '],
#  ['category_0_74', 'กล้องหน้า', 'แบบ pop up'],
#  ['category_0_74', 'หน้าจอ', ' 6.39 นิ้ว แสดงผลแบบ amoled full screen'],
#  ['category_0_74', 'หน่วยประมวลผล', 'กราฟิกโดยเฉพาะแบบ adreno 618'],
#  ['category_0_74', 'ขนาด', ' 128 gb'],
#  ['category_0_74', 'ขนาด', ' 6 gb'],
#  ['category_0_74', 'แบตเตอรี่', ' lithium polymer '],
#  ['category_0_74', 'ความจุ', ' 4000 mah'],
#  ['category_0_74', 'แบรนด์', ' xiaomi'],
#  ['category_0_74', 'sku', ' 587986529 th 1092060094'],
#  ['category_0_74', 'กล้องหน้า', ' ล้านพิกเซล 20ล้านพิกเซล '],
#  ['category_0_74', 'ระบบปฏิบัติการ', 'เวอร์ชัน android 9.0 pie'],
#  ['category_0_74', 'โมเดล', ' mi 9t 6gb 128gb '],
#  ['category_0_74', 'ขนาดหน้าจอ', ' นิ้ว 6.39'],
#  ['category_0_74', 'ระยะเวลาการรับประกัน', ' 15 เดือน'],
#  ['category_0_74', 'ความจุแบตเตอรี่', ' 1000 mah ถึง 5000 mah'],
#  ['category_0_75',
#   'ความละเอียด',
#   ' 2340 x 1080 พิกเซล 403 ppi capacitive corning gorilla glass 5'],
#  ['category_0_75',
#   'หน้าจอ',
#   ' fingerprint under จอแสดงผล ระบบหมุนภาพอัตโนมัติ accele'],
#  ['category_0_75',
#   'หน้าจอ',
#   'อัตโนมัติขณะสนทนา proximity ระบบเซนเซอร์หมุนภาพ gyroscope ปรับมุมมองการแสดงผลอัตโนมัติ orientation '],
#  ['category_0_75', 'ระบบปฏิบัติการ', ' miui 10 android 9 pie'],
#  ['category_0_75',
#   'หน่วยประมวลผล',
#   ' qualcomm snapdragon 730 octa core ความเร็ว 2.2 ghz'],
#  ['category_0_75', 'รองรับ', ' 2 ซิมการ์ด'],
#  ['category_0_75', 'กล้องหน้า', ' front camera '],
#  ['category_0_75', 'ความละเอียด', ' 20ล้านพิกเซล '],
#  ['category_0_75', 'รองรับ', ' video call สนทนาแบบเห็นภาพ '],
#  ['category_0_75', 'กล้องหน้า', ' hdr '],
#  ['category_0_75', 'กล้องหน้า', ' portrait '],
#  ['category_0_75', 'กล้องหน้า', 'แบบ pop up'],
#  ['category_0_75', 'แบตเตอรี่', 'มาตรฐาน 4000 mah standard battery '],
#  ['category_0_75', 'แบรนด์', ' xiaomi'],
#  ['category_0_75', 'sku', ' 264227445 th 791158102'],
#  ['category_0_75', 'โมเดล', ' xiaomi mi 9t'],
#  ['category_0_75', 'ระยะเวลาการรับประกัน', ' 1 ปี'],
#  ['category_0_76',
#   'รุ่น',
#   ' non slip soft 3d คาร์บอนไฟเบอร์ฝาหลังฟิล์มป้องกันด้านหลังสติกเกอร์ป้องกัน ฿ 55.00 ฿ 92.00 40เปอร์เซนต์ '],
#  ['category_0_76', 'หน้าจอ', ' lcd'],
#  ['category_0_76',
#   'หน้าจอ',
#   'สำหรับ xiaomi mi9 super amoled ดิจิไทเซอร์จอแอลซีดี asembbly เปลี่ยนอะไหล่ซ่อมสำรอง กระจกเทมเปอร์ ซ่อมเครื่องมือเครื่องมือ ฿ 9624.00 ฿ 19247.00 50เปอร์เซนต์ '],
#  ['category_0_76', 'โมเดล', ' ฿ 11290.00 ฿ 11790.00 4เปอร์เซนต์ '],
#  ['category_0_76',
#   'หน้าจอ',
#   ' 6.26 นิ้ว tft lcd ips ฿ 9290.00 ฿ 10990.00 15เปอร์เซนต์ '],
#  ['category_0_77', 'ความละเอียด', ' 1440 x 720 พิกเซล 295 ppi '],
#  ['category_0_77',
#   'หน้าจอ',
#   'อัตโนมัติขณะสนทนา proximity ระบบเซนเซอร์หมุนภาพ gyroscope '],
#  ['category_0_77', 'รองรับ', ' 2 ซิมการ์ด'],
#  ['category_0_77', 'ระบบปฏิบัติการ', ' os '],
#  ['category_0_77', 'ระบบปฏิบัติการ', ' miui 10 android 9 pie'],
#  ['category_0_77',
#   'หน่วยประมวลผล',
#   ' qualcomm snapdrafon 439 octa core ความเร็ว 2.0 ghz'],
#  ['category_0_77', 'กล้องหน้า', ' front camera '],
#  ['category_0_77', 'ความละเอียด', ' 5ล้านพิกเซล '],
#  ['category_0_77', 'กล้องหน้า', ' hdr '],
#  ['category_0_77', 'กล้องหน้า', ' portrait'],
#  ['category_0_77', 'แบตเตอรี่', 'มาตรฐาน 4000 mah standard battery '],
#  ['category_0_78',
#   'แบรนด์',
#   ' new original packaging undamaged unopened unused item it is original and packaging is the same as what is found in the retail store unless the item is handmade or was packaged by the manufacturer in non retail packaging such as an unprinted box or plastic bag '],
#  ['category_0_78', 'แบรนด์', ' xiaomi'],
#  ['category_0_78', 'sku', ' 617148976 th 1172758996'],
#  ['category_0_78', 'ระบบปฏิบัติการ', 'เวอร์ชัน android 9.0 pie'],
#  ['category_0_78', 'โมเดล', ' xiaomi redmi note 8 pro 128gb '],
#  ['category_0_78', 'ระยะเวลาการรับประกัน', ' 1 ปี'],
#  ['category_0_79', 'รุ่น', 'เรือธง'],
#  ['category_0_79', 'cpu', ' snapdragon 855 ชิปประมวลผล เรือธงของปี'],
#  ['category_0_79', 'cpu', ' สถาปัตยกรรม kryo 485 ใหม่ทั้งหมดพร้อมชิปเซ็ต'],
#  ['category_0_79', 'ขนาด', ' 7nm'],
#  ['category_0_79', 'cpu', ' ชิปประมวลผลระดับ octa core สูงสุดถึง 2.84 ghz'],
#  ['category_0_79', 'cpu', ' 45เปอร์เซนต์ '],
#  ['category_0_79', 'gpu', ' adreno 640'],
#  ['category_0_79', 'gpu', ' 20เปอร์เซนต์ '],
#  ['category_0_79', 'gpu', ' สมาร์ทโฟน'],
#  ['category_0_79', 'รุ่น', 'แรกที่'],
#  ['category_0_79',
#   'รองรับ',
#   ' vulkan 1.1ไดร์เวอร์กราฟิกและโพสต์โปรเซสระดับภาพยนตร์'],
#  ['category_0_79', 'รุ่น', ' aie ตัวประมวล aie '],
#  ['category_0_79', 'รุ่น', 'ที่ 7 พร้อมระบบ ai ที่ทรงพลังกว่า 3 เท่า'],
#  ['category_0_79', 'ระบบปฏิบัติการ', 'miui 10'],
#  ['category_0_79', 'รองรับ', ' mi turboโทรศัพท์เครื่องแรกของเราที่ให้การ'],
#  ['category_0_79', 'รองรับ', 'การจัดระเบียบ i o การเพิ่มประสิทธิภาพ '],
#  ['category_0_79',
#   'รองรับ',
#   'การเพิ่มประสิทธิภาพความเร็วเปิดแอปลดความล่าช้าลง 35เปอร์เซนต์ หลังจากใช้งาน 18 เดือน'],
#  ['category_0_79', 'รองรับ', ' game turbo'],
#  ['category_0_79', 'รองรับ', 'ข้อมูลจำเพาะเกมที่กำหนดเอง '],
#  ['category_0_79',
#   'รองรับ',
#   'การปรับปรุงการแสดงเกมที่กำหนดเอง สัมผัสแบบ 4d สำหรับเกมยิง'],
#  ['category_0_79', 'รองรับ', 'การใช้งาน '],
#  ['category_0_79', 'cpu', 'gpu'],
#  ['category_0_79', 'gpu', ' และจอแสดงผล fps เครื่องมือเกม'],
#  ['category_0_79', 'รองรับ', 'การ์ดสลับเครือข่ายแบบวันทัช'],
#  ['category_0_79',
#   'รองรับ',
#   'การปรับปรุงประสิทธิภาพของเกมและการตอบสนองด้วยการสัมผัสที่ดีที่สุด '],
#  ['category_0_79', 'รองรับ', 'ข้อจำกัดขอบเขตที่กำหนดเอง '],
#  ['category_0_79', 'รองรับ', 'การปิดใช้งานความสว่างอัตโนมัติ ภาพ'],
#  ['category_0_79',
#   'หน้าจอ',
#   'สามนิ้วและโหมดป้องกันตาภาพพื้นหลังและจอแสดงผลไดนามิกalways on จอแสดงผล มัลติคัลเลอร์ '],
#  ['category_0_79',
#   'รองรับ',
#   'การเปลี่ยนภาพพื้นหลังไดนามิกโดยอัตโนมัติตามเวลาท้องถิ่น'],
#  ['category_0_79', 'รองรับ', 'โหมดสีเข้มหน่วยความจำ6gb 128gb'],
#  ['category_0_79', 'ขนาด', 'แรม '],
#  ['category_0_79', 'ความละเอียด', ' 2340 x 1080 fhd 403 ppi'],
#  ['category_0_79',
#   'หน้าจอ',
#   'มีความยาวแนวทแยง 6.39 นิ้ว พื้นที่แสดงผลจริงอาจมี'],
#  ['category_0_79', 'ขนาด', 'เล็กกว่าเล็กน้อย คำว่า การแสดงผลเต็ม'],
#  ['category_0_79', 'หน้าจอ', ' แสดงว่าโทรศัพท์มีอัตราส่วน'],
#  ['category_0_79', 'หน้าจอ', 'ต่อร่างกายสูงเมื่อเทียบกับโทรศัพท์ xiaomi '],
#  ['category_0_79', 'รุ่น', 'ดั้งเดิม อัตราส่วน'],
#  ['category_0_79',
#   'หน้าจอ',
#   'ต่อร่างกาย 90.7เปอร์เซนต์ ได้รับจากข้อมูลห้องปฏิบัติการ xiaomi วิธีการวัดอาจแตกต่างและผลลัพธ์อาจแตกต่างกันไป'],
#  ['category_0_79', 'กล้องหลัง', 'sony 4ล้านพิกเซล ความอัจฉริยะของ ai 3 '],
#  ['category_0_79', 'กล้องหลัง', ' ultra wide angle'],
#  ['category_0_79', 'รองรับ', 'การถ่ายภาพมาโคร '],
#  ['category_0_79', 'รองรับ', 'การถ่ายภาพมุมกว้าง '],
#  ['category_0_80', 'กล้องหลัง', ' 4 ตัว แบตเตอร์รี่ 5000 mah'],
#  ['category_0_80', 'แบรนด์', ' ออปโป อ๊อปโป'],
#  ['category_0_80', 'sku', ' 601804919 th 1133136752'],
#  ['category_0_80', 'กล้องหน้า', ' ล้านพิกเซล 7ล้านพิกเซล ขึ้นไป'],
#  ['category_0_80', 'ระบบปฏิบัติการ', 'เวอร์ชัน android 9.0 pie'],
#  ['category_0_80', 'โมเดล', ' a5'],
#  ['category_0_80', 'ระบบปฏิบัติการ', ' android'],
#  ['category_0_80', 'ความจุแบตเตอรี่', ' 1000 mah ถึง 5000 mah'],
#  ['category_0_81', 'รองรับ', 'เทคโนโลยีgsm hspa lte'],
#  ['category_0_81',
#   'ขนาด',
#   'ตัวเครื่อง155.9 x 75.4 x 8.1 มม. 6.14 x 2.97 x 0.32 in '],
#  ['category_0_81', 'น้ำหนัก', '168 g 5.93 oz '],
#  ['category_0_81', 'ขนาด', '6.2 นิ้ว'],
#  ['category_0_81', 'ความละเอียด', '720 x 1520 พิกเซล'],
#  ['category_0_81', 'ระบบปฏิบัติการ', 'ณ์ android 8.1 oreo coloros 5.2'],
#  ['category_0_81', 'cpu', ' octa core 1.8 ghz cortex a53'],
#  ['category_0_81', 'gpu', ' adreno 506'],
#  ['category_0_81', 'รองรับ', ' microsd up to 256 gb'],
#  ['category_0_81',
#   'กล้องหลัง',
#   'คู่ dual 13ล้านพิกเซล f 2.2 af 2ล้านพิกเซล f 2.4 depth sensor'],
#  ['category_0_81', 'แบตเตอรี่', ' li ion 4230 mah '],
#  ['category_0_81', 'แบรนด์', ' ออปโป อ๊อปโป'],
#  ['category_0_81', 'sku', ' 594172715 th 1115450949'],
#  ['category_0_81', 'หน่วยประมวลผล', ' octa core'],
#  ['category_0_81', 'ความละเอียด', 'วิดีโอ 1080p'],
#  ['category_0_81', 'ระยะเวลาการรับประกัน', ' 1 ปี'],
#  ['category_0_81', 'ระบบปฏิบัติการ', ' android 8.1 oreo'],
#  ['category_0_82', 'แบรนด์', ' ออปโป อ๊อปโป'],
#  ['category_0_82', 'sku', ' 368406522 th 720230984'],
#  ['category_0_82', 'โมเดล', ' cph1955'],
#  ['category_0_82', 'ระยะเวลาการรับประกัน', ' 1 ปี'],
#  ['category_0_83', 'แบตเตอรี่', ' 4230 mah ดีไซน์หยดน้ำ '],
#  ['category_0_83', 'กล้องหลัง', 'คู่ สีแดง สีน้ำเงิน'],
#  ['category_0_83', 'แบรนด์', ' ออปโป อ๊อปโป'],
#  ['category_0_83', 'sku', ' 596522329 th 1119982547'],
#  ['category_0_83', 'ระบบปฏิบัติการ', 'เวอร์ชัน android 7.1'],
#  ['category_0_83', 'โมเดล', ' oppo a5s 4 64 gb'],
#  ['category_0_83', 'ระยะเวลาการรับประกัน', ' 1 ปี'],
#  ['category_0_84', 'แบรนด์', ' ออปโป อ๊อปโป'],
#  ['category_0_84', 'sku', ' 561194526 th 1029420220'],
#  ['category_0_84', 'ระยะเวลาการรับประกัน', ' 1 ปี'],
#  ['category_0_84', 'แบตเตอรี่', ' built in rechargeable battery'],
#  ['category_0_84', 'กล้องหน้า', ' ล้านพิกเซล 7ล้านพิกเซล ขึ้นไป'],
#  ['category_0_84', 'ระบบปฏิบัติการ', 'เวอร์ชัน android 9.0 pie'],
#  ['category_0_84', 'โมเดล', ' a5 2020 cph1931'],
#  ['category_0_84', 'หน้าจอ', ' lcd'],
#  ['category_0_84', 'ขนาดหน้าจอ', ' นิ้ว 6.5'],
#  ['category_0_84', 'ความละเอียด', 'วิดีโอ 1080p'],
#  ['category_0_84', 'ความจุแบตเตอรี่', ' 5000 mah หรือมากกว่า'],
#  ['category_0_85',
#   'กล้องหน้า',
#   ' 25 ล้าน ai beauty ปลดล็อกด้วยใบหน้า ดีไซน์มันวาว'],
#  ['category_0_85', 'แบรนด์', ' ออปโป อ๊อปโป'],
#  ['category_0_85', 'sku', ' 594468094 th 1116094894'],
#  ['category_0_85', 'กล้องหน้า', ' ล้านพิกเซล 7ล้านพิกเซล ขึ้นไป'],
#  ['category_0_85', 'ระบบปฏิบัติการ', 'เวอร์ชัน android 8.0 oreo'],
#  ['category_0_85', 'โมเดล', ' cph1821'],
#  ['category_0_85', 'ขนาดหน้าจอ', ' นิ้ว 6.23'],
#  ['category_0_85', 'ระยะเวลาการรับประกัน', ' 1 ปี'],
#  ['category_0_85', 'ความจุแบตเตอรี่', ' 1000 mah ถึง 5000 mah'],
#  ['category_0_86', 'ขนาด', 'ตัวเครื่อง 163.6 x 75.6 x 9. มม. '],
#  ['category_0_86', 'น้ำหนัก', ' 195 กรัม'],
#  ['category_0_86', 'ความละเอียด', ' hd ดีไซน์รอยแหว่งหยดน้ำแบบใหม่ อัตราส่วน'],
#  ['category_0_86', 'หน้าจอ', 'ต่อตัวเครื่้อง 89เปอร์เซนต์ '],
#  ['category_0_86', 'รองรับ', ' microsd card เพิ่มเติม'],
#  ['category_0_86', 'ความจุ', 'สูงสุด 256gb'],
#  ['category_0_86', 'ระบบปฏิบัติการ', ' coloros 6.0.1 พื้นฐาน android 9 pie'],
#  ['category_0_86', 'กล้องหลัง', ' 4 เลนส์ และไฟแฟลช เลนส์หลัก '],
#  ['category_0_86', 'ความละเอียด', ' 12 ล้านพิกเซล เลนส์ ultra wide angle '],
#  ['category_0_86', 'ความละเอียด', ' 8 ล้านพิกเซล เลนส์ portrait '],
#  ['category_0_86', 'ความละเอียด', ' 2 ล้านพิกเซล เลนส์ mono '],
#  ['category_0_86', 'ความละเอียด', ' 2 ล้านพิกเซล'],
#  ['category_0_86', 'กล้องหน้า', 'ความละเอียด'],
#  ['category_0_86', 'ความละเอียด', ' 8 ล้านพิกเซล'],
#  ['category_0_86', 'รองรับ', 'ระบบเสียง dolby atmos'],
#  ['category_0_86', 'รองรับ', 'ซิมการ์ด 4g แบบ nano sim 2 ซิม'],
#  ['category_0_86', 'แบตเตอรี่', ' 5000mah '],
#  ['category_0_86', 'รองรับ', 'การแบ่ง'],
#  ['category_0_86', 'แบตเตอรี่', 'แบบ otg'],
#  ['category_0_86', 'แบรนด์', ' ออปโป อ๊อปโป'],
#  ['category_0_86', 'sku', ' 463662961 th 851448786'],
#  ['category_0_86', 'กล้องหน้า', ' ล้านพิกเซล 7ล้านพิกเซล ขึ้นไป'],
#  ['category_0_86', 'ระบบปฏิบัติการ', 'เวอร์ชัน android 9.0 pie'],
#  ['category_0_86', 'โมเดล', ' oppo a5 3gb 64gb'],
#  ['category_0_86', 'ระยะเวลาการรับประกัน', ' 1 ปี'],
#  ['category_0_86', 'ความจุแบตเตอรี่', ' 1000 mah ถึง 5000 mah'],
#  ['category_0_87', 'กล้องหลัง', ' 4 ตัว แบตเตอร์รี่ 5000 mah'],
#  ['category_0_87', 'แบรนด์', ' ออปโป อ๊อปโป'],
#  ['category_0_87', 'sku', ' 535266417 th 967736081'],
#  ['category_0_87', 'โมเดล', ' oppo a5 2020 4 128gb '],
#  ...]

# %%
# Write the triples to text file
with open('./Data/triples_01.txt', 'w', encoding='utf-8') as f:
    for _list in triples:
        for _string in _list:
            #f.seek(0)
            f.write(str(_string) + '\t')
        f.write('\n')

# %% [markdown]
# # Proprocessing text

# %% [markdown]
# # download stopwords of TH and EN
# nltk.download('words')
# th_stop = tuple(thai_stopwords())
# en_stop = tuple(get_stop_words('en'))
#
# # path of custom dictionary for word tokenize
# PATH_TO_CUSTOM_DICT = './Data/custom_dict.txt'
#
# from pythainlp.tokenize import sent_tokenize
#
# # split text to words
# def split_word(text):
#
#     # Split text to words
#     _tokenizer = Tokenizer(custom_dict=PATH_TO_CUSTOM_DICT, engine='newmm')
#     words = sent_tokenize(text)
#
#     # Remove stop words in TH and EN
#     words = [i for i in words if not i in th_stop and not i in en_stop]
#
#     # Delete whitespace
#     words = [i for i in words if not ' ' in i]
#
#
#     return words

# %% [markdown]
# ## Tokenize text

# %% [markdown]
# token = {}
# for key,value in data_clean.items():
#     tmp = [split_word(txt) for txt in value]
#     token[key] = tmp

# %% [markdown]
# token_list = {}
# for i,v in token.items():
#     token_list[i] = [item for sublist in v for item in sublist]

# %% [markdown]
# attr_list = {}
# res = []
# for i,v in attr.items():
#     tmp_list = []
#     for t in v:
#         if type(t) != list:
#             t_split = t.split(':')
#             if len(t_split)<3:
#                 tmp_list.append(t_split)
#         else:
#             for ele in t:
#                 if (ele[0]!='' and ele[1]!=''):
#                     res = [list(ele)]
#
#             for l in res:
#                 tmp_list.append(l)
#     attr_list[i] = tmp_list

# %% [markdown]
# attr_list

# %% [markdown]
# dict_attr = {}
# dict_value = {}
# for i,v in attr_list.items():
#     tmp_attr = []
#     tmp_value = []
#     for e in v:
#         tmp_attr.append(e[0])
#         tmp_value.append(e[1])
#     dict_attr[i] = tmp_attr
#     dict_value[i] = tmp_value

# %% [markdown]
# dict_value

# %% [markdown]
# series = { key: pd.Series(val) for key, val in token.items() }
#
# token2 = {}
# for i,v in series.items():
#     token2[i] = v.apply(pd.Series).stack()

# %% [markdown]
# pd.DataFrame.from_dict(token2, orient='index').transpose()

# %% [markdown]
# ## Category 1

# %% [markdown]
# token2

# %% [markdown]
# # Save data to csv file

# %% [markdown]
# # Transform dict to dataframe and save to csv file
# pd.DataFrame.from_dict(data_clean, orient='index').transpose().reset_index().to_csv("./Data/{}_clean.csv".format(file_name))

# %% [markdown]
# pd.DataFrame.from_dict(data_clean, orient='index').transpose().reset_index().to_excel('./Data/category1_clean.xlsx',engine='xlsxwriter')

# %% [markdown]
# pd.DataFrame.from_dict(dict_value, orient='index').transpose().to_csv("./Data/{}_value.csv".format(file_name))
