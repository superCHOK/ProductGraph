# %%
import pandas as pd
import csv
import re
import string
import nltk

from pythainlp.tokenize import Tokenizer
from pythainlp import word_tokenize
from pythainlp.corpus import thai_stopwords
from pythainlp.tokenize import dict_trie
from pythainlp.tag import pos_tag

from nltk.corpus import words
from stop_words import get_stop_words

# %%
# import data from csv
file_name = 'category1'

FILE = './Data/{}.csv'.format(file_name)
df = pd.read_csv(FILE)

# %%
df.head()
# Out:
#    Unnamed: 0                                       category_0_0  \
# 0           0                          โทรศัพท์มือถือและแท็บเล็ต
# 1           1                                        Smartphones
# 2           2    Samsung Galaxy M30s (4/64GB) ( โทรศัพท์มือถือ )
# 3           3  แบตอึดอยู่นาน สนุกได้ทั้งวัน กับความจุ 6000 mA...
# 4           4  ระบบกล้องหลัง 3 ตัว ที่มีกล้องชัดสูงสุดถึง 48 ...
#
#                                         category_0_1  \
# 0                          โทรศัพท์มือถือและแท็บเล็ต
# 1                                        Smartphones
# 2  โทรศัพท์มือถือ Samsung Galaxy A50s Ram4/64GB (...
# 3                           GSM 850/900/1800/1900MHz
# 4                      3G WCDMA 850/900/1900/2100MHz
#
#                                         category_0_2  \
# 0                          โทรศัพท์มือถือและแท็บเล็ต
# 1                                        Smartphones
# 2               Samsung Galaxy A10s (RAM2GB/ROM32GB)
# 3      สมาร์ทโฟน (โทรศัพท์มือถือพร้อมระบบปฏิบัติการ)
# 4  จอแสดงผล TFT-LCD 24-bit (16 ล้านสี)- หน้าจอทรง...
#
#                                         category_0_3  \
# 0                          โทรศัพท์มือถือและแท็บเล็ต
# 1                                        Smartphones
# 2  Samsung Galaxy Note 10 + (12/256 GB) ( โทรศัพท...
# 3                                ขนาดหน้าจอ 6.8 นิ้ว
# 4                                          Ram 12 GB
#
#                                         category_0_4  \
# 0                          โทรศัพท์มือถือและแท็บเล็ต
# 1                                        Smartphones
# 2                           Samsung Galaxy A7 (2017)
# 3  ระบบเซ็นเซอร์ (Sensor)\r\n- ระบบตรวจสอบลายนิ้ว...
# 4  คุณสมบัติการกันน้ำ (Waterproof)\r\n- กันน้ำได้...
#
#                                         category_0_5  \
# 0                          โทรศัพท์มือถือและแท็บเล็ต
# 1                                        Smartphones
# 2  Samsung Galaxy A9 (2018) 6 GB RAM 128 GB ROM 6...
# 3  จอแสดงผล Super AMOLED 24-bit (16 ล้านสี)Fullvi...
# 4  ระบบตรวจสอบลายนิ้วมือ (Fingerprint)ระบบจดจำใบห...
#
#                                         category_0_6  \
# 0                          โทรศัพท์มือถือและแท็บเล็ต
# 1                                        Smartphones
# 2  Samsung A30S (RAM 4GB / ROM 64 GB) มือ 1 ประกั...
# 3                             คุณสมบัติ Samsung A30S
# 4           จอแสดงผล Super AMOLED 24-bit (16 ล้านสี)
#
#                                         category_0_7  \
# 0                          โทรศัพท์มือถือและแท็บเล็ต
# 1                                        Smartphones
# 2  (มือ1 ศูนย์ไทย) Samsung Galaxy Note 10 Plus No...
# 3  Samsung Galaxy Note10 plus TH ประกันศูนย์ไทย 1...
# 4                                      แบรนด์ ซัมซุง
#
#                                       category_0_8  ...  \
# 0                        โทรศัพท์มือถือและแท็บเล็ต  ...
# 1                                      Smartphones  ...
# 2  Samsung Galaxy A70 (8/128GB) ( โทรศัพท์มือถือ )  ...
# 3                      Galaxy A70 (SM-A705FZBGTHL)  ...
# 4                               สเปคเทพของเกมเมอร์  ...
#
#                                      category_33_234  \
# 0                                   สมาร์ทดีไวซ์ New
# 1                                           แก็ดเจ็ต
# 2                           เครื่องเล่นเกมคอมโซล New
# 3                                         คอนโซล New
# 4  GloryStar BASEUS PUBG ไฟฟรีเกมที่วางโทรศัพท์แผ...
#
#                                      category_33_235  \
# 0                                   สมาร์ทดีไวซ์ New
# 1                                           แก็ดเจ็ต
# 2                           เครื่องเล่นเกมคอมโซล New
# 3                                         คอนโซล New
# 4  GloryStar นาฬิกาติดตามตำแหน่งอัจฉริยะเด็กนาฬิก...
#
#                                      category_33_236  \
# 0                                   สมาร์ทดีไวซ์ New
# 1                                           แก็ดเจ็ต
# 2                           เครื่องเล่นเกมคอมโซล New
# 3                                         คอนโซล New
# 4  GloryStar Joy-CON ตัวควบคุมเกมแป้นเกมส์จอยเกมส...
#
#                                      category_33_237  \
# 0                                   สมาร์ทดีไวซ์ New
# 1                                           แก็ดเจ็ต
# 2                           เครื่องเล่นเกมคอมโซล New
# 3                                         คอนโซล New
# 4  GloryStar คอนโซลเกมคลาสสิก 8 BitsProfessional ...
#
#                                      category_33_238  \
# 0                                   สมาร์ทดีไวซ์ New
# 1                                           แก็ดเจ็ต
# 2                           เครื่องเล่นเกมคอมโซล New
# 3                                         คอนโซล New
# 4  GloryStar สีน้ำเงินแปรงเกมควบคุมเครื่องรับสัญญ...
#
#                                      category_33_239  \
# 0                                   สมาร์ทดีไวซ์ New
# 1                                           แก็ดเจ็ต
# 2                           เครื่องเล่นเกมคอมโซล New
# 3                                         คอนโซล New
# 4  GloryStar Flysky รีโมทคอนโทรล FS-IT4S + IA4B 4...
#
#                                 category_33_240  \
# 0                              สมาร์ทดีไวซ์ New
# 1                                      แก็ดเจ็ต
# 2                      เครื่องเล่นเกมคอมโซล New
# 3                                    คอนโซล New
# 4  Top-Sky PlayStation 2 PS2 Memory Card - 32MB
#
#                                  category_33_241  \
# 0                               สมาร์ทดีไวซ์ New
# 1                                       แก็ดเจ็ต
# 2                       เครื่องเล่นเกมคอมโซล New
# 3                                     คอนโซล New
# 4  Top-Sky PlayStation 2 PS2 Memory Card - 256MB
#
#                                  category_33_242  \
# 0                               สมาร์ทดีไวซ์ New
# 1                                       แก็ดเจ็ต
# 2                       เครื่องเล่นเกมคอมโซล New
# 3                                     คอนโซล New
# 4  Top-Sky PlayStation 2 PS2 Memory Card - 128MB
#
#                                      category_33_243
# 0                                   สมาร์ทดีไวซ์ New
# 1                                           แก็ดเจ็ต
# 2                           เครื่องเล่นเกมคอมโซล New
# 3                                         คอนโซล New
# 4  Top - Sky 3 - in - 1 PS4/PS4 Slim/PS4 เกมโปรที...
#
# [5 rows x 5619 columns]

# %%
# Drop a column that not use
data = df.drop(columns=['Unnamed: 0'])

# Drop column that all equal to NaN
data = data.dropna(axis=1, how='all')

# Fill NaN with "-"
data = data.fillna('-')

# %%
data.head(10)
# Out:
#                                         category_0_0  \
# 0                          โทรศัพท์มือถือและแท็บเล็ต
# 1                                        Smartphones
# 2    Samsung Galaxy M30s (4/64GB) ( โทรศัพท์มือถือ )
# 3  แบตอึดอยู่นาน สนุกได้ทั้งวัน กับความจุ 6000 mA...
# 4  ระบบกล้องหลัง 3 ตัว ที่มีกล้องชัดสูงสุดถึง 48 ...
# 5  ใช้ Exynos 9611 สเป็กแรงขึ้นเล่นเกมส์ได้ไม่มีส...
# 6  หน้าจอแสดงผล Super AMOLED Infinity-U ขนาด 6.4 ...
# 7                                      แบรนด์ ซัมซุง
# 8                         SKU 480942616_TH-870640886
# 9               ประเภทของการรับประกัน มีการรับประกัน
#
#                                         category_0_1  \
# 0                          โทรศัพท์มือถือและแท็บเล็ต
# 1                                        Smartphones
# 2  โทรศัพท์มือถือ Samsung Galaxy A50s Ram4/64GB (...
# 3                           GSM 850/900/1800/1900MHz
# 4                      3G WCDMA 850/900/1900/2100MHz
# 5  4G FDD LTE B1(2100), B3(1800), B5(850), B7(260...
# 6         4G TDD LTE B38(2600), B40(2300), B41(2500)
# 7                              รองรับ 2 ซิม Nano-SIM
# 8  หน่วยประมวลผล Exynos 9610 Quad 2.3 GHz + Quad ...
# 9                             ระบบปฏิบัติการ Android
#
#                                         category_0_2  \
# 0                          โทรศัพท์มือถือและแท็บเล็ต
# 1                                        Smartphones
# 2               Samsung Galaxy A10s (RAM2GB/ROM32GB)
# 3      สมาร์ทโฟน (โทรศัพท์มือถือพร้อมระบบปฏิบัติการ)
# 4  จอแสดงผล TFT-LCD 24-bit (16 ล้านสี)- หน้าจอทรง...
# 5  ระบบเซ็นเซอร์ (Sensor)- ระบบตรวจสอบลายนิ้วมือ ...
# 6    มีสีให้เลือก (Colors) : Black, Red, Green, Blue
# 7                                      แบรนด์ ซัมซุง
# 8                         SKU 404422189_TH-784670279
# 9                                  มือถือ Smartphone
#
#                                         category_0_3  \
# 0                          โทรศัพท์มือถือและแท็บเล็ต
# 1                                        Smartphones
# 2  Samsung Galaxy Note 10 + (12/256 GB) ( โทรศัพท...
# 3                                ขนาดหน้าจอ 6.8 นิ้ว
# 4                                          Ram 12 GB
# 5                            ความจุ (Storage) 256 GB
# 6                       แบตเตอรี่ 4300 mAh (typical)
# 7                    มาตรฐานการกันน้ำและกันฝุ่น IP68
# 8                                      แบรนด์ ซัมซุง
# 9                         SKU 385536916_TH-749070165
#
#                                         category_0_4  \
# 0                          โทรศัพท์มือถือและแท็บเล็ต
# 1                                        Smartphones
# 2                           Samsung Galaxy A7 (2017)
# 3  ระบบเซ็นเซอร์ (Sensor)\r\n- ระบบตรวจสอบลายนิ้ว...
# 4  คุณสมบัติการกันน้ำ (Waterproof)\r\n- กันน้ำได้...
# 5  มีสีให้เลือก (Colors) : Black, Pink, Gold, Blu...
# 6  เทคโนโลยีการรับ/ส่งข้อมูล\r\n- 2G: EDGE/GPRS\r...
# 7                                    ใช้งาน Nano-SIM
# 8                                  รองรับ 2 ซิมการ์ด
# 9        ระบบปฏิบัติการ: Android 6.0.1 (Marshmallow)
#
#                                         category_0_5  \
# 0                          โทรศัพท์มือถือและแท็บเล็ต
# 1                                        Smartphones
# 2  Samsung Galaxy A9 (2018) 6 GB RAM 128 GB ROM 6...
# 3  จอแสดงผล Super AMOLED 24-bit (16 ล้านสี)Fullvi...
# 4  ระบบตรวจสอบลายนิ้วมือ (Fingerprint)ระบบจดจำใบห...
# 5  กล้องดิจิตอล (Main Camera) 24MP + (Ultra Wide ...
# 6                        กล้องหน้า ความละเอียด 24 MP
# 7                                            RAM 6GB
# 8                        หน่วยความจำตัวเครื่อง128 GB
# 9                                      แบรนด์ ซัมซุง
#
#                                         category_0_6  \
# 0                          โทรศัพท์มือถือและแท็บเล็ต
# 1                                        Smartphones
# 2  Samsung A30S (RAM 4GB / ROM 64 GB) มือ 1 ประกั...
# 3                             คุณสมบัติ Samsung A30S
# 4           จอแสดงผล Super AMOLED 24-bit (16 ล้านสี)
# 5  กว้าง 6.4 นิ้ว (แนวทะแยง) - ความละเอียด 720 x ...
# 6    ประเภทจอ Corning Gorilla Glass 3 ระบบปฏิบัติการ
# 7  Android 9.0 (Pie) หน่วยประมวลผล : Exynos 7885 ...
# 8                RAM 4GB - ROM 64GB การ์ดหน่วยความจำ
# 9                                microSD สูงสุด 1 TB
#
#                                         category_0_7  \
# 0                          โทรศัพท์มือถือและแท็บเล็ต
# 1                                        Smartphones
# 2  (มือ1 ศูนย์ไทย) Samsung Galaxy Note 10 Plus No...
# 3  Samsung Galaxy Note10 plus TH ประกันศูนย์ไทย 1...
# 4                                      แบรนด์ ซัมซุง
# 5                        SKU 599364278_TH-1176694583
# 6               ประเภทของการรับประกัน มีการรับประกัน
# 7             ระบบปฏิบัติการเวอร์ชัน Android 9.0 Pie
# 8                   Model samsung galaxy note10 plus
# 9                              ขนาดหน้าจอ (นิ้ว) 6.8
#
#                                       category_0_8  \
# 0                        โทรศัพท์มือถือและแท็บเล็ต
# 1                                      Smartphones
# 2  Samsung Galaxy A70 (8/128GB) ( โทรศัพท์มือถือ )
# 3                      Galaxy A70 (SM-A705FZBGTHL)
# 4                               สเปคเทพของเกมเมอร์
# 5          หน้าจอกว้าง 6.7" แบบ Infinity-U display
# 6                    3 กล้อง พร้อมเลนส์ Ultra Wide
# 7                                    แบรนด์ ซัมซุง
# 8                       SKU 309636084_TH-547152150
# 9             ประเภทของการรับประกัน มีการรับประกัน
#
#                                         category_0_9  ...  \
# 0                          โทรศัพท์มือถือและแท็บเล็ต  ...
# 1                                        Smartphones  ...
# 2  Smartphone โทรศัพท์มือถือ Samsung Galaxy A10S ...  ...
# 3                                      แบรนด์ ซัมซุง  ...
# 4                        SKU 571250946_TH-1048780375  ...
# 5                                  มือถือ Smartphone  ...
# 6                       ระยะเวลาการรับประกัน 1 เดือน  ...
# 7      ประเภทของการรับประกัน มีการรับประกันจากผู้ขาย  ...
# 8  ประเภทของแบตเตอรี่ แบตเตอรี่ชาร์จใหม่ได้และถอดได้  ...
# 9                                    สภาพสินค้า ใหม่  ...
#
#                                      category_33_234  \
# 0                                   สมาร์ทดีไวซ์ New
# 1                                           แก็ดเจ็ต
# 2                           เครื่องเล่นเกมคอมโซล New
# 3                                         คอนโซล New
# 4  GloryStar BASEUS PUBG ไฟฟรีเกมที่วางโทรศัพท์แผ...
# 5  แหล่งจ่ายไฟมือถือ 2000 mAh รองรับการชาร์จมือถื...
# 6  ใช้ได้กับ Xiaomi Huawei LG เกมที่วางโทรศัพท์ใน...
# 7             อุปกรณ์คอมพาทิเบิล: 4 "~ 6.5" มาร์ทโฟน
# 8                                   แบรนด์ GloryStar
# 9                         SKU 388218384_TH-754088901
#
#                                      category_33_235  \
# 0                                   สมาร์ทดีไวซ์ New
# 1                                           แก็ดเจ็ต
# 2                           เครื่องเล่นเกมคอมโซล New
# 3                                         คอนโซล New
# 4  GloryStar นาฬิกาติดตามตำแหน่งอัจฉริยะเด็กนาฬิก...
# 5                     1.3 นิ้ว HD IPS จอแสดงผลสีจริง
# 6  SOS โทรฉุกเฉิน, GPS, AGPS, LBS, กล้อง, gsensor...
# 7  นาฬิกาปลุกนาฬกิกาข้อมือ, การวางตำแหน่งออนไลน์,...
# 8  พยากรณ์อากาศ, การปิดระบบระยะไกล, App รองรับ An...
# 9                                   แบรนด์ GloryStar
#
#                                      category_33_236  \
# 0                                   สมาร์ทดีไวซ์ New
# 1                                           แก็ดเจ็ต
# 2                           เครื่องเล่นเกมคอมโซล New
# 3                                         คอนโซล New
# 4  GloryStar Joy-CON ตัวควบคุมเกมแป้นเกมส์จอยเกมส...
# 5  รุ่นนี้สำหรับคอนโซลเปลี่ยนค่ะ ตัวควบคุมมีฟังก์...
# 6  ตัวควบคุมประกอบด้วย 24 ปุ่มและ 2 3D ความแม่นยำ...
# 7                                   แบรนด์ GloryStar
# 8                         SKU 366718052_TH-716248719
# 9               ประเภทของการรับประกัน ไม่มีการประกัน
#
#                                      category_33_237  \
# 0                                   สมาร์ทดีไวซ์ New
# 1                                           แก็ดเจ็ต
# 2                           เครื่องเล่นเกมคอมโซล New
# 3                                         คอนโซล New
# 4  GloryStar คอนโซลเกมคลาสสิก 8 BitsProfessional ...
# 5  คอนโซลเกมคลาสสิก: 8 - bit เกมคอนโซล, เกมคลาสสิ...
# 6  การควบคุมแบบ Dual: จับเก้าหลุม, ใช้งานง่าย, เห...
# 7  620 เกมในตัว: 620 คลาสสิกในวัยเด็กทีวีวิดีโอเก...
# 8        ออกแบบสำหรับ: ระบบ Professional สำหรับ NES.
# 9  ภายในบรรจุภัณฑ์ประกอบด้วย: คอนโซลเกม + Dual + ...
#
#                                      category_33_238  \
# 0                                   สมาร์ทดีไวซ์ New
# 1                                           แก็ดเจ็ต
# 2                           เครื่องเล่นเกมคอมโซล New
# 3                                         คอนโซล New
# 4  GloryStar สีน้ำเงินแปรงเกมควบคุมเครื่องรับสัญญ...
# 5                    ปรับความกว้าง 50-85 มม. ช่วง ..
# 6  ความเข้ากันได้กว้างเหมาะสำหรับ Xiaomi Controll...
# 7                                   แบรนด์ GloryStar
# 8                         SKU 322894357_TH-613796747
# 9               ประเภทของการรับประกัน ไม่มีการประกัน
#
#                                      category_33_239  \
# 0                                   สมาร์ทดีไวซ์ New
# 1                                           แก็ดเจ็ต
# 2                           เครื่องเล่นเกมคอมโซล New
# 3                                         คอนโซล New
# 4  GloryStar Flysky รีโมทคอนโทรล FS-IT4S + IA4B 4...
# 5  2.4055 GHz ถึง 2.475 GHz กว้างแถบความถี่และ 14...
# 6  รอบทิศทางเสาอากาศกำลังส่งสูงครอบคลุมทุก frequn...
# 7  ID พิเศษ,ปรับปรุงเสถียรภาพของความถี่อัตโนมัติก...
# 8  Comsumption พลังงานต่ำชิ้นส่วนอิเล็กทรอนิกส์,ช...
# 9  การแสดงข้อมูลเรียลไทม์ของรุ่นเช่น voltadge ควา...
#
#                                      category_33_240  \
# 0                                   สมาร์ทดีไวซ์ New
# 1                                           แก็ดเจ็ต
# 2                           เครื่องเล่นเกมคอมโซล New
# 3                                         คอนโซล New
# 4       Top-Sky PlayStation 2 PS2 Memory Card - 32MB
# 5  Can be used to save game data for any PS2 game...
# 6  The memory card stores the character in a dura...
# 7  This portable memory card allows you to pause ...
# 8        Store all custom profiles/data on this card
# 9  Designed for the PS2, this memory card provide...
#
#                                      category_33_241  \
# 0                                   สมาร์ทดีไวซ์ New
# 1                                           แก็ดเจ็ต
# 2                           เครื่องเล่นเกมคอมโซล New
# 3                                         คอนโซล New
# 4      Top-Sky PlayStation 2 PS2 Memory Card - 256MB
# 5  Can be used to save game data for any PS2 game...
# 6  The memory card stores the character in a dura...
# 7  This portable memory card allows you to pause ...
# 8        Store all custom profiles/data on this card
# 9  Designed for the PS2, this memory card provide...
#
#                                      category_33_242  \
# 0                                   สมาร์ทดีไวซ์ New
# 1                                           แก็ดเจ็ต
# 2                           เครื่องเล่นเกมคอมโซล New
# 3                                         คอนโซล New
# 4      Top-Sky PlayStation 2 PS2 Memory Card - 128MB
# 5  Can be used to save game data for any PS2 game...
# 6  The memory card stores the character in a dura...
# 7  This portable memory card allows you to pause ...
# 8        Store all custom profiles/data on this card
# 9  Designed for the PS2, this memory card provide...
#
#                                      category_33_243
# 0                                   สมาร์ทดีไวซ์ New
# 1                                           แก็ดเจ็ต
# 2                           เครื่องเล่นเกมคอมโซล New
# 3                                         คอนโซล New
# 4  Top - Sky 3 - in - 1 PS4/PS4 Slim/PS4 เกมโปรที...
# 5  ที่ขาตั้งรองรับสำหรับ PS4 โฮสต์, และพอร์ตระบาย...
# 6  คู่ชาร์จที่ด้านบนของที่ยึดผู้ถือสามารถเรียกเก็...
# 7  ประหยัดพื้นที่ช่วยให้สามารถ PS4 ด้วย Dual ควบค...
# 8  ช่วยให้มั่นใจได้ว่าประหยัดพื้นที่และสำหรับ PS4...
# 9  จอยควบคุมเกม, แผ่นดิสก์เกมและโฮสต์จะรวม, หลีกเ...
#
# [10 rows x 5617 columns]

# %% [markdown]
# # Clean text

# %%
file_name2 = './Data/attributes_category1.txt'
with open(file_name2, 'r', encoding='utf-8') as f:
    x = f.read().splitlines()

# %%
s = 'จอแสดงผล tft lcd 24 bit 16 ล้านสี หน้าจอทรงหยดน้ำ รูปตัว v infinity v กว้าง 6.2 นิ้ว แนวทะแยง ความละเอียด 1520 x 720 พิกเซล'
if any(ext in s for ext in x):
    print(s)
# Out:
# จอแสดงผล tft lcd 24 bit 16 ล้านสี หน้าจอทรงหยดน้ำ รูปตัว v infinity v กว้าง 6.2 นิ้ว แนวทะแยง ความละเอียด 1520 x 720 พิกเซล

# %%
# clean the text
def clean_text_category1(msg):
    msg = str(msg).lower()
    if re.match("[0-9]\*[0-9]",str(msg)):
        msg = re.sub(r"\*","x",str(msg))
    if re.match("",str(msg)):
        msg = re.sub(r"\*","x",str(msg))
    msg = re.sub(r"\&","และ",str(msg))
    msg = re.sub(r"sku","sku ",str(msg))
    msg = re.sub(r"\%","เปอร์เซนต์ ",str(msg))
    msg = re.sub(r"brand","แบรนด์ ",str(msg))
    msg = re.sub(r"model","โมเดล ",str(msg))
    msg = re.sub(r"\sos\:?\s","ระบบปฏิบัติการ ",str(msg))
    msg = re.sub(r"ความจุ\s*\(storage\)","ความจุที่เก็บข้อมูล ",str(msg))
    msg = re.sub(r"[\d+\s+]mp|เมกะพิกเซล\s?","ล้านพิกเซล ",str(msg))
    msg = re.sub(r"smartphone[s]?","สมาร์ทโฟน",str(msg))
    msg = re.sub(r"\s+แรม\s?"," ram ",str(msg))
    msg = re.sub(r"\s+รอม\s?"," rom ",str(msg))
    msg = re.sub(r"ฮาร์ดดิสก์\s?|hard\s?disk\s?"," hdd ",str(msg))
    msg = re.sub(r"display","จอแสดงผล ",str(msg))
    msg = re.sub(r"weight?","น้ำหนัก ",str(msg))
    msg = re.sub(r"[b]attery\s?[c]apacity","ความจุแบตเตอรี่ ",str(msg))
    msg = re.sub(r"แบต\s","แบตเตอรี่ ",str(msg))
    msg = re.sub(r"\฿,"," บาท ",str(msg))
    msg = re.sub(r"[\d\s]*มิลลิเมตร|\smm\.?|millimeter\.?"," มม. ",str(msg))
    msg = re.sub(r"[\d\s]*เซนติเมตร|\scm\.?|centimeter\.?"," ซม. ",str(msg))
    msg = re.sub(r"\,","",str(msg))
    msg = re.sub(r"[^a-z0-9ก-๙\.\s]"," ", str(msg))
    msg = re.sub(r"\s+"," ",str(msg))
    if any(ext in msg for ext in x):
        return msg
    else:
        return

# %%
# Cleaning text with clean_text function and keep in dict
data_clean = {}
for key,value in data.iteritems():
    tmp = [clean_text_category1(txt) for txt in value if not txt == '-']
    tmp = [i for i in tmp if i] 
    data_clean[key] = tmp

# %%
# Show some of data in dict
dict(list(data_clean.items())[0:10])
# Out:
# {'category_0_0': ['โทรศัพท์มือถือและแท็บเล็ต',
#   'สมาร์ทโฟน',
#   'แบตอึดอยู่นาน สนุกได้ทั้งวัน กับความจุ 6000 mah และสามารถชาร์จแบตเร็ว ด้วย fast charging',
#   'ระบบกล้องหลัง 3 ตัว ที่มีกล้องชัดสูงสุดถึง 48ล้านพิกเซล มาพร้อมกับเลนส์มุมกว้างพิเศษ ultra wide',
#   'หน้าจอแสดงผล super amoled infinity u ขนาด 6.4 นิ้ว',
#   'แบรนด์ ซัมซุง',
#   'sku 480942616 th 870640886',
#   'โมเดล galaxy m30s 4 64gb ',
#   'ระยะเวลาการรับประกัน 1 ปี'],
#  'category_0_1': ['โทรศัพท์มือถือและแท็บเล็ต',
#   'สมาร์ทโฟน',
#   'รองรับ 2 ซิม nano sim',
#   'หน่วยประมวลผล exynos 9610 quad 2.3 ghz quad 1.7 ghz',
#   'ระบบปฏิบัติการ android',
#   'หน่วยความจำภายใน 64gb เพิ่ม micro sd รองรับสูงสุด 512 gb',
#   'หน้าจอ 6.4 นิ้ว ความละเอียด 1080 x 2340 พิกเซล fhd ',
#   'กล้องหลัง 3 เลนส์ 48 ล้านพิกเซล f 2.0 5 ล้านพิกเซล f 2.2 bokeh 8 ล้านพิกเซล f 2.4 ultrawide แฟลช led',
#   'กล้องหน้า 32 ล้านพิกเซล f 2.0',
#   'แบตเตอรี่ 4000 mah',
#   'ขนาด 158.5 x 74.5 x 7.7 มม. ',
#   'น้ำหนัก 169 g',
#   'แบรนด์ ซัมซุง',
#   'sku 593772364 th 1113954823',
#   'ระยะเวลาการรับประกัน 1 ปี',
#   'กล้องหน้า ล้านพิกเซล 7ล้านพิกเซล ขึ้นไป',
#   'ระบบปฏิบัติการเวอร์ชัน android 9.0 pie',
#   'โมเดล a50s',
#   'ขนาดหน้าจอ นิ้ว 6.4',
#   'กล้องด้านหลัง 2ล้านพิกเซล ขึ้นไป',
#   'ความจุแบตเตอรี่ 1000 mah ถึง 5000 mah'],
#  'category_0_2': ['โทรศัพท์มือถือและแท็บเล็ต',
#   'สมาร์ทโฟน',
#   'สมาร์ทโฟน โทรศัพท์มือถือพร้อมระบบปฏิบัติการ ',
#   'จอแสดงผล tft lcd 24 bit 16 ล้านสี หน้าจอทรงหยดน้ำ รูปตัว v infinity v กว้าง 6.2 นิ้ว แนวทะแยง ความละเอียด 1520 x 720 พิกเซล',
#   'ระบบเซ็นเซอร์ sensor ระบบตรวจสอบลายนิ้วมือ fingerprint ระบบหมุนภาพอัตโนมัติ accelerometer ระบบเซนเซอร์หมุนภาพ gyroscope ',
#   'แบรนด์ ซัมซุง',
#   'sku 404422189 th 784670279',
#   'มือถือ สมาร์ทโฟน',
#   'ระยะเวลาการรับประกัน 1 ปี',
#   'ระบบปฏิบัติการ android 9.0 pie',
#   'กล้องหน้า ล้านพิกเซล 7ล้านพิกเซล ขึ้นไป',
#   'ระบบปฏิบัติการเวอร์ชัน android 9.0 pie',
#   'โมเดล samsung galaxy a10s ram2gb rom32gb ',
#   'ขนาดหน้าจอ นิ้ว 6.2',
#   'กล้องด้านหลัง 11 1ล้านพิกเซล ',
#   'ความจุแบตเตอรี่ 1000 mah ถึง 5000 mah'],
#  'category_0_3': ['โทรศัพท์มือถือและแท็บเล็ต',
#   'สมาร์ทโฟน',
#   'ขนาดหน้าจอ 6.8 นิ้ว',
#   'ความจุที่เก็บข้อมูล 256 gb',
#   'แบตเตอรี่ 4300 mah typical ',
#   'มาตรฐานการกันน้ำและกันฝุ่น ip68',
#   'แบรนด์ ซัมซุง',
#   'sku 385536916 th 749070165',
#   'โมเดล galaxy note 10 ',
#   'ขนาดหน้าจอ นิ้ว 6.8',
#   'ระยะเวลาการรับประกัน 1 ปี'],
#  'category_0_4': ['โทรศัพท์มือถือและแท็บเล็ต',
#   'สมาร์ทโฟน',
#   'ระบบเซ็นเซอร์ sensor ระบบตรวจสอบลายนิ้วมือ fingerprint ระบบหมุนภาพอัตโนมัติ accelerometer ระบบเปิด ปิดหน้าจออัตโนมัติขณะสนทนา proximity ระบบตรวจจับคลื่นแม่เหล็ก geomagnetic ระบบเซนเซอร์หมุนภาพ gyroscope ระบบวัดความกดอากาศ barometer ',
#   'รองรับ 2 ซิมการ์ด',
#   'ระบบปฏิบัติการ android 6.0.1 marshmallow ',
#   'หน่วยประมวลผล octa core ความเร็ว 1.9 ghz',
#   'bluetooth 4.2 รองรับชุดหูฟังสเตอริโอ a2dp bluetooth stereo ',
#   'รองรับ nfc near field communication ',
#   'usb type c',
#   'กล้องดิจิตอล 16 ล้านพิกเซล digital camera รูรับแสงขนาด 1.9 ไฟแฟลช led โฟกัสอัตโนมัติ auto focus แตะเลือกจุดโฟกัส touch focus ค้นหาใบหน้าอัตโนมัติ face detection โหมดถ่ายภาพพาโนราม่า panorama ',
#   'กล้องหน้า front camera ความละเอียด 16ล้านพิกเซล รูรับแสงขนาด 1.9',
#   'เครื่องเล่นวีดีโอ video player รูปแบบไฟล์ ล้านพิกเซล eg 4 wmv h.264 h.263 รองรับวีดีโอจาก youtube ',
#   'สนับสนุน gmail google search',
#   'ริงโทนล้านพิกเซล 3 ระบบสั่น vibration in phone '],
#  'category_0_5': ['โทรศัพท์มือถือและแท็บเล็ต',
#   'สมาร์ทโฟน',
#   'samsung galaxy a9 2018 6 gb ram 128 gb rom 6.3 นิ้ว 5 กล้อง สูงสุด 24ล้านพิกเซล tetra cell f1.7 โทรศัพท์มือถือ ',
#   'จอแสดงผล super amoled 24 bit 16 ล้านสี fullview จอแสดงผล กว้าง 6.3 นิ้ว',
#   'ระบบตรวจสอบลายนิ้วมือ fingerprint ระบบจดจำใบหน้า face detection ',
#   'กล้องดิจิตอล main camera 2ล้านพิกเซล ultra wide camera ล้านพิกเซล telephoto camera 1ล้านพิกเซล depth camera ล้านพิกเซล fourth camera รูรับแสงขนาด 1.7',
#   'กล้องหน้า ความละเอียด 24ล้านพิกเซล ',
#   'แบรนด์ ซัมซุง',
#   'sku 265390897 th 412154584',
#   'โมเดล galaxy a9 2018 ',
#   'ระยะเวลาการรับประกัน 1 ปี'],
#  'category_0_6': ['โทรศัพท์มือถือและแท็บเล็ต',
#   'สมาร์ทโฟน',
#   'จอแสดงผล super amoled 24 bit 16 ล้านสี ',
#   'กว้าง 6.4 นิ้ว แนวทะแยง ความละเอียด 720 x 1560 พิกเซล 268 ppi ',
#   'ประเภทจอ corning gorilla glass 3 ระบบปฏิบัติการ',
#   'android 9.0 pie หน่วยประมวลผล exynos 7885 octa core ความเร็ว 1.8 mhz หน่วยความจำ',
#   'กล้องดิจิตอล 2ล้านพิกเซล 8ล้านพิกเซล ultrawide 5ล้านพิกเซล depth sensor triple camera รูรับแสงขนาด 1.7 ไฟแฟลช led โหมดถ่ายภาพช่วงการรับแสงสูง hdr ',
#   'กล้องหน้า front camera ความละเอียด 16ล้านพิกเซล รูรับแสงขนาด 2.0',
#   'เชื่อมต่อไร้สายระหว่างอุปกรณ์โดยตรง wi fi direct bluetooth 5.0 type c usb 2.0 ช่องเสียบชุดหูฟัง 3. มม. ',
#   'ใช้งาน nano sim รองรับ 2 ซิมการ์ด',
#   'ระบบเซ็นเซอร์ sensor ระบบสแกนลายนิ้วมือใต้หน้าจอ fingerprint under จอแสดงผล ตรวจจับความเคลื่อนไหวของตัวเครื่อง accelerometer ระบบเปิด ปิดหน้าจออัตโนมัติขณะสนทนา proximity ',
#   'แบตเตอรี่มาตรฐาน li pol 4000 mah standard battery ',
#   'แบรนด์ ซัมซุง',
#   'sku 594352438 th 1115888431',
#   'กล้องหน้า ล้านพิกเซล 16ล้านพิกเซล ',
#   'โมเดล samsung a30s',
#   'กล้องด้านหลัง 2ล้านพิกเซล ขึ้นไป',
#   'ระยะเวลาการรับประกัน 1 ปี',
#   'ความจุแบตเตอรี่ 1000 mah ถึง 5000 mah'],
#  'category_0_7': ['โทรศัพท์มือถือและแท็บเล็ต',
#   'สมาร์ทโฟน',
#   'แบรนด์ ซัมซุง',
#   'sku 599364278 th 1176694583',
#   'ระบบปฏิบัติการเวอร์ชัน android 9.0 pie',
#   'โมเดล samsung galaxy note10 plus',
#   'ขนาดหน้าจอ นิ้ว 6.8',
#   'ระยะเวลาการรับประกัน 1 ปี'],
#  'category_0_8': ['โทรศัพท์มือถือและแท็บเล็ต',
#   'สมาร์ทโฟน',
#   'หน้าจอกว้าง 6.7 แบบ infinity u จอแสดงผล ',
#   '3 กล้อง พร้อมเลนส์ ultra wide',
#   'แบรนด์ ซัมซุง',
#   'sku 309636084 th 547152150',
#   'โมเดล a70 8 128gb ',
#   'ระยะเวลาการรับประกัน 1 ปี'],
#  'category_0_9': ['โทรศัพท์มือถือและแท็บเล็ต',
#   'สมาร์ทโฟน',
#   'สมาร์ทโฟน โทรศัพท์มือถือ samsung galaxy a10s sm a107m ขนาดหน้าจอ 6.2 นิ้ว ram 2 rom 32 gb สีน้ำเงิน ',
#   'แบรนด์ ซัมซุง',
#   'sku 571250946 th 1048780375',
#   'มือถือ สมาร์ทโฟน',
#   'ระยะเวลาการรับประกัน 1 เดือน',
#   'ประเภทของแบตเตอรี่ แบตเตอรี่ชาร์จใหม่ได้และถอดได้',
#   'กล้องหน้า ล้านพิกเซล 7ล้านพิกเซล ขึ้นไป',
#   'โมเดล สมาร์ทโฟน โทรศัพท์มือถือ samsung galaxy a10s sm a107m ขนาดหน้าจอ 6.2 นิ้ว ram 2 rom 32 gb สีน้ำเงิน ',
#   'ประเภทหน้าจอ lcd',
#   'กล้องด้านหลัง 11 1ล้านพิกเซล ',
#   'ความละเอียดวิดีโอ 1080p',
#   'ความจุแบตเตอรี่ 1000 mah ถึง 5000 mah']}

# %% [markdown]
# # Proprocessing text

# %%
# download stopwords of TH and EN
nltk.download('words')
th_stop = tuple(thai_stopwords())
en_stop = tuple(get_stop_words('en'))

# path of custom dictionary for word tokenize
PATH_TO_CUSTOM_DICT = './Data/custom_dict.txt'

# split text to words 
def split_word(text):
    
    # Split text to words
    _tokenizer = Tokenizer(custom_dict=PATH_TO_CUSTOM_DICT, engine='newmm')
    words = _tokenizer.word_tokenize(text)

    # Remove stop words in TH and EN
    words = [i for i in words if not i in th_stop and not i in en_stop]
    
    # Delete whitespace
    words = [i for i in words if not ' ' in i]

    return words
# Out:
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\super\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!

# %% [markdown]
# ## Tokenize text

# %%
token = {}
for key,value in data_clean.items():
    tmp = [split_word(txt) for txt in value]
    token[key] = tmp

# %%
token
# Out:
# {'category_0_0': [['โทรศัพท์มือถือและแท็บเล็ต'],
#   ['สมาร์ทโฟน'],
#   ['แบต',
#    'อึดอยู่นาน',
#    'สนุกได้ทั้งวัน',
#    'ความจุ',
#    '6000',
#    'mah',
#    'และสามารถชาร์จ',
#    'แบต',
#    'fast',
#    'charging'],
#   ['ระบบ',
#    'กล้องหลัง',
#    '3',
#    'ตัว',
#    'ที่มีกล้องชัดสูงสุดถึง',
#    '48',
#    'ล้านพิกเซล',
#    'มาพร้อมกับเลนส์มุมกว้างพิเศษ',
#    'ultra',
#    'wide'],
#   ['หน้า',
#    'จอแสดงผล',
#    'super',
#    'amoled',
#    'infinity',
#    'u',
#    'ขนาด',
#    '6.4',
#    'นิ้ว'],
#   ['แบรนด์', 'ซัมซุง'],
#   ['sku', '480942616', 'th', '870640886'],
#   ['โมเดล', 'galaxy', 'm', '30', 's', '4', '64', 'gb'],
#   ['ระยะเวลาการรับประกัน', '1', 'ปี']],
#  'category_0_1': [['โทรศัพท์มือถือและแท็บเล็ต'],
#   ['สมาร์ทโฟน'],
#   ['2', 'ซิม', 'nano', 'sim'],
#   ['หน่วยประมวลผล',
#    'exynos',
#    '9610',
#    'quad',
#    '2.3',
#    'ghz',
#    'quad',
#    '1.7',
#    'ghz'],
#   ['ระบบปฏิบัติการ', 'android'],
#   ['หน่วยความจำภายใน', '64', 'gb', 'micro', 'sd', 'รองรับ', '512', 'gb'],
#   ['หน้าจอ',
#    '6.4',
#    'นิ้ว',
#    'ความละเอียด',
#    '1080',
#    'x',
#    '2340',
#    'พิกเซล',
#    'fhd'],
#   ['กล้องหลัง',
#    '3',
#    'เลนส์',
#    '48',
#    'ล้านพิกเซล',
#    'f',
#    '2.0',
#    '5',
#    'ล้านพิกเซล',
#    'f',
#    '2.2',
#    'bokeh',
#    '8',
#    'ล้านพิกเซล',
#    'f',
#    '2.4',
#    'ultrawide',
#    'แฟลช',
#    'led'],
#   ['กล้องหน้า', '32', 'ล้านพิกเซล', 'f', '2.0'],
#   ['แบตเตอรี่', '4000', 'mah'],
#   ['ขนาด', '158.5', 'x', '74.5', 'x', '7.7', 'มม.'],
#   ['น้ำหนัก', '169', 'g'],
#   ['แบรนด์', 'ซัมซุง'],
#   ['sku', '593772364', 'th', '1113954823'],
#   ['ระยะเวลาการรับประกัน', '1', 'ปี'],
#   ['กล้องหน้า', 'ล้านพิกเซล', '7', 'ล้านพิกเซล', 'ขึ้นไป'],
#   ['ระบบปฏิบัติการ', 'เวอร์ชัน', 'android', '9.0', 'pie'],
#   ['โมเดล', '50', 's'],
#   ['ขนาดหน้าจอ', 'นิ้ว', '6.4'],
#   ['กล้องด้านหลัง', '2', 'ล้านพิกเซล', 'ขึ้นไป'],
#   ['ความจุแบตเตอรี่', '1000', 'mah', '5000', 'mah']],
#  'category_0_2': [['โทรศัพท์มือถือและแท็บเล็ต'],
#   ['สมาร์ทโฟน'],
#   ['สมาร์ทโฟน', 'โทรศัพท์มือถือพร้อม', 'ระบบปฏิบัติการ'],
#   ['จอแสดงผล',
#    'tft',
#    'lcd',
#    '24',
#    'bit',
#    '16',
#    'ล้านสี',
#    'หน้าจอทรงหยดน้ำ',
#    'รูปตัว',
#    'v',
#    'infinity',
#    'v',
#    '6.2',
#    'นิ้ว',
#    'แนวทะแยง',
#    'ความละเอียด',
#    '1520',
#    'x',
#    '720',
#    'พิกเซล'],
#   ['ระบบ',
#    'เซ็นเซอร์',
#    'sensor',
#    'ระบบ',
#    'ตรวจสอบลายนิ้วมือ',
#    'fingerprint',
#    'ระบบ',
#    'หมุนภาพอัตโนมัติ',
#    'accelerometer',
#    'ระบบ',
#    'เซนเซอร์หมุนภาพ',
#    'gyroscope'],
#   ['แบรนด์', 'ซัมซุง'],
#   ['sku', '404422189', 'th', '784670279'],
#   ['มือถือ', 'สมาร์ทโฟน'],
#   ['ระยะเวลาการรับประกัน', '1', 'ปี'],
#   ['ระบบปฏิบัติการ', 'android', '9.0', 'pie'],
#   ['กล้องหน้า', 'ล้านพิกเซล', '7', 'ล้านพิกเซล', 'ขึ้นไป'],
#   ['ระบบปฏิบัติการ', 'เวอร์ชัน', 'android', '9.0', 'pie'],
#   ['โมเดล',
#    'samsung',
#    'galaxy',
#    '10',
#    's',
#    'ram',
#    '2',
#    'gb',
#    'rom',
#    '32',
#    'gb'],
#   ['ขนาดหน้าจอ', 'นิ้ว', '6.2'],
#   ['กล้องด้านหลัง', '11', '1', 'ล้านพิกเซล'],
#   ['ความจุแบตเตอรี่', '1000', 'mah', '5000', 'mah']],
#  'category_0_3': [['โทรศัพท์มือถือและแท็บเล็ต'],
#   ['สมาร์ทโฟน'],
#   ['ขนาดหน้าจอ', '6.8', 'นิ้ว'],
#   ['ความจุ', 'ที่เก็บข้อมูล', '256', 'gb'],
#   ['แบตเตอรี่', '4300', 'mah', 'typical'],
#   ['มาตรฐานการกันน้ำและกันฝุ่น', 'ip', '68'],
#   ['แบรนด์', 'ซัมซุง'],
#   ['sku', '385536916', 'th', '749070165'],
#   ['โมเดล', 'galaxy', 'note', '10'],
#   ['ขนาดหน้าจอ', 'นิ้ว', '6.8'],
#   ['ระยะเวลาการรับประกัน', '1', 'ปี']],
#  'category_0_4': [['โทรศัพท์มือถือและแท็บเล็ต'],
#   ['สมาร์ทโฟน'],
#   ['ระบบ',
#    'เซ็นเซอร์',
#    'sensor',
#    'ระบบ',
#    'ตรวจสอบลายนิ้วมือ',
#    'fingerprint',
#    'ระบบ',
#    'หมุนภาพอัตโนมัติ',
#    'accelerometer',
#    'ระบบ',
#    'ปิดหน้าจออัตโนมัติขณะสนทนา',
#    'proximity',
#    'ระบบ',
#    'ตรวจจับคลื่นแม่เหล็ก',
#    'geomagnetic',
#    'ระบบ',
#    'เซนเซอร์หมุนภาพ',
#    'gyroscope',
#    'ระบบ',
#    'วัดความกดอากาศ',
#    'barometer'],
#   ['2', 'ซิมการ์ด'],
#   ['ระบบปฏิบัติการ', 'android', '6.0.1', 'marshmallow'],
#   ['หน่วยประมวลผล', 'octa', 'core', 'ความเร็ว', '1.9', 'ghz'],
#   ['bluetooth',
#    '4.2',
#    'รองรับ',
#    'ชุดหูฟังสเตอริโอ',
#    '2',
#    'dp',
#    'bluetooth',
#    'stereo'],
#   ['nfc', 'near', 'field', 'communication'],
#   ['usb', 'type', 'c'],
#   ['กล้องดิจิตอล',
#    '16',
#    'ล้านพิกเซล',
#    'digital',
#    'camera',
#    'รูรับแสง',
#    'ขนาด',
#    '1.9',
#    'ไฟแฟลช',
#    'led',
#    'โฟกัสอัตโนมัติ',
#    'auto',
#    'focus',
#    'แตะเลือกจุดโฟกัส',
#    'touch',
#    'focus',
#    'ค้นหาใบหน้าอัตโนมัติ',
#    'face',
#    'detection',
#    'โหมดถ่ายภาพพาโนราม่า',
#    'panorama'],
#   ['กล้องหน้า',
#    'front',
#    'camera',
#    'ความละเอียด',
#    '16',
#    'ล้านพิกเซล',
#    'รูรับแสง',
#    'ขนาด',
#    '1.9'],
#   ['เครื่องเล่นวีดีโอ',
#    'video',
#    'player',
#    'รูปแบบไฟล์',
#    'ล้านพิกเซล',
#    'eg',
#    '4',
#    'wmv',
#    'h',
#    '.',
#    '264',
#    'h',
#    '.',
#    '263',
#    'รองรับ',
#    'วีดีโอจาก',
#    'youtube'],
#   ['สนับสนุน', 'gmail', 'google', 'search'],
#   ['ริงโทนล้านพิกเซล', '3', 'ระบบ', 'สั่น', 'vibration', 'phone']],
#  'category_0_5': [['โทรศัพท์มือถือและแท็บเล็ต'],
#   ['สมาร์ทโฟน'],
#   ['samsung',
#    'galaxy',
#    '9',
#    '2018',
#    '6',
#    'gb',
#    'ram',
#    '128',
#    'gb',
#    'rom',
#    '6.3',
#    'นิ้ว',
#    '5',
#    'กล้อง',
#    '24',
#    'ล้านพิกเซล',
#    'tetra',
#    'cell',
#    'f',
#    '1.7',
#    'โทรศัพท์มือถือ'],
#   ['จอแสดงผล',
#    'super',
#    'amoled',
#    '24',
#    'bit',
#    '16',
#    'ล้านสี',
#    'fullview',
#    'จอแสดงผล',
#    '6.3',
#    'นิ้ว'],
#   ['ระบบ',
#    'ตรวจสอบลายนิ้วมือ',
#    'fingerprint',
#    'ระบบ',
#    'จดจำใบหน้า',
#    'face',
#    'detection'],
#   ['กล้องดิจิตอล',
#    'main',
#    'camera',
#    '2',
#    'ล้านพิกเซล',
#    'ultra',
#    'wide',
#    'camera',
#    'ล้านพิกเซล',
#    'telephoto',
#    'camera',
#    '1',
#    'ล้านพิกเซล',
#    'depth',
#    'camera',
#    'ล้านพิกเซล',
#    'fourth',
#    'camera',
#    'รูรับแสง',
#    'ขนาด',
#    '1.7'],
#   ['กล้องหน้า', 'ความละเอียด', '24', 'ล้านพิกเซล'],
#   ['แบรนด์', 'ซัมซุง'],
#   ['sku', '265390897', 'th', '412154584'],
#   ['โมเดล', 'galaxy', '9', '2018'],
#   ['ระยะเวลาการรับประกัน', '1', 'ปี']],
#  'category_0_6': [['โทรศัพท์มือถือและแท็บเล็ต'],
#   ['สมาร์ทโฟน'],
#   ['จอแสดงผล', 'super', 'amoled', '24', 'bit', '16', 'ล้านสี'],
#   ['6.4',
#    'นิ้ว',
#    'แนวทะแยง',
#    'ความละเอียด',
#    '720',
#    'x',
#    '1560',
#    'พิกเซล',
#    '268',
#    'ppi'],
#   ['ประเภทจอ', 'corning', 'gorilla', 'glass', '3', 'ระบบปฏิบัติการ'],
#   ['android',
#    '9.0',
#    'pie',
#    'หน่วยประมวลผล',
#    'exynos',
#    '7885',
#    'octa',
#    'core',
#    'ความเร็ว',
#    '1.8',
#    'mhz',
#    'หน่วยความจำ'],
#   ['กล้องดิจิตอล',
#    '2',
#    'ล้านพิกเซล',
#    '8',
#    'ล้านพิกเซล',
#    'ultrawide',
#    '5',
#    'ล้านพิกเซล',
#    'depth',
#    'sensor',
#    'triple',
#    'camera',
#    'รูรับแสง',
#    'ขนาด',
#    '1.7',
#    'ไฟแฟลช',
#    'led',
#    'โหมดถ่ายภาพช่วงการรับแสงสูง',
#    'hdr'],
#   ['กล้องหน้า',
#    'front',
#    'camera',
#    'ความละเอียด',
#    '16',
#    'ล้านพิกเซล',
#    'รูรับแสง',
#    'ขนาด',
#    '2.0'],
#   ['เชื่อมต่อไร้สายระหว่างอุปกรณ์โดยตรง',
#    'wi',
#    'fi',
#    'direct',
#    'bluetooth',
#    '5.0',
#    'type',
#    'c',
#    'usb',
#    '2.0',
#    'ช่องเสียบชุดหูฟัง',
#    '3.',
#    'มม.'],
#   ['ใช้งาน', 'nano', 'sim', '2', 'ซิมการ์ด'],
#   ['ระบบ',
#    'เซ็นเซอร์',
#    'sensor',
#    'ระบบ',
#    'สแกนลายนิ้วมือใต้หน้าจอ',
#    'fingerprint',
#    'จอแสดงผล',
#    'ตรวจจับความเคลื่อนไหวของตัวเครื่อง',
#    'accelerometer',
#    'ระบบ',
#    'ปิดหน้าจออัตโนมัติขณะสนทนา',
#    'proximity'],
#   ['แบตเตอรี่', 'มาตรฐาน', 'li', 'pol', '4000', 'mah', 'standard', 'battery'],
#   ['แบรนด์', 'ซัมซุง'],
#   ['sku', '594352438', 'th', '1115888431'],
#   ['กล้องหน้า', 'ล้านพิกเซล', '16', 'ล้านพิกเซล'],
#   ['โมเดล', 'samsung', '30', 's'],
#   ['กล้องด้านหลัง', '2', 'ล้านพิกเซล', 'ขึ้นไป'],
#   ['ระยะเวลาการรับประกัน', '1', 'ปี'],
#   ['ความจุแบตเตอรี่', '1000', 'mah', '5000', 'mah']],
#  'category_0_7': [['โทรศัพท์มือถือและแท็บเล็ต'],
#   ['สมาร์ทโฟน'],
#   ['แบรนด์', 'ซัมซุง'],
#   ['sku', '599364278', 'th', '1176694583'],
#   ['ระบบปฏิบัติการ', 'เวอร์ชัน', 'android', '9.0', 'pie'],
#   ['โมเดล', 'samsung', 'galaxy', 'note', '10', 'plus'],
#   ['ขนาดหน้าจอ', 'นิ้ว', '6.8'],
#   ['ระยะเวลาการรับประกัน', '1', 'ปี']],
#  'category_0_8': [['โทรศัพท์มือถือและแท็บเล็ต'],
#   ['สมาร์ทโฟน'],
#   ['หน้าจอกว้าง', '6.7', 'infinity', 'u', 'จอแสดงผล'],
#   ['3', 'กล้อง', 'พร้อมเลนส์', 'ultra', 'wide'],
#   ['แบรนด์', 'ซัมซุง'],
#   ['sku', '309636084', 'th', '547152150'],
#   ['โมเดล', '70', '8', '128', 'gb'],
#   ['ระยะเวลาการรับประกัน', '1', 'ปี']],
#  'category_0_9': [['โทรศัพท์มือถือและแท็บเล็ต'],
#   ['สมาร์ทโฟน'],
#   ['สมาร์ทโฟน',
#    'โทรศัพท์มือถือ',
#    'samsung',
#    'galaxy',
#    '10',
#    's',
#    'sm',
#    '107',
#    'm',
#    'ขนาดหน้าจอ',
#    '6.2',
#    'นิ้ว',
#    'ram',
#    '2',
#    'rom',
#    '32',
#    'gb',
#    'สีน้ำเงิน'],
#   ['แบรนด์', 'ซัมซุง'],
#   ['sku', '571250946', 'th', '1048780375'],
#   ['มือถือ', 'สมาร์ทโฟน'],
#   ['ระยะเวลาการรับประกัน', '1', 'เดือน'],
#   ['ประเภทของ', 'แบตเตอรี่', 'แบตเตอรี่', 'ชาร์จใหม่ได้และถอดได้'],
#   ['กล้องหน้า', 'ล้านพิกเซล', '7', 'ล้านพิกเซล', 'ขึ้นไป'],
#   ['โมเดล',
#    'สมาร์ทโฟน',
#    'โทรศัพท์มือถือ',
#    'samsung',
#    'galaxy',
#    '10',
#    's',
#    'sm',
#    '107',
#    'm',
#    'ขนาดหน้าจอ',
#    '6.2',
#    'นิ้ว',
#    'ram',
#    '2',
#    'rom',
#    '32',
#    'gb',
#    'สีน้ำเงิน'],
#   ['ประเภทหน้าจอ', 'lcd'],
#   ['กล้องด้านหลัง', '11', '1', 'ล้านพิกเซล'],
#   ['ความละเอียดวิดีโอ', '1080', 'p'],
#   ['ความจุแบตเตอรี่', '1000', 'mah', '5000', 'mah']],
#  'category_0_10': [['โทรศัพท์มือถือและแท็บเล็ต'],
#   ['สมาร์ทโฟน'],
#   ['สมาร์ทโฟน', 'โทรศัพท์มือถือพร้อม', 'ระบบปฏิบัติการ'],
#   ['จอแสดงผล',
#    'super',
#    'amoled',
#    '24',
#    'bit',
#    '16',
#    'ล้านสี',
#    '5.2',
#    'นิ้ว',
#    'แนวทะแยง',
#    'ความละเอียด',
#    '1080',
#    'x',
#    '1920',
#    'พิกเซล',
#    'ประเภทจอ',
#    'หน้าจอกระจกแข็ง',
#    'ประเภทจอ',
#    'ระบบ',
#    'ป้องกัน',
#    'ฝุ่นละออง',
#    'resistance',
#    'dust'],
#   ['ระบบ',
#    'เซ็นเซอร์',
#    'sensor',
#    'ระบบ',
#    'ตรวจสอบลายนิ้วมือ',
#    'fingerprint',
#    'ระบบ',
#    'หมุนภาพอัตโนมัติ',
#    'accelerometer',
#    'ระบบ',
#    'ปิดหน้าจออัตโนมัติขณะสนทนา',
#    'proximity',
#    'ระบบ',
#    'ตรวจจับคลื่นแม่เหล็ก',
#    'geomagnetic',
#    'ระบบ',
#    'เซนเซอร์หมุนภาพ',
#    'gyroscope',
#    'ระบบ',
#    'วัดความกดอากาศ',
#    'barometer'],
#   ['2', 'ซิมการ์ด'],
#   ['ระบบปฏิบัติการ', 'android', '6.0.1', 'marshmallow'],
#   ['หน่วยประมวลผล', 'octa', 'core', 'ความเร็ว', '1.9', 'ghz'],
#   ['bluetooth',
#    '4.2',
#    'รองรับ',
#    'ชุดหูฟังสเตอริโอ',
#    '2',
#    'dp',
#    'bluetooth',
#    'stereo'],
#   ['nfc', 'near', 'field', 'communication'],
#   ['usb', 'type', 'c'],
#   ['กล้องดิจิตอล',
#    '16',
#    'ล้านพิกเซล',
#    'digital',
#    'camera',
#    'รูรับแสง',
#    'ขนาด',
#    '1.9',
#    'ไฟแฟลช',
#    'led',
#    'โฟกัสอัตโนมัติ',
#    'auto',
#    'focus',
#    'แตะเลือกจุดโฟกัส',
#    'touch',
#    'focus',
#    'โหมดถ่ายภาพพาโนราม่า',
#    'panorama'],
#   ['กล้องหน้า',
#    'front',
#    'camera',
#    'ความละเอียด',
#    '16',
#    'ล้านพิกเซล',
#    'รูรับแสง',
#    'ขนาด',
#    '1.9'],
#   ['เครื่องเล่นวีดีโอ',
#    'video',
#    'player',
#    'รูปแบบไฟล์',
#    'ล้านพิกเซล',
#    'eg',
#    '4',
#    'wmv',
#    'h',
#    '.',
#    '264',
#    'h',
#    '.',
#    '263',
#    'รองรับ',
#    'วีดีโอจาก',
#    'youtube'],
#   ['สนับสนุน', 'gmail', 'google', 'search']],
#  'category_0_11': [['โทรศัพท์มือถือและแท็บเล็ต'],
#   ['สมาร์ทโฟน'],
#   ['หน้า', 'จอแสดงผล', 'super', 'amoled', 'ขนาด', '5.2', 'นิ้ว'],
#   ['ความละเอียดระดับ',
#    'full',
#    'hd',
#    '1080',
#    'p',
#    '1080',
#    'x',
#    '1920',
#    'พิกเซล'],
#   ['หน่วยความจำ', 'แรม', 'ram', 'ขนาด', '3', 'gb'],
#   ['หน่วยความจำภายใน', 'ขนาด', '32', 'gb'],
#   ['กล้องด้านหลังความละเอียด', '16', 'ล้านพิกเซล'],
#   ['แบรนด์', 'ซัมซุง'],
#   ['sku', 'sa', '861', 'elaa', '8', 'nxs', '2', 'anth', '17866375'],
#   ['ระยะเวลาการรับประกัน', '1', 'ปี'],
#   ['ระบบปฏิบัติการ', 'android'],
#   ['กล้องหน้า', 'ล้านพิกเซล', '7', 'ล้านพิกเซล', 'ขึ้นไป'],
#   ['ระบบปฏิบัติการ', 'เวอร์ชัน', 'marshmallow'],
#   ['โมเดล', 'samsung', 'galaxy', '5', '2017', 'gold'],
#   ['ประเภทหน้าจอ', 'amoled'],
#   ['ขนาดหน้าจอ', 'นิ้ว', '5.2'],
#   ['กล้องด้านหลัง', '16', '2', 'ล้านพิกเซล']],
#  'category_0_12': [['โทรศัพท์มือถือและแท็บเล็ต'],
#   ['สมาร์ทโฟน'],
#   ['หน้าจอความละเอียดสูงระดับ',
#    'dynamic',
#    'amoled',
#    'ให้สีสันและความคมชัดเสมือนจอทีวีระดับพรีเมี่ยม'],
#   ['กล้องหลัง', '2', 'ตัวพร้อม', 'ระบบ', 'ถ่ายภาพอัจฉริยะ'],
#   ['แบรนด์', 'ซัมซุง'],
#   ['sku', '526004055', 'th', '942110374'],
#   ['โมเดล', 's', '10', 'e', '6', '128', 'gb'],
#   ['ระยะเวลาการรับประกัน', '1', 'ปี']],
#  'category_0_13': [['โทรศัพท์มือถือและแท็บเล็ต'],
#   ['สมาร์ทโฟน'],
#   ['สมาร์ทโฟน',
#    'โทรศัพท์มือถือ',
#    'samsung',
#    'galaxy',
#    '10',
#    's',
#    'sm',
#    '107',
#    'm',
#    'ขนาดหน้าจอ',
#    '6.2',
#    'นิ้ว',
#    'ram',
#    '2',
#    'rom',
#    '32',
#    'gb',
#    'สีเขียว'],
#   ['แบรนด์', 'ซัมซุง'],
#   ['sku', '571320012', 'th', '1048806072'],
#   ['มือถือ', 'สมาร์ทโฟน'],
#   ['ระยะเวลาการรับประกัน', '1', 'เดือน'],
#   ['ประเภทของ', 'แบตเตอรี่', 'แบตเตอรี่', 'ชาร์จใหม่ได้และถอดได้'],
#   ['กล้องหน้า', 'ล้านพิกเซล', '7', 'ล้านพิกเซล', 'ขึ้นไป'],
#   ['โมเดล',
#    'สมาร์ทโฟน',
#    'โทรศัพท์มือถือ',
#    'samsung',
#    'galaxy',
#    '10',
#    's',
#    'sm',
#    '107',
#    'm',
#    'ขนาดหน้าจอ',
#    '6.2',
#    'นิ้ว',
#    'ram',
#    '2',
#    'rom',
#    '32',
#    'gb',
#    'สีเขียว'],
#   ['ประเภทหน้าจอ', 'lcd'],
#   ['กล้องด้านหลัง', '11', '1', 'ล้านพิกเซล'],
#   ['ความละเอียดวิดีโอ', '1080', 'p'],
#   ['ความจุแบตเตอรี่', '1000', 'mah', '5000', 'mah']],
#  'category_0_14': [['โทรศัพท์มือถือและแท็บเล็ต'],
#   ['สมาร์ทโฟน'],
#   ['ขนาด',
#    'เครื่อง',
#    '156.9',
#    'x',
#    '75.8',
#    'x',
#    '7.8',
#    'มม.',
#    'หนัก',
#    '168',
#    'กรัม',
#    'หน้าจอ',
#    'pls',
#    'tft',
#    'lcd',
#    'ความละเอียด',
#    '720',
#    'x',
#    '1520',
#    'พิกเซล',
#    'hd',
#    'ขนาด',
#    '6.2',
#    'นิ้ว'],
#   ['ชิปเซต',
#    'mediatek',
#    'mt',
#    '6762',
#    'helio',
#    'p',
#    '22',
#    'ประมวลผล',
#    'octa',
#    'core',
#    '2.0',
#    'ghz',
#    'cortex',
#    '53',
#    'gpu',
#    'powervr',
#    'ge',
#    '8320'],
#   ['หน่วยความจำ',
#    'ram',
#    '2',
#    'gb',
#    'rom',
#    '32',
#    'gb',
#    'รองรับ',
#    'หน่วยความจำเสริม',
#    'microsd',
#    'card',
#    '512',
#    'gb'],
#   ['กล้องหลัง',
#    'เลนส์คู่',
#    'กล้องหลัก',
#    '13',
#    'ล้านพิกเซล',
#    'รูรับแสง',
#    'f',
#    '1.8',
#    'ระบบ',
#    'ออโต้โฟกัส'],
#   ['กล้อง', 'depth', 'sensor', '2', 'ล้านพิกเซล', 'รูรับแสง', 'f', '2.4'],
#   ['รองรับ', 'การบันทึกวีดีโอสูงสุด', 'fhd', '1920', 'x', '1080', '30', 'fps'],
#   ['กล้องหน้า',
#    '8',
#    'ล้านพิกเซล',
#    'รูรับแสง',
#    'f',
#    '2.0',
#    'รองรับ',
#    'การทำงานสองซิม'],
#   ['สัญญานเครือข่ายที่',
#    '2',
#    'g',
#    'gsm',
#    '3',
#    'g',
#    'wcdma',
#    '4',
#    'g',
#    'lte',
#    'fdd',
#    '4',
#    'g',
#    'lte',
#    'tdd'],
#   ['wi',
#    'fi',
#    '802.11',
#    'b',
#    'g',
#    'n',
#    '2.4',
#    'ghz',
#    'wi',
#    'fi',
#    'direct',
#    'สนับสนุน',
#    'bluetooth',
#    '4.2'],
#   ['แบตเตอรี่', 'ขนาด', '4000', 'mah'],
#   ['ระบบปฏิบัติการ', 'android', '9', 'pie', 'oneui'],
#   ['แบรนด์', 'ซัมซุง'],
#   ['sku', '594306208', 'th', '1115720937'],
#   ['กล้องหน้า', 'ล้านพิกเซล', '7', 'ล้านพิกเซล', 'ขึ้นไป'],
#   ['โมเดล', 'samsung', '10', 's'],
#   ['กล้องด้านหลัง', '11', '1', 'ล้านพิกเซล'],
#   ['ระยะเวลาการรับประกัน', '1', 'ปี'],
#   ['ความจุแบตเตอรี่', '1000', 'mah', '5000', 'mah']],
#  'category_0_15': [['samsung',
#    'galaxy',
#    '30',
#    '4',
#    'gb',
#    'ram',
#    '64',
#    'gb',
#    'rom',
#    '6.4',
#    'นิ้ว',
#    '3',
#    'กล้อง',
#    '16',
#    'ล้านพิกเซล',
#    'ff',
#    'f',
#    '2.0',
#    'โทรศัพท์มือถือ',
#    '฿',
#    '5990.00',
#    '฿',
#    '7290.00',
#    '18',
#    'เปอร์เซนต์'],
#   ['ซื้อ',
#    '1',
#    'แถม',
#    '1',
#    'ฟรี',
#    'สำหรับ',
#    'vivo',
#    'v',
#    '9',
#    'v',
#    '11',
#    'v',
#    '11',
#    'v',
#    '7',
#    'y',
#    '15',
#    'pro',
#    'y',
#    '12',
#    'รุ่น',
#    'non',
#    'slip',
#    'soft',
#    '3',
#    'd',
#    'คาร์บอนไฟเบอร์ฝาหลังฟิล์มป้องกันด้านหลังสติกเกอร์ป้องกัน',
#    '฿',
#    '55.00',
#    '฿',
#    '92.00',
#    '40',
#    'เปอร์เซนต์'],
#   ['samsung',
#    'galaxy',
#    'tab',
#    's',
#    '6',
#    '6',
#    'gb',
#    '128',
#    'gb',
#    'แท็บเล็ต',
#    '฿',
#    '23900.00',
#    '฿',
#    '25900.00',
#    '8',
#    'เปอร์เซนต์']],
#  'category_0_16': [['โทรศัพท์มือถือและแท็บเล็ต'],
#   ['สมาร์ทโฟน'],
#   ['samsung',
#    'galaxy',
#    's',
#    '10',
#    '8',
#    'gb',
#    'ram',
#    '128',
#    'gb',
#    'rom',
#    '6.1',
#    'นิ้ว',
#    '4',
#    'กล้อง',
#    '16',
#    'ล้านพิกเซล',
#    'ff',
#    'f',
#    '2.2',
#    'โทรศัพท์มือถือ'],
#   ['หน้าจอ',
#    '6.1',
#    'นิ้ว',
#    'ความละเอียด',
#    '3040',
#    'x',
#    '1440',
#    'quad',
#    'hd',
#    '550',
#    'ppi'],
#   ['กล้องหลัง',
#    '3',
#    'ตัว',
#    '16',
#    'ล้านพิกเซล',
#    'f',
#    '2.2',
#    'ultra',
#    'wide',
#    '12',
#    'ล้านพิกเซล',
#    'f',
#    '1.5',
#    '2.4',
#    'wide',
#    '12',
#    'ล้านพิกเซล',
#    'f',
#    '2.4',
#    'tele'],
#   ['กล้องหน้า', '10', 'ล้านพิกเซล', 'f', '1.9'],
#   ['หน่วยประมวลผล',
#    'octa',
#    'core',
#    'snapdragon',
#    '855',
#    'octa',
#    'core',
#    'exynos',
#    '9',
#    '9820'],
#   ['แบตเตอรี่', '3400', 'mah', 'typical'],
#   ['แบรนด์', 'ซัมซุง'],
#   ['sku', '289434461', 'th', '479544867'],
#   ['โมเดล', 's', '10', '128', 'gb'],
#   ['ระยะเวลาการรับประกัน', '1', 'ปี']],
#  'category_0_17': [['โทรศัพท์มือถือและแท็บเล็ต'],
#   ['สมาร์ทโฟน'],
#   ['ขนาด',
#    'น้ำหนัก',
#    '163.3',
#    '77.5',
#    'หนา',
#    '8',
#    'มม.',
#    'น้ำหนัก',
#    '183',
#    'กรัม'],
#   ['จอภาพ',
#    'ชนิดจอ',
#    'จอสัมผัส',
#    'tft',
#    'ขนาด',
#    'ความละเอียด',
#    '6.5',
#    'นิ้ว',
#    '264',
#    'ppi',
#    '720',
#    '1560',
#    'px'],
#   ['หน้าจอ',
#    'tft',
#    'infinity',
#    'u',
#    'จอแสดงผล',
#    'ขนาด',
#    '6.5',
#    'นิ้ว',
#    'ความละเอียด',
#    'hd',
#    '720',
#    'x',
#    '1560',
#    'พิกเซล',
#    'อัตราส่วนหน้าจอ',
#    '19.5',
#    '9'],
#   ['หน่วยประมวลผล',
#    'cpu',
#    'snapdragon',
#    '450',
#    'หน่วยประมวลผล',
#    'gpu',
#    'adreno',
#    '506'],
#   ['หน่วยความจำ',
#    'ram',
#    '3',
#    'gb',
#    'rom',
#    '32',
#    'gb',
#    'micro',
#    'sd',
#    '512',
#    'gb',
#    '2',
#    'ซิมการ์ด',
#    'รองรับ',
#    'การเพิ่มความจำด้วย',
#    'microsd',
#    'card',
#    '512',
#    'gb'],
#   ['กล้องหลัง', '3', 'ตัว', 'ประกอบด้วย'],
#   ['เลนส์หลัก',
#    'ความละเอียด',
#    '13',
#    'ล้านพิกเซล',
#    'f',
#    '1.8',
#    'เลนส์',
#    'ultra',
#    'wide',
#    '120',
#    'องศา',
#    'ความละเอียด',
#    '8',
#    'ล้านพิกเซล',
#    'f',
#    '2.2',
#    'เลนส์',
#    'depth',
#    'ความละเอียด',
#    '5',
#    'ล้านพิกเซล',
#    'f',
#    '2.2'],
#   ['กล้องหน้า', 'ความละเอียด', '8', 'ล้านพิกเซล', 'f', '2.0'],
#   ['รองรับ',
#    'ระบบ',
#    'เสียง',
#    'dolby',
#    'atmos',
#    'เซ็นเซอร์',
#    'accelerometer',
#    'fingerprint',
#    'sensor',
#    'gyro',
#    'sensor',
#    'geomagnetic',
#    'sensor',
#    'light',
#    'sensor',
#    'proximity',
#    'sensor',
#    'การเชื่อมต่อ',
#    'bluetooth',
#    '4.2',
#    'wi',
#    'fi',
#    '802.11',
#    'b',
#    'g',
#    'n',
#    '2.4',
#    'ghz',
#    '3.5',
#    'mm',
#    'earjack',
#    'usb',
#    'type',
#    'c',
#    'wi',
#    'fi',
#    'direct',
#    'gps',
#    'glonass',
#    'beidou',
#    'galileo',
#    'pc',
#    'sync',
#    '.',
#    '2',
#    'g',
#    'gsm',
#    '850',
#    'gsm',
#    '900',
#    'dcs',
#    '1800',
#    'pcs',
#    '1900',
#    '3',
#    'g',
#    'b',
#    '1',
#    '2100',
#    'b',
#    '2',
#    '1900',
#    'b',
#    '5',
#    '850',
#    'b',
#    '8',
#    '900',
#    '4',
#    'g',
#    'lte'],
#   ['แบตเตอรี่',
#    'ความจุ',
#    '4000',
#    'mah',
#    '15',
#    'w',
#    'fast',
#    'charging',
#    'ระบบ',
#    'ปฎิบัติการ',
#    'android',
#    '9.0',
#    'pi'],
#   ['แบรนด์', 'ซัมซุง'],
#   ['sku', '594338092', 'th', '1115814517'],
#   ['กล้องหน้า', 'ล้านพิกเซล', '7', 'ล้านพิกเซล', 'ขึ้นไป'],
#   ['โมเดล', 'samsung', '20', 's'],
#   ['กล้องด้านหลัง', '11', '1', 'ล้านพิกเซล'],
#   ['ระยะเวลาการรับประกัน', '1', 'ปี'],
#   ['ความจุแบตเตอรี่', '1000', 'mah', '5000', 'mah']],
#  'category_0_18': [['โทรศัพท์มือถือและแท็บเล็ต'],
#   ['สมาร์ทโฟน'],
#   ['หน้าจอ',
#    'super',
#    'amoled',
#    'ขนาด',
#    '6.7',
#    'นิ้ว',
#    'ความละเอียด',
#    'fhd',
#    '1080',
#    'x',
#    '2400'],
#   ['cpu', 'snapdragon', '730'],
#   ['ความจุ', '128', 'gb', 'ufs', '2.1', 'microsd', 'card'],
#   ['กล้องหน้า',
#    '4',
#    'ล้านพิกเซล',
#    'f',
#    '2.0',
#    'imx',
#    '586',
#    'ultra',
#    'wide',
#    'ล้านพิกเซล',
#    'f',
#    '2.2',
#    'tof'],
#   ['สแกนนิ้วมือบนหน้าจอ'],
#   ['แบตเตอรี่', '3700', 'mah', 'super', 'fast', 'charging', '25', 'w'],
#   ['แบรนด์', 'ซัมซุง'],
#   ['sku', '340860812', 'th', '661136678'],
#   ['มือถือ', 'สมาร์ทโฟน'],
#   ['ระยะเวลาการรับประกัน', '1', 'ปี'],
#   ['ระบบปฏิบัติการ', 'android'],
#   ['ระบบปฏิบัติการ', 'เวอร์ชัน', 'android', '9.0', 'pie'],
#   ['โมเดล', '80'],
#   ['ขนาดหน้าจอ', 'นิ้ว', '6.7'],
#   ['ความจุแบตเตอรี่', '3000', '3999', 'mah']],
#  'category_0_19': [['โทรศัพท์มือถือและแท็บเล็ต'],
#   ['สมาร์ทโฟน'],
#   ['2', 'ซิมการ์ด'],
#   ['จอแสดงผล',
#    'super',
#    'amoled',
#    '24',
#    'bit',
#    '16',
#    'ล้านสี',
#    'ระบบ',
#    'สัมผัส',
#    'multi',
#    'touch',
#    '6.4',
#    'นิ้ว',
#    'แนวทะแยง',
#    'ความละเอียด',
#    '2960',
#    'x',
#    '1440',
#    'พิกเซล',
#    'capacitive',
#    'corning',
#    'gorilla',
#    'glass',
#    '5',
#    'ระบบ',
#    'ป้องกัน',
#    'ฝุ่นละออง',
#    'resistance',
#    'dust'],
#   ['ระบบ',
#    'เซ็นเซอร์',
#    'sensor',
#    'ระบบ',
#    'ตรวจสอบลายนิ้วมือ',
#    'finger',
#    'print',
#    'ระบบ',
#    'จดจำใบหน้า',
#    'face',
#    'detection',
#    'ระบบ',
#    'หมุนภาพอัตโนมัติ',
#    'accelerometer',
#    'ระบบ',
#    'ปิดหน้าจออัตโนมัติขณะสนทนา',
#    'proximity',
#    'ระบบ',
#    'เซนเซอร์หมุนภาพ',
#    'gyroscope',
#    'ระบบ',
#    'วัดความกดอากาศ',
#    'barometer',
#    's',
#    'pen',
#    'ระบบ',
#    'ปากกาอัจฉริยะ',
#    'ระบบ',
#    'สแกนม่านตา'],
#   ['ระบบปฏิบัติการ', 'android', '8.1', 'oreo'],
#   ['หน่วยประมวลผล',
#    'exynos',
#    '9810',
#    'octa',
#    'core',
#    'ความเร็ว',
#    '2.7',
#    'ghz'],
#   ['usb', 'type', 'c'],
#   ['กล้องดิจิตอล',
#    '12',
#    '12',
#    'ล้านพิกเซล',
#    'dual',
#    'camera',
#    'รูรับแสง',
#    'ขนาด',
#    '1.5',
#    'ไฟแฟลช',
#    'led',
#    'ซูมออฟติคอล',
#    '2',
#    '2',
#    'x',
#    'optical',
#    'zoom',
#    'โฟกัสอัตโนมัติ',
#    'auto',
#    'focus',
#    'แตะเลือกจุดโฟกัส',
#    'touch',
#    'focus',
#    'ระบบ',
#    'ป้องกันภาพสั่นไหวแบบออปติคอล',
#    'ois',
#    'ค้นหาใบหน้าอัตโนมัติ',
#    'face',
#    'detection',
#    'โหมดถ่ายภาพพาโนราม่า',
#    'panorama'],
#   ['กล้องหน้า',
#    'front',
#    'camera',
#    'ความละเอียด',
#    '8',
#    'ล้านพิกเซล',
#    'รูรับแสง',
#    'ขนาด',
#    '1.7'],
#   ['ระบบ', 'เสียง', 'dolby', 'atmos'],
#   ['ระบบ', 'ชาร์จไร้สายในตัว'],
#   ['แบตเตอรี่', 'มาตรฐาน', '4000', 'mah', 'standard', 'battery'],
#   ['แบรนด์', 'ซัมซุง'],
#   ['sku', '283666353', 'th', '461390461'],
#   ['โมเดล',
#    'samsung',
#    'galaxy',
#    'note',
#    '9',
#    '6',
#    'gb',
#    '128',
#    'gb',
#    'เครื่องศูนย์',
#    'มีประกัน',
#    'ocean',
#    'blue'],
#   ['ระยะเวลาการรับประกัน', '1', 'ปี'],
#   ['ระบบปฏิบัติการ', 'android']],
#  'category_0_20': [['โทรศัพท์มือถือและแท็บเล็ต'],
#   ['สมาร์ทโฟน'],
#   ['samsung',
#    'galaxy',
#    '10',
#    's',
#    'สมาร์ทโฟน',
#    'กล้องหลัง',
#    'คู่',
#    '13',
#    'ล้านพิกเซล',
#    'แบตเตอรี่',
#    '4000',
#    'mah',
#    'ประกันศูนย์',
#    '1',
#    'ปี',
#    'แถมฟรีหูฟังซัมซุง',
#    'มูลค่า',
#    '399',
#    'บาท'],
#   ['น้ำหนัก', '168', 'กรัม'],
#   ['หน้า',
#    'จอแสดงผล',
#    'tft',
#    'lcd',
#    '6.2',
#    'นิ้ว',
#    'ความละเอียด',
#    '1520',
#    'x',
#    '720',
#    'พิกเซล',
#    'hd',
#    'มีดีไซน์รอยแหว่งแบบ',
#    'infinity',
#    'v'],
#   ['ระบบปฏิบัติการ', 'one', 'ui', '1.1', 'บนพื้นฐาน', 'android', '9', 'pie'],
#   ['กล้องหลัง',
#    '2',
#    'เลนส์',
#    'พร้อมไฟแฟลชเลนส์หลัก',
#    'ความละเอียด',
#    '13',
#    'ล้านพิกเซล',
#    'รูรับแสง',
#    'f',
#    '1.8'],
#   ['เลนส์', 'depth', 'ความละเอียด', '2', 'ล้านพิกเซล', 'รูรับแสง', 'f', '2.4'],
#   ['กล้องหน้า', 'ความละเอียด', '8', 'ล้านพิกเซล', 'รูรับแสง', 'f', '2.2'],
#   ['ซิมการ์ด', '2', 'ซิมแบบ', 'nano', 'sim'],
#   ['การเชื่อมต่อ',
#    'w',
#    'fi',
#    '2.4',
#    'ghz',
#    'blurtooth',
#    '4.2',
#    'พอร์ต',
#    'micro',
#    'usb',
#    '2.0',
#    'ช่องเสียบหูฟัง',
#    '3.',
#    'มม.'],
#   ['ระบบ', 'ความปลอดภัย', 'รหัส', 'สแกนใบหน้า', 'สแกนลายนิ้วมือ'],
#   ['แบตเตอรี่', '4000', 'mah'],
#   ['สาย', 'micro', 'usb', '2.0'],
#   ['แบรนด์', 'ซัมซุง'],
#   ['sku', '616572478', 'th', '1170962904'],
#   ['มือถือ', 'สมาร์ทโฟน'],
#   ['ระยะเวลาการรับประกัน', '1', 'ปี'],
#   ['ประเภทของ', 'แบตเตอรี่', 'built', 'rechargeable', 'battery'],
#   ['กล้องหน้า', 'ล้านพิกเซล', '7', 'ล้านพิกเซล', 'ขึ้นไป'],
#   ['ระบบปฏิบัติการ', 'เวอร์ชัน', 'android', '9.0', 'pie'],
#   ['โมเดล', 'samsung', 'galaxy', '10', 's', 'sm', '107', 'f']],
#  'category_0_21': [['โทรศัพท์มือถือและแท็บเล็ต'],
#   ['สมาร์ทโฟน'],
#   ['แบรนด์', 'ซัมซุง'],
#   ['sku', '307684896', 'th', '537048806'],
#   ['โมเดล', 'samsung', 'galaxy', 'j', '4', 'plus'],
#   ['ระยะเวลาการรับประกัน', '1', 'ปี']],
#  'category_0_22': [['โทรศัพท์มือถือและแท็บเล็ต'],
#   ['สมาร์ทโฟน'],
#   ['ขนาดหน้าจอ', '6.3', 'นิ้ว'],
#   ['ความจุ', 'ที่เก็บข้อมูล', '256', 'gb'],
#   ['แบตเตอรี่', '3500', 'mah', 'typical'],
#   ['มาตรฐานการกันน้ำและกันฝุ่น', 'ip', '68'],
#   ['แบรนด์', 'ซัมซุง'],
#   ['sku', '373972071', 'th', '728742055'],
#   ['โมเดล', '8', '256', 'gb'],
#   ['ระยะเวลาการรับประกัน', '1', 'ปี']],
#  'category_0_23': [['โทรศัพท์มือถือและแท็บเล็ต'],
#   ['สมาร์ทโฟน'],
#   ['หน้าจอกว้าง', 'ขนาด', '6.3', 'ใหญ่ที่สุดในตระกูล', 'note'],
#   ['หน้าจอกว้างขึ้น',
#    'ขนาด',
#    '6.3',
#    'ใหญ่ที่สุดในตระกูล',
#    'note',
#    'มอบภาพที่คมชัด',
#    'แจ้มแจ้งในทุกรายละเอียด'],
#   ['มีทั้งกล้องมุมกว้าง', 'ซึ่งสามารถถ่ายภาพได้ดีในสภาวะแสงน้อย'],
#   ['อัตราส่วน',
#    'หน้าจอขนาด',
#    '18',
#    '5',
#    '9',
#    'ช่วยให้คุณเห็นรายละเอียดบนหน้าจอที่มาก',
#    'ปรับแต่งรายการต่างๆ',
#    'พร้อมขยับจอน้อยลง'],
#   ['แบรนด์', 'ซัมซุง'],
#   ['sku', '310302392', 'th', '552106447'],
#   ['โมเดล', 'sm', 'n', '950'],
#   ['ระยะเวลาการรับประกัน', '1', 'ปี']],
#  'category_0_24': [['โทรศัพท์มือถือและแท็บเล็ต'],
#   ['สมาร์ทโฟน'],
#   ['จอแสดงผล',
#    'super',
#    'amoled',
#    '24',
#    'bit',
#    '16',
#    'ล้านสี',
#    'fullview',
#    'จอแสดงผล',
#    '6.3',
#    'นิ้ว'],
#   ['ระบบ',
#    'ตรวจสอบลายนิ้วมือ',
#    'fingerprint',
#    'ระบบ',
#    'จดจำใบหน้า',
#    'face',
#    'detection'],
#   ['กล้องดิจิตอล',
#    'main',
#    'camera',
#    '2',
#    'ล้านพิกเซล',
#    'ultra',
#    'wide',
#    'camera',
#    'ล้านพิกเซล',
#    'telephoto',
#    'camera',
#    '1',
#    'ล้านพิกเซล',
#    'depth',
#    'camera',
#    'ล้านพิกเซล',
#    'fourth',
#    'camera',
#    'รูรับแสง',
#    'ขนาด',
#    '1.7'],
#   ['กล้องหน้า', 'ความละเอียด', '24', 'ล้านพิกเซล'],
#   ['แบรนด์', 'ซัมซุง'],
#   ['sku', '280354579', 'th', '453591358'],
#   ['ระยะเวลาการรับประกัน', '5'],
#   ['ระบบปฏิบัติการ', 'android'],
#   ['กล้องหน้า', 'ล้านพิกเซล', '7', 'ล้านพิกเซล', 'ขึ้นไป'],
#   ['ระบบปฏิบัติการ', 'เวอร์ชัน', 'android', '8.0', 'oreo'],
#   ['โมเดล',
#    'samsung',
#    'galaxy',
#    '9',
#    '2018',
#    '6',
#    '128',
#    'gb',
#    'เครื่องศูนย์',
#    'เคลียสตอคไม่มีประกัน',
#    'caviar',
#    'black'],
#   ['ขนาดหน้าจอ', 'นิ้ว', '6.3'],
#   ['กล้องด้านหลัง', '2', 'ล้านพิกเซล', 'ขึ้นไป'],
#   ['ความจุแบตเตอรี่', '1000', 'mah', '5000', 'mah']],
#  'category_0_25': [['โทรศัพท์มือถือและแท็บเล็ต'],
#   ['สมาร์ทโฟน'],
#   ['จอแสดงผล',
#    'super',
#    'amoled',
#    '24',
#    'bit',
#    '16',
#    'ล้านสี',
#    'หน้าจอทรงหยดน้ำ',
#    'รูปตัว',
#    'u',
#    'infinity',
#    'u',
#    'ระบบ',
#    'สัมผัส',
#    'multi',
#    'touch',
#    '6.7',
#    'นิ้ว',
#    'แนวทะแยง',
#    'ความละเอียด',
#    '1080',
#    'x',
#    '2400',
#    'พิกเซล',
#    'capacitive',
#    'ระบบ',
#    'เซ็นเซอร์',
#    'sensor',
#    'ระบบ',
#    'สแกนลายนิ้วมือใต้หน้าจอ',
#    'fingerprint',
#    'จอแสดงผล',
#    'ระบบ',
#    'จดจำใบหน้า',
#    'face',
#    'detection',
#    'ระบบ',
#    'หมุนภาพอัตโนมัติ',
#    'accelerometer',
#    'ตรวจจับแสงปรับความสว่างอัตโนมัติ',
#    'ambient',
#    'light',
#    'ระบบ',
#    'ปิดหน้าจออัตโนมัติขณะสนทนา',
#    'proximity',
#    'ระบบ',
#    'เซนเซอร์หมุนภาพ',
#    'gyroscope',
#    'ปรับมุมมองการแสดงผลอัตโนมัติ',
#    'orientation',
#    'ระบบปฏิบัติการ',
#    'android',
#    '9',
#    'pie',
#    'หน่วยประมวลผล',
#    'snapdragon',
#    '675',
#    'octa',
#    'core',
#    'ความเร็ว',
#    '2.0',
#    'ghz',
#    'หน่วยความจำ',
#    'rom',
#    '128',
#    'gb',
#    'ram',
#    '8',
#    'gb',
#    'การ์ดหน่วยความจำ',
#    'microsd',
#    '512',
#    'gb',
#    'กล้องดิจิตอล',
#    '3',
#    'ล้านพิกเซล',
#    '8',
#    'ultra',
#    'wide',
#    '5',
#    'triple',
#    'camera',
#    'รูรับแสง',
#    'ขนาด',
#    '1.7',
#    'ไฟแฟลช',
#    'led',
#    'ค้นหาใบหน้าอัตโนมัติ',
#    'face',
#    'detection',
#    'เทคโนโลยีถ่ายภาพอัจฉริยะ',
#    'ai',
#    'camera',
#    'โหมดปรับหน้าสวยอัตโนมัติ',
#    'ai',
#    'face',
#    'beauty',
#    'โหมดเปลี่ยนภาพเซลฟี่เป็นอิโมจิ',
#    'ar',
#    'emoji',
#    'โหมดเปลี่ยนภาพเซลฟี่เป็นสติกเกอร์',
#    'ar',
#    'sticker',
#    'โหมดถ่ายภาพพาโนราม่า',
#    'panorama',
#    'โหมดถ่ายภาพช่วงการรับแสงสูง',
#    'hdr',
#    'กล้องหน้า',
#    'front',
#    'camera',
#    'ความละเอียด',
#    '32',
#    'รูรับแสง',
#    'ขนาด',
#    '2.0',
#    'กล้องหน้า',
#    'hdr',
#    'บันทึกวีดีโอ',
#    'ภาพเคลื่อนไหว',
#    'video',
#    'recording',
#    'รูปแบบไฟล์วีดีโอ',
#    'ล้านพิกเซล',
#    'eg',
#    '4',
#    'เครื่องเล่นวีดีโอ',
#    'video',
#    'player',
#    'รูปแบบไฟล์',
#    'ล้านพิกเซล',
#    'eg',
#    '4',
#    'รองรับ',
#    'วีดีโอจาก',
#    'youtube',
#    'เครื่องเล่นเพลง',
#    'music',
#    'player',
#    'รูปแบบไฟล์',
#    'ล้านพิกเซล',
#    '3',
#    'ระบบ',
#    'เสียง',
#    'dolby',
#    'atmos',
#    'เทคโนโลยีเพิ่มความเร็วในการชาร์จ',
#    'แบตเตอรี่',
#    'มาตรฐาน',
#    '4500',
#    'mah',
#    'standard',
#    'battery'],
#   ['แบรนด์', 'ซัมซุง'],
#   ['sku', '595150747', 'th', '1117932783'],
#   ['โมเดล', 'samsung', '70']],
#  'category_0_26': [['โทรศัพท์มือถือและแท็บเล็ต'],
#   ['สมาร์ทโฟน'],
#   ['จอคุณภาพสูง', 'full', 'front', 'จอแสดงผล', 'samoled'],
#   ['กล้องหน้า', 'หลังความละเอียดเท่ากัน', '16', 'ล้านพิกเซล'],
#   ['กล้องหน้า',
#    'มาพร้อม',
#    '3',
#    'step',
#    'lighting',
#    'ช่วยปรับแสงได้',
#    '3',
#    'ระดับ',
#    'กล้องหลัง',
#    'รูรับแสงกว้าง',
#    'f',
#    '1.7'],
#   ['app',
#    'pair',
#    'สามารถเปิด',
#    '2',
#    'แอพที่ชอบได้พร้อมกัน',
#    '2',
#    'หน้าจอในคลิ๊กเดียว'],
#   ['แชทได้พร้อมกัน',
#    '2',
#    'บัญชีในเครื่องเดียว',
#    'รองรับ',
#    'แอพ',
#    'social',
#    'เยอะที่สุดถึง',
#    '18',
#    'แอพ'],
#   ['แบรนด์', 'ซัมซุง'],
#   ['sku', '264741378', 'th', '411062149'],
#   ['โมเดล', 'galaxy', '6', 'sm', '605', 'g', 'ds'],
#   ['ขนาดหน้าจอ', 'นิ้ว', '6'],
#   ['ระยะเวลาการรับประกัน', '1', 'ปี']],
#  'category_0_27': [['โทรศัพท์มือถือและแท็บเล็ต'],
#   ['สมาร์ทโฟน'],
#   ['samsung',
#    'galaxy',
#    '50',
#    's',
#    '128',
#    'gb',
#    '6',
#    'gb',
#    'ram',
#    'original',
#    'set',
#    'แบรนด์',
#    'new',
#    'original',
#    'packaging',
#    'undamaged',
#    'unopened',
#    'unused',
#    'item',
#    'original',
#    'packaging',
#    'found',
#    'retail',
#    'store',
#    'unless',
#    'item',
#    'handmade',
#    'packaged',
#    'manufacturer',
#    'non',
#    'retail',
#    'packaging',
#    'unprinted',
#    'box',
#    'plastic',
#    'bag'],
#   ['แบรนด์', 'ซัมซุง'],
#   ['sku', '617108827', 'th', '1172618764'],
#   ['ระบบปฏิบัติการ', 'เวอร์ชัน', 'android', '9.0', 'pie'],
#   ['โมเดล',
#    'samsung',
#    'galaxy',
#    '50',
#    's',
#    '128',
#    'gb',
#    '6',
#    'gb',
#    'ram',
#    'original',
#    'set'],
#   ['ระยะเวลาการรับประกัน', '1', 'ปี']],
#  'category_0_28': [['โทรศัพท์มือถือและแท็บเล็ต'],
#   ['สมาร์ทโฟน'],
#   ['สนุกทุกประสบการณ์กับหน้าจอใหญ่ที่เต็มตากว่าเดิม'],
#   ['เด่นทุกมุมมองด้วยกล้องสามเลนส์'],
#   ['แบรนด์', 'ซัมซุง'],
#   ['sku', '511068392', 'th', '907938105'],
#   ['โมเดล', 'galaxy', '20', 's', '3', '32', 'gb'],
#   ['ระยะเวลาการรับประกัน', '1', 'ปี']],
#  'category_0_29': [['โทรศัพท์มือถือและแท็บเล็ต'],
#   ['สมาร์ทโฟน'],
#   ['หน้าจอใหญ่', 'super', 'amoled', '5.6', 'นิ้ว', 'สัดส่วน', '18.5', '9'],
#   ['ระบบปฏิบัติการ', 'แอนดรอยด์', '7.1', 'nougat'],
#   ['กล้องถ่ายภาพ', '16', 'ล้านพิกเซล', 'รูรับแสงกว้าง', 'f', '1.7'],
#   ['กล้องหน้า', 'แบบคู่', '16', '8', 'ล้านพิกเซล', 'รูรับแสง', 'f', '1.9'],
#   ['กล้องหน้า', 'live', 'focus', 'ปรับฉากหลังละลายได้'],
#   ['ปลดล็อคหน้าจอด้วยการสแกนใบหน้า'],
#   ['รองรับ', 'การใช้งาน', 'secure', 'folder'],
#   ['รองรับ', 'การสแกนลายนิ้วมือ'],
#   ['หน้าจอใหญ่', 'super', 'amoled', '5.6', 'นิ้ว', 'สัดส่วน', '18.5', '9'],
#   ['ระบบปฏิบัติการ', 'แอนดรอยด์', '7.1', 'nougat'],
#   ['กล้องถ่ายภาพ', '16', 'ล้านพิกเซล', 'รูรับแสงกว้าง', 'f', '1.7'],
#   ['กล้องหน้า', 'แบบคู่', '16', '8', 'ล้านพิกเซล', 'รูรับแสง', 'f', '1.9'],
#   ['กล้องหน้า', 'live', 'focus', 'ปรับฉากหลังละลายได้'],
#   ['ปลดล็อคหน้าจอด้วยการสแกนใบหน้า'],
#   ['รองรับ', 'การใช้งาน', 'secure', 'folder'],
#   ['รองรับ', 'การสแกนลายนิ้วมือ'],
#   ['แบรนด์', 'ซัมซุง'],
#   ['sku', '207916690', 'th', '313021622'],
#   ['โมเดล', 'refurbish', 'samsung', 'galaxy', '8', '2018', 'gold'],
#   ['ระยะเวลาการรับประกัน', '3', 'เดือน']],
#  'category_0_30': [['โทรศัพท์มือถือและแท็บเล็ต'],
#   ['สมาร์ทโฟน'],
#   ['samsung',
#    'galaxy',
#    's',
#    '10',
#    '8',
#    'gb',
#    'ram',
#    '128',
#    'gb',
#    'rom',
#    '6.4',
#    'นิ้ว',
#    '5',
#    'กล้อง',
#    '16',
#    'ล้านพิกเซล',
#    'ff',
#    'f',
#    '2.2',
#    'โทรศัพท์มือถือ'],
#   ['หน้าจอ',
#    '6.4',
#    'นิ้ว',
#    'ความละเอียด',
#    '3040',
#    'x',
#    '1440',
#    'quad',
#    'hd',
#    '550',
#    'ppi'],
#   ['กล้องหลัง',
#    '3',
#    'ตัว',
#    '16',
#    'ล้านพิกเซล',
#    'f',
#    '2.2',
#    'ultra',
#    'wide',
#    '12',
#    'ล้านพิกเซล',
#    'f',
#    '1.5',
#    '2.4',
#    'wide',
#    '12',
#    'ล้านพิกเซล',
#    'f',
#    '2.4',
#    'tele'],
#   ['กล้องหน้า',
#    '2',
#    'ตัว',
#    '10',
#    'ล้านพิกเซล',
#    'f',
#    '1.9',
#    'main',
#    '8',
#    'ล้านพิกเซล',
#    'f',
#    '2.2',
#    'live',
#    'focus'],
#   ['หน่วยประมวลผล',
#    'octa',
#    'core',
#    'snapdragon',
#    '855',
#    'octa',
#    'core',
#    'exynos',
#    '9',
#    '9820'],
#   ['แบตเตอรี่', '4100', 'mah', 'typical'],
#   ['แบรนด์', 'ซัมซุง'],
#   ['sku', '289426638', 'th', '479560515'],
#   ['โมเดล', 's', '10', '128', 'gb'],
#   ['ระยะเวลาการรับประกัน', '1', 'ปี']],
#  'category_0_31': [['โทรศัพท์มือถือและแท็บเล็ต'],
#   ['สมาร์ทโฟน'],
#   ['ระบบปฏิบัติการ', 'os', 'cpu', 'ระบบปฏิบัติการ', 'android', '8.0', 'oreo'],
#   ['หน่วยประมวลผล', 'qualcomm', 'snapdragon', '450', 'octa', 'core'],
#   ['แบรนด์', 'ซัมซุง'],
#   ['sku', '289402378', 'th', '479508064'],
#   ['โมเดล',
#    'samsung',
#    'j',
#    '8',
#    'ram',
#    '3',
#    '32',
#    'gb',
#    'เครื่องศูนย์ประกันมีเดือน',
#    'สีทอง',
#    'แถมฟรี',
#    'เคสใส',
#    'ฟิลม์กระจก'],
#   ['ระยะเวลาการรับประกัน', '3', 'เดือน'],
#   ['ระบบปฏิบัติการ', 'android']],
#  'category_0_32': [['xiaomi',
#    'redmi',
#    'note',
#    '8',
#    '3',
#    'gb',
#    '32',
#    'gb',
#    'สมาร์ตโฟน',
#    '4',
#    'กล้อง',
#    'ai',
#    'ความละเอียด',
#    '48',
#    'ล้านพิกเซล',
#    'จอกว้าง',
#    '6.3',
#    'นิ้ว',
#    'fhd',
#    'ชิปเซ็ต',
#    'qualcomm',
#    'sd',
#    '665',
#    '฿',
#    '4299.00',
#    '฿',
#    '4999.00',
#    '14',
#    'เปอร์เซนต์'],
#   ['samsung',
#    'wireless',
#    'battery',
#    'pack',
#    '10000',
#    'mah',
#    'พาวเวอร์แบงค์',
#    'แบตเตอรี่',
#    'สำรอง',
#    '฿',
#    '1290.00',
#    '฿',
#    '1590.00',
#    '19',
#    'เปอร์เซนต์'],
#   ['samsung',
#    'galaxy',
#    'tab',
#    's',
#    '4',
#    '10.5',
#    '4',
#    'gb',
#    'ram',
#    '64',
#    'gb',
#    'rom',
#    '10.5',
#    'นิ้ว',
#    'แท็บเล็ต',
#    '฿',
#    '13990.00',
#    '฿',
#    '23900.00',
#    '41',
#    'เปอร์เซนต์']],
#  'category_0_33': [['โทรศัพท์มือถือและแท็บเล็ต'],
#   ['สมาร์ทโฟน'],
#   ['แบรนด์', 'new'],
#   ['แบรนด์', 'ซัมซุง'],
#   ['sku', '612014873', 'th', '1155486191'],
#   ['ระบบปฏิบัติการ', 'เวอร์ชัน', 'android', '8.1', 'oreo'],
#   ['โมเดล', 'samsung', 'galaxy', 'note', '10', 'plus'],
#   ['ระยะเวลาการรับประกัน', '1', 'ปี']],
#  'category_0_34': [['โทรศัพท์มือถือและแท็บเล็ต'],
#   ['สมาร์ทโฟน'],
#   ['2', 'ซิมการ์ด'],
#   ['จอแสดงผล',
#    'super',
#    'amoled',
#    '24',
#    'bit',
#    '16',
#    'ล้านสี',
#    'ระบบ',
#    'สัมผัส',
#    'multi',
#    'touch',
#    '6.4',
#    'นิ้ว',
#    'แนวทะแยง',
#    'ความละเอียด',
#    '2960',
#    'x',
#    '1440',
#    'พิกเซล',
#    'capacitive',
#    'corning',
#    'gorilla',
#    'glass',
#    '5',
#    'ระบบ',
#    'ป้องกันฝุ่นละออง',
#    'resistance',
#    'dust'],
#   ['ระบบ',
#    'เซ็นเซอร์',
#    'sensor',
#    'ระบบ',
#    'ตรวจสอบลายนิ้วมือ',
#    'finger',
#    'print',
#    'ระบบ',
#    'จดจำใบหน้า',
#    'face',
#    'detection',
#    'ระบบ',
#    'หมุนภาพอัติโนมัติ',
#    'accelerometer',
#    'ระบบ',
#    'ปิดหน้าจออัตโนมัติขณะสนทนา',
#    'proximity',
#    'ระบบ',
#    'เซ็นเซอร์หมุนภาพ',
#    'gyroscope',
#    'ระบบ',
#    'วัดความกดอากาศ',
#    'barometer',
#    's',
#    'pen',
#    'ระบบ',
#    'ปากกาอัจฉริยะ',
#    'ระบบ',
#    'สแกนม่านตา'],
#   ['ระบบปฏิบัติการ', 'android', '8.1', 'oreo'],
#   ['หน่วยประมวลผล',
#    'exynos',
#    '9810',
#    'octa',
#    'core',
#    'ความเร็ว',
#    '2.7',
#    'ghz'],
#   ['การ์ดหน่วยความจำ', 'รองรับ', 'ได้สูงสุด', '512', 'gb'],
#   ['usb', 'type', 'c'],
#   ['กล้องดิจิตอล',
#    '12',
#    '12',
#    'ล้านพิกเซล',
#    'dual',
#    'camera',
#    'ซูมออฟติคอล',
#    '2',
#    '2',
#    'x',
#    'optical',
#    'zoom',
#    'โฟกัสอัตโนมัติ',
#    'auto',
#    'focus',
#    'แตะเลือกจุดโฟกัส',
#    'touch',
#    'focus',
#    'ระบบ',
#    'ป้องกัยภาพสั่นไหวแบบออปติคอล',
#    'ols',
#    'ค้นหาใบหน้าแบบอัตโนมัติ',
#    'face',
#    'detection',
#    'โหมดถ่ายภาพพาโนรามา',
#    'panorama'],
#   ['กล้องหน้า', 'front', 'camera', 'ความละเอียด', '8', 'ล้านพิกเซล'],
#   ['ระบบ', 'เสียง', 'dolby', 'atmos'],
#   ['ระบบ', 'ชาร์จไร้สาย', 'wireless', 'charge'],
#   ['แบตเตอรี่', 'มาตรฐาน', '4000', 'mah', 'standard', 'battery'],
#   ['แบรนด์', 'ซัมซุง'],
#   ['sku', '283658415', 'th', '461387419'],
#   ['โมเดล',
#    'samsung',
#    'galaxy',
#    'note',
#    '9',
#    '6',
#    'gb',
#    '128',
#    'gb',
#    'เครื่องศูนย์',
#    'มีประกัน',
#    'midnight',
#    'black',
#    'ระ'],
#   ['ระยะเวลาการรับประกัน', '1', 'ปี'],
#   ['ระบบปฏิบัติการ', 'android']],
#  'category_0_35': [['โทรศัพท์มือถือและแท็บเล็ต'],
#   ['สมาร์ทโฟน'],
#   ['แบรนด์', 'new', 'samsung', 'galaxy', 's', '10', 'plus', '128', 'gb'],
#   ['แบรนด์', 'new'],
#   ['แบรนด์', 'ซัมซุง'],
#   ['sku', '610820644', 'th', '1151996547'],
#   ['ระบบปฏิบัติการ', 'เวอร์ชัน', 'android', '8.0', 'oreo'],
#   ['โมเดล', 'samsung', 'galaxy', 's', '10', 'plus'],
#   ['ระยะเวลาการรับประกัน', '1', 'ปี']],
#  'category_0_36': [['โทรศัพท์มือถือและแท็บเล็ต'],
#   ['สมาร์ทโฟน'],
#   ['samsung',
#    'galaxy',
#    'note',
#    '9',
#    '8',
#    'gb',
#    '512',
#    'gb',
#    'แบรนด์',
#    'new',
#    'original',
#    'packaging',
#    'undamaged',
#    'unopened',
#    'unused',
#    'item',
#    'original',
#    'packaging',
#    'found',
#    'retail',
#    'store',
#    'unless',
#    'item',
#    'handmade',
#    'packaged',
#    'manufacturer',
#    'non',
#    'retail',
#    'packaging',
#    'unprinted',
#    'box',
#    'plastic',
#    'bag'],
#   ['แบรนด์', 'ซัมซุง'],
#   ['sku', '617168251', 'th', '1172664402'],
#   ['ระบบปฏิบัติการ', 'เวอร์ชัน', 'android', '9.0', 'pie'],
#   ['โมเดล', 'samsung', 'galaxy', 'note', '9', '8', 'gb', '512', 'gb'],
#   ['ระยะเวลาการรับประกัน', '1', 'ปี']],
#  'category_0_37': [['samsung',
#    'galaxy',
#    '30',
#    '4',
#    'gb',
#    'ram',
#    '64',
#    'gb',
#    'rom',
#    '6.4',
#    'นิ้ว',
#    '3',
#    'กล้อง',
#    '16',
#    'ล้านพิกเซล',
#    'ff',
#    'f',
#    '2.0',
#    'โทรศัพท์มือถือ',
#    '฿',
#    '5990.00',
#    '฿',
#    '7290.00',
#    '18',
#    'เปอร์เซนต์'],
#   ['samsung',
#    'galaxy',
#    'tab',
#    's',
#    '6',
#    '6',
#    'gb',
#    '128',
#    'gb',
#    'แท็บเล็ต',
#    '฿',
#    '23900.00',
#    '฿',
#    '25900.00',
#    '8',
#    'เปอร์เซนต์'],
#   ['โทรศัพท์ซัมซุง',
#    'galaxy',
#    'รุ่น',
#    's',
#    '9',
#    'plus',
#    '256',
#    'gb',
#    'สีฟ้า',
#    '฿',
#    '7900.00',
#    '฿',
#    '13590.00',
#    '42',
#    'เปอร์เซนต์'],
#   ['samsung',
#    'galaxy',
#    'tab',
#    's',
#    '5',
#    'e',
#    '10.5',
#    'แท็บเล็ต',
#    '฿',
#    '14490.00',
#    '฿',
#    '18990.00',
#    '24',
#    'เปอร์เซนต์']],
#  'category_0_38': [['โทรศัพท์มือถือและแท็บเล็ต'],
#   ['สมาร์ทโฟน'],
#   ['samsung',
#    'galaxy',
#    '30',
#    '4',
#    'gb',
#    'ram',
#    '64',
#    'gb',
#    'rom',
#    '6.4',
#    'นิ้ว',
#    '3',
#    'กล้อง',
#    '16',
#    'ล้านพิกเซล',
#    'ff',
#    'f',
#    '2.0',
#    'โทรศัพท์มือถือ'],
#   ['หน้าจอ',
#    'samoled',
#    'full',
#    'จอแสดงผล',
#    'ไร้กรอบ',
#    'ไร้ปุ่มโฮม',
#    'เพิ่มมุมมองการเห็น',
#    'ด้วยสัดส่วน',
#    '19.5',
#    '9',
#    'จอกว้างขึ้น',
#    'พร้อมความละเอียด',
#    'fhd',
#    'เพื่อการชมภาพยนตร์ที่เต็มอิ่มมากขึ้น'],
#   ['เลนส์หลัก',
#    '16',
#    'ล้านพิกเซล',
#    'tetra',
#    'cell',
#    'f',
#    '1.7',
#    'ถ่ายภาพชัด',
#    'ทั้งแสงน้อย',
#    'แสงมาก',
#    'scene',
#    'optimizer',
#    'กล้องอัจฉริยะ',
#    'วิเคราะห์ฉาก',
#    'และวัตถุได้',
#    '19',
#    'ชนิด',
#    'เพื่อปรับสี',
#    'และคอนทราสให้เหมาะกับวัตถุและภาพที่ถ่ายแบบอัตโนมัติ'],
#   ['เลนส์',
#    'ultra',
#    'wide',
#    'ล้านพิกเซล',
#    'f',
#    '2.2',
#    'ถ่ายภาพมุมกว้าง',
#    'เก็บได้ครบถึง',
#    '123',
#    'องศา',
#    'ได้เหมือนตามนุษย์'],
#   ['surrond',
#    'sound',
#    'effect',
#    'dolby',
#    'atmos',
#    'x',
#    'เมื่อใส่หูฟังเท่านั้น'],
#   ['แบรนด์', 'ซัมซุง'],
#   ['sku', '299990648', 'th', '515722325'],
#   ['โมเดล', 'galaxy', '30', '4', '64', 'gb'],
#   ['ระยะเวลาการรับประกัน', '1', 'ปี']],
#  'category_0_39': [['โทรศัพท์มือถือและแท็บเล็ต'],
#   ['สมาร์ทโฟน'],
#   ['กล้องคู่สำหรับทุกช่วงเวลาสำคัญ'],
#   ['แบรนด์', 'ซัมซุง'],
#   ['sku', '408012228', 'th', '792604544'],
#   ['โมเดล', 'galaxy', '10', 's', '2', '32', 'gb'],
#   ['ระยะเวลาการรับประกัน', '1', 'ปี']],
#  'category_0_40': [['โทรศัพท์มือถือและแท็บเล็ต'],
#   ['สมาร์ทโฟน'],
#   ['หน้าจอ',
#    '5.45',
#    'นิ้ว',
#    'ความละเอียด',
#    'hd',
#    '1440',
#    'x',
#    '720',
#    'พิกเซล'],
#   ['ระบบปฏิบัติการ', 'android', '9', 'pie', 'ครอบทับด้วย', 'miui', '10'],
#   ['gpu', 'adreno', '505'],
#   ['rom', '16', 'gb', 'microsd', '256', 'gb'],
#   ['กล้องหลัง', '13', 'ล้านพิกเซล', 'f', '2.2', '1.12', 'm', 'led', 'flash'],
#   ['กล้องหน้า', '5', 'ล้านพิกเซล'],
#   ['face', 'unlock'],
#   ['แบตเตอรี่',
#    'ความจุ',
#    '4000',
#    'mah',
#    'รองรับ',
#    'การชาร์จ',
#    '5',
#    'v',
#    '2',
#    'micro',
#    'usb'],
#   ['dual', 'sim', '4', 'g', 'lte'],
#   ['wi',
#    'fi',
#    '802.11',
#    'b',
#    'g',
#    'n',
#    '2.4',
#    'ghz',
#    'wifi',
#    'direct',
#    'wifi',
#    'จอแสดงผล',
#    'hotspot'],
#   ['usb', '2.0', 'usb', 'go'],
#   ['ขนาด',
#    'ตัวเครื่อง',
#    '146.30',
#    'x',
#    '70.41',
#    'x',
#    '9.55',
#    'มม.',
#    'หนัก',
#    '165',
#    'กรัม'],
#   ['แบรนด์', 'xiaomi'],
#   ['sku', '213755551', 'th', '1138512951'],
#   ['กล้องหน้า', 'ล้านพิกเซล', '5', '6', 'ล้านพิกเซล'],
#   ['ระบบปฏิบัติการ', 'เวอร์ชัน', 'android', '9.0', 'pie'],
#   ['โมเดล', 'xiaomi', 'redmi', '7', '2', '32', 'gb'],
#   ['ขนาดหน้าจอ', 'นิ้ว', '5.45'],
#   ['กล้องด้านหลัง', '11', '1', 'ล้านพิกเซล'],
#   ['ระยะเวลาการรับประกัน', '1', 'ปี'],
#   ['ระบบปฏิบัติการ', 'android'],
#   ['ความจุแบตเตอรี่', '1000', 'mah', '5000', 'mah']],
#  'category_0_41': [['โทรศัพท์มือถือและแท็บเล็ต'],
#   ['สมาร์ทโฟน'],
#   ['4', 'กล้อง', 'ai', 'ความละเอียด', '4', 'ล้านพิกเซล'],
#   ['แบตเตอรี่', 'ความจุ', '4000', 'mah'],
#   ['รองรับ', 'ระบบ'],
#   ['จอแสดงผล', 'dot', 'drop'],
#   ['แบรนด์', 'xiaomi'],
#   ['sku', '222527681', 'th', '889412058'],
#   ['กล้องหน้า', 'ล้านพิกเซล', '1', 'ล้านพิกเซล'],
#   ['ระบบปฏิบัติการ', 'เวอร์ชัน', 'android', '9.0', 'pie'],
#   ['โมเดล', 'xiaomi', 'redmi', 'note', '8'],
#   ['กล้องด้านหลัง', '2', 'ล้านพิกเซล', 'ขึ้นไป'],
#   ['ระยะเวลาการรับประกัน', '1', 'ปี'],
#   ['ความจุแบตเตอรี่', '4000', '4999', 'mah']],
#  'category_0_42': [['โทรศัพท์มือถือและแท็บเล็ต'],
#   ['สมาร์ทโฟน'],
#   ['สินค้าพร้อมส่ง',
#    'ฟรี',
#    'mi',
#    'air',
#    'purifier',
#    '2',
#    'xiaomi',
#    'mi',
#    'note',
#    '10',
#    '6',
#    '128',
#    'gb',
#    'สมาร์ทโฟน',
#    'กล้อง',
#    '5',
#    'ตัว',
#    'ความละเอียด',
#    '10',
#    'ล้านพิกเซล',
#    'รับประกันศูนย์ไทย',
#    '15',
#    'เดือน'],
#   ['แบรนด์', 'xiaomi'],
#   ['sku', '595884854', 'th', '1119120013'],
#   ['ระบบปฏิบัติการ', 'เวอร์ชัน', 'android', '9.0', 'pie'],
#   ['โมเดล', 'mi', 'note', '10'],
#   ['ระยะเวลาการรับประกัน', '15', 'เดือน']],
#  'category_0_43': [['โทรศัพท์มือถือและแท็บเล็ต'],
#   ['สมาร์ทโฟน'],
#   ['ตัวเครื่องมี',
#    'ขนาด',
#    '156.48',
#    'x',
#    '75.41',
#    'x',
#    '9.',
#    'มม.',
#    'และมี',
#    'น้ำหนัก',
#    '188',
#    'กรัม'],
#   ['หน้า',
#    'จอแสดงผล',
#    'dot',
#    'notch',
#    'จอแสดงผล',
#    'ขนาด',
#    '6.22',
#    'นิ้ว',
#    'ในอัตราส่วน',
#    '19',
#    '9',
#    'ความละเอียดระดับ',
#    'hd',
#    '720',
#    'x',
#    '1520',
#    'พิกเซล',
#    '270',
#    'ppi',
#    'ครอบทับด้วยกระจกขอบโค้งแบบ',
#    '2.5',
#    'd',
#    'corning',
#    'gorilla',
#    'glass',
#    '5'],
#   ['หน่วยประมวลผล', 'กราฟิก', 'gpu', 'adreno', '505'],
#   ['หน่วยความจำ', 'แรม', 'ram', 'ขนาด', '4', 'gb'],
#   ['หน่วยความจำภายใน',
#    'rom',
#    'ขนาด',
#    '64',
#    'gb',
#    'รองรับ',
#    'การ์ดหน่วยความจำภายนอกแบบ',
#    'microsd',
#    'สูงสุดที่',
#    'ขนาด',
#    '512',
#    'gb'],
#   ['กล้องดิจิทัลด้านหลังแบบคู่',
#    'ai',
#    'dual',
#    'camera',
#    'ความละเอียด',
#    '12',
#    'ล้านพิกเซล',
#    'เซ็นเซอร์รับภาพ',
#    'sony',
#    'imx',
#    '363',
#    'พิกเซล',
#    'ขนาด',
#    '1.4',
#    'ไมครอน',
#    'ขนาด',
#    'รูรับแสง',
#    'f',
#    '1.8',
#    'กล้องตัวที่สองเลนส์',
#    'depth',
#    'ความละเอียด',
#    '2',
#    'ล้านพิกเซล',
#    'รองรับ',
#    'เทคโนโลยี',
#    'dual',
#    'pd',
#    'ai',
#    'portrait',
#    'ai',
#    'scene',
#    'detection',
#    'ในการตรวจจับซีนทั้งหมด',
#    '33',
#    'หมวดหมู่'],
#   ['กล้องดิจิทัลด้านหน้า',
#    'ai',
#    'ความละเอียด',
#    '8',
#    'ล้านพิกเซล',
#    'พิกเซล',
#    'ขนาด',
#    '1.12',
#    'ไมครอน',
#    'ขนาด',
#    'รูรับแสง',
#    'f',
#    '2.0',
#    'รองรับ',
#    'เทคโนโลยี',
#    'ai',
#    'selfie',
#    'portrait'],
#   ['แบตเตอรี่',
#    'ความจุ',
#    '5000',
#    'mah',
#    'พร้อมเทคโนโลยีชาร์จไว',
#    '18',
#    'w',
#    'fast',
#    'charging'],
#   ['ระบบปฏิบัติการ', 'android', '9.0', 'pie'],
#   ['ระบบ', 'สแกนใบหน้า', 'face', 'unlock'],
#   ['รองรับ', 'การใช้งานพร้อมกัน', '2', 'ซิมการ์ด', 'dual', 'sim'],
#   ['รองรับ', 'ถาดใส่ซิมการ์ดแบบ', 'triple', 'slot'],
#   ['รองรับ', 'การใช้งานบนเครือข่าย', '4', 'g', 'lte'],
#   ['รองรับ',
#    'การเชื่อมต่อ',
#    'wi',
#    'fi',
#    '802.11',
#    'b',
#    'g',
#    'n',
#    'bluetooth',
#    '4.2'],
#   ['รองรับ', 'การเชื่อมต่อแบบ', 'usb', 'type', 'c'],
#   ['แบรนด์', 'xiaomi'],
#   ['sku', '611154425', 'th', '1152864043'],
#   ['กล้องหน้า', 'ล้านพิกเซล', '7', 'ล้านพิกเซล', 'ขึ้นไป'],
#   ['ระบบปฏิบัติการ', 'เวอร์ชัน', 'android', '9.0', 'pie'],
#   ['โมเดล', 'xiaomi', 'redmi', '8', '3', '32', 'gb'],
#   ['ขนาดหน้าจอ', 'นิ้ว', '6.22'],
#   ['กล้องด้านหลัง', '11', '1', 'ล้านพิกเซล'],
#   ['ระยะเวลาการรับประกัน', '15', 'เดือน'],
#   ['ความจุแบตเตอรี่', '1000', 'mah', '5000', 'mah']],
#  'category_0_44': [['โทรศัพท์มือถือและแท็บเล็ต'],
#   ['สมาร์ทโฟน'],
#   ['xiaomi',
#    'mi',
#    '9',
#    't',
#    'pro',
#    'เสียวหมี่',
#    'ram',
#    '6',
#    'rom',
#    '64',
#    'gb',
#    'จอ',
#    '6.39',
#    'นิ้ว',
#    'กล้องดิจิตอล',
#    '4',
#    'ล้านพิกเซล',
#    'ล้านพิกเซล',
#    'telephoto',
#    '1',
#    'ล้านพิกเซล',
#    'triple',
#    'camera',
#    'แถมเคส',
#    'ประกันศูนย์ไทย'],
#   ['สมาร์ทโฟน', 'โทรศัพท์มือถือพร้อม', 'ระบบปฏิบัติการ'],
#   ['จอแสดงผล',
#    'amoled',
#    '24',
#    'bit',
#    '16',
#    'ล้านสี',
#    'จอแสดงผล',
#    'hdr',
#    'ระบบ',
#    'สัมผัส',
#    'multi',
#    'touch',
#    '6.39',
#    'นิ้ว',
#    'แนวทะแยง',
#    'ความละเอียด',
#    '2340',
#    'x',
#    '1080',
#    'พิกเซล',
#    '403',
#    'ppi',
#    'capacitive',
#    'corning',
#    'gorilla',
#    'glass',
#    '5'],
#   ['ระบบ',
#    'เซ็นเซอร์',
#    'sensor',
#    'ระบบ',
#    'สแกนลายนิ้วมือใต้หน้าจอ',
#    'fingerprint',
#    'จอแสดงผล',
#    'ระบบ',
#    'หมุนภาพอัตโนมัติ',
#    'accelerometer',
#    'ตรวจจับแสงปรับความสว่างอัตโนมัติ',
#    'ambient',
#    'light',
#    'ระบบ',
#    'ปิดหน้าจออัตโนมัติขณะสนทนา',
#    'proximity',
#    'ระบบ',
#    'เซนเซอร์หมุนภาพ',
#    'gyroscope',
#    'ปรับมุมมองการแสดงผลอัตโนมัติ',
#    'orientation'],
#   ['2', 'ซิมการ์ด'],
#   ['ระบบปฏิบัติการ', 'miui', '10', 'based', 'android', '9.0', 'pie'],
#   ['หน่วยประมวลผล',
#    'qualcomm',
#    'snapdragon',
#    '855',
#    'octa',
#    'core',
#    'ความเร็ว',
#    '2.84',
#    'ghz'],
#   ['การหาตำแหน่ง', 'assisted', 'gps', 'รองรับ', 'แอพพลิเคชั่น', 'egps'],
#   ['nfc', 'near', 'field', 'communication'],
#   ['type', 'c', 'usb', '3.1'],
#   ['รองรับ', 'การถ่ายโอนข้อมูลกับ', 'flash', 'drive', 'โดยตรง', 'usb', 'go'],
#   ['กล้องดิจิตอล',
#    '4',
#    'ล้านพิกเซล',
#    'ล้านพิกเซล',
#    'telephoto',
#    '1',
#    'ล้านพิกเซล',
#    'ultra',
#    'wide',
#    'angle',
#    'triple',
#    'camera',
#    'รูรับแสง',
#    'ขนาด',
#    '1.75',
#    'ไฟแฟลช',
#    'dual',
#    'led',
#    'ซูมดิจิตอล',
#    '10',
#    '10',
#    'x',
#    'digital',
#    'zoom',
#    'ซูมออฟติคอล',
#    '2',
#    '2',
#    'x',
#    'optical',
#    'zoom',
#    'ขนาด',
#    'ภาพสูงสุด',
#    '8000',
#    'x',
#    '6000',
#    'พิกเซล',
#    'image',
#    'size',
#    'โฟกัสอัตโนมัติ',
#    'auto',
#    'focus',
#    'โหมดฉาก',
#    'บุคคล',
#    'เวลากลางคืน',
#    'ค้นหาใบหน้าอัตโนมัติ',
#    'face',
#    'detection',
#    'เทคโนโลยีถ่ายภาพอัจฉริยะ',
#    'ai',
#    'camera',
#    'โหมดปรับหน้าสวยอัตโนมัติ',
#    'ai',
#    'face',
#    'beauty',
#    'ตั้งเวลาถ่ายภาพอัตโนมัติ',
#    'self',
#    'timer',
#    'โหมดถ่ายภาพพาโนราม่า',
#    'panorama'],
#   ['กล้องหน้า',
#    'front',
#    'camera',
#    'ความละเอียด',
#    '20',
#    'ล้านพิกเซล',
#    'ไฟแฟลช',
#    'led',
#    'รูรับแสง',
#    'ขนาด',
#    '2.2',
#    'video',
#    'call',
#    'สนทนาแบบเห็นภาพ',
#    'กล้องหน้า',
#    'hdr',
#    'กล้องหน้า',
#    'portrait',
#    'กล้องหน้า',
#    'pop'],
#   ['บันทึกวีดีโอ',
#    'ภาพเคลื่อนไหว',
#    'video',
#    'recording',
#    'ความละเอียด',
#    'hd',
#    '3840',
#    'x',
#    '2160',
#    'พิกเซล',
#    'บันทึกวีดีโอ',
#    '4',
#    'k',
#    '60',
#    'เฟรมต่อวินาที',
#    'slow',
#    'motion'],
#   ['เครื่องเล่นวีดีโอ',
#    'video',
#    'player',
#    'รูปแบบไฟล์',
#    'ล้านพิกเซล',
#    'eg',
#    '4',
#    'h',
#    '.',
#    '264',
#    'xvid',
#    'm',
#    '4',
#    'v',
#    'mkv',
#    'วีดีโอสตรีมมิ่ง',
#    '3',
#    'gp',
#    'avi',
#    'ล้านพิกเซล',
#    '4',
#    'rm',
#    'รองรับ',
#    'วีดีโอจาก',
#    'youtube'],
#   ['รองรับ', 'ไฟล์รูปภาพ', 'jpg', 'jpeg', 'bmp', 'gif', 'tiff'],
# ...
#    '014',
#    'black',
#    '15.6',
#    'full',
#    'hd',
#    'ips',
#    '144',
#    'hz',
#    'amd',
#    'ryzen',
#    '5',
#    '3550',
#    'h',
#    'ram',
#    '8',
#    'gb',
#    'ssd',
#    '512',
#    'gb',
#    'amd',
#    'radeon',
#    'rx',
#    '560',
#    'x',
#    '4',
#    'gb',
#    'gddr',
#    '5',
#    'win',
#    '10',
#    'รับประกันศูนย์',
#    'acer',
#    '3',
#    'ปี',
#    'คอมพิวเตอร์',
#    'pc',
#    'เกมมิ่งโน้ตบุ๊ค',
#    'ส่งเร็ว',
#    '฿',
#    '15900.00',
#    '฿',
#    '21990.00',
#    '28',
#    'เปอร์เซนต์'],
#   ['โน้ตบุ๊คและแท็บเล็ต',
#    'lenovo',
#    '2',
#    '1',
#    'ideapad',
#    'd',
#    '330',
#    '10',
#    'igm',
#    '81',
#    'h',
#    '3005',
#    'ata',
#    'wifi',
#    'celeron',
#    'n',
#    '4000',
#    '10.1',
#    'inch',
#    'ram',
#    '4',
#    'gb',
#    'lpddr',
#    '4',
#    '2133',
#    'integrated',
#    'graphic',
#    '64',
#    'gb',
#    'emmc',
#    'win',
#    '10',
#    'รับประกันศูนย์',
#    'lenovo',
#    '1',
#    'ปี',
#    'mineral',
#    'gray',
#    'free',
#    'active',
#    'pen',
#    'โน๊ตบุ๊คถูก',
#    'ผ่อน',
#    '0',
#    'เปอร์เซนต์',
#    '10',
#    'เดือน',
#    'ส่งเร็ว',
#    '฿',
#    '9490.00',
#    '฿',
#    '12990.00',
#    '27',
#    'เปอร์เซนต์']],
#  'category_4_90': [['hp',
#    'notebook',
#    '14',
#    'cm',
#    '0112',
#    'au',
#    '6',
#    'nh',
#    '17',
#    'pa',
#    'amd',
#    '9',
#    '9125',
#    '14',
#    'inch',
#    '4',
#    'gb',
#    '500',
#    'gb',
#    'hdd',
#    'windows',
#    '10',
#    'home',
#    'amd',
#    'radeon',
#    'r',
#    '3',
#    'graphics',
#    '2',
#    'years',
#    'hp',
#    'warranty',
#    'โน๊ตบุ๊ค',
#    'คอมพิวเตอร์',
#    'โน๊ตบุ๊คถูกๆ',
#    'notebook',
#    '฿',
#    '7990.00',
#    '฿',
#    '8990.00',
#    '11',
#    'เปอร์เซนต์'],
#   ['โน๊ตบุ๊ค',
#    'notebook',
#    'acer',
#    'nitro',
#    '515',
#    '54',
#    '566',
#    'm',
#    'nh',
#    '.',
#    'q',
#    '5',
#    'ast',
#    '.',
#    '003',
#    '15.6',
#    'ips',
#    'fhd',
#    '5',
#    '9300',
#    'h',
#    'ram',
#    '8',
#    'gb',
#    'ddr',
#    '4',
#    'hdd',
#    '1',
#    'tb',
#    '7200',
#    'rpm',
#    'gtx',
#    '1050',
#    '3',
#    'gb',
#    'gddr',
#    '5',
#    'dvd',
#    'win',
#    '10',
#    'รับประกันศูนย์',
#    'acer',
#    '3',
#    'ปี',
#    'black',
#    'คอมพิวเตอร์',
#    'โน๊ตบุ๊คถูกๆ',
#    'เกมมิ่งโน้ตบุ๊ค',
#    'ผ่อน',
#    '0',
#    'เปอร์เซนต์',
#    '10',
#    'เดือน',
#    'ส่งเร็ว',
#    '฿',
#    '20789.00',
#    '฿',
#    '25990.00',
#    '20',
#    'เปอร์เซนต์'],
#   ['ระบบ',
#    'window',
#    '10',
#    'ระบบ',
#    'ของภาษาไทย',
#    'แถมฟรี',
#    'สติ๊กเกอร์ติดแป้นพิมพ์',
#    'คอมพิวเตอร์โน๊ตบุ๊ค',
#    'แล็ปท็อป',
#    'notebook',
#    'intel',
#    'z',
#    '8350',
#    'led',
#    '15.6',
#    'นิ่ว',
#    '1920',
#    'x',
#    '1080',
#    'ips',
#    'ram',
#    '4',
#    'g',
#    'ssd',
#    'm',
#    '.',
#    '2',
#    '64',
#    'g',
#    'สามารถตั้งค่าภาษาไทย',
#    '฿',
#    '5920.00',
#    '฿',
#    '14980.00',
#    '60',
#    'เปอร์เซนต์'],
#   ['แล็ปท็อปโน้ตบุ๊คคอมพิวเตอร์โน๊ตบุ๊ค',
#    'slim',
#    'สีดำของขวัญทำงาน',
#    'supply',
#    '฿',
#    '12115.00',
#    '฿',
#    '40383.00',
#    '70',
#    'เปอร์เซนต์']],
#  'category_4_91': [['คอมพิวเตอร์', 'แล็ปท็อป'],
#   ['แล็ปท็อป'],
#   ['แล็ปท็อปสำหรับเล่นเกมส์']],
#  'category_4_92': [['คอมพิวเตอร์', 'แล็ปท็อป'],
#   ['แล็ปท็อป'],
#   ['แล็ปท็อปสำหรับเล่นเกมส์']],
#  'category_4_93': [['คอมพิวเตอร์', 'แล็ปท็อป'],
#   ['แล็ปท็อป'],
#   ['แล็ปท็อปสำหรับเล่นเกมส์']],
#  'category_4_94': [['คอมพิวเตอร์', 'แล็ปท็อป'],
#   ['แล็ปท็อป'],
#   ['แล็ปท็อปสำหรับเล่นเกมส์']],
#  'category_4_95': [['คอมพิวเตอร์', 'แล็ปท็อป'],
#   ['แล็ปท็อป'],
#   ['แล็ปท็อปสำหรับเล่นเกมส์']],
#  'category_4_96': [['คอมพิวเตอร์', 'แล็ปท็อป'],
#   ['แล็ปท็อป'],
#   ['แล็ปท็อปสำหรับเล่นเกมส์']],
#  'category_4_97': [['คอมพิวเตอร์', 'แล็ปท็อป'],
#   ['แล็ปท็อป'],
#   ['แล็ปท็อปสำหรับเล่นเกมส์']],
#  'category_4_98': [['คอมพิวเตอร์', 'แล็ปท็อป'],
#   ['แล็ปท็อป'],
#   ['แล็ปท็อปสำหรับเล่นเกมส์']],
#  'category_4_99': [['คอมพิวเตอร์', 'แล็ปท็อป'],
#   ['แล็ปท็อป'],
#   ['แล็ปท็อปสำหรับเล่นเกมส์']],
#  'category_4_100': [['คอมพิวเตอร์', 'แล็ปท็อป'],
#   ['แล็ปท็อป'],
#   ['แล็ปท็อปสำหรับเล่นเกมส์']],
#  'category_4_101': [['คอมพิวเตอร์', 'แล็ปท็อป'],
#   ['แล็ปท็อป'],
#   ['แล็ปท็อปสำหรับเล่นเกมส์']],
#  'category_4_102': [['คอมพิวเตอร์', 'แล็ปท็อป'],
#   ['แล็ปท็อป'],
#   ['แล็ปท็อปสำหรับเล่นเกมส์']],
#  'category_4_103': [['คอมพิวเตอร์', 'แล็ปท็อป'],
#   ['แล็ปท็อป'],
#   ['แล็ปท็อปสำหรับเล่นเกมส์']],
#  'category_4_104': [['โน้ตบุ๊ค',
#    'gaming',
#    'notebook',
#    'acer',
#    'nitro',
#    '5',
#    '515',
#    '43',
#    'r',
#    '1',
#    'n',
#    '1',
#    'nh',
#    '.',
#    'q',
#    '5',
#    'xst',
#    '.',
#    '014',
#    'black',
#    '15.6',
#    'full',
#    'hd',
#    'ips',
#    '144',
#    'hz',
#    'amd',
#    'ryzen',
#    '5',
#    '3550',
#    'h',
#    'ram',
#    '8',
#    'gb',
#    'ssd',
#    '512',
#    'gb',
#    'amd',
#    'radeon',
#    'rx',
#    '560',
#    'x',
#    '4',
#    'gb',
#    'gddr',
#    '5',
#    'win',
#    '10',
#    'รับประกันศูนย์',
#    'acer',
#    '3',
#    'ปี',
#    'คอมพิวเตอร์',
#    'pc',
#    'เกมมิ่งโน้ตบุ๊ค',
#    'ส่งเร็ว',
#    '฿',
#    '15900.00',
#    '฿',
#    '21990.00',
#    '28',
#    'เปอร์เซนต์'],
#   ['โน้ตบุ๊คและแท็บเล็ต',
#    'lenovo',
#    '2',
#    '1',
#    'ideapad',
#    'd',
#    '330',
#    '10',
#    'igm',
#    '81',
#    'h',
#    '3005',
#    'ata',
#    'wifi',
#    'celeron',
#    'n',
#    '4000',
#    '10.1',
#    'inch',
#    'ram',
#    '4',
#    'gb',
#    'lpddr',
#    '4',
#    '2133',
#    'integrated',
#    'graphic',
#    '64',
#    'gb',
#    'emmc',
#    'win',
#    '10',
#    'รับประกันศูนย์',
#    'lenovo',
#    '1',
#    'ปี',
#    'mineral',
#    'gray',
#    'free',
#    'active',
#    'pen',
#    'โน๊ตบุ๊คถูก',
#    'ผ่อน',
#    '0',
#    'เปอร์เซนต์',
#    '10',
#    'เดือน',
#    'ส่งเร็ว',
#    '฿',
#    '9490.00',
#    '฿',
#    '12990.00',
#    '27',
#    'เปอร์เซนต์']],
#  'category_4_105': [['ระบบ',
#    'window',
#    '10',
#    'ระบบ',
#    'ของภาษาไทย',
#    'แถมฟรี',
#    'สติ๊กเกอร์ติดแป้นพิมพ์',
#    'คอมพิวเตอร์โน๊ตบุ๊ค',
#    'แล็ปท็อป',
#    'notebook',
#    'intel',
#    'z',
#    '8350',
#    'led',
#    '15.6',
#    'นิ่ว',
#    '1920',
#    'x',
#    '1080',
#    'ips',
#    'ram',
#    '4',
#    'g',
#    'ssd',
#    'm',
#    '.',
#    '2',
#    '64',
#    'g',
#    'สามารถตั้งค่าภาษาไทย',
#    '฿',
#    '5920.00',
#    '฿',
#    '14980.00',
#    '60',
#    'เปอร์เซนต์'],
#   ['โน๊ตบุ๊ค',
#    'notebook',
#    'acer',
#    'nitro',
#    '515',
#    '54',
#    '566',
#    'm',
#    'nh',
#    '.',
#    'q',
#    '5',
#    'ast',
#    '.',
#    '003',
#    '15.6',
#    'ips',
#    'fhd',
#    '5',
#    '9300',
#    'h',
#    'ram',
#    '8',
#    'gb',
#    'ddr',
#    '4',
#    'hdd',
#    '1',
#    'tb',
#    '7200',
#    'rpm',
#    'gtx',
#    '1050',
#    '3',
#    'gb',
#    'gddr',
#    '5',
#    'dvd',
#    'win',
#    '10',
#    'รับประกันศูนย์',
#    'acer',
#    '3',
#    'ปี',
#    'black',
#    'คอมพิวเตอร์',
#    'โน๊ตบุ๊คถูกๆ',
#    'เกมมิ่งโน้ตบุ๊ค',
#    'ผ่อน',
#    '0',
#    'เปอร์เซนต์',
#    '10',
#    'เดือน',
#    'ส่งเร็ว',
#    '฿',
#    '20789.00',
#    '฿',
#    '25990.00',
#    '20',
#    'เปอร์เซนต์'],
#   ['hp',
#    'notebook',
#    '14',
#    'cm',
#    '0112',
#    'au',
#    '6',
#    'nh',
#    '17',
#    'pa',
#    'amd',
#    '9',
#    '9125',
#    '14',
#    'inch',
#    '4',
#    'gb',
#    '500',
#    'gb',
#    'hdd',
#    'windows',
#    '10',
#    'home',
#    'amd',
#    'radeon',
#    'r',
#    '3',
#    'graphics',
#    '2',
#    'years',
#    'hp',
#    'warranty',
#    'โน๊ตบุ๊ค',
#    'คอมพิวเตอร์',
#    'โน๊ตบุ๊คถูกๆ',
#    'notebook',
#    '฿',
#    '7990.00',
#    '฿',
#    '8990.00',
#    '11',
#    'เปอร์เซนต์'],
#   ['แล็ปท็อปโน้ตบุ๊คคอมพิวเตอร์โน๊ตบุ๊ค',
#    'slim',
#    'สีดำของขวัญทำงาน',
#    'supply',
#    '฿',
#    '12115.00',
#    '฿',
#    '40383.00',
#    '70',
#    'เปอร์เซนต์']],
#  'category_4_106': [['คอมพิวเตอร์', 'แล็ปท็อป'],
#   ['แล็ปท็อป'],
#   ['แล็ปท็อปสำหรับเล่นเกมส์']],
#  'category_4_107': [['คอมพิวเตอร์', 'แล็ปท็อป'],
#   ['แล็ปท็อป'],
#   ['แล็ปท็อปสำหรับเล่นเกมส์']],
#  'category_4_108': [['คอมพิวเตอร์', 'แล็ปท็อป'],
#   ['แล็ปท็อป'],
#   ['แล็ปท็อปสำหรับเล่นเกมส์']],
#  'category_4_109': [['คอมพิวเตอร์', 'แล็ปท็อป'],
#   ['แล็ปท็อป'],
#   ['แล็ปท็อปสำหรับเล่นเกมส์']],
#  'category_4_110': [['คอมพิวเตอร์', 'แล็ปท็อป'],
#   ['แล็ปท็อป'],
#   ['แล็ปท็อปสำหรับเล่นเกมส์']],
#  'category_4_111': [['คอมพิวเตอร์', 'แล็ปท็อป'],
#   ['แล็ปท็อป'],
#   ['แล็ปท็อปสำหรับเล่นเกมส์']],
#  'category_4_112': [['คอมพิวเตอร์', 'แล็ปท็อป'],
#   ['แล็ปท็อป'],
#   ['แล็ปท็อปสำหรับเล่นเกมส์']],
#  'category_4_113': [['โน้ตบุ๊ค',
#    'gaming',
#    'notebook',
#    'acer',
#    'nitro',
#    '5',
#    '515',
#    '43',
#    'r',
#    '1',
#    'n',
#    '1',
#    'nh',
#    '.',
#    'q',
#    '5',
#    'xst',
#    '.',
#    '014',
#    'black',
#    '15.6',
#    'full',
#    'hd',
#    'ips',
#    '144',
#    'hz',
#    'amd',
#    'ryzen',
#    '5',
#    '3550',
#    'h',
#    'ram',
#    '8',
#    'gb',
#    'ssd',
#    '512',
#    'gb',
#    'amd',
#    'radeon',
#    'rx',
#    '560',
#    'x',
#    '4',
#    'gb',
#    'gddr',
#    '5',
#    'win',
#    '10',
#    'รับประกันศูนย์',
#    'acer',
#    '3',
#    'ปี',
#    'คอมพิวเตอร์',
#    'pc',
#    'เกมมิ่งโน้ตบุ๊ค',
#    'ส่งเร็ว',
#    '฿',
#    '15900.00',
#    '฿',
#    '21990.00',
#    '28',
#    'เปอร์เซนต์'],
#   ['โน้ตบุ๊คและแท็บเล็ต',
#    'lenovo',
#    '2',
#    '1',
#    'ideapad',
#    'd',
#    '330',
#    '10',
#    'igm',
#    '81',
#    'h',
#    '3005',
#    'ata',
#    'wifi',
#    'celeron',
#    'n',
#    '4000',
#    '10.1',
#    'inch',
#    'ram',
#    '4',
#    'gb',
#    'lpddr',
#    '4',
#    '2133',
#    'integrated',
#    'graphic',
#    '64',
#    'gb',
#    'emmc',
#    'win',
#    '10',
#    'รับประกันศูนย์',
#    'lenovo',
#    '1',
#    'ปี',
#    'mineral',
#    'gray',
#    'free',
#    'active',
#    'pen',
#    'โน๊ตบุ๊คถูก',
#    'ผ่อน',
#    '0',
#    'เปอร์เซนต์',
#    '10',
#    'เดือน',
#    'ส่งเร็ว',
#    '฿',
#    '9490.00',
#    '฿',
#    '12990.00',
#    '27',
#    'เปอร์เซนต์']],
#  'category_4_114': [['คอมพิวเตอร์', 'แล็ปท็อป'],
#   ['แล็ปท็อป'],
#   ['แล็ปท็อปสำหรับเล่นเกมส์']],
#  'category_4_115': [['คอมพิวเตอร์', 'แล็ปท็อป'],
#   ['แล็ปท็อป'],
#   ['แล็ปท็อปสำหรับเล่นเกมส์']],
#  'category_4_116': [['คอมพิวเตอร์', 'แล็ปท็อป'],
#   ['แล็ปท็อป'],
#   ['แล็ปท็อปสำหรับเล่นเกมส์']],
#  'category_4_117': [['ระบบ',
#    'window',
#    '10',
#    'ระบบ',
#    'ของภาษาไทย',
#    'แถมฟรี',
#    'สติ๊กเกอร์ติดแป้นพิมพ์',
#    'คอมพิวเตอร์โน๊ตบุ๊ค',
#    'แล็ปท็อป',
#    'notebook',
#    'intel',
#    'z',
#    '8350',
#    'led',
#    '15.6',
#    'นิ่ว',
#    '1920',
#    'x',
#    '1080',
#    'ips',
#    'ram',
#    '4',
#    'g',
#    'ssd',
#    'm',
#    '.',
#    '2',
#    '64',
#    'g',
#    'สามารถตั้งค่าภาษาไทย',
#    '฿',
#    '5920.00',
#    '฿',
#    '14980.00',
#    '60',
#    'เปอร์เซนต์'],
#   ['โน๊ตบุ๊ค',
#    'notebook',
#    'acer',
#    'nitro',
#    '515',
#    '54',
#    '566',
#    'm',
#    'nh',
#    '.',
#    'q',
#    '5',
#    'ast',
#    '.',
#    '003',
#    '15.6',
#    'ips',
#    'fhd',
#    '5',
#    '9300',
#    'h',
#    'ram',
#    '8',
#    'gb',
#    'ddr',
#    '4',
#    'hdd',
#    '1',
#    'tb',
#    '7200',
#    'rpm',
#    'gtx',
#    '1050',
#    '3',
#    'gb',
#    'gddr',
#    '5',
#    'dvd',
#    'win',
#    '10',
#    'รับประกันศูนย์',
#    'acer',
#    '3',
#    'ปี',
#    'black',
#    'คอมพิวเตอร์',
#    'โน๊ตบุ๊คถูกๆ',
#    'เกมมิ่งโน้ตบุ๊ค',
#    'ผ่อน',
#    '0',
#    'เปอร์เซนต์',
#    '10',
#    'เดือน',
#    'ส่งเร็ว',
#    '฿',
#    '20789.00',
#    '฿',
#    '25990.00',
#    '20',
#    'เปอร์เซนต์'],
#   ['hp',
#    'notebook',
#    '14',
#    'cm',
#    '0112',
#    'au',
#    '6',
#    'nh',
#    '17',
#    'pa',
#    'amd',
#    '9',
#    '9125',
#    '14',
#    'inch',
#    '4',
#    'gb',
#    '500',
#    'gb',
#    'hdd',
#    'windows',
#    '10',
#    'home',
#    'amd',
#    'radeon',
#    'r',
#    '3',
#    'graphics',
#    '2',
#    'years',
#    'hp',
#    'warranty',
#    'โน๊ตบุ๊ค',
#    'คอมพิวเตอร์',
#    'โน๊ตบุ๊คถูกๆ',
#    'notebook',
#    '฿',
#    '7990.00',
#    '฿',
#    '8990.00',
#    '11',
#    'เปอร์เซนต์'],
#   ['apple',
#    'airpods',
#    'charging',
#    'case',
#    '2019',
#    'โมเดล',
#    'หูฟังไร้สาย',
#    'bluetooth',
#    '฿',
#    '4890.00',
#    '฿',
#    '6500.00',
#    '25',
#    'เปอร์เซนต์']],
#  'category_4_118': [['คอมพิวเตอร์', 'แล็ปท็อป'],
#   ['แล็ปท็อป'],
#   ['แล็ปท็อปสำหรับเล่นเกมส์']],
#  'category_4_119': [['คอมพิวเตอร์', 'แล็ปท็อป'],
#   ['แล็ปท็อป'],
#   ['แล็ปท็อปสำหรับเล่นเกมส์']],
#  'category_4_120': [['คอมพิวเตอร์', 'แล็ปท็อป'],
#   ['แล็ปท็อป'],
#   ['แล็ปท็อปสำหรับเล่นเกมส์']],
#  'category_4_121': [['คอมพิวเตอร์', 'แล็ปท็อป'],
#   ['แล็ปท็อป'],
#   ['แล็ปท็อปสำหรับเล่นเกมส์']],
#  'category_4_122': [['คอมพิวเตอร์', 'แล็ปท็อป'],
#   ['แล็ปท็อป'],
#   ['แล็ปท็อปสำหรับเล่นเกมส์']],
#  'category_4_123': [['คอมพิวเตอร์', 'แล็ปท็อป'],
#   ['แล็ปท็อป'],
#   ['แล็ปท็อปสำหรับเล่นเกมส์']],
#  'category_4_124': [['คอมพิวเตอร์', 'แล็ปท็อป'],
#   ['แล็ปท็อป'],
#   ['แล็ปท็อปสำหรับเล่นเกมส์']],
#  'category_4_125': [['คอมพิวเตอร์', 'แล็ปท็อป'],
#   ['แล็ปท็อป'],
#   ['แล็ปท็อปสำหรับเล่นเกมส์']],
#  'category_4_126': [['คอมพิวเตอร์', 'แล็ปท็อป'],
#   ['แล็ปท็อป'],
#   ['แล็ปท็อปสำหรับเล่นเกมส์']],
#  'category_4_127': [['คอมพิวเตอร์', 'แล็ปท็อป'],
#   ['แล็ปท็อป'],
#   ['แล็ปท็อปสำหรับเล่นเกมส์']],
#  'category_4_128': [['คอมพิวเตอร์', 'แล็ปท็อป'],
#   ['แล็ปท็อป'],
#   ['แล็ปท็อปสำหรับเล่นเกมส์']],
#  'category_4_129': [['คอมพิวเตอร์', 'แล็ปท็อป'],
#   ['แล็ปท็อป'],
#   ['แล็ปท็อปสำหรับเล่นเกมส์']],
#  'category_4_130': [['คอมพิวเตอร์', 'แล็ปท็อป'],
#   ['แล็ปท็อป'],
#   ['แล็ปท็อปสำหรับเล่นเกมส์']],
#  'category_4_131': [['คอมพิวเตอร์', 'แล็ปท็อป'],
#   ['แล็ปท็อป'],
#   ['แล็ปท็อปสำหรับเล่นเกมส์']],
#  'category_4_132': [['โน้ตบุ๊ค',
#    'gaming',
#    'notebook',
#    'acer',
#    'nitro',
#    '5',
#    '515',
#    '43',
#    'r',
#    '1',
#    'n',
#    '1',
#    'nh',
#    '.',
#    'q',
#    '5',
#    'xst',
#    '.',
#    '014',
#    'black',
#    '15.6',
#    'full',
#    'hd',
#    'ips',
#    '144',
#    'hz',
#    'amd',
#    'ryzen',
#    '5',
#    '3550',
#    'h',
#    'ram',
#    '8',
#    'gb',
#    'ssd',
#    '512',
#    'gb',
#    'amd',
#    'radeon',
#    'rx',
#    '560',
#    'x',
#    '4',
#    'gb',
#    'gddr',
#    '5',
#    'win',
#    '10',
#    'รับประกันศูนย์',
#    'acer',
#    '3',
#    'ปี',
#    'คอมพิวเตอร์',
#    'pc',
#    'เกมมิ่งโน้ตบุ๊ค',
#    'ส่งเร็ว',
#    '฿',
#    '15900.00',
#    '฿',
#    '21990.00',
#    '28',
#    'เปอร์เซนต์'],
#   ['โน้ตบุ๊คและแท็บเล็ต',
#    'lenovo',
#    '2',
#    '1',
#    'ideapad',
#    'd',
#    '330',
#    '10',
#    'igm',
#    '81',
#    'h',
#    '3005',
#    'ata',
#    'wifi',
#    'celeron',
#    'n',
#    '4000',
#    '10.1',
#    'inch',
#    'ram',
#    '4',
#    'gb',
#    'lpddr',
#    '4',
#    '2133',
#    'integrated',
#    'graphic',
#    '64',
#    'gb',
#    'emmc',
#    'win',
#    '10',
#    'รับประกันศูนย์',
#    'lenovo',
#    '1',
#    'ปี',
#    'mineral',
#    'gray',
#    'free',
#    'active',
#    'pen',
#    'โน๊ตบุ๊คถูก',
#    'ผ่อน',
#    '0',
#    'เปอร์เซนต์',
#    '10',
#    'เดือน',
#    'ส่งเร็ว',
#    '฿',
#    '9490.00',
#    '฿',
#    '12990.00',
#    '27',
#    'เปอร์เซนต์']],
#  'category_4_133': [['คอมพิวเตอร์', 'แล็ปท็อป'],
#   ['แล็ปท็อป'],
#   ['แล็ปท็อปสำหรับเล่นเกมส์']],
#  'category_4_134': [['คอมพิวเตอร์', 'แล็ปท็อป'],
#   ['แล็ปท็อป'],
#   ['แล็ปท็อปสำหรับเล่นเกมส์']],
#  'category_4_135': [['คอมพิวเตอร์', 'แล็ปท็อป'],
#   ['แล็ปท็อป'],
#   ['แล็ปท็อปสำหรับเล่นเกมส์']],
#  'category_4_136': [['คอมพิวเตอร์', 'แล็ปท็อป'],
#   ['แล็ปท็อป'],
#   ['แล็ปท็อปสำหรับเล่นเกมส์']],
#  'category_4_137': [['คอมพิวเตอร์', 'แล็ปท็อป'],
#   ['แล็ปท็อป'],
#   ['แล็ปท็อปสำหรับเล่นเกมส์']],
#  'category_4_138': [['คอมพิวเตอร์', 'แล็ปท็อป'],
#   ['แล็ปท็อป'],
#   ['แล็ปท็อปสำหรับเล่นเกมส์']],
#  'category_4_139': [['คอมพิวเตอร์', 'แล็ปท็อป'],
#   ['แล็ปท็อป'],
#   ['แล็ปท็อปสำหรับเล่นเกมส์']],
#  'category_4_140': [['คอมพิวเตอร์', 'แล็ปท็อป'],
#   ['แล็ปท็อป'],
#   ['แล็ปท็อปสำหรับเล่นเกมส์']],
#  'category_4_141': [['คอมพิวเตอร์', 'แล็ปท็อป'],
#   ['แล็ปท็อป'],
#   ['แล็ปท็อปสำหรับเล่นเกมส์']],
#  'category_4_142': [['คอมพิวเตอร์', 'แล็ปท็อป'],
#   ['แล็ปท็อป'],
#   ['แล็ปท็อปสำหรับเล่นเกมส์']],
#  'category_4_143': [['คอมพิวเตอร์', 'แล็ปท็อป'],
#   ['แล็ปท็อป'],
#   ['แล็ปท็อปสำหรับเล่นเกมส์']],
#  'category_4_144': [['คอมพิวเตอร์', 'แล็ปท็อป'],
#   ['แล็ปท็อป'],
#   ['แล็ปท็อปสำหรับเล่นเกมส์']],
#  'category_4_145': [['คอมพิวเตอร์', 'แล็ปท็อป'],
#   ['แล็ปท็อป'],
#   ['แล็ปท็อปสำหรับเล่นเกมส์']],
#  'category_4_146': [['คอมพิวเตอร์', 'แล็ปท็อป'],
#   ['แล็ปท็อป'],
#   ['แล็ปท็อปสำหรับเล่นเกมส์']],
#  'category_4_147': [['คอมพิวเตอร์', 'แล็ปท็อป'],
#   ['แล็ปท็อป'],
#   ['แล็ปท็อปสำหรับเล่นเกมส์']],
#  'category_4_148': [['คอมพิวเตอร์', 'แล็ปท็อป'],
#   ['แล็ปท็อป'],
#   ['แล็ปท็อปสำหรับเล่นเกมส์']],
#  'category_4_149': [['คอมพิวเตอร์', 'แล็ปท็อป'],
#   ['แล็ปท็อป'],
#   ['แล็ปท็อปสำหรับเล่นเกมส์']],
#  'category_4_150': [['คอมพิวเตอร์', 'แล็ปท็อป'],
#   ['แล็ปท็อป'],
#   ['แล็ปท็อปสำหรับเล่นเกมส์']],
#  'category_4_151': [['คอมพิวเตอร์', 'แล็ปท็อป'],
#   ['แล็ปท็อป'],
#   ['แล็ปท็อปสำหรับเล่นเกมส์']],
#  'category_4_152': [['คอมพิวเตอร์', 'แล็ปท็อป'],
#   ['แล็ปท็อป'],
#   ['แล็ปท็อปสำหรับเล่นเกมส์']],
#  'category_4_153': [['คอมพิวเตอร์', 'แล็ปท็อป'],
#   ['แล็ปท็อป'],
#   ['แล็ปท็อปสำหรับเล่นเกมส์']],
#  'category_4_154': [['คอมพิวเตอร์', 'แล็ปท็อป'],
#   ['แล็ปท็อป'],
#   ['แล็ปท็อปสำหรับเล่นเกมส์']],
#  'category_4_155': [['คอมพิวเตอร์', 'แล็ปท็อป'],
#   ['แล็ปท็อป'],
#   ['แล็ปท็อปสำหรับเล่นเกมส์']],
#  ...}

# %% [markdown]
# # Capture attribute of product by regex

# %%
def cap_attr(text):
    m = re.match("([ก-ฮa-z]+)\:\s?([ก-๙a-z0-9]+)",text)
    if m:
        yield text
    elif re.match("sku\:\s+[t]?[h]?\s*\d*",text):
        yield text
    else:
        m = re.search("([ก-๙a-z]+)\:\s?([ก-๙a-z0-9]+)",text)
        if m is not None:
            p = re.findall("([^:\s]*):\s?([^:\s]*)",text)
            yield p

# %%
attr = {}
for i,v in data_clean.items():
    tmp_list = []
    for txt in v:
        match = cap_attr(txt)
        for x in match:
            tmp_list.append(x)
    attr[i] = tmp_list

# %%
attr
# Out:
# {'category_0_0': [[('แรม', '4'), ('รอม', '64')],
#   'sku: 480942616 th 870640886'],
#  'category_0_1': [[('แรม', '4')],
#   'sku: 593772364 th 1113954823',
#   [('แรม', '512mb')],
#   [('ความจุแบตเตอรี่', '1000')]],
#  'category_0_2': ['sku: 404422189 th 784670279',
#   [('แรม', '2gb')],
#   [('ความจุแบตเตอรี่', '1000')]],
#  'category_0_3': ['sku: 385536916 th 749070165'],
#  'category_0_4': [[('2g', 'edge'), ('3g', 'hspa'), ('4g', 'lte')],
#   [('ระบบปฏิบัติการ', 'android')],
#   [('แรม', '3gb')],
#   [('การหาตำแหน่ง', 'assisted')]],
#  'category_0_5': [[('แรม', '128'), ('รอม', '6.3')],
#   [('จอแสดงผล', 'กว้าง')],
#   'sku: 265390897 th 412154584'],
#  'category_0_6': [[('รอม', '64')],
#   [('รอม', '64gb')],
#   [('2g', 'edge')],
#   [('จอแสดงผล', 'ตรวจจับความเคลื่อนไหวของตัวเครื่อง')],
#   'sku: 594352438 th 1115888431',
#   [('ความจุแบตเตอรี่', '1000')]],
#  'category_0_7': ['sku: 599364278 th 1176694583'],
#  'category_0_8': ['sku: 309636084 th 547152150'],
#  'category_0_9': [[('แรม', '2'), ('รอม', '32')],
#   'sku: 571250946 th 1048780375',
#   [('แรม', '2'), ('รอม', '32')],
#   [('ความจุแบตเตอรี่', '1000')]],
#  'category_0_10': [[('2g', 'edge'), ('3g', 'hspa'), ('4g', 'lte')],
#   [('ระบบปฏิบัติการ', 'android')],
#   [('แรม', '3gb')],
#   [('การหาตำแหน่ง', 'assisted')]],
#  'category_0_11': ['sku: sa861elaa8nxs2anth 17866375', [('แรม', '3gb')]],
#  'category_0_12': ['sku: 526004055 th 942110374'],
#  'category_0_13': [[('แรม', '2'), ('รอม', '32')],
#   'sku: 571320012 th 1048806072',
#   [('แรม', '2'), ('รอม', '32')],
#   [('ความจุแบตเตอรี่', '1000')]],
#  'category_0_14': [[('แรม', '2gb')],
#   'sku: 594306208 th 1115720937',
#   [('ความจุแบตเตอรี่', '1000')]],
#  'category_0_15': [[('แรม', '64'), ('รอม', '6.4')]],
#  'category_0_16': [[('แรม', '128'), ('รอม', '6.1')],
#   'sku: 289434461 th 479544867'],
#  'category_0_17': [[('น้ำหนัก', 'ยาว')],
#   [('ชนิดจอ', 'จอสัมผัส'), ('ความละเอียด', '6.5')],
#   [('จอแสดงผล', 'ขนาด'), ('19.5', '9')],
#   [('แรม', '3'), ('รอม', '32'), ('', 'micro')],
#   'sku: 594338092 th 1115814517',
#   [('ความจุแบตเตอรี่', '1000')]],
#  'category_0_18': ['sku: 340860812 th 661136678',
#   [('แรม', '8gb')],
#   [('ความจุแบตเตอรี่', '3000')]],
#  'category_0_19': [[('2g', 'edge'), ('3g', 'hspa')],
#   [('ระบบปฏิบัติการ', 'android')],
#   [('รอม', '128gb'), ('แรม', '6gb')],
#   'sku: 283666353 th 461390461'],
#  'category_0_20': ['sku: 616572478 th 1170962904'],
#  'category_0_21': ['sku: 307684896 th 537048806'],
#  'category_0_22': ['sku: 373972071 th 728742055'],
#  'category_0_23': ['sku: 310302392 th 552106447'],
#  'category_0_24': [[('จอแสดงผล', 'กว้าง')],
#   'sku: 280354579 th 453591358',
#   [('แรม', '6gb')],
#   [('ความจุแบตเตอรี่', '1000')]],
#  'category_0_25': [[('แรม', '8')],
#   [('จอแสดงผล', 'ระบบจดจำใบหน้า'),
#    ('ระบบปฏิบัติการ', 'android'),
#    ('', 'snapdragon'),
#    ('', '2.0'),
#    ('รอม', '128gb'),
#    ('แรม', '8gbการ์ดหน่วยความจำ'),
#    ('', 'ล้านพิกเซล'),
#    ('', 'ล้านพิกเซล'),
#    ('', 'ล้านพิกเซล')],
#   'sku: 595150747 th 1117932783'],
#  'category_0_26': [[('จอแสดงผล', 'samoled')],
#   'sku: 264741378 th 411062149',
#   [('แรม', '4gb')]],
#  'category_0_27': [[('แรม', 'original')],
#   [('แรม', 'original'), ('แบรนด์', 'new')],
#   'sku: 617108827 th 1172618764',
#   [('แรม', 'original')]],
#  'category_0_28': ['sku: 511068392 th 907938105'],
#  'category_0_29': [[('แรม', '4gb')],
#   [('แรม', '4gb')],
#   'sku: 207916690 th 313021622'],
#  'category_0_30': [[('แรม', '128'), ('รอม', '6.4')],
#   'sku: 289426638 th 479560515'],
#  'category_0_31': [[('แรม', '3')],
#   [('ระบบปฏิบัติการ', 'android')],
#   'sku: 289402378 th 479508064',
#   [('แรม', '3')]],
#  'category_0_32': [[('แรม', '6'), ('รอม', '128gb')],
#   [('แรม', '64'), ('รอม', '10.5')]],
#  'category_0_33': [[('แบรนด์', 'new')], 'sku: 612014873 th 1155486191'],
#  'category_0_34': [[('3g', 'hspa')],
#   [('รอม', '128gb')],
#   'sku: 283658415 th 461387419'],
#  'category_0_35': [[('แบรนด์', 'new')],
#   [('แบรนด์', 'new')],
#   'sku: 610820644 th 1151996547'],
#  'category_0_36': [[('แบรนด์', 'new')], 'sku: 617168251 th 1172664402'],
#  'category_0_37': [[('แรม', '64'), ('รอม', '6.4')]],
#  'category_0_38': [[('แรม', '64'), ('รอม', '6.4')],
#   [('จอแสดงผล', 'ไร้กรอบ'), ('19.5', '9')],
#   'sku: 299990648 th 515722325'],
#  'category_0_39': ['sku: 408012228 th 792604544'],
#  'category_0_40': [[('', 'wi'), ('จอแสดงผล', 'hotspot')],
#   'sku: 213755551 th 1138512951',
#   [('แรม', '2gb')],
#   [('ความจุแบตเตอรี่', '1000')]],
#  'category_0_41': ['sku: 222527681 th 889412058',
#   [('แรม', '4gb')],
#   [('ความจุแบตเตอรี่', '4000')]],
#  'category_0_42': ['sku: 595884854 th 1119120013'],
#  'category_0_43': [[('จอแสดงผล', 'ขนาด'), ('19', '9'), ('', '270')],
#   'sku: 611154425 th 1152864043',
#   [('แรม', '4gb')],
#   [('ความจุแบตเตอรี่', '1000')]],
#  'category_0_44': [[('แรม', '6')],
#   [('จอแสดงผล', 'ระบบหมุนภาพอัตโนมัติ')],
#   [('2g', 'edge')],
#   [('ระบบปฏิบัติการ', 'miui')],
#   [('แรม', '6'), ('รอม', '64')],
#   [('การหาตำแหน่ง', 'assisted')]],
#  'category_0_45': [[('แรม', '64'), ('รอม', '10.5')],
#   [('แรม', '4'), ('รอม', '64')]],
#  'category_0_46': [[('รอม', '64')],
#   'sku: 533460461 th 963560027',
#   [('แรม', '4gb')],
#   [('ความจุแบตเตอรี่', '1000')]],
#  'category_0_47': ['sku: 495988905 th 884338021',
#   [('แรม', '3gb')],
#   [('ความจุแบตเตอรี่', '1000')]],
#  'category_0_48': [[('2g', 'edge')],
#   [('ระบบปฏิบัติการ', 'miui')],
#   [('แรม', '6')],
#   [('รอม', '128gb')]],
#  'category_0_49': ['sku: 234902116 th 713640836',
#   [('ความจุแบตเตอรี่', '4000')]],
#  'category_0_50': ['sku: 494026300 th 882746256'],
#  'category_0_51': [[('แรม', '6'), ('รอม', '128')],
#   [('แรม', '6gb'), ('รอม', '128gb')],
#   [('ขนาดความสูง', '157.8'), ('ความกว้าง', '74.2'), ('ความหนา', '9.67')],
#   [('น้ำหนัก', '208')],
#   'sku: 604332862 th 1137128463'],
#  'category_0_52': [[('แรม', '8gb')],
#   [('รอม', '256gb')],
#   'sku: 611792752 th 1155040122'],
#  'category_0_53': [[('กล้องด้านหน้า', '20.ล้านพิกเซล')],
#   'sku: 343546977 th 668396557'],
#  'category_0_54': [[('แรม', '6'), ('รอม', '128gb')]],
#  'category_0_55': ['sku: 587988556 th 1092062042',
#   [('แรม', '3gb')],
#   [('ความจุแบตเตอรี่', '1000')]],
#  'category_0_56': [[('แรม', '4')],
#   [('2g', 'edge')],
#   [('ระบบปฏิบัติการ', 'miui')],
#   [('แรม', '4gb'), ('รอม', '64gb')],
#   'sku: 526910733 th 944832734',
#   [('แรม', '4gb')],
#   [('ความจุแบตเตอรี่', '1000')]],
#  'category_0_57': ['sku: 221761904 th 931764445',
#   [('แรม', '4gb')],
#   [('ความจุแบตเตอรี่', '4000')]],
#  'category_0_58': [[('แรม', '128gb'), ('รอม', '3g')],
#   [('แรม', '64'), ('รอม', '10.5')]],
#  'category_0_59': [[('รอม', '128gb')],
#   [('รอม', '128gb')],
#   'sku: 595984523 th 1119224437'],
#  'category_0_60': [[('แรม', '4')],
#   [('จอแสดงผล', 'กว้าง')],
#   [('2g', 'edge')],
#   [('ระบบปฏิบัติการ', 'miui')],
#   [('แรม', '3'), ('รอม', '32')],
#   [('การหาตำแหน่ง', 'assisted')],
#   'sku: 612338298 th 1156318935'],
#  'category_0_61': [[('แรม', '32gb'), ('รอม', 'dualcameras')],
#   [('dualcameras', 'frontcamera16.ล้านพิกเซล')],
#   'sku: 615188295 th 1166414603',
#   [('แรม', '3gb')],
#   [('ความจุแบตเตอรี่', '3000')]],
#  'category_0_62': [[('แรม', '2')],
#   [('2g', 'edge')],
#   [('ระบบปฏิบัติการ', 'miui')],
#   [('แรม', '2'), ('รอม', '32gb')],
#   [('การหาตำแหน่ง', 'assisted')],
#   'sku: 524454971 th 937876465'],
#  'category_0_63': [[('รอม', '128gb')],
#   [('coreความถี่', 'สูงสุด')],
#   [('ความละเอียด', '2340')],
#   'sku: 600264311 th 1129088854',
#   [('แรม', '6gb')],
#   [('ความจุแบตเตอรี่', '5000')]],
#  'category_0_64': [[('แรม', '4'), ('รอม', '64')],
#   [('แรม', '6'), ('รอม', '128gb')]],
#  'category_0_65': ['sku: 273675979 th 909150212',
#   [('แรม', '6gb')],
#   [('ความจุแบตเตอรี่', '4000')]],
#  'category_0_66': ['sku: 602338133 th 1134472444',
#   [('แรม', '6gb')],
#   [('ความจุแบตเตอรี่', '4000')]],
#  'category_0_67': [[('แรม', '128gb'), ('รอม', '3g')],
#   [('แรม', '64'), ('รอม', '10.5')]],
#  'category_0_68': ['sku: 602306922 th 1134540658',
#   [('แรม', '6gb')],
#   [('ความจุแบตเตอรี่', '4000')]],
#  'category_0_69': [[('ระบบปฏิบัติการ', 'android')],
#   'sku: 594522639 th 1116438503',
#   [('ความจุแบตเตอรี่', '3000')]],
#  'category_0_70': [[('2g', 'edge')],
#   [('ระบบปฏิบัติการ', 'miui')],
#   [('แรม', '2')],
#   [('รอม', '16')]],
#  'category_0_71': [[('2g', 'edge')],
#   [('ระบบปฏิบัติการ', 'miui')],
#   [('แรม', '2')],
#   [('รอม', '32gb')]],
#  'category_0_72': [[('2g', 'edge')],
#   [('ระบบปฏิบัติการ', 'miui')],
#   [('แรม', '4'), ('รอม', '64')],
#   [('การหาตำแหน่ง', 'assisted')],
#   'sku: 477810714 th 868398689',
#   [('แรม', '32gb'), ('รอม', '')]],
#  'category_0_73': [[('ระบบปฏิบัติการ', 'android')],
#   'sku: 594600147 th 1116542821',
#   [('ความจุแบตเตอรี่', '3000')]],
#  'category_0_74': ['sku: 587986529 th 1092060094',
#   [('แรม', '6gb')],
#   [('ความจุแบตเตอรี่', '1000')]],
#  'category_0_75': [[('จอแสดงผล', 'ระบบหมุนภาพอัตโนมัติ')],
#   [('ระบบปฏิบัติการ', 'miui')],
#   [('รอม', '64'), ('แรม', '6')],
#   [('2g', 'edge')],
#   [('การหาตำแหน่ง', 'assisted')],
#   'sku: 264227445 th 791158102'],
#  'category_0_76': [[('แรม', '4'), ('รอม', '64')],
#   [('แรม', '6'), ('รอม', '128gb')]],
#  'category_0_77': [[('2g', 'edge')],
#   [('ระบบปฏิบัติการ', 'miui')],
#   [('แรม', '2'), ('รอม', '16')],
#   [('การหาตำแหน่ง', 'assisted')]],
#  'category_0_78': [[('รอม', '8gb'), ('แรม', '')],
#   [('รอม', '8gb'), ('แรม', 'it'), ('แบรนด์', 'new')],
#   'sku: 617148976 th 1172758996',
#   [('รอม', '8gb'), ('แรม', '')]],
#  'category_0_79': [[('ชิปประมวลผลรุ่นเรือธงcpu', 'snapdragon')],
#   [('cpu', 'สถาปัตยกรรม')],
#   [('cpu', 'ชิปประมวลผลระดับ')],
#   [('qualcomm', '1')],
#   [('cpu', '45เปอร์เซนต์')],
#   [('พัฒนาความสามารถ', '40เปอร์เซนต์')],
#   'gpu: adreno 640',
#   [('gpu', '20เปอร์เซนต์')],
#   [('พัฒนาความสามารถ', '25เปอร์เซนต์')],
#   [('aie', 'ตัวประมวล')],
#   [('จอแสดงผล', 'มัลติคัลเลอร์')],
#   [('9ram', 'ช่องสัญญาณคู่')],
#   'rom: พื้นที่เก็บข้อมูลแฟลช 64gb 128gb ufs2.1 หน่วยความจำและขนาดแรม ram ที่ใช้จริงจะน้อยกว่าที่ระบุไว้ เนื่องจากปัจจัยการใช้งานต่างๆของระบบ พื้นที่เก็บข้อมูลจริง rom จะน้อยกว่าที่ระบุไว้ เนื่องจากการใช้งานของข้อมูลของระบบจอแสดงผล6.39 samsung amoled full screen จอแสดงผล: 6.39 samsung amoled full screen จอแสดงผล: ',
#   [('ความละเอียด', '2340')],
#   [('ความสว่าง', '600nit')],
#   [('ความคมชัดสูง', '60000'), ('', '1'), ('gamut', 'ntsc')],
#   [('ซูม', 'ซูม')]],
#  'category_0_80': [[('แรม', '3gb')],
#   'sku: 601804919 th 1133136752',
#   [('แรม', '3gb')],
#   [('ความจุแบตเตอรี่', '1000')]],
#  'category_0_81': [[('แรม', '4gb'), ('รอม', '64gb')],
#   'sku: 594172715 th 1115450949'],
#  'category_0_82': ['sku: 368406522 th 720230984'],
#  'category_0_83': ['sku: 596522329 th 1119982547'],
#  'category_0_84': [[('แรม', '3'), ('รอม', '64')],
#   'sku: 561194526 th 1029420220',
#   [('แรม', '3gb')],
#   [('ความจุแบตเตอรี่', '5000')]],
#  'category_0_85': ['sku: 594468094 th 1116094894',
#   [('แรม', '6gb')],
#   [('ความจุแบตเตอรี่', '1000')]],
#  'category_0_86': ['sku: 463662961 th 851448786',
#   [('ความจุแบตเตอรี่', '1000')]],
#  'category_0_87': ['sku: 535266417 th 967736081'],
#  'category_0_88': ['sku: 423372568 th 807510964'],
#  'category_0_89': ['sku: 585868817 th 1085346089',
#   [('แรม', '3gb')],
#   [('ความจุแบตเตอรี่', '1000')]],
#  'category_0_90': [[('แรม', '8'), ('รอม', '128')],
#   'sku: 560716580 th 1028340869',
#   [('แรม', '8gb')],
#   [('ความจุแบตเตอรี่', '5000')]],
#  'category_0_91': [[('', '1.'), ('camera', '12m')],
#   [('แรม', '3gb'), ('รอม', '128gb')],
#   [('box', '1.')],
#   'sku: 450862429 th 833064273',
#   [('ความจุแบตเตอรี่', '30001')]],
#  'category_0_92': [[('รอม', '64gb')],
#   [('แรม', '128gb'), ('รอม', '3g')],
#   [('แรม', '64'), ('รอม', '10.5')]],
#  'category_0_93': [[('2g', 'edge'), ('3g', 'hspa')],
#   [('ระบบปฏิบัติการ', 'colorระบบปฏิบัติการ'), ('', '5.1')],
#   [('แรม', '2')],
#   [('การหาตำแหน่ง', 'assisted')]],
#  'category_0_94': [[('ระบบปฏิบัติการ', 'colorระบบปฏิบัติการ'), ('', '5.1')],
#   [('แรม', '2gb')],
#   [('การหาตำแหน่ง', 'assisted')],
#   'sku: 247483720 th 381013589'],
#  'category_0_95': [[('colorระบบปฏิบัติการ', '5.0')],
#   [('2g', 'edge'), ('3g', 'hsdpa'), ('4g', 'lte')],
#   'sku: 602816227 th 1135834467',
#   [('แรม', '6gb')]],
#  'category_0_96': [[('แรม', '3')],
#   'gsm: 850 900 1800 1900mhz',
#   [('wcdma', 'bands')],
#   [('lte', 'bands')],
#   [('lte', 'bands')],
#   'sku: 593798249 th 1114132244',
#   [('ความจุแบตเตอรี่', '1000')]],
#  'category_0_97': ['sku: 521740370 th 929150153', [('แรม', '3gb')]],
#  'category_0_98': [[('แรม', '4'), ('รอม', '64')], [('จอแสดงผล', 'ชิปเซต')]],
#  'category_0_99': ['sku: 333366885 th 778320295'],
#  'category_0_100': [],
#  'category_0_101': [[('จอแสดงผล', ''),
#    ('', '6.2'),
#    ('colorระบบปฏิบัติการ', ''),
#    ('', 'colorระบบปฏิบัติการ'),
#    ('', '5.2.1')],
#   [('', 'mtk'),
#    ('', 'img'),
#    ('แรม', ''),
#    ('', '3gb'),
#    ('แรม', 'รอม'),
#    ('', ''),
#    ('', '32gb'),
#    ('รอม', 'up')],
#   'sku: 341378077 th 675334858',
#   [('ความจุแบตเตอรี่', '30001')]],
#  'category_0_102': [[('จอแสดงผล', 'ระบบหมุนภาพอัตโนมัติ')],
#   'sku: 561338580 th 1029522253',
#   [('แรม', '8gb')],
#   [('ความจุแบตเตอรี่', '1000')]],
#  'category_0_103': ['cpu: snapdragon 665 และ game boost 2.0',
#   'sku: 464602916 th 852566078',
#   [('ความจุแบตเตอรี่', '5000')]],
#  'category_0_104': [[('แรม', '128gb'), ('รอม', '3g')],
#   [('แรม', '64'), ('รอม', '10.5')],
#   [('รอม', '64gb')]],
#  'category_0_105': [[('2g', 'edge'), ('3g', 'hspa')],
#   [('จอแสดงผล', 'ระบบสัมผัส')],
#   [('ระบบปฏิบัติการ', 'colorระบบปฏิบัติการ'), ('', '5.2')],
#   [('รอม', '64gb'), ('แรม', '6gb')],
#   [('การหาตำแหน่ง', 'assisted')]],
#  'category_0_106': ['sku: 535274298 th 967670887',
#   [('แรม', '3gb')],
#   [('ความจุแบตเตอรี่', '1000')]],
#  'category_0_107': [[('แรม', '3')],
#   [('2g', 'edge')],
#   [('ระบบปฏิบัติการ', 'colorระบบปฏิบัติการ'), ('', '6.0.1')],
#   [('แรม', '3gb'), ('รอม', '64gb')],
#   [('การหาตำแหน่ง', 'assisted')],
#   'sku: 593006855 th 1111420743',
#   [('ความจุแบตเตอรี่', '1000')]],
#  'category_0_108': [[('แรม', '4')],
#   [('ระบบปฏิบัติการ', 'colorระบบปฏิบัติการ'), ('', '6.0'), ('', 'helio')],
#   'sku: 534116952 th 965278124',
#   [('แรม', '4')],
#   [('แรม', '4gb')],
#   [('ความจุแบตเตอรี่', '4000')]],
#  'category_0_109': [[('จอแสดงผล', 'ชิปเซต')]],
#  'category_0_110': [[('แรม', '128gb'), ('รอม', '3g')],
#   [('แรม', '64'), ('รอม', '10.5')],
#   [('รอม', '64gb')]],
#  'category_0_111': [[('จอแสดงผล', 'ชิปเซต')]],
#  'category_0_112': [[('สี', 'พังก์บลูและไอน้ำสีขาว')],
#   [('หน้าจอ', 'fhd')],
#   [('ป๊อปอัพกล้องเซลฟี่', '1ล้านพิกเซล')],
#   [('แบบคู่กล้องหลัง', '4ล้านพิกเซล')],
#   'sku: 397028849 th 771186043',
#   [('sku', 'c17722')],
#   [('แรม', '4gb')],
#   [('ความจุแบตเตอรี่', '3000')]],
#  'category_0_113': [[('แรม', '128gb'), ('รอม', '3g')],
#   [('แรม', '64'), ('รอม', '10.5')],
#   [('รอม', '64gb')]],
#  'category_0_114': [[('จอแสดงผล', 'ระบบสัมผัส')],
#   [('2g', 'edge'), ('3g', 'hspa'), ('4g', 'lte')],
#   [('ระบบปฏิบัติการ', 'colorระบบปฏิบัติการ'), ('', '5.2')],
#   [('แรม', '4'), ('รอม', '64')],
#   [('การหาตำแหน่ง', 'assisted')]],
#  'category_0_115': [[('2g', 'edge'), ('3g', 'hsdpa')],
#   [('ระบบปฏิบัติการ', 'colorระบบปฏิบัติการ'), ('', '5.2')],
#   [('แรม', '3'), ('รอม', '64gb')],
#   'sku: 348144719 th 681012331',
#   [('แรม', '4gb')]],
#  'category_0_116': [[('แรม', '3')],
#   [('2g', 'edge')],
#   [('ระบบปฏิบัติการ', 'colorระบบปฏิบัติการ'), ('', '6.0.1')],
#   [('แรม', '3gb'), ('รอม', '64gb')],
#   [('การหาตำแหน่ง', 'assisted')],
#   'sku: 601974390 th 1133472706',
#   [('แรม', '3')],
#   [('แรม', '3gb')]],
#  'category_0_117': ['sku: 563834910 th 1033632588',
#   [('แรม', '4gb')],
#   [('ความจุแบตเตอรี่', '4000')]],
#  'category_0_118': [[('แรม', '2')],
#   'sku: 612114232 th 1155648106',
#   [('แรม', '2')],
#   [('แรม', '2gb')],
#   [('ความจุแบตเตอรี่', '4000')]],
#  'category_0_119': ['sku: 594318240 th 1115776512',
#   [('ความจุแบตเตอรี่', '4000')]],
#  'category_0_120': [[('แบตเตอรี่', '5000mah')],
#   [('แบตเตอรี่', '5000mah')],
#   'sku: 517866127 th 919968463'],
#  'category_0_121': [[('รอม', '64')],
#   'sku: 590034214 th 1151538667',
#   [('แรม', '4gb')],
#   [('ความจุแบตเตอรี่', '1000')]],
#  'category_0_122': [[('แรม', '6'), ('รอม', '128gb')]],
#  'category_0_123': [[('แรม', '8'), ('รอม', '128')],
#   [('รอม', '128')],
#   'sku: 595656544 th 1118856653',
#   [('แรม', '8gb')],
#   [('ความจุแบตเตอรี่', '1000')]],
#  'category_0_124': ['sku: 587972692 th 1092032386',
#   [('แรม', '8gb')],
#   [('ความจุแบตเตอรี่', '1000')]],
#  'category_0_125': [[('รอม', '128gb')],
#   [('แรม', '128gb'), ('รอม', 'เพิ่มเมมโมเรี่ได้สูงสุด')],
#   [('funtouchระบบปฏิบัติการ', '9.2')],
#   'sku: 599192867 th 1127342158',
#   [('แรม', '8gb')],
#   [('ความจุแบตเตอรี่', '4000')]],
#  'category_0_126': [[('aและqq', 'how'),
#    ('a', 'pls'),
#    ('link', 'http'),
#    ('', 'global.cainiao.com'),
#    ('q', 'about'),
#    ('a', 'we'),
#    ('country', '1'),
#    ('link', 'willmyphonework.net'),
#    ('q', 'what'),
#    ('a', 'we'),
#    ('แบรนด์', 'new'),
#    ('แบรนด์', 'at'),
#    ('รอม', 'about'),
#    ('duty', 'we')],
#   'sku: 616436256 th 1170664199',
#   [('แรม', '8gb')],
#   [('ความจุแบตเตอรี่', '1000')]],
#  'category_0_127': [[('แรม', '128gb'), ('รอม', 'เครื่องใหม่')],
#   [('ระบบปฏิบัติการfuntouchระบบปฏิบัติการ', '9.2')],
#   [('ขนาดตัวเครื่อง', '159.25')],
#   [('น้ำหนัก', '186.7')],
#   'sku: 599066750 th 1127098963',
#   [('แรม', '128gb')]],
#  'category_0_128': [[('รอม', '128gbกล้องถ่ายรูปด้านหลัง')],
#   'sku: 612664987 th 1157674465',
#   [('แรม', '8gb')],
#   [('ความจุแบตเตอรี่', '4000')]],
#  'category_0_129': [[('จอแสดงผล', '6.53')], 'sku: 525912975 th 942022546'],
#  'category_0_130': [[('แรม', '128gb'), ('รอม', '3g')],
#   [('แรม', '64'), ('รอม', '10.5')],
#   [('รอม', '64gb')]],
#  'category_0_131': [[('แรม', '6'), ('รอม', '128gb')]],
#  'category_0_132': [[('แรม', '2')],
#   'sku: 328508874 th 629190573',
#   [('แรม', '2gb')]],
#  'category_0_133': ['q: how to track the order ',
#   'a: pls check this link:https: www.17track.net zh cn',
#   'q: about network bands',
#   'a: we add a link to show you how to check the phone whether can be used in your country: all our สมาร์ทโฟน unlocked for worldwide use but please check if your local area network is compatible with our phones you can check this link:willmyphonework.net or maps.mobileworldlive.com to see the network frequency for your country please confirm with your carriers or providers before you purchase this item.',
#   'q: what if i m dissatisfied with the product ',
#   'a: we guarantee you will be 100เปอร์เซนต์ satisfied with the quality of your product. if you re unhappy with it please contact our customer service who will be glad to help.when contacting customer service team please give your order number a short description and a photo of the problem so we can prevent these problems in the future.',
#   [('แบรนด์', 'new'), ('แบรนด์', 'at')],
#   'sku: 604588733 th 1137744184',
#   [('แรม', '6gb')],
#   [('ความจุแบตเตอรี่', '1000')]],
#  'category_0_134': [[('รอม', '128gb')],
#   [('แรม', '128gb'), ('รอม', 'เพิ่มเมมโมเรี่ได้สูงสุด')],
#   [('funtouchระบบปฏิบัติการ', '9.2')],
#   'sku: 599300858 th 1127464169',
#   [('แรม', '8gb')],
#   [('ความจุแบตเตอรี่', '4000')]],
#  'category_0_135': ['q: how to track the order ',
#   'a: pls check this link:https: www.17track.net zh cn',
#   'q: about network bands',
#   'a: we add a link to show you how to check the phone whether can be used in your country: all our สมาร์ทโฟน unlocked for worldwide use but please check if your local area network is compatible with our phones you can check this link:willmyphonework.net or maps.mobileworldlive.com to see the network frequency for your country please confirm with your carriers or providers before you purchase this item.',
#   'q: what if i m dissatisfied with the product ',
#   'a: we guarantee you will be 100เปอร์เซนต์ satisfied with the quality of your product. if you re unhappy with it please contact our customer service who will be glad to help.when contacting customer service team please give your order number a short description and a photo of the problem so we can prevent these problems in the future.',
#   [('แบรนด์', 'new'), ('แบรนด์', 'at')],
#   'sku: 604632624 th 1137814458',
#   [('แรม', '6gb')],
#   [('ความจุแบตเตอรี่', '1000')]],
#  'category_0_136': [[('แรม', '8gb'), ('รอม', '128gb')],
#   [('จอแสดงผล', 'กว้าง')],
#   [('จอแสดงผล', 'ระบบหมุนภาพอัตโนมัติ')],
#   [('2g', 'edge'), ('3g', 'hspa')],
#   [('ระบบปฏิบัติการ', 'funtouchระบบปฏิบัติการ'), ('', '9.2')],
#   [('แรม', '8gb'), ('รอม', '128gb')],
#   [('การหาตำแหน่ง', 'assisted')]],
#  'category_0_137': ['sku: 616744349 th 1171552379'],
#  'category_0_138': ['q: how to track the order ',
#   'a: pls check this link:https: www.17track.net zh cn',
#   'q: about network bands',
#   'a: we add a link to show you how to check the phone whether can be used in your country: all our สมาร์ทโฟน unlocked for worldwide use but please check if your local area network is compatible with our phones you can check this link:willmyphonework.net or maps.mobileworldlive.com to see the network frequency for your country please confirm with your carriers or providers before you purchase this item.',
#   'q: what if i m dissatisfied with the product ',
#   'a: we guarantee you will be 100เปอร์เซนต์ satisfied with the quality of your product. if you re unhappy with it please contact our customer service who will be glad to help.when contacting customer service team please give your order number a short description and a photo of the problem so we can prevent these problems in the future.',
#   [('แบรนด์', 'new'), ('แบรนด์', 'at')],
#   'sku: 604648308 th 1137718830',
#   [('แรม', '8gb')],
#   [('ความจุแบตเตอรี่', '1000')]],
#  'category_0_139': [[('รอม', '64gb')],
#   [('แรม', '64gb'), ('รอม', 'เพิ่มเมมโมเรี่ได้สูงสุด')],
#   [('จอแสดงผล', 'ขนาด')],
#   'sku: 618416957 th 1177008040',
#   [('แรม', '4gb')],
#   [('ความจุแบตเตอรี่', '5000')]],
#  'category_0_140': [[('แรม', '8gb'), ('รอม', '128gb')],
#   [('จอแสดงผล', 'fingerprint')],
#   'sku: 561416932 th 1029822407',
#   [('แรม', '8gb')],
#   [('ความจุแบตเตอรี่', '1000')]],
#  'category_0_141': ['q: how to track the order ',
#   'a: pls check this link:https: www.17track.net zh cn',
#   'q: about network bands',
#   'a: we add a link to show you how to check the phone whether can be used in your country: all our สมาร์ทโฟน unlocked for worldwide use but please check if your local area network is compatible with our phones you can check this link:willmyphonework.net or maps.mobileworldlive.com to see the network frequency for your country please confirm with your carriers or providers before you purchase this item.',
#   'q: what if i m dissatisfied with the product ',
#   'a: we guarantee you will be 100เปอร์เซนต์ satisfied with the quality of your product. if you re unhappy with it please contact our customer service who will be glad to help.when contacting customer service team please give your order number a short description and a photo of the problem so we can prevent these problems in the future.',
#   [('แบรนด์', 'new'), ('แบรนด์', 'at')],
#   'sku: 604770080 th 1138152071',
#   [('แรม', '3gb')],
#   [('ความจุแบตเตอรี่', '1000')]],
#  'category_0_142': ['q: how to track the order ',
#   'a: pls check this link:https: www.17track.net zh cn',
#   'q: about network bands',
#   'a: we add a link to show you how to check the phone whether can be used in your country: all our สมาร์ทโฟน unlocked for worldwide use but please check if your local area network is compatible with our phones you can check this link:willmyphonework.net or maps.mobileworldlive.com to see the network frequency for your country please confirm with your carriers or providers before you purchase this item.',
#   'q: what if i m dissatisfied with the product ',
#   'a: we guarantee you will be 100เปอร์เซนต์ satisfied with the quality of your product. if you re unhappy with it please contact our customer service who will be glad to help.when contacting customer service team please give your order number a short description and a photo of the problem so we can prevent these problems in the future.',
#   [('แบรนด์', 'new'), ('แบรนด์', 'at')],
#   'sku: 604694624 th 1137940704',
#   [('แรม', '6gb')],
#   [('ความจุแบตเตอรี่', '1000')]],
#  'category_0_143': [[('ระบบปฏิบัติการ', 'funtouchระบบปฏิบัติการ'), ('', '9')],
#   [('แรม', '6')],
#   [('รอม', '64')],
#   'sku: 569488592 th 1045390934',
#   [('ความจุแบตเตอรี่', '1000')]],
#  'category_0_144': [[('aและqq', 'how'),
#    ('a', 'pls'),
#    ('link', 'http'),
#    ('', 'global.cainiao.com'),
#    ('q', 'about'),
#    ('a', 'we'),
#    ('country', '1'),
#    ('link', 'willmyphonework.net'),
#    ('q', 'what'),
#    ('a', 'we'),
#    ('แบรนด์', 'new'),
#    ('แบรนด์', 'at')],
#   'sku: 615690512 th 1168470733',
#   [('แรม', '6gb')],
#   [('ความจุแบตเตอรี่', '1000')]],
#  'category_0_145': ['faqq: how to track the order ',
#   'a: pls check this link:https: www.17track.net zh cn',
#   'q: about network bands',
#   'a: we add a link to show you how to check the phone whether can be used in your country: all our สมาร์ทโฟน unlocked for worldwide use but please check if your local area network is compatible with our phones you can check this link:willmyphonework.net or maps.mobileworldlive.com to see the network frequency for your country please confirm with your carriers or providers before you purchase this item.',
#   'q: what if i m dissatisfied with the product ',
#   'a: we guarantee you will be 100เปอร์เซนต์ satisfied with the quality of your product. if you re unhappy with it please contact our customer service who will be glad to help.when contacting customer service team please give your order number a short description and a photo of the problem so we can prevent these problems in the future.',
#   [('แบรนด์', 'new'), ('แบรนด์', 'at')],
#   'sku: 604548331 th 1137518592',
#   [('แรม', '8gb')],
#   [('ความจุแบตเตอรี่', '1000')]],
#  'category_0_146': ['q: how to track the order ',
#   'a: pls check this link: https: www.17track.net zh cn',
#   'q: about network bands',
#   'a: we add a link to show you how to check the phone whether can be used in your country: all our สมาร์ทโฟน unlocked for worldwide use but please check if your local area network is compatible with our phones you can check this link:willmyphonework.net or maps.mobileworldlive.com to see the network frequency for your country please confirm with your carriers or providers before you purchase this item.',
#   'q: what if i m dissatisfied with the product ',
#   'a: we guarantee you will be 100เปอร์เซนต์ satisfied with the quality of your product. if you re unhappy with it please contact our customer service who will be glad to help.when contacting customer service team please give your order number a short description and a photo of the problem so we can prevent these problems in the future.',
#   [('แบรนด์', 'new'), ('แบรนด์', 'at')],
#   'sku: 604796218 th 1138260078',
#   [('แรม', '8gb')],
#   [('ความจุแบตเตอรี่', '1000')]],
#  'category_0_147': [[('จอแสดงผล', 'fingerprint'),
#    ('ระบบปฎิบัติการfuntouchระบบปฏิบัติการ', '9')],
#   'sku: 373546910 th 728028139',
#   [('ความจุแบตเตอรี่', '4000')]],
#  'category_0_148': [[('ระบบปฏิบัติการ', 'funtouchระบบปฏิบัติการ'),
#    ('', '9'),
#    ('', 'mediatek')],
#   [('รอม', '128gb')],
#   [('แรม', '6')],
#   [('การหาตำแหน่ง', 'assisted')]],
#  'category_0_149': [[('แรม', '64'), ('รอม', '10.5')],
#   [('แรม', '128gb'), ('รอม', '3g')]],
#  'category_0_150': ['faqq: how to track the order ',
#   'a: pls check this link:https: www.17track.net zh cn',
#   'q: about network bands',
#   'a: we add a link to show you how to check the phone whether can be used in your country: all our สมาร์ทโฟน unlocked for worldwide use but please check if your local area network is compatible with our phones you can check this link:willmyphonework.net or maps.mobileworldlive.com to see the network frequency for your country please confirm with your carriers or providers before you purchase this item.',
#   'q: what if i m dissatisfied with the product ',
#   'a: we guarantee you will be 100เปอร์เซนต์ satisfied with the quality of your product. if you re unhappy with it please contact our customer service who will be glad to help.when contacting customer service team please give your order number a short description and a photo of the problem so we can prevent these problems in the future.',
#   [('แบรนด์', 'new'), ('แบรนด์', 'at')],
#   'sku: 604540891 th 1137654540',
#   [('แรม', '6gb')],
#   [('ความจุแบตเตอรี่', '1000')]],
#  'category_0_151': ['q: how to track the order ',
#   'a: pls check this link: https: www.17track.net zh cn',
#   'q: about network bands',
#   'a: we add a link to show you how to check the phone whether can be used in your country: all our สมาร์ทโฟน unlocked for worldwide use but please check if your local area network is compatible with our phones you can check this link:willmyphonework.net or maps.mobileworldlive.com to see the network frequency for your country please confirm with your carriers or providers before you purchase this item.',
#   'q: what if i m dissatisfied with the product ',
#   'a: we guarantee you will be 100เปอร์เซนต์ satisfied with the quality of your product. if you re unhappy with it please contact our customer service who will be glad to help.when contacting customer service team please give your order number a short description and a photo of the problem so we can prevent these problems in the future.',
#   [('แบรนด์', 'new'), ('แบรนด์', 'at')],
#   'sku: 604696718 th 1138034104',
#   [('แรม', '6gb')],
#   [('ความจุแบตเตอรี่', '1000')]],
#  'category_0_152': [[('จอแสดงผล', 'ขนาด6.35')],
#   [('2g', 'edge'), ('3g', 'hspa')],
#   [('จอแสดงผล', 'ระบบสัมผัส')],
#   [('ระบบปฏิบัติการ', 'funtouchระบบปฏิบัติการ'), ('', '9')],
#   [('รอม', '64gb'), ('แรม', '4gb')],
#   [('การหาตำแหน่ง', 'assisted')]],
#  'category_0_153': [[('แรม', '4gb'), ('รอม', '64gb')],
#   [('รอม', '64gb')],
#   [('funtouchระบบปฏิบัติการ', '9')],
#   [('หมายเหตุ',
#     'โปรโมชั่นของแถมอาจมีการเปลี่ยนแปลงโดยไม่แจ้งให้ทราบล่วงหน้า')],
#   'sku: 598708474 th 1126022611',
#   [('ความจุแบตเตอรี่', '1000')]],
#  'category_0_154': ['q: how to track the order ',
#   'a: pls check this link:https: www.17track.net zh cn',
#   'q: about network bands',
#   'a: we add a link to show you how to check the phone whether can be used in your country: all our สมาร์ทโฟน unlocked for worldwide use but please check if your local area network is compatible with our phones you can check this link:willmyphonework.net or maps.mobileworldlive.com to see the network frequency for your country please confirm with your carriers or providers before you purchase this item.',
#   'q: what if i m dissatisfied with the product ',
#   'a: we guarantee you will be 100เปอร์เซนต์ satisfied with the quality of your product. if you re unhappy with it please contact our customer service who will be glad to help.when contacting customer service team please give your order number a short description and a photo of the problem so we can prevent these problems in the future.',
#   [('แบรนด์', 'new'), ('แบรนด์', 'at')],
#   'sku: 604840484 th 1138436028',
#   [('แรม', '8gb')],
#   [('ความจุแบตเตอรี่', '1000')]],
#  'category_0_155': ['q: how to track the order ',
#   'a: pls check this link:https: www.17track.net zh cn',
#   'q: about network bands',
#   'a: we add a link to show you how to check the phone whether can be used in your country: all our สมาร์ทโฟน unlocked for worldwide use but please check if your local area network is compatible with our phones you can check this link:willmyphonework.net or maps.mobileworldlive.com to see the network frequency for your country please confirm with your carriers or providers before you purchase this item.',
#   'q: what if i m dissatisfied with the product ',
#   'a: we guarantee you will be 100เปอร์เซนต์ satisfied with the quality of your product. if you re unhappy with it please contact our customer service who will be glad to help.when contacting customer service team please give your order number a short description and a photo of the problem so we can prevent these problems in the future.',
#   [('แบรนด์', 'new'), ('แบรนด์', 'at')],
#   'sku: 604710729 th 1138026540',
#   [('แรม', '4gb')],
#   [('ความจุแบตเตอรี่', '1000')]],
#  'category_0_156': ['sku: 259769078 th 399969081',
#   [('ความจุแบตเตอรี่', '1000')]],
#  'category_0_157': [[('aและqq', 'how'),
#    ('a', 'pls'),
#    ('link', 'http'),
#    ('', 'global.cainiao.com'),
#    ('q', 'about'),
#    ('a', 'we'),
#    ('country', '1'),
#    ('link', 'willmyphonework.net'),
#    ('q', 'what'),
#    ('a', 'we'),
#    ('แบรนด์', 'new'),
#    ('แบรนด์', 'at')],
#   'sku: 615722552 th 1168598091',
#   [('แรม', '8gb')],
#   [('ความจุแบตเตอรี่', '1000')]],
#  'category_0_158': [[('แรม', '8gb')],
#   [('2g', 'edge')],
#   [('3g', 'hspa')],
#   [('ระบบปฏิบัติการ', 'funtouchระบบปฏิบัติการ'), ('', '9.2')],
#   [('แรม', '8gb')]],
#  'category_0_159': [[('2g', 'edge')],
#   [('ระบบปฏิบัติการ', 'funtouchระบบปฏิบัติการ'), ('', '9')],
#   [('แรม', '3gb'), ('รอม', '32gb')],
#   [('การหาตำแหน่ง', 'assisted')]],
#  'category_0_160': [[('แรม', '3'), ('รอม', '64')],
#   'sku: 600314964 th 1129342245'],
#  'category_0_161': [[('แรม', '6'), ('รอม', '128')],
#   [('2g', 'edge')],
#   [('ระบบปฏิบัติการ', 'emui')],
#   [('แรม', '6gb'), ('รอม', '128gb')],
#   [('การหาตำแหน่ง', 'assisted')],
#   'sku: 596214366 th 1119566057',
#   [('แรม', '512mb')]],
#  'category_0_162': ['sku: 596222116 th 1119494559'],
#  'category_0_163': [[('cpu', 'mtk')], 'sku: 594192103 th 1115374774'],
#  'category_0_164': [[('แรม', '6'), ('รอม', '128')],
#   [('หน้าจอ', '6.59')],
#   'cpu: huawei kirin 710f octa core 4 x cortex a73 based 2.2 ghz 4 x cortex a53 based 1.7 ghz',
#   [('ระบบปฏิบัติการ', 'emui')],
#   [('หน่วยความจำ', 'แรม'), ('', '6'), ('รอม', '128')],
#   [('กล้องหน้า', '1ล้านพิกเซล')],
#   [('กล้องหลัง', '4ล้านพิกเซล')],
#   [('แบตเตอรี่', '4000')],
#   'sku: 601420142 th 1132208267',
#   [('แรม', '6gb')],
#   [('ความจุแบตเตอรี่', '1000')]],
#  'category_0_165': [[('ระบบปฎิบัติการ', 'android')],
#   'sku: 289716515 th 847906769',
#   [('แรม', '3gb')],
#   [('ความจุแบตเตอรี่', '4000')]],
#  'category_0_166': ['sku: 528100922 th 947986549'],
#  'category_0_167': ['sku: 375868110 th 732110495',
#   [('ความจุแบตเตอรี่', '1000')]],
#  'category_0_168': [[('แรม', 'รองรับ')], 'sku: 601192402 th 1131434450'],
#  'category_0_169': [[('แรม', '3'), ('รอม', '64')],
#   [('2g', 'edge')],
#   [('ระบบปฏิบัติการ', 'emui')],
#   [('แรม', '3'), ('รอม', '64gb')],
#   [('การหาตำแหน่ง', 'assisted')],
#   'sku: 599110939 th 1127098782',
#   [('แรม', '3'), ('รอม', '64')],
#   [('แรม', '3gb')]],
#  'category_0_170': [[('', 'เซนเซอร์หลักความละเอียด'),
#    ('รูปภาพ', '8000'),
#    ('วิดีโอ', '1920')],
#   [('', 'แสดงสี'), ('', '2340'), ('ppi', '391')],
#   [('', '2g'), ('gsm', 'b2')],
#   [('', '3g'), ('umts', 'b1')],
#   [('', '4g'), ('tdd', 'b38')],
#   [('fdd', 'b1')]],
#  'category_0_171': ['sku: 593028182 th 1112374566',
#   [('แรม', '3gb')],
#   [('ความจุแบตเตอรี่', '3000')]],
#  'category_0_172': [[('แรม', '3')],
#   [('gsm', 'bands')],
#   [('wcdma', 'bands')],
#   [('lte', 'bands')],
#   [('lte', 'bands')],
#   'sku: 596394547 th 1119824766',
#   [('ความจุแบตเตอรี่', '1000')]],
#  'category_0_173': [[('รอม', '32gb'), ('แรม', '3gb')],
#   'sku: 320064385 th 812406952',
#   [('แรม', '3gb')]],
#  'category_0_174': ['sku: 357150478 th 699988012'],
#  'category_0_175': [[('รอม', '8gb'), ('แรม', '฿')],
#   [('แรม', '4'), ('รอม', '64')],
#   [('แรม', '6'), ('รอม', '128gb')],
#   [('แรม', '3gb')],
#   [('แรม', '8')]],
#  'category_0_176': [[('แรม', '6gb')],
#   [('ระบบปฏิบัติการ', 'emui')],
#   [('แรม', '6gb'), ('รอม', '128gb')],
#   [('2g', 'edge')],
#   'sku: 594532004 th 1116304128',
#   [('ความจุแบตเตอรี่', '1000')]],
#  'category_0_177': [[('แรม', '6')],
#   'sku: 594462946 th 1116358223',
#   [('แรม', '6')]],
#  'category_0_178': ['sku: 594398527 th 1116232042',
#   [('ความจุแบตเตอรี่', '1000')]],
#  'category_0_179': [[('หน้าจอ', 'dewdrop'), ('จอแสดงผล', '6.09')],
#   [('ความปลอดภัย', 'สแกนลายนิ้วมือที่ข้างตัวเครื่อง')],
#   [('พอร์ต', 'แจ๊ค')],
#   [('กล้องหน้า', 'ความละเอียด')],
#   [('กล้องหลัง', 'ความละเอียด')],
#   [('ชิปเซ็ต', 'mediatek')],
#   'ram: 3gb rom: 64gb',
#   [('แบตเตอรี', '3200')],
#   [('ระบบปฎิบัติการณ์', 'android')],
#   [('สี', 'starry')],
#   'sku: 594270092 th 1115594659',
#   [('ความจุแบตเตอรี่', '30001')]],
#  'category_0_180': [[('แรม', 'รองรับ')], 'sku: 596522728 th 1120102293'],
#  'category_0_181': [[('ขนาดหน้าจอ', '6.59')],
#   [('ประเภทหน้าจอ', 'tft')],
#   [('สีหน้าจอ', '16.7')],
#   [('ความละเอียดหน้าจอ', '2340')],
#   [('ppi', '391หน่วยประมวลผล'),
#    ('', 'hisilicon'),
#    ('710fระบบปฎิบัติการ', 'emui'),
#    ('หน่วยความจำภายใน', '4')],
#   [('กล้องด้านหน้า', '16')],
#   [('กล้องด้านหลัง', '16'), ('mแบตเตอรี่', '4000')],
#   [('จอแสดงผล', 'ระบบสัมผัส')],
#   [('ระบบปฏิบัติการ', 'android')],
#   [('แรม', '4gb'), ('รอม', '128gb')]],
#  'category_0_182': [[('แรม', '4')],
#   [('แรม', '4gb')],
#   'sku: 328258784 th 628690621',
#   [('แรม', '4')],
#   [('แรม', '4gb')]],
#  'category_0_183': ['sku: 342498502 th 665538006'],
#  'category_0_184': [[('แรม', '3'), ('รอม', '64')],
#   [('รอม', '64')],
#   [('', '73.5'),
#    ('', '156.28'),
#    ('', '8.0'),
#    ('', 'ประมาณ'),
#    ('', '6.09'),
#    ('', '16.7'),
#    ('', 'tft'),
#    ('', '1560'),
#    ('cpu', 'mtk'),
#    ('', 'emui'),
#    ('', '3'),
#    ('การสนับสนุนหน่วยความจำภายนอก', 'การ์ด'),
#    ('', '13'),
#    ('', '8ล้านพิกเซล'),
#    ('', '3020'),
#    ('', 'input'),
#    ('', '100'),
#    ('output', '5v1a')],
#   'sku: 596756304 th 1120612454'],
#  'category_0_185': [[('แรม', '4gb'), ('รอม', '64')],
#   [('กล้อง', 'กล้องหน้า')],
#   [('กล้อง', 'กล้องหน้า')],
#   [('แรม', '4gb'), ('รอม', '64')],
#   'sku: 291298342 th 483916431'],
#  'category_0_186': [[('แรม', '6')],
#   [('ชิปเซ็ต', 'kirin')],
#   'ram: 6gb',
#   [('ความจุ', '128gb')],
#   'sku: 598526513 th 1125486439'],
#  'category_0_187': [[('แรม', '8')],
#   [('gsm', 'แบนด์')],
#   [('wcdma', 'แบนด์'), ('tds', 'แบนด์')],
#   [('lte', 'แบนด์'), ('lte', 'แบนด์')],
#   'sku: 358866806 th 704258251',
#   [('แรม', '8')]],
#  'category_0_188': [[('แรม', '4gb'), ('รอม', '64')],
#   [('กล้อง', 'กล้องหน้า')],
#   [('กล้อง', 'กล้องหน้า')],
#   [('แรม', '4gb'), ('รอม', '64')],
#   'sku: 291282274 th 483922421',
#   [('แรม', '4gb')],
#   [('ความจุแบตเตอรี่', '3000')]],
#  'category_0_189': [[('กว้าง', '70.9'), ('สูง', '146.5'), ('หนา', '8.3')],
#   [('น้ำหนัก', 'ประมาณ')],
#   [('ขนาดหน้าจอ', '5.45')],
#   [('สีของหน้าจอ', '16.7')],
#   [('ประเภทของหน้าจอ', 'tft')],
#   [('ความละเอียด', 'hd')],
#   [('ความคมชัดของหน้าจอ', '295')],
#   [('ประเภทการ์ดเก็บข้อมูล', 'การ์ด')],
#   [('รองรับหน่วยความจำภายนอก', '256')],
#   [('กล้องเลนส์เดี่ยว', '8ล้านพิกเซล')],
#   [('กล้องเลนส์เดี่ยว', '5ล้านพิกเซล')],
#   [('แฟลช', 'ด้านหน้าเป็นแฟลชแบบ')],
#   [('fdd', 'b1')],
#   [('tdd', 'b40')],
#   [('wcdma', 'b1')],
#   [('gsm', 'b2')],
#   [('บันทึก', 'ฟังก์ชั่นที่มีนี้ขึ้นอยู่กับเครือข่ายผู้ให้บริการ')],
#   [('ซิมการ์ดหลัก', '4g'),
#    ('fdd', 'b1'),
#    ('tdd', 'b403g'),
#    ('wcdma', 'b1'),
#    ('gsm', 'b2')],
#   [('', '3g'), ('wcdma', 'b1'), ('gsm', 'b2')],
#   [('บันทึก',
#     'ช่องเสียบการ์ดทั้งสองสามารถตั้งค่าเพื่อรองรับซิมการ์ดหลักหรือรองได้')],
#   [('', '802.11b'), ('bluetooth', 'bt'), ('port', 'micro')]],
#  'category_0_190': [[('แรม', '64'), ('รอม', '10.5')],
#   [('แรม', '128gb'), ('รอม', '3g')]],
#  'category_0_191': [[('กว้าง', '77.1'),
#    ('มมสูง', '162.4'),
#    ('มมหนา', '8.05'),
#    ('มมน้ำหนัก', '173')]],
#  'category_0_192': ['sku: 570030784 th 1046476409'],
#  'category_0_193': [[('ppi', '391')],
#   'sku: 343882248 th 669814957',
#   [('แรม', '4gb')],
#   [('ความจุแบตเตอรี่', '4000')]],
#  'category_0_194': [[('แรม', '4gb')], 'sku: 599542296 th 1127736447'],
#  'category_0_195': [[('แรม', '8gb'), ('รอม', '512gb')],
#   'sku: 594360907 th 1117668861',
#   [('ความจุแบตเตอรี่', '1000')]],
#  'category_0_196': ['sku: 582918405 th 1077862110',
#   [('ความจุแบตเตอรี่', '3000')]],
#  'category_0_197': [[('แบตเตอรี่', '3750')],
#   [('ระบบปฏิบัติการ', 'android')],
#   'sku: 403214185 th 782722982'],
#  'category_0_198': [[('ระบบปฏิบัติการ', 'android')],
#   [('แรม', '6gb')],
#   'sku: 310318635 th 552322430'],
#  'category_0_199': [[('กล้องหลัง', '2ล้านพิกเซล')],
#   [('แบตเตอรี่', '3750')],
#   'sku: 328120492 th 628182917',
#   [('ความจุแบตเตอรี่', '3000')]],
#  'category_0_200': [],
#  'category_0_201': ['sku: 593892371 th 1114492226'],
#  'category_0_202': [],
#  'category_0_203': ['sku: 599084896 th 1127026639'],
#  'category_0_204': ['sku: 598884689 th 1127090507',
#   [('แรม', '4gb')],
#   [('ความจุแบตเตอรี่', '1000')]],
#  'category_0_205': ['sku: 599068800 th 1127036426'],
#  'category_0_206': [[('แรม', '3'), ('รอม', '64')],
#   [('ระบบปฏิบัติการ', 'colorระบบปฏิบัติการ'), ('', '6.0')],
#   [('แรม', '3'), ('รอม', '64')],
#   'sku: 611118429 th 1152724834',
#   [('แรม', '3'), ('รอม', '64')],
#   [('แรม', '3gb')],
#   [('ความจุแบตเตอรี่', '1000')]],
#  'category_0_207': ['sku: 576962917 th 1065758090',
#   [('แรม', '512mb')],
#   [('ความจุแบตเตอรี่', '1000')]],
#  'category_0_208': [[('', 'colorระบบปฏิบัติการ'), ('', '6')],
#   'sku: 595536413 th 1118762069',
#   [('แรม', '4gb')]],
#  'category_0_209': [[('แรม', '128')],
#   [('จอแสดงผล', 'ระบบหมุนภาพอัตโนมัติ')],
#   [('2g', 'edge')],
#   [('ระบบปฏิบัติการ', 'colorระบบปฏิบัติการ'), ('', '6.1')],
#   [('แรม', '6'), ('รอม', '64')],
#   [('การหาตำแหน่ง', 'assisted')]],
#  'category_0_210': ['sku: 593892271 th 1114412808'],
#  'category_0_211': [[('แรม', '64'), ('รอม', 'expandable')],
#   'sku: 326952660 th 624226626',
#   [('ความจุแบตเตอรี่', '1000')]],
#  'category_0_212': ['sku: 265436667 th 412888313',
#   [('ความจุแบตเตอรี่', '1000')]],
#  'category_0_213': [[('รอม', '8gb'), ('แรม', '฿')],
#   [('แรม', '4'), ('รอม', '64')],
#   [('แรม', '8')],
#   [('แรม', '3gb')],
#   [('แรม', '6'), ('รอม', '128gb')]],
#  'category_0_214': ['sku: 403004685 th 782382982',
#   [('ความจุแบตเตอรี่', '1000')]],
#  'category_0_215': ['sku: 417942838 th 801314333',
#   [('ความจุแบตเตอรี่', '30001')]],
#  'category_0_216': ['sku: 604764960 th 1138830339',
#   [('แรม', '4gb')],
#   [('ความจุแบตเตอรี่', '5000')]],
#  'category_0_217': [[('แรม', '64'), ('รอม', '10.5')],
#   [('รอม', '64gb')],
#   [('แรม', '128gb'), ('รอม', '3g')]],
#  'category_0_218': ['sku: 580734651 th 1073342091',
#   [('แรม', '4gb')],
#   [('ความจุแบตเตอรี่', '1000')]],
#  'category_0_219': [[('แรม', '4')],
#   [('2g', 'edge')],
#   [('ระบบปฏิบัติการ', 'colorระบบปฏิบัติการ'), ('', '6')],
#   [('แรม', '4'), ('รอม', '128')],
#   [('การหาตำแหน่ง', 'assisted')],
#   'sku: 600982947 th 1131064759',
#   [('แรม', '4gb')]],
#  'category_0_220': [[('แรม', '4')],
#   [('ระบบปฏิบัติการ', 'colorระบบปฏิบัติการ'), ('', '6.0')],
#   [('แรม', '4')],
#   [('รอม', '128')]],
#  'category_0_221': [[('แรม', '3'), ('รอม', '32')],
#   [('ระบบปฏิบัติการ', 'colorระบบปฏิบัติการ'), ('', '6.0')],
#   [('แรม', '3'), ('รอม', '32')],
#   [('จอแสดงผล', 'ตรวจจับความเคลื่อนไหวของตัวเครื่อง')],
#   'sku: 594530664 th 1116430818'],
#  'category_0_222': [[('รอม', '8gb'), ('แรม', '฿')],
#   [('แรม', '4'), ('รอม', '64')],
#   [('แรม', '3gb')],
#   [('แรม', '8')],
#   [('แรม', '6'), ('รอม', '128gb')]],
#  'category_0_223': [[('รอม', '128gb')],
#   'sku: 599480538 th 1128100802',
#   [('แรม', '4gb')],
#   [('ความจุแบตเตอรี่', '5000')]],
#  'category_0_224': ['sku: 418146358 th 801330478',
#   [('ความจุแบตเตอรี่', '1000')]],
#  'category_0_225': ['sku: 402982804 th 782386887',
#   [('ความจุแบตเตอรี่', '1000')]],
#  'category_0_226': [[('จอแสดงผล', 'ตรวจจับความเคลื่อนไหวของตัวเครื่อง')],
#   [('ระบบปฏิบัติการ', 'colorระบบปฏิบัติการ'), ('', '6.0')],
#   [('แรม', '3'), ('รอม', '32')],
#   [('จอแสดงผล', 'ตรวจจับความเคลื่อนไหวของตัวเครื่อง')],
#   [('ระบบปฏิบัติการ', 'colorระบบปฏิบัติการ'), ('', '6.0')],
#   [('แรม', '3'), ('รอม', '32')]],
#  'category_0_227': ['sku: 418142432 th 801348251',
#   [('ความจุแบตเตอรี่', '1000')]],
#  'category_0_228': [[('แรม', '64'), ('รอม', '10.5')],
#   [('แรม', '128gb'), ('รอม', '3g')]],
#  'category_0_229': [[('colorระบบปฏิบัติการ', '6.0')],
#   'sku: 460654202 th 847892071',
#   [('แรม', '8gb')],
#   [('ความจุแบตเตอรี่', '1000')]],
#  'category_0_230': [[('', 'colorระบบปฏิบัติการ'), ('', '6')],
#   'sku: 591918757 th 1108276056',
#   [('แรม', '4gb')]],
#  'category_0_231': ['sku: 452446880 th 836206666',
#   [('ความจุแบตเตอรี่', '5000')]],
#  'category_0_232': [[('แรม', '3'), ('รอม', '32')],
#   [('ระบบปฏิบัติการ', 'colorระบบปฏิบัติการ'), ('', '6.0')],
#   [('แรม', '3gb'), ('รอม', '32gb')],
#   [('แรม', '2'), ('รอม', '16')],
#   [('จอแสดงผล', 'ระบบสัมผัส')],
#   [('2g', 'edge'), ('3g', 'hspa')],
#   [('ระบบปฏิบัติการ', 'colorระบบปฏิบัติการ'), ('', '6.0')],
#   [('แรม', '2'), ('รอม', '16')],
#   [('การหาตำแหน่ง', 'assisted')]],
#  'category_0_233': [[('รอม', 'แท้จากโรงงาน')],
#   [('network', '2g'),
#    ('', 'gsm'),
#    ('', '850'),
#    ('cdma', 'bc0'),
#    ('3g', 'wcdma'),
#    ('', 'b1'),
#    ('cdma2000', 'bc0'),
#    ('scdma', 'b34'),
#    ('4g', 'lte'),
#    ('fdd', 'b1'),
#    ('lte', 'b34')],
#   'sku: 616366381 th 1170420923',
#   [('แรม', '8gb')]],
#  'category_0_234': [[('รอม', '128gb')],
#   [('แรม', '4gb'), ('รอม', '128gb'), ('แรม', '8gb'), ('รอม', '128gb')],
#   [('colorระบบปฏิบัติการ', '6')],
#   'sku: 600790956 th 1130624325',
#   [('แรม', '4gb')]],
#  'category_0_235': [[('แรม', '4')],
#   [('รอม', 'สูงสุด')],
#   'sku: 338952152 th 656874222'],
#  'category_0_236': [[('รอม', '128gb')],
#   [('รอม', '128gb')],
#   'sku: 599704659 th 1128032096'],
#  'category_0_237': [[('รอม', 'เพิ่มสูงสุดถึง')],
#   'sku: 601276452 th 1131698507',
#   [('แรม', '4gb')],
#   [('ความจุแบตเตอรี่', '5001')]],
#  'category_0_238': [[('จอแสดงผล', 'ระบบสัมผัส')],
#   [('2g', 'edge'), ('3g', 'hspa')],
#   [('ระบบปฏิบัติการ', 'colorระบบปฏิบัติการ'), ('', '6.0')],
#   [('แรม', '2'), ('รอม', '16')],
#   'sku: 408100004 th 792804384',
#   [('ความจุแบตเตอรี่', '1000')]],
#  'category_0_239': [[('แรม', '8')],
#   [('ระบบปฏิบัติการ', 'colorระบบปฏิบัติการ'), ('', '6.0')],
#   [('แรม', '8'), ('รอม', '128')],
#   [('การหาตำแหน่ง', 'assisted')],
#   'sku: 416330239 th 799976588'],
#  'category_0_240': ['sku: 268324226 th 603248979',
#   [('แรม', '1gb')],
#   [('ความจุแบตเตอรี่', '3000')]],
#  'category_0_241': [[('แรม', '2'), ('รอม', '16')],
#   'sku: 365700164 th 714698964'],
#  'category_0_242': [[('แรม', '2'), ('รอม', '32gb')],
#   'sku: 552184749 th 1006836063'],
#  'category_0_243': [[('แรม', '2'), ('รอม', '32gb')],
#   'sku: 385566108 th 815456220'],
#  'category_0_244': [[('แรม', '2'), ('รอม', '16gb')],
#   'sku: 405068513 th 805010589'],
#  'category_0_245': [[('รอม', '32gb')],
#   'sku: 400040507 th 777298618',
#   [('แรม', '2gb')],
#   [('ความจุแบตเตอรี่', '30001')]],
#  'category_0_246': ['sku: 270282019 th 422771415',
#   [('แรม', '1gb')],
#   [('ความจุแบตเตอรี่', '3000')]],
#  'category_0_247': ['sku: 405108122 th 805050038',
#   [('ความจุแบตเตอรี่', '1000')]],
#  'category_0_248': [[('แรม', '2'), ('รอม', '32gb')],
#   'sku: 550594069 th 1000618756'],
#  'category_0_249': [[('แรม', '2gb')],
#   'sku: 275617311 th 815450167',
#   [('แรม', '2gb')],
#   [('ความจุแบตเตอรี่', '3000')]],
#  'category_0_250': [[('แรม', '2'), ('รอม', '32gb')],
#   'sku: 603116847 th 1136274443'],
#  'category_0_251': [[('รอม', '16gb')],
#   'sku: 314710401 th 576202145',
#   [('แรม', '1gb')],
#   [('ความจุแบตเตอรี่', '3000')]],
#  'category_0_252': [[('แรม', '2'), ('รอม', '32gb')],
#   'sku: 603110290 th 1136224459'],
#  'category_0_253': [[('แรม', '2'), ('รอม', '16')],
#   'sku: 328582974 th 629520209'],
#  'category_0_254': [[('', 'รอม'), ('', '16gb'), ('แรม', '1gb')],
#   [('แบตเตอรี่', '3200mah')],
#   'sku: 270179696 th 578982558',
#   [('แรม', '1gb')],
#   [('ความจุแบตเตอรี่', '3000')]],
#  'category_0_255': [[('รอม', '16gb')],
#   [('สนทนาต่อเนื่องสูงสุดประมาณ', '8')],
#   [('ขนาด', '75')],
#   [('น้ำหนัก', '150')],
#   [('ข้อความ', 'sms')],
#   [('ภาษา', 'thai')],
#   [('หน่วยความจำภายนอก', 'รองรับt')],
#   [('หน่วยความจำภายใน', 'รอม'), ('', '16gb'), ('แรม', '1')],
#   'cpu:mtk 6580 1.3ghz quad core',
#   [('วิดีโอ', 'เครื่องเล่น')],
#   [('เครื่องเสียง', 'เครื่องเล่นล้านพิกเซล')],
#   [('ริงโทน', 'ล้านพิกเซล')],
#   [('วิทยุ', 'มี')],
#   'wallpaper: bmpjpegpng',
#   [('gps', 'มี')],
#   'battery:haixu battery 3200mah '],
#  'category_0_256': [[('แรม', '2'), ('รอม', '32gb')],
#   'sku: 603094531 th 1136238502'],
#  'category_0_257': [[('รอม', '8gb'), ('แรม', '฿')],
#   [('แรม', '4'), ('รอม', '64')],
#   [('แรม', '2')],
#   [('รอม', '64gb')]],
#  'category_0_258': [[('แรม', '2')],
#   'sku: 312418366 th 1030968530',
#   [('แรม', '2gb')],
#   [('ความจุแบตเตอรี่', '3000')]],
#  'category_0_259': [[('รอม', '16gb')],
#   [('แรม', '2gb'), ('รอม', '16gb')],
#   'sku: 601494155 th 1132134762'],
#  'category_0_260': [[('แบตเตอรี่', '3400mah')],
#   [('แบตเตอรี่', '3400mah')],
#   'sku: 314412441 th 573360540',
#   [('แรม', '2gb')],
#   [('ความจุแบตเตอรี่', '3000')]],
#  'category_0_261': ['sku: 312924192 th 563944053',
#   [('แรม', '1gb')],
#   [('ความจุแบตเตอรี่', '3000')]],
#  'category_0_262': [[('แรม', '3gb')], [('แรม', '128gb'), ('รอม', '3g')]],
#  'category_0_263': ['sku: 602892154 th 1136000618'],
#  'category_0_264': [[('แรม', '2gb'), ('รอม', '16gb')],
#   'sku: 601448844 th 1132182102'],
#  'category_0_265': [[('รอม', '8gb'), ('แรม', '฿')],
#   [('แรม', '4'), ('รอม', '64')],
#   [('แรม', '2')],
#   [('รอม', '64gb')]],
#  'category_0_266': [[('แรม', '2gb'), ('รอม', '16gb')],
#   [('แรม', '2gb'), ('รอม', '16gb')],
#   'sku: 601266875 th 1131662738'],
# ...
#  'category_3_181': ['cpu:intel core i3 7020u 2.3 ghz 3 mb l3 cache ',
#   'gpu:amd radeon 520 2gb gddr5 ',
#   'ram:4 gb ddr4 2400 mhz',
#   'storage:1 tb 5400 rpm',
#   'os:ubuntu',
#   'sku: 373586549 th 728024230'],
#  'category_3_182': ['sku: 334232879 th 647120903'],
#  'category_3_183': [[('แรม', '2')],
#   [('ฮาร์ดดิสก์', '160')],
#   'sku: 599150109 th 1127170665'],
#  'category_3_184': [[('ฮาร์ดดิสก์', 'amd')],
#   [('แรม', '8gb'), ('ฮาร์ดดิสก์', '500')]],
#  'category_3_185': ['sku: 333876982 th 646008437'],
#  'category_3_186': [[('แรม', '4'), ('ฮาร์ดดิสก์', '1')],
#   [('แรม', '4gb')],
#   [('แรม', '4gb'), ('ฮาร์ดดิสก์', '1tb')],
#   [('แรม', '4'), ('ฮาร์ดดิสก์', '1')],
#   [('ฮาร์ดดิสก์', '500gb')]],
#  'category_3_187': [[('ฮาร์ดดิสก์', 'windows10')],
#   'sku: 319960011 th 609242785'],
#  'category_3_188': [[('ram', '4gb'), ('ฮาร์ดดิสก์', ''), ('', '320gb')],
#   'sku: 566832434 th 1144928330'],
#  'category_3_189': ['sku: 484708909 th 872936864'],
#  'category_3_190': [[('ฮาร์ดดิสก์', 'amd')],
#   [('แรม', '8gb'), ('ฮาร์ดดิสก์', '500')],
#   [('แรม', '8g')],
#   [('แรม', '128gb')]],
#  'category_3_191': [[('แบรนด์', 'dell')],
#   [('จอแสดงผล', 'screen'), ('จอแสดงผล', '')],
#   'note: the memory is integrated on the system board from the factory and it cannot be upgraded later.',
#   'sku: 533484443 th 963614782'],
#  'category_3_192': ['sku: 564042949 th 1034122536'],
#  'category_3_193': [[('แรม', '8')], 'sku: 571338885 th 1049004809'],
#  'category_3_194': [[('ฮาร์ดดิสก์', '512gb')], 'sku: 471532400 th 861288862'],
#  'category_3_195': [[('แบรนด์', 'ยี่ห้อ'), ('', 'dell')],
#   'cpu: intel core i5 4310m 2.70ghz',
#   [('หน้าจอ', '14')],
#   'memory: แรม ddr3 4 gb',
#   'storage: ฮาร์ดดิสก์: sata 320 gb',
#   [('พอร์ต', 'hdmi'), ('รอม', 'ช่องต่อหูฟัง')],
#   'sku: 592728650 th 1110476822'],
#  'category_3_196': ['cpu:amd ryzen 3 2200u 2.50 ghz up to 3.40 ghz 4 mb l3 cache ',
#   'gpu:amd radeon rx vega 3',
#   'ram:4 gb ddr4 2400 mhz',
#   'storage:1 tb 5400 rpm',
#   'os:windows 10 home 64 bit ',
#   'sku: 373746991 th 728358777'],
#  'category_3_197': ['sku: 279815926 th 452425319'],
#  'category_3_198': [[('แรม', '4'), ('ฮาร์ดดิสก์', '1')],
#   [('แรม', '4gb')],
#   [('แรม', '4gb'), ('ฮาร์ดดิสก์', '1tb')],
#   [('แรม', '4'), ('ฮาร์ดดิสก์', '1')],
#   [('ฮาร์ดดิสก์', '500gb')]],
#  'category_3_199': ['cpu:intel core i5 7200u 2.5 ghz 3 mb l3 cache up to 3.10 ghz ',
#   'gpu:nvidia geforce gt 940mx 2gb gddr5 ',
#   'ram:4 gb ddr4',
#   'storage:1 tb 5400 rpm',
#   'os:windows 10 home 64 bit ',
#   'sku: 373590146 th 727994623'],
#  'category_3_200': [[('ฮาร์ดดิสก์', '250gb'), ('แรม', '4gb')],
#   'ram: ddr3 4 gb',
#   'condition: สินค้าหมดสัญญาเช่า',
#   [('duty', 'https'), ('', 'youtu.be')],
#   'sku: 536850936 th 971818832'],
#  'category_3_201': ['sku: 365566252 th 714386288'],
#  'category_3_202': [[('', 'แรม'), ('', '2gb')], 'sku: 317658755 th 598712542'],
#  'category_3_203': [[('แรม', '2gb'), ('ฮาร์ดดิสก์', ''), ('', '160gb')],
#   'sku: 619684279 th 1180350471'],
#  'category_3_204': ['sku: 596072994 th 1119382481'],
#  'category_3_205': [[('แรม', '8gb'), ('ฮาร์ดดิสก์', '320gb')],
#   [('', 'ฮาร์ดดิสก์'), ('', '320')],
#   'sku: 264850282 th 411491182'],
#  'category_3_206': ['sku: 596100078 th 1119344299'],
#  'category_3_207': ['sku: 422636515 th 806532310'],
#  'category_3_208': [[('จอแสดงผล', '24')], 'sku: 458276940 th 844340071'],
#  'category_3_209': ['sku: 596366330 th 1119728473'],
#  'category_3_210': ['sku: 456514309 th 842678620'],
#  'category_3_211': [[('น้ำหนัก', 'ing')],
#   [('จอแสดงผล', 'with')],
#   [('lightน้ำหนัก', 'design')],
#   'sku: 505170632 th 895484287'],
#  'category_3_212': [[('ฮาร์ดดิสก์', 'ssd')], 'sku: 307310840 th 535774426'],
#  'category_3_213': [[('แรม', '4')],
#   [('', 'notebook'),
#    ('', 'intel'),
#    ('', 'แรม'),
#    ('', '4gb'),
#    ('ฮาร์ดดิสก์', ''),
#    ('', 'ssd'),
#    ('', 'touch'),
#    ('', 'vga')],
#   'sku: 338326057 th 655318929'],
#  'category_3_214': [[('แรม', '4gb'), ('ฮาร์ดดิสก์', '250gb')],
#   [('เดือนcondition', 'สินค้าหมดสัญญาเช่า')],
#   'sku: 477448954 th 868162873'],
#  'category_3_215': ['sku: 520914744 th 926852256'],
#  'category_3_216': [[('ฮาร์ดดิสก์', '160')], 'sku: 619100600 th 1178808344'],
#  'category_3_217': [[('cpu', 'intel')],
#   [('หน้าจอ', '15.6')],
#   [('memory', 'แรม')],
#   [('storage', 'ฮาร์ดดิสก์'), ('', '320')],
#   [('card', 'intel')],
#   [('พอร์ต', 'usb'), ('รอม', 'ช่องต่อหูฟังช่องต่อไมค์')],
#   'sku: 618700944 th 1178002977'],
#  'category_3_218': [[('ฮาร์ดดิสก์', 'ssd')], 'sku: 315136418 th 579798392'],
#  'category_3_219': ['sku: 429384851 th 811210249'],
#  'category_3_220': [[('แรม', '8gb')], 'sku: 273482281 th 433418368'],
#  'category_3_221': [[('แรม', '4g')],
#   [('ฮาร์ดดิสก์', 'amd')],
#   [('แรม', '8gb')],
#   [('ฮาร์ดดิสก์', 'ssd')],
#   [('แรม', '8g')]],
#  'category_3_222': [[('แรม', '4gb'), ('ฮาร์ดดิสก์', '320gb')],
#   [('', 'ฮาร์ดดิสก์'), ('', '320')],
#   'sku: 357372659 th 700430122'],
#  'category_3_223': [[('แรม', 'ddr4'), ('ฮาร์ดดิสก์', '500')],
#   'cpu: intel i5 6200u up to 2.8 ghz รุ่นยังใหม่ ',
#   'sku: 524772813 th 939400510',
#   [('จอแสดงผล', 'usb')]],
#  'category_3_224': [[('แรม', '2gb')],
#   [('cpu', 'intel')],
#   [('ram', '2gb')],
#   [('ฮาร์ดดิสก์', 'ได้')],
#   [('แรม', '4gb')],
#   'sku: 362846517 th 707960298'],
#  'category_3_225': [[('แรม', '16gb'), ('ฮาร์ดดิสก์', '320gb')],
#   [('', 'ฮาร์ดดิสก์'), ('', '320')],
#   'sku: 306262057 th 532028488'],
#  'category_3_226': [[('ฮาร์ดดิสก์', 'แรม'), ('', '2')],
#   'sku: 426308346 th 809984137'],
#  'category_3_227': ['sku: 520906979 th 926876567'],
#  'category_3_228': [[('แรม', '4gb')],
#   [('cpu', 'intel')],
#   [('ram', '4gb')],
#   [('แรม', '4gb')],
#   'sku: 362854645 th 707986350'],
#  'category_3_229': ['sku: 383720733 th 745420127'],
#  'category_3_230': [[('ฮาร์ดดิสก์', '320')], 'sku: 341896421 th 663882490'],
#  'category_3_231': ['sku: 499354441 th 888832580'],
#  'category_3_232': [[('แรม', '4'), ('ฮาร์ดดิสก์', '1')],
#   [('แรม', '4gb')],
#   [('แรม', '4gb'), ('ฮาร์ดดิสก์', '1tb')],
#   [('แรม', '8')]],
#  'category_3_233': [[('', 'notebook'),
#    ('', 'intel'),
#    ('', 'แรม'),
#    ('', '4gb'),
#    ('ฮาร์ดดิสก์', ''),
#    ('', 'ssd'),
#    ('', 'touch'),
#    ('', 'vga')],
#   'sku: 338348872 th 655450591'],
#  'category_3_234': ['cpu: intel core i3 4000m 2.40ghz',
#   [('หน้าจอ', '15.6')],
#   'memory: แรม 4 gb',
#   'storage: ฮาร์ดดิสก์: 320 gb',
#   [('card', 'intel')],
#   [('', 'usb'), ('รอม', 'ช่องต่อหูฟัง')],
#   'sku: 341764533 th 663488273'],
#  'category_3_235': [[('cpu', 'intel')],
#   [('หน้าจอ', '15.6')],
#   [('memory', 'แรม')],
#   [('storage', 'ฮาร์ดดิสก์'), ('', '320')],
#   [('card', 'intel')],
#   [('พอร์ต', 'usb'), ('รอม', 'ช่องต่อหูฟังช่องต่อไมค์')],
#   'sku: 284442011 th 463196461'],
#  'category_3_236': [[('แรม', '4g')],
#   [('ฮาร์ดดิสก์', 'amd')],
#   [('แรม', '8gb')],
#   [('ฮาร์ดดิสก์', 'ssd')],
#   [('แรม', '8g')]],
#  'category_3_237': [[('แรม', '4gb'), ('ฮาร์ดดิสก์', '250gb')],
#   [('เดือนcondition', 'สินค้าหมดสัญญาเช่า')],
#   'sku: 526308795 th 943262650'],
#  'category_3_238': ['sku: 369256830 th 721506510'],
#  'category_3_239': [[('แรม', '16gb')], 'sku: 351894856 th 688180629'],
#  'category_3_240': [[('bar', '2.6ghz')]],
#  'category_3_241': ['sku: ap067elab7776panth 95251955'],
#  'category_3_242': [[('bar', '2.3ghz')]],
#  'category_3_243': [[('bar', '2.3ghz')]],
#  'category_3_244': ['sku: 268149406 th 419640978'],
#  'category_3_245': ['sku: 339304444 th 657674326'],
#  'category_3_246': [[('bar', 'i9')], 'sku: 338938903 th 656940293'],
#  'category_3_247': [[('bar', 'i9')], 'sku: 338972081 th 656944412'],
#  'category_3_248': [],
#  'category_3_249': [[('แรม', '4'), ('ฮาร์ดดิสก์', '1')],
#   [('แรม', '4gb')],
#   [('แรม', '8')]],
#  'category_3_250': [[('จอแสดงผล', '3.2')], 'sku: 206947226 th 311731496'],
#  'category_3_251': ['sku: 271912154 th 427453830'],
#  'category_3_252': ['sku: 206954757 th 311748169'],
#  'category_3_253': ['sku: 206956737 th 311743604'],
#  'category_3_254': ['sku: 479484496 th 869582594'],
#  'category_3_255': ['sku: 339288980 th 657660950'],
#  'category_3_256': ['sku: 278405142 th 446050699'],
#  'category_3_257': ['sku: 367388885 th 717882423'],
#  'category_3_258': ['sku: 263380058 th 406998756'],
#  'category_3_259': ['sku: 256080660 th 394889852'],
#  'category_3_260': [[('จอแสดงผล', 'i5')], 'sku: 206959733 th 311750598'],
#  'category_3_261': ['sku: 263382021 th 407001355'],
#  'category_3_262': [[('แรม', '4g')], [('แรม', '8g')], [('ฮาร์ดดิสก์', 'ssd')]],
#  'category_3_263': [[('bar', 'i5')], 'sku: 338914129 th 656814487'],
#  'category_3_264': ['sku: 367426145 th 717882899'],
#  'category_3_265': ['sku: 367416344 th 717866940'],
#  'category_3_266': [[('bar', 'i5')], 'sku: 339306479 th 657680884'],
#  'category_3_267': ['sku: 256061912 th 394880055'],
#  'category_3_268': [[('bar', 'i5')], 'sku: 338924689 th 656854169'],
#  'category_3_269': [[('bar', 'i7')], 'sku: 338950541 th 656908726'],
#  'category_3_270': [[('แรม', '4'), ('ฮาร์ดดิสก์', '1')],
#   [('แรม', '4gb')],
#   [('แรม', '8')],
#   [('แรม', '128gb')]],
#  'category_3_271': [[('bar', 'i7')], 'sku: 338956160 th 656882836'],
#  'category_3_272': ['sku: 265101762 th 412063584'],
#  'category_3_273': [[('air', '1.6ghz')],
#   'sku: 357692148 th 701478826',
#   [('air', '1.6ghz')]],
#  'category_3_274': [[('air', '1.6ghz')],
#   'sku: 357684428 th 701498251',
#   [('air', '1.6ghz')]],
#  'category_3_275': [[('แรม', '4g')], [('แรม', '8g')], [('ฮาร์ดดิสก์', 'ssd')]],
#  'category_3_276': [[('bar', '1.4ghz')],
#   'sku: 357690162 th 701476997',
#   [('bar', '1.4ghz')]],
#  'category_3_277': ['sku: ap067elab4ecrianth 88800081'],
#  'category_3_278': [[('bar', '1.4ghz')],
#   'sku: 357688208 th 701480659',
#   [('bar', '1.4ghz')]],
#  'category_3_279': [[('แรม', '4'), ('ฮาร์ดดิสก์', '1')],
#   [('แรม', '4gb')],
#   [('แรม', '8gb')],
#   [('แรม', '128gb')]],
#  'category_4_0': [[('แรม', '4g')], [('แรม', '4gb')]],
#  'category_4_1': [],
#  'category_4_2': [],
#  'category_4_3': [[('แรม', '4'), ('ฮาร์ดดิสก์', '1')],
#   [('แรม', '8gb')],
#   [('ฮาร์ดดิสก์', 'ssd')]],
#  'category_4_4': [],
#  'category_4_5': [[('แรม', '4g')], [('แรม', '4gb')], [('แรม', '8g')]],
#  'category_4_6': [],
#  'category_4_7': [],
#  'category_4_8': [],
#  'category_4_9': [],
#  'category_4_10': [],
#  'category_4_11': [],
#  'category_4_12': [],
#  'category_4_13': [],
#  'category_4_14': [[('แรม', '4'), ('ฮาร์ดดิสก์', '1')],
#   [('แรม', '8gb')],
#   [('แรม', '128gb')],
#   [('ฮาร์ดดิสก์', 'ssd')]],
#  'category_4_15': [],
#  'category_4_16': [],
#  'category_4_17': [],
#  'category_4_18': [],
#  'category_4_19': [[('แรม', '4g')], [('แรม', '4gb')], [('แรม', '8g')]],
#  'category_4_20': [[('แรม', '4'), ('ฮาร์ดดิสก์', '1')],
#   [('แรม', '8gb')],
#   [('แรม', '128gb')],
#   [('ฮาร์ดดิสก์', 'ssd')]],
#  'category_4_21': [[('แรม', '4g')], [('แรม', '4gb')], [('แรม', '8g')]],
#  'category_4_22': [],
#  'category_4_23': [],
#  'category_4_24': [],
#  'category_4_25': [[('แรม', '4'), ('ฮาร์ดดิสก์', '1')],
#   [('แรม', '8gb')],
#   [('แรม', '128gb')],
#   [('ฮาร์ดดิสก์', 'ssd')]],
#  'category_4_26': [[('แรม', '4g')], [('แรม', '4gb')], [('แรม', '8g')]],
#  'category_4_27': [],
#  'category_4_28': [[('แรม', '4'), ('ฮาร์ดดิสก์', '1')],
#   [('แรม', '8gb')],
#   [('แรม', '128gb')]],
#  'category_4_29': [],
#  'category_4_30': [],
#  'category_4_31': [],
#  'category_4_32': [],
#  'category_4_33': [[('แรม', '4g')], [('แรม', '4gb')], [('แรม', '8g')]],
#  'category_4_34': [],
#  'category_4_35': [],
#  'category_4_36': [],
#  'category_4_37': [],
#  'category_4_38': [],
#  'category_4_39': [],
#  'category_4_40': [[('แรม', '8gb')]],
#  'category_4_41': [],
#  'category_4_42': [[('แรม', '4'), ('ฮาร์ดดิสก์', '1')],
#   [('แรม', '8gb')],
#   [('แรม', '128gb')]],
#  'category_4_43': [],
#  'category_4_44': [],
#  'category_4_45': [[('แรม', '8gb')]],
#  'category_4_46': [],
#  'category_4_47': [],
#  'category_4_48': [[('ฮาร์ดดิสก์', 'geforce')]],
#  'category_4_49': [[('ฮาร์ดดิสก์', 'windows')],
#   [('แรม', '4gb')],
#   [('แรม', '8g')],
#   [('แรม', '4g')],
#   [('แรม', '4gb'), ('ฮาร์ดดิสก์', '320gb')]],
#  'category_4_50': [[('แรม', '128gb')],
#   [('แรม', '8gb')],
#   [('แรม', '4'), ('ฮาร์ดดิสก์', '1')],
#   [('ฮาร์ดดิสก์', 'ssd')]],
#  'category_4_51': [],
#  'category_4_52': [],
#  'category_4_53': [[('ฮาร์ดดิสก์', 'geforce')]],
#  'category_4_54': [[('ฮาร์ดดิสก์', 'windows')],
#   [('แรม', '4gb')],
#   [('แรม', '8g')],
#   [('แรม', '4g')],
#   [('แรม', '4gb'), ('ฮาร์ดดิสก์', '320gb')]],
#  'category_4_55': [[('ฮาร์ดดิสก์', 'geforce')]],
#  'category_4_56': [],
#  'category_4_57': [],
#  'category_4_58': [],
#  'category_4_59': [[('ฮาร์ดดิสก์', 'geforce')]],
#  'category_4_60': [[('แรม', '8gb')],
#   [('แรม', '4'), ('ฮาร์ดดิสก์', '1')],
#   [('แรม', '128gb')]],
#  'category_4_61': [],
#  'category_4_62': [[('ฮาร์ดดิสก์', 'windows')],
#   [('แรม', '8g')],
#   [('แรม', '4g')],
#   [('แรม', '4gb'), ('ฮาร์ดดิสก์', '320gb')],
#   [('แรม', 'srfcpro')]],
#  'category_4_63': [[('แรม', '8gb')], [('แรม', '4gb')], [('แรม', '128gb')]],
#  'category_4_64': [],
#  'category_4_65': [[('ฮาร์ดดิสก์', 'windows')],
#   [('แรม', '8g')],
#   [('แรม', '4g')],
#   [('แรม', '4gb'), ('ฮาร์ดดิสก์', '320gb')]],
#  'category_4_66': [],
#  'category_4_67': [],
#  'category_4_68': [],
#  'category_4_69': [[('แรม', '8gb')], [('แรม', '4gb')], [('แรม', '128gb')]],
#  'category_4_70': [[('ฮาร์ดดิสก์', 'windows')],
#   [('แรม', '8g')],
#   [('แรม', '4g')],
#   [('แรม', '4gb'), ('ฮาร์ดดิสก์', '320gb')]],
#  'category_4_71': [],
#  'category_4_72': [],
#  'category_4_73': [],
#  'category_4_74': [],
#  'category_4_75': [],
#  'category_4_76': [],
#  'category_4_77': [],
#  'category_4_78': [],
#  'category_4_79': [],
#  'category_4_80': [],
#  'category_4_81': [[('แรม', '8gb')],
#   [('แรม', '4'), ('ฮาร์ดดิสก์', '1')],
#   [('แรม', '4gb')]],
#  'category_4_82': [],
#  'category_4_83': [[('ฮาร์ดดิสก์', 'windows')],
#   [('แรม', '8gb'), ('ฮาร์ดดิสก์', '1tb')],
#   [('แรม', '8g')],
#   [('แรม', '4g')],
#   [('แรม', '8gb')],
#   [('แรม', '128gb')]],
#  'category_4_84': [],
#  'category_4_85': [],
#  'category_4_86': [],
#  'category_4_87': [],
#  'category_4_88': [],
#  'category_4_89': [[('แรม', '8gb')],
#   [('แรม', '4'), ('ฮาร์ดดิสก์', '1')],
#   [('แรม', '4gb')]],
#  'category_4_90': [[('ฮาร์ดดิสก์', 'windows')],
#   [('แรม', '8gb'), ('ฮาร์ดดิสก์', '1tb')],
#   [('แรม', '8g')],
#   [('แรม', '4g')]],
#  'category_4_91': [],
#  'category_4_92': [],
#  'category_4_93': [],
#  'category_4_94': [[('แรม', '8')]],
#  'category_4_95': [],
#  'category_4_96': [],
#  'category_4_97': [[('แรม', '8')]],
#  'category_4_98': [],
#  'category_4_99': [],
#  'category_4_100': [],
#  'category_4_101': [],
#  'category_4_102': [],
#  'category_4_103': [],
#  'category_4_104': [[('แรม', '8gb')], [('แรม', '4'), ('ฮาร์ดดิสก์', '1')]],
#  'category_4_105': [[('แรม', '4g')],
#   [('แรม', '8gb'), ('ฮาร์ดดิสก์', '1tb')],
#   [('ฮาร์ดดิสก์', 'windows')],
#   [('แรม', '128gb')]],
#  'category_4_106': [],
#  'category_4_107': [],
#  'category_4_108': [[('แรม', '8')]],
#  'category_4_109': [[('แรม', '8')]],
#  'category_4_110': [],
#  'category_4_111': [],
#  'category_4_112': [],
#  'category_4_113': [[('แรม', '8gb')],
#   [('แรม', '4'), ('ฮาร์ดดิสก์', '1')],
#   [('แรม', '16gb')]],
#  'category_4_114': [],
#  'category_4_115': [],
#  'category_4_116': [],
#  'category_4_117': [[('แรม', '4g')],
#   [('แรม', '8gb'), ('ฮาร์ดดิสก์', '1tb')],
#   [('แรม', 'srfcpro')],
#   [('ฮาร์ดดิสก์', 'windows')]],
#  'category_4_118': [],
#  'category_4_119': [],
#  'category_4_120': [],
#  'category_4_121': [],
#  'category_4_122': [],
#  'category_4_123': [],
#  'category_4_124': [],
#  'category_4_125': [],
#  'category_4_126': [],
#  'category_4_127': [[('แรม', '8g'), ('รอม', '512g')]],
#  'category_4_128': [],
#  'category_4_129': [],
#  'category_4_130': [],
#  'category_4_131': [],
#  'category_4_132': [[('แรม', '8gb')],
#   [('แรม', '4'), ('ฮาร์ดดิสก์', '1')],
#   [('แรม', '8'), ('ฮาร์ดดิสก์', '1')]],
#  'category_4_133': [],
#  'category_4_134': [[('แรม', '8g')]],
#  'category_4_135': [],
#  'category_4_136': [],
#  'category_4_137': [],
#  'category_4_138': [[('ฮาร์ดดิสก์', '256gb')]],
#  'category_4_139': [],
#  'category_4_140': [[('แรม', '8gb'), ('ฮาร์ดดิสก์', '1tb')]],
#  'category_4_141': [],
#  'category_4_142': [],
#  'category_4_143': [],
#  'category_4_144': [],
#  'category_4_145': [],
#  'category_4_146': [],
#  'category_4_147': [],
#  'category_4_148': [],
#  'category_4_149': [],
#  'category_4_150': [],
#  'category_4_151': [[('แรม', '8gb')]],
#  'category_4_152': [],
#  'category_4_153': [],
#  'category_4_154': [],
#  'category_4_155': [],
#  ...}

# %%
attr_list = {}
res = []
for i,v in attr.items():
    tmp_list = []
    for t in v:
        if type(t) != list:
            t_split = t.split(':')
            if len(t_split)<3:
                tmp_list.append(t_split)
        else:
            for ele in t:
                if (ele[0]!='' and ele[1]!=''):
                    res = [list(ele)]
            
            for l in res:
                tmp_list.append(l)
    attr_list[i] = tmp_list

# %%
attr_list
# Out:
# {'category_0_0': [['รอม', '64'], ['sku', ' 480942616 th 870640886']],
#  'category_0_1': [['แรม', '4'],
#   ['sku', ' 593772364 th 1113954823'],
#   ['แรม', '512mb'],
#   ['ความจุแบตเตอรี่', '1000']],
#  'category_0_2': [['sku', ' 404422189 th 784670279'],
#   ['แรม', '2gb'],
#   ['ความจุแบตเตอรี่', '1000']],
#  'category_0_3': [['sku', ' 385536916 th 749070165']],
#  'category_0_4': [['4g', 'lte'],
#   ['ระบบปฏิบัติการ', 'android'],
#   ['แรม', '3gb'],
#   ['การหาตำแหน่ง', 'assisted']],
#  'category_0_5': [['รอม', '6.3'],
#   ['จอแสดงผล', 'กว้าง'],
#   ['sku', ' 265390897 th 412154584']],
#  'category_0_6': [['รอม', '64'],
#   ['รอม', '64gb'],
#   ['2g', 'edge'],
#   ['จอแสดงผล', 'ตรวจจับความเคลื่อนไหวของตัวเครื่อง'],
#   ['sku', ' 594352438 th 1115888431'],
#   ['ความจุแบตเตอรี่', '1000']],
#  'category_0_7': [['sku', ' 599364278 th 1176694583']],
#  'category_0_8': [['sku', ' 309636084 th 547152150']],
#  'category_0_9': [['รอม', '32'],
#   ['sku', ' 571250946 th 1048780375'],
#   ['รอม', '32'],
#   ['ความจุแบตเตอรี่', '1000']],
#  'category_0_10': [['4g', 'lte'],
#   ['ระบบปฏิบัติการ', 'android'],
#   ['แรม', '3gb'],
#   ['การหาตำแหน่ง', 'assisted']],
#  'category_0_11': [['sku', ' sa861elaa8nxs2anth 17866375'], ['แรม', '3gb']],
#  'category_0_12': [['sku', ' 526004055 th 942110374']],
#  'category_0_13': [['รอม', '32'],
#   ['sku', ' 571320012 th 1048806072'],
#   ['รอม', '32'],
#   ['ความจุแบตเตอรี่', '1000']],
#  'category_0_14': [['แรม', '2gb'],
#   ['sku', ' 594306208 th 1115720937'],
#   ['ความจุแบตเตอรี่', '1000']],
#  'category_0_15': [['รอม', '6.4']],
#  'category_0_16': [['รอม', '6.1'], ['sku', ' 289434461 th 479544867']],
#  'category_0_17': [['น้ำหนัก', 'ยาว'],
#   ['ความละเอียด', '6.5'],
#   ['19.5', '9'],
#   ['รอม', '32'],
#   ['sku', ' 594338092 th 1115814517'],
#   ['ความจุแบตเตอรี่', '1000']],
#  'category_0_18': [['sku', ' 340860812 th 661136678'],
#   ['แรม', '8gb'],
#   ['ความจุแบตเตอรี่', '3000']],
#  'category_0_19': [['3g', 'hspa'],
#   ['ระบบปฏิบัติการ', 'android'],
#   ['แรม', '6gb'],
#   ['sku', ' 283666353 th 461390461']],
#  'category_0_20': [['sku', ' 616572478 th 1170962904']],
#  'category_0_21': [['sku', ' 307684896 th 537048806']],
#  'category_0_22': [['sku', ' 373972071 th 728742055']],
#  'category_0_23': [['sku', ' 310302392 th 552106447']],
#  'category_0_24': [['จอแสดงผล', 'กว้าง'],
#   ['sku', ' 280354579 th 453591358'],
#   ['แรม', '6gb'],
#   ['ความจุแบตเตอรี่', '1000']],
#  'category_0_25': [['แรม', '8'],
#   ['แรม', '8gbการ์ดหน่วยความจำ'],
#   ['sku', ' 595150747 th 1117932783']],
#  'category_0_26': [['จอแสดงผล', 'samoled'],
#   ['sku', ' 264741378 th 411062149'],
#   ['แรม', '4gb']],
#  'category_0_27': [['แรม', 'original'],
#   ['แบรนด์', 'new'],
#   ['sku', ' 617108827 th 1172618764'],
#   ['แรม', 'original']],
#  'category_0_28': [['sku', ' 511068392 th 907938105']],
#  'category_0_29': [['แรม', '4gb'],
#   ['แรม', '4gb'],
#   ['sku', ' 207916690 th 313021622']],
#  'category_0_30': [['รอม', '6.4'], ['sku', ' 289426638 th 479560515']],
#  'category_0_31': [['แรม', '3'],
#   ['ระบบปฏิบัติการ', 'android'],
#   ['sku', ' 289402378 th 479508064'],
#   ['แรม', '3']],
#  'category_0_32': [['รอม', '128gb'], ['รอม', '10.5']],
#  'category_0_33': [['แบรนด์', 'new'], ['sku', ' 612014873 th 1155486191']],
#  'category_0_34': [['3g', 'hspa'],
#   ['รอม', '128gb'],
#   ['sku', ' 283658415 th 461387419']],
#  'category_0_35': [['แบรนด์', 'new'],
#   ['แบรนด์', 'new'],
#   ['sku', ' 610820644 th 1151996547']],
#  'category_0_36': [['แบรนด์', 'new'], ['sku', ' 617168251 th 1172664402']],
#  'category_0_37': [['รอม', '6.4']],
#  'category_0_38': [['รอม', '6.4'],
#   ['19.5', '9'],
#   ['sku', ' 299990648 th 515722325']],
#  'category_0_39': [['sku', ' 408012228 th 792604544']],
#  'category_0_40': [['จอแสดงผล', 'hotspot'],
#   ['sku', ' 213755551 th 1138512951'],
#   ['แรม', '2gb'],
#   ['ความจุแบตเตอรี่', '1000']],
#  'category_0_41': [['sku', ' 222527681 th 889412058'],
#   ['แรม', '4gb'],
#   ['ความจุแบตเตอรี่', '4000']],
#  'category_0_42': [['sku', ' 595884854 th 1119120013']],
#  'category_0_43': [['19', '9'],
#   ['sku', ' 611154425 th 1152864043'],
#   ['แรม', '4gb'],
#   ['ความจุแบตเตอรี่', '1000']],
#  'category_0_44': [['แรม', '6'],
#   ['จอแสดงผล', 'ระบบหมุนภาพอัตโนมัติ'],
#   ['2g', 'edge'],
#   ['ระบบปฏิบัติการ', 'miui'],
#   ['รอม', '64'],
#   ['การหาตำแหน่ง', 'assisted']],
#  'category_0_45': [['รอม', '10.5'], ['รอม', '64']],
#  'category_0_46': [['รอม', '64'],
#   ['sku', ' 533460461 th 963560027'],
#   ['แรม', '4gb'],
#   ['ความจุแบตเตอรี่', '1000']],
#  'category_0_47': [['sku', ' 495988905 th 884338021'],
#   ['แรม', '3gb'],
#   ['ความจุแบตเตอรี่', '1000']],
#  'category_0_48': [['2g', 'edge'],
#   ['ระบบปฏิบัติการ', 'miui'],
#   ['แรม', '6'],
#   ['รอม', '128gb']],
#  'category_0_49': [['sku', ' 234902116 th 713640836'],
#   ['ความจุแบตเตอรี่', '4000']],
#  'category_0_50': [['sku', ' 494026300 th 882746256']],
#  'category_0_51': [['รอม', '128'],
#   ['รอม', '128gb'],
#   ['ความหนา', '9.67'],
#   ['น้ำหนัก', '208'],
#   ['sku', ' 604332862 th 1137128463']],
#  'category_0_52': [['แรม', '8gb'],
#   ['รอม', '256gb'],
#   ['sku', ' 611792752 th 1155040122']],
#  'category_0_53': [['กล้องด้านหน้า', '20.ล้านพิกเซล'],
#   ['sku', ' 343546977 th 668396557']],
#  'category_0_54': [['รอม', '128gb']],
#  'category_0_55': [['sku', ' 587988556 th 1092062042'],
#   ['แรม', '3gb'],
#   ['ความจุแบตเตอรี่', '1000']],
#  'category_0_56': [['แรม', '4'],
#   ['2g', 'edge'],
#   ['ระบบปฏิบัติการ', 'miui'],
#   ['รอม', '64gb'],
#   ['sku', ' 526910733 th 944832734'],
#   ['แรม', '4gb'],
#   ['ความจุแบตเตอรี่', '1000']],
#  'category_0_57': [['sku', ' 221761904 th 931764445'],
#   ['แรม', '4gb'],
#   ['ความจุแบตเตอรี่', '4000']],
#  'category_0_58': [['รอม', '3g'], ['รอม', '10.5']],
#  'category_0_59': [['รอม', '128gb'],
#   ['รอม', '128gb'],
#   ['sku', ' 595984523 th 1119224437']],
#  'category_0_60': [['แรม', '4'],
#   ['จอแสดงผล', 'กว้าง'],
#   ['2g', 'edge'],
#   ['ระบบปฏิบัติการ', 'miui'],
#   ['รอม', '32'],
#   ['การหาตำแหน่ง', 'assisted'],
#   ['sku', ' 612338298 th 1156318935']],
#  'category_0_61': [['รอม', 'dualcameras'],
#   ['dualcameras', 'frontcamera16.ล้านพิกเซล'],
#   ['sku', ' 615188295 th 1166414603'],
#   ['แรม', '3gb'],
#   ['ความจุแบตเตอรี่', '3000']],
#  'category_0_62': [['แรม', '2'],
#   ['2g', 'edge'],
#   ['ระบบปฏิบัติการ', 'miui'],
#   ['รอม', '32gb'],
#   ['การหาตำแหน่ง', 'assisted'],
#   ['sku', ' 524454971 th 937876465']],
#  'category_0_63': [['รอม', '128gb'],
#   ['coreความถี่', 'สูงสุด'],
#   ['ความละเอียด', '2340'],
#   ['sku', ' 600264311 th 1129088854'],
#   ['แรม', '6gb'],
#   ['ความจุแบตเตอรี่', '5000']],
#  'category_0_64': [['รอม', '64'], ['รอม', '128gb']],
#  'category_0_65': [['sku', ' 273675979 th 909150212'],
#   ['แรม', '6gb'],
#   ['ความจุแบตเตอรี่', '4000']],
#  'category_0_66': [['sku', ' 602338133 th 1134472444'],
#   ['แรม', '6gb'],
#   ['ความจุแบตเตอรี่', '4000']],
#  'category_0_67': [['รอม', '3g'], ['รอม', '10.5']],
#  'category_0_68': [['sku', ' 602306922 th 1134540658'],
#   ['แรม', '6gb'],
#   ['ความจุแบตเตอรี่', '4000']],
#  'category_0_69': [['ระบบปฏิบัติการ', 'android'],
#   ['sku', ' 594522639 th 1116438503'],
#   ['ความจุแบตเตอรี่', '3000']],
#  'category_0_70': [['2g', 'edge'],
#   ['ระบบปฏิบัติการ', 'miui'],
#   ['แรม', '2'],
#   ['รอม', '16']],
#  'category_0_71': [['2g', 'edge'],
#   ['ระบบปฏิบัติการ', 'miui'],
#   ['แรม', '2'],
#   ['รอม', '32gb']],
#  'category_0_72': [['2g', 'edge'],
#   ['ระบบปฏิบัติการ', 'miui'],
#   ['รอม', '64'],
#   ['การหาตำแหน่ง', 'assisted'],
#   ['sku', ' 477810714 th 868398689'],
#   ['แรม', '32gb']],
#  'category_0_73': [['ระบบปฏิบัติการ', 'android'],
#   ['sku', ' 594600147 th 1116542821'],
#   ['ความจุแบตเตอรี่', '3000']],
#  'category_0_74': [['sku', ' 587986529 th 1092060094'],
#   ['แรม', '6gb'],
#   ['ความจุแบตเตอรี่', '1000']],
#  'category_0_75': [['จอแสดงผล', 'ระบบหมุนภาพอัตโนมัติ'],
#   ['ระบบปฏิบัติการ', 'miui'],
#   ['แรม', '6'],
#   ['2g', 'edge'],
#   ['การหาตำแหน่ง', 'assisted'],
#   ['sku', ' 264227445 th 791158102']],
#  'category_0_76': [['รอม', '64'], ['รอม', '128gb']],
#  'category_0_77': [['2g', 'edge'],
#   ['ระบบปฏิบัติการ', 'miui'],
#   ['รอม', '16'],
#   ['การหาตำแหน่ง', 'assisted']],
#  'category_0_78': [['รอม', '8gb'],
#   ['แบรนด์', 'new'],
#   ['sku', ' 617148976 th 1172758996'],
#   ['รอม', '8gb']],
#  'category_0_79': [['ชิปประมวลผลรุ่นเรือธงcpu', 'snapdragon'],
#   ['cpu', 'สถาปัตยกรรม'],
#   ['cpu', 'ชิปประมวลผลระดับ'],
#   ['qualcomm', '1'],
#   ['cpu', '45เปอร์เซนต์'],
#   ['พัฒนาความสามารถ', '40เปอร์เซนต์'],
#   ['gpu', ' adreno 640'],
#   ['gpu', '20เปอร์เซนต์'],
#   ['พัฒนาความสามารถ', '25เปอร์เซนต์'],
#   ['aie', 'ตัวประมวล'],
#   ['จอแสดงผล', 'มัลติคัลเลอร์'],
#   ['9ram', 'ช่องสัญญาณคู่'],
#   ['ความละเอียด', '2340'],
#   ['ความสว่าง', '600nit'],
#   ['gamut', 'ntsc'],
#   ['ซูม', 'ซูม']],
#  'category_0_80': [['แรม', '3gb'],
#   ['sku', ' 601804919 th 1133136752'],
#   ['แรม', '3gb'],
#   ['ความจุแบตเตอรี่', '1000']],
#  'category_0_81': [['รอม', '64gb'], ['sku', ' 594172715 th 1115450949']],
#  'category_0_82': [['sku', ' 368406522 th 720230984']],
#  'category_0_83': [['sku', ' 596522329 th 1119982547']],
#  'category_0_84': [['รอม', '64'],
#   ['sku', ' 561194526 th 1029420220'],
#   ['แรม', '3gb'],
#   ['ความจุแบตเตอรี่', '5000']],
#  'category_0_85': [['sku', ' 594468094 th 1116094894'],
#   ['แรม', '6gb'],
#   ['ความจุแบตเตอรี่', '1000']],
#  'category_0_86': [['sku', ' 463662961 th 851448786'],
#   ['ความจุแบตเตอรี่', '1000']],
#  'category_0_87': [['sku', ' 535266417 th 967736081']],
#  'category_0_88': [['sku', ' 423372568 th 807510964']],
#  'category_0_89': [['sku', ' 585868817 th 1085346089'],
#   ['แรม', '3gb'],
#   ['ความจุแบตเตอรี่', '1000']],
#  'category_0_90': [['รอม', '128'],
#   ['sku', ' 560716580 th 1028340869'],
#   ['แรม', '8gb'],
#   ['ความจุแบตเตอรี่', '5000']],
#  'category_0_91': [['camera', '12m'],
#   ['รอม', '128gb'],
#   ['box', '1.'],
#   ['sku', ' 450862429 th 833064273'],
#   ['ความจุแบตเตอรี่', '30001']],
#  'category_0_92': [['รอม', '64gb'], ['รอม', '3g'], ['รอม', '10.5']],
#  'category_0_93': [['3g', 'hspa'],
#   ['ระบบปฏิบัติการ', 'colorระบบปฏิบัติการ'],
#   ['แรม', '2'],
#   ['การหาตำแหน่ง', 'assisted']],
#  'category_0_94': [['ระบบปฏิบัติการ', 'colorระบบปฏิบัติการ'],
#   ['แรม', '2gb'],
#   ['การหาตำแหน่ง', 'assisted'],
#   ['sku', ' 247483720 th 381013589']],
#  'category_0_95': [['colorระบบปฏิบัติการ', '5.0'],
#   ['4g', 'lte'],
#   ['sku', ' 602816227 th 1135834467'],
#   ['แรม', '6gb']],
#  'category_0_96': [['แรม', '3'],
#   ['gsm', ' 850 900 1800 1900mhz'],
#   ['wcdma', 'bands'],
#   ['lte', 'bands'],
#   ['lte', 'bands'],
#   ['sku', ' 593798249 th 1114132244'],
#   ['ความจุแบตเตอรี่', '1000']],
#  'category_0_97': [['sku', ' 521740370 th 929150153'], ['แรม', '3gb']],
#  'category_0_98': [['รอม', '64'], ['จอแสดงผล', 'ชิปเซต']],
#  'category_0_99': [['sku', ' 333366885 th 778320295']],
#  'category_0_100': [],
#  'category_0_101': [['จอแสดงผล', 'ชิปเซต'],
#   ['รอม', 'up'],
#   ['sku', ' 341378077 th 675334858'],
#   ['ความจุแบตเตอรี่', '30001']],
#  'category_0_102': [['จอแสดงผล', 'ระบบหมุนภาพอัตโนมัติ'],
#   ['sku', ' 561338580 th 1029522253'],
#   ['แรม', '8gb'],
#   ['ความจุแบตเตอรี่', '1000']],
#  'category_0_103': [['cpu', ' snapdragon 665 และ game boost 2.0'],
#   ['sku', ' 464602916 th 852566078'],
#   ['ความจุแบตเตอรี่', '5000']],
#  'category_0_104': [['รอม', '3g'], ['รอม', '10.5'], ['รอม', '64gb']],
#  'category_0_105': [['3g', 'hspa'],
#   ['จอแสดงผล', 'ระบบสัมผัส'],
#   ['ระบบปฏิบัติการ', 'colorระบบปฏิบัติการ'],
#   ['แรม', '6gb'],
#   ['การหาตำแหน่ง', 'assisted']],
#  'category_0_106': [['sku', ' 535274298 th 967670887'],
#   ['แรม', '3gb'],
#   ['ความจุแบตเตอรี่', '1000']],
#  'category_0_107': [['แรม', '3'],
#   ['2g', 'edge'],
#   ['ระบบปฏิบัติการ', 'colorระบบปฏิบัติการ'],
#   ['รอม', '64gb'],
#   ['การหาตำแหน่ง', 'assisted'],
#   ['sku', ' 593006855 th 1111420743'],
#   ['ความจุแบตเตอรี่', '1000']],
#  'category_0_108': [['แรม', '4'],
#   ['ระบบปฏิบัติการ', 'colorระบบปฏิบัติการ'],
#   ['sku', ' 534116952 th 965278124'],
#   ['แรม', '4'],
#   ['แรม', '4gb'],
#   ['ความจุแบตเตอรี่', '4000']],
#  'category_0_109': [['จอแสดงผล', 'ชิปเซต']],
#  'category_0_110': [['รอม', '3g'], ['รอม', '10.5'], ['รอม', '64gb']],
#  'category_0_111': [['จอแสดงผล', 'ชิปเซต']],
#  'category_0_112': [['สี', 'พังก์บลูและไอน้ำสีขาว'],
#   ['หน้าจอ', 'fhd'],
#   ['ป๊อปอัพกล้องเซลฟี่', '1ล้านพิกเซล'],
#   ['แบบคู่กล้องหลัง', '4ล้านพิกเซล'],
#   ['sku', ' 397028849 th 771186043'],
#   ['sku', 'c17722'],
#   ['แรม', '4gb'],
#   ['ความจุแบตเตอรี่', '3000']],
#  'category_0_113': [['รอม', '3g'], ['รอม', '10.5'], ['รอม', '64gb']],
#  'category_0_114': [['จอแสดงผล', 'ระบบสัมผัส'],
#   ['4g', 'lte'],
#   ['ระบบปฏิบัติการ', 'colorระบบปฏิบัติการ'],
#   ['รอม', '64'],
#   ['การหาตำแหน่ง', 'assisted']],
#  'category_0_115': [['3g', 'hsdpa'],
#   ['ระบบปฏิบัติการ', 'colorระบบปฏิบัติการ'],
#   ['รอม', '64gb'],
#   ['sku', ' 348144719 th 681012331'],
#   ['แรม', '4gb']],
#  'category_0_116': [['แรม', '3'],
#   ['2g', 'edge'],
#   ['ระบบปฏิบัติการ', 'colorระบบปฏิบัติการ'],
#   ['รอม', '64gb'],
#   ['การหาตำแหน่ง', 'assisted'],
#   ['sku', ' 601974390 th 1133472706'],
#   ['แรม', '3'],
#   ['แรม', '3gb']],
#  'category_0_117': [['sku', ' 563834910 th 1033632588'],
#   ['แรม', '4gb'],
#   ['ความจุแบตเตอรี่', '4000']],
#  'category_0_118': [['แรม', '2'],
#   ['sku', ' 612114232 th 1155648106'],
#   ['แรม', '2'],
#   ['แรม', '2gb'],
#   ['ความจุแบตเตอรี่', '4000']],
#  'category_0_119': [['sku', ' 594318240 th 1115776512'],
#   ['ความจุแบตเตอรี่', '4000']],
#  'category_0_120': [['แบตเตอรี่', '5000mah'],
#   ['แบตเตอรี่', '5000mah'],
#   ['sku', ' 517866127 th 919968463']],
#  'category_0_121': [['รอม', '64'],
#   ['sku', ' 590034214 th 1151538667'],
#   ['แรม', '4gb'],
#   ['ความจุแบตเตอรี่', '1000']],
#  'category_0_122': [['รอม', '128gb']],
#  'category_0_123': [['รอม', '128'],
#   ['รอม', '128'],
#   ['sku', ' 595656544 th 1118856653'],
#   ['แรม', '8gb'],
#   ['ความจุแบตเตอรี่', '1000']],
#  'category_0_124': [['sku', ' 587972692 th 1092032386'],
#   ['แรม', '8gb'],
#   ['ความจุแบตเตอรี่', '1000']],
#  'category_0_125': [['รอม', '128gb'],
#   ['รอม', 'เพิ่มเมมโมเรี่ได้สูงสุด'],
#   ['funtouchระบบปฏิบัติการ', '9.2'],
#   ['sku', ' 599192867 th 1127342158'],
#   ['แรม', '8gb'],
#   ['ความจุแบตเตอรี่', '4000']],
#  'category_0_126': [['duty', 'we'],
#   ['sku', ' 616436256 th 1170664199'],
#   ['แรม', '8gb'],
#   ['ความจุแบตเตอรี่', '1000']],
#  'category_0_127': [['รอม', 'เครื่องใหม่'],
#   ['ระบบปฏิบัติการfuntouchระบบปฏิบัติการ', '9.2'],
#   ['ขนาดตัวเครื่อง', '159.25'],
#   ['น้ำหนัก', '186.7'],
#   ['sku', ' 599066750 th 1127098963'],
#   ['แรม', '128gb']],
#  'category_0_128': [['รอม', '128gbกล้องถ่ายรูปด้านหลัง'],
#   ['sku', ' 612664987 th 1157674465'],
#   ['แรม', '8gb'],
#   ['ความจุแบตเตอรี่', '4000']],
#  'category_0_129': [['จอแสดงผล', '6.53'], ['sku', ' 525912975 th 942022546']],
#  'category_0_130': [['รอม', '3g'], ['รอม', '10.5'], ['รอม', '64gb']],
#  'category_0_131': [['รอม', '128gb']],
#  'category_0_132': [['แรม', '2'],
#   ['sku', ' 328508874 th 629190573'],
#   ['แรม', '2gb']],
#  'category_0_133': [['q', ' how to track the order '],
#   ['q', ' about network bands'],
#   ['q', ' what if i m dissatisfied with the product '],
#   ['a',
#    ' we guarantee you will be 100เปอร์เซนต์ satisfied with the quality of your product. if you re unhappy with it please contact our customer service who will be glad to help.when contacting customer service team please give your order number a short description and a photo of the problem so we can prevent these problems in the future.'],
#   ['แบรนด์', 'at'],
#   ['sku', ' 604588733 th 1137744184'],
#   ['แรม', '6gb'],
#   ['ความจุแบตเตอรี่', '1000']],
#  'category_0_134': [['รอม', '128gb'],
#   ['รอม', 'เพิ่มเมมโมเรี่ได้สูงสุด'],
#   ['funtouchระบบปฏิบัติการ', '9.2'],
#   ['sku', ' 599300858 th 1127464169'],
#   ['แรม', '8gb'],
#   ['ความจุแบตเตอรี่', '4000']],
#  'category_0_135': [['q', ' how to track the order '],
#   ['q', ' about network bands'],
#   ['q', ' what if i m dissatisfied with the product '],
#   ['a',
#    ' we guarantee you will be 100เปอร์เซนต์ satisfied with the quality of your product. if you re unhappy with it please contact our customer service who will be glad to help.when contacting customer service team please give your order number a short description and a photo of the problem so we can prevent these problems in the future.'],
#   ['แบรนด์', 'at'],
#   ['sku', ' 604632624 th 1137814458'],
#   ['แรม', '6gb'],
#   ['ความจุแบตเตอรี่', '1000']],
#  'category_0_136': [['รอม', '128gb'],
#   ['จอแสดงผล', 'กว้าง'],
#   ['จอแสดงผล', 'ระบบหมุนภาพอัตโนมัติ'],
#   ['3g', 'hspa'],
#   ['ระบบปฏิบัติการ', 'funtouchระบบปฏิบัติการ'],
#   ['รอม', '128gb'],
#   ['การหาตำแหน่ง', 'assisted']],
#  'category_0_137': [['sku', ' 616744349 th 1171552379']],
#  'category_0_138': [['q', ' how to track the order '],
#   ['q', ' about network bands'],
#   ['q', ' what if i m dissatisfied with the product '],
#   ['a',
#    ' we guarantee you will be 100เปอร์เซนต์ satisfied with the quality of your product. if you re unhappy with it please contact our customer service who will be glad to help.when contacting customer service team please give your order number a short description and a photo of the problem so we can prevent these problems in the future.'],
#   ['แบรนด์', 'at'],
#   ['sku', ' 604648308 th 1137718830'],
#   ['แรม', '8gb'],
#   ['ความจุแบตเตอรี่', '1000']],
#  'category_0_139': [['รอม', '64gb'],
#   ['รอม', 'เพิ่มเมมโมเรี่ได้สูงสุด'],
#   ['จอแสดงผล', 'ขนาด'],
#   ['sku', ' 618416957 th 1177008040'],
#   ['แรม', '4gb'],
#   ['ความจุแบตเตอรี่', '5000']],
#  'category_0_140': [['รอม', '128gb'],
#   ['จอแสดงผล', 'fingerprint'],
#   ['sku', ' 561416932 th 1029822407'],
#   ['แรม', '8gb'],
#   ['ความจุแบตเตอรี่', '1000']],
#  'category_0_141': [['q', ' how to track the order '],
#   ['q', ' about network bands'],
#   ['q', ' what if i m dissatisfied with the product '],
#   ['a',
#    ' we guarantee you will be 100เปอร์เซนต์ satisfied with the quality of your product. if you re unhappy with it please contact our customer service who will be glad to help.when contacting customer service team please give your order number a short description and a photo of the problem so we can prevent these problems in the future.'],
#   ['แบรนด์', 'at'],
#   ['sku', ' 604770080 th 1138152071'],
#   ['แรม', '3gb'],
#   ['ความจุแบตเตอรี่', '1000']],
#  'category_0_142': [['q', ' how to track the order '],
#   ['q', ' about network bands'],
#   ['q', ' what if i m dissatisfied with the product '],
#   ['a',
#    ' we guarantee you will be 100เปอร์เซนต์ satisfied with the quality of your product. if you re unhappy with it please contact our customer service who will be glad to help.when contacting customer service team please give your order number a short description and a photo of the problem so we can prevent these problems in the future.'],
#   ['แบรนด์', 'at'],
#   ['sku', ' 604694624 th 1137940704'],
#   ['แรม', '6gb'],
#   ['ความจุแบตเตอรี่', '1000']],
#  'category_0_143': [['ระบบปฏิบัติการ', 'funtouchระบบปฏิบัติการ'],
#   ['แรม', '6'],
#   ['รอม', '64'],
#   ['sku', ' 569488592 th 1045390934'],
#   ['ความจุแบตเตอรี่', '1000']],
#  'category_0_144': [['แบรนด์', 'at'],
#   ['sku', ' 615690512 th 1168470733'],
#   ['แรม', '6gb'],
#   ['ความจุแบตเตอรี่', '1000']],
#  'category_0_145': [['faqq', ' how to track the order '],
#   ['q', ' about network bands'],
#   ['q', ' what if i m dissatisfied with the product '],
#   ['a',
#    ' we guarantee you will be 100เปอร์เซนต์ satisfied with the quality of your product. if you re unhappy with it please contact our customer service who will be glad to help.when contacting customer service team please give your order number a short description and a photo of the problem so we can prevent these problems in the future.'],
#   ['แบรนด์', 'at'],
#   ['sku', ' 604548331 th 1137518592'],
#   ['แรม', '8gb'],
#   ['ความจุแบตเตอรี่', '1000']],
#  'category_0_146': [['q', ' how to track the order '],
#   ['q', ' about network bands'],
#   ['q', ' what if i m dissatisfied with the product '],
#   ['a',
#    ' we guarantee you will be 100เปอร์เซนต์ satisfied with the quality of your product. if you re unhappy with it please contact our customer service who will be glad to help.when contacting customer service team please give your order number a short description and a photo of the problem so we can prevent these problems in the future.'],
#   ['แบรนด์', 'at'],
#   ['sku', ' 604796218 th 1138260078'],
#   ['แรม', '8gb'],
#   ['ความจุแบตเตอรี่', '1000']],
#  'category_0_147': [['ระบบปฎิบัติการfuntouchระบบปฏิบัติการ', '9'],
#   ['sku', ' 373546910 th 728028139'],
#   ['ความจุแบตเตอรี่', '4000']],
#  'category_0_148': [['ระบบปฏิบัติการ', 'funtouchระบบปฏิบัติการ'],
#   ['รอม', '128gb'],
#   ['แรม', '6'],
#   ['การหาตำแหน่ง', 'assisted']],
#  'category_0_149': [['รอม', '10.5'], ['รอม', '3g']],
#  'category_0_150': [['faqq', ' how to track the order '],
#   ['q', ' about network bands'],
#   ['q', ' what if i m dissatisfied with the product '],
#   ['a',
#    ' we guarantee you will be 100เปอร์เซนต์ satisfied with the quality of your product. if you re unhappy with it please contact our customer service who will be glad to help.when contacting customer service team please give your order number a short description and a photo of the problem so we can prevent these problems in the future.'],
#   ['แบรนด์', 'at'],
#   ['sku', ' 604540891 th 1137654540'],
#   ['แรม', '6gb'],
#   ['ความจุแบตเตอรี่', '1000']],
#  'category_0_151': [['q', ' how to track the order '],
#   ['q', ' about network bands'],
#   ['q', ' what if i m dissatisfied with the product '],
#   ['a',
#    ' we guarantee you will be 100เปอร์เซนต์ satisfied with the quality of your product. if you re unhappy with it please contact our customer service who will be glad to help.when contacting customer service team please give your order number a short description and a photo of the problem so we can prevent these problems in the future.'],
#   ['แบรนด์', 'at'],
#   ['sku', ' 604696718 th 1138034104'],
#   ['แรม', '6gb'],
#   ['ความจุแบตเตอรี่', '1000']],
#  'category_0_152': [['จอแสดงผล', 'ขนาด6.35'],
#   ['3g', 'hspa'],
#   ['จอแสดงผล', 'ระบบสัมผัส'],
#   ['ระบบปฏิบัติการ', 'funtouchระบบปฏิบัติการ'],
#   ['แรม', '4gb'],
#   ['การหาตำแหน่ง', 'assisted']],
#  'category_0_153': [['รอม', '64gb'],
#   ['รอม', '64gb'],
#   ['funtouchระบบปฏิบัติการ', '9'],
#   ['หมายเหตุ', 'โปรโมชั่นของแถมอาจมีการเปลี่ยนแปลงโดยไม่แจ้งให้ทราบล่วงหน้า'],
#   ['sku', ' 598708474 th 1126022611'],
#   ['ความจุแบตเตอรี่', '1000']],
#  'category_0_154': [['q', ' how to track the order '],
#   ['q', ' about network bands'],
#   ['q', ' what if i m dissatisfied with the product '],
#   ['a',
#    ' we guarantee you will be 100เปอร์เซนต์ satisfied with the quality of your product. if you re unhappy with it please contact our customer service who will be glad to help.when contacting customer service team please give your order number a short description and a photo of the problem so we can prevent these problems in the future.'],
#   ['แบรนด์', 'at'],
#   ['sku', ' 604840484 th 1138436028'],
#   ['แรม', '8gb'],
#   ['ความจุแบตเตอรี่', '1000']],
#  'category_0_155': [['q', ' how to track the order '],
#   ['q', ' about network bands'],
#   ['q', ' what if i m dissatisfied with the product '],
#   ['a',
#    ' we guarantee you will be 100เปอร์เซนต์ satisfied with the quality of your product. if you re unhappy with it please contact our customer service who will be glad to help.when contacting customer service team please give your order number a short description and a photo of the problem so we can prevent these problems in the future.'],
#   ['แบรนด์', 'at'],
#   ['sku', ' 604710729 th 1138026540'],
#   ['แรม', '4gb'],
#   ['ความจุแบตเตอรี่', '1000']],
#  'category_0_156': [['sku', ' 259769078 th 399969081'],
#   ['ความจุแบตเตอรี่', '1000']],
#  'category_0_157': [['แบรนด์', 'at'],
#   ['sku', ' 615722552 th 1168598091'],
#   ['แรม', '8gb'],
#   ['ความจุแบตเตอรี่', '1000']],
#  'category_0_158': [['แรม', '8gb'],
#   ['2g', 'edge'],
#   ['3g', 'hspa'],
#   ['ระบบปฏิบัติการ', 'funtouchระบบปฏิบัติการ'],
#   ['แรม', '8gb']],
#  'category_0_159': [['2g', 'edge'],
#   ['ระบบปฏิบัติการ', 'funtouchระบบปฏิบัติการ'],
#   ['รอม', '32gb'],
#   ['การหาตำแหน่ง', 'assisted']],
#  'category_0_160': [['รอม', '64'], ['sku', ' 600314964 th 1129342245']],
#  'category_0_161': [['รอม', '128'],
#   ['2g', 'edge'],
#   ['ระบบปฏิบัติการ', 'emui'],
#   ['รอม', '128gb'],
#   ['การหาตำแหน่ง', 'assisted'],
#   ['sku', ' 596214366 th 1119566057'],
#   ['แรม', '512mb']],
#  'category_0_162': [['sku', ' 596222116 th 1119494559']],
#  'category_0_163': [['cpu', 'mtk'], ['sku', ' 594192103 th 1115374774']],
#  'category_0_164': [['รอม', '128'],
#   ['หน้าจอ', '6.59'],
#   ['cpu',
#    ' huawei kirin 710f octa core 4 x cortex a73 based 2.2 ghz 4 x cortex a53 based 1.7 ghz'],
#   ['ระบบปฏิบัติการ', 'emui'],
#   ['รอม', '128'],
#   ['กล้องหน้า', '1ล้านพิกเซล'],
#   ['กล้องหลัง', '4ล้านพิกเซล'],
#   ['แบตเตอรี่', '4000'],
#   ['sku', ' 601420142 th 1132208267'],
#   ['แรม', '6gb'],
#   ['ความจุแบตเตอรี่', '1000']],
#  'category_0_165': [['ระบบปฎิบัติการ', 'android'],
#   ['sku', ' 289716515 th 847906769'],
#   ['แรม', '3gb'],
#   ['ความจุแบตเตอรี่', '4000']],
#  'category_0_166': [['sku', ' 528100922 th 947986549']],
#  'category_0_167': [['sku', ' 375868110 th 732110495'],
#   ['ความจุแบตเตอรี่', '1000']],
#  'category_0_168': [['แรม', 'รองรับ'], ['sku', ' 601192402 th 1131434450']],
#  'category_0_169': [['รอม', '64'],
#   ['2g', 'edge'],
#   ['ระบบปฏิบัติการ', 'emui'],
#   ['รอม', '64gb'],
#   ['การหาตำแหน่ง', 'assisted'],
#   ['sku', ' 599110939 th 1127098782'],
#   ['รอม', '64'],
#   ['แรม', '3gb']],
#  'category_0_170': [['วิดีโอ', '1920'],
#   ['ppi', '391'],
#   ['gsm', 'b2'],
#   ['umts', 'b1'],
#   ['tdd', 'b38'],
#   ['fdd', 'b1']],
#  'category_0_171': [['sku', ' 593028182 th 1112374566'],
#   ['แรม', '3gb'],
#   ['ความจุแบตเตอรี่', '3000']],
#  'category_0_172': [['แรม', '3'],
#   ['gsm', 'bands'],
#   ['wcdma', 'bands'],
#   ['lte', 'bands'],
#   ['lte', 'bands'],
#   ['sku', ' 596394547 th 1119824766'],
#   ['ความจุแบตเตอรี่', '1000']],
#  'category_0_173': [['แรม', '3gb'],
#   ['sku', ' 320064385 th 812406952'],
#   ['แรม', '3gb']],
#  'category_0_174': [['sku', ' 357150478 th 699988012']],
#  'category_0_175': [['แรม', '฿'],
#   ['รอม', '64'],
#   ['รอม', '128gb'],
#   ['แรม', '3gb'],
#   ['แรม', '8']],
#  'category_0_176': [['แรม', '6gb'],
#   ['ระบบปฏิบัติการ', 'emui'],
#   ['รอม', '128gb'],
#   ['2g', 'edge'],
#   ['sku', ' 594532004 th 1116304128'],
#   ['ความจุแบตเตอรี่', '1000']],
#  'category_0_177': [['แรม', '6'],
#   ['sku', ' 594462946 th 1116358223'],
#   ['แรม', '6']],
#  'category_0_178': [['sku', ' 594398527 th 1116232042'],
#   ['ความจุแบตเตอรี่', '1000']],
#  'category_0_179': [['จอแสดงผล', '6.09'],
#   ['ความปลอดภัย', 'สแกนลายนิ้วมือที่ข้างตัวเครื่อง'],
#   ['พอร์ต', 'แจ๊ค'],
#   ['กล้องหน้า', 'ความละเอียด'],
#   ['กล้องหลัง', 'ความละเอียด'],
#   ['ชิปเซ็ต', 'mediatek'],
#   ['แบตเตอรี', '3200'],
#   ['ระบบปฎิบัติการณ์', 'android'],
#   ['สี', 'starry'],
#   ['sku', ' 594270092 th 1115594659'],
#   ['ความจุแบตเตอรี่', '30001']],
#  'category_0_180': [['แรม', 'รองรับ'], ['sku', ' 596522728 th 1120102293']],
#  'category_0_181': [['ขนาดหน้าจอ', '6.59'],
#   ['ประเภทหน้าจอ', 'tft'],
#   ['สีหน้าจอ', '16.7'],
#   ['ความละเอียดหน้าจอ', '2340'],
#   ['หน่วยความจำภายใน', '4'],
#   ['กล้องด้านหน้า', '16'],
#   ['mแบตเตอรี่', '4000'],
#   ['จอแสดงผล', 'ระบบสัมผัส'],
#   ['ระบบปฏิบัติการ', 'android'],
#   ['รอม', '128gb']],
#  'category_0_182': [['แรม', '4'],
#   ['แรม', '4gb'],
#   ['sku', ' 328258784 th 628690621'],
#   ['แรม', '4'],
#   ['แรม', '4gb']],
#  'category_0_183': [['sku', ' 342498502 th 665538006']],
#  'category_0_184': [['รอม', '64'],
#   ['รอม', '64'],
#   ['output', '5v1a'],
#   ['sku', ' 596756304 th 1120612454']],
#  'category_0_185': [['รอม', '64'],
#   ['กล้อง', 'กล้องหน้า'],
#   ['กล้อง', 'กล้องหน้า'],
#   ['รอม', '64'],
#   ['sku', ' 291298342 th 483916431']],
#  'category_0_186': [['แรม', '6'],
#   ['ชิปเซ็ต', 'kirin'],
#   ['ram', ' 6gb'],
#   ['ความจุ', '128gb'],
#   ['sku', ' 598526513 th 1125486439']],
#  'category_0_187': [['แรม', '8'],
#   ['gsm', 'แบนด์'],
#   ['tds', 'แบนด์'],
#   ['lte', 'แบนด์'],
#   ['sku', ' 358866806 th 704258251'],
#   ['แรม', '8']],
#  'category_0_188': [['รอม', '64'],
#   ['กล้อง', 'กล้องหน้า'],
#   ['กล้อง', 'กล้องหน้า'],
#   ['รอม', '64'],
#   ['sku', ' 291282274 th 483922421'],
#   ['แรม', '4gb'],
#   ['ความจุแบตเตอรี่', '3000']],
#  'category_0_189': [['หนา', '8.3'],
#   ['น้ำหนัก', 'ประมาณ'],
#   ['ขนาดหน้าจอ', '5.45'],
#   ['สีของหน้าจอ', '16.7'],
#   ['ประเภทของหน้าจอ', 'tft'],
#   ['ความละเอียด', 'hd'],
#   ['ความคมชัดของหน้าจอ', '295'],
#   ['ประเภทการ์ดเก็บข้อมูล', 'การ์ด'],
#   ['รองรับหน่วยความจำภายนอก', '256'],
#   ['กล้องเลนส์เดี่ยว', '8ล้านพิกเซล'],
#   ['กล้องเลนส์เดี่ยว', '5ล้านพิกเซล'],
#   ['แฟลช', 'ด้านหน้าเป็นแฟลชแบบ'],
#   ['fdd', 'b1'],
#   ['tdd', 'b40'],
#   ['wcdma', 'b1'],
#   ['gsm', 'b2'],
#   ['บันทึก', 'ฟังก์ชั่นที่มีนี้ขึ้นอยู่กับเครือข่ายผู้ให้บริการ'],
#   ['gsm', 'b2'],
#   ['gsm', 'b2'],
#   ['บันทึก',
#    'ช่องเสียบการ์ดทั้งสองสามารถตั้งค่าเพื่อรองรับซิมการ์ดหลักหรือรองได้'],
#   ['port', 'micro']],
#  'category_0_190': [['รอม', '10.5'], ['รอม', '3g']],
#  'category_0_191': [['มมน้ำหนัก', '173']],
#  'category_0_192': [['sku', ' 570030784 th 1046476409']],
#  'category_0_193': [['ppi', '391'],
#   ['sku', ' 343882248 th 669814957'],
#   ['แรม', '4gb'],
#   ['ความจุแบตเตอรี่', '4000']],
#  'category_0_194': [['แรม', '4gb'], ['sku', ' 599542296 th 1127736447']],
#  'category_0_195': [['รอม', '512gb'],
#   ['sku', ' 594360907 th 1117668861'],
#   ['ความจุแบตเตอรี่', '1000']],
#  'category_0_196': [['sku', ' 582918405 th 1077862110'],
#   ['ความจุแบตเตอรี่', '3000']],
#  'category_0_197': [['แบตเตอรี่', '3750'],
#   ['ระบบปฏิบัติการ', 'android'],
#   ['sku', ' 403214185 th 782722982']],
#  'category_0_198': [['ระบบปฏิบัติการ', 'android'],
#   ['แรม', '6gb'],
#   ['sku', ' 310318635 th 552322430']],
#  'category_0_199': [['กล้องหลัง', '2ล้านพิกเซล'],
#   ['แบตเตอรี่', '3750'],
#   ['sku', ' 328120492 th 628182917'],
#   ['ความจุแบตเตอรี่', '3000']],
#  'category_0_200': [],
#  'category_0_201': [['sku', ' 593892371 th 1114492226']],
#  'category_0_202': [],
#  'category_0_203': [['sku', ' 599084896 th 1127026639']],
#  'category_0_204': [['sku', ' 598884689 th 1127090507'],
#   ['แรม', '4gb'],
#   ['ความจุแบตเตอรี่', '1000']],
#  'category_0_205': [['sku', ' 599068800 th 1127036426']],
#  'category_0_206': [['รอม', '64'],
#   ['ระบบปฏิบัติการ', 'colorระบบปฏิบัติการ'],
#   ['รอม', '64'],
#   ['sku', ' 611118429 th 1152724834'],
#   ['รอม', '64'],
#   ['แรม', '3gb'],
#   ['ความจุแบตเตอรี่', '1000']],
#  'category_0_207': [['sku', ' 576962917 th 1065758090'],
#   ['แรม', '512mb'],
#   ['ความจุแบตเตอรี่', '1000']],
#  'category_0_208': [['ความจุแบตเตอรี่', '1000'],
#   ['sku', ' 595536413 th 1118762069'],
#   ['แรม', '4gb']],
#  'category_0_209': [['แรม', '128'],
#   ['จอแสดงผล', 'ระบบหมุนภาพอัตโนมัติ'],
#   ['2g', 'edge'],
#   ['ระบบปฏิบัติการ', 'colorระบบปฏิบัติการ'],
#   ['รอม', '64'],
#   ['การหาตำแหน่ง', 'assisted']],
#  'category_0_210': [['sku', ' 593892271 th 1114412808']],
#  'category_0_211': [['รอม', 'expandable'],
#   ['sku', ' 326952660 th 624226626'],
#   ['ความจุแบตเตอรี่', '1000']],
#  'category_0_212': [['sku', ' 265436667 th 412888313'],
#   ['ความจุแบตเตอรี่', '1000']],
#  'category_0_213': [['แรม', '฿'],
#   ['รอม', '64'],
#   ['แรม', '8'],
#   ['แรม', '3gb'],
#   ['รอม', '128gb']],
#  'category_0_214': [['sku', ' 403004685 th 782382982'],
#   ['ความจุแบตเตอรี่', '1000']],
#  'category_0_215': [['sku', ' 417942838 th 801314333'],
#   ['ความจุแบตเตอรี่', '30001']],
#  'category_0_216': [['sku', ' 604764960 th 1138830339'],
#   ['แรม', '4gb'],
#   ['ความจุแบตเตอรี่', '5000']],
#  'category_0_217': [['รอม', '10.5'], ['รอม', '64gb'], ['รอม', '3g']],
#  'category_0_218': [['sku', ' 580734651 th 1073342091'],
#   ['แรม', '4gb'],
#   ['ความจุแบตเตอรี่', '1000']],
#  'category_0_219': [['แรม', '4'],
#   ['2g', 'edge'],
#   ['ระบบปฏิบัติการ', 'colorระบบปฏิบัติการ'],
#   ['รอม', '128'],
#   ['การหาตำแหน่ง', 'assisted'],
#   ['sku', ' 600982947 th 1131064759'],
#   ['แรม', '4gb']],
#  'category_0_220': [['แรม', '4'],
#   ['ระบบปฏิบัติการ', 'colorระบบปฏิบัติการ'],
#   ['แรม', '4'],
#   ['รอม', '128']],
#  'category_0_221': [['รอม', '32'],
#   ['ระบบปฏิบัติการ', 'colorระบบปฏิบัติการ'],
#   ['รอม', '32'],
#   ['จอแสดงผล', 'ตรวจจับความเคลื่อนไหวของตัวเครื่อง'],
#   ['sku', ' 594530664 th 1116430818']],
#  'category_0_222': [['แรม', '฿'],
#   ['รอม', '64'],
#   ['แรม', '3gb'],
#   ['แรม', '8'],
#   ['รอม', '128gb']],
#  'category_0_223': [['รอม', '128gb'],
#   ['sku', ' 599480538 th 1128100802'],
#   ['แรม', '4gb'],
#   ['ความจุแบตเตอรี่', '5000']],
#  'category_0_224': [['sku', ' 418146358 th 801330478'],
#   ['ความจุแบตเตอรี่', '1000']],
#  'category_0_225': [['sku', ' 402982804 th 782386887'],
#   ['ความจุแบตเตอรี่', '1000']],
#  'category_0_226': [['จอแสดงผล', 'ตรวจจับความเคลื่อนไหวของตัวเครื่อง'],
#   ['ระบบปฏิบัติการ', 'colorระบบปฏิบัติการ'],
#   ['รอม', '32'],
#   ['จอแสดงผล', 'ตรวจจับความเคลื่อนไหวของตัวเครื่อง'],
#   ['ระบบปฏิบัติการ', 'colorระบบปฏิบัติการ'],
#   ['รอม', '32']],
#  'category_0_227': [['sku', ' 418142432 th 801348251'],
#   ['ความจุแบตเตอรี่', '1000']],
#  'category_0_228': [['รอม', '10.5'], ['รอม', '3g']],
#  'category_0_229': [['colorระบบปฏิบัติการ', '6.0'],
#   ['sku', ' 460654202 th 847892071'],
#   ['แรม', '8gb'],
#   ['ความจุแบตเตอรี่', '1000']],
#  'category_0_230': [['ความจุแบตเตอรี่', '1000'],
#   ['sku', ' 591918757 th 1108276056'],
#   ['แรม', '4gb']],
#  'category_0_231': [['sku', ' 452446880 th 836206666'],
#   ['ความจุแบตเตอรี่', '5000']],
#  'category_0_232': [['รอม', '32'],
#   ['ระบบปฏิบัติการ', 'colorระบบปฏิบัติการ'],
#   ['รอม', '32gb'],
#   ['รอม', '16'],
#   ['จอแสดงผล', 'ระบบสัมผัส'],
#   ['3g', 'hspa'],
#   ['ระบบปฏิบัติการ', 'colorระบบปฏิบัติการ'],
#   ['รอม', '16'],
#   ['การหาตำแหน่ง', 'assisted']],
#  'category_0_233': [['รอม', 'แท้จากโรงงาน'],
#   ['lte', 'b34'],
#   ['sku', ' 616366381 th 1170420923'],
#   ['แรม', '8gb']],
#  'category_0_234': [['รอม', '128gb'],
#   ['รอม', '128gb'],
#   ['colorระบบปฏิบัติการ', '6'],
#   ['sku', ' 600790956 th 1130624325'],
#   ['แรม', '4gb']],
#  'category_0_235': [['แรม', '4'],
#   ['รอม', 'สูงสุด'],
#   ['sku', ' 338952152 th 656874222']],
#  'category_0_236': [['รอม', '128gb'],
#   ['รอม', '128gb'],
#   ['sku', ' 599704659 th 1128032096']],
#  'category_0_237': [['รอม', 'เพิ่มสูงสุดถึง'],
#   ['sku', ' 601276452 th 1131698507'],
#   ['แรม', '4gb'],
#   ['ความจุแบตเตอรี่', '5001']],
#  'category_0_238': [['จอแสดงผล', 'ระบบสัมผัส'],
#   ['3g', 'hspa'],
#   ['ระบบปฏิบัติการ', 'colorระบบปฏิบัติการ'],
#   ['รอม', '16'],
#   ['sku', ' 408100004 th 792804384'],
#   ['ความจุแบตเตอรี่', '1000']],
#  'category_0_239': [['แรม', '8'],
#   ['ระบบปฏิบัติการ', 'colorระบบปฏิบัติการ'],
#   ['รอม', '128'],
#   ['การหาตำแหน่ง', 'assisted'],
#   ['sku', ' 416330239 th 799976588']],
#  'category_0_240': [['sku', ' 268324226 th 603248979'],
#   ['แรม', '1gb'],
#   ['ความจุแบตเตอรี่', '3000']],
#  'category_0_241': [['รอม', '16'], ['sku', ' 365700164 th 714698964']],
#  'category_0_242': [['รอม', '32gb'], ['sku', ' 552184749 th 1006836063']],
#  'category_0_243': [['รอม', '32gb'], ['sku', ' 385566108 th 815456220']],
#  'category_0_244': [['รอม', '16gb'], ['sku', ' 405068513 th 805010589']],
#  'category_0_245': [['รอม', '32gb'],
#   ['sku', ' 400040507 th 777298618'],
#   ['แรม', '2gb'],
#   ['ความจุแบตเตอรี่', '30001']],
#  'category_0_246': [['sku', ' 270282019 th 422771415'],
#   ['แรม', '1gb'],
#   ['ความจุแบตเตอรี่', '3000']],
#  'category_0_247': [['sku', ' 405108122 th 805050038'],
#   ['ความจุแบตเตอรี่', '1000']],
#  'category_0_248': [['รอม', '32gb'], ['sku', ' 550594069 th 1000618756']],
#  'category_0_249': [['แรม', '2gb'],
#   ['sku', ' 275617311 th 815450167'],
#   ['แรม', '2gb'],
#   ['ความจุแบตเตอรี่', '3000']],
#  'category_0_250': [['รอม', '32gb'], ['sku', ' 603116847 th 1136274443']],
#  'category_0_251': [['รอม', '16gb'],
#   ['sku', ' 314710401 th 576202145'],
#   ['แรม', '1gb'],
#   ['ความจุแบตเตอรี่', '3000']],
#  'category_0_252': [['รอม', '32gb'], ['sku', ' 603110290 th 1136224459']],
#  'category_0_253': [['รอม', '16'], ['sku', ' 328582974 th 629520209']],
#  'category_0_254': [['แรม', '1gb'],
#   ['แบตเตอรี่', '3200mah'],
#   ['sku', ' 270179696 th 578982558'],
#   ['แรม', '1gb'],
#   ['ความจุแบตเตอรี่', '3000']],
#  'category_0_255': [['รอม', '16gb'],
#   ['สนทนาต่อเนื่องสูงสุดประมาณ', '8'],
#   ['ขนาด', '75'],
#   ['น้ำหนัก', '150'],
#   ['ข้อความ', 'sms'],
#   ['ภาษา', 'thai'],
#   ['หน่วยความจำภายนอก', 'รองรับt'],
#   ['แรม', '1'],
#   ['cpu', 'mtk 6580 1.3ghz quad core'],
#   ['วิดีโอ', 'เครื่องเล่น'],
#   ['เครื่องเสียง', 'เครื่องเล่นล้านพิกเซล'],
#   ['ริงโทน', 'ล้านพิกเซล'],
#   ['วิทยุ', 'มี'],
#   ['wallpaper', ' bmpjpegpng'],
#   ['gps', 'มี'],
#   ['battery', 'haixu battery 3200mah ']],
#  'category_0_256': [['รอม', '32gb'], ['sku', ' 603094531 th 1136238502']],
#  'category_0_257': [['แรม', '฿'],
#   ['รอม', '64'],
#   ['แรม', '2'],
#   ['รอม', '64gb']],
#  'category_0_258': [['แรม', '2'],
#   ['sku', ' 312418366 th 1030968530'],
#   ['แรม', '2gb'],
#   ['ความจุแบตเตอรี่', '3000']],
#  'category_0_259': [['รอม', '16gb'],
#   ['รอม', '16gb'],
#   ['sku', ' 601494155 th 1132134762']],
#  'category_0_260': [['แบตเตอรี่', '3400mah'],
#   ['แบตเตอรี่', '3400mah'],
#   ['sku', ' 314412441 th 573360540'],
#   ['แรม', '2gb'],
#   ['ความจุแบตเตอรี่', '3000']],
#  'category_0_261': [['sku', ' 312924192 th 563944053'],
#   ['แรม', '1gb'],
#   ['ความจุแบตเตอรี่', '3000']],
#  'category_0_262': [['แรม', '3gb'], ['รอม', '3g']],
#  'category_0_263': [['sku', ' 602892154 th 1136000618']],
#  'category_0_264': [['รอม', '16gb'], ['sku', ' 601448844 th 1132182102']],
#  'category_0_265': [['แรม', '฿'],
#   ['รอม', '64'],
#   ['แรม', '2'],
#   ['รอม', '64gb']],
#  'category_0_266': [['รอม', '16gb'],
#   ['รอม', '16gb'],
#   ['sku', ' 601266875 th 1131662738']],
#  'category_0_267': [['แรม', '3gb'], ['รอม', '3g']],
#  'category_0_268': [['รอม', '16gb'], ['sku', ' 555184763 th 1015570247']],
#  'category_0_269': [['รอม', '16gb'], ['sku', ' 603102818 th 1136286057']],
#  'category_0_270': [['รอม', '16'],
#   ['รอม', '16'],
#   ['sku', ' 428064860 th 810616983']],
#  'category_0_271': [['แรม', '฿'], ['รอม', '64'], ['แรม', '2']],
#  'category_0_272': [['sku', ' 603142333 th 1136248709']],
#  'category_0_273': [['sku', ' 553590398 th 1011094010']],
#  'category_0_274': [['รอม', '32gb'], ['sku', ' 555104212 th 1015272954']],
#  'category_0_275': [['sku', ' 286990241 th 467726070'],
#   ['แรม', '1gb'],
#   ['ความจุแบตเตอรี่', '3000']],
#  'category_0_276': [['แบตเตอรี่', '3200mah'],
#   ['แบตเตอรี่', '3200mah'],
#   ['sku', ' 331348050 th 636820649'],
#   ['แรม', '2gb'],
#   ['ความจุแบตเตอรี่', '30001']],
#  'category_0_277': [['รอม', '32gb'],
#   ['sku', ' 170065248 th 1042248064'],
#   ['แรม', '2gb'],
#   ['ความจุแบตเตอรี่', '30001']],
#  'category_0_278': [['sku', ' 268626162 th 420613109'],
#   ['แรม', '1gb'],
#   ['ความจุแบตเตอรี่', '3000']],
#  'category_0_279': [['แรม', '1gb'],
#   ['แบตเตอรี่', '3200mah'],
#   ['sku', ' 289374358 th 479328386'],
#   ['แรม', '1gb'],
#   ['ความจุแบตเตอรี่', '3000']],
#  'category_1_0': [['รอม', '128gb'],
#   ['รอม', '128gb'],
#   ['sku', ' 444394704 th 823064920']],
#  'category_1_1': [['รอม', '10.5'], ['sku', ' 253236549 th 390793920']],
#  'category_1_2': [['รอม', '3g']],
#  'category_1_3': [['แรม', '฿'], ['แรม', '2'], ['รอม', '64']],
#  'category_1_4': [['รอม', '10.5'], ['sku', ' 259980716 th 400314174']],
#  'category_1_5': [['แบรนด์', 'new'],
#   ['แบรนด์', 'new'],
#   ['sku', ' 611042206 th 1152562194']],
#  'category_1_6': [['sku', ' 309616290 th 547144949']],
#  'category_1_7': [['แรม', '3'],
#   ['จอแสดงผล', '1920'],
#   ['camera', '8.0ล้านพิกเซล'],
#   ['camera', '5.ล้านพิกเซล'],
#   ['ใช้งานอินเทอร์เน็ตสูงสุด', 'ประมาณ'],
#   ['sku', ' 505676488 th 896220807']],
#  'category_1_8': [['sku', ' 616546968 th 1171084081']],
#  'category_1_9': [['แรม', '1.5'], ['แรม', '1.5']],
#  'category_1_10': [['sku', ' 281307545 th 456411484']],
#  'category_1_11': [['รอม', '128gb'],
#   ['4g', 'lte'],
#   ['ระบบปฏิบัติการ', 'android']],
#  'category_1_12': [['รอม', '64gb'], ['sku', ' 598818135 th 1126274363']],
#  'category_1_13': [['แรม', '2gb'],
#   ['sku', ' 575476567 th 1061786680'],
#   ['แรม', '2gb']],
#  'category_1_14': [['จอแสดงผล', '8.0'],
#   ['จอแสดงผล', '1280'],
#   ['จอแสดงผล', 'tft'],
#   ['จอแสดงผล', '16m']],
#  'category_1_15': [['แรม', '3']],
#  'category_1_16': [['sku', ' sa861elaa6wjmeanth 14640556']],
#  'category_1_17': [['sku', ' 464218693 th 851672912']],
#  'category_1_18': [['แรม', '3'],
#   ['จอแสดงผล', '1920'],
#   ['camera', '8.0ล้านพิกเซล'],
#   ['camera', '5.ล้านพิกเซล'],
#   ['ใช้งานอินเทอร์เน็ตสูงสุด', 'ประมาณ'],
#   ['sku', ' 332126164 th 639418501']],
#  'category_1_19': [['sku', ' sa861elaa1jddcanth 3366121']],
#  'category_1_20': [['ราคา', '25900'], ['sku', ' 511662652 th 909614254']],
#  'category_1_21': [['แรม', '3']],
#  'category_1_22': [['sku', ' sa861elaa6y4tnanth 14725929'], ['แรม', '2gb']],
#  'category_1_23': [['จอแสดงผล', 'ระบบจดจำใบหน้า'],
#   ['4g', 'lte'],
#   ['ระบบปฏิบัติการ', 'android'],
#   ['รอม', '128'],
#   ['จอแสดงผล', 'ระบบจดจำใบหน้า'],
#   ['4g', 'lte'],
#   ['ระบบปฏิบัติการ', 'android'],
#   ['รอม', '128'],
#   ['การหาตำแหน่ง', 'assisted']],
#  'category_1_24': [['แรม', '6gb'], ['sku', ' 578246550 th 1067310939']],
#  'category_1_25': [['แรม', '3'],
#   ['cpu', ' octa core 1.8ghz 1.6ghz'],
#   ['รองรับการเชื่อมต่อ', 'gps'],
#   ['sku', ' 385742465 th 749484157'],
#   ['แรม', '3']],
#  'category_1_26': [['แรม', '4'],
#   ['จอแสดงผล', 'samdled'],
#   ['cpu', 'qualcomm sdm 670 dual 2.0 ghz hexa 1.7ghz '],
#   ['ระบบปฏิบัติการ', 'android'],
#   ['หน่วยความจำเพิ่ม', 'สูงสุด'],
#   ['sku', ' 349596471 th 683518481'],
#   ['แรม', '4']],
#  'category_1_27': [['sku', ' sa861elaa96yxuanth 18836115'], ['แรม', '8gb']],
#  'category_1_28': [['แรม', '4'],
#   ['จอแสดงผล', 'samdled'],
#   ['cpu', 'qualcomm sdm 670 dual 2.0 ghz hexa 1.7ghz '],
#   ['ระบบปฏิบัติการ', 'android'],
#   ['หน่วยความจำเพิ่ม', 'สูงสุด'],
#   ['sku', ' 349716880 th 683852191'],
#   ['แรม', '4']],
#  'category_1_29': [['แรม', '3'],
#   ['cpu', ' octa core 1.8ghz 1.6ghz'],
#   ['รองรับการเชื่อมต่อ', 'gps'],
#   ['sku', ' 385762324 th 749490169'],
#   ['แรม', '3']],
#  'category_1_30': [['แรม', '3']],
#  'category_1_31': [['ระบบปฏิบัติการ', 'android'],
#   ['แรม', '4gb'],
#   ['การหาตำแหน่ง', 'assisted']],
#  'category_1_32': [['แรม', 'size'],
#   ['รอม', 'size'],
#   ['sku', ' 425442569 th 809202694'],
#   ['แรม', '6gb']],
#  'category_1_33': [['แรม', '3'],
#   ['sku', ' 420596705 th 802242814'],
#   ['แรม', '3']],
#  'category_1_34': [['sku', ' sa861elaa772b0anth 15168461']],
#  'category_1_35': [['แรม', '3'],
#   ['cpu', ' octa core 1.8ghz 1.6ghz'],
#   ['รองรับการเชื่อมต่อ', 'gps'],
#   ['sku', ' 385844163 th 749708159'],
#   ['แรม', '3']],
#  'category_1_36': [],
#  'category_1_37': [['sku', ' 262630513 th 404670218']],
#  'category_1_38': [['ราคา', '25900'], ['sku', ' 511720036 th 909722120']],
#  'category_1_39': [['แรม', '4'],
#   ['จอแสดงผล', 'samdled'],
#   ['cpu', 'qualcomm sdm 670 dual 2.0 ghz hexa 1.7ghz '],
#   ['ระบบปฏิบัติการ', 'android'],
#   ['หน่วยความจำเพิ่ม', 'สูงสุด'],
#   ['sku', ' 349706881 th 683844239'],
#   ['แรม', '4']],
#  'category_1_40': [['รอม', '64'],
#   ['microsd', 'สูงสุด'],
#   ['น้ำหนัก', 'ประมาณ'],
#   ['fi', 'ieee'],
#   ['บลูทูธ', 'bt'],
#   ['fdd', 'b1'],
#   ['tdd', 'b40'],
#   ['wcdma', 'b1 b2 b5 b6 b8 b19'],
#   ['gsm', '850 900 1800 1900 mhz'],
#   ['fi', '802.11a'],
#   ['cpu', 'kirin 659 4 x a53 2.4 ghz 4 x a53 1.7 ghz '],
#   ['sku', ' 616454002 th 1170706018']],
#  'category_1_41': [['รอม', '64gb'], ['sku', ' 598458483 th 1125468954']],
#  'category_1_42': [['ความละเอียด', '1920'],
#   ['ระบบปฎิบัติการ', 'android'],
#   ['sku', ' 287662655 th 470616189'],
#   ['แรม', '2gb']],
#  'category_1_43': [['ความละเอียด', '1920'],
#   ['ระบบปฎิบัติการ', 'android'],
#   ['sku', ' 282104000 th 867692783'],
#   ['แรม', '3gb']],
#  'category_1_44': [['รอม', '64']],
#  'category_1_45': [['ppi', '283'],
#   ['ระบบปฎิบัติการ', 'android'],
#   ['sku', ' 334238580 th 647152832'],
#   ['แรม', '3gb']],
#  'category_1_46': [['sku', ' 595116515 th 1117738762'],
#   ['sku', 'b85114'],
#   ['แรม', '4gb']],
#  'category_1_47': [['รอม', '3g']],
#  'category_1_48': [['ppi', '283'],
#   ['ระบบปฎิบัติการ', 'android'],
#   ['sku', ' 589984097 th 1099528273']],
#  'category_1_49': [['sku', ' 417282490 th 1163072900']],
#  'category_1_50': [['umts', 'b1 b2 b5'],
#   ['gsm', 'b2 b3 b5 b8'],
#   ['wapi', '802.11b'],
#   ['sku', ' 609582335 th 1148502501'],
#   ['แรม', '2gb']],
#  'category_1_51': [['sku', ' 595136404 th 1117770081'],
#   ['sku', 'b67869'],
#   ['แรม', '4gb']],
#  'category_1_52': [['แรม', '3gb'],
#   ['ระบบปฏิบัติการ', 'android'],
#   ['sku', ' 290826124 th 482712138']],
#  'category_1_53': [['ประเภทหน้าจอ', 'capacitive'],
#   ['sku', ' 342568306 th 665622238']],
#  'category_1_54': [['sku', ' 595122670 th 1117796536'],
#   ['sku', 'b85142'],
#   ['แรม', '3gb']],
#  'category_1_55': [['gpu', 'mali'],
#   ['microsd', 'สูงสุด'],
#   ['ด้านหลัง', '8ล้านพิกเซล'],
#   ['sku', ' 536688599 th 971382516']],
#  'category_1_56': [['รอม', '32gb'],
#   ['sku', ' 595106628 th 1117744619'],
#   ['sku', 'b62376'],
#   ['แรม', '3gb']],
#  'category_1_57': [['sku', ' 282104000 th 459910623'],
#   ['แรม', '3gb'],
#   ['sku', ' 306912272 th 534614461']],
#  'category_1_58': [['sku', ' 557924211 th 1024318332']],
#  'category_1_59': [['รอม', '32'],
#   ['wapi', '802.11a'],
#   ['sku', ' 399314990 th 775480298']],
#  'category_1_60': [['รอม', '16gb'], ['sku', ' 264390003 th 620896181']],
#  'category_1_61': [['sku', ' 290632248 th 482354221']],
#  'category_1_62': [['รอม', '32gb'],
#   ['ความละเอียด', '1920'],
#   ['ระบบปฎิบัติการ', 'android'],
#   ['ความละเอียด', '1920'],
#   ['ระบบปฎิบัติการ', 'android'],
#   ['sku', ' 287440622 th 469360971'],
#   ['แรม', '3gb']],
#  'category_1_63': [['แท็ก', 'แท็บเล็ต'], ['sku', ' 404528555 th 784942219']],
#  'category_1_64': [['sku', ' 292678457 th 532430370']],
#  'category_1_65': [['แรม', '4'],
#   ['ความละเอียด', '2560'],
#   ['ระบบปฎิบัติการ', 'android'],
#   ['sku', ' 370918900 th 724140336']],
#  'category_1_66': [['แรม', '3gb'],
#   ['ความละเอียด', '1920'],
#   ['ระบบปฎิบัติการ', 'android'],
#   ['3g', 'hspa'],
#   ['ระบบปฏิบัติการ', 'android'],
#   ['แรม', '3gb']],
#  'category_1_67': [['sku', ' 255408768 th 393960215']],
#  'category_1_68': [['แรม', '3gb'],
#   ['3g', 'hspa'],
#   ['ระบบปฏิบัติการ', 'android'],
#   ['แรม', '3gb'],
#   ['sku', ' 290662150 th 482422464']],
#  'category_1_69': [['ระบบปฏิบัติการ', 'android'],
#   ['แรม', '4gb'],
#   ['การหาตำแหน่ง', 'assisted']],
#  'category_1_70': [['แรม', '2gb'],
#   ['sku', ' 506850955 th 899038940'],
#   ['แรม', '2gb']],
#  'category_1_71': [['แรม', '4'],
#   ['ความละเอียด', '2560'],
#   ['ระบบปฎิบัติการ', 'android'],
#   ['sku', ' 370904875 th 724108404']],
#  'category_1_72': [['apertureกล้องหน้า', '8ล้านพิกเซล'],
#   ['sku', ' 336198592 th 651110836']],
#  'category_1_73': [['มมน้ำหนัก', 'ประมาณ'],
#   ['memory', 'microsd'],
#   ['tdd', 'b40'],
#   ['ca', 'ca'],
#   ['wapi', '802.11a'],
#   ['กล้องหน้า', '8ล้านพิกเซล'],
#   ['sku', ' 336002915 th 650804832'],
#   ['แรม', '3gb']],
#  'category_1_74': [['sku', ' 529216400 th 963900075'], ['แรม', '3gb']],
#  'category_1_75': [['แรม', '4'],
#   ['ความละเอียด', '2560'],
#   ['ระบบปฎิบัติการ', 'android'],
#   ['sku', ' 370906523 th 724086780']],
#  'category_1_76': [['ระบบปฏิบัติการ', 'android'],
#   ['แรม', '4gb'],
#   ['ระบบปฏิบัติการ', 'android'],
#   ['แรม', '4gb'],
#   ['การหาตำแหน่ง', 'assisted']],
#  'category_1_77': [['รอม', '32'], ['sku', ' 333328687 th 643922974']],
#  'category_1_78': [['sku', ' 341902484 th 663890262']],
#  'category_1_79': [['แรม', '4'],
#   ['ความละเอียด', '2560'],
#   ['ระบบปฎิบัติการ', 'android'],
#   ['sku', ' 370930514 th 724094910']],
#  'category_1_80': [['type', 'a10x'],
#   ['speed', 'n'],
#   ['size', '10.5'],
#   ['features', 'led'],
#   ['จอแสดงผล', 'type'],
#   ['resolution', ' 2224 by 1668 resolution at 264 pixels per inch ppi '],
#   ['communication',
#    ' wi fi 802.11a b g n ac dual band 2.4ghz and 5ghz ht80 with mimo'],
#   ['bluetooth', ' bluetooth 4.2'],
#   ['slot', 'not'],
#   ['camera', '12ล้านพิกเซล'],
#   ['camera', '7ล้านพิกเซล'],
#   ['battery', ' built in 30.4 watt hour rechargeable lithium polymer battery'],
#   ['life', 'up'],
#   ['น้ำหนัก', 'kg'],
#   ['os', ' ios 10.0.1 upgradable to ios 11'],
#   ['warranty', ' 1 year'],
#   ['sku', ' ap067elaag6sgganth 33437482']],
#  'category_1_81': [['แรม', 'รอม'], ['แรม', '2']],
#  'category_1_82': [['จอแสดงผล', 'liliwi'],
#   ['type', 'a10x'],
#   ['speed', 'n'],
#   ['size', '10.5'],
#   ['features', 'led'],
#   ['จอแสดงผล', 'type'],
#   ['resolution', ' 2224 by 1668 resolution at 264 pixels per inch ppi '],
#   ['communication',
#    ' wi fi 802.11a b g n ac dual band 2.4ghz and 5ghz ht80 with mimo'],
#   ['bluetooth', ' bluetooth 4.2'],
#   ['slot', 'nano'],
#   ['camera', '12ล้านพิกเซล'],
#   ['camera', '7ล้านพิกเซล'],
#   ['battery', ' built in 30.4 watt hour rechargeable lithium polymer battery'],
#   ['life', 'up'],
#   ['น้ำหนัก', 'kg'],
#   ['os', ' ios 10.0.1 upgradable to ios 11'],
#   ['warranty', ' 1 year'],
#   ['sku', ' ap067elaakgmyjanth 41624609']],
#  'category_1_83': [['sku', ' ap067elad0j7anth 146971'], ['แรม', '1gb']],
#  'category_1_84': [['นิ้วความละเอียดหน้าจอ', '1280'],
#   ['ความจุแบตเตอรี่', '5500mah'],
#   ['sku', ' 388878675 th 755276884'],
#   ['แรม', '2gb']],
#  'category_1_85': [['รอม', 'และรองรับความจุภายนอก'],
#   ['sku', ' 389948570 th 757528306'],
#   ['แรม', '3gb']],
#  'category_1_86': [['รอม', 'รองรับ'],
#   ['sku', ' cu106elaajdf26anth 39529562'],
#   ['แรม', '1gb']],
# ...
#   ['ฮาร์ดดิสก์', '500'],
#   ['ฮาร์ดดิสก์', 'ssd'],
#   ['ฮาร์ดดิสก์', '500gb']],
#  'category_3_168': [['ฮาร์ดดิสก์', '320'], ['sku', ' 312640922 th 562424030']],
#  'category_3_169': [['sku', ' 538796110 th 976074148']],
#  'category_3_170': [['ฮาร์ดดิสก์', '500'], ['sku', ' 310080233 th 550168975']],
#  'category_3_171': [['cpu', 'intel core i7 9750h'],
#   ['gpu', 'nvidia geforce gtx 1050 3gb gddr5 '],
#   ['ram', '8 gb ddr4 2666 mhz'],
#   ['storage', '256 gb ssd pcie m.2'],
#   ['os', 'windows 10 home 64 bit '],
#   ['sku', ' 370810695 th 723986065']],
#  'category_3_172': [['sku', ' 472646078 th 862302809']],
#  'category_3_173': [['sku', ' 415848985 th 799356754']],
#  'category_3_174': [['ฮาร์ดดิสก์', '250'],
#   ['sku', ' 601964204 th 1133366278']],
#  'category_3_175': [['ฮาร์ดดิสก์', '1tb'],
#   ['จอแสดงผล', '14.0'],
#   ['support', 'onsite'],
#   ['sku', ' 507064062 th 900504545']],
#  'category_3_176': [['ฮาร์ดดิสก์', '1'],
#   ['แรม', '4gb'],
#   ['ฮาร์ดดิสก์', '1tb'],
#   ['แรม', '4gb'],
#   ['แรม', '8g']],
#  'category_3_177': [['sku', ' 334444841 th 647842769']],
#  'category_3_178': [['sku', ' 334226983 th 647114669']],
#  'category_3_179': [['แรม', '4gb'],
#   ['แรม', '4'],
#   ['condition', 'มือสองสภาพดีสินค้าหมดสัญญาเช่า'],
#   ['sku', ' 541708949 th 981450846']],
#  'category_3_180': [['ฮาร์ดดิสก์', '320gb'],
#   ['sku', ' 284746714 th 464246861']],
#  'category_3_181': [['cpu', 'intel core i3 7020u 2.3 ghz 3 mb l3 cache '],
#   ['gpu', 'amd radeon 520 2gb gddr5 '],
#   ['ram', '4 gb ddr4 2400 mhz'],
#   ['storage', '1 tb 5400 rpm'],
#   ['os', 'ubuntu'],
#   ['sku', ' 373586549 th 728024230']],
#  'category_3_182': [['sku', ' 334232879 th 647120903']],
#  'category_3_183': [['แรม', '2'],
#   ['ฮาร์ดดิสก์', '160'],
#   ['sku', ' 599150109 th 1127170665']],
#  'category_3_184': [['ฮาร์ดดิสก์', 'amd'], ['ฮาร์ดดิสก์', '500']],
#  'category_3_185': [['sku', ' 333876982 th 646008437']],
#  'category_3_186': [['ฮาร์ดดิสก์', '1'],
#   ['แรม', '4gb'],
#   ['ฮาร์ดดิสก์', '1tb'],
#   ['ฮาร์ดดิสก์', '1'],
#   ['ฮาร์ดดิสก์', '500gb']],
#  'category_3_187': [['ฮาร์ดดิสก์', 'windows10'],
#   ['sku', ' 319960011 th 609242785']],
#  'category_3_188': [['ram', '4gb'], ['sku', ' 566832434 th 1144928330']],
#  'category_3_189': [['sku', ' 484708909 th 872936864']],
#  'category_3_190': [['ฮาร์ดดิสก์', 'amd'],
#   ['ฮาร์ดดิสก์', '500'],
#   ['แรม', '8g'],
#   ['แรม', '128gb']],
#  'category_3_191': [['แบรนด์', 'dell'],
#   ['จอแสดงผล', 'screen'],
#   ['note',
#    ' the memory is integrated on the system board from the factory and it cannot be upgraded later.'],
#   ['sku', ' 533484443 th 963614782']],
#  'category_3_192': [['sku', ' 564042949 th 1034122536']],
#  'category_3_193': [['แรม', '8'], ['sku', ' 571338885 th 1049004809']],
#  'category_3_194': [['ฮาร์ดดิสก์', '512gb'],
#   ['sku', ' 471532400 th 861288862']],
#  'category_3_195': [['แบรนด์', 'ยี่ห้อ'],
#   ['cpu', ' intel core i5 4310m 2.70ghz'],
#   ['หน้าจอ', '14'],
#   ['memory', ' แรม ddr3 4 gb'],
#   ['รอม', 'ช่องต่อหูฟัง'],
#   ['sku', ' 592728650 th 1110476822']],
#  'category_3_196': [['cpu',
#    'amd ryzen 3 2200u 2.50 ghz up to 3.40 ghz 4 mb l3 cache '],
#   ['gpu', 'amd radeon rx vega 3'],
#   ['ram', '4 gb ddr4 2400 mhz'],
#   ['storage', '1 tb 5400 rpm'],
#   ['os', 'windows 10 home 64 bit '],
#   ['sku', ' 373746991 th 728358777']],
#  'category_3_197': [['sku', ' 279815926 th 452425319']],
#  'category_3_198': [['ฮาร์ดดิสก์', '1'],
#   ['แรม', '4gb'],
#   ['ฮาร์ดดิสก์', '1tb'],
#   ['ฮาร์ดดิสก์', '1'],
#   ['ฮาร์ดดิสก์', '500gb']],
#  'category_3_199': [['cpu',
#    'intel core i5 7200u 2.5 ghz 3 mb l3 cache up to 3.10 ghz '],
#   ['gpu', 'nvidia geforce gt 940mx 2gb gddr5 '],
#   ['ram', '4 gb ddr4'],
#   ['storage', '1 tb 5400 rpm'],
#   ['os', 'windows 10 home 64 bit '],
#   ['sku', ' 373590146 th 727994623']],
#  'category_3_200': [['แรม', '4gb'],
#   ['ram', ' ddr3 4 gb'],
#   ['condition', ' สินค้าหมดสัญญาเช่า'],
#   ['duty', 'https'],
#   ['sku', ' 536850936 th 971818832']],
#  'category_3_201': [['sku', ' 365566252 th 714386288']],
#  'category_3_202': [['duty', 'https'], ['sku', ' 317658755 th 598712542']],
#  'category_3_203': [['แรม', '2gb'], ['sku', ' 619684279 th 1180350471']],
#  'category_3_204': [['sku', ' 596072994 th 1119382481']],
#  'category_3_205': [['ฮาร์ดดิสก์', '320gb'],
#   ['ฮาร์ดดิสก์', '320gb'],
#   ['sku', ' 264850282 th 411491182']],
#  'category_3_206': [['sku', ' 596100078 th 1119344299']],
#  'category_3_207': [['sku', ' 422636515 th 806532310']],
#  'category_3_208': [['จอแสดงผล', '24'], ['sku', ' 458276940 th 844340071']],
#  'category_3_209': [['sku', ' 596366330 th 1119728473']],
#  'category_3_210': [['sku', ' 456514309 th 842678620']],
#  'category_3_211': [['น้ำหนัก', 'ing'],
#   ['จอแสดงผล', 'with'],
#   ['lightน้ำหนัก', 'design'],
#   ['sku', ' 505170632 th 895484287']],
#  'category_3_212': [['ฮาร์ดดิสก์', 'ssd'], ['sku', ' 307310840 th 535774426']],
#  'category_3_213': [['แรม', '4'],
#   ['แรม', '4'],
#   ['sku', ' 338326057 th 655318929']],
#  'category_3_214': [['ฮาร์ดดิสก์', '250gb'],
#   ['เดือนcondition', 'สินค้าหมดสัญญาเช่า'],
#   ['sku', ' 477448954 th 868162873']],
#  'category_3_215': [['sku', ' 520914744 th 926852256']],
#  'category_3_216': [['ฮาร์ดดิสก์', '160'],
#   ['sku', ' 619100600 th 1178808344']],
#  'category_3_217': [['cpu', 'intel'],
#   ['หน้าจอ', '15.6'],
#   ['memory', 'แรม'],
#   ['storage', 'ฮาร์ดดิสก์'],
#   ['card', 'intel'],
#   ['รอม', 'ช่องต่อหูฟังช่องต่อไมค์'],
#   ['sku', ' 618700944 th 1178002977']],
#  'category_3_218': [['ฮาร์ดดิสก์', 'ssd'], ['sku', ' 315136418 th 579798392']],
#  'category_3_219': [['sku', ' 429384851 th 811210249']],
#  'category_3_220': [['แรม', '8gb'], ['sku', ' 273482281 th 433418368']],
#  'category_3_221': [['แรม', '4g'],
#   ['ฮาร์ดดิสก์', 'amd'],
#   ['แรม', '8gb'],
#   ['ฮาร์ดดิสก์', 'ssd'],
#   ['แรม', '8g']],
#  'category_3_222': [['ฮาร์ดดิสก์', '320gb'],
#   ['ฮาร์ดดิสก์', '320gb'],
#   ['sku', ' 357372659 th 700430122']],
#  'category_3_223': [['ฮาร์ดดิสก์', '500'],
#   ['cpu', ' intel i5 6200u up to 2.8 ghz รุ่นยังใหม่ '],
#   ['sku', ' 524772813 th 939400510'],
#   ['จอแสดงผล', 'usb']],
#  'category_3_224': [['แรม', '2gb'],
#   ['cpu', 'intel'],
#   ['ram', '2gb'],
#   ['ฮาร์ดดิสก์', 'ได้'],
#   ['แรม', '4gb'],
#   ['sku', ' 362846517 th 707960298']],
#  'category_3_225': [['ฮาร์ดดิสก์', '320gb'],
#   ['ฮาร์ดดิสก์', '320gb'],
#   ['sku', ' 306262057 th 532028488']],
#  'category_3_226': [['ฮาร์ดดิสก์', 'แรม'], ['sku', ' 426308346 th 809984137']],
#  'category_3_227': [['sku', ' 520906979 th 926876567']],
#  'category_3_228': [['แรม', '4gb'],
#   ['cpu', 'intel'],
#   ['ram', '4gb'],
#   ['แรม', '4gb'],
#   ['sku', ' 362854645 th 707986350']],
#  'category_3_229': [['sku', ' 383720733 th 745420127']],
#  'category_3_230': [['ฮาร์ดดิสก์', '320'], ['sku', ' 341896421 th 663882490']],
#  'category_3_231': [['sku', ' 499354441 th 888832580']],
#  'category_3_232': [['ฮาร์ดดิสก์', '1'],
#   ['แรม', '4gb'],
#   ['ฮาร์ดดิสก์', '1tb'],
#   ['แรม', '8']],
#  'category_3_233': [['แรม', '8'], ['sku', ' 338348872 th 655450591']],
#  'category_3_234': [['cpu', ' intel core i3 4000m 2.40ghz'],
#   ['หน้าจอ', '15.6'],
#   ['memory', ' แรม 4 gb'],
#   ['card', 'intel'],
#   ['รอม', 'ช่องต่อหูฟัง'],
#   ['sku', ' 341764533 th 663488273']],
#  'category_3_235': [['cpu', 'intel'],
#   ['หน้าจอ', '15.6'],
#   ['memory', 'แรม'],
#   ['storage', 'ฮาร์ดดิสก์'],
#   ['card', 'intel'],
#   ['รอม', 'ช่องต่อหูฟังช่องต่อไมค์'],
#   ['sku', ' 284442011 th 463196461']],
#  'category_3_236': [['แรม', '4g'],
#   ['ฮาร์ดดิสก์', 'amd'],
#   ['แรม', '8gb'],
#   ['ฮาร์ดดิสก์', 'ssd'],
#   ['แรม', '8g']],
#  'category_3_237': [['ฮาร์ดดิสก์', '250gb'],
#   ['เดือนcondition', 'สินค้าหมดสัญญาเช่า'],
#   ['sku', ' 526308795 th 943262650']],
#  'category_3_238': [['sku', ' 369256830 th 721506510']],
#  'category_3_239': [['แรม', '16gb'], ['sku', ' 351894856 th 688180629']],
#  'category_3_240': [['bar', '2.6ghz']],
#  'category_3_241': [['sku', ' ap067elab7776panth 95251955']],
#  'category_3_242': [['bar', '2.3ghz']],
#  'category_3_243': [['bar', '2.3ghz']],
#  'category_3_244': [['sku', ' 268149406 th 419640978']],
#  'category_3_245': [['sku', ' 339304444 th 657674326']],
#  'category_3_246': [['bar', 'i9'], ['sku', ' 338938903 th 656940293']],
#  'category_3_247': [['bar', 'i9'], ['sku', ' 338972081 th 656944412']],
#  'category_3_248': [],
#  'category_3_249': [['ฮาร์ดดิสก์', '1'], ['แรม', '4gb'], ['แรม', '8']],
#  'category_3_250': [['จอแสดงผล', '3.2'], ['sku', ' 206947226 th 311731496']],
#  'category_3_251': [['sku', ' 271912154 th 427453830']],
#  'category_3_252': [['sku', ' 206954757 th 311748169']],
#  'category_3_253': [['sku', ' 206956737 th 311743604']],
#  'category_3_254': [['sku', ' 479484496 th 869582594']],
#  'category_3_255': [['sku', ' 339288980 th 657660950']],
#  'category_3_256': [['sku', ' 278405142 th 446050699']],
#  'category_3_257': [['sku', ' 367388885 th 717882423']],
#  'category_3_258': [['sku', ' 263380058 th 406998756']],
#  'category_3_259': [['sku', ' 256080660 th 394889852']],
#  'category_3_260': [['จอแสดงผล', 'i5'], ['sku', ' 206959733 th 311750598']],
#  'category_3_261': [['sku', ' 263382021 th 407001355']],
#  'category_3_262': [['แรม', '4g'], ['แรม', '8g'], ['ฮาร์ดดิสก์', 'ssd']],
#  'category_3_263': [['bar', 'i5'], ['sku', ' 338914129 th 656814487']],
#  'category_3_264': [['sku', ' 367426145 th 717882899']],
#  'category_3_265': [['sku', ' 367416344 th 717866940']],
#  'category_3_266': [['bar', 'i5'], ['sku', ' 339306479 th 657680884']],
#  'category_3_267': [['sku', ' 256061912 th 394880055']],
#  'category_3_268': [['bar', 'i5'], ['sku', ' 338924689 th 656854169']],
#  'category_3_269': [['bar', 'i7'], ['sku', ' 338950541 th 656908726']],
#  'category_3_270': [['ฮาร์ดดิสก์', '1'],
#   ['แรม', '4gb'],
#   ['แรม', '8'],
#   ['แรม', '128gb']],
#  'category_3_271': [['bar', 'i7'], ['sku', ' 338956160 th 656882836']],
#  'category_3_272': [['sku', ' 265101762 th 412063584']],
#  'category_3_273': [['air', '1.6ghz'],
#   ['sku', ' 357692148 th 701478826'],
#   ['air', '1.6ghz']],
#  'category_3_274': [['air', '1.6ghz'],
#   ['sku', ' 357684428 th 701498251'],
#   ['air', '1.6ghz']],
#  'category_3_275': [['แรม', '4g'], ['แรม', '8g'], ['ฮาร์ดดิสก์', 'ssd']],
#  'category_3_276': [['bar', '1.4ghz'],
#   ['sku', ' 357690162 th 701476997'],
#   ['bar', '1.4ghz']],
#  'category_3_277': [['sku', ' ap067elab4ecrianth 88800081']],
#  'category_3_278': [['bar', '1.4ghz'],
#   ['sku', ' 357688208 th 701480659'],
#   ['bar', '1.4ghz']],
#  'category_3_279': [['ฮาร์ดดิสก์', '1'],
#   ['แรม', '4gb'],
#   ['แรม', '8gb'],
#   ['แรม', '128gb']],
#  'category_4_0': [['แรม', '4g'], ['แรม', '4gb']],
#  'category_4_1': [],
#  'category_4_2': [],
#  'category_4_3': [['ฮาร์ดดิสก์', '1'], ['แรม', '8gb'], ['ฮาร์ดดิสก์', 'ssd']],
#  'category_4_4': [],
#  'category_4_5': [['แรม', '4g'], ['แรม', '4gb'], ['แรม', '8g']],
#  'category_4_6': [],
#  'category_4_7': [],
#  'category_4_8': [],
#  'category_4_9': [],
#  'category_4_10': [],
#  'category_4_11': [],
#  'category_4_12': [],
#  'category_4_13': [],
#  'category_4_14': [['ฮาร์ดดิสก์', '1'],
#   ['แรม', '8gb'],
#   ['แรม', '128gb'],
#   ['ฮาร์ดดิสก์', 'ssd']],
#  'category_4_15': [],
#  'category_4_16': [],
#  'category_4_17': [],
#  'category_4_18': [],
#  'category_4_19': [['แรม', '4g'], ['แรม', '4gb'], ['แรม', '8g']],
#  'category_4_20': [['ฮาร์ดดิสก์', '1'],
#   ['แรม', '8gb'],
#   ['แรม', '128gb'],
#   ['ฮาร์ดดิสก์', 'ssd']],
#  'category_4_21': [['แรม', '4g'], ['แรม', '4gb'], ['แรม', '8g']],
#  'category_4_22': [],
#  'category_4_23': [],
#  'category_4_24': [],
#  'category_4_25': [['ฮาร์ดดิสก์', '1'],
#   ['แรม', '8gb'],
#   ['แรม', '128gb'],
#   ['ฮาร์ดดิสก์', 'ssd']],
#  'category_4_26': [['แรม', '4g'], ['แรม', '4gb'], ['แรม', '8g']],
#  'category_4_27': [],
#  'category_4_28': [['ฮาร์ดดิสก์', '1'], ['แรม', '8gb'], ['แรม', '128gb']],
#  'category_4_29': [],
#  'category_4_30': [],
#  'category_4_31': [],
#  'category_4_32': [],
#  'category_4_33': [['แรม', '4g'], ['แรม', '4gb'], ['แรม', '8g']],
#  'category_4_34': [],
#  'category_4_35': [],
#  'category_4_36': [],
#  'category_4_37': [],
#  'category_4_38': [],
#  'category_4_39': [],
#  'category_4_40': [['แรม', '8gb']],
#  'category_4_41': [],
#  'category_4_42': [['ฮาร์ดดิสก์', '1'], ['แรม', '8gb'], ['แรม', '128gb']],
#  'category_4_43': [],
#  'category_4_44': [],
#  'category_4_45': [['แรม', '8gb']],
#  'category_4_46': [],
#  'category_4_47': [],
#  'category_4_48': [['ฮาร์ดดิสก์', 'geforce']],
#  'category_4_49': [['ฮาร์ดดิสก์', 'windows'],
#   ['แรม', '4gb'],
#   ['แรม', '8g'],
#   ['แรม', '4g'],
#   ['ฮาร์ดดิสก์', '320gb']],
#  'category_4_50': [['แรม', '128gb'],
#   ['แรม', '8gb'],
#   ['ฮาร์ดดิสก์', '1'],
#   ['ฮาร์ดดิสก์', 'ssd']],
#  'category_4_51': [],
#  'category_4_52': [],
#  'category_4_53': [['ฮาร์ดดิสก์', 'geforce']],
#  'category_4_54': [['ฮาร์ดดิสก์', 'windows'],
#   ['แรม', '4gb'],
#   ['แรม', '8g'],
#   ['แรม', '4g'],
#   ['ฮาร์ดดิสก์', '320gb']],
#  'category_4_55': [['ฮาร์ดดิสก์', 'geforce']],
#  'category_4_56': [],
#  'category_4_57': [],
#  'category_4_58': [],
#  'category_4_59': [['ฮาร์ดดิสก์', 'geforce']],
#  'category_4_60': [['แรม', '8gb'], ['ฮาร์ดดิสก์', '1'], ['แรม', '128gb']],
#  'category_4_61': [],
#  'category_4_62': [['ฮาร์ดดิสก์', 'windows'],
#   ['แรม', '8g'],
#   ['แรม', '4g'],
#   ['ฮาร์ดดิสก์', '320gb'],
#   ['แรม', 'srfcpro']],
#  'category_4_63': [['แรม', '8gb'], ['แรม', '4gb'], ['แรม', '128gb']],
#  'category_4_64': [],
#  'category_4_65': [['ฮาร์ดดิสก์', 'windows'],
#   ['แรม', '8g'],
#   ['แรม', '4g'],
#   ['ฮาร์ดดิสก์', '320gb']],
#  'category_4_66': [],
#  'category_4_67': [],
#  'category_4_68': [],
#  'category_4_69': [['แรม', '8gb'], ['แรม', '4gb'], ['แรม', '128gb']],
#  'category_4_70': [['ฮาร์ดดิสก์', 'windows'],
#   ['แรม', '8g'],
#   ['แรม', '4g'],
#   ['ฮาร์ดดิสก์', '320gb']],
#  'category_4_71': [],
#  'category_4_72': [],
#  'category_4_73': [],
#  'category_4_74': [],
#  'category_4_75': [],
#  'category_4_76': [],
#  'category_4_77': [],
#  'category_4_78': [],
#  'category_4_79': [],
#  'category_4_80': [],
#  'category_4_81': [['แรม', '8gb'], ['ฮาร์ดดิสก์', '1'], ['แรม', '4gb']],
#  'category_4_82': [],
#  'category_4_83': [['ฮาร์ดดิสก์', 'windows'],
#   ['ฮาร์ดดิสก์', '1tb'],
#   ['แรม', '8g'],
#   ['แรม', '4g'],
#   ['แรม', '8gb'],
#   ['แรม', '128gb']],
#  'category_4_84': [],
#  'category_4_85': [],
#  'category_4_86': [],
#  'category_4_87': [],
#  'category_4_88': [],
#  'category_4_89': [['แรม', '8gb'], ['ฮาร์ดดิสก์', '1'], ['แรม', '4gb']],
#  'category_4_90': [['ฮาร์ดดิสก์', 'windows'],
#   ['ฮาร์ดดิสก์', '1tb'],
#   ['แรม', '8g'],
#   ['แรม', '4g']],
#  'category_4_91': [],
#  'category_4_92': [],
#  'category_4_93': [],
#  'category_4_94': [['แรม', '8']],
#  'category_4_95': [],
#  'category_4_96': [],
#  'category_4_97': [['แรม', '8']],
#  'category_4_98': [],
#  'category_4_99': [],
#  'category_4_100': [],
#  'category_4_101': [],
#  'category_4_102': [],
#  'category_4_103': [],
#  'category_4_104': [['แรม', '8gb'], ['ฮาร์ดดิสก์', '1']],
#  'category_4_105': [['แรม', '4g'],
#   ['ฮาร์ดดิสก์', '1tb'],
#   ['ฮาร์ดดิสก์', 'windows'],
#   ['แรม', '128gb']],
#  'category_4_106': [],
#  'category_4_107': [],
#  'category_4_108': [['แรม', '8']],
#  'category_4_109': [['แรม', '8']],
#  'category_4_110': [],
#  'category_4_111': [],
#  'category_4_112': [],
#  'category_4_113': [['แรม', '8gb'], ['ฮาร์ดดิสก์', '1'], ['แรม', '16gb']],
#  'category_4_114': [],
#  'category_4_115': [],
#  'category_4_116': [],
#  'category_4_117': [['แรม', '4g'],
#   ['ฮาร์ดดิสก์', '1tb'],
#   ['แรม', 'srfcpro'],
#   ['ฮาร์ดดิสก์', 'windows']],
#  'category_4_118': [],
#  'category_4_119': [],
#  'category_4_120': [],
#  'category_4_121': [],
#  'category_4_122': [],
#  'category_4_123': [],
#  'category_4_124': [],
#  'category_4_125': [],
#  'category_4_126': [],
#  'category_4_127': [['รอม', '512g']],
#  'category_4_128': [],
#  'category_4_129': [],
#  'category_4_130': [],
#  'category_4_131': [],
#  'category_4_132': [['แรม', '8gb'], ['ฮาร์ดดิสก์', '1'], ['ฮาร์ดดิสก์', '1']],
#  'category_4_133': [],
#  'category_4_134': [['แรม', '8g']],
#  'category_4_135': [],
#  'category_4_136': [],
#  'category_4_137': [],
#  'category_4_138': [['ฮาร์ดดิสก์', '256gb']],
#  'category_4_139': [],
#  'category_4_140': [['ฮาร์ดดิสก์', '1tb']],
#  'category_4_141': [],
#  'category_4_142': [],
#  'category_4_143': [],
#  'category_4_144': [],
#  'category_4_145': [],
#  'category_4_146': [],
#  'category_4_147': [],
#  'category_4_148': [],
#  'category_4_149': [],
#  'category_4_150': [],
#  'category_4_151': [['แรม', '8gb']],
#  'category_4_152': [],
#  'category_4_153': [],
#  'category_4_154': [],
#  'category_4_155': [],
#  ...}

# %%
dict_attr = {}
dict_value = {}
for i,v in attr_list.items():
    tmp_attr = []
    tmp_value = []
    for e in v:
        tmp_attr.append(e[0])
        tmp_value.append(e[1])
    dict_attr[i] = tmp_attr
    dict_value[i] = tmp_value

# %%
dict_value
# Out:
# {'category_0_0': [' 480942616 th 870640886'],
#  'category_0_1': [' 593772364 th 1113954823'],
#  'category_0_2': [' 404422189 th 784670279'],
#  'category_0_3': [' 385536916 th 749070165'],
#  'category_0_4': [],
#  'category_0_5': [' 265390897 th 412154584'],
#  'category_0_6': [' 594352438 th 1115888431'],
#  'category_0_7': [' 599364278 th 1176694583'],
#  'category_0_8': [' 309636084 th 547152150'],
#  'category_0_9': [' 571250946 th 1048780375'],
#  'category_0_10': [],
#  'category_0_11': [' sa861elaa8nxs2anth 17866375'],
#  'category_0_12': [' 526004055 th 942110374'],
#  'category_0_13': [' 571320012 th 1048806072'],
#  'category_0_14': [' 594306208 th 1115720937'],
#  'category_0_15': [],
#  'category_0_16': [' 289434461 th 479544867'],
#  'category_0_17': [' 594338092 th 1115814517'],
#  'category_0_18': [' 340860812 th 661136678'],
#  'category_0_19': [' 283666353 th 461390461'],
#  'category_0_20': [' 616572478 th 1170962904'],
#  'category_0_21': [' 307684896 th 537048806'],
#  'category_0_22': [' 373972071 th 728742055'],
#  'category_0_23': [' 310302392 th 552106447'],
#  'category_0_24': [' 280354579 th 453591358'],
#  'category_0_25': [' 595150747 th 1117932783'],
#  'category_0_26': [' 264741378 th 411062149'],
#  'category_0_27': [' 617108827 th 1172618764'],
#  'category_0_28': [' 511068392 th 907938105'],
#  'category_0_29': [' 207916690 th 313021622'],
#  'category_0_30': [' 289426638 th 479560515'],
#  'category_0_31': [' 289402378 th 479508064'],
#  'category_0_32': [],
#  'category_0_33': [' 612014873 th 1155486191'],
#  'category_0_34': [' 283658415 th 461387419'],
#  'category_0_35': [' 610820644 th 1151996547'],
#  'category_0_36': [' 617168251 th 1172664402'],
#  'category_0_37': [],
#  'category_0_38': [' 299990648 th 515722325'],
#  'category_0_39': [' 408012228 th 792604544'],
#  'category_0_40': [' 213755551 th 1138512951'],
#  'category_0_41': [' 222527681 th 889412058'],
#  'category_0_42': [' 595884854 th 1119120013'],
#  'category_0_43': [' 611154425 th 1152864043'],
#  'category_0_44': [],
#  'category_0_45': [],
#  'category_0_46': [' 533460461 th 963560027'],
#  'category_0_47': [' 495988905 th 884338021'],
#  'category_0_48': [],
#  'category_0_49': [' 234902116 th 713640836'],
#  'category_0_50': [' 494026300 th 882746256'],
#  'category_0_51': [' 604332862 th 1137128463'],
#  'category_0_52': [' 611792752 th 1155040122'],
#  'category_0_53': [' 343546977 th 668396557'],
#  'category_0_54': [],
#  'category_0_55': [' 587988556 th 1092062042'],
#  'category_0_56': [' 526910733 th 944832734'],
#  'category_0_57': [' 221761904 th 931764445'],
#  'category_0_58': [],
#  'category_0_59': [' 595984523 th 1119224437'],
#  'category_0_60': [' 612338298 th 1156318935'],
#  'category_0_61': [' 615188295 th 1166414603'],
#  'category_0_62': [' 524454971 th 937876465'],
#  'category_0_63': [' 600264311 th 1129088854'],
#  'category_0_64': [],
#  'category_0_65': [' 273675979 th 909150212'],
#  'category_0_66': [' 602338133 th 1134472444'],
#  'category_0_67': [],
#  'category_0_68': [' 602306922 th 1134540658'],
#  'category_0_69': [' 594522639 th 1116438503'],
#  'category_0_70': [],
#  'category_0_71': [],
#  'category_0_72': [' 477810714 th 868398689'],
#  'category_0_73': [' 594600147 th 1116542821'],
#  'category_0_74': [' 587986529 th 1092060094'],
#  'category_0_75': [' 264227445 th 791158102'],
#  'category_0_76': [],
#  'category_0_77': [],
#  'category_0_78': [' 617148976 th 1172758996'],
#  'category_0_79': [' adreno 640'],
#  'category_0_80': [' 601804919 th 1133136752'],
#  'category_0_81': [' 594172715 th 1115450949'],
#  'category_0_82': [' 368406522 th 720230984'],
#  'category_0_83': [' 596522329 th 1119982547'],
#  'category_0_84': [' 561194526 th 1029420220'],
#  'category_0_85': [' 594468094 th 1116094894'],
#  'category_0_86': [' 463662961 th 851448786'],
#  'category_0_87': [' 535266417 th 967736081'],
#  'category_0_88': [' 423372568 th 807510964'],
#  'category_0_89': [' 585868817 th 1085346089'],
#  'category_0_90': [' 560716580 th 1028340869'],
#  'category_0_91': [' 450862429 th 833064273'],
#  'category_0_92': [],
#  'category_0_93': [],
#  'category_0_94': [' 247483720 th 381013589'],
#  'category_0_95': [' 602816227 th 1135834467'],
#  'category_0_96': [' 850 900 1800 1900mhz', ' 593798249 th 1114132244'],
#  'category_0_97': [' 521740370 th 929150153'],
#  'category_0_98': [],
#  'category_0_99': [' 333366885 th 778320295'],
#  'category_0_100': [],
#  'category_0_101': ['', ' 341378077 th 675334858', ''],
#  'category_0_102': ['', ' 561338580 th 1029522253', '', ''],
#  'category_0_103': [' snapdragon 665 และ game boost 2.0',
#   ' 464602916 th 852566078',
#   ''],
#  'category_0_104': ['', '', ''],
#  'category_0_105': ['', '', '', '', ''],
#  'category_0_106': [' 535274298 th 967670887', '', ''],
#  'category_0_107': ['', '', '', '', '', ' 593006855 th 1111420743', ''],
#  'category_0_108': ['', '', ' 534116952 th 965278124', '', '', ''],
#  'category_0_109': [''],
#  'category_0_110': ['', '', ''],
#  'category_0_111': [''],
#  'category_0_112': ['', '', '', '', ' 397028849 th 771186043', '', '', ''],
#  'category_0_113': ['', '', ''],
#  'category_0_114': ['', '', '', '', ''],
#  'category_0_115': ['', '', '', ' 348144719 th 681012331', ''],
#  'category_0_116': ['', '', '', '', '', ' 601974390 th 1133472706', '', ''],
#  'category_0_117': [' 563834910 th 1033632588', '', ''],
#  'category_0_118': ['', ' 612114232 th 1155648106', '', '', ''],
#  'category_0_119': [' 594318240 th 1115776512', ''],
#  'category_0_120': ['', '', ' 517866127 th 919968463'],
#  'category_0_121': ['', ' 590034214 th 1151538667', '', ''],
#  'category_0_122': [''],
#  'category_0_123': ['', '', ' 595656544 th 1118856653', '', ''],
#  'category_0_124': [' 587972692 th 1092032386', '', ''],
#  'category_0_125': ['', '', '', ' 599192867 th 1127342158', '', ''],
#  'category_0_126': ['', ' 616436256 th 1170664199', '', ''],
#  'category_0_127': ['', '', '', '', ' 599066750 th 1127098963', ''],
#  'category_0_128': ['', ' 612664987 th 1157674465', '', ''],
#  'category_0_129': ['', ' 525912975 th 942022546'],
#  'category_0_130': ['', '', ''],
#  'category_0_131': [''],
#  'category_0_132': ['', ' 328508874 th 629190573', ''],
#  'category_0_133': [' how to track the order ',
#   ' about network bands',
#   ' what if i m dissatisfied with the product ',
#   ' we guarantee you will be 100เปอร์เซนต์ satisfied with the quality of your product. if you re unhappy with it please contact our customer service who will be glad to help.when contacting customer service team please give your order number a short description and a photo of the problem so we can prevent these problems in the future.',
#   '',
#   ' 604588733 th 1137744184',
#   '',
#   ''],
#  'category_0_134': ['', '', '', ' 599300858 th 1127464169', '', ''],
#  'category_0_135': [' how to track the order ',
#   ' about network bands',
#   ' what if i m dissatisfied with the product ',
#   ' we guarantee you will be 100เปอร์เซนต์ satisfied with the quality of your product. if you re unhappy with it please contact our customer service who will be glad to help.when contacting customer service team please give your order number a short description and a photo of the problem so we can prevent these problems in the future.',
#   '',
#   ' 604632624 th 1137814458',
#   '',
#   ''],
#  'category_0_136': ['', '', '', '', '', '', ''],
#  'category_0_137': [' 616744349 th 1171552379'],
#  'category_0_138': [' how to track the order ',
#   ' about network bands',
#   ' what if i m dissatisfied with the product ',
#   ' we guarantee you will be 100เปอร์เซนต์ satisfied with the quality of your product. if you re unhappy with it please contact our customer service who will be glad to help.when contacting customer service team please give your order number a short description and a photo of the problem so we can prevent these problems in the future.',
#   '',
#   ' 604648308 th 1137718830',
#   '',
#   ''],
#  'category_0_139': ['', '', '', ' 618416957 th 1177008040', '', ''],
#  'category_0_140': ['', '', ' 561416932 th 1029822407', '', ''],
#  'category_0_141': [' how to track the order ',
#   ' about network bands',
#   ' what if i m dissatisfied with the product ',
#   ' we guarantee you will be 100เปอร์เซนต์ satisfied with the quality of your product. if you re unhappy with it please contact our customer service who will be glad to help.when contacting customer service team please give your order number a short description and a photo of the problem so we can prevent these problems in the future.',
#   '',
#   ' 604770080 th 1138152071',
#   '',
#   ''],
#  'category_0_142': [' how to track the order ',
#   ' about network bands',
#   ' what if i m dissatisfied with the product ',
#   ' we guarantee you will be 100เปอร์เซนต์ satisfied with the quality of your product. if you re unhappy with it please contact our customer service who will be glad to help.when contacting customer service team please give your order number a short description and a photo of the problem so we can prevent these problems in the future.',
#   '',
#   ' 604694624 th 1137940704',
#   '',
#   ''],
#  'category_0_143': ['', '', '', ' 569488592 th 1045390934', ''],
#  'category_0_144': ['', ' 615690512 th 1168470733', '', ''],
#  'category_0_145': [' how to track the order ',
#   ' about network bands',
#   ' what if i m dissatisfied with the product ',
#   ' we guarantee you will be 100เปอร์เซนต์ satisfied with the quality of your product. if you re unhappy with it please contact our customer service who will be glad to help.when contacting customer service team please give your order number a short description and a photo of the problem so we can prevent these problems in the future.',
#   '',
#   ' 604548331 th 1137518592',
#   '',
#   ''],
#  'category_0_146': [' how to track the order ',
#   ' about network bands',
#   ' what if i m dissatisfied with the product ',
#   ' we guarantee you will be 100เปอร์เซนต์ satisfied with the quality of your product. if you re unhappy with it please contact our customer service who will be glad to help.when contacting customer service team please give your order number a short description and a photo of the problem so we can prevent these problems in the future.',
#   '',
#   ' 604796218 th 1138260078',
#   '',
#   ''],
#  'category_0_147': ['', ' 373546910 th 728028139', ''],
#  'category_0_148': ['', '', '', ''],
#  'category_0_149': ['', ''],
#  'category_0_150': [' how to track the order ',
#   ' about network bands',
#   ' what if i m dissatisfied with the product ',
#   ' we guarantee you will be 100เปอร์เซนต์ satisfied with the quality of your product. if you re unhappy with it please contact our customer service who will be glad to help.when contacting customer service team please give your order number a short description and a photo of the problem so we can prevent these problems in the future.',
#   '',
#   ' 604540891 th 1137654540',
#   '',
#   ''],
#  'category_0_151': [' how to track the order ',
#   ' about network bands',
#   ' what if i m dissatisfied with the product ',
#   ' we guarantee you will be 100เปอร์เซนต์ satisfied with the quality of your product. if you re unhappy with it please contact our customer service who will be glad to help.when contacting customer service team please give your order number a short description and a photo of the problem so we can prevent these problems in the future.',
#   '',
#   ' 604696718 th 1138034104',
#   '',
#   ''],
#  'category_0_152': ['', '', '', '', '', ''],
#  'category_0_153': ['', '', '', '', ' 598708474 th 1126022611', ''],
#  'category_0_154': [' how to track the order ',
#   ' about network bands',
#   ' what if i m dissatisfied with the product ',
#   ' we guarantee you will be 100เปอร์เซนต์ satisfied with the quality of your product. if you re unhappy with it please contact our customer service who will be glad to help.when contacting customer service team please give your order number a short description and a photo of the problem so we can prevent these problems in the future.',
#   '',
#   ' 604840484 th 1138436028',
#   '',
#   ''],
#  'category_0_155': [' how to track the order ',
#   ' about network bands',
#   ' what if i m dissatisfied with the product ',
#   ' we guarantee you will be 100เปอร์เซนต์ satisfied with the quality of your product. if you re unhappy with it please contact our customer service who will be glad to help.when contacting customer service team please give your order number a short description and a photo of the problem so we can prevent these problems in the future.',
#   '',
#   ' 604710729 th 1138026540',
#   '',
#   ''],
#  'category_0_156': [' 259769078 th 399969081', ''],
#  'category_0_157': ['', ' 615722552 th 1168598091', '', ''],
#  'category_0_158': ['', '', '', '', ''],
#  'category_0_159': ['', '', '', ''],
#  'category_0_160': ['', ' 600314964 th 1129342245'],
#  'category_0_161': ['', '', '', '', '', ' 596214366 th 1119566057', ''],
#  'category_0_162': [' 596222116 th 1119494559'],
#  'category_0_163': ['', ' 594192103 th 1115374774'],
#  'category_0_164': ['',
#   '',
#   ' huawei kirin 710f octa core 4 x cortex a73 based 2.2 ghz 4 x cortex a53 based 1.7 ghz',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ' 601420142 th 1132208267',
#   '',
#   ''],
#  'category_0_165': ['', ' 289716515 th 847906769', '', ''],
#  'category_0_166': [' 528100922 th 947986549'],
#  'category_0_167': [' 375868110 th 732110495', ''],
#  'category_0_168': ['', ' 601192402 th 1131434450'],
#  'category_0_169': ['', '', '', '', '', ' 599110939 th 1127098782', '', ''],
#  'category_0_170': ['', '', '', '', '', ''],
#  'category_0_171': [' 593028182 th 1112374566', '', ''],
#  'category_0_172': ['', '', '', '', '', ' 596394547 th 1119824766', ''],
#  'category_0_173': ['', ' 320064385 th 812406952', ''],
#  'category_0_174': [' 357150478 th 699988012'],
#  'category_0_175': ['', '', '', '', ''],
#  'category_0_176': ['', '', '', '', ' 594532004 th 1116304128', ''],
#  'category_0_177': ['', ' 594462946 th 1116358223', ''],
#  'category_0_178': [' 594398527 th 1116232042', ''],
#  'category_0_179': ['',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ' 594270092 th 1115594659',
#   ''],
#  'category_0_180': ['', ' 596522728 th 1120102293'],
#  'category_0_181': ['', '', '', '', '', '', '', '', '', ''],
#  'category_0_182': ['', '', ' 328258784 th 628690621', '', ''],
#  'category_0_183': [' 342498502 th 665538006'],
#  'category_0_184': ['', '', '', ' 596756304 th 1120612454'],
#  'category_0_185': ['', '', '', '', ' 291298342 th 483916431'],
#  'category_0_186': ['', '', ' 6gb', '', ' 598526513 th 1125486439'],
#  'category_0_187': ['', '', '', '', ' 358866806 th 704258251', ''],
#  'category_0_188': ['', '', '', '', ' 291282274 th 483922421', '', ''],
#  'category_0_189': ['',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  'category_0_190': ['', ''],
#  'category_0_191': [''],
#  'category_0_192': [' 570030784 th 1046476409'],
#  'category_0_193': ['', ' 343882248 th 669814957', '', ''],
#  'category_0_194': ['', ' 599542296 th 1127736447'],
#  'category_0_195': ['', ' 594360907 th 1117668861', ''],
#  'category_0_196': [' 582918405 th 1077862110', ''],
#  'category_0_197': ['', '', ' 403214185 th 782722982'],
#  'category_0_198': ['', '', ' 310318635 th 552322430'],
#  'category_0_199': ['', '', ' 328120492 th 628182917', ''],
#  'category_0_200': [],
#  'category_0_201': [' 593892371 th 1114492226'],
#  'category_0_202': [],
#  'category_0_203': [' 599084896 th 1127026639'],
#  'category_0_204': [' 598884689 th 1127090507', '', ''],
#  'category_0_205': [' 599068800 th 1127036426'],
#  'category_0_206': ['', '', '', ' 611118429 th 1152724834', '', '', ''],
#  'category_0_207': [' 576962917 th 1065758090', '', ''],
#  'category_0_208': ['', ' 595536413 th 1118762069', ''],
#  'category_0_209': ['', '', '', '', '', ''],
#  'category_0_210': [' 593892271 th 1114412808'],
#  'category_0_211': ['', ' 326952660 th 624226626', ''],
#  'category_0_212': [' 265436667 th 412888313', ''],
#  'category_0_213': ['', '', '', '', ''],
#  'category_0_214': [' 403004685 th 782382982', ''],
#  'category_0_215': [' 417942838 th 801314333', ''],
#  'category_0_216': [' 604764960 th 1138830339', '', ''],
#  'category_0_217': ['', '', ''],
#  'category_0_218': [' 580734651 th 1073342091', '', ''],
#  'category_0_219': ['', '', '', '', '', ' 600982947 th 1131064759', ''],
#  'category_0_220': ['', '', '', ''],
#  'category_0_221': ['', '', '', '', ' 594530664 th 1116430818'],
#  'category_0_222': ['', '', '', '', ''],
#  'category_0_223': ['', ' 599480538 th 1128100802', '', ''],
#  'category_0_224': [' 418146358 th 801330478', ''],
#  'category_0_225': [' 402982804 th 782386887', ''],
#  'category_0_226': ['', '', '', '', '', ''],
#  'category_0_227': [' 418142432 th 801348251', ''],
#  'category_0_228': ['', ''],
#  'category_0_229': ['', ' 460654202 th 847892071', '', ''],
#  'category_0_230': ['', ' 591918757 th 1108276056', ''],
#  'category_0_231': [' 452446880 th 836206666', ''],
#  'category_0_232': ['', '', '', '', '', '', '', '', ''],
#  'category_0_233': ['', '', ' 616366381 th 1170420923', ''],
#  'category_0_234': ['', '', '', ' 600790956 th 1130624325', ''],
#  'category_0_235': ['', '', ' 338952152 th 656874222'],
#  'category_0_236': ['', '', ' 599704659 th 1128032096'],
#  'category_0_237': ['', ' 601276452 th 1131698507', '', ''],
#  'category_0_238': ['', '', '', '', ' 408100004 th 792804384', ''],
#  'category_0_239': ['', '', '', '', ' 416330239 th 799976588'],
#  'category_0_240': [' 268324226 th 603248979', '', ''],
#  'category_0_241': ['', ' 365700164 th 714698964'],
#  'category_0_242': ['', ' 552184749 th 1006836063'],
#  'category_0_243': ['', ' 385566108 th 815456220'],
#  'category_0_244': ['', ' 405068513 th 805010589'],
#  'category_0_245': ['', ' 400040507 th 777298618', '', ''],
#  'category_0_246': [' 270282019 th 422771415', '', ''],
#  'category_0_247': [' 405108122 th 805050038', ''],
#  'category_0_248': ['', ' 550594069 th 1000618756'],
#  'category_0_249': ['', ' 275617311 th 815450167', '', ''],
#  'category_0_250': ['', ' 603116847 th 1136274443'],
#  'category_0_251': ['', ' 314710401 th 576202145', '', ''],
#  'category_0_252': ['', ' 603110290 th 1136224459'],
#  'category_0_253': ['', ' 328582974 th 629520209'],
#  'category_0_254': ['', '', ' 270179696 th 578982558', '', ''],
#  'category_0_255': ['',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'mtk 6580 1.3ghz quad core',
#   '',
#   '',
#   '',
#   '',
#   ' bmpjpegpng',
#   '',
#   'haixu battery 3200mah '],
#  'category_0_256': ['', ' 603094531 th 1136238502'],
#  'category_0_257': ['', '', '', ''],
#  'category_0_258': ['', ' 312418366 th 1030968530', '', ''],
#  'category_0_259': ['', '', ' 601494155 th 1132134762'],
#  'category_0_260': ['', '', ' 314412441 th 573360540', '', ''],
#  'category_0_261': [' 312924192 th 563944053', '', ''],
#  'category_0_262': ['', ''],
#  'category_0_263': [' 602892154 th 1136000618'],
#  'category_0_264': ['', ' 601448844 th 1132182102'],
#  'category_0_265': ['', '', '', ''],
#  'category_0_266': ['', '', ' 601266875 th 1131662738'],
#  'category_0_267': ['', ''],
#  'category_0_268': ['', ' 555184763 th 1015570247'],
#  'category_0_269': ['', ' 603102818 th 1136286057'],
#  'category_0_270': ['', '', ' 428064860 th 810616983'],
#  'category_0_271': ['', '', ''],
#  'category_0_272': [' 603142333 th 1136248709'],
#  'category_0_273': [' 553590398 th 1011094010'],
#  'category_0_274': ['', ' 555104212 th 1015272954'],
#  'category_0_275': [' 286990241 th 467726070', '', ''],
#  'category_0_276': ['', '', ' 331348050 th 636820649', '', ''],
#  'category_0_277': ['', ' 170065248 th 1042248064', '', ''],
#  'category_0_278': [' 268626162 th 420613109', '', ''],
#  'category_0_279': ['', '', ' 289374358 th 479328386', '', ''],
#  'category_1_0': ['', '', ' 444394704 th 823064920'],
#  'category_1_1': ['', ' 253236549 th 390793920'],
#  'category_1_2': [''],
#  'category_1_3': ['', '', ''],
#  'category_1_4': ['', ' 259980716 th 400314174'],
#  'category_1_5': ['', '', ' 611042206 th 1152562194'],
#  'category_1_6': [' 309616290 th 547144949'],
#  'category_1_7': ['', '', '', '', '', ' 505676488 th 896220807'],
#  'category_1_8': [' 616546968 th 1171084081'],
#  'category_1_9': ['', ''],
#  'category_1_10': [' 281307545 th 456411484'],
#  'category_1_11': ['', '', ''],
#  'category_1_12': ['', ' 598818135 th 1126274363'],
#  'category_1_13': ['', ' 575476567 th 1061786680', ''],
#  'category_1_14': ['', '', '', ''],
#  'category_1_15': [''],
#  'category_1_16': [' sa861elaa6wjmeanth 14640556'],
#  'category_1_17': [' 464218693 th 851672912'],
#  'category_1_18': ['', '', '', '', '', ' 332126164 th 639418501'],
#  'category_1_19': [' sa861elaa1jddcanth 3366121'],
#  'category_1_20': ['', ' 511662652 th 909614254'],
#  'category_1_21': [''],
#  'category_1_22': [' sa861elaa6y4tnanth 14725929', ''],
#  'category_1_23': ['', '', '', '', '', '', '', '', ''],
#  'category_1_24': ['', ' 578246550 th 1067310939'],
#  'category_1_25': ['',
#   ' octa core 1.8ghz 1.6ghz',
#   '',
#   ' 385742465 th 749484157',
#   ''],
#  'category_1_26': ['',
#   '',
#   'qualcomm sdm 670 dual 2.0 ghz hexa 1.7ghz ',
#   '',
#   '',
#   ' 349596471 th 683518481',
#   ''],
#  'category_1_27': [' sa861elaa96yxuanth 18836115', ''],
#  'category_1_28': ['',
#   '',
#   'qualcomm sdm 670 dual 2.0 ghz hexa 1.7ghz ',
#   '',
#   '',
#   ' 349716880 th 683852191',
#   ''],
#  'category_1_29': ['',
#   ' octa core 1.8ghz 1.6ghz',
#   '',
#   ' 385762324 th 749490169',
#   ''],
#  'category_1_30': [''],
#  'category_1_31': ['', '', ''],
#  'category_1_32': ['', '', ' 425442569 th 809202694', ''],
#  'category_1_33': ['', ' 420596705 th 802242814', ''],
#  'category_1_34': [' sa861elaa772b0anth 15168461'],
#  'category_1_35': ['',
#   ' octa core 1.8ghz 1.6ghz',
#   '',
#   ' 385844163 th 749708159',
#   ''],
#  'category_1_36': [],
#  'category_1_37': [' 262630513 th 404670218'],
#  'category_1_38': ['', ' 511720036 th 909722120'],
#  'category_1_39': ['',
#   '',
#   'qualcomm sdm 670 dual 2.0 ghz hexa 1.7ghz ',
#   '',
#   '',
#   ' 349706881 th 683844239',
#   ''],
#  'category_1_40': ['',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'b1 b2 b5 b6 b8 b19',
#   '850 900 1800 1900 mhz',
#   '',
#   'kirin 659 4 x a53 2.4 ghz 4 x a53 1.7 ghz ',
#   ' 616454002 th 1170706018'],
#  'category_1_41': ['', ' 598458483 th 1125468954'],
#  'category_1_42': ['', '', ' 287662655 th 470616189', ''],
#  'category_1_43': ['', '', ' 282104000 th 867692783', ''],
#  'category_1_44': [''],
#  'category_1_45': ['', '', ' 334238580 th 647152832', ''],
#  'category_1_46': [' 595116515 th 1117738762', '', ''],
#  'category_1_47': [''],
#  'category_1_48': ['', '', ' 589984097 th 1099528273'],
#  'category_1_49': [' 417282490 th 1163072900'],
#  'category_1_50': ['b1 b2 b5',
#   'b2 b3 b5 b8',
#   '',
#   ' 609582335 th 1148502501',
#   ''],
#  'category_1_51': [' 595136404 th 1117770081', '', ''],
#  'category_1_52': ['', '', ' 290826124 th 482712138'],
#  'category_1_53': ['', ' 342568306 th 665622238'],
#  'category_1_54': [' 595122670 th 1117796536', '', ''],
#  'category_1_55': ['', '', '', ' 536688599 th 971382516'],
#  'category_1_56': ['', ' 595106628 th 1117744619', '', ''],
#  'category_1_57': [' 282104000 th 459910623', '', ' 306912272 th 534614461'],
#  'category_1_58': [' 557924211 th 1024318332'],
#  'category_1_59': ['', '', ' 399314990 th 775480298'],
#  'category_1_60': ['', ' 264390003 th 620896181'],
#  'category_1_61': [' 290632248 th 482354221'],
#  'category_1_62': ['', '', '', '', '', ' 287440622 th 469360971', ''],
#  'category_1_63': ['', ' 404528555 th 784942219'],
#  'category_1_64': [' 292678457 th 532430370'],
#  'category_1_65': ['', '', '', ' 370918900 th 724140336'],
#  'category_1_66': ['', '', '', '', '', ''],
#  'category_1_67': [' 255408768 th 393960215'],
#  'category_1_68': ['', '', '', '', ' 290662150 th 482422464'],
#  'category_1_69': ['', '', ''],
#  'category_1_70': ['', ' 506850955 th 899038940', ''],
#  'category_1_71': ['', '', '', ' 370904875 th 724108404'],
#  'category_1_72': ['', ' 336198592 th 651110836'],
#  'category_1_73': ['', '', '', '', '', '', ' 336002915 th 650804832', ''],
#  'category_1_74': [' 529216400 th 963900075', ''],
#  'category_1_75': ['', '', '', ' 370906523 th 724086780'],
#  'category_1_76': ['', '', '', '', ''],
#  'category_1_77': ['', ' 333328687 th 643922974'],
#  'category_1_78': [' 341902484 th 663890262'],
#  'category_1_79': ['', '', '', ' 370930514 th 724094910'],
#  'category_1_80': ['',
#   '',
#   '',
#   '',
#   '',
#   ' 2224 by 1668 resolution at 264 pixels per inch ppi ',
#   ' wi fi 802.11a b g n ac dual band 2.4ghz and 5ghz ht80 with mimo',
#   ' bluetooth 4.2',
#   '',
#   '',
#   '',
#   ' built in 30.4 watt hour rechargeable lithium polymer battery',
#   '',
#   '',
#   ' ios 10.0.1 upgradable to ios 11',
#   ' 1 year',
#   ' ap067elaag6sgganth 33437482'],
#  'category_1_81': ['', ''],
#  'category_1_82': ['',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ' 2224 by 1668 resolution at 264 pixels per inch ppi ',
#   ' wi fi 802.11a b g n ac dual band 2.4ghz and 5ghz ht80 with mimo',
#   ' bluetooth 4.2',
#   '',
#   '',
#   '',
#   ' built in 30.4 watt hour rechargeable lithium polymer battery',
#   '',
#   '',
#   ' ios 10.0.1 upgradable to ios 11',
#   ' 1 year',
#   ' ap067elaakgmyjanth 41624609'],
#  'category_1_83': [' ap067elad0j7anth 146971', ''],
#  'category_1_84': ['', '', ' 388878675 th 755276884', ''],
#  'category_1_85': ['', ' 389948570 th 757528306', ''],
#  'category_1_86': ['', ' cu106elaajdf26anth 39529562', ''],
#  'category_1_87': ['', ' 285554967 th 465794708', ''],
#  'category_1_88': ['', '', '', ' 503692395 th 893042913'],
#  'category_1_89': ['', ' al864elabnysb8anth 134358055', ''],
#  'category_1_90': ['', '', '', '', '', '', ' 272845086 th 430919368', ''],
#  'category_1_91': ['', ''],
#  'category_1_92': ['', '', '', '', '', '', ' 280801443 th 454758950', ''],
#  'category_1_93': [' 499020804 th 888320509', ''],
#  'category_1_94': ['', ' 300902238 th 518496087', ''],
#  'category_1_95': ['',
#   '',
#   ' gpu img gx6250',
#   '',
#   '',
#   '',
#   '',
#   ' 300990094 th 518858140',
#   '',
#   ''],
#  'category_1_96': ['', ' 282648205 th 460016239', ''],
#  'category_1_97': ['', '', ' 601642446 th 1132642209'],
#  'category_1_98': ['', '', ' 207850428 th 400637138', ''],
#  'category_1_99': ['',
#   '',
#   '',
#   '',
#   '',
#   ' 802.11ac a b g n 2.4ghz 5ghz อินเตอร์เน็ตไร้สาย',
#   ' 280550470 th 454471923',
#   ''],
#  'category_1_100': ['', '', '', ' 282952215 th 460608655', ''],
#  'category_1_101': [' 577362037 th 1249164460', ''],
#  'category_1_102': ['', '', ' 388890678 th 755322201', ''],
#  'category_1_103': [' 499128490 th 888362234', ''],
#  'category_1_104': ['', '', '', ' 252873165 th 390211412', ''],
#  'category_1_105': ['', '', ' 618982731 th 1178448719'],
#  'category_1_106': ['', '', '', '', '', ' 409828698 th 795708964', ''],
#  'category_1_107': ['', '', '', ' cu106elaatf4wqanth 60257261', ''],
#  'category_1_108': ['',
#   '',
#   '',
#   '',
#   ' 802.11ac a b g n 2.4ghz 5ghz อินเตอร์เน็ตไร้สาย',
#   ' 540920177 th 980288611',
#   ''],
#  'category_1_109': ['', '', '', '', ' 243341561 th 373364383'],
#  'category_1_110': ['', '', '', '', '', ' 301222703 th 519562963', ''],
#  'category_1_111': ['', '', '', '', ' 216059051 th 326591918', ''],
#  'category_1_112': ['', '', ' 387584750 th 753258646', ''],
#  'category_1_113': ['', '', ' 276668065 th 441462371', ''],
#  'category_1_114': ['', ' 300898700 th 518536872', ''],
#  'category_1_115': ['', '', '', ' 501552258 th 891508304'],
#  'category_1_116': ['', '', '', '', '', ' 342838335 th 666296234', ''],
#  'category_1_117': ['', '', ''],
#  'category_1_118': ['', ''],
#  'category_1_119': ['', '', '', '', ' 300888638 th 518510997', ''],
#  'category_1_120': [' 536640279 th 971030868', ''],
#  'category_1_121': ['', '', ' 547804511 th 991624323'],
#  'category_1_122': ['', '', '', ' 411226137 th 796098879', ''],
#  'category_1_123': ['', '', ''],
#  'category_1_124': [' 595372630 th 1118738329', ''],
#  'category_1_125': ['', ' 609808466 th 1149298147', ''],
#  'category_1_126': ['',
#   '',
#   ' the keyboard is not included',
#   ' 600086384 th 1128714973',
#   ''],
#  'category_1_127': ['', '', ' 330954090 th 635632809', ''],
#  'category_1_128': ['', '', ' 455858290 th 841196295'],
#  'category_1_129': ['', ' 504760349 th 1031036585', ''],
#  'category_1_130': ['', '', ' 504838476 th 894608323'],
#  'category_1_131': [' 369338085 th 721592040', ''],
#  'category_1_132': ['',
#   '',
#   '',
#   '',
#   '',
#   ' 8 gb',
#   ' 365274624 th 713730324',
#   '',
#   ''],
#  'category_1_133': ['',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ' 8 gb',
#   '',
#   ' 328764185 th 630004477',
#   ''],
#  'category_1_134': ['', '', ' 511308227 th 908492581'],
#  'category_1_135': ['', ' 345244860 th 673554742', '', ''],
#  'category_1_136': ['', ' 301128225 th 519320229', ''],
#  'category_1_137': ['', '', '', '', ' 261988577 th 403364153'],
#  'category_1_138': ['', '', ' 306422970 th 533032057', ''],
#  'category_1_139': [' 509614941 th 1066868406', ''],
#  'category_1_140': ['', ' 267667800 th 418806059', ''],
#  'category_1_141': ['', '', '', ' 314724061 th 576202229', ''],
#  'category_1_142': ['', ' 545596916 th 986722073', ''],
#  'category_1_143': [' 509564789 th 904688102', ''],
#  'category_1_144': [' 258113124 th 397953498', ''],
#  'category_1_145': ['', ' 503772526 th 893346561'],
#  'category_1_146': ['', ' 314706423 th 576198303', ''],
#  'category_1_147': ['', ' 372810993 th 726910568'],
#  'category_1_148': ['', '', '', '', ' te655elabaz3hianth 104153078'],
#  'category_1_149': [' 261988383 th 403360137'],
#  'category_1_150': [' 283590613 th 461450785', ''],
#  'category_1_151': ['', '', '', ' 582144567 th 1075730686'],
#  'category_1_152': ['',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ' ใช่',
#   ' 527916026 th 947446494'],
#  'category_1_153': ['',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'dual cameras',
#   '',
#   'wifi',
#   'yes',
#   '',
#   '',
#   '',
#   'second webcam',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '2.4ghz 5ghz',
#   'arm mali t880ล้านพิกเซล 4',
#   'bluetooth4.2',
#   ' 557868043 th 1024146416'],
#  'category_1_154': ['',
#   '',
#   '',
#   '',
#   ' b1',
#   '',
#   ' b3b8',
#   ' 503218189 th 892562304',
#   ''],
#  'category_1_155': ['', '', ' 410346680 th 795522708', ''],
#  'category_1_156': ['',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ' รองรับ',
#   '',
#   '',
#   ' 372758376 th 726788440'],
#  'category_1_157': ['', ' 505198696 th 895494851'],
#  'category_1_158': ['', '', '', ' 372780203 th 726794923'],
#  'category_1_159': ['',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ' รองรับ',
#   '',
#   '',
#   ' 372736984 th 726782949'],
#  'category_1_160': ['', '', '', ' 554660482 th 1013802023'],
#  'category_1_161': ['', ' 446310813 th 824672133', ''],
#  'category_1_162': ['', '', ' 522992772 th 933116322', ''],
#  'category_1_163': ['', ' 256948533 th 396011124'],
#  'category_1_164': ['', '', ' 248973909 th 383782356'],
#  'category_1_165': [' 607790253 th 1143294210'],
#  'category_1_166': ['', ''],
#  'category_1_167': [' 339268461 th 657632012'],
#  'category_1_168': ['', ''],
#  'category_1_169': [' 271533978 th 427492103'],
#  'category_1_170': [' 262877305 th 801350305'],
#  'category_1_171': ['', ' 425832276 th 809478858'],
#  'category_1_172': ['', '', ' 264542523 th 410767565', ''],
#  'category_1_173': ['', ' 287540767 th 469840328'],
#  'category_1_174': [' 313418163 th 567950229'],
#  'category_1_175': [' am049elaa5whhbanth 12681403', ''],
#  'category_1_176': ['', '', ' 399332611 th 775518205'],
#  'category_1_177': ['', ' 391212729 th 759204916'],
#  'category_1_178': ['', ' 391056009 th 758880313'],
#  'category_1_179': ['', ' 11558677 th 746428153', '', ''],
#  'category_1_180': ['', ' 296170535 th 502950500'],
#  'category_1_181': [' 306398869 th 532916653'],
#  'category_1_182': ['', '', ' 264549520 th 410769989', ''],
#  'category_1_183': [' 536712644 th 971368999'],
#  'category_1_184': [' 339382658 th 1090882656'],
#  'category_1_185': [' 230905368 th 353640017'],
#  'category_1_186': ['', ' 339074919 th 657212791'],
#  'category_1_187': [' 364616286 th 712138554'],
#  'category_1_188': ['', ' 425932118 th 809532345'],
#  'category_1_189': [' 248397054 th 382492970'],
#  'category_1_190': ['', ' 327142789 th 625062584'],
#  'category_1_191': ['', '', ' 264555454 th 410774948', ''],
#  'category_1_192': [' 313422642 th 568252240'],
#  'category_1_193': ['', ' 229413222 th 350857873'],
#  'category_1_194': ['', '', ' 326672220 th 1222298271'],
#  'category_1_195': ['', '', ' 288936811 th 477388115'],
#  'category_1_196': [' 340818472 th 660976947'],
#  'category_1_197': ['', ' 425806738 th 852790291'],
#  'category_1_198': ['', '', ' 264546477 th 410756942', ''],
#  'category_1_199': [' 274919226 th 437257785', ''],
#  'category_1_200': [' 275659270 th 439074886'],
#  'category_1_201': ['', ' 425890650 th 809544644'],
#  'category_1_202': [' 274658955 th 437261313', ''],
#  'category_1_203': ['', ' 605552050 th 1140340579'],
#  'category_1_204': ['', ' 616426348 th 1170672125', ''],
#  'category_1_205': ['', ' 616432298 th 1170674039', ''],
#  'category_1_206': ['', ' 616388832 th 1170652433', ''],
#  'category_1_207': ['', ' 505022151 th 895278817', ''],
#  'category_1_208': ['', '', ' 587746754 th 1091566194'],
#  'category_1_209': ['', '', '', ' le611elaatacyganth 59998412'],
#  'category_1_210': [],
#  'category_1_211': ['', '', ' 616450213 th 1170652707', ''],
#  'category_1_212': ['', ' 616470088 th 1170736144', ''],
#  'category_1_213': ['', ' 267260291 th 417588813'],
#  'category_1_214': ['', ' 616410628 th 1170652391', ''],
#  'category_1_215': ['', '', ' 616462030 th 1170676586', ''],
#  'category_1_216': ['', ' 616444557 th 1170684894', ''],
#  'category_1_217': [' 1gb', ' 16gb', '', ' 271949397 th 427884556'],
#  'category_1_218': ['', ' 454626123 th 838876875', ''],
#  'category_1_219': ['',
#   '',
#   ' mediatek 64 bit quad core up to 1.3 ghz ',
#   ' 2gb',
#   '',
#   '',
#   '',
#   ' 4g lte with voice',
#   '',
#   '',
#   '',
#   ' 2 x front speaker',
#   ' 3500mah',
#   ' 2.4ghz 802.11 b g n',
#   ' bt 4.0',
#   ' micro usb 3.5mm audio jack',
#   ' yes',
#   '',
#   ' 564446979 th 1034898602'],
#  'category_1_220': ['', ''],
#  'category_1_221': ['', ' 448778270 th 828394561'],
#  'category_1_222': [''],
#  'category_1_223': [' 527686316 th 946952842'],
#  'category_1_224': ['', '', ' 297482165 th 508638091', ''],
#  'category_1_225': [' 2gb', ' 16 gb', '', ' 479414707 th 869558314'],
#  'category_1_226': ['', ' 295768242 th 500194997', ''],
#  'category_1_227': ['', ' le611elaasgg63anth 58279737', ''],
#  'category_1_228': [' 1gb', ' 16gb', '', ' le954elabkir8janth 126890450'],
#  'category_1_229': ['', '', '', ' le634elabk0menanth 125919785'],
#  'category_1_230': ['', ' 295764269 th 500218143', ''],
#  'category_1_231': ['', ' le611elabgdkr5anth 117213539'],
#  'category_1_232': [' 224964566 th 343772150'],
#  'category_1_233': [' le611elaae2m7lanth 28482262', ''],
#  'category_1_234': [' 4gb', ' 64gb', '', ' 333478869 th 644516097'],
#  'category_1_235': [' le611elaa4mwvianth 9960417', ''],
#  'category_1_236': [' le611elaa7ywwkanth 16584510'],
#  'category_1_237': ['', ' 523078318 th 933300133'],
#  'category_1_238': ['', '', ' 254158707 th 392325427', ''],
#  'category_1_239': [' 332512941 th 641144040'],
#  'category_1_240': ['', ' 487584299 th 875784181', ''],
#  'category_1_241': [' le611elaal4zmjanth 42868896', ''],
#  'category_1_242': [''],
#  'category_1_243': ['', ' 404360545 th 784536408'],
#  'category_2_0': ['', '', '', ' 525920571 th 942006655'],
#  'category_2_1': ['', ' 584094721 th 1080148194'],
#  'category_2_2': [''],
#  'category_2_3': ['', ' 568328239 th 1042348147'],
#  'category_2_4': ['', '', '', ' 614868604 th 1165396121'],
#  'category_2_5': ['', '', '', ' 616546367 th 1170944363'],
#  'category_2_6': [' 260153560 th 400661103'],
#  'category_2_7': ['', ' 616564483 th 1170972439'],
#  'category_2_8': ['', ' 612996584 th 1158864985'],
#  'category_2_9': ['', '', ' 616564470 th 1170998303', ''],
#  'category_2_10': ['', '', '', ' 481936296 th 871358193'],
#  'category_2_11': ['', ' 619684279 th 1180350471'],
#  'category_2_12': ['', ' 386156387 th 750522899'],
#  'category_2_13': ['', '', '', ' 616480852 th 1170844903'],
#  'category_2_14': ['', '', '', ' 594386183 th 1115934392', ''],
#  'category_2_15': ['', ' 402746088 th 781944947'],
#  'category_2_16': ['', '', '', '', '', '', ' 607584186 th 1143104232'],
#  'category_2_17': [' ap067elab7776panth 95251955'],
#  'category_2_18': [' 397254694 th 771776257'],
#  'category_2_19': ['', '', '', '', '', ' 422656518 th 806468965'],
#  'category_2_20': ['', '', '', ' 368712981 th 720710024'],
#  'category_2_21': [' 520932716 th 926856654'],
#  'category_2_22': ['', ' 338974194 th 657038296'],
#  'category_2_23': ['', '', '', '', ' 380884467 th 741362171'],
#  'category_2_24': [' 405238684 th 786436226'],
#  'category_2_25': ['', '', '', ' 594334362 th 1115816926', ''],
#  'category_2_26': [' 268514368 th 420396841'],
#  'category_2_27': ['', '', ' 395128011 th 767074341'],
#  'category_2_28': [' 366232815 th 715608517'],
#  'category_2_29': [' 255756194 th 394441196'],
#  'category_2_30': [' 276439622 th 440772956'],
#  'category_2_31': ['', ' 278981474 th 449293698'],
#  'category_2_32': ['', ' 266712078 th 415943012'],
#  'category_2_33': [' 380872136 th 741322198'],
#  'category_2_34': ['', '', '', '', '', ' 539146701 th 976886184'],
#  'category_2_35': [' 366336621 th 715707000'],
#  'category_2_36': [' 300526601 th 517286509'],
#  'category_2_37': ['', ' 264790437 th 411186006'],
#  'category_2_38': [' 278208019 th 445614554'],
#  'category_2_39': ['',
#   ' intel apollo ทะเลสาบ n3350 1.1ghz 2.3 ghz',
#   ' 6 gb',
#   '',
#   '',
#   '',
#   ' 349784668 th 683964676'],
#  'category_3_0': ['', ''],
#  'category_3_1': ['amd ryzen 5 3500u',
#   'amd radeon rx vega 8',
#   '4 gb ddr4 2133 mhz',
#   '1 tb 5400 rpm',
#   'windows 10 home 64 bit ',
#   ' 475204316 th 866392597'],
#  'category_3_2': ['', ' 601484693 th 1132280219'],
#  'category_3_3': ['intel core i5 8265u',
#   'nvidia geforce mx250 2gb gddr5 ',
#   '8 gb ddr4 2400 mhz',
#   '1 tb 5400 rpm',
#   'windows 10 home 64 bit ',
#   ' 380850719 th 741320378'],
#  'category_3_4': ['', ' 594360877 th 1115948657'],
#  'category_3_5': ['intel core i7 8565u',
#   'nvidia geforce mx250 2gb gddr5 ',
#   '8 gb ddr3l on board 2133 mhz',
#   '1tb ssd pcie m.2',
#   'windows 10 home 64 bit ',
#   ' 350262058 th 684782349'],
#  'category_3_6': ['intel core i5 8265u',
#   'nvidia geforce mx250 2gb gddr5 ',
#   '8 gb ddr4 2400 mhz',
#   '1 tb 5400 rpm',
#   'windows 10 home 64 bit ',
#   ' 365562507 th 714366402'],
#  'category_3_7': [''],
#  'category_3_8': ['intel core i7 8565u',
#   'nvidia geforce mx250 2gb gddr5 ',
#   '8 gb ddr4 2400 mhz',
#   '1 tb 5400 rpm 512 gb ssd pcie m.2',
#   'windows 10 home 64 bit ',
#   ' 350554535 th 685448710'],
#  'category_3_9': ['intel core i3 8145u',
#   '4 gb ddr4 2400 mhz',
#   '1 tb 5400 rpm',
#   'windows 10 home 64 bit ',
#   ' 365550195 th 714296583'],
#  'category_3_10': [' as078elabkbq3danth 126493719'],
#  'category_3_11': ['', ''],
#  'category_3_12': [' chiclet keyboard then '],
#  'category_3_13': [' 524398005 th 937542149'],
#  'category_3_14': [''],
#  'category_3_15': [' 439664979 th 815554284'],
#  'category_3_16': ['', ''],
#  'category_3_17': ['',
#   '',
#   '',
#   ' none',
#   ' illuminated chiclet keyboard thai eng ',
#   '',
#   ' 449922523 th 830502120'],
#  'category_3_18': ['intel core i5 8265u',
#   'nvidia geforce mx250 2gb gddr5 ',
#   '8 gb ddr3l on board 2133 mhz',
#   '512 gb ssd pcie m.2',
#   'windows 10 home 64 bit ',
#   ' 349780409 th 684558723'],
#  'category_3_19': [' 397970432 th 773134145'],
#  'category_3_20': ['intel core i7 8565u',
#   'nvidia geforce mx250 2gb gddr5 ',
#   '8 gb ddr3l on board 2133 mhz',
#   '1tb ssd pcie m.2',
#   'windows 10 home 64 bit ',
#   ' 392056520 th 760592720'],
#  'category_3_21': [' 486406473 th 874760109'],
#  'category_3_22': [' 360204737 th 705592548'],
#  'category_3_23': ['amd ryzen 5 3500u',
#   'amd radeon rx vega 8',
#   '4 gb ddr4 2400 mhz',
#   '1 tb 5400 rpm',
#   'windows 10 home 64 bit ',
#   ' 486114152 th 874332376'],
#  'category_3_24': ['', ' 356086236 th 697698389'],
#  'category_3_25': ['', '', '', '', '', ' 591888125 th 1108034766'],
#  'category_3_26': [' 332486615 th 640872906'],
#  'category_3_27': ['', ' 466822199 th 853826068'],
#  'category_3_28': ['', ' 347416233 th 788130238'],
#  'category_3_29': ['', '', ' 364400489 th 711704444'],
#  'category_3_30': ['amd ryzen 7 3700u',
#   'amd radeon rx vega 10',
#   '8 gb ddr4 2133 mhz',
#   '512 gb ssd pcie m.2',
#   'windows 10 home 64 bit',
#   ' 484260930 th 872758788'],
#  'category_3_31': [' 535304957 th 967916129'],
#  'category_3_32': [' 328714340 th 629854557'],
#  'category_3_33': [' 327922508 th 627588009'],
#  'category_3_34': [' 406988615 th 790152726'],
#  'category_3_35': ['', '', '', '', ' 355162034 th 695710447'],
#  'category_3_36': [' 408840712 th 794622072'],
#  'category_3_37': ['', ' 405144122 th 786124810'],
#  'category_3_38': ['', '', ''],
#  'category_3_39': [' mobile intel hm370 express chipsets',
#   '',
#   '',
#   '',
#   ' 527788463 th 947198341'],
#  'category_3_40': ['', '', ''],
#  'category_3_41': ['', '', ' 14 นิ้ว', ' 593788445 th 1114250313'],
#  'category_3_42': [' 300562979 th 517432499'],
#  'category_3_43': [' 406544984 th 789392916'],
#  'category_3_44': ['',
#   'amd ryzen 5 3550h',
#   'amd radeon rx560x 4gb gddr5 ',
#   '8 gb ddr4 2400 mhz',
#   '512 gb ssd pcie m.2',
#   'windows 10 home 64 bit ',
#   ' 455758728 th 841052343'],
#  'category_3_45': ['',
#   'amd ryzen 5 3550h',
#   'amd radeon rx560x 4gb gddr5 ',
#   '8 gb ddr4 2400 mhz',
#   '512 gb ssd pcie m.2',
#   'windows 10 home 64 bit ',
#   ' 584126541 th 1080228235'],
#  'category_3_46': ['', '', ' 616428214 th 1170606589'],
#  'category_3_47': ['', '', ' 313236248 th 566294485'],
#  'category_3_48': ['', '', ''],
#  'category_3_49': ['', ' 408198403 th 792940376'],
#  'category_3_50': [],
#  'category_3_51': ['', ' 406258217 th 788320869'],
#  'category_3_52': ['', '', '', ' 616430655 th 1170670673'],
#  'category_3_53': [' 401008582 th 779202220'],
#  'category_3_54': ['', '', ' 557710179 th 1023850343'],
#  'category_3_55': [' 299722200 th 515100718'],
#  'category_3_56': ['', '', '', ' 329158365 th 631496201', ''],
#  'category_3_57': ['', '', '', ''],
#  'category_3_58': ['', '', ''],
#  'category_3_59': [' 556840749 th 1020322608'],
#  'category_3_60': ['', '', ''],
#  'category_3_61': [' 270887206 th 424354655'],
#  'category_3_62': [' 411068199 th 796096533'],
#  'category_3_63': [],
#  'category_3_64': [' 334098631 th 646612094'],
#  'category_3_65': ['', '', ' 494708616 th 883384853'],
#  'category_3_66': ['', ''],
#  'category_3_67': ['', '', ' 595156724 th 1117966455'],
#  'category_3_68': [' 277568977 th 444780869'],
#  'category_3_69': ['hdmi port with hdcp support ethernet rj 45 port 3.5 มม. headphone speaker jack supporting headsets with built in microphone 1 x usb type c port 1 x usb 3.0 port featuring power off usb charging 2 x usb 2.0 ports',
#   '',
#   'hdmi port with hdcp support ethernet rj 45 port 3.5 มม. headphone speaker jack supporting headsets with built in microphone 1 x usb type c port 1 x usb 3.0 port featuring power off usb charging 2 x usb 2.0 ports'],
#  'category_3_70': [' 594458851 th 1116274326'],
#  'category_3_71': ['', '', ''],
#  'category_3_72': [' 499572998 th 889200529'],
#  'category_3_73': ['', ' 384284798 th 746362604'],
#  'category_3_74': ['', ' 518470484 th 921182497'],
#  'category_3_75': ['', '', '', ''],
#  'category_3_76': ['', '', '', ''],
#  'category_3_77': [' 300398149 th 516882020'],
#  'category_3_78': [' 594404608 th 1116050889'],
#  'category_3_79': [' 336104037 th 650938509'],
#  'category_3_80': ['', '', '', ' 525920571 th 942006655'],
#  'category_3_81': ['', ' 612036428 th 1155398325'],
#  'category_3_82': ['', '', '', ' 481936296 th 871358193'],
#  'category_3_83': ['', '', '', ''],
#  'category_3_84': [' 455210168 th 839732416'],
#  'category_3_85': [' 350318964 th 685078279'],
#  'category_3_86': [' 334136155 th 646688469'],
#  'category_3_87': [' 523580444 th 934836999'],
#  'category_3_88': ['', ' 303968340 th 525274859'],
#  'category_3_89': ['', '', '', ''],
#  'category_3_90': ['intel core i5 8265u',
#   'nvidia geforce mx250 2gb gddr5 ',
#   '8 gb ddr4 2400 mhz',
#   '256 gb ssd pcie m.2',
#   'windows 10 home 64 bit ',
#   ' 522664868 th 932122246'],
#  'category_3_91': ['', '', '', ''],
#  'category_3_92': [''],
#  'category_3_93': ['intel core i5 8265u',
#   'nvidia geforce mx150 2gb gddr5 ',
#   '8 gb ddr4 2400 mhz',
#   '256 gb ssd pcie m.2',
#   'windows 10 home 64 bit ',
#   ' 300994442 th 518944357'],
#  'category_3_94': ['', ' 309830765 th 548680080'],
#  'category_3_95': ['', ' 507688594 th 900628876'],
#  'category_3_96': [' 592736503 th 1110504122'],
#  'category_3_97': ['', '', ' 357910789 th 702006710'],
#  'category_3_98': ['', '', '', ''],
#  'category_3_99': ['', ''],
#  'category_3_100': [' 357484900 th 700948391'],
#  'category_3_101': ['', ' 601596351 th 1132584648'],
#  'category_3_102': [''],
#  'category_3_103': [' 541956849 th 981298746'],
#  'category_3_104': ['', ' 265432869 th 413174739'],
#  'category_3_105': ['intel pentium n3710 1.60 ghz 2 mb l3 cache up to 2.60 ghz ',
#   'intel hd graphics 405',
#   '4 gb ddr3l',
#   '128 gb ssd',
#   'windows 10 home 64 bit ',
#   ' 370068726 th 722776469'],
#  'category_3_106': [' 270185391 th 422588453'],
#  'category_3_107': ['', ' 609258261 th 1147304453'],
#  'category_3_108': [' 599082422 th 1126976516', ''],
#  'category_3_109': [' 263429245 th 407170952'],
#  'category_3_110': [' 337912748 th 654268828'],
#  'category_3_111': ['', ' 363060539 th 708406064'],
#  'category_3_112': ['intel pentium n3710 1.60 ghz 2 mb l3 cache up to 2.60 ghz ',
#   'intel hd graphics 405',
#   '4 gb ddr3l 1600 mhz',
#   '128 gb ssd',
#   'windows 10 home 64 bit ',
#   ' 370102273 th 722814769'],
#  'category_3_113': [' 282944592 th 460716578'],
#  'category_3_114': ['', '', '', '', ''],
#  'category_3_115': ['', '', '', ''],
#  'category_3_116': [' 487646636 th 875730287'],
#  'category_3_117': [' 295324287 th 497156991'],
#  'category_3_118': ['', ''],
#  'category_3_119': ['', '', '', ''],
#  'category_3_120': ['intel core i7 8565u',
#   'intel uhd graphics 620',
#   '8 gb ddr3l on board 2133 mhz',
#   '512 gb ssd pcie m.2',
#   'windows 10 home 64 bit ',
#   ' 340200165 th 659424301'],
#  'category_3_121': ['', ' 571712129 th 1049844297'],
#  'category_3_122': ['', ' 310378960 th 552768179'],
#  'category_3_123': ['', '', ' 435752401 th 813166023'],
#  'category_3_124': [' 392522757 th 761834674'],
#  'category_3_125': ['intel core i3 8145u',
#   '8 gb ddr4 2400 mhz',
#   '128 gb ssd',
#   'dos operating system',
#   ' 367362381 th 717724281'],
#  'category_3_126': [' 339058179 th 657126300'],
#  'category_3_127': ['', '', '', '', ' 555456028 th 1016270346'],
#  'category_3_128': ['', '', '', ' 558126953 th 1025080740'],
#  'category_3_129': [' intel core i7 8750h processor 9m cache up to 4.10 ghz ',
#   ' 4gb 1x4gbddr4 2133 ',
#   ' nvidia geforce gtx 1050 4gb gddr5 ',
#   '',
#   '',
#   ' lan 10 100 1000m wifi 1x1 ac bt4.1',
#   ' 0.3 mega with single mic',
#   ' windows 10 home 64 bit',
#   ' 3 cell 45 wh li on',
#   ' 2 yearscarry in regional by lenovo',
#   ' bag',
#   ' 279953404 th 452622811'],
#  'category_3_130': [''],
#  'category_3_131': [' 268313749 th 420134127'],
#  'category_3_132': ['intel core i3 8145u',
#   'nvidia geforce mx110 2gb gddr5 ',
#   '4 gb ddr4 2133 mhz',
#   '256 gb ssd',
#   'windows 10 home 64 bit ',
#   ' 367522985 th 718248712'],
#  'category_3_133': [' 477938863 th 868616219'],
#  'category_3_134': [' 420928613 th 802946034'],
#  'category_3_135': ['', '', '', ' 306608272 th 533552713'],
#  'category_3_136': ['', '', '', ' 364306685 th 711422516'],
#  'category_3_137': [' nvidia geforce gtx 1050 3g g5',
#   ' 8gb ddr4 2400 sodimm',
#   ' w10 home high end apac em ppp',
#   ' 15.6fhd ips ag 250n n',
#   ' 533390541 th 963318671'],
#  'category_3_138': [' 596134652 th 1119394948'],
#  'category_3_139': ['',
#   ' intel core i5 5300u 2.30ghz',
#   '',
#   ' แรม 4 gb',
#   '',
#   '',
#   ' 592722732 th 1110486538'],
#  'category_3_140': ['', '', ' 363712579 th 710352904'],
#  'category_3_141': ['', ' 344230582 th 670428125'],
#  'category_3_142': ['', '', '', ''],
#  'category_3_143': ['', ' 364440551 th 712050605'],
#  'category_3_144': ['', '', ' 245892789 th 378602722'],
#  'category_3_145': [' 334588993 th 648424765'],
#  'category_3_146': [' 506650200 th 898552578'],
#  'category_3_147': [' 289514783 th 479740973'],
#  'category_3_148': [' 330122247 th 633914986'],
#  'category_3_149': [' 365598347 th 714478751'],
#  'category_3_150': [' 478454629 th 868754753'],
#  'category_3_151': [' 259802264 th 400033097'],
#  'category_3_152': ['', '', '', ''],
#  'category_3_153': ['intel core i5 8265u',
#   'intel uhd graphics 620',
#   '8 gb ddr4 1866 mhz',
#   '512 gb ssd pcie m.2',
#   'windows 10 home 64 bit ',
#   ' 316804354 th 591816341'],
#  'category_3_154': ['', '', '', '', '', ' 279480653 th 451257243'],
#  'category_3_155': [' 268288807 th 420127608'],
#  'category_3_156': ['',
#   ' backlit chiclet keyboard keyboard thai eng numpad',
#   ' 406416815 th 788754846'],
#  'category_3_157': ['amd ryzen 7 3700u',
#   'amd radeon rx vega 10',
#   '8 gb ddr4 2400 mhz',
#   '512 gb ssd pcie m.2',
#   'windows 10 home 64 bit ',
#   '',
#   '',
#   ' 380914998 th 741460204'],
#  'category_3_158': [' 477942777 th 868954181'],
#  'category_3_159': ['', '', '', ' 316114721 th 585968603'],
#  'category_3_160': [' 373692283 th 728204174'],
#  'category_3_161': ['', ' 612060261 th 1155432430', ''],
#  'category_3_162': ['', ' 484776652 th 873010031'],
#  'category_3_163': ['', ' 545846770 th 987382835'],
#  'category_3_164': ['', '', ''],
#  'category_3_165': [' 522414366 th 931350008'],
#  'category_3_166': ['', '', '', ' 317240639 th 595184012', ''],
#  'category_3_167': ['', '', '', ''],
#  'category_3_168': ['', ' 312640922 th 562424030'],
#  'category_3_169': [' 538796110 th 976074148'],
#  'category_3_170': ['', ' 310080233 th 550168975'],
#  'category_3_171': ['intel core i7 9750h',
#   'nvidia geforce gtx 1050 3gb gddr5 ',
#   '8 gb ddr4 2666 mhz',
#   '256 gb ssd pcie m.2',
#   'windows 10 home 64 bit ',
#   ' 370810695 th 723986065'],
#  'category_3_172': [' 472646078 th 862302809'],
#  'category_3_173': [' 415848985 th 799356754'],
#  'category_3_174': ['', ' 601964204 th 1133366278'],
#  'category_3_175': ['', '', '', ' 507064062 th 900504545'],
#  'category_3_176': ['', '', '', '', ''],
#  'category_3_177': [' 334444841 th 647842769'],
#  'category_3_178': [' 334226983 th 647114669'],
#  'category_3_179': ['', '', '', ' 541708949 th 981450846'],
#  'category_3_180': ['', ' 284746714 th 464246861'],
#  'category_3_181': ['intel core i3 7020u 2.3 ghz 3 mb l3 cache ',
#   'amd radeon 520 2gb gddr5 ',
#   '4 gb ddr4 2400 mhz',
#   '1 tb 5400 rpm',
#   'ubuntu',
#   ' 373586549 th 728024230'],
#  'category_3_182': [' 334232879 th 647120903'],
#  'category_3_183': ['', '', ' 599150109 th 1127170665'],
#  'category_3_184': ['', ''],
#  'category_3_185': [' 333876982 th 646008437'],
#  'category_3_186': ['', '', '', '', ''],
#  'category_3_187': ['', ' 319960011 th 609242785'],
#  'category_3_188': ['', ' 566832434 th 1144928330'],
#  'category_3_189': [' 484708909 th 872936864'],
#  'category_3_190': ['', '', '', ''],
#  'category_3_191': ['',
#   '',
#   ' the memory is integrated on the system board from the factory and it cannot be upgraded later.',
#   ' 533484443 th 963614782'],
#  'category_3_192': [' 564042949 th 1034122536'],
#  'category_3_193': ['', ' 571338885 th 1049004809'],
#  'category_3_194': ['', ' 471532400 th 861288862'],
#  'category_3_195': ['',
#   ' intel core i5 4310m 2.70ghz',
#   '',
#   ' แรม ddr3 4 gb',
#   '',
#   ' 592728650 th 1110476822'],
#  'category_3_196': ['amd ryzen 3 2200u 2.50 ghz up to 3.40 ghz 4 mb l3 cache ',
#   'amd radeon rx vega 3',
#   '4 gb ddr4 2400 mhz',
#   '1 tb 5400 rpm',
#   'windows 10 home 64 bit ',
#   ' 373746991 th 728358777'],
#  'category_3_197': [' 279815926 th 452425319'],
#  'category_3_198': ['', '', '', '', ''],
#  'category_3_199': ['intel core i5 7200u 2.5 ghz 3 mb l3 cache up to 3.10 ghz ',
#   'nvidia geforce gt 940mx 2gb gddr5 ',
#   '4 gb ddr4',
#   '1 tb 5400 rpm',
#   'windows 10 home 64 bit ',
#   ' 373590146 th 727994623'],
#  'category_3_200': ['',
#   ' ddr3 4 gb',
#   ' สินค้าหมดสัญญาเช่า',
#   '',
#   ' 536850936 th 971818832'],
#  'category_3_201': [' 365566252 th 714386288'],
#  'category_3_202': ['', ' 317658755 th 598712542'],
#  'category_3_203': ['', ' 619684279 th 1180350471'],
#  'category_3_204': [' 596072994 th 1119382481'],
#  'category_3_205': ['', '', ' 264850282 th 411491182'],
#  'category_3_206': [' 596100078 th 1119344299'],
#  'category_3_207': [' 422636515 th 806532310'],
#  'category_3_208': ['', ' 458276940 th 844340071'],
#  'category_3_209': [' 596366330 th 1119728473'],
#  'category_3_210': [' 456514309 th 842678620'],
#  'category_3_211': ['', '', '', ' 505170632 th 895484287'],
#  'category_3_212': ['', ' 307310840 th 535774426'],
#  'category_3_213': ['', '', ' 338326057 th 655318929'],
#  'category_3_214': ['', '', ' 477448954 th 868162873'],
#  'category_3_215': [' 520914744 th 926852256'],
#  'category_3_216': ['', ' 619100600 th 1178808344'],
#  'category_3_217': ['', '', '', '', '', '', ' 618700944 th 1178002977'],
#  'category_3_218': ['', ' 315136418 th 579798392'],
#  'category_3_219': [' 429384851 th 811210249'],
#  'category_3_220': ['', ' 273482281 th 433418368'],
#  'category_3_221': ['', '', '', '', ''],
#  'category_3_222': ['', '', ' 357372659 th 700430122'],
#  'category_3_223': ['',
#   ' intel i5 6200u up to 2.8 ghz รุ่นยังใหม่ ',
#   ' 524772813 th 939400510',
#   ''],
#  'category_3_224': ['', '', '', '', '', ' 362846517 th 707960298'],
#  'category_3_225': ['', '', ' 306262057 th 532028488'],
#  'category_3_226': ['', ' 426308346 th 809984137'],
#  'category_3_227': [' 520906979 th 926876567'],
#  'category_3_228': ['', '', '', '', ' 362854645 th 707986350'],
#  'category_3_229': [' 383720733 th 745420127'],
#  'category_3_230': ['', ' 341896421 th 663882490'],
#  'category_3_231': [' 499354441 th 888832580'],
#  'category_3_232': ['', '', '', ''],
#  'category_3_233': ['', ' 338348872 th 655450591'],
#  'category_3_234': [' intel core i3 4000m 2.40ghz',
#   '',
#   ' แรม 4 gb',
#   '',
#   '',
#   ' 341764533 th 663488273'],
#  'category_3_235': ['', '', '', '', '', '', ' 284442011 th 463196461'],
#  'category_3_236': ['', '', '', '', ''],
#  'category_3_237': ['', '', ' 526308795 th 943262650'],
#  'category_3_238': [' 369256830 th 721506510'],
#  'category_3_239': ['', ' 351894856 th 688180629'],
#  'category_3_240': [''],
#  'category_3_241': [' ap067elab7776panth 95251955'],
#  'category_3_242': [''],
#  'category_3_243': [''],
#  'category_3_244': [' 268149406 th 419640978'],
#  'category_3_245': [' 339304444 th 657674326'],
#  'category_3_246': ['', ' 338938903 th 656940293'],
#  'category_3_247': ['', ' 338972081 th 656944412'],
#  'category_3_248': [],
#  'category_3_249': ['', '', ''],
#  'category_3_250': ['', ' 206947226 th 311731496'],
#  'category_3_251': [' 271912154 th 427453830'],
#  'category_3_252': [' 206954757 th 311748169'],
#  'category_3_253': [' 206956737 th 311743604'],
#  'category_3_254': [' 479484496 th 869582594'],
#  'category_3_255': [' 339288980 th 657660950'],
#  'category_3_256': [' 278405142 th 446050699'],
#  'category_3_257': [' 367388885 th 717882423'],
#  'category_3_258': [' 263380058 th 406998756'],
#  'category_3_259': [' 256080660 th 394889852'],
#  'category_3_260': ['', ' 206959733 th 311750598'],
#  'category_3_261': [' 263382021 th 407001355'],
#  'category_3_262': ['', '', ''],
#  'category_3_263': ['', ' 338914129 th 656814487'],
#  'category_3_264': [' 367426145 th 717882899'],
#  'category_3_265': [' 367416344 th 717866940'],
#  'category_3_266': ['', ' 339306479 th 657680884'],
#  'category_3_267': [' 256061912 th 394880055'],
#  'category_3_268': ['', ' 338924689 th 656854169'],
#  'category_3_269': ['', ' 338950541 th 656908726'],
#  'category_3_270': ['', '', '', ''],
#  'category_3_271': ['', ' 338956160 th 656882836'],
#  'category_3_272': [' 265101762 th 412063584'],
#  'category_3_273': ['', ' 357692148 th 701478826', ''],
#  'category_3_274': ['', ' 357684428 th 701498251', ''],
#  'category_3_275': ['', '', ''],
#  'category_3_276': ['', ' 357690162 th 701476997', ''],
#  'category_3_277': [' ap067elab4ecrianth 88800081'],
#  'category_3_278': ['', ' 357688208 th 701480659', ''],
#  'category_3_279': ['', '', '', ''],
#  'category_4_0': ['', ''],
#  'category_4_1': [],
#  'category_4_2': [],
#  'category_4_3': ['', '', ''],
#  'category_4_4': [],
#  'category_4_5': ['', '', ''],
#  'category_4_6': [],
#  'category_4_7': [],
#  'category_4_8': [],
#  'category_4_9': [],
#  'category_4_10': [],
#  'category_4_11': [],
#  'category_4_12': [],
#  'category_4_13': [],
#  'category_4_14': ['', '', '', ''],
#  'category_4_15': [],
#  'category_4_16': [],
#  'category_4_17': [],
#  'category_4_18': [],
#  'category_4_19': ['', '', ''],
#  'category_4_20': ['', '', '', ''],
#  'category_4_21': ['', '', ''],
#  'category_4_22': [],
#  'category_4_23': [],
#  'category_4_24': [],
#  'category_4_25': ['', '', '', ''],
#  'category_4_26': ['', '', ''],
#  'category_4_27': [],
#  'category_4_28': ['', '', ''],
#  'category_4_29': [],
#  'category_4_30': [],
#  'category_4_31': [],
#  'category_4_32': [],
#  'category_4_33': ['', '', ''],
#  'category_4_34': [],
#  'category_4_35': [],
#  'category_4_36': [],
#  'category_4_37': [],
#  'category_4_38': [],
#  'category_4_39': [],
#  'category_4_40': [''],
#  'category_4_41': [],
#  'category_4_42': ['', '', ''],
#  'category_4_43': [],
#  'category_4_44': [],
#  'category_4_45': [''],
#  'category_4_46': [],
#  'category_4_47': [],
#  'category_4_48': [''],
#  'category_4_49': ['', '', '', '', ''],
#  'category_4_50': ['', '', '', ''],
#  'category_4_51': [],
#  'category_4_52': [],
#  'category_4_53': [''],
#  'category_4_54': ['', '', '', '', ''],
#  'category_4_55': [''],
#  'category_4_56': [],
#  'category_4_57': [],
#  'category_4_58': [],
#  'category_4_59': [''],
#  'category_4_60': ['', '', ''],
#  'category_4_61': [],
#  'category_4_62': ['', '', '', '', ''],
#  'category_4_63': ['', '', ''],
#  'category_4_64': [],
#  'category_4_65': ['', '', '', ''],
#  'category_4_66': [],
#  'category_4_67': [],
#  'category_4_68': [],
#  'category_4_69': ['', '', ''],
#  'category_4_70': ['', '', '', ''],
#  'category_4_71': [],
#  'category_4_72': [],
#  'category_4_73': [],
#  'category_4_74': [],
#  'category_4_75': [],
#  'category_4_76': [],
#  'category_4_77': [],
#  'category_4_78': [],
#  'category_4_79': [],
#  'category_4_80': [],
#  'category_4_81': ['', '', ''],
#  'category_4_82': [],
#  'category_4_83': ['', '', '', '', '', ''],
#  'category_4_84': [],
#  'category_4_85': [],
#  'category_4_86': [],
#  'category_4_87': [],
#  'category_4_88': [],
#  'category_4_89': ['', '', ''],
#  'category_4_90': ['', '', '', ''],
#  'category_4_91': [],
#  'category_4_92': [],
#  'category_4_93': [],
#  'category_4_94': [''],
#  'category_4_95': [],
#  'category_4_96': [],
#  'category_4_97': [''],
#  'category_4_98': [],
#  'category_4_99': [],
#  'category_4_100': [],
#  'category_4_101': [],
#  'category_4_102': [],
#  'category_4_103': [],
#  'category_4_104': ['', ''],
#  'category_4_105': ['', '', '', ''],
#  'category_4_106': [],
#  'category_4_107': [],
#  'category_4_108': [''],
#  'category_4_109': [''],
#  'category_4_110': [],
#  'category_4_111': [],
#  'category_4_112': [],
#  'category_4_113': ['', '', ''],
#  'category_4_114': [],
#  'category_4_115': [],
#  'category_4_116': [],
#  'category_4_117': ['', '', '', ''],
#  'category_4_118': [],
#  'category_4_119': [],
#  'category_4_120': [],
#  'category_4_121': [],
#  'category_4_122': [],
#  'category_4_123': [],
#  'category_4_124': [],
#  'category_4_125': [],
#  'category_4_126': [],
#  'category_4_127': [''],
#  'category_4_128': [],
#  'category_4_129': [],
#  'category_4_130': [],
#  'category_4_131': [],
#  'category_4_132': ['', '', ''],
#  'category_4_133': [],
#  'category_4_134': [''],
#  'category_4_135': [],
#  'category_4_136': [],
#  'category_4_137': [],
#  'category_4_138': [''],
#  'category_4_139': [],
#  'category_4_140': [''],
#  'category_4_141': [],
#  'category_4_142': [],
#  'category_4_143': [],
#  'category_4_144': [],
#  'category_4_145': [],
#  'category_4_146': [],
#  'category_4_147': [],
#  'category_4_148': [],
#  'category_4_149': [],
#  'category_4_150': [],
#  'category_4_151': [''],
#  'category_4_152': [],
#  'category_4_153': [],
#  'category_4_154': [],
#  'category_4_155': [],
#  ...}

# %%
series = { key: pd.Series(val) for key, val in token.items() }

token2 = {}
for i,v in series.items():
    token2[i] = v.apply(pd.Series).stack()

# %%
pd.DataFrame.from_dict(token2, orient='index').transpose()
# Out:
#                     category_0_0               category_0_1  \
# 0  0   โทรศัพท์มือถือและแท็บเล็ต  โทรศัพท์มือถือและแท็บเล็ต
# 1  0                   สมาร์ทโฟน                  สมาร์ทโฟน
# 2  0                     samsung             โทรศัพท์มือถือ
#    1                      galaxy                    samsung
#    2                           m                     galaxy
# ...                          ...                        ...
# 18 81                        NaN                        NaN
#    82                        NaN                        NaN
#    83                        NaN                        NaN
#    84                        NaN                        NaN
#    85                        NaN                        NaN
#
#                     category_0_2               category_0_3  \
# 0  0   โทรศัพท์มือถือและแท็บเล็ต  โทรศัพท์มือถือและแท็บเล็ต
# 1  0                   สมาร์ทโฟน                  สมาร์ทโฟน
# 2  0                     samsung                    samsung
#    1                      galaxy                     galaxy
#    2                          10                       note
# ...                          ...                        ...
# 18 81                        NaN                        NaN
#    82                        NaN                        NaN
#    83                        NaN                        NaN
#    84                        NaN                        NaN
#    85                        NaN                        NaN
#
#                     category_0_4               category_0_5  \
# 0  0   โทรศัพท์มือถือและแท็บเล็ต  โทรศัพท์มือถือและแท็บเล็ต
# 1  0                   สมาร์ทโฟน                  สมาร์ทโฟน
# 2  0                     samsung                    samsung
#    1                      galaxy                     galaxy
#    2                           7                          9
# ...                          ...                        ...
# 18 81                        NaN                        NaN
#    82                        NaN                        NaN
#    83                        NaN                        NaN
#    84                        NaN                        NaN
#    85                        NaN                        NaN
#
#                     category_0_6               category_0_7  \
# 0  0   โทรศัพท์มือถือและแท็บเล็ต  โทรศัพท์มือถือและแท็บเล็ต
# 1  0                   สมาร์ทโฟน                  สมาร์ทโฟน
# 2  0                     samsung                        มือ
#    1                          30                          1
#    2                           s                   ศูนย์ไทย
# ...                          ...                        ...
# 18 81                        NaN                        NaN
#    82                        NaN                        NaN
#    83                        NaN                        NaN
#    84                        NaN                        NaN
#    85                        NaN                        NaN
#
#                     category_0_8               category_0_9  ...  \
# 0  0   โทรศัพท์มือถือและแท็บเล็ต  โทรศัพท์มือถือและแท็บเล็ต  ...
# 1  0                   สมาร์ทโฟน                  สมาร์ทโฟน  ...
# 2  0                     samsung                  สมาร์ทโฟน  ...
#    1                      galaxy             โทรศัพท์มือถือ  ...
#    2                          70                    samsung  ...
# ...                          ...                        ...  ...
# 18 81                        NaN                        NaN  ...
#    82                        NaN                        NaN  ...
#    83                        NaN                        NaN  ...
#    84                        NaN                        NaN  ...
#    85                        NaN                        NaN  ...
#
#             category_33_234       category_33_235       category_33_236  \
# 0  0           สมาร์ทดีไวซ์          สมาร์ทดีไวซ์          สมาร์ทดีไวซ์
# 1  0               แก็ดเจ็ต              แก็ดเจ็ต              แก็ดเจ็ต
# 2  0   เครื่องเล่นเกมคอมโซล  เครื่องเล่นเกมคอมโซล  เครื่องเล่นเกมคอมโซล
#    1                    new                   new                   new
#    2                    NaN                   NaN                   NaN
# ...                     ...                   ...                   ...
# 18 81                   NaN                   NaN                   NaN
#    82                   NaN                   NaN                   NaN
#    83                   NaN                   NaN                   NaN
#    84                   NaN                   NaN                   NaN
#    85                   NaN                   NaN                   NaN
#
#             category_33_237       category_33_238       category_33_239  \
# 0  0           สมาร์ทดีไวซ์          สมาร์ทดีไวซ์          สมาร์ทดีไวซ์
# 1  0               แก็ดเจ็ต              แก็ดเจ็ต              แก็ดเจ็ต
# 2  0   เครื่องเล่นเกมคอมโซล  เครื่องเล่นเกมคอมโซล  เครื่องเล่นเกมคอมโซล
#    1                    new                   new                   new
#    2                    NaN                   NaN                   NaN
# ...                     ...                   ...                   ...
# 18 81                   NaN                   NaN                   NaN
#    82                   NaN                   NaN                   NaN
#    83                   NaN                   NaN                   NaN
#    84                   NaN                   NaN                   NaN
#    85                   NaN                   NaN                   NaN
#
#             category_33_240       category_33_241       category_33_242  \
# 0  0           สมาร์ทดีไวซ์          สมาร์ทดีไวซ์          สมาร์ทดีไวซ์
# 1  0               แก็ดเจ็ต              แก็ดเจ็ต              แก็ดเจ็ต
# 2  0   เครื่องเล่นเกมคอมโซล  เครื่องเล่นเกมคอมโซล  เครื่องเล่นเกมคอมโซล
#    1                    new                   new                   new
#    2                    NaN                   NaN                   NaN
# ...                     ...                   ...                   ...
# 18 81                   NaN                   NaN                   NaN
#    82                   NaN                   NaN                   NaN
#    83                   NaN                   NaN                   NaN
#    84                   NaN                   NaN                   NaN
#    85                   NaN                   NaN                   NaN
#
#             category_33_243
# 0  0           สมาร์ทดีไวซ์
# 1  0               แก็ดเจ็ต
# 2  0   เครื่องเล่นเกมคอมโซล
#    1                    new
#    2                    NaN
# ...                     ...
# 18 81                   NaN
#    82                   NaN
#    83                   NaN
#    84                   NaN
#    85                   NaN
#
# [6380 rows x 5617 columns]

# %% [markdown]
# ## Category 1

# %%
token2
# Out:
# {'category_0_0': 0   0    โทรศัพท์มือถือและแท็บเล็ต
#  1   0                    สมาร์ทโฟน
#  2   0                      samsung
#      1                       galaxy
#      2                            m
#                     ...
#  10  7                           gb
#  11  0         ระยะเวลาการรับประกัน
#      1                            1
#      2                           ปี
#  12  0                          793
#  Length: 68, dtype: object, 'category_0_1': 0   0    โทรศัพท์มือถือและแท็บเล็ต
#  1   0                    สมาร์ทโฟน
#  2   0               โทรศัพท์มือถือ
#      1                      samsung
#      2                       galaxy
#                     ...
#  30  2                          mah
#      3                         5000
#      4                          mah
#  31  0              ช่องเสียบแบบบาง
#      1                          คู่
#  Length: 187, dtype: object, 'category_0_2': 0   0    โทรศัพท์มือถือและแท็บเล็ต
#  1   0                    สมาร์ทโฟน
#  2   0                      samsung
#      1                       galaxy
#      2                           10
#                     ...
#  19  3                         5000
#      4                          mah
#  20  0              ช่องเสียบแบบบาง
#      1                  เตียงเดี่ยว
#  21  0                          143
#  Length: 109, dtype: object, 'category_0_3': 0   0     โทรศัพท์มือถือและแท็บเล็ต
#  1   0                     สมาร์ทโฟน
#  2   0                       samsung
#      1                        galaxy
#      2                          note
#      3                            10
#      4                            12
#      5                           256
#      6                            gb
#      7                โทรศัพท์มือถือ
#  3   0                    ขนาดหน้าจอ
#      1                           6.8
#      2                          นิ้ว
#  4   0                           ram
#      1                            12
#      2                            gb
#  5   0                        ความจุ
#      1                       storage
#      2                           256
#      3                            gb
#  6   0                     แบตเตอรี่
#      1                          4300
#      2                           mah
#      3                       typical
#  7   0    มาตรฐานการกันน้ำและกันฝุ่น
#      1                            ip
#      2                            68
#  8   0                        แบรนด์
#      1                        ซัมซุง
#  9   0                           sku
#      1                     385536916
#      2                            th
#      3                     749070165
#  10  0         ประเภทของการรับประกัน
#      1                มีการรับประกัน
#  11  0                         model
#      1                        galaxy
#      2                          note
#      3                            10
#  12  0                    ขนาดหน้าจอ
#      1                          นิ้ว
#      2                           6.8
#  13  0          ระยะเวลาการรับประกัน
#      1                             1
#      2                            ปี
#  14  0                           243
#  dtype: object, 'category_0_4': 0   0    โทรศัพท์มือถือและแท็บเล็ต
#  1   0                    สมาร์ทโฟน
#  2   0                      samsung
#      1                       galaxy
#      2                            7
#                     ...
#  33  2                            3
#      3                         ระบบ
#      4                         สั่น
#      5                    vibration
#      6                        phone
#  Length: 205, dtype: object, 'category_0_5': 0   0    โทรศัพท์มือถือและแท็บเล็ต
#  1   0                    สมาร์ทโฟน
#  2   0                      samsung
#      1                       galaxy
#      2                            9
#                     ...
#  12  3                         2018
#  13  0         ระยะเวลาการรับประกัน
#      1                            1
#      2                           ปี
#  14  0                          141
#  Length: 88, dtype: object, 'category_0_6': 0   0    โทรศัพท์มือถือและแท็บเล็ต
#  1   0                    สมาร์ทโฟน
#  2   0                      samsung
#      1                           30
#      2                            s
#                     ...
#  27  0              ความจุแบตเตอรี่
#      1                         1000
#      2                          mah
#      3                         5000
#      4                          mah
#  Length: 206, dtype: object, 'category_0_7': 0   0        โทรศัพท์มือถือและแท็บเล็ต
#  1   0                        สมาร์ทโฟน
#  2   0                              มือ
#      1                                1
#      2                         ศูนย์ไทย
#      3                          samsung
#      4                           galaxy
#      5                             note
#      6                               10
#      7                             plus
#      8                             note
#      9                               10
#      10                              12
#      11                             256
#      12                              gb
#      13                          ประกัน
#      14                               1
#      15                              ปี
#  3   0                          samsung
#      1                           galaxy
#      2                             note
#      3                               10
#      4                             plus
#      5                               th
#      6                   ประกันศูนย์ไทย
#      7                                1
#      8                               ปี
#      9     เข้าศูนย์ซัมซุงได้ทั่วประเทศ
#      10                             มือ
#      11                               1
#      12                      เครื่องแท้
#      13                             100
#      14                      เปอร์เซนต์
#  4   0                           แบรนด์
#      1                           ซัมซุง
#  5   0                              sku
#      1                        599364278
#      2                               th
#      3                       1176694583
#  6   0            ประเภทของการรับประกัน
#      1                   มีการรับประกัน
#  7   0                   ระบบปฏิบัติการ
#      1                         เวอร์ชัน
#      2                          android
#      3                              9.0
#      4                              pie
#  8   0                            model
#      1                          samsung
#      2                           galaxy
#      3                             note
#      4                               10
#      5                             plus
#  9   0                       ขนาดหน้าจอ
#      1                             นิ้ว
#      2                              6.8
#  10  0             ระยะเวลาการรับประกัน
#      1                                1
#      2                               ปี
#  11  0                  ช่องเสียบแบบบาง
#      1                      เตียงเดี่ยว
#  dtype: object, 'category_0_8': 0   0    โทรศัพท์มือถือและแท็บเล็ต
#  1   0                    สมาร์ทโฟน
#  2   0                      samsung
#      1                       galaxy
#      2                           70
#      3                            8
#      4                          128
#      5                           gb
#      6               โทรศัพท์มือถือ
#  3   0                       galaxy
#      1                           70
#      2                           sm
#      3                          705
#      4                      fzbgthl
#  4   0           สเปคเทพของเกมเมอร์
#  5   0                  หน้าจอกว้าง
#      1                          6.7
#      2                     infinity
#      3                            u
#      4                     จอแสดงผล
#  6   0                            3
#      1                        กล้อง
#      2                   พร้อมเลนส์
#      3                        ultra
#      4                         wide
#  7   0                       แบรนด์
#      1                       ซัมซุง
#  8   0                          sku
#      1                    309636084
#      2                           th
#      3                    547152150
#  9   0        ประเภทของการรับประกัน
#      1               มีการรับประกัน
#  10  0                        model
#      1                           70
#      2                            8
#      3                          128
#      4                           gb
#  11  0         ระยะเวลาการรับประกัน
#      1                            1
#      2                           ปี
#  12  0                          249
#  dtype: object, 'category_0_9': 0   0    โทรศัพท์มือถือและแท็บเล็ต
#  1   0                    สมาร์ทโฟน
#  2   0                    สมาร์ทโฟน
#      1               โทรศัพท์มือถือ
#      2                      samsung
#                     ...
#  17  0              ความจุแบตเตอรี่
#      1                         1000
#      2                          mah
#      3                         5000
#      4                          mah
#  Length: 81, dtype: object, 'category_0_10': 0   0    โทรศัพท์มือถือและแท็บเล็ต
#  1   0                    สมาร์ทโฟน
#  2   0                      samsung
#      1                       galaxy
#      2                            5
#                     ...
#  33  0                ออร์กาไนเซอร์
#      1                       ปฏิทิน
#      2                เครื่องคิดเลข
#      3                   นาฬิกาปลุก
#      4                     จดบันทึก
#  Length: 222, dtype: object, 'category_0_11': 0   0    โทรศัพท์มือถือและแท็บเล็ต
#  1   0                    สมาร์ทโฟน
#  2   0                      samsung
#      1                       galaxy
#      2                            5
#                     ...
#  19  2                          5.2
#  20  0                กล้องด้านหลัง
#      1                           16
#      2                           20
#      3                           mp
#  Length: 81, dtype: object, 'category_0_12': 0   0                         โทรศัพท์มือถือและแท็บเล็ต
#  1   0                                         สมาร์ทโฟน
#  2   0                                           samsung
#      1                                            galaxy
#      2                                                 s
#      3                                                10
#      4                                                 e
#      5                                                 6
#      6                                               128
#      7                                                gb
#      8                                    โทรศัพท์มือถือ
#  3   0                                            galaxy
#      1                                                 s
#      2                                                10
#      3                                                 e
#  4   0                         หน้าจอความละเอียดสูงระดับ
#      1                                           dynamic
#      2                                            amoled
#      3    ให้สีสันและความคมชัดเสมือนจอทีวีระดับพรีเมี่ยม
#  5   0                                         กล้องหลัง
#      1                                                 2
#      2                                          ตัวพร้อม
#      3                                              ระบบ
#      4                                   ถ่ายภาพอัจฉริยะ
#  6   0                                            แบรนด์
#      1                                            ซัมซุง
#  7   0                                               sku
#      1                                         526004055
#      2                                                th
#      3                                         942110374
#  8   0                             ประเภทของการรับประกัน
#      1                                    มีการรับประกัน
#  9   0                                             model
#      1                                                 s
#      2                                                10
#      3                                                 e
#      4                                                 6
#      5                                               128
#      6                                                gb
#  10  0                              ระยะเวลาการรับประกัน
#      1                                                 1
#      2                                                ปี
#  dtype: object, 'category_0_13': 0   0    โทรศัพท์มือถือและแท็บเล็ต
#  1   0                    สมาร์ทโฟน
#  2   0                    สมาร์ทโฟน
#      1               โทรศัพท์มือถือ
#      2                      samsung
#                     ...
#  17  0              ความจุแบตเตอรี่
#      1                         1000
#      2                          mah
#      3                         5000
#      4                          mah
#  Length: 81, dtype: object, 'category_0_14': 0   0    โทรศัพท์มือถือและแท็บเล็ต
#  1   0                    สมาร์ทโฟน
#  2   0                      samsung
#      1                           10
#      2                            s
#                     ...
#  25  0              ความจุแบตเตอรี่
#      1                         1000
#      2                          mah
#      3                         5000
#      4                          mah
#  Length: 184, dtype: object, 'category_0_15': 0   0        samsung
#      1         galaxy
#      2             30
#      3              4
#      4             gb
#               ...
#  11  8        1080.00
#      9              ฿
#      10       1290.00
#      11            16
#      12    เปอร์เซนต์
#  Length: 208, dtype: object, 'category_0_16': 0   0    โทรศัพท์มือถือและแท็บเล็ต
#  1   0                    สมาร์ทโฟน
#  2   0                      samsung
#      1                       galaxy
#      2                            s
#                     ...
#  12  3                          128
#      4                           gb
#  13  0         ระยะเวลาการรับประกัน
#      1                            1
#      2                           ปี
#  Length: 87, dtype: object, 'category_0_17': 0   0    โทรศัพท์มือถือและแท็บเล็ต
#  1   0                    สมาร์ทโฟน
#  2   0                      samsung
#      1                           20
#      2                            s
#                     ...
#  22  0              ความจุแบตเตอรี่
#      1                         1000
#      2                          mah
#      3                         5000
#      4                          mah
#  Length: 233, dtype: object, 'category_0_18': 0   0    โทรศัพท์มือถือและแท็บเล็ต
#  1   0                    สมาร์ทโฟน
#  2   0                      samsung
#      1                       galaxy
#      2                           80
#                     ...
#  21  1                         3000
#      2                         3999
#      3                          mah
#  22  0              ช่องเสียบแบบบาง
#      1                          คู่
#  Length: 109, dtype: object, 'category_0_19': 0   0    โทรศัพท์มือถือและแท็บเล็ต
#  1   0                    สมาร์ทโฟน
#  2   0                      samsung
#      1                       galaxy
#      2                         note
#                     ...
#  30  0         ระยะเวลาการรับประกัน
#      1                            1
#      2                           ปี
#  31  0               ระบบปฏิบัติการ
#      1                      android
#  Length: 214, dtype: object, 'category_0_20': 0   0    โทรศัพท์มือถือและแท็บเล็ต
#  1   0                    สมาร์ทโฟน
#  2   0                      samsung
#      1                       galaxy
#      2                           10
#                     ...
#  33  3                           10
#      4                            s
#      5                           sm
#      6                          107
#      7                            f
#  Length: 177, dtype: object, 'category_0_21': 0  0        โทรศัพท์มือถือและแท็บเล็ต
#  1  0                        สมาร์ทโฟน
#  2  0                          samsung
#     1                           galaxy
#     2                                j
#     3                                4
#     4                             plus
#     5                      ประกันศูนย์
#     6                             pink
#  3  0                           แบรนด์
#     1                           ซัมซุง
#  4  0                              sku
#     1                        307684896
#     2                               th
#     3                        537048806
#  5  0            ประเภทของการรับประกัน
#     1    การรับประกันจากโรงงานในประเทศ
#  6  0                            model
#     1                          samsung
#     2                           galaxy
#     3                                j
#     4                                4
#     5                             plus
#  7  0             ระยะเวลาการรับประกัน
#     1                                1
#     2                               ปี
#  dtype: object, 'category_0_22': 0   0     โทรศัพท์มือถือและแท็บเล็ต
#  1   0                     สมาร์ทโฟน
#  2   0                       samsung
#      1                        galaxy
#      2                          note
#      3                            10
#      4                             8
#      5                           256
#      6                            gb
#      7                โทรศัพท์มือถือ
#  3   0                    ขนาดหน้าจอ
#      1                           6.3
#      2                          นิ้ว
#  4   0                           ram
#      1                             8
#      2                            gb
#  5   0                        ความจุ
#      1                       storage
#      2                           256
#      3                            gb
#  6   0                     แบตเตอรี่
#      1                          3500
#      2                           mah
#      3                       typical
#  7   0    มาตรฐานการกันน้ำและกันฝุ่น
#      1                            ip
#      2                            68
#  8   0                        แบรนด์
#      1                        ซัมซุง
#  9   0                           sku
#      1                     373972071
#      2                            th
#      3                     728742055
#  10  0         ประเภทของการรับประกัน
#      1                มีการรับประกัน
#  11  0                         model
#      1                             8
#      2                           256
#      3                            gb
#  12  0          ระยะเวลาการรับประกัน
#      1                             1
#      2                            ปี
#  dtype: object, 'category_0_23': 0   0    โทรศัพท์มือถือและแท็บเล็ต
#  1   0                    สมาร์ทโฟน
#  2   0                      samsung
#      1                       galaxy
#      2                         note
#                     ...
#  21  2                            n
#      3                          950
#  22  0         ระยะเวลาการรับประกัน
#      1                            1
#      2                           ปี
#  Length: 99, dtype: object, 'category_0_24': 0   0    โทรศัพท์มือถือและแท็บเล็ต
#  1   0                    สมาร์ทโฟน
#  2   0                      samsung
#      1                       galaxy
#      2                            9
#                     ...
#  20  2                          mah
#      3                         5000
#      4                          mah
#  21  0              ช่องเสียบแบบบาง
#      1                          คู่
#  Length: 114, dtype: object, 'category_0_25': 0  0    โทรศัพท์มือถือและแท็บเล็ต
#  1  0                    สมาร์ทโฟน
#  2  0                      samsung
#     1                           70
#     2                          แรม
#                    ...
#  6  0        ประเภทของการรับประกัน
#     1               ไม่มีการประกัน
#  7  0                        model
#     1                      samsung
#     2                           70
#  Length: 169, dtype: object, 'category_0_26': 0   0    โทรศัพท์มือถือและแท็บเล็ต
#  1   0                    สมาร์ทโฟน
#  2   0                      samsung
#      1                       galaxy
#      2                            6
#                     ...
#  14  2                            6
#  15  0         ระยะเวลาการรับประกัน
#      1                            1
#      2                           ปี
#  16  0                        262.0
#  Length: 75, dtype: object, 'category_0_27': 0   0    โทรศัพท์มือถือและแท็บเล็ต
#  1   0                    สมาร์ทโฟน
#  2   0                      samsung
#      1                       galaxy
#      2                           50
#                     ...
#  9   0         ระยะเวลาการรับประกัน
#      1                            1
#      2                           ปี
#  10  0              ช่องเสียบแบบบาง
#      1                          คู่
#  Length: 79, dtype: object, 'category_0_28': 0   0                          โทรศัพท์มือถือและแท็บเล็ต
#  1   0                                          สมาร์ทโฟน
#  2   0                                            samsung
#      1                                             galaxy
#      2                                                 20
#      3                                                  s
#      4                                                  3
#      5                                                 32
#      6                                                 gb
#      7                                     โทรศัพท์มือถือ
#  3   0                                             galaxy
#      1                                                 20
#      2                                                  s
#  4   0    สนุกทุกประสบการณ์กับหน้าจอใหญ่ที่เต็มตากว่าเดิม
#  5   0                                   ด้านหลังเรียบเงา
#      1                                   ใช้งานได้ถนัดมือ
#  6   0                     เด่นทุกมุมมองด้วยกล้องสามเลนส์
#  7   0                                             แบรนด์
#      1                                             ซัมซุง
#  8   0                                                sku
#      1                                          511068392
#      2                                                 th
#      3                                          907938105
#  9   0                              ประเภทของการรับประกัน
#      1                                     มีการรับประกัน
#  10  0                                              model
#      1                                             galaxy
#      2                                                 20
#      3                                                  s
#      4                                                  3
#      5                                                 32
#      6                                                 gb
#  11  0                               ระยะเวลาการรับประกัน
#      1                                                  1
#      2                                                 ปี
#  dtype: object, 'category_0_29': 0   0    โทรศัพท์มือถือและแท็บเล็ต
#  1   0                    สมาร์ทโฟน
#  2   0                    refurbish
#      1                      samsung
#      2                       galaxy
#                     ...
#  30  5                         2018
#      6                         gold
#  31  0         ระยะเวลาการรับประกัน
#      1                            3
#      2                        เดือน
#  Length: 154, dtype: object, 'category_0_30': 0   0    โทรศัพท์มือถือและแท็บเล็ต
#  1   0                    สมาร์ทโฟน
#  2   0                      samsung
#      1                       galaxy
#      2                            s
#                     ...
#  12  4                           gb
#  13  0         ระยะเวลาการรับประกัน
#      1                            1
#      2                           ปี
#  14  0                          139
#  Length: 96, dtype: object, 'category_0_31': 0   0    โทรศัพท์มือถือและแท็บเล็ต
#  1   0                    สมาร์ทโฟน
#  2   0                      samsung
#      1                            j
#      2                            8
#                     ...
#  18  0         ระยะเวลาการรับประกัน
#      1                            3
#      2                        เดือน
#  19  0               ระบบปฏิบัติการ
#      1                      android
#  Length: 78, dtype: object, 'category_0_32': 0   0         xiaomi
#      1          redmi
#      2           note
#      3              8
#      4              3
#               ...
#  11  10       8590.00
#      11             ฿
#      12      12900.00
#      13            33
#      14    เปอร์เซนต์
#  Length: 187, dtype: object, 'category_0_33': 0   0    โทรศัพท์มือถือและแท็บเล็ต
#  1   0                    สมาร์ทโฟน
#  2   0                      samsung
#      1                       galaxy
#      2                         note
#                     ...
#  25  0         ระยะเวลาการรับประกัน
#      1                            1
#      2                           ปี
#  26  0              ช่องเสียบแบบบาง
#      1                          คู่
#  Length: 131, dtype: object, 'category_0_34': 0   0    โทรศัพท์มือถือและแท็บเล็ต
#  1   0                    สมาร์ทโฟน
#  2   0                      samsung
#      1                       galaxy
#      2                         note
#                     ...
#  29  0         ระยะเวลาการรับประกัน
#      1                            1
#      2                           ปี
#  30  0               ระบบปฏิบัติการ
#      1                      android
#  Length: 208, dtype: object, 'category_0_35': 0   0    โทรศัพท์มือถือและแท็บเล็ต
#  1   0                    สมาร์ทโฟน
#  2   0                       แบรนด์
#      1                          new
#      2                      samsung
#                     ...
#  25  0         ระยะเวลาการรับประกัน
#      1                            1
#      2                           ปี
#  26  0              ช่องเสียบแบบบาง
#      1                          คู่
#  Length: 133, dtype: object, 'category_0_36': 0   0    โทรศัพท์มือถือและแท็บเล็ต
#  1   0                    สมาร์ทโฟน
#  2   0                      samsung
#      1                       galaxy
#      2                         note
#                     ...
#  9   0         ระยะเวลาการรับประกัน
#      1                            1
#      2                           ปี
#  10  0              ช่องเสียบแบบบาง
#      1                          คู่
#  Length: 70, dtype: object, 'category_0_37': 0   0                      samsung
#      1                       galaxy
#      2                           30
#      3                            4
#      4                           gb
#                     ...
#  11  2    เครื่องใหม่แท้ศูนย์ประกัน
#      3                            3
#      4                        เดือน
#      5                            ฿
#      6                     11900.00
#  Length: 177, dtype: object, 'category_0_38': 0   0    โทรศัพท์มือถือและแท็บเล็ต
#  1   0                    สมาร์ทโฟน
#  2   0                      samsung
#      1                       galaxy
#      2                           30
#                     ...
#  12  5                           gb
#  13  0         ระยะเวลาการรับประกัน
#      1                            1
#      2                           ปี
#  14  0                          340
#  Length: 100, dtype: object, 'category_0_39': 0   0         โทรศัพท์มือถือและแท็บเล็ต
#  1   0                         สมาร์ทโฟน
#  2   0                           samsung
#      1                            galaxy
#      2                                10
#      3                                 s
#      4                                 2
#      5                                32
#      6                                gb
#      7                    โทรศัพท์มือถือ
#  3   0                            galaxy
#      1                                10
#      2                                 s
#      3                                sm
#      4                               107
#      5                           fzgdthl
#  4   0    พลังงานที่ยาวนานขึ้นในแต่ละวัน
#  5   0             การออกแบบที่สะดวกสบาย
#      1                            สวยงาม
#  6   0    กล้องคู่สำหรับทุกช่วงเวลาสำคัญ
#  7   0                            แบรนด์
#      1                            ซัมซุง
#  8   0                               sku
#      1                         408012228
#      2                                th
#      3                         792604544
#  9   0             ประเภทของการรับประกัน
#      1                    มีการรับประกัน
#  10  0                             model
#      1                            galaxy
#      2                                10
#      3                                 s
#      4                                 2
#      5                                32
#      6                                gb
#  11  0              ระยะเวลาการรับประกัน
#      1                                 1
#      2                                ปี
#  dtype: object, 'category_0_40': 0   0    โทรศัพท์มือถือและแท็บเล็ต
#  1   0                    สมาร์ทโฟน
#  2   0                       xiaomi
#      1                        redmi
#      2                            7
#                     ...
#  33  0              ความจุแบตเตอรี่
#      1                         1000
#      2                          mah
#      3                         5000
#      4                          mah
#  Length: 167, dtype: object, 'category_0_41': 0   0    โทรศัพท์มือถือและแท็บเล็ต
#  1   0                    สมาร์ทโฟน
#  2   0                       xiaomi
#      1                        redmi
#      2                         note
#                     ...
#  24  2                         4999
#      3                          mah
#  25  0              ช่องเสียบแบบบาง
#      1                          คู่
#  26  0                          327
#  Length: 100, dtype: object, 'category_0_42': 0  0     โทรศัพท์มือถือและแท็บเล็ต
#  1  0                     สมาร์ทโฟน
#  2  0                สินค้าพร้อมส่ง
#     1                           ฟรี
#     2                            mi
#     3                           air
#     4                      purifier
#     5                             2
#     6                        xiaomi
#     7                            mi
#     8                          note
#     9                            10
#     10                            6
#     11                          128
#     12                           gb
#     13                    สมาร์ทโฟน
#     14                        กล้อง
#     15                            5
#     16                          ตัว
#     17                  ความละเอียด
#     18                          108
#     19                           mp
#     20            รับประกันศูนย์ไทย
#     21                           15
#     22                        เดือน
#  3  0                        แบรนด์
#     1                        xiaomi
#  4  0                           sku
#     1                     595884854
#     2                            th
#     3                    1119120013
#  5  0         ประเภทของการรับประกัน
#     1                มีการรับประกัน
#  6  0                ระบบปฏิบัติการ
#     1                      เวอร์ชัน
#     2                       android
#     3                           9.0
#     4                           pie
#  7  0                         model
#     1                            mi
#     2                          note
#     3                            10
#  8  0          ระยะเวลาการรับประกัน
#     1                            15
#     2                         เดือน
#  9  0               ช่องเสียบแบบบาง
#     1                   เตียงเดี่ยว
#  dtype: object, 'category_0_43': 0   0    โทรศัพท์มือถือและแท็บเล็ต
#  1   0                    สมาร์ทโฟน
#  2   0                       xiaomi
#      1                        redmi
#      2                            8
#                     ...
#  31  2                          mah
#      3                         5000
#      4                          mah
#  32  0              ช่องเสียบแบบบาง
#      1                          คู่
#  Length: 234, dtype: object, 'category_0_44': 0   0    โทรศัพท์มือถือและแท็บเล็ต
#  1   0                    สมาร์ทโฟน
#  2   0                       xiaomi
#      1                           mi
#      2                            9
#                     ...
#  33  1                      มาตรฐาน
#      2                         4000
#      3                          mah
#      4                     standard
#      5                      battery
#  Length: 339, dtype: object, 'category_0_45': 0   0         xiaomi
#      1          redmi
#      2           note
#      3              8
#      4              3
#               ...
#  11  18       5090.00
#      19             ฿
#      20       5990.00
#      21            15
#      22    เปอร์เซนต์
#  Length: 182, dtype: object, 'category_0_46': 0   0    โทรศัพท์มือถือและแท็บเล็ต
#  1   0                    สมาร์ทโฟน
#  2   0               โทรศัพท์มือถือ
#      1                       xiaomi
#      2                           mi
#                     ...
#  20  3                         5000
#      4                          mah
#  21  0              ช่องเสียบแบบบาง
#      1                          คู่
#  22  0                          142
#  Length: 120, dtype: object, 'category_0_47': 0   0    โทรศัพท์มือถือและแท็บเล็ต
#  1   0                    สมาร์ทโฟน
#  2   0                       xiaomi
#      1                        redmi
#      2                         note
#                     ...
#  13  3                         5000
#      4                          mah
#  14  0              ช่องเสียบแบบบาง
#      1                          คู่
#  15  0                          719
#  Length: 67, dtype: object, 'category_0_48': 0   0    โทรศัพท์มือถือและแท็บเล็ต
#  1   0                    สมาร์ทโฟน
#  2   0                       xiaomi
#      1                        redmi
#      2                         note
#                     ...
#  32  2                            8
#      3                           gb
#  33  0                          รอม
#      1                          128
#      2                           gb
#  Length: 138, dtype: object, 'category_0_49': 0   0     โทรศัพท์มือถือและแท็บเล็ต
#  1   0                     สมาร์ทโฟน
#  2   0                        xiaomi
#      1                            mi
#      2                         redmi
#      3                             7
#      4                             2
#      5                            16
#      6                            gb
#      7                ประกันศูนย์ไทย
#      8                             1
#      9                            ปี
#      10                   snapdragon
#      11                          439
#      12                    แบตเตอรี่
#      13                         4000
#      14                          mah
#      15                           ai
#      16                       beauty
#  3   0                        แบรนด์
#      1                        xiaomi
#  4   0                           sku
#      1                     234902116
#      2                            th
#      3                     713640836
#  5   0         ประเภทของการรับประกัน
#      1                มีการรับประกัน
#  6   0                     กล้องหน้า
#      1                    เมกะพิกเซล
#      2                             5
#      3                    เมกะพิกเซล
#  7   0                         model
#      1                        xiaomi
#      2                            mi
#      3                         redmi
#      4                             7
#  8   0                 กล้องด้านหลัง
#      1                            11
#      2                            15
#      3                            mp
#  9   0          ระยะเวลาการรับประกัน
#      1                             1
#      2                            ปี
#  10  0               ความจุแบตเตอรี่
#      1                          4000
#      2                          4999
#      3                           mah
#  11  0                           212
#  dtype: object, 'category_0_50': 0  0     โทรศัพท์มือถือและแท็บเล็ต
#  1  0                     สมาร์ทโฟน
#  2  0                        xiaomi
#     1                         redmi
#     2                          note
#     3                             8
#     4                           ram
#     5                             4
#     6                            gb
#     7                        รับฟรี
#     8                            mi
#     9                       compact
#     10                    bluetooth
#     11                      speaker
#     12                            2
#     13                       มูลค่า
#     14                          299
#     15                          บาท
#  3  0                        แบรนด์
#     1                        xiaomi
#  4  0                           sku
#     1                     494026300
#     2                            th
#     3                     882746256
#  5  0         ประเภทของการรับประกัน
#     1                มีการรับประกัน
#  6  0                         model
#     1                         redmi
#     2                          note
#     3                             8
#  7  0          ระยะเวลาการรับประกัน
#     1                            15
#     2                         เดือน
#  dtype: object, 'category_0_51': 0   0    โทรศัพท์มือถือและแท็บเล็ต
#  1   0                    สมาร์ทโฟน
#  2   0                         ผ่อน
#      1                            0
#      2                   เปอร์เซนต์
#                     ...
#  32  0         ระยะเวลาการรับประกัน
#      1                           15
#      2                        เดือน
#  33  0        ประเภทของการรับประกัน
#      1               มีการรับประกัน
#  Length: 193, dtype: object, 'category_0_52': 0   0    โทรศัพท์มือถือและแท็บเล็ต
#  1   0                    สมาร์ทโฟน
#  2   0                       xiaomi
#      1                           mi
#      2                           cc
#                     ...
#  33  0               ระบบปฏิบัติการ
#      1                     เวอร์ชัน
#      2                      android
#      3                          9.0
#      4                          pie
#  Length: 198, dtype: object, 'category_0_53': 0   0    โทรศัพท์มือถือและแท็บเล็ต
#  1   0                    สมาร์ทโฟน
#  2   0                       xiaomi
#      1                           mi
#      2                            9
#                     ...
#  14  0         ระยะเวลาการรับประกัน
#      1                            1
#      2                           ปี
#  15  0              ช่องเสียบแบบบาง
#      1                          คู่
#  Length: 87, dtype: object, 'category_0_54': 0   0           ซื้อ
#      1              1
#      2            แถม
#      3              1
#      4            ฟรี
#               ...
#  11  13        745.00
#      14             ฿
#      15       1566.00
#      16            52
#      17    เปอร์เซนต์
#  Length: 212, dtype: object, 'category_0_55': 0   0    โทรศัพท์มือถือและแท็บเล็ต
#  1   0                    สมาร์ทโฟน
#  2   0                        redmi
#      1                            8
#      2                            3
#                     ...
#  20  2                          mah
#      3                         5000
#      4                          mah
#  21  0              ช่องเสียบแบบบาง
#      1                          คู่
#  Length: 86, dtype: object, 'category_0_56': 0   0    โทรศัพท์มือถือและแท็บเล็ต
#  1   0                    สมาร์ทโฟน
#  2   0                       xiaomi
#      1                        redmi
#      2                            8
#                     ...
#  27  0              ความจุแบตเตอรี่
#      1                         1000
#      2                          mah
#      3                         5000
#      4                          mah
#  Length: 168, dtype: object, 'category_0_57': 0   0    โทรศัพท์มือถือและแท็บเล็ต
#  1   0                    สมาร์ทโฟน
#  2   0                       xiaomi
#      1                        redmi
#      2                         note
#                     ...
#  32  2                           hd
#  33  0              ความจุแบตเตอรี่
#      1                         4000
#      2                         4999
#      3                          mah
#  Length: 125, dtype: object, 'category_0_58': 0   0          apple
#      1         iphone
#      2             11
#      3              ฿
#      4       23900.00
#               ...
#  11  19       4450.00
#      20             ฿
#      21       4599.00
#      22             3
#      23    เปอร์เซนต์
#  Length: 206, dtype: object, 'category_0_59': 0   0    โทรศัพท์มือถือและแท็บเล็ต
#  1   0                    สมาร์ทโฟน
#  2   0                       xiaomi
#      1                         note
#      2                           10
#                     ...
#  33  0                    ประเภทของ
#      1                    แบตเตอรี่
#      2                        built
#      3                 rechargeable
#      4                      battery
#  Length: 165, dtype: object, 'category_0_60': 0   0    โทรศัพท์มือถือและแท็บเล็ต
#  1   0                    สมาร์ทโฟน
#  2   0                        redmi
#      1                            8
#      2                    เสียวหมี่
#                     ...
#  32  1                    แบตเตอรี่
#      2                        built
#      3                 rechargeable
#      4                      battery
#  33  0                   สภาพสินค้า
#  Length: 218, dtype: object, 'category_0_61': 0   0    โทรศัพท์มือถือและแท็บเล็ต
#  1   0                    สมาร์ทโฟน
#  2   0                       xiaomi
#      1                        redmi
#      2                         note
#                     ...
#  21  1                         3000
#      2                         3999
#      3                          mah
#  22  0              ช่องเสียบแบบบาง
#      1                          คู่
#  Length: 90, dtype: object, 'category_0_62': 0   0        โทรศัพท์มือถือและแท็บเล็ต
#  1   0                        สมาร์ทโฟน
#  2   0                           xiaomi
#      1                            redmi
#      2                                8
#                       ...
#  32  1    มีการรับประกันจากผู้ให้บริการ
#  33  0                        กล้องหน้า
#      1                       เมกะพิกเซล
#      2                       เมกะพิกเซล
#      3                           ขึ้นไป
#  Length: 203, dtype: object, 'category_0_63': 0   0    โทรศัพท์มือถือและแท็บเล็ต
#  1   0                    สมาร์ทโฟน
#  2   0                       xiaomi
#      1                           mi
#      2                         note
#                     ...
#  32  3                          ppi
#  33  0              ความจุแบตเตอรี่
#      1                         5000
#      2                          mah
#      3                  หรือมากกว่า
#  Length: 161, dtype: object, 'category_0_64': 0   0           ซื้อ
#      1              1
#      2            แถม
#      3              1
#      4            ฟรี
#               ...
#  11  16         83.98
#      17             ฿
#      18        120.00
#      19            30
#      20    เปอร์เซนต์
#  Length: 250, dtype: object, 'category_0_65': 0   0    โทรศัพท์มือถือและแท็บเล็ต
#  1   0                    สมาร์ทโฟน
#  2   0                        redmi
#      1                         note
#      2                            8
#                     ...
#  26  1                         4000
#      2                         4999
#      3                          mah
#  27  0              ช่องเสียบแบบบาง
#      1                          คู่
#  Length: 116, dtype: object, 'category_0_66': 0   0    โทรศัพท์มือถือและแท็บเล็ต
#  1   0                    สมาร์ทโฟน
#  2   0                       xiaomi
#      1                           mi
#      2                         note
#                     ...
#  21  1                         4000
#      2                         4999
#      3                          mah
#  22  0              ช่องเสียบแบบบาง
#      1                          คู่
#  Length: 112, dtype: object, 'category_0_67': 0   0          apple
#      1         iphone
#      2             11
#      3              ฿
#      4       23900.00
#               ...
#  11  12        121.17
#      13             ฿
#      14        196.90
#      15            38
#      16    เปอร์เซนต์
#  Length: 216, dtype: object, 'category_0_68': 0   0    โทรศัพท์มือถือและแท็บเล็ต
#  1   0                    สมาร์ทโฟน
#  2   0                       xiaomi
#      1                           mi
#      2                         note
#                     ...
#  21  1                         4000
#      2                         4999
#      3                          mah
#  22  0              ช่องเสียบแบบบาง
#      1                          คู่
#  Length: 103, dtype: object, 'category_0_69': 0   0    โทรศัพท์มือถือและแท็บเล็ต
#  1   0                    สมาร์ทโฟน
#  2   0                       xiaomi
#      1                           mi
#      2                            9
#                     ...
#  31  2                        เดือน
#  32  0              ความจุแบตเตอรี่
#      1                         3000
#      2                         3999
#      3                          mah
#  Length: 175, dtype: object, 'category_0_70': 0   0    โทรศัพท์มือถือและแท็บเล็ต
#  1   0                    สมาร์ทโฟน
#  2   0                       xiaomi
#      1                        redmi
#      2                            7
#                     ...
#  31  2                           gb
#  32  0                          รอม
#      1                           16
#      2                           gb
#  33  0             การ์ดหน่วยความจำ
#  Length: 119, dtype: object, 'category_0_71': 0   0    โทรศัพท์มือถือและแท็บเล็ต
#  1   0                    สมาร์ทโฟน
#  2   0                       xiaomi
#      1                        redmi
#      2                            8
#                     ...
#  32  2                            3
#      3                           gb
#  33  0                          รอม
#      1                           32
#      2                           gb
#  Length: 131, dtype: object, 'category_0_72': 0   0    โทรศัพท์มือถือและแท็บเล็ต
#  1   0                    สมาร์ทโฟน
#  2   0                       xiaomi
#      1                        redmi
#      2                         note
#                     ...
#  32  9                          รอม
#  33  0                กล้องด้านหลัง
#      1                           21
#      2                           mp
#      3                       ขึ้นไป
#  Length: 216, dtype: object, 'category_0_73': 0   0    โทรศัพท์มือถือและแท็บเล็ต
#  1   0                    สมาร์ทโฟน
#  2   0                       xiaomi
#      1                           mi
#      2                            9
#                     ...
#  31  2                        เดือน
#  32  0              ความจุแบตเตอรี่
#      1                         3000
#      2                         3999
#      3                          mah
#  Length: 175, dtype: object, 'category_0_74': 0   0    โทรศัพท์มือถือและแท็บเล็ต
#  1   0                    สมาร์ทโฟน
#  2   0               โทรศัพท์มือถือ
#      1                       xiaomi
#      2                           mi
#                     ...
#  19  2                          mah
#      3                         5000
#      4                          mah
#  20  0              ช่องเสียบแบบบาง
#      1                          คู่
#  Length: 115, dtype: object, 'category_0_75': 0   0    โทรศัพท์มือถือและแท็บเล็ต
#  1   0                    สมาร์ทโฟน
#  2   0                       xiaomi
#      1                           mi
#      2                            9
#                     ...
#  31  3                            9
#      4                            t
#  32  0         ระยะเวลาการรับประกัน
#      1                            1
#      2                           ปี
#  Length: 276, dtype: object, 'category_0_76': 0   0       ซื้อ
#      1          1
#      2        แถม
#      3          1
#      4        ฟรี
#            ...
#  11  1          j
#      2          2
#      3      prime
#      4          ฿
#      5    1690.00
#  Length: 224, dtype: object, 'category_0_77': 0   0    โทรศัพท์มือถือและแท็บเล็ต
#  1   0                    สมาร์ทโฟน
#  2   0                       global
#      1                      version
#      2                       xiaomi
#                     ...
#  33  1                      มาตรฐาน
#      2                         4000
#      3                          mah
#      4                     standard
#      5                      battery
#  Length: 210, dtype: object, 'category_0_78': 0   0    โทรศัพท์มือถือและแท็บเล็ต
#  1   0                    สมาร์ทโฟน
#  2   0                       xiaomi
#      1                        redmi
#      2                         note
#                     ...
#  9   0         ระยะเวลาการรับประกัน
#      1                            1
#      2                           ปี
#  10  0              ช่องเสียบแบบบาง
#      1                          คู่
#  Length: 79, dtype: object, 'category_0_79': 0   0    โทรศัพท์มือถือและแท็บเล็ต
#  1   0                    สมาร์ทโฟน
# ...
#     15                         gb
#     16                        ssd
#     17                        gtx
#     18                       1650
#     19                          4
#     20                         gb
#     21                       15.6
#     22                        win
#     23                         10
#     24                      black
#  dtype: object, 'category_4_142': 0  0                 คอมพิวเตอร์
#     1                    แล็ปท็อป
#  1  0                    แล็ปท็อป
#  2  0     แล็ปท็อปสำหรับเล่นเกมส์
#  3  0                      lenovo
#     1                     ideapad
#     2                           l
#     3                         340
#     4                          15
#     5                         irh
#     6                          81
#     7                          lk
#     8                          00
#     9                        mlta
#     10                          5
#     11                       9300
#     12                          h
#     13                          8
#     14                         gb
#     15                        512
#     16                         gb
#     17                        ssd
#     18                        gtx
#     19                       1050
#     20                       15.6
#     21                        win
#     22                         10
#     23                      black
#  dtype: object, 'category_4_143': 0  0                 คอมพิวเตอร์
#     1                    แล็ปท็อป
#  1  0                    แล็ปท็อป
#  2  0     แล็ปท็อปสำหรับเล่นเกมส์
#  3  0                      lenovo
#     1                      legion
#     2                           y
#     3                         740
#     4                          17
#     5                        irhg
#     6                          81
#     7                          uj
#     8                         005
#     9                         dta
#     10                     gaming
#     11                   notebook
#  dtype: object, 'category_4_144': 0  0                คอมพิวเตอร์
#     1                   แล็ปท็อป
#  1  0                   แล็ปท็อป
#  2  0    แล็ปท็อปสำหรับเล่นเกมส์
#  3  0                     lenovo
#     1                     legion
#     2                          y
#     3                        740
#     4                         17
#     5                         81
#     6                         uj
#     7                        005
#     8                        dta
#  dtype: object, 'category_4_145': 0  0                 คอมพิวเตอร์
#     1                    แล็ปท็อป
#  1  0                    แล็ปท็อป
#  2  0     แล็ปท็อปสำหรับเล่นเกมส์
#  3  0                      lenovo
#     1                      gaming
#     2                    notebook
#     3                     ideapad
#     4                           l
#     5                         340
#     6                          15
#     7                         irh
#     8                           5
#     9                        9300
#     10                          h
#     11                          8
#     12                          g
#     13                        512
#     14                          g
#     15                        gtx
#     16                       1050
#     17                          3
#     18                          g
#     19                          w
#     20                         10
#     21                          3
#     22                          y
#     23                   โน๊ตบุ๊ค
#  dtype: object, 'category_4_146': 0  0                 คอมพิวเตอร์
#     1                    แล็ปท็อป
#  1  0                    แล็ปท็อป
#  2  0     แล็ปท็อปสำหรับเล่นเกมส์
#  3  0                    โน๊ตบุ๊ค
#     1                      lenovo
#     2                    notebook
#     3                      gaming
#     4                      legion
#     5                           y
#     6                         530
#     7                          15
#     8                         ich
#     9                          81
#     10                         lb
#     11                        006
#     12                        vta
#     13                       15.6
#     14                       full
#     15                         hd
#     16                        ips
#     17                       core
#     18                          7
#     19                       8750
#     20                          h
#     21                        ram
#     22                          8
#     23                         gb
#     24                        ddr
#     25                          4
#     26                       2666
#     27                        ssd
#     28                        512
#     29                         gb
#     30                        win
#     31                         10
#     32                     nvidia
#     33                    geforce
#     34                        gtx
#     35                       1060
#     36                          6
#     37                         gb
#     38                       gddr
#     39                          5
#     40                        dvd
#     41                      black
#     42             รับประกันศูนย์
#     43                     lenovo
#     44                          2
#     45                         ปี
#     46                       ผ่อน
#     47                          0
#     48                 เปอร์เซนต์
#     49                         10
#     50                      เดือน
#     51                    ส่งเร็ว
#  dtype: object, 'category_4_147': 0  0                 คอมพิวเตอร์
#     1                    แล็ปท็อป
#  1  0                    แล็ปท็อป
#  2  0     แล็ปท็อปสำหรับเล่นเกมส์
#  3  0                      lenovo
#     1                      legion
#     2                           y
#     3                         530
#     4                          15
#     5                         ich
#     6                          81
#     7                          fv
#     8                          01
#     9                        cpta
#     10                          5
#     11                       8300
#     12                          h
#     13                          8
#     14                         gb
#     15                        512
#     16                         gb
#     17                        ssd
#     18                        gtx
#     19                       1050
#     20                       15.6
#     21                        win
#     22                         10
#     23                      black
#  dtype: object, 'category_4_148': 0  0                 คอมพิวเตอร์
#     1                    แล็ปท็อป
#  1  0                    แล็ปท็อป
#  2  0     แล็ปท็อปสำหรับเล่นเกมส์
#  3  0                      lenovo
#     1                      legion
#     2                           y
#     3                        7000
#     4                          se
#     5                          81
#     6                           t
#     7                       00011
#     8                          ta
#     9                           7
#     10                       9750
#     11                          h
#     12                          8
#     13                         gb
#     14                        512
#     15                         gb
#     16                        ssd
#     17                        gtx
#     18                       1650
#     19                          4
#     20                         gb
#     21                       15.6
#     22                        win
#     23                         10
#     24                      black
#  dtype: object, 'category_4_149': 0  0                 คอมพิวเตอร์
#     1                    แล็ปท็อป
#  1  0                    แล็ปท็อป
#  2  0     แล็ปท็อปสำหรับเล่นเกมส์
#  3  0                      lenovo
#     1                    notebook
#     2                    notebook
#     3                           y
#     4                      series
#     5                     legiony
#     6                         530
#     7                          15
#     8                         ich
#     9                          81
#     10                         fv
#     11                        015
#     12                        wta
#     13                          5
#     14                       8300
#     15                          h
#     16                          8
#     17                         gb
#     18                          1
#     19                         tb
#     20                          7
#     21                         mm
#     22                       5400
#     23                        rpm
#     24                        gtx
#     25                       1050
#     26                         ti
#     27                          4
#     28                         gb
#     29                       15.6
#     30                        fhd
#     31                        win
#     32                         10
#     33                       home
#     34                      black
#     35                          2
#     36                       year
#     37                       site
#     38                          0
#     39                 เปอร์เซนต์
#  dtype: object, 'category_4_150': 0  0                 คอมพิวเตอร์
#     1                    แล็ปท็อป
#  1  0                    แล็ปท็อป
#  2  0     แล็ปท็อปสำหรับเล่นเกมส์
#  3  0                      lenovo
#     1                     ideapad
#     2                           l
#     3                         340
#     4                          15
#     5                         irh
#     6                          81
#     7                          lk
#     8                          00
#     9                        mmta
#     10                          5
#     11                       9300
#     12                          h
#     13                          8
#     14                         gb
#     15                        512
#     16                         gb
#     17                        ssd
#     18                        gtx
#     19                       1650
#     20                       15.6
#     21                        win
#     22                         10
#     23                      black
#  dtype: object, 'category_4_151': 0  0                 คอมพิวเตอร์
#     1                    แล็ปท็อป
#  1  0                    แล็ปท็อป
#  2  0     แล็ปท็อปสำหรับเล่นเกมส์
#  3  0                      lenovo
#     1                      legion
#     2                           y
#     3                        7000
#     4                        2019
#     5                          pg
#     6                           0
#     7                          81
#     8                           t
#     9                       00011
#     10                         ta
#     11                     gaming
#     12                   notebook
#     13                       15.6
#     14                          7
#     15                       9750
#     16                          h
#     17                        แรม
#     18                          8
#     19                         gb
#     20                        ssd
#     21                        512
#     22                         gb
#     23                        gtx
#     24                       1650
#     25                          w
#     26                         10
#     27                      black
#  dtype: object, 'category_4_152': 0  0                 คอมพิวเตอร์
#     1                    แล็ปท็อป
#  1  0                    แล็ปท็อป
#  2  0     แล็ปท็อปสำหรับเล่นเกมส์
#  3  0                      lenovo
#     1                      legion
#     2                           y
#     3                         740
#     4                          17
#     5                          81
#     6                          uj
#     7                         005
#     8                         dta
#     9                           7
#     10                       9750
#     11                          h
#     12                         32
#     13                         gb
#     14                          1
#     15                         tb
#     16                          m
#     17                          .
#     18                          2
#     19                        ssd
#     20                    geforce
#     21                        rtx
#     22                       2070
#     23                       maxq
#     24                          8
#     25                         gb
#     26                       17.3
#     27                        fhd
#     28                        win
#     29                         10
#     30                       home
#     31                      black
#     32                        top
#     33                   computer
#  dtype: object, 'category_4_153': 0  0                 คอมพิวเตอร์
#     1                    แล็ปท็อป
#  1  0                    แล็ปท็อป
#  2  0     แล็ปท็อปสำหรับเล่นเกมส์
#  3  0                      lenovo
#     1                     ideapad
#     2                           l
#     3                         340
#     4                          15
#     5                         irh
#     6                          81
#     7                          lk
#     8                          00
#     9                        mlta
#     10                          5
#     11                       9300
#     12                          h
#     13                          8
#     14                         gb
#     15                        512
#     16                         gb
#     17                        ssd
#     18                        gtx
#     19                       1050
#     20                       15.6
#     21                        win
#     22                         10
#     23                      black
#  dtype: object, 'category_4_154': 0  0                 คอมพิวเตอร์
#     1                    แล็ปท็อป
#  1  0                    แล็ปท็อป
#  2  0     แล็ปท็อปสำหรับเล่นเกมส์
#  3  0                      lenovo
#     1                    notebook
#     2                    notebook
#     3                           y
#     4                      series
#     5                      legion
#     6                           y
#     7                         530
#     8                          15
#     9                         ich
#     10                         81
#     11                         fv
#     12                        000
#     13                        lta
#     14                          7
#     15                       8750
#     16                          h
#     17                          8
#     18                         gb
#     19                          1
#     20                         tb
#     21                        128
#     22                         gb
#     23                        ssd
#     24                        gtx
#     25                       1050
#     26                         ti
#     27                          4
#     28                         gb
#     29                       15.6
#     30                        fhd
#     31                        ips
#     32                        win
#     33                         10
#     34                       home
#     35                      black
#  dtype: object, 'category_4_155': 0  0                 คอมพิวเตอร์
#     1                    แล็ปท็อป
#  1  0                    แล็ปท็อป
#  2  0     แล็ปท็อปสำหรับเล่นเกมส์
#  3  0                      lenovo
#     1                      legion
#     2                           y
#     3                         540
#     4                          81
#     5                          sy
#     6                          00
#     7                        arta
#     8                           5
#     9                        9300
#     10                          h
#     11                          8
#     12                         gb
#     13                          1
#     14                         tb
#     15                        256
#     16                         gb
#     17                          m
#     18                          .
#     19                          2
#     20                        ssd
#     21                    geforce
#     22                        gtx
#     23                       1650
#     24                          4
#     25                         gb
#     26                       15.6
#     27                        fhd
#     28                        win
#     29                         10
#     30                       home
#     31                      black
#     32                        top
#     33                   computer
#  dtype: object, ...}

# %% [markdown]
# # Save data to csv file

# %%
# Transform dict to dataframe and save to csv file
pd.DataFrame.from_dict(data_clean, orient='index').transpose().reset_index().to_csv("./Data/{}_clean.csv".format(file_name))

# %%
pd.DataFrame.from_dict(data_clean, orient='index').transpose().reset_index().to_excel('./Data/category1_clean.xlsx',engine='xlsxwriter')

# %%
pd.DataFrame.from_dict(dict_value, orient='index').transpose().to_csv("./Data/{}_value.csv".format(file_name))
