# %%
import pandas as pd
import csv
import re
import string
import nltk

from pythainlp.tokenize import Tokenizer
from pythainlp import word_tokenize
from pythainlp.corpus import thai_stopwords
from pythainlp.tokenize import dict_trie

from nltk.corpus import words
from stop_words import get_stop_words

# %%
# import data from csv
file_name = 'category1'

FILE = './Data/{}.csv'.format(file_name)
df = pd.read_csv(FILE)

# %%
df.head()
# Out:
#    Unnamed: 0                                       category_0_0  \
# 0           0                          โทรศัพท์มือถือและแท็บเล็ต
# 1           1                                        Smartphones
# 2           2    Samsung Galaxy M30s (4/64GB) ( โทรศัพท์มือถือ )
# 3           3  แบตอึดอยู่นาน สนุกได้ทั้งวัน กับความจุ 6000 mA...
# 4           4  ระบบกล้องหลัง 3 ตัว ที่มีกล้องชัดสูงสุดถึง 48 ...
#
#                                         category_0_1  \
# 0                          โทรศัพท์มือถือและแท็บเล็ต
# 1                                        Smartphones
# 2  โทรศัพท์มือถือ Samsung Galaxy A50s Ram4/64GB (...
# 3                           GSM 850/900/1800/1900MHz
# 4                      3G WCDMA 850/900/1900/2100MHz
#
#                                         category_0_2  \
# 0                          โทรศัพท์มือถือและแท็บเล็ต
# 1                                        Smartphones
# 2               Samsung Galaxy A10s (RAM2GB/ROM32GB)
# 3      สมาร์ทโฟน (โทรศัพท์มือถือพร้อมระบบปฏิบัติการ)
# 4  จอแสดงผล TFT-LCD 24-bit (16 ล้านสี)- หน้าจอทรง...
#
#                                         category_0_3  \
# 0                          โทรศัพท์มือถือและแท็บเล็ต
# 1                                        Smartphones
# 2  Samsung Galaxy Note 10 + (12/256 GB) ( โทรศัพท...
# 3                                ขนาดหน้าจอ 6.8 นิ้ว
# 4                                          Ram 12 GB
#
#                                         category_0_4  \
# 0                          โทรศัพท์มือถือและแท็บเล็ต
# 1                                        Smartphones
# 2                           Samsung Galaxy A7 (2017)
# 3  ระบบเซ็นเซอร์ (Sensor)\r\n- ระบบตรวจสอบลายนิ้ว...
# 4  คุณสมบัติการกันน้ำ (Waterproof)\r\n- กันน้ำได้...
#
#                                         category_0_5  \
# 0                          โทรศัพท์มือถือและแท็บเล็ต
# 1                                        Smartphones
# 2  Samsung Galaxy A9 (2018) 6 GB RAM 128 GB ROM 6...
# 3  จอแสดงผล Super AMOLED 24-bit (16 ล้านสี)Fullvi...
# 4  ระบบตรวจสอบลายนิ้วมือ (Fingerprint)ระบบจดจำใบห...
#
#                                         category_0_6  \
# 0                          โทรศัพท์มือถือและแท็บเล็ต
# 1                                        Smartphones
# 2  Samsung A30S (RAM 4GB / ROM 64 GB) มือ 1 ประกั...
# 3                             คุณสมบัติ Samsung A30S
# 4           จอแสดงผล Super AMOLED 24-bit (16 ล้านสี)
#
#                                         category_0_7  \
# 0                          โทรศัพท์มือถือและแท็บเล็ต
# 1                                        Smartphones
# 2  (มือ1 ศูนย์ไทย) Samsung Galaxy Note 10 Plus No...
# 3  Samsung Galaxy Note10 plus TH ประกันศูนย์ไทย 1...
# 4                                      แบรนด์ ซัมซุง
#
#                                       category_0_8  ...  \
# 0                        โทรศัพท์มือถือและแท็บเล็ต  ...
# 1                                      Smartphones  ...
# 2  Samsung Galaxy A70 (8/128GB) ( โทรศัพท์มือถือ )  ...
# 3                      Galaxy A70 (SM-A705FZBGTHL)  ...
# 4                               สเปคเทพของเกมเมอร์  ...
#
#                                      category_33_234  \
# 0                                   สมาร์ทดีไวซ์ New
# 1                                           แก็ดเจ็ต
# 2                           เครื่องเล่นเกมคอมโซล New
# 3                                         คอนโซล New
# 4  GloryStar BASEUS PUBG ไฟฟรีเกมที่วางโทรศัพท์แผ...
#
#                                      category_33_235  \
# 0                                   สมาร์ทดีไวซ์ New
# 1                                           แก็ดเจ็ต
# 2                           เครื่องเล่นเกมคอมโซล New
# 3                                         คอนโซล New
# 4  GloryStar นาฬิกาติดตามตำแหน่งอัจฉริยะเด็กนาฬิก...
#
#                                      category_33_236  \
# 0                                   สมาร์ทดีไวซ์ New
# 1                                           แก็ดเจ็ต
# 2                           เครื่องเล่นเกมคอมโซล New
# 3                                         คอนโซล New
# 4  GloryStar Joy-CON ตัวควบคุมเกมแป้นเกมส์จอยเกมส...
#
#                                      category_33_237  \
# 0                                   สมาร์ทดีไวซ์ New
# 1                                           แก็ดเจ็ต
# 2                           เครื่องเล่นเกมคอมโซล New
# 3                                         คอนโซล New
# 4  GloryStar คอนโซลเกมคลาสสิก 8 BitsProfessional ...
#
#                                      category_33_238  \
# 0                                   สมาร์ทดีไวซ์ New
# 1                                           แก็ดเจ็ต
# 2                           เครื่องเล่นเกมคอมโซล New
# 3                                         คอนโซล New
# 4  GloryStar สีน้ำเงินแปรงเกมควบคุมเครื่องรับสัญญ...
#
#                                      category_33_239  \
# 0                                   สมาร์ทดีไวซ์ New
# 1                                           แก็ดเจ็ต
# 2                           เครื่องเล่นเกมคอมโซล New
# 3                                         คอนโซล New
# 4  GloryStar Flysky รีโมทคอนโทรล FS-IT4S + IA4B 4...
#
#                                 category_33_240  \
# 0                              สมาร์ทดีไวซ์ New
# 1                                      แก็ดเจ็ต
# 2                      เครื่องเล่นเกมคอมโซล New
# 3                                    คอนโซล New
# 4  Top-Sky PlayStation 2 PS2 Memory Card - 32MB
#
#                                  category_33_241  \
# 0                               สมาร์ทดีไวซ์ New
# 1                                       แก็ดเจ็ต
# 2                       เครื่องเล่นเกมคอมโซล New
# 3                                     คอนโซล New
# 4  Top-Sky PlayStation 2 PS2 Memory Card - 256MB
#
#                                  category_33_242  \
# 0                               สมาร์ทดีไวซ์ New
# 1                                       แก็ดเจ็ต
# 2                       เครื่องเล่นเกมคอมโซล New
# 3                                     คอนโซล New
# 4  Top-Sky PlayStation 2 PS2 Memory Card - 128MB
#
#                                      category_33_243
# 0                                   สมาร์ทดีไวซ์ New
# 1                                           แก็ดเจ็ต
# 2                           เครื่องเล่นเกมคอมโซล New
# 3                                         คอนโซล New
# 4  Top - Sky 3 - in - 1 PS4/PS4 Slim/PS4 เกมโปรที...
#
# [5 rows x 5619 columns]

# %%
# Drop a column that not use
data = df.drop(columns=['Unnamed: 0'])

# Drop column that all equal to NaN
data = data.dropna(axis=1, how='all')

# Fill NaN with "-"
data = data.fillna('-')

# %%
data.head()
# Out:
#                                         category_0_0  \
# 0                          โทรศัพท์มือถือและแท็บเล็ต
# 1                                        Smartphones
# 2    Samsung Galaxy M30s (4/64GB) ( โทรศัพท์มือถือ )
# 3  แบตอึดอยู่นาน สนุกได้ทั้งวัน กับความจุ 6000 mA...
# 4  ระบบกล้องหลัง 3 ตัว ที่มีกล้องชัดสูงสุดถึง 48 ...
#
#                                         category_0_1  \
# 0                          โทรศัพท์มือถือและแท็บเล็ต
# 1                                        Smartphones
# 2  โทรศัพท์มือถือ Samsung Galaxy A50s Ram4/64GB (...
# 3                           GSM 850/900/1800/1900MHz
# 4                      3G WCDMA 850/900/1900/2100MHz
#
#                                         category_0_2  \
# 0                          โทรศัพท์มือถือและแท็บเล็ต
# 1                                        Smartphones
# 2               Samsung Galaxy A10s (RAM2GB/ROM32GB)
# 3      สมาร์ทโฟน (โทรศัพท์มือถือพร้อมระบบปฏิบัติการ)
# 4  จอแสดงผล TFT-LCD 24-bit (16 ล้านสี)- หน้าจอทรง...
#
#                                         category_0_3  \
# 0                          โทรศัพท์มือถือและแท็บเล็ต
# 1                                        Smartphones
# 2  Samsung Galaxy Note 10 + (12/256 GB) ( โทรศัพท...
# 3                                ขนาดหน้าจอ 6.8 นิ้ว
# 4                                          Ram 12 GB
#
#                                         category_0_4  \
# 0                          โทรศัพท์มือถือและแท็บเล็ต
# 1                                        Smartphones
# 2                           Samsung Galaxy A7 (2017)
# 3  ระบบเซ็นเซอร์ (Sensor)\r\n- ระบบตรวจสอบลายนิ้ว...
# 4  คุณสมบัติการกันน้ำ (Waterproof)\r\n- กันน้ำได้...
#
#                                         category_0_5  \
# 0                          โทรศัพท์มือถือและแท็บเล็ต
# 1                                        Smartphones
# 2  Samsung Galaxy A9 (2018) 6 GB RAM 128 GB ROM 6...
# 3  จอแสดงผล Super AMOLED 24-bit (16 ล้านสี)Fullvi...
# 4  ระบบตรวจสอบลายนิ้วมือ (Fingerprint)ระบบจดจำใบห...
#
#                                         category_0_6  \
# 0                          โทรศัพท์มือถือและแท็บเล็ต
# 1                                        Smartphones
# 2  Samsung A30S (RAM 4GB / ROM 64 GB) มือ 1 ประกั...
# 3                             คุณสมบัติ Samsung A30S
# 4           จอแสดงผล Super AMOLED 24-bit (16 ล้านสี)
#
#                                         category_0_7  \
# 0                          โทรศัพท์มือถือและแท็บเล็ต
# 1                                        Smartphones
# 2  (มือ1 ศูนย์ไทย) Samsung Galaxy Note 10 Plus No...
# 3  Samsung Galaxy Note10 plus TH ประกันศูนย์ไทย 1...
# 4                                      แบรนด์ ซัมซุง
#
#                                       category_0_8  \
# 0                        โทรศัพท์มือถือและแท็บเล็ต
# 1                                      Smartphones
# 2  Samsung Galaxy A70 (8/128GB) ( โทรศัพท์มือถือ )
# 3                      Galaxy A70 (SM-A705FZBGTHL)
# 4                               สเปคเทพของเกมเมอร์
#
#                                         category_0_9  ...  \
# 0                          โทรศัพท์มือถือและแท็บเล็ต  ...
# 1                                        Smartphones  ...
# 2  Smartphone โทรศัพท์มือถือ Samsung Galaxy A10S ...  ...
# 3                                      แบรนด์ ซัมซุง  ...
# 4                        SKU 571250946_TH-1048780375  ...
#
#                                      category_33_234  \
# 0                                   สมาร์ทดีไวซ์ New
# 1                                           แก็ดเจ็ต
# 2                           เครื่องเล่นเกมคอมโซล New
# 3                                         คอนโซล New
# 4  GloryStar BASEUS PUBG ไฟฟรีเกมที่วางโทรศัพท์แผ...
#
#                                      category_33_235  \
# 0                                   สมาร์ทดีไวซ์ New
# 1                                           แก็ดเจ็ต
# 2                           เครื่องเล่นเกมคอมโซล New
# 3                                         คอนโซล New
# 4  GloryStar นาฬิกาติดตามตำแหน่งอัจฉริยะเด็กนาฬิก...
#
#                                      category_33_236  \
# 0                                   สมาร์ทดีไวซ์ New
# 1                                           แก็ดเจ็ต
# 2                           เครื่องเล่นเกมคอมโซล New
# 3                                         คอนโซล New
# 4  GloryStar Joy-CON ตัวควบคุมเกมแป้นเกมส์จอยเกมส...
#
#                                      category_33_237  \
# 0                                   สมาร์ทดีไวซ์ New
# 1                                           แก็ดเจ็ต
# 2                           เครื่องเล่นเกมคอมโซล New
# 3                                         คอนโซล New
# 4  GloryStar คอนโซลเกมคลาสสิก 8 BitsProfessional ...
#
#                                      category_33_238  \
# 0                                   สมาร์ทดีไวซ์ New
# 1                                           แก็ดเจ็ต
# 2                           เครื่องเล่นเกมคอมโซล New
# 3                                         คอนโซล New
# 4  GloryStar สีน้ำเงินแปรงเกมควบคุมเครื่องรับสัญญ...
#
#                                      category_33_239  \
# 0                                   สมาร์ทดีไวซ์ New
# 1                                           แก็ดเจ็ต
# 2                           เครื่องเล่นเกมคอมโซล New
# 3                                         คอนโซล New
# 4  GloryStar Flysky รีโมทคอนโทรล FS-IT4S + IA4B 4...
#
#                                 category_33_240  \
# 0                              สมาร์ทดีไวซ์ New
# 1                                      แก็ดเจ็ต
# 2                      เครื่องเล่นเกมคอมโซล New
# 3                                    คอนโซล New
# 4  Top-Sky PlayStation 2 PS2 Memory Card - 32MB
#
#                                  category_33_241  \
# 0                               สมาร์ทดีไวซ์ New
# 1                                       แก็ดเจ็ต
# 2                       เครื่องเล่นเกมคอมโซล New
# 3                                     คอนโซล New
# 4  Top-Sky PlayStation 2 PS2 Memory Card - 256MB
#
#                                  category_33_242  \
# 0                               สมาร์ทดีไวซ์ New
# 1                                       แก็ดเจ็ต
# 2                       เครื่องเล่นเกมคอมโซล New
# 3                                     คอนโซล New
# 4  Top-Sky PlayStation 2 PS2 Memory Card - 128MB
#
#                                      category_33_243
# 0                                   สมาร์ทดีไวซ์ New
# 1                                           แก็ดเจ็ต
# 2                           เครื่องเล่นเกมคอมโซล New
# 3                                         คอนโซล New
# 4  Top - Sky 3 - in - 1 PS4/PS4 Slim/PS4 เกมโปรที...
#
# [5 rows x 5617 columns]

# %% [markdown]
# # Clean text

# %%
# clean the text
def clean_text_category1(msg):
    msg = msg.lower()
    if re.match("[0-9]\*[0-9]",str(msg)):
        msg = re.sub(r"\*","x",str(msg))
        
    msg = re.sub(r"\&","และ",str(msg))
    msg = re.sub(r"\%","เปอร์เซนต์",str(msg))
    msg = re.sub(r"[b]rand","แบรนด์",str(msg))
    msg = re.sub(r"ram","แรม",str(msg))
    msg = re.sub(r"rom","รอม",str(msg))
    msg = re.sub(r"[b]attery\s?[c]apacity","ความจุแบตเตอรี่",str(msg))
    msg = re.sub(r"\฿,"," บาท ",str(msg))
    msg = re.sub(r"[\d\s]*มม|mm\.?","มิลลิเมตร",str(msg))
    msg = re.sub(r"[\d\s]*ซม|cm\.?","เซนติเมตร",str(msg))
    msg = re.sub(r"\&","และ",str(msg))
    msg = re.sub(r"\,","",str(msg))
    msg = re.sub(r"[^a-z0-9ก-๙\.\s]"," ", str(msg))
    msg = re.sub(r"\s+"," ",str(msg))
    
    return msg

# %%
# Cleaning text with clean_text function and keep in dict
data_clean = {}
for key,value in data.iteritems():
    tmp = [clean_text_category1(txt) for txt in value if not txt == '-']
    data_clean[key] = tmp

# %%
# Show some of data in dict
dict(list(data_clean.items())[0:10])
# Out:
# {'category_0_0': ['โทรศัพท์มือถือและแท็บเล็ต',
#   'smartphones',
#   'samsung galaxy m30s 4 64gb โทรศัพท์มือถือ ',
#   'แบตอึดอยู่นาน สนุกได้ทั้งวัน กับความจุ 6000 mah และสามารถชาร์จแบตเร็ว ด้วย fast charging',
#   'ระบบกล้องหลัง 3 ตัว ที่มีกล้องชัดสูงสุดถึง 48 mp มาพร้อมกับเลนส์มุมกว้างพิเศษ ultra wide',
#   'ใช้ exynos 9611 สเป็กแรงขึ้นเล่นเกมส์ได้ไม่มีสะดุด กับ แรม 4 gb รอม 64 gb',
#   'หน้าจอแสดงผล super amoled infinity u ขนาด 6.4 นิ้ว',
#   'แบรนด์ ซัมซุง',
#   'sku 480942616 th 870640886',
#   'ประเภทของการรับประกัน มีการรับประกัน',
#   'model galaxy m30s 4 64gb ',
#   'ระยะเวลาการรับประกัน 1 ปี',
#   '793'],
#  'category_0_1': ['โทรศัพท์มือถือและแท็บเล็ต',
#   'smartphones',
#   'โทรศัพท์มือถือ samsung galaxy a50s แรม4 64gb รับประกันศูนย์ by jaymart',
#   'gsm 850 900 1800 1900mhz',
#   '3g wcdma 850 900 1900 2100mhz',
#   '4g fdd lte b1 2100 b3 1800 b5 850 b7 2600 b8 900 b20 800 b28 700 ',
#   '4g tdd lte b38 2600 b40 2300 b41 2500 ',
#   'รองรับ 2 ซิม nano sim',
#   'หน่วยประมวลผล exynos 9610 quad 2.3 ghz quad 1.7 ghz',
#   'ระบบปฏิบัติการ android',
#   'หน่วยความจำภายใน 64gb เพิ่ม micro sd รองรับสูงสุด 512 gb',
#   'แรม 4 gb',
#   'หน้าจอ 6.4 นิ้ว ความละเอียด 1080 x 2340 พิกเซล fhd ',
#   'กล้องหลัง 3 เลนส์ 48 ล้านพิกเซล f 2.0 5 ล้านพิกเซล f 2.2 bokeh 8 ล้านพิกเซล f 2.4 ultrawide แฟลช led',
#   'กล้องหน้า 32 ล้านพิกเซล f 2.0',
#   'wifi 802.11 a b g n ac',
#   'bluetooth 5.0',
#   'แบตเตอรี่ 4000 mah',
#   'ขนาด 158.5 x 74.5 x 7.7 mm',
#   'น้ำหนัก 169 g',
#   'แบรนด์ ซัมซุง',
#   'sku 593772364 th 1113954823',
#   'ระยะเวลาการรับประกัน 1 ปี',
#   'ประเภทของการรับประกัน การรับประกันจากโรงงานในประเทศ',
#   'กล้องหน้า เมกะพิกเซล 7 mp ขึ้นไป',
#   'ระบบปฏิบัติการเวอร์ชัน android 9.0 pie',
#   'model a50s',
#   'หน่วยความจำ แรม 512mb และน้อยกว่า',
#   'ขนาดหน้าจอ นิ้ว 6.4',
#   'กล้องด้านหลัง 21mp ขึ้นไป',
#   'ความจุแบตเตอรี่ 1000 mah ถึง 5000 mah',
#   'ช่องเสียบแบบบาง คู่'],
#  'category_0_2': ['โทรศัพท์มือถือและแท็บเล็ต',
#   'smartphones',
#   'samsung galaxy a10s แรม2gb รอม32gb ',
#   'สมาร์ทโฟน โทรศัพท์มือถือพร้อมระบบปฏิบัติการ ',
#   'จอแสดงผล tft lcd 24 bit 16 ล้านสี หน้าจอทรงหยดน้ำ รูปตัว v infinity v กว้าง 6.2 นิ้ว แนวทะแยง ความละเอียด 1520 x 720 พิกเซล',
#   'ระบบเซ็นเซอร์ sensor ระบบตรวจสอบลายนิ้วมือ fingerprint ระบบหมุนภาพอัตโนมัติ acceleรอมeter ระบบเซนเซอร์หมุนภาพ gyroscope ',
#   'มีสีให้เลือก colors black red green blue',
#   'แบรนด์ ซัมซุง',
#   'sku 404422189 th 784670279',
#   'มือถือ smartphone',
#   'ระยะเวลาการรับประกัน 1 ปี',
#   'ระบบปฏิบัติการ android 9.0 pie',
#   'ประเภทของการรับประกัน มีการรับประกัน',
#   'กล้องหน้า เมกะพิกเซล 7 mp ขึ้นไป',
#   'ระบบปฏิบัติการเวอร์ชัน android 9.0 pie',
#   'model samsung galaxy a10s แรม2gb รอม32gb ',
#   'หน่วยความจำ แรม 2gb',
#   'ขนาดหน้าจอ นิ้ว 6.2',
#   'กล้องด้านหลัง 11 15mp',
#   'ความจุแบตเตอรี่ 1000 mah ถึง 5000 mah',
#   'ช่องเสียบแบบบาง เตียงเดี่ยว',
#   '143'],
#  'category_0_3': ['โทรศัพท์มือถือและแท็บเล็ต',
#   'smartphones',
#   'samsung galaxy note 10 12 256 gb โทรศัพท์มือถือ ',
#   'ขนาดหน้าจอ 6.8 นิ้ว',
#   'แรม 12 gb',
#   'ความจุ storage 256 gb',
#   'แบตเตอรี่ 4300 mah typical ',
#   'มาตรฐานการกันน้ำและกันฝุ่น ip68',
#   'แบรนด์ ซัมซุง',
#   'sku 385536916 th 749070165',
#   'ประเภทของการรับประกัน มีการรับประกัน',
#   'model galaxy note 10 ',
#   'ขนาดหน้าจอ นิ้ว 6.8',
#   'ระยะเวลาการรับประกัน 1 ปี',
#   '243'],
#  'category_0_4': ['โทรศัพท์มือถือและแท็บเล็ต',
#   'smartphones',
#   'samsung galaxy a7 2017 ',
#   'ระบบเซ็นเซอร์ sensor ระบบตรวจสอบลายนิ้วมือ fingerprint ระบบหมุนภาพอัตโนมัติ acceleรอมeter ระบบเปิด ปิดหน้าจออัตโนมัติขณะสนทนา proximity ระบบตรวจจับคลื่นแม่เหล็ก geomagnetic ระบบเซนเซอร์หมุนภาพ gyroscope ระบบวัดความกดอากาศ baรอมeter ',
#   'คุณสมบัติการกันน้ำ waterproof กันน้ำได้ชั่วคราว',
#   'มีสีให้เลือก colors black pink gold bluelight',
#   'เทคโนโลยีการรับ ส่งข้อมูล 2g edge gprs 3g hspa 4g lte dl lte ul',
#   'ใช้งาน nano sim',
#   'รองรับ 2 ซิมการ์ด',
#   'ระบบปฏิบัติการ android 6.0.1 marshmallow ',
#   'หน่วยประมวลผล octa core ความเร็ว 1.9 ghz',
#   'หน่วยความจำ 32 gb ตัวเครื่อง แรม 3gb',
#   'การ์ดหน่วยความจำ',
#   ' microsd',
#   'การหาตำแหน่ง assisted gps',
#   'wifi 802.11 a b g n ac จุดกระจายสัญญาณอินเตอร์เน็ตแบบพกพา portable wi fi hotspot เชื่อมต่อไร้สายระหว่างอุปกรณ์โดยตรง wi fi direct ',
#   'bluetooth 4.2 รองรับชุดหูฟังสเตอริโอ a2dp bluetooth stereo ',
#   'รองรับ nfc near field communication ',
#   'ant ',
#   'usb type c',
#   'ช่องเสียบชุดหูฟัง 3.5 มิลลิเมตร',
#   'โซเชียลเน็ตเวิร์คแอพฯ facebook twitter',
#   'กล้องดิจิตอล 16 ล้านพิกเซล digital camera รูรับแสงขนาด 1.9 ไฟแฟลช led โฟกัสอัตโนมัติ auto focus แตะเลือกจุดโฟกัส touch focus ค้นหาใบหน้าอัตโนมัติ face detection โหมดถ่ายภาพพาโนราม่า panoแรมa ',
#   'โหมดถ่ายภาพช่วงการรับแสงสูง hdr ',
#   'กล้องหน้า front camera ความละเอียด 16 mp รูรับแสงขนาด 1.9',
#   'บันทึกวีดีโอ ภาพเคลื่อนไหว video recording รูปแบบไฟล์วีดีโอ mpeg 4',
#   'เครื่องเล่นวีดีโอ video player รูปแบบไฟล์ mpeg 4 wmv h.264 h.263 รองรับวีดีโอจาก youtube ',
#   'เครื่องเล่นเพลง music player รูปแบบไฟล์ amr nb aac lc aac eaac mp3 wma flac',
#   'sms mms',
#   'ข้อความแชท skype',
#   'สนับสนุน gmail google search',
#   'ไมโครโฟนสำหรับตัดเสียงรบกวนการสนทนา',
#   'ออร์กาไนเซอร์ ปฏิทิน เครื่องคิดเลข นาฬิกาปลุก จดบันทึก',
#   'ริงโทน mp3 ระบบสั่น vibration in phone '],
#  'category_0_5': ['โทรศัพท์มือถือและแท็บเล็ต',
#   'smartphones',
#   'samsung galaxy a9 2018 6 gb แรม 128 gb รอม 6.3 นิ้ว 5 กล้อง สูงสุด 24 mp tetra cell f1.7 โทรศัพท์มือถือ ',
#   'จอแสดงผล super amoled 24 bit 16 ล้านสี fullview displayกว้าง 6.3 นิ้ว',
#   'ระบบตรวจสอบลายนิ้วมือ fingerprint ระบบจดจำใบหน้า face detection ',
#   'กล้องดิจิตอล main camera 24mp ultra wide camera 8mp telephoto camera 10mp depth camera 5mp fourth camera รูรับแสงขนาด 1.7',
#   'กล้องหน้า ความละเอียด 24 mp',
#   'แรม 6gb',
#   'หน่วยความจำตัวเครื่อง128 gb',
#   'แบรนด์ ซัมซุง',
#   'sku 265390897 th 412154584',
#   'ประเภทของการรับประกัน มีการรับประกัน',
#   'model galaxy a9 2018 ',
#   'ระยะเวลาการรับประกัน 1 ปี',
#   '141'],
#  'category_0_6': ['โทรศัพท์มือถือและแท็บเล็ต',
#   'smartphones',
#   'samsung a30s แรม 4gb รอม 64 gb มือ 1 ประกันศูนย์ 1 ปี',
#   'คุณสมบัติ samsung a30s',
#   'จอแสดงผล super amoled 24 bit 16 ล้านสี ',
#   'กว้าง 6.4 นิ้ว แนวทะแยง ความละเอียด 720 x 1560 พิกเซล 268 ppi ',
#   'ประเภทจอ corning gorilla glass 3 ระบบปฏิบัติการ',
#   'android 9.0 pie หน่วยประมวลผล exynos 7885 octa core ความเร็ว 1.8 mhz หน่วยความจำ',
#   'แรม 4gb รอม 64gb การ์ดหน่วยความจำ',
#   'microsd สูงสุด 1 tb',
#   'กล้องดิจิตอล 25mp 8 mp ultrawide 5 mp depth sensor triple camera รูรับแสงขนาด 1.7 ไฟแฟลช led โหมดถ่ายภาพช่วงการรับแสงสูง hdr ',
#   'กล้องหน้า front camera ความละเอียด 16 mp รูรับแสงขนาด 2.0',
#   'ลำโพงเสียงสเตอริโอ stereo speakers wifi 802.11 a b g n ac',
#   'จุดกระจายสัญญาณอินเตอร์เน็ตแบบพกพา portable wi fi hotspot ',
#   'เชื่อมต่อไร้สายระหว่างอุปกรณ์โดยตรง wi fi direct bluetooth 5.0 type c usb 2.0 ช่องเสียบชุดหูฟัง 3.5 มิลลิเมตร',
#   'เครือข่าย gsm 850 900 1800 1900 mhz umts 850 900 2100 mhz lte bands 1 3 5 7 8 20 38 40 41 เทคโนโลยีการรับ ส่งข้อมูล 2g edge gprs 3g 4g',
#   'ใช้งาน nano sim รองรับ 2 ซิมการ์ด',
#   'ระบบเซ็นเซอร์ sensor ระบบสแกนลายนิ้วมือใต้หน้าจอ fingerprint under display ตรวจจับความเคลื่อนไหวของตัวเครื่อง acceleรอมeter ระบบเปิด ปิดหน้าจออัตโนมัติขณะสนทนา proximity ',
#   'แบตเตอรี่มาตรฐาน li pol 4000 mah standard battery ',
#   'มีสีให้เลือก colors ดำขาว เขียว',
#   'แบรนด์ ซัมซุง',
#   'sku 594352438 th 1115888431',
#   'ประเภทของการรับประกัน การรับประกันจากโรงงานในประเทศ',
#   'กล้องหน้า เมกะพิกเซล 16 mp',
#   'model samsung a30s',
#   'กล้องด้านหลัง 21mp ขึ้นไป',
#   'ระยะเวลาการรับประกัน 1 ปี',
#   'ความจุแบตเตอรี่ 1000 mah ถึง 5000 mah'],
#  'category_0_7': ['โทรศัพท์มือถือและแท็บเล็ต',
#   'smartphones',
#   ' มือ1 ศูนย์ไทย samsung galaxy note 10 plus note 10 12 256gb ประกัน1ปี',
#   'samsung galaxy note10 plus th ประกันศูนย์ไทย 1ปี เข้าศูนย์ซัมซุงได้ทั่วประเทศ มือ1เครื่องแท้ 100เปอร์เซนต์',
#   'แบรนด์ ซัมซุง',
#   'sku 599364278 th 1176694583',
#   'ประเภทของการรับประกัน มีการรับประกัน',
#   'ระบบปฏิบัติการเวอร์ชัน android 9.0 pie',
#   'model samsung galaxy note10 plus',
#   'ขนาดหน้าจอ นิ้ว 6.8',
#   'ระยะเวลาการรับประกัน 1 ปี',
#   'ช่องเสียบแบบบาง เตียงเดี่ยว'],
#  'category_0_8': ['โทรศัพท์มือถือและแท็บเล็ต',
#   'smartphones',
#   'samsung galaxy a70 8 128gb โทรศัพท์มือถือ ',
#   'galaxy a70 sm a705fzbgthl ',
#   'สเปคเทพของเกมเมอร์',
#   'หน้าจอกว้าง 6.7 แบบ infinity u display',
#   '3 กล้อง พร้อมเลนส์ ultra wide',
#   'แบรนด์ ซัมซุง',
#   'sku 309636084 th 547152150',
#   'ประเภทของการรับประกัน มีการรับประกัน',
#   'model a70 8 128gb ',
#   'ระยะเวลาการรับประกัน 1 ปี',
#   '249'],
#  'category_0_9': ['โทรศัพท์มือถือและแท็บเล็ต',
#   'smartphones',
#   'smartphone โทรศัพท์มือถือ samsung galaxy a10s sm a107m ขนาดหน้าจอ 6.2 นิ้ว แรม 2 รอม 32 gb สีน้ำเงิน ',
#   'แบรนด์ ซัมซุง',
#   'sku 571250946 th 1048780375',
#   'มือถือ smartphone',
#   'ระยะเวลาการรับประกัน 1 เดือน',
#   'ประเภทของการรับประกัน มีการรับประกันจากผู้ขาย',
#   'ประเภทของแบตเตอรี่ แบตเตอรี่ชาร์จใหม่ได้และถอดได้',
#   'สภาพสินค้า ใหม่',
#   'กล้องหน้า เมกะพิกเซล 7 mp ขึ้นไป',
#   'model smartphone โทรศัพท์มือถือ samsung galaxy a10s sm a107m ขนาดหน้าจอ 6.2 นิ้ว แรม 2 รอม 32 gb สีน้ำเงิน ',
#   'ประเภทหน้าจอ lcd',
#   'กล้องด้านหลัง 11 15mp',
#   'ppi มากกว่า 500 ppi',
#   'ความละเอียดวิดีโอ 1080p',
#   'resolution full hd',
#   'ความจุแบตเตอรี่ 1000 mah ถึง 5000 mah']}

# %% [markdown]
# # Capture attribute of product by regex

# %% [markdown]
# def cap_attr(text):
#     m = re.match("([ก-๙A-Za-z]+)\:\s?([ก-๙A-Za-z0-9]+)",text)
#     if m:
#         yield text
#     elif re.match("SKU\s\d+\_TH\-\d+",text):
#         yield text
#     else:
#         m = re.search("([ก-๙A-Za-z]+)\:\s?([ก-๙A-Za-z0-9]+)",text)
#         if m is not None:
#             p = re.findall("([^:\s]*):\s?([^:\s]*)",text)
#             yield p

# %% [markdown]
# attr = {}
# for i,v in data_clean.items():
#     tmp_list = []
#     for txt in v:
#         match = cap_attr(txt)
#         for x in match:
#             tmp_list.append(x)
#     attr[i] = tmp_list

# %% [markdown]
# attr

# %% [markdown]
# attr_list = {}
# for i,v in attr.items():
#     tmp_list = []
#     for t in v:
#         if type(t) != list:
#             t_split = t.split(':')
#             if len(t_split)<3:
#                 tmp_list.append(t_split)
#         else:
#             for ele in t:
#                 if not (ele[0]!='' or ele[1]!=''):
#                     res = [list(ele)]
#             for l in res:
#                 tmp_list.append(l)
#     attr_list[i] = tmp_list

# %% [markdown]
# attr_list

# %% [markdown]
# dict_attr = {}
# dict_value = {}
# for i,v in attr_list.items():
#     tmp_attr = []
#     tmp_value = []
#     for e in v:
#         tmp_attr.append(e[0])
#         tmp_value.append(e[1])
#     dict_attr[i] = tmp_attr
#     dict_value[i] = tmp_value

# %% [markdown]
# dict_value

# %% [markdown]
# # Proprocessing text

# %%
# download stopwords of TH and EN
nltk.download('words')
th_stop = tuple(thai_stopwords())
en_stop = tuple(get_stop_words('en'))

# path of custom dictionary for word tokenize
PATH_TO_CUSTOM_DICT = './Data/custom_dict.txt'

# split text to words 
def split_word(text):
    
    # Split text to words
    _tokenizer = Tokenizer(custom_dict=PATH_TO_CUSTOM_DICT, engine='newmm')
    words = _tokenizer.word_tokenize(text)

    # Remove stop words in TH and EN
    words = [i for i in words if not i in th_stop and not i in en_stop]
    
    # Delete whitespace
    words = [i for i in words if not ' ' in i]

    return words
# Out:
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\super\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!

# %% [markdown]
# ## Tokenize text

# %%
token = {}
for key,value in data_clean.items():
    tmp = [split_word(txt) for txt in value]
    token[key] = tmp

# %%
dict(list(token.items())[0:10])
# Out:
# {'category_0_0': [['โทรศัพท์มือถือและแท็บเล็ต'],
#   ['smartphones'],
#   ['samsung', 'galaxy', 'm', '30', 's', '4', '64', 'gb', 'โทรศัพท์มือถือ'],
#   ['แบต',
#    'อึดอยู่นาน',
#    'สนุกได้ทั้งวัน',
#    'กับความจุ',
#    '6000',
#    'mah',
#    'และสามารถชาร์จ',
#    'แบต',
#    'fast',
#    'charging'],
#   ['ระบบ',
#    'กล้องหลัง',
#    '3',
#    'ตัว',
#    'ที่มีกล้องชัดสูงสุดถึง',
#    '48',
#    'mp',
#    'มาพร้อมกับเลนส์มุมกว้างพิเศษ',
#    'ultra',
#    'wide'],
#   ['exynos',
#    '9611',
#    'สเป็กแรงขึ้นเล่นเกมส์ได้ไม่มีสะดุด',
#    'ram',
#    '4',
#    'gb',
#    'rom',
#    '64',
#    'gb'],
#   ['หน้าจอแสดงผล', 'super', 'amoled', 'infinity', 'u', 'ขนาด', '6.4', 'นิ้ว'],
#   ['แบรนด์', 'ซัมซุง'],
#   ['sku', '480942616', 'th', '870640886'],
#   ['ประเภทของการรับประกัน', 'มีการรับประกัน'],
#   ['model', 'galaxy', 'm', '30', 's', '4', '64', 'gb'],
#   ['ระยะเวลาการรับประกัน', '1', 'ปี'],
#   ['793']],
#  'category_0_1': [['โทรศัพท์มือถือและแท็บเล็ต'],
#   ['smartphones'],
#   ['โทรศัพท์มือถือ',
#    'samsung',
#    'galaxy',
#    '50',
#    's',
#    'ram',
#    '4',
#    '64',
#    'gb',
#    'รับประกันศูนย์',
#    'jaymart'],
#   ['gsm', '850', '900', '1800', '1900', 'mhz'],
#   ['3', 'g', 'wcdma', '850', '900', '1900', '2100', 'mhz'],
#   ['4',
#    'g',
#    'fdd',
#    'lte',
#    'b',
#    '1',
#    '2100',
#    'b',
#    '3',
#    '1800',
#    'b',
#    '5',
#    '850',
#    'b',
#    '7',
#    '2600',
#    'b',
#    '8',
#    '900',
#    'b',
#    '20',
#    '800',
#    'b',
#    '28',
#    '700'],
#   ['4',
#    'g',
#    'tdd',
#    'lte',
#    'b',
#    '38',
#    '2600',
#    'b',
#    '40',
#    '2300',
#    'b',
#    '41',
#    '2500'],
#   ['รองรับ', '2', 'ซิม', 'nano', 'sim'],
#   ['หน่วยประมวลผล',
#    'exynos',
#    '9610',
#    'quad',
#    '2.3',
#    'ghz',
#    'quad',
#    '1.7',
#    'ghz'],
#   ['ระบบปฏิบัติการ', 'android'],
#   ['หน่วยความจำภายใน', '64', 'gb', 'micro', 'sd', 'รองรับ', '512', 'gb'],
#   ['ram', '4', 'gb'],
#   ['หน้าจอ',
#    '6.4',
#    'นิ้ว',
#    'ความละเอียด',
#    '1080',
#    'x',
#    '2340',
#    'พิกเซล',
#    'fhd'],
#   ['กล้องหลัง',
#    '3',
#    'เลนส์',
#    '48',
#    'ล้านพิกเซล',
#    'f',
#    '2.0',
#    '5',
#    'ล้านพิกเซล',
#    'f',
#    '2.2',
#    'bokeh',
#    '8',
#    'ล้านพิกเซล',
#    'f',
#    '2.4',
#    'ultrawide',
#    'แฟลช',
#    'led'],
#   ['กล้องหน้า', '32', 'ล้านพิกเซล', 'f', '2.0'],
#   ['wifi', '802.11', 'b', 'g', 'n', 'ac'],
#   ['bluetooth', '5.0'],
#   ['แบตเตอรี่', '4000', 'mah'],
#   ['ขนาด', '158.5', 'x', '74.5', 'x', '7.7', 'mm'],
#   ['น้ำหนัก', '169', 'g'],
#   ['แบรนด์', 'ซัมซุง'],
#   ['sku', '593772364', 'th', '1113954823'],
#   ['ระยะเวลาการรับประกัน', '1', 'ปี'],
#   ['ประเภทของการรับประกัน', 'การรับประกันจากโรงงานในประเทศ'],
#   ['กล้องหน้า', 'เมกะพิกเซล', '7', 'mp', 'ขึ้นไป'],
#   ['ระบบปฏิบัติการ', 'เวอร์ชัน', 'android', '9.0', 'pie'],
#   ['model', '50', 's'],
#   ['หน่วยความจำ', 'ram', '512', 'mb', 'และน้อยกว่า'],
#   ['ขนาดหน้าจอ', 'นิ้ว', '6.4'],
#   ['กล้องด้านหลัง', '21', 'mp', 'ขึ้นไป'],
#   ['battery', 'capacity', '1000', 'mah', '5000', 'mah'],
#   ['ช่องเสียบแบบบาง', 'คู่']],
#  'category_0_2': [['โทรศัพท์มือถือและแท็บเล็ต'],
#   ['smartphones'],
#   ['samsung', 'galaxy', '10', 's', 'ram', '2', 'gb', 'rom', '32', 'gb'],
#   ['สมาร์ทโฟน', 'โทรศัพท์มือถือพร้อม', 'ระบบปฏิบัติการ'],
#   ['จอแสดงผล',
#    'tft',
#    'lcd',
#    '24',
#    'bit',
#    '16',
#    'ล้านสี',
#    'หน้าจอทรงหยดน้ำ',
#    'รูปตัว',
#    'v',
#    'infinity',
#    'v',
#    '6.2',
#    'นิ้ว',
#    'แนวทะแยง',
#    'ความละเอียด',
#    '1520',
#    'x',
#    '720',
#    'พิกเซล'],
#   ['ระบบเซ็นเซอร์',
#    'sensor',
#    'ระบบตรวจสอบลายนิ้วมือ',
#    'fingerprint',
#    'ระบบหมุนภาพอัตโนมัติ',
#    'accelerometer',
#    'ระบบเซนเซอร์หมุนภาพ',
#    'gyroscope'],
#   ['มีสีให้เลือก', 'colors', 'black', 'red', 'green', 'blue'],
#   ['แบรนด์', 'ซัมซุง'],
#   ['sku', '404422189', 'th', '784670279'],
#   ['มือถือ', 'smartphone'],
#   ['ระยะเวลาการรับประกัน', '1', 'ปี'],
#   ['ระบบปฏิบัติการ', 'android', '9.0', 'pie'],
#   ['ประเภทของการรับประกัน', 'มีการรับประกัน'],
#   ['กล้องหน้า', 'เมกะพิกเซล', '7', 'mp', 'ขึ้นไป'],
#   ['ระบบปฏิบัติการ', 'เวอร์ชัน', 'android', '9.0', 'pie'],
#   ['model',
#    'samsung',
#    'galaxy',
#    '10',
#    's',
#    'ram',
#    '2',
#    'gb',
#    'rom',
#    '32',
#    'gb'],
#   ['หน่วยความจำ', 'ram', '2', 'gb'],
#   ['ขนาดหน้าจอ', 'นิ้ว', '6.2'],
#   ['กล้องด้านหลัง', '11', '15', 'mp'],
#   ['battery', 'capacity', '1000', 'mah', '5000', 'mah'],
#   ['ช่องเสียบแบบบาง', 'เตียงเดี่ยว'],
#   ['143']],
#  'category_0_3': [['โทรศัพท์มือถือและแท็บเล็ต'],
#   ['smartphones'],
#   ['samsung', 'galaxy', 'note', '10', '12', '256', 'gb', 'โทรศัพท์มือถือ'],
#   ['ขนาดหน้าจอ', '6.8', 'นิ้ว'],
#   ['ram', '12', 'gb'],
#   ['ความจุ', 'storage', '256', 'gb'],
#   ['แบตเตอรี่', '4300', 'mah', 'typical'],
#   ['มาตรฐานการกันน้ำและกันฝุ่น', 'ip', '68'],
#   ['แบรนด์', 'ซัมซุง'],
#   ['sku', '385536916', 'th', '749070165'],
#   ['ประเภทของการรับประกัน', 'มีการรับประกัน'],
#   ['model', 'galaxy', 'note', '10'],
#   ['ขนาดหน้าจอ', 'นิ้ว', '6.8'],
#   ['ระยะเวลาการรับประกัน', '1', 'ปี'],
#   ['243']],
#  'category_0_4': [['โทรศัพท์มือถือและแท็บเล็ต'],
#   ['smartphones'],
#   ['samsung', 'galaxy', '7', '2017'],
#   ['ระบบเซ็นเซอร์',
#    'sensor',
#    'ระบบตรวจสอบลายนิ้วมือ',
#    'fingerprint',
#    'ระบบหมุนภาพอัตโนมัติ',
#    'accelerometer',
#    'ระบบเปิด',
#    'ปิดหน้าจออัตโนมัติขณะสนทนา',
#    'proximity',
#    'ระบบตรวจจับคลื่นแม่เหล็ก',
#    'geomagnetic',
#    'ระบบเซนเซอร์หมุนภาพ',
#    'gyroscope',
#    'ระบบวัดความกดอากาศ',
#    'barometer'],
#   ['คุณสมบัติการกันน้ำ', 'waterproof', 'กันน้ำได้ชั่วคราว'],
#   ['มีสีให้เลือก', 'colors', 'black', 'pink', 'gold', 'bluelight'],
#   ['เทคโนโลยีการรับ',
#    'ส่งข้อมูล',
#    '2',
#    'g',
#    'edge',
#    'gprs',
#    '3',
#    'g',
#    'hspa',
#    '4',
#    'g',
#    'lte',
#    'dl',
#    'lte',
#    'ul'],
#   ['ใช้งาน', 'nano', 'sim'],
#   ['รองรับ', '2', 'ซิมการ์ด'],
#   ['ระบบปฏิบัติการ', 'android', '6.0.1', 'marshmallow'],
#   ['หน่วยประมวลผล', 'octa', 'core', 'ความเร็ว', '1.9', 'ghz'],
#   ['หน่วยความจำ', '32', 'gb', 'ตัวเครื่อง', 'ram', '3', 'gb'],
#   ['การ์ดหน่วยความจำ'],
#   ['microsd'],
#   ['การหาตำแหน่ง', 'assisted', 'gps'],
#   ['wifi',
#    '802.11',
#    'b',
#    'g',
#    'n',
#    'ac',
#    'จุดกระจายสัญญาณอินเตอร์เน็ตแบบพกพา',
#    'portable',
#    'wi',
#    'fi',
#    'hotspot',
#    'เชื่อมต่อไร้สายระหว่างอุปกรณ์โดยตรง',
#    'wi',
#    'fi',
#    'direct'],
#   ['bluetooth',
#    '4.2',
#    'รองรับ',
#    'ชุดหูฟังสเตอริโอ',
#    '2',
#    'dp',
#    'bluetooth',
#    'stereo'],
#   ['รองรับ', 'nfc', 'near', 'field', 'communication'],
#   ['ant'],
#   ['usb', 'type', 'c'],
#   ['ช่องเสียบชุดหูฟัง', '3.5', 'มิลลิเมตร'],
#   ['โซเชียลเน็ตเวิร์คแอพฯ', 'facebook', 'twitter'],
#   ['กล้องดิจิตอล',
#    '16',
#    'ล้านพิกเซล',
#    'digital',
#    'camera',
#    'รูรับแสงขนาด',
#    '1.9',
#    'ไฟแฟลช',
#    'led',
#    'โฟกัสอัตโนมัติ',
#    'auto',
#    'focus',
#    'แตะเลือกจุดโฟกัส',
#    'touch',
#    'focus',
#    'ค้นหาใบหน้าอัตโนมัติ',
#    'face',
#    'detection',
#    'โหมดถ่ายภาพพาโนราม่า',
#    'panorama'],
#   ['โหมดถ่ายภาพช่วงการรับแสงสูง', 'hdr'],
#   ['กล้องหน้า',
#    'front',
#    'camera',
#    'ความละเอียด',
#    '16',
#    'mp',
#    'รูรับแสงขนาด',
#    '1.9'],
#   ['บันทึกวีดีโอ',
#    'ภาพเคลื่อนไหว',
#    'video',
#    'recording',
#    'รูปแบบไฟล์วีดีโอ',
#    'mpeg',
#    '4'],
#   ['เครื่องเล่นวีดีโอ',
#    'video',
#    'player',
#    'รูปแบบไฟล์',
#    'mpeg',
#    '4',
#    'wmv',
#    'h',
#    '.',
#    '264',
#    'h',
#    '.',
#    '263',
#    'รองรับ',
#    'วีดีโอจาก',
#    'youtube'],
#   ['เครื่องเล่นเพลง',
#    'music',
#    'player',
#    'รูปแบบไฟล์',
#    'amr',
#    'nb',
#    'aac',
#    'lc',
#    'aac',
#    'eaac',
#    'mp',
#    '3',
#    'wma',
#    'flac'],
#   ['sms', 'mms'],
#   ['ข้อความแชท', 'skype'],
#   ['สนับสนุน', 'gmail', 'google', 'search'],
#   ['ไมโครโฟนสำหรับตัดเสียงรบกวนการสนทนา'],
#   ['ออร์กาไนเซอร์', 'ปฏิทิน', 'เครื่องคิดเลข', 'นาฬิกาปลุก', 'จดบันทึก'],
#   ['ริงโทน', 'mp', '3', 'ระบบสั่น', 'vibration', 'phone']],
#  'category_0_5': [['โทรศัพท์มือถือและแท็บเล็ต'],
#   ['smartphones'],
#   ['samsung',
#    'galaxy',
#    '9',
#    '2018',
#    '6',
#    'gb',
#    'ram',
#    '128',
#    'gb',
#    'rom',
#    '6.3',
#    'นิ้ว',
#    '5',
#    'กล้อง',
#    '24',
#    'mp',
#    'tetra',
#    'cell',
#    'f',
#    '1.7',
#    'โทรศัพท์มือถือ'],
#   ['จอแสดงผล',
#    'super',
#    'amoled',
#    '24',
#    'bit',
#    '16',
#    'ล้านสี',
#    'fullview',
#    'display',
#    '6.3',
#    'นิ้ว'],
#   ['ระบบตรวจสอบลายนิ้วมือ',
#    'fingerprint',
#    'ระบบจดจำใบหน้า',
#    'face',
#    'detection'],
#   ['กล้องดิจิตอล',
#    'main',
#    'camera',
#    '24',
#    'mp',
#    'ultra',
#    'wide',
#    'camera',
#    '8',
#    'mp',
#    'telephoto',
#    'camera',
#    '10',
#    'mp',
#    'depth',
#    'camera',
#    '5',
#    'mp',
#    'fourth',
#    'camera',
#    'รูรับแสงขนาด',
#    '1.7'],
#   ['กล้องหน้า', 'ความละเอียด', '24', 'mp'],
#   ['ram', '6', 'gb'],
#   ['หน่วยความจำตัวเครื่อง', '128', 'gb'],
#   ['แบรนด์', 'ซัมซุง'],
#   ['sku', '265390897', 'th', '412154584'],
#   ['ประเภทของการรับประกัน', 'มีการรับประกัน'],
#   ['model', 'galaxy', '9', '2018'],
#   ['ระยะเวลาการรับประกัน', '1', 'ปี'],
#   ['141']],
#  'category_0_6': [['โทรศัพท์มือถือและแท็บเล็ต'],
#   ['smartphones'],
#   ['samsung',
#    '30',
#    's',
#    'ram',
#    '4',
#    'gb',
#    'rom',
#    '64',
#    'gb',
#    'มือ',
#    '1',
#    'ประกันศูนย์',
#    '1',
#    'ปี'],
#   ['คุณสมบัติ', 'samsung', '30', 's'],
#   ['จอแสดงผล', 'super', 'amoled', '24', 'bit', '16', 'ล้านสี'],
#   ['6.4',
#    'นิ้ว',
#    'แนวทะแยง',
#    'ความละเอียด',
#    '720',
#    'x',
#    '1560',
#    'พิกเซล',
#    '268',
#    'ppi'],
#   ['ประเภทจอ', 'corning', 'gorilla', 'glass', '3', 'ระบบปฏิบัติการ'],
#   ['android',
#    '9.0',
#    'pie',
#    'หน่วยประมวลผล',
#    'exynos',
#    '7885',
#    'octa',
#    'core',
#    'ความเร็ว',
#    '1.8',
#    'mhz',
#    'หน่วยความจำ'],
#   ['ram', '4', 'gb', 'rom', '64', 'gb', 'การ์ดหน่วยความจำ'],
#   ['microsd', '1', 'tb'],
#   ['กล้องดิจิตอล',
#    '25',
#    'mp',
#    '8',
#    'mp',
#    'ultrawide',
#    '5',
#    'mp',
#    'depth',
#    'sensor',
#    'triple',
#    'camera',
#    'รูรับแสงขนาด',
#    '1.7',
#    'ไฟแฟลช',
#    'led',
#    'โหมดถ่ายภาพช่วงการรับแสงสูง',
#    'hdr'],
#   ['กล้องหน้า',
#    'front',
#    'camera',
#    'ความละเอียด',
#    '16',
#    'mp',
#    'รูรับแสงขนาด',
#    '2.0'],
#   ['ลำโพงเสียงสเตอริโอ',
#    'stereo',
#    'speakers',
#    'wifi',
#    '802.11',
#    'b',
#    'g',
#    'n',
#    'ac'],
#   ['จุดกระจายสัญญาณอินเตอร์เน็ตแบบพกพา', 'portable', 'wi', 'fi', 'hotspot'],
#   ['เชื่อมต่อไร้สายระหว่างอุปกรณ์โดยตรง',
#    'wi',
#    'fi',
#    'direct',
#    'bluetooth',
#    '5.0',
#    'type',
#    'c',
#    'usb',
#    '2.0',
#    'ช่องเสียบชุดหูฟัง',
#    '3.5',
#    'มิลลิเมตร'],
#   ['เครือข่าย',
#    'gsm',
#    '850',
#    '900',
#    '1800',
#    '1900',
#    'mhz',
#    'umts',
#    '850',
#    '900',
#    '2100',
#    'mhz',
#    'lte',
#    'bands',
#    '1',
#    '3',
#    '5',
#    '7',
#    '8',
#    '20',
#    '38',
#    '40',
#    '41',
#    'เทคโนโลยีการรับ',
#    'ส่งข้อมูล',
#    '2',
#    'g',
#    'edge',
#    'gprs',
#    '3',
#    'g',
#    '4',
#    'g'],
#   ['ใช้งาน', 'nano', 'sim', 'รองรับ', '2', 'ซิมการ์ด'],
#   ['ระบบเซ็นเซอร์',
#    'sensor',
#    'ระบบสแกนลายนิ้วมือใต้หน้าจอ',
#    'fingerprint',
#    'display',
#    'ตรวจจับความเคลื่อนไหวของตัวเครื่อง',
#    'accelerometer',
#    'ระบบเปิด',
#    'ปิดหน้าจออัตโนมัติขณะสนทนา',
#    'proximity'],
#   ['แบตเตอรี่', 'มาตรฐาน', 'li', 'pol', '4000', 'mah', 'standard', 'battery'],
#   ['มีสีให้เลือก', 'colors', 'ดำขาว', 'เขียว'],
#   ['แบรนด์', 'ซัมซุง'],
#   ['sku', '594352438', 'th', '1115888431'],
#   ['ประเภทของการรับประกัน', 'การรับประกันจากโรงงานในประเทศ'],
#   ['กล้องหน้า', 'เมกะพิกเซล', '16', 'mp'],
#   ['model', 'samsung', '30', 's'],
#   ['กล้องด้านหลัง', '21', 'mp', 'ขึ้นไป'],
#   ['ระยะเวลาการรับประกัน', '1', 'ปี'],
#   ['battery', 'capacity', '1000', 'mah', '5000', 'mah']],
#  'category_0_7': [['โทรศัพท์มือถือและแท็บเล็ต'],
#   ['smartphones'],
#   ['มือ',
#    '1',
#    'ศูนย์ไทย',
#    'samsung',
#    'galaxy',
#    'note',
#    '10',
#    'plus',
#    'note',
#    '10',
#    '12',
#    '256',
#    'gb',
#    'ประกัน',
#    '1',
#    'ปี'],
#   ['samsung',
#    'galaxy',
#    'note',
#    '10',
#    'plus',
#    'th',
#    'ประกันศูนย์ไทย',
#    '1',
#    'ปี',
#    'เข้าศูนย์ซัมซุงได้ทั่วประเทศ',
#    'มือ',
#    '1',
#    'เครื่องแท้',
#    '100'],
#   ['แบรนด์', 'ซัมซุง'],
#   ['sku', '599364278', 'th', '1176694583'],
#   ['ประเภทของการรับประกัน', 'มีการรับประกัน'],
#   ['ระบบปฏิบัติการ', 'เวอร์ชัน', 'android', '9.0', 'pie'],
#   ['model', 'samsung', 'galaxy', 'note', '10', 'plus'],
#   ['ขนาดหน้าจอ', 'นิ้ว', '6.8'],
#   ['ระยะเวลาการรับประกัน', '1', 'ปี'],
#   ['ช่องเสียบแบบบาง', 'เตียงเดี่ยว']],
#  'category_0_8': [['โทรศัพท์มือถือและแท็บเล็ต'],
#   ['smartphones'],
#   ['samsung', 'galaxy', '70', '8', '128', 'gb', 'โทรศัพท์มือถือ'],
#   ['galaxy', '70', 'sm', '705', 'fzbgthl'],
#   ['สเปคเทพของเกมเมอร์'],
#   ['หน้าจอกว้าง', '6.7', 'infinity', 'u', 'display'],
#   ['3', 'กล้อง', 'พร้อมเลนส์', 'ultra', 'wide'],
#   ['แบรนด์', 'ซัมซุง'],
#   ['sku', '309636084', 'th', '547152150'],
#   ['ประเภทของการรับประกัน', 'มีการรับประกัน'],
#   ['model', '70', '8', '128', 'gb'],
#   ['ระยะเวลาการรับประกัน', '1', 'ปี'],
#   ['249']],
#  'category_0_9': [['โทรศัพท์มือถือและแท็บเล็ต'],
#   ['smartphones'],
#   ['smartphone',
#    'โทรศัพท์มือถือ',
#    'samsung',
#    'galaxy',
#    '10',
#    's',
#    'sm',
#    '107',
#    'm',
#    'ขนาดหน้าจอ',
#    '6.2',
#    'นิ้ว',
#    'ram',
#    '2',
#    'rom',
#    '32',
#    'gb',
#    'สีน้ำเงิน'],
#   ['แบรนด์', 'ซัมซุง'],
#   ['sku', '571250946', 'th', '1048780375'],
#   ['มือถือ', 'smartphone'],
#   ['ระยะเวลาการรับประกัน', '1', 'เดือน'],
#   ['ประเภทของการรับประกัน', 'มีการรับประกันจากผู้ขาย'],
#   ['ประเภทของ', 'แบตเตอรี่', 'แบตเตอรี่', 'ชาร์จใหม่ได้และถอดได้'],
#   ['สภาพสินค้า'],
#   ['กล้องหน้า', 'เมกะพิกเซล', '7', 'mp', 'ขึ้นไป'],
#   ['model',
#    'smartphone',
#    'โทรศัพท์มือถือ',
#    'samsung',
#    'galaxy',
#    '10',
#    's',
#    'sm',
#    '107',
#    'm',
#    'ขนาดหน้าจอ',
#    '6.2',
#    'นิ้ว',
#    'ram',
#    '2',
#    'rom',
#    '32',
#    'gb',
#    'สีน้ำเงิน'],
#   ['ประเภทหน้าจอ', 'lcd'],
#   ['กล้องด้านหลัง', '11', '15', 'mp'],
#   ['ppi', '500', 'ppi'],
#   ['ความละเอียดวิดีโอ', '1080', 'p'],
#   ['resolution', 'full', 'hd'],
#   ['battery', 'capacity', '1000', 'mah', '5000', 'mah']]}

# %%
series = { key: pd.Series(val) for key, val in token.items() }

token2 = {}
for i,v in series.items():
    token2[i] = v.apply(pd.Series).stack()

# %%
pd.DataFrame.from_dict(token2, orient='index').transpose().reset_index().iloc[0:5]
# Out:
#    level_0  level_1               category_0_0               category_0_1  \
# 0        0        0  โทรศัพท์มือถือและแท็บเล็ต  โทรศัพท์มือถือและแท็บเล็ต
# 1        1        0                smartphones                smartphones
# 2        2        0                    samsung             โทรศัพท์มือถือ
# 3        2        1                     galaxy                    samsung
# 4        2        2                          m                     galaxy
#
#                 category_0_2               category_0_3  \
# 0  โทรศัพท์มือถือและแท็บเล็ต  โทรศัพท์มือถือและแท็บเล็ต
# 1                smartphones                smartphones
# 2                    samsung                    samsung
# 3                     galaxy                     galaxy
# 4                         10                       note
#
#                 category_0_4               category_0_5  \
# 0  โทรศัพท์มือถือและแท็บเล็ต  โทรศัพท์มือถือและแท็บเล็ต
# 1                smartphones                smartphones
# 2                    samsung                    samsung
# 3                     galaxy                     galaxy
# 4                          7                          9
#
#                 category_0_6               category_0_7  ...  \
# 0  โทรศัพท์มือถือและแท็บเล็ต  โทรศัพท์มือถือและแท็บเล็ต  ...
# 1                smartphones                smartphones  ...
# 2                    samsung                        มือ  ...
# 3                         30                          1  ...
# 4                          s                   ศูนย์ไทย  ...
#
#         category_33_234       category_33_235       category_33_236  \
# 0          สมาร์ทดีไวซ์          สมาร์ทดีไวซ์          สมาร์ทดีไวซ์
# 1              แก็ดเจ็ต              แก็ดเจ็ต              แก็ดเจ็ต
# 2  เครื่องเล่นเกมคอมโซล  เครื่องเล่นเกมคอมโซล  เครื่องเล่นเกมคอมโซล
# 3                   new                   new                   new
# 4                   NaN                   NaN                   NaN
#
#         category_33_237       category_33_238       category_33_239  \
# 0          สมาร์ทดีไวซ์          สมาร์ทดีไวซ์          สมาร์ทดีไวซ์
# 1              แก็ดเจ็ต              แก็ดเจ็ต              แก็ดเจ็ต
# 2  เครื่องเล่นเกมคอมโซล  เครื่องเล่นเกมคอมโซล  เครื่องเล่นเกมคอมโซล
# 3                   new                   new                   new
# 4                   NaN                   NaN                   NaN
#
#         category_33_240       category_33_241       category_33_242  \
# 0          สมาร์ทดีไวซ์          สมาร์ทดีไวซ์          สมาร์ทดีไวซ์
# 1              แก็ดเจ็ต              แก็ดเจ็ต              แก็ดเจ็ต
# 2  เครื่องเล่นเกมคอมโซล  เครื่องเล่นเกมคอมโซล  เครื่องเล่นเกมคอมโซล
# 3                   new                   new                   new
# 4                   NaN                   NaN                   NaN
#
#         category_33_243
# 0          สมาร์ทดีไวซ์
# 1              แก็ดเจ็ต
# 2  เครื่องเล่นเกมคอมโซล
# 3                   new
# 4                   NaN
#
# [5 rows x 5619 columns]

# %% [markdown]
# # Save data to csv file

# %%
# Transform dict to dataframe and save to csv file
pd.DataFrame.from_dict(token2, orient='index').transpose().reset_index().to_csv("./Data/{}_processed.csv".format(file_name))

# %%
pd.DataFrame.from_dict(dict_value, orient='index').transpose().to_csv("./Data/{}_value.csv".format(file_name))
