# %%
import csv
import pandas as pd
import nltk

from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer

from pythainlp.tokenize import Tokenizer
from pythainlp import word_tokenize
from pythainlp.corpus import thai_stopwords
from pythainlp.tokenize import dict_trie

from nltk.corpus import words
from stop_words import get_stop_words

# %% [markdown]
# # Load data

# %%
file_name = 'category1_data-clean-utf8'
df = pd.read_excel('./Data/{}.xlsx'.format(file_name), index_col=0).fillna('-').reset_index()

# %%
df.head()
# Out:
#    Column1  index category_0_0_label  \
# 0        0      0                cat
# 1        1      1                sub
# 2        2      2               name
# 3        3      3                  -
# 4        4      4               attr
#
#                                         category_0_0 category_0_1_label  \
# 0                          โทรศัพท์มือถือและแท็บเล็ต                cat
# 1                                        smartphones                sub
# 2         samsung galaxy m30s 4 64gb โทรศัพท์มือถือ                name
# 3  แบตอึดอยู่นาน สนุกได้ทั้งวัน กับความจุ 6000 ma...                  -
# 4  ระบบกล้องหลัง 3 ตัว ที่มีกล้องชัดสูงสุดถึง 48 ...                  -
#
#                                         category_0_1 category_0_2_label  \
# 0                          โทรศัพท์มือถือและแท็บเล็ต                cat
# 1                                        smartphones                sub
# 2  โทรศัพท์มือถือ samsung galaxy a50s ram4 64gb ร...               name
# 3                           gsm 850 900 1800 1900mhz                  -
# 4                      3g wcdma 850 900 1900 2100mhz               attr
#
#                                         category_0_2 category_0_3_label  \
# 0                          โทรศัพท์มือถือและแท็บเล็ต                cat
# 1                                        smartphones                sub
# 2                samsung galaxy a10s ram2gb rom32gb                name
# 3       สมาร์ทโฟน โทรศัพท์มือถือพร้อมระบบปฏิบัติการ                attr
# 4  จอแสดงผล tft lcd 24 bit 16 ล้านสี หน้าจอทรงหยด...               attr
#
#                                        category_0_3  ...  \
# 0                         โทรศัพท์มือถือและแท็บเล็ต  ...
# 1                                       smartphones  ...
# 2  samsung galaxy note 10 12 256 gb โทรศัพท์มือถือ   ...
# 3                               ขนาดหน้าจอ 6.8 นิ้ว  ...
# 4                                         ram 12 gb  ...
#
#                                       category_0_270  \
# 0                          โทรศัพท์มือถือและแท็บเล็ต
# 1                                        smartphones
# 2  new haixu v14 หน้าจอ 5.5 นิ้ว 2sim ram2 rom 16...
# 3                   หน้าจอ 5.5 นิ้ว 2sim ram2 rom 16
# 4                                        brand haixu
#
#                                       category_0_271  \
# 0   ซื้อ 1 แถม 1 ฟรี สำหรับ vivo v9 v11 v11i v7 y...
# 1  huawei nova 5t 128gb rom 8gb ram ฿ 5400.00 ฿ 1...
# 2          oppo a5 2020 ประกันศูนย์oppo1ปี ฿ 4690.00
# 3  apple 7 plus 8 plus โทรศัพท์มือถือ anti ลายนิ้...
# 4  เครื่องเกาหลี นำเข้า note9 ฿ 4299.00 ฿ 6999.00...
#
#                                       category_0_272  \
# 0                          โทรศัพท์มือถือและแท็บเล็ต
# 1                                        smartphones
# 2  ฟรีค่าส่งทั้งร้าน haixu star หน้าจอใหญ่ 5.5 นิ...
# 3                                 หน้าจอใหญ่ 5.5นิ้ว
# 4                                        brand haixu
#
#                                       category_0_273  \
# 0                          โทรศัพท์มือถือและแท็บเล็ต
# 1                                        smartphones
# 2  haixu star edit หน้าจอใหญ่ 5.5 นิ้ว 16gb รองรั...
# 3                                 หน้าจอใหญ่ 5.5นิ้ว
# 4                                        brand haixu
#
#                                       category_0_274  \
# 0                          โทรศัพท์มือถือและแท็บเล็ต
# 1                                        smartphones
# 2  haixu v11 หน้าจอใหญ่ 6.1 นิ้ว ram2 rom32gb สาม...
# 3                                         จอใหญ่ 6.1
# 4                                        brand haixu
#
#                                       category_0_275  \
# 0                          โทรศัพท์มือถือและแท็บเล็ต
# 1                                        smartphones
# 2  haixu star 16gb หน้าจอใหญ่ 5.5 battery 3200mah...
# 3                    รองรับ 3g 4g ทุกเครือข่าย 2sim
# 4                            หน้าจอใหญ่ 5.5 นิ้ว qhd
#
#                                       category_0_276  \
# 0                          โทรศัพท์มือถือและแท็บเล็ต
# 1                                        smartphones
# 2  haixu ram 2gb rom 16gb ชุดพิเศษ camera 13mp ถ่...
# 3  ชุดพิเศษ แถมหูฟังครอบหู มีไมค์ใมนตัวคุยได้ ฟิล...
# 4                  ram 2gb rom 16gb สเปคแท้ เร็ว แรง
#
#                                       category_0_277  \
# 0                          โทรศัพท์มือถือและแท็บเล็ต
# 1                                        smartphones
# 2  haixu 6.3 ram 2gb rom 32gb เครื่องศูนย์แท้ รับ...
# 3                   ram 2gb rom 32gb สเปคแท้ ไม่โกหก
# 4  หน้าจอใหญ่ จอ 6.3 นิ้ว สดใส ด้วยระบบ qhd คมชัด...
#
#                                       category_0_278  \
# 0                          โทรศัพท์มือถือและแท็บเล็ต
# 1                                        smartphones
# 2  haixu star edit หน้าจอใหญ่ 5.5 นิ้ว 16gb 2sim ...
# 3                                 หน้าจอใหญ่ 5.5นิ้ว
# 4                                        brand haixu
#
#                                       category_0_279
# 0                          โทรศัพท์มือถือและแท็บเล็ต
# 1                                        smartphones
# 2  haixu star หน้าจอใหญ่ 5.5 นิ้ว ความจำเครื่อง 1...
# 3                    รองรับ 3g 4g ทุกเครือข่าย 2sim
# 4                            หน้าจอใหญ่ 5.5 นิ้ว qhd
#
# [5 rows x 316 columns]

# %%
# Drop a column that not use
data = df.drop(columns='Column1')

# %%
data.head()
# Out:
#    index category_0_0_label  \
# 0      0                cat
# 1      1                sub
# 2      2               name
# 3      3                  -
# 4      4               attr
#
#                                         category_0_0 category_0_1_label  \
# 0                          โทรศัพท์มือถือและแท็บเล็ต                cat
# 1                                        smartphones                sub
# 2         samsung galaxy m30s 4 64gb โทรศัพท์มือถือ                name
# 3  แบตอึดอยู่นาน สนุกได้ทั้งวัน กับความจุ 6000 ma...                  -
# 4  ระบบกล้องหลัง 3 ตัว ที่มีกล้องชัดสูงสุดถึง 48 ...                  -
#
#                                         category_0_1 category_0_2_label  \
# 0                          โทรศัพท์มือถือและแท็บเล็ต                cat
# 1                                        smartphones                sub
# 2  โทรศัพท์มือถือ samsung galaxy a50s ram4 64gb ร...               name
# 3                           gsm 850 900 1800 1900mhz                  -
# 4                      3g wcdma 850 900 1900 2100mhz               attr
#
#                                         category_0_2 category_0_3_label  \
# 0                          โทรศัพท์มือถือและแท็บเล็ต                cat
# 1                                        smartphones                sub
# 2                samsung galaxy a10s ram2gb rom32gb                name
# 3       สมาร์ทโฟน โทรศัพท์มือถือพร้อมระบบปฏิบัติการ                attr
# 4  จอแสดงผล tft lcd 24 bit 16 ล้านสี หน้าจอทรงหยด...               attr
#
#                                        category_0_3 category_0_4_label  ...  \
# 0                         โทรศัพท์มือถือและแท็บเล็ต                cat  ...
# 1                                       smartphones                sub  ...
# 2  samsung galaxy note 10 12 256 gb โทรศัพท์มือถือ                name  ...
# 3                               ขนาดหน้าจอ 6.8 นิ้ว                  -  ...
# 4                                         ram 12 gb                  -  ...
#
#                                       category_0_270  \
# 0                          โทรศัพท์มือถือและแท็บเล็ต
# 1                                        smartphones
# 2  new haixu v14 หน้าจอ 5.5 นิ้ว 2sim ram2 rom 16...
# 3                   หน้าจอ 5.5 นิ้ว 2sim ram2 rom 16
# 4                                        brand haixu
#
#                                       category_0_271  \
# 0   ซื้อ 1 แถม 1 ฟรี สำหรับ vivo v9 v11 v11i v7 y...
# 1  huawei nova 5t 128gb rom 8gb ram ฿ 5400.00 ฿ 1...
# 2          oppo a5 2020 ประกันศูนย์oppo1ปี ฿ 4690.00
# 3  apple 7 plus 8 plus โทรศัพท์มือถือ anti ลายนิ้...
# 4  เครื่องเกาหลี นำเข้า note9 ฿ 4299.00 ฿ 6999.00...
#
#                                       category_0_272  \
# 0                          โทรศัพท์มือถือและแท็บเล็ต
# 1                                        smartphones
# 2  ฟรีค่าส่งทั้งร้าน haixu star หน้าจอใหญ่ 5.5 นิ...
# 3                                 หน้าจอใหญ่ 5.5นิ้ว
# 4                                        brand haixu
#
#                                       category_0_273  \
# 0                          โทรศัพท์มือถือและแท็บเล็ต
# 1                                        smartphones
# 2  haixu star edit หน้าจอใหญ่ 5.5 นิ้ว 16gb รองรั...
# 3                                 หน้าจอใหญ่ 5.5นิ้ว
# 4                                        brand haixu
#
#                                       category_0_274  \
# 0                          โทรศัพท์มือถือและแท็บเล็ต
# 1                                        smartphones
# 2  haixu v11 หน้าจอใหญ่ 6.1 นิ้ว ram2 rom32gb สาม...
# 3                                         จอใหญ่ 6.1
# 4                                        brand haixu
#
#                                       category_0_275  \
# 0                          โทรศัพท์มือถือและแท็บเล็ต
# 1                                        smartphones
# 2  haixu star 16gb หน้าจอใหญ่ 5.5 battery 3200mah...
# 3                    รองรับ 3g 4g ทุกเครือข่าย 2sim
# 4                            หน้าจอใหญ่ 5.5 นิ้ว qhd
#
#                                       category_0_276  \
# 0                          โทรศัพท์มือถือและแท็บเล็ต
# 1                                        smartphones
# 2  haixu ram 2gb rom 16gb ชุดพิเศษ camera 13mp ถ่...
# 3  ชุดพิเศษ แถมหูฟังครอบหู มีไมค์ใมนตัวคุยได้ ฟิล...
# 4                  ram 2gb rom 16gb สเปคแท้ เร็ว แรง
#
#                                       category_0_277  \
# 0                          โทรศัพท์มือถือและแท็บเล็ต
# 1                                        smartphones
# 2  haixu 6.3 ram 2gb rom 32gb เครื่องศูนย์แท้ รับ...
# 3                   ram 2gb rom 32gb สเปคแท้ ไม่โกหก
# 4  หน้าจอใหญ่ จอ 6.3 นิ้ว สดใส ด้วยระบบ qhd คมชัด...
#
#                                       category_0_278  \
# 0                          โทรศัพท์มือถือและแท็บเล็ต
# 1                                        smartphones
# 2  haixu star edit หน้าจอใหญ่ 5.5 นิ้ว 16gb 2sim ...
# 3                                 หน้าจอใหญ่ 5.5นิ้ว
# 4                                        brand haixu
#
#                                       category_0_279
# 0                          โทรศัพท์มือถือและแท็บเล็ต
# 1                                        smartphones
# 2  haixu star หน้าจอใหญ่ 5.5 นิ้ว ความจำเครื่อง 1...
# 3                    รองรับ 3g 4g ทุกเครือข่าย 2sim
# 4                            หน้าจอใหญ่ 5.5 นิ้ว qhd
#
# [5 rows x 315 columns]

# %%
label = data.filter(regex='label$', axis=1)

# %%
label.head()
# Out:
#   category_0_0_label category_0_1_label category_0_2_label category_0_3_label  \
# 0                cat                cat                cat                cat
# 1                sub                sub                sub                sub
# 2               name               name               name               name
# 3                  -                  -                  -               attr
# 4               attr                  -               attr               attr
#
#   category_0_4_label category_0_5_label category_0_6_label category_0_7_label  \
# 0                cat                cat                cat                cat
# 1                sub                sub                sub                sub
# 2               name               name               name               name
# 3                  -               attr                  -                  -
# 4                  -                  -               attr               attr
#
#   category_0_8_label category_0_9_label  ... category_0_24_label  \
# 0                cat                cat  ...                 cat
# 1                sub                sub  ...                 sub
# 2               name               name  ...                name
# 3                  -               attr  ...                attr
# 4                  -                sku  ...                   -
#
#   category_0_25_label category_0_26_label category_0_27_label  \
# 0                 cat                 cat                 cat
# 1                 sub                 sub                 sub
# 2                name                name                name
# 3                attr                   -                   -
# 4                attr                   -                attr
#
#   category_0_28_label category_0_29_label category_0_30_label  \
# 0                 cat                 cat                 cat
# 1                 sub                 sub                 sub
# 2                name                name                name
# 3                   -                attr                attr
# 4                   -                attr                attr
#
#   category_0_31_label category_0_32_label category_0_33_label
# 0                 cat                   -                 cat
# 1                 sub                   -                 sub
# 2                name                   -                name
# 3                   -                   -                   -
# 4                   -                   -                   -
#
# [5 rows x 34 columns]

# %%
x = data.filter(regex='[0-9]$', axis=1)

# %%
x.head()
# Out:
#                                         category_0_0  \
# 0                          โทรศัพท์มือถือและแท็บเล็ต
# 1                                        smartphones
# 2         samsung galaxy m30s 4 64gb โทรศัพท์มือถือ
# 3  แบตอึดอยู่นาน สนุกได้ทั้งวัน กับความจุ 6000 ma...
# 4  ระบบกล้องหลัง 3 ตัว ที่มีกล้องชัดสูงสุดถึง 48 ...
#
#                                         category_0_1  \
# 0                          โทรศัพท์มือถือและแท็บเล็ต
# 1                                        smartphones
# 2  โทรศัพท์มือถือ samsung galaxy a50s ram4 64gb ร...
# 3                           gsm 850 900 1800 1900mhz
# 4                      3g wcdma 850 900 1900 2100mhz
#
#                                         category_0_2  \
# 0                          โทรศัพท์มือถือและแท็บเล็ต
# 1                                        smartphones
# 2                samsung galaxy a10s ram2gb rom32gb
# 3       สมาร์ทโฟน โทรศัพท์มือถือพร้อมระบบปฏิบัติการ
# 4  จอแสดงผล tft lcd 24 bit 16 ล้านสี หน้าจอทรงหยด...
#
#                                        category_0_3  \
# 0                         โทรศัพท์มือถือและแท็บเล็ต
# 1                                       smartphones
# 2  samsung galaxy note 10 12 256 gb โทรศัพท์มือถือ
# 3                               ขนาดหน้าจอ 6.8 นิ้ว
# 4                                         ram 12 gb
#
#                                         category_0_4  \
# 0                          โทรศัพท์มือถือและแท็บเล็ต
# 1                                        smartphones
# 2                            samsung galaxy a7 2017
# 3  ระบบเซ็นเซอร์ sensor ระบบตรวจสอบลายนิ้วมือ fin...
# 4    คุณสมบัติการกันน้ำ waterproof กันน้ำได้ชั่วคราว
#
#                                         category_0_5  \
# 0                          โทรศัพท์มือถือและแท็บเล็ต
# 1                                        smartphones
# 2  samsung galaxy a9 2018 6 gb ram 128 gb rom 6.3...
# 3  จอแสดงผล super amoled 24 bit 16 ล้านสี fullvie...
# 4  ระบบตรวจสอบลายนิ้วมือ fingerprint ระบบจดจำใบหน...
#
#                                         category_0_6  \
# 0                          โทรศัพท์มือถือและแท็บเล็ต
# 1                                        smartphones
# 2  samsung a30s ram 4gb rom 64 gb มือ 1 ประกันศูน...
# 3                             คุณสมบัติ samsung a30s
# 4            จอแสดงผล super amoled 24 bit 16 ล้านสี
#
#                                         category_0_7  \
# 0                          โทรศัพท์มือถือและแท็บเล็ต
# 1                                        smartphones
# 2   มือ1 ศูนย์ไทย samsung galaxy note 10 plus not...
# 3  samsung galaxy note10 plus th ประกันศูนย์ไทย 1...
# 4                                       brand ซัมซุง
#
#                                  category_0_8  \
# 0                   โทรศัพท์มือถือและแท็บเล็ต
# 1                                 smartphones
# 2  samsung galaxy a70 8 128gb โทรศัพท์มือถือ
# 3                  galaxy a70 sm a705fzbgthl
# 4                          สเปคเทพของเกมเมอร์
#
#                                         category_0_9  ...  \
# 0                          โทรศัพท์มือถือและแท็บเล็ต  ...
# 1                                        smartphones  ...
# 2  smartphone โทรศัพท์มือถือ samsung galaxy a10s ...  ...
# 3                                       brand ซัมซุง  ...
# 4                        sku 571250946 th 1048780375  ...
#
#                                       category_0_270  \
# 0                          โทรศัพท์มือถือและแท็บเล็ต
# 1                                        smartphones
# 2  new haixu v14 หน้าจอ 5.5 นิ้ว 2sim ram2 rom 16...
# 3                   หน้าจอ 5.5 นิ้ว 2sim ram2 rom 16
# 4                                        brand haixu
#
#                                       category_0_271  \
# 0   ซื้อ 1 แถม 1 ฟรี สำหรับ vivo v9 v11 v11i v7 y...
# 1  huawei nova 5t 128gb rom 8gb ram ฿ 5400.00 ฿ 1...
# 2          oppo a5 2020 ประกันศูนย์oppo1ปี ฿ 4690.00
# 3  apple 7 plus 8 plus โทรศัพท์มือถือ anti ลายนิ้...
# 4  เครื่องเกาหลี นำเข้า note9 ฿ 4299.00 ฿ 6999.00...
#
#                                       category_0_272  \
# 0                          โทรศัพท์มือถือและแท็บเล็ต
# 1                                        smartphones
# 2  ฟรีค่าส่งทั้งร้าน haixu star หน้าจอใหญ่ 5.5 นิ...
# 3                                 หน้าจอใหญ่ 5.5นิ้ว
# 4                                        brand haixu
#
#                                       category_0_273  \
# 0                          โทรศัพท์มือถือและแท็บเล็ต
# 1                                        smartphones
# 2  haixu star edit หน้าจอใหญ่ 5.5 นิ้ว 16gb รองรั...
# 3                                 หน้าจอใหญ่ 5.5นิ้ว
# 4                                        brand haixu
#
#                                       category_0_274  \
# 0                          โทรศัพท์มือถือและแท็บเล็ต
# 1                                        smartphones
# 2  haixu v11 หน้าจอใหญ่ 6.1 นิ้ว ram2 rom32gb สาม...
# 3                                         จอใหญ่ 6.1
# 4                                        brand haixu
#
#                                       category_0_275  \
# 0                          โทรศัพท์มือถือและแท็บเล็ต
# 1                                        smartphones
# 2  haixu star 16gb หน้าจอใหญ่ 5.5 battery 3200mah...
# 3                    รองรับ 3g 4g ทุกเครือข่าย 2sim
# 4                            หน้าจอใหญ่ 5.5 นิ้ว qhd
#
#                                       category_0_276  \
# 0                          โทรศัพท์มือถือและแท็บเล็ต
# 1                                        smartphones
# 2  haixu ram 2gb rom 16gb ชุดพิเศษ camera 13mp ถ่...
# 3  ชุดพิเศษ แถมหูฟังครอบหู มีไมค์ใมนตัวคุยได้ ฟิล...
# 4                  ram 2gb rom 16gb สเปคแท้ เร็ว แรง
#
#                                       category_0_277  \
# 0                          โทรศัพท์มือถือและแท็บเล็ต
# 1                                        smartphones
# 2  haixu 6.3 ram 2gb rom 32gb เครื่องศูนย์แท้ รับ...
# 3                   ram 2gb rom 32gb สเปคแท้ ไม่โกหก
# 4  หน้าจอใหญ่ จอ 6.3 นิ้ว สดใส ด้วยระบบ qhd คมชัด...
#
#                                       category_0_278  \
# 0                          โทรศัพท์มือถือและแท็บเล็ต
# 1                                        smartphones
# 2  haixu star edit หน้าจอใหญ่ 5.5 นิ้ว 16gb 2sim ...
# 3                                 หน้าจอใหญ่ 5.5นิ้ว
# 4                                        brand haixu
#
#                                       category_0_279
# 0                          โทรศัพท์มือถือและแท็บเล็ต
# 1                                        smartphones
# 2  haixu star หน้าจอใหญ่ 5.5 นิ้ว ความจำเครื่อง 1...
# 3                    รองรับ 3g 4g ทุกเครือข่าย 2sim
# 4                            หน้าจอใหญ่ 5.5 นิ้ว qhd
#
# [5 rows x 280 columns]

# %%
x_train = x.iloc[:,0:34]

# %%
x_train.head()
# Out:
#                                         category_0_0  \
# 0                          โทรศัพท์มือถือและแท็บเล็ต
# 1                                        smartphones
# 2         samsung galaxy m30s 4 64gb โทรศัพท์มือถือ
# 3  แบตอึดอยู่นาน สนุกได้ทั้งวัน กับความจุ 6000 ma...
# 4  ระบบกล้องหลัง 3 ตัว ที่มีกล้องชัดสูงสุดถึง 48 ...
#
#                                         category_0_1  \
# 0                          โทรศัพท์มือถือและแท็บเล็ต
# 1                                        smartphones
# 2  โทรศัพท์มือถือ samsung galaxy a50s ram4 64gb ร...
# 3                           gsm 850 900 1800 1900mhz
# 4                      3g wcdma 850 900 1900 2100mhz
#
#                                         category_0_2  \
# 0                          โทรศัพท์มือถือและแท็บเล็ต
# 1                                        smartphones
# 2                samsung galaxy a10s ram2gb rom32gb
# 3       สมาร์ทโฟน โทรศัพท์มือถือพร้อมระบบปฏิบัติการ
# 4  จอแสดงผล tft lcd 24 bit 16 ล้านสี หน้าจอทรงหยด...
#
#                                        category_0_3  \
# 0                         โทรศัพท์มือถือและแท็บเล็ต
# 1                                       smartphones
# 2  samsung galaxy note 10 12 256 gb โทรศัพท์มือถือ
# 3                               ขนาดหน้าจอ 6.8 นิ้ว
# 4                                         ram 12 gb
#
#                                         category_0_4  \
# 0                          โทรศัพท์มือถือและแท็บเล็ต
# 1                                        smartphones
# 2                            samsung galaxy a7 2017
# 3  ระบบเซ็นเซอร์ sensor ระบบตรวจสอบลายนิ้วมือ fin...
# 4    คุณสมบัติการกันน้ำ waterproof กันน้ำได้ชั่วคราว
#
#                                         category_0_5  \
# 0                          โทรศัพท์มือถือและแท็บเล็ต
# 1                                        smartphones
# 2  samsung galaxy a9 2018 6 gb ram 128 gb rom 6.3...
# 3  จอแสดงผล super amoled 24 bit 16 ล้านสี fullvie...
# 4  ระบบตรวจสอบลายนิ้วมือ fingerprint ระบบจดจำใบหน...
#
#                                         category_0_6  \
# 0                          โทรศัพท์มือถือและแท็บเล็ต
# 1                                        smartphones
# 2  samsung a30s ram 4gb rom 64 gb มือ 1 ประกันศูน...
# 3                             คุณสมบัติ samsung a30s
# 4            จอแสดงผล super amoled 24 bit 16 ล้านสี
#
#                                         category_0_7  \
# 0                          โทรศัพท์มือถือและแท็บเล็ต
# 1                                        smartphones
# 2   มือ1 ศูนย์ไทย samsung galaxy note 10 plus not...
# 3  samsung galaxy note10 plus th ประกันศูนย์ไทย 1...
# 4                                       brand ซัมซุง
#
#                                  category_0_8  \
# 0                   โทรศัพท์มือถือและแท็บเล็ต
# 1                                 smartphones
# 2  samsung galaxy a70 8 128gb โทรศัพท์มือถือ
# 3                  galaxy a70 sm a705fzbgthl
# 4                          สเปคเทพของเกมเมอร์
#
#                                         category_0_9  ...  \
# 0                          โทรศัพท์มือถือและแท็บเล็ต  ...
# 1                                        smartphones  ...
# 2  smartphone โทรศัพท์มือถือ samsung galaxy a10s ...  ...
# 3                                       brand ซัมซุง  ...
# 4                        sku 571250946 th 1048780375  ...
#
#                                        category_0_24  \
# 0                          โทรศัพท์มือถือและแท็บเล็ต
# 1                                        smartphones
# 2  samsung galaxy a9 2018 6 128gb เครื่องศูนย์ เค...
# 3  จอแสดงผล super amoled 24 bit 16 ล้านสี fullvie...
# 4  ระบบตรวจสอบลายนิ้วมือ fingerprint ระบบจดจำใบหน...
#
#                                        category_0_25  \
# 0                          โทรศัพท์มือถือและแท็บเล็ต
# 1                                        smartphones
# 2      samsung a70 ram8 128 เครื่องศูนย์เคลียร์สต๊อค
# 3  จอแสดงผล super amoled 24 bit 16 ล้านสี หน้าจอท...
# 4                                       brand ซัมซุง
#
#                                 category_0_26  \
# 0                   โทรศัพท์มือถือและแท็บเล็ต
# 1                                 smartphones
# 2                    samsung galaxy a6 4 32gb
# 3       จอคุณภาพสูงfull front display samoled
# 4  กล้องหน้า และ หลังความละเอียดเท่ากัน 16 mp
#
#                                        category_0_27  \
# 0                          โทรศัพท์มือถือและแท็บเล็ต
# 1                                        smartphones
# 2     samsung galaxy a50s 128gb 6gb ram original set
# 3  samsung galaxy a50s 128gb 6gb ram original set...
# 4                                       brand ซัมซุง
#
#                                      category_0_28  \
# 0                        โทรศัพท์มือถือและแท็บเล็ต
# 1                                      smartphones
# 2       samsung galaxy a20s 3 32gb โทรศัพท์มือถือ
# 3                                      galaxy a20s
# 4  สนุกทุกประสบการณ์กับหน้าจอใหญ่ที่เต็มตากว่าเดิม
#
#                                      category_0_29  \
# 0                        โทรศัพท์มือถือและแท็บเล็ต
# 1                                      smartphones
# 2            refurbish samsung galaxy a8 2018 gold
# 3  หน้าจอใหญ่ super amoled 5.6 นิ้ว สัดส่วน 18.5 9
# 4             ชิพเซต exynos 7885 octa core 2.2 ghz
#
#                                        category_0_30  \
# 0                          โทรศัพท์มือถือและแท็บเล็ต
# 1                                        smartphones
# 2  samsung galaxy s10 8 gb ram 128 gb rom 6.4 นิ้...
# 3  หน้าจอ 6.4 นิ้ว ความละเอียด 3040x1440 quad hd ...
# 4  กล้องหลัง 3 ตัว 16 mp f 2.2 ultra wide 12 mp f...
#
#                                        category_0_31  \
# 0                          โทรศัพท์มือถือและแท็บเล็ต
# 1                                        smartphones
# 2  samsung j8 ram3 32gb เครื่องศูนย์ประกันมีเดือน...
# 3  ระบบปฏิบัติการ os cpu ระบบปฏิบัติการ android 8...
# 4  หน่วยประมวลผล qualco มม. snapdragon 450 octa core
#
#                                        category_0_32  \
# 0  xiaomi redmi note 8 3gb 32gb สมาร์ตโฟน 4 กล้อง...
# 1  เครื่องเกาหลี นำเข้า note9 ฿ 4299.00 ฿ 6999.00...
# 2  samsung wireless battery pack 10000 mah พาวเวอ...
# 3  samsung galaxy note 9 snapdragon845 ram6 rom12...
# 4  samsung galaxy note10 ram8gb rom256gb aura pin...
#
#                        category_0_33
# 0          โทรศัพท์มือถือและแท็บเล็ต
# 1                        smartphones
# 2  samsung galaxy note 10 plus 512gb
# 3                          brand new
# 4                           original
#
# [5 rows x 34 columns]

# %% [markdown]
# # Tokenize

# %%
# download stopwords of TH and EN
nltk.download('words')
th_stop = tuple(thai_stopwords())
en_stop = tuple(get_stop_words('en'))

# path of custom dictionary for word tokenize
PATH_TO_CUSTOM_DICT = './Data/custom_dict.txt'

# split text to words 
def split_word(text):
    
    # Split text to words
    _tokenizer = Tokenizer(custom_dict=PATH_TO_CUSTOM_DICT, engine='newmm')
    words = _tokenizer.word_tokenize(text)

    # Remove stop words in TH and EN
    words = [i for i in words if not i in th_stop and not i in en_stop]
    
    # Delete whitespace
    words = [i for i in words if not ' ' in i]

    return words
# Out:
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\super\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!

# %%
token = {}
for key,value in x_train.items():
    tmp = [split_word(txt) for txt in value if not txt == '-']
    token[key] = tmp

# %%
token
# Out:
# {'category_0_0': [['โทรศัพท์มือถือและแท็บเล็ต'],
#   ['smartphones'],
#   ['samsung', 'galaxy', 'm', '30', 's', '4', '64', 'gb', 'โทรศัพท์มือถือ'],
#   ['แบต',
#    'อึดอยู่นาน',
#    'สนุกได้ทั้งวัน',
#    'กับความจุ',
#    '6000',
#    'mah',
#    'และสามารถชาร์จ',
#    'แบต',
#    'fast',
#    'charging'],
#   ['ระบบ',
#    'กล้องหลัง',
#    '3',
#    'ตัว',
#    'ที่มีกล้องชัดสูงสุดถึง',
#    '48',
#    'mp',
#    'มาพร้อมกับเลนส์มุมกว้างพิเศษ',
#    'ultra',
#    'wide'],
#   ['exynos',
#    '9611',
#    'สเป็กแรงขึ้นเล่นเกมส์ได้ไม่มีสะดุด',
#    'ram',
#    '4',
#    'gb',
#    'rom',
#    '64',
#    'gb'],
#   ['หน้าจอแสดงผล', 'super', 'amoled', 'infinity', 'u', 'ขนาด', '6.4', 'นิ้ว'],
#   ['brand', 'ซัมซุง'],
#   ['sku', '480942616', 'th', '870640886'],
#   ['ประเภทของการรับประกัน', 'มีการรับประกัน'],
#   ['model', 'galaxy', 'm', '30', 's', '4', '64', 'gb'],
#   ['ระยะเวลาการรับประกัน', '1', 'ปี'],
#   ['793']],
#  'category_0_1': [['โทรศัพท์มือถือและแท็บเล็ต'],
#   ['smartphones'],
#   ['โทรศัพท์มือถือ',
#    'samsung',
#    'galaxy',
#    '50',
#    's',
#    'ram',
#    '4',
#    '64',
#    'gb',
#    'รับประกันศูนย์',
#    'jaymart'],
#   ['gsm', '850', '900', '1800', '1900', 'mhz'],
#   ['3', 'g', 'wcdma', '850', '900', '1900', '2100', 'mhz'],
#   ['4',
#    'g',
#    'fdd',
#    'lte',
#    'b',
#    '1',
#    '2100',
#    'b',
#    '3',
#    '1800',
#    'b',
#    '5',
#    '850',
#    'b',
#    '7',
#    '2600',
#    'b',
#    '8',
#    '900',
#    'b',
#    '20',
#    '800',
#    'b',
#    '28',
#    '700'],
#   ['4',
#    'g',
#    'tdd',
#    'lte',
#    'b',
#    '38',
#    '2600',
#    'b',
#    '40',
#    '2300',
#    'b',
#    '41',
#    '2500'],
#   ['รองรับ', '2', 'ซิม', 'nano', 'sim'],
#   ['หน่วยประมวลผล',
#    'exynos',
#    '9610',
#    'quad',
#    '2.3',
#    'ghz',
#    'quad',
#    '1.7',
#    'ghz'],
#   ['ระบบปฏิบัติการ', 'android'],
#   ['หน่วยความจำภายใน', '64', 'gb', 'micro', 'sd', 'รองรับ', '512', 'gb'],
#   ['ram', '4', 'gb'],
#   ['หน้าจอ',
#    '6.4',
#    'นิ้ว',
#    'ความละเอียด',
#    '1080',
#    'x',
#    '2340',
#    'พิกเซล',
#    'fhd'],
#   ['กล้องหลัง',
#    '3',
#    'เลนส์',
#    '48',
#    'ล้านพิกเซล',
#    'f',
#    '2.0',
#    '5',
#    'ล้านพิกเซล',
#    'f',
#    '2.2',
#    'bokeh',
#    '8',
#    'ล้านพิกเซล',
#    'f',
#    '2.4',
#    'ultrawide',
#    'แฟลช',
#    'led'],
#   ['กล้องหน้า', '32', 'ล้านพิกเซล', 'f', '2.0'],
#   ['wifi', '802.11', 'b', 'g', 'n', 'ac'],
#   ['bluetooth', '5.0'],
#   ['แบตเตอรี่', '4000', 'mah'],
#   ['ขนาด', '158.5', 'x', '74.5', 'x', '7.7', 'มม.'],
#   ['น้ำหนัก', '169', 'g'],
#   ['brand', 'ซัมซุง'],
#   ['sku', '593772364', 'th', '1113954823'],
#   ['ระยะเวลาการรับประกัน', '1', 'ปี'],
#   ['ประเภทของการรับประกัน', 'การรับประกันจากโรงงานในประเทศ'],
#   ['กล้องหน้า', 'เมกะพิกเซล', '7', 'mp', 'ขึ้นไป'],
#   ['ระบบปฏิบัติการ', 'เวอร์ชัน', 'android', '9.0', 'pie'],
#   ['model', '50', 's'],
#   ['หน่วยความจำ', 'ram', '512', 'mb', 'และน้อยกว่า'],
#   ['ขนาดหน้าจอ', 'นิ้ว', '6.4'],
#   ['กล้องด้านหลัง', '21', 'mp', 'ขึ้นไป'],
#   ['ความจุ', 'แบตเตอรี่', '1000', 'mah', '5000', 'mah'],
#   ['ช่องเสียบแบบบาง', 'คู่']],
#  'category_0_2': [['โทรศัพท์มือถือและแท็บเล็ต'],
#   ['smartphones'],
#   ['samsung', 'galaxy', '10', 's', 'ram', '2', 'gb', 'rom', '32', 'gb'],
#   ['สมาร์ทโฟน', 'โทรศัพท์มือถือพร้อม', 'ระบบปฏิบัติการ'],
#   ['จอแสดงผล',
#    'tft',
#    'lcd',
#    '24',
#    'bit',
#    '16',
#    'ล้านสี',
#    'หน้าจอทรงหยดน้ำ',
#    'รูปตัว',
#    'v',
#    'infinity',
#    'v',
#    '6.2',
#    'นิ้ว',
#    'แนวทะแยง',
#    'ความละเอียด',
#    '1520',
#    'x',
#    '720',
#    'พิกเซล'],
#   ['ระบบเซ็นเซอร์',
#    'sensor',
#    'ระบบตรวจสอบลายนิ้วมือ',
#    'fingerprint',
#    'ระบบหมุนภาพอัตโนมัติ',
#    'accelerometer',
#    'ระบบเซนเซอร์หมุนภาพ',
#    'gyroscope'],
#   ['มีสีให้เลือก', 'colors', 'black', 'red', 'green', 'blue'],
#   ['brand', 'ซัมซุง'],
#   ['sku', '404422189', 'th', '784670279'],
#   ['มือถือ', 'smartphone'],
#   ['ระยะเวลาการรับประกัน', '1', 'ปี'],
#   ['ระบบปฏิบัติการ', 'android', '9.0', 'pie'],
#   ['ประเภทของการรับประกัน', 'มีการรับประกัน'],
#   ['กล้องหน้า', 'เมกะพิกเซล', '7', 'mp', 'ขึ้นไป'],
#   ['ระบบปฏิบัติการ', 'เวอร์ชัน', 'android', '9.0', 'pie'],
#   ['model',
#    'samsung',
#    'galaxy',
#    '10',
#    's',
#    'ram',
#    '2',
#    'gb',
#    'rom',
#    '32',
#    'gb'],
#   ['หน่วยความจำ', 'ram', '2', 'gb'],
#   ['ขนาดหน้าจอ', 'นิ้ว', '6.2'],
#   ['กล้องด้านหลัง', '11', '15', 'mp'],
#   ['ความจุ', 'แบตเตอรี่', '1000', 'mah', '5000', 'mah'],
#   ['ช่องเสียบแบบบาง', 'เตียงเดี่ยว'],
#   ['143']],
#  'category_0_3': [['โทรศัพท์มือถือและแท็บเล็ต'],
#   ['smartphones'],
#   ['samsung', 'galaxy', 'note', '10', '12', '256', 'gb', 'โทรศัพท์มือถือ'],
#   ['ขนาดหน้าจอ', '6.8', 'นิ้ว'],
#   ['ram', '12', 'gb'],
#   ['ความจุ', 'storage', '256', 'gb'],
#   ['แบตเตอรี่', '4300', 'mah', 'typical'],
#   ['มาตรฐานการกันน้ำและกันฝุ่น', 'ip', '68'],
#   ['brand', 'ซัมซุง'],
#   ['sku', '385536916', 'th', '749070165'],
#   ['ประเภทของการรับประกัน', 'มีการรับประกัน'],
#   ['model', 'galaxy', 'note', '10'],
#   ['ขนาดหน้าจอ', 'นิ้ว', '6.8'],
#   ['ระยะเวลาการรับประกัน', '1', 'ปี'],
#   ['243']],
#  'category_0_4': [['โทรศัพท์มือถือและแท็บเล็ต'],
#   ['smartphones'],
#   ['samsung', 'galaxy', '7', '2017'],
#   ['ระบบเซ็นเซอร์',
#    'sensor',
#    'ระบบตรวจสอบลายนิ้วมือ',
#    'fingerprint',
#    'ระบบหมุนภาพอัตโนมัติ',
#    'accelerometer',
#    'ระบบเปิด',
#    'ปิดหน้าจออัตโนมัติขณะสนทนา',
#    'proximity',
#    'ระบบตรวจจับคลื่นแม่เหล็ก',
#    'geomagnetic',
#    'ระบบเซนเซอร์หมุนภาพ',
#    'gyroscope',
#    'ระบบวัดความกดอากาศ',
#    'barometer'],
#   ['คุณสมบัติการกันน้ำ', 'waterproof', 'กันน้ำได้ชั่วคราว'],
#   ['มีสีให้เลือก', 'colors', 'black', 'pink', 'gold', 'bluelight'],
#   ['เทคโนโลยีการรับ',
#    'ส่งข้อมูล',
#    '2',
#    'g',
#    'edge',
#    'gprs',
#    '3',
#    'g',
#    'hspa',
#    '4',
#    'g',
#    'lte',
#    'dl',
#    'lte',
#    'ul'],
#   ['ใช้งาน', 'nano', 'sim'],
#   ['รองรับ', '2', 'ซิมการ์ด'],
#   ['ระบบปฏิบัติการ', 'android', '6.0.1', 'marshmallow'],
#   ['หน่วยประมวลผล', 'octa', 'core', 'ความเร็ว', '1.9', 'ghz'],
#   ['หน่วยความจำ', '32', 'gb', 'ตัวเครื่อง', 'ram', '3', 'gb'],
#   ['การ์ดหน่วยความจำ'],
#   ['microsd'],
#   ['การหาตำแหน่ง', 'assisted', 'gps'],
#   ['wifi',
#    '802.11',
#    'b',
#    'g',
#    'n',
#    'ac',
#    'จุดกระจายสัญญาณอินเตอร์เน็ตแบบพกพา',
#    'portable',
#    'wi',
#    'fi',
#    'hotspot',
#    'เชื่อมต่อไร้สายระหว่างอุปกรณ์โดยตรง',
#    'wi',
#    'fi',
#    'direct'],
#   ['bluetooth',
#    '4.2',
#    'รองรับ',
#    'ชุดหูฟังสเตอริโอ',
#    '2',
#    'dp',
#    'bluetooth',
#    'stereo'],
#   ['รองรับ', 'nfc', 'near', 'field', 'co', 'มม.', 'unication'],
#   ['ant'],
#   ['usb', 'type', 'c'],
#   ['ช่องเสียบชุดหูฟัง', '3.', 'มม.'],
#   ['โซเชียลเน็ตเวิร์คแอพฯ', 'facebook', 'twitter'],
#   ['กล้องดิจิตอล',
#    '16',
#    'ล้านพิกเซล',
#    'digital',
#    'camera',
#    'รูรับแสงขนาด',
#    '1.9',
#    'ไฟแฟลช',
#    'led',
#    'โฟกัสอัตโนมัติ',
#    'auto',
#    'focus',
#    'แตะเลือกจุดโฟกัส',
#    'touch',
#    'focus',
#    'ค้นหาใบหน้าอัตโนมัติ',
#    'face',
#    'detection',
#    'โหมดถ่ายภาพพาโนราม่า',
#    'panorama'],
#   ['โหมดถ่ายภาพช่วงการรับแสงสูง', 'hdr'],
#   ['กล้องหน้า',
#    'front',
#    'camera',
#    'ความละเอียด',
#    '16',
#    'mp',
#    'รูรับแสงขนาด',
#    '1.9'],
#   ['บันทึกวีดีโอ',
#    'ภาพเคลื่อนไหว',
#    'video',
#    'recording',
#    'รูปแบบไฟล์วีดีโอ',
#    'mpeg',
#    '4'],
#   ['เครื่องเล่นวีดีโอ',
#    'video',
#    'player',
#    'รูปแบบไฟล์',
#    'mpeg',
#    '4',
#    'wmv',
#    'h',
#    '.',
#    '264',
#    'h',
#    '.',
#    '263',
#    'รองรับ',
#    'วีดีโอจาก',
#    'youtube'],
#   ['เครื่องเล่นเพลง',
#    'music',
#    'player',
#    'รูปแบบไฟล์',
#    'amr',
#    'nb',
#    'aac',
#    'lc',
#    'aac',
#    'eaac',
#    'mp',
#    '3',
#    'wma',
#    'flac'],
#   ['sms', 'มม.', 's'],
#   ['ข้อความแชท', 'skype'],
#   ['สนับสนุน', 'gmail', 'google', 'search'],
#   ['ไมโครโฟนสำหรับตัดเสียงรบกวนการสนทนา'],
#   ['ออร์กาไนเซอร์', 'ปฏิทิน', 'เครื่องคิดเลข', 'นาฬิกาปลุก', 'จดบันทึก'],
#   ['ริงโทน', 'mp', '3', 'ระบบสั่น', 'vibration', 'phone']],
#  'category_0_5': [['โทรศัพท์มือถือและแท็บเล็ต'],
#   ['smartphones'],
#   ['samsung',
#    'galaxy',
#    '9',
#    '2018',
#    '6',
#    'gb',
#    'ram',
#    '128',
#    'gb',
#    'rom',
#    '6.3',
#    'นิ้ว',
#    '5',
#    'กล้อง',
#    '24',
#    'mp',
#    'tetra',
#    'cell',
#    'f',
#    '1.7',
#    'โทรศัพท์มือถือ'],
#   ['จอแสดงผล',
#    'super',
#    'amoled',
#    '24',
#    'bit',
#    '16',
#    'ล้านสี',
#    'fullview',
#    'display',
#    '6.3',
#    'นิ้ว'],
#   ['ระบบตรวจสอบลายนิ้วมือ',
#    'fingerprint',
#    'ระบบจดจำใบหน้า',
#    'face',
#    'detection'],
#   ['กล้องดิจิตอล',
#    'main',
#    'camera',
#    '24',
#    'mp',
#    'ultra',
#    'wide',
#    'camera',
#    '8',
#    'mp',
#    'telephoto',
#    'camera',
#    '10',
#    'mp',
#    'depth',
#    'camera',
#    '5',
#    'mp',
#    'fourth',
#    'camera',
#    'รูรับแสงขนาด',
#    '1.7'],
#   ['กล้องหน้า', 'ความละเอียด', '24', 'mp'],
#   ['ram', '6', 'gb'],
#   ['หน่วยความจำตัวเครื่อง', '128', 'gb'],
#   ['brand', 'ซัมซุง'],
#   ['sku', '265390897', 'th', '412154584'],
#   ['ประเภทของการรับประกัน', 'มีการรับประกัน'],
#   ['model', 'galaxy', '9', '2018'],
#   ['ระยะเวลาการรับประกัน', '1', 'ปี'],
#   ['141']],
#  'category_0_6': [['โทรศัพท์มือถือและแท็บเล็ต'],
#   ['smartphones'],
#   ['samsung',
#    '30',
#    's',
#    'ram',
#    '4',
#    'gb',
#    'rom',
#    '64',
#    'gb',
#    'มือ',
#    '1',
#    'ประกันศูนย์',
#    '1',
#    'ปี'],
#   ['คุณสมบัติ', 'samsung', '30', 's'],
#   ['จอแสดงผล', 'super', 'amoled', '24', 'bit', '16', 'ล้านสี'],
#   ['6.4',
#    'นิ้ว',
#    'แนวทะแยง',
#    'ความละเอียด',
#    '720',
#    'x',
#    '1560',
#    'พิกเซล',
#    '268',
#    'ppi'],
#   ['ประเภทจอ', 'corning', 'gorilla', 'glass', '3', 'ระบบปฏิบัติการ'],
#   ['android',
#    '9.0',
#    'pie',
#    'หน่วยประมวลผล',
#    'exynos',
#    '7885',
#    'octa',
#    'core',
#    'ความเร็ว',
#    '1.8',
#    'mhz',
#    'หน่วยความจำ'],
#   ['ram', '4', 'gb', 'rom', '64', 'gb', 'การ์ดหน่วยความจำ'],
#   ['microsd', '1', 'tb'],
#   ['กล้องดิจิตอล',
#    '25',
#    'mp',
#    '8',
#    'mp',
#    'ultrawide',
#    '5',
#    'mp',
#    'depth',
#    'sensor',
#    'triple',
#    'camera',
#    'รูรับแสงขนาด',
#    '1.7',
#    'ไฟแฟลช',
#    'led',
#    'โหมดถ่ายภาพช่วงการรับแสงสูง',
#    'hdr'],
#   ['กล้องหน้า',
#    'front',
#    'camera',
#    'ความละเอียด',
#    '16',
#    'mp',
#    'รูรับแสงขนาด',
#    '2.0'],
#   ['ลำโพงเสียงสเตอริโอ',
#    'stereo',
#    'speakers',
#    'wifi',
#    '802.11',
#    'b',
#    'g',
#    'n',
#    'ac'],
#   ['จุดกระจายสัญญาณอินเตอร์เน็ตแบบพกพา', 'portable', 'wi', 'fi', 'hotspot'],
#   ['เชื่อมต่อไร้สายระหว่างอุปกรณ์โดยตรง',
#    'wi',
#    'fi',
#    'direct',
#    'bluetooth',
#    '5.0',
#    'type',
#    'c',
#    'usb',
#    '2.0',
#    'ช่องเสียบชุดหูฟัง',
#    '3.',
#    'มม.'],
#   ['เครือข่าย',
#    'gsm',
#    '850',
#    '900',
#    '1800',
#    '1900',
#    'mhz',
#    'umts',
#    '850',
#    '900',
#    '2100',
#    'mhz',
#    'lte',
#    'bands',
#    '1',
#    '3',
#    '5',
#    '7',
#    '8',
#    '20',
#    '38',
#    '40',
#    '41',
#    'เทคโนโลยีการรับ',
#    'ส่งข้อมูล',
#    '2',
#    'g',
#    'edge',
#    'gprs',
#    '3',
#    'g',
#    '4',
#    'g'],
#   ['ใช้งาน', 'nano', 'sim', 'รองรับ', '2', 'ซิมการ์ด'],
#   ['ระบบเซ็นเซอร์',
#    'sensor',
#    'ระบบสแกนลายนิ้วมือใต้หน้าจอ',
#    'fingerprint',
#    'display',
#    'ตรวจจับความเคลื่อนไหวของตัวเครื่อง',
#    'accelerometer',
#    'ระบบเปิด',
#    'ปิดหน้าจออัตโนมัติขณะสนทนา',
#    'proximity'],
#   ['แบตเตอรี่', 'มาตรฐาน', 'li', 'pol', '4000', 'mah', 'standard', 'battery'],
#   ['มีสีให้เลือก', 'colors', 'ดำขาว', 'เขียว'],
#   ['brand', 'ซัมซุง'],
#   ['sku', '594352438', 'th', '1115888431'],
#   ['ประเภทของการรับประกัน', 'การรับประกันจากโรงงานในประเทศ'],
#   ['กล้องหน้า', 'เมกะพิกเซล', '16', 'mp'],
#   ['model', 'samsung', '30', 's'],
#   ['กล้องด้านหลัง', '21', 'mp', 'ขึ้นไป'],
#   ['ระยะเวลาการรับประกัน', '1', 'ปี'],
#   ['ความจุ', 'แบตเตอรี่', '1000', 'mah', '5000', 'mah']],
#  'category_0_7': [['โทรศัพท์มือถือและแท็บเล็ต'],
#   ['smartphones'],
#   ['มือ',
#    '1',
#    'ศูนย์ไทย',
#    'samsung',
#    'galaxy',
#    'note',
#    '10',
#    'plus',
#    'note',
#    '10',
#    '12',
#    '256',
#    'gb',
#    'ประกัน',
#    '1',
#    'ปี'],
#   ['samsung',
#    'galaxy',
#    'note',
#    '10',
#    'plus',
#    'th',
#    'ประกันศูนย์ไทย',
#    '1',
#    'ปี',
#    'เข้าศูนย์ซัมซุงได้ทั่วประเทศ',
#    'มือ',
#    '1',
#    'เครื่องแท้',
#    '100',
#    'เปอร์เซนต์'],
#   ['brand', 'ซัมซุง'],
#   ['sku', '599364278', 'th', '1176694583'],
#   ['ประเภทของการรับประกัน', 'มีการรับประกัน'],
#   ['ระบบปฏิบัติการ', 'เวอร์ชัน', 'android', '9.0', 'pie'],
#   ['model', 'samsung', 'galaxy', 'note', '10', 'plus'],
#   ['ขนาดหน้าจอ', 'นิ้ว', '6.8'],
#   ['ระยะเวลาการรับประกัน', '1', 'ปี'],
#   ['ช่องเสียบแบบบาง', 'เตียงเดี่ยว']],
#  'category_0_8': [['โทรศัพท์มือถือและแท็บเล็ต'],
#   ['smartphones'],
#   ['samsung', 'galaxy', '70', '8', '128', 'gb', 'โทรศัพท์มือถือ'],
#   ['galaxy', '70', 'sm', '705', 'fzbgthl'],
#   ['สเปคเทพของเกมเมอร์'],
#   ['หน้าจอกว้าง', '6.7', 'infinity', 'u', 'display'],
#   ['3', 'กล้อง', 'พร้อมเลนส์', 'ultra', 'wide'],
#   ['brand', 'ซัมซุง'],
#   ['sku', '309636084', 'th', '547152150'],
#   ['ประเภทของการรับประกัน', 'มีการรับประกัน'],
#   ['model', '70', '8', '128', 'gb'],
#   ['ระยะเวลาการรับประกัน', '1', 'ปี'],
#   ['249']],
#  'category_0_9': [['โทรศัพท์มือถือและแท็บเล็ต'],
#   ['smartphones'],
#   ['smartphone',
#    'โทรศัพท์มือถือ',
#    'samsung',
#    'galaxy',
#    '10',
#    's',
#    'sm',
#    '107',
#    'm',
#    'ขนาดหน้าจอ',
#    '6.2',
#    'นิ้ว',
#    'ram',
#    '2',
#    'rom',
#    '32',
#    'gb',
#    'สีน้ำเงิน'],
#   ['brand', 'ซัมซุง'],
#   ['sku', '571250946', 'th', '1048780375'],
#   ['มือถือ', 'smartphone'],
#   ['ระยะเวลาการรับประกัน', '1', 'เดือน'],
#   ['ประเภทของการรับประกัน', 'มีการรับประกันจากผู้ขาย'],
#   ['ประเภทของ', 'แบตเตอรี่', 'แบตเตอรี่', 'ชาร์จใหม่ได้และถอดได้'],
#   ['สภาพสินค้า'],
#   ['กล้องหน้า', 'เมกะพิกเซล', '7', 'mp', 'ขึ้นไป'],
#   ['model',
#    'smartphone',
#    'โทรศัพท์มือถือ',
#    'samsung',
#    'galaxy',
#    '10',
#    's',
#    'sm',
#    '107',
#    'm',
#    'ขนาดหน้าจอ',
#    '6.2',
#    'นิ้ว',
#    'ram',
#    '2',
#    'rom',
#    '32',
#    'gb',
#    'สีน้ำเงิน'],
#   ['ประเภทหน้าจอ', 'lcd'],
#   ['กล้องด้านหลัง', '11', '15', 'mp'],
#   ['ppi', '500', 'ppi'],
#   ['ความละเอียดวิดีโอ', '1080', 'p'],
#   ['resolution', 'full', 'hd'],
#   ['ความจุ', 'แบตเตอรี่', '1000', 'mah', '5000', 'mah']],
#  'category_0_10': [['โทรศัพท์มือถือและแท็บเล็ต'],
#   ['smartphones'],
#   ['samsung', 'galaxy', '5', '2017'],
#   ['สมาร์ทโฟน', 'โทรศัพท์มือถือพร้อม', 'ระบบปฏิบัติการ'],
#   ['จอแสดงผล',
#    'super',
#    'amoled',
#    '24',
#    'bit',
#    '16',
#    'ล้านสี',
#    '5.2',
#    'นิ้ว',
#    'แนวทะแยง',
#    'ความละเอียด',
#    '1080',
#    'x',
#    '1920',
#    'พิกเซล',
#    'ประเภทจอ',
#    'หน้าจอกระจกแข็ง',
#    'ประเภทจอ',
#    'ระบบป้องกัน',
#    'ฝุ่นละออง',
#    'resistance',
#    'dust'],
#   ['ระบบเซ็นเซอร์',
#    'sensor',
#    'ระบบตรวจสอบลายนิ้วมือ',
#    'fingerprint',
#    'ระบบหมุนภาพอัตโนมัติ',
#    'accelerometer',
#    'ระบบเปิด',
#    'ปิดหน้าจออัตโนมัติขณะสนทนา',
#    'proximity',
#    'ระบบตรวจจับคลื่นแม่เหล็ก',
#    'geomagnetic',
#    'ระบบเซนเซอร์หมุนภาพ',
#    'gyroscope',
#    'ระบบวัดความกดอากาศ',
#    'barometer'],
#   ['คุณสมบัติการกันน้ำ', 'waterproof', 'กันน้ำได้ชั่วคราว'],
#   ['มีสีให้เลือก', 'colors', 'black', 'pink', 'gold', 'bluelight'],
#   ['เทคโนโลยีการรับ',
#    'ส่งข้อมูล',
#    '2',
#    'g',
#    'edge',
#    'gprs',
#    '3',
#    'g',
#    'hspa',
#    '4',
#    'g',
#    'lte',
#    'dl',
#    'lte',
#    'ul'],
#   ['ใช้งาน', 'nano', 'sim'],
#   ['รองรับ', '2', 'ซิมการ์ด'],
#   ['ระบบปฏิบัติการ', 'android', '6.0.1', 'marshmallow'],
#   ['หน่วยประมวลผล', 'octa', 'core', 'ความเร็ว', '1.9', 'ghz'],
#   ['หน่วยความจำ', '32', 'gb', 'ตัวเครื่อง', 'ram', '3', 'gb'],
#   ['การ์ดหน่วยความจำ'],
#   ['microsd', '256', 'gb'],
#   ['การหาตำแหน่ง', 'assisted', 'gps'],
#   ['wifi',
#    '802.11',
#    'b',
#    'g',
#    'n',
#    'ac',
#    'จุดกระจายสัญญาณอินเตอร์เน็ตแบบพกพา',
#    'portable',
#    'wi',
#    'fi',
#    'hotspot',
#    'เชื่อมต่อไร้สายระหว่างอุปกรณ์โดยตรง',
#    'wi',
#    'fi',
#    'direct'],
#   ['bluetooth',
#    '4.2',
#    'รองรับ',
#    'ชุดหูฟังสเตอริโอ',
#    '2',
#    'dp',
#    'bluetooth',
#    'stereo'],
#   ['รองรับ', 'nfc', 'near', 'field', 'co', 'มม.', 'unication'],
#   ['ant'],
#   ['usb', 'type', 'c'],
#   ['ช่องเสียบชุดหูฟัง', '3.', 'มม.'],
#   ['โซเชียลเน็ตเวิร์คแอพฯ', 'facebook', 'twitter'],
#   ['กล้องดิจิตอล',
#    '16',
#    'ล้านพิกเซล',
#    'digital',
#    'camera',
#    'รูรับแสงขนาด',
#    '1.9',
#    'ไฟแฟลช',
#    'led',
#    'โฟกัสอัตโนมัติ',
#    'auto',
#    'focus',
#    'แตะเลือกจุดโฟกัส',
#    'touch',
#    'focus',
#    'โหมดถ่ายภาพพาโนราม่า',
#    'panorama'],
#   ['โหมดถ่ายภาพช่วงการรับแสงสูง', 'hdr'],
#   ['กล้องหน้า',
#    'front',
#    'camera',
#    'ความละเอียด',
#    '16',
#    'mp',
#    'รูรับแสงขนาด',
#    '1.9'],
#   ['บันทึกวีดีโอ',
#    'ภาพเคลื่อนไหว',
#    'video',
#    'recording',
#    'รูปแบบไฟล์วีดีโอ',
#    'mpeg',
#    '4'],
#   ['เครื่องเล่นวีดีโอ',
#    'video',
#    'player',
#    'รูปแบบไฟล์',
#    'mpeg',
#    '4',
#    'wmv',
#    'h',
#    '.',
#    '264',
#    'h',
#    '.',
#    '263',
#    'รองรับ',
#    'วีดีโอจาก',
#    'youtube'],
#   ['เครื่องเล่นเพลง',
#    'music',
#    'player',
#    'รูปแบบไฟล์',
#    'amr',
#    'nb',
#    'aac',
#    'lc',
#    'aac',
#    'eaac',
#    'mp',
#    '3',
#    'wma',
#    'flac'],
#   ['sms', 'มม.', 's'],
#   ['ข้อความแชท', 'skype'],
#   ['สนับสนุน', 'gmail', 'google', 'search'],
#   ['ออร์กาไนเซอร์', 'ปฏิทิน', 'เครื่องคิดเลข', 'นาฬิกาปลุก', 'จดบันทึก']],
#  'category_0_11': [['โทรศัพท์มือถือและแท็บเล็ต'],
#   ['smartphones'],
#   ['samsung', 'galaxy', '5', '2017', 'gold'],
#   ['หน้าจอแสดงผลแบบ', 'super', 'amoled', 'ขนาด', '5.2', 'นิ้ว'],
#   ['ความละเอียดระดับ',
#    'full',
#    'hd',
#    '1080',
#    'p',
#    '1080',
#    'x',
#    '1920',
#    'พิกเซล'],
#   ['หน่วยความจำ', 'ram', 'ram', 'ขนาด', '3', 'gb'],
#   ['หน่วยความจำภายในขนาด', '32', 'gb'],
#   ['กล้องด้านหลังความละเอียด', '16', 'ล้านพิกเซล'],
#   ['brand', 'ซัมซุง'],
#   ['sku', 'sa', '861', 'elaa', '8', 'nxs', '2', 'anth', '17866375'],
#   ['ระยะเวลาการรับประกัน', '1', 'ปี'],
#   ['ระบบปฏิบัติการ', 'android'],
#   ['ประเภทของการรับประกัน', 'การรับประกันจากโรงงานในประเทศ'],
#   ['สภาพสินค้า'],
#   ['กล้องหน้า', 'เมกะพิกเซล', '7', 'mp', 'ขึ้นไป'],
#   ['ระบบปฏิบัติการ', 'เวอร์ชัน', 'marshmallow'],
#   ['model', 'samsung', 'galaxy', '5', '2017', 'gold'],
#   ['หน่วยความจำ', 'ram', '3', 'gb'],
#   ['ประเภทหน้าจอ', 'amoled'],
#   ['ขนาดหน้าจอ', 'นิ้ว', '5.2'],
#   ['กล้องด้านหลัง', '16', '20', 'mp']],
#  'category_0_12': [['โทรศัพท์มือถือและแท็บเล็ต'],
#   ['smartphones'],
#   ['samsung', 'galaxy', 's', '10', 'e', '6', '128', 'gb', 'โทรศัพท์มือถือ'],
#   ['galaxy', 's', '10', 'e'],
#   ['หน้าจอความละเอียดสูงระดับ',
#    'dynamic',
#    'amoled',
#    'ให้สีสันและความคมชัดเสมือนจอทีวีระดับพรีเมี่ยม'],
#   ['กล้องหลัง', '2', 'ตัวพร้อมระบบถ่ายภาพอัจฉริยะ'],
#   ['brand', 'ซัมซุง'],
#   ['sku', '526004055', 'th', '942110374'],
#   ['ประเภทของการรับประกัน', 'มีการรับประกัน'],
#   ['model', 's', '10', 'e', '6', '128', 'gb'],
#   ['ระยะเวลาการรับประกัน', '1', 'ปี']],
#  'category_0_13': [['โทรศัพท์มือถือและแท็บเล็ต'],
#   ['smartphones'],
#   ['smartphone',
#    'โทรศัพท์มือถือ',
#    'samsung',
#    'galaxy',
#    '10',
#    's',
#    'sm',
#    '107',
#    'm',
#    'ขนาดหน้าจอ',
#    '6.2',
#    'นิ้ว',
#    'ram',
#    '2',
#    'rom',
#    '32',
#    'gb',
#    'สีเขียว'],
#   ['brand', 'ซัมซุง'],
#   ['sku', '571320012', 'th', '1048806072'],
#   ['มือถือ', 'smartphone'],
#   ['ระยะเวลาการรับประกัน', '1', 'เดือน'],
#   ['ประเภทของการรับประกัน', 'มีการรับประกันจากผู้ขาย'],
#   ['ประเภทของ', 'แบตเตอรี่', 'แบตเตอรี่', 'ชาร์จใหม่ได้และถอดได้'],
#   ['สภาพสินค้า'],
#   ['กล้องหน้า', 'เมกะพิกเซล', '7', 'mp', 'ขึ้นไป'],
#   ['model',
#    'smartphone',
#    'โทรศัพท์มือถือ',
#    'samsung',
#    'galaxy',
#    '10',
#    's',
#    'sm',
#    '107',
#    'm',
#    'ขนาดหน้าจอ',
#    '6.2',
#    'นิ้ว',
#    'ram',
#    '2',
#    'rom',
#    '32',
#    'gb',
#    'สีเขียว'],
#   ['ประเภทหน้าจอ', 'lcd'],
#   ['กล้องด้านหลัง', '11', '15', 'mp'],
#   ['ppi', '500', 'ppi'],
#   ['ความละเอียดวิดีโอ', '1080', 'p'],
#   ['resolution', 'full', 'hd'],
#   ['ความจุ', 'แบตเตอรี่', '1000', 'mah', '5000', 'mah']],
#  'category_0_14': [['โทรศัพท์มือถือและแท็บเล็ต'],
#   ['smartphones'],
#   ['samsung',
#    '10',
#    's',
#    'ram',
#    '2',
#    'gb',
#    'rom',
#    '32',
#    'gr',
#    'มือ',
#    '1',
#    'ประกันศูนย์',
#    '1',
#    'ปี'],
#   ['ขนาดเครื่อง',
#    '156.9',
#    'x',
#    '75.8',
#    'x',
#    '7.8',
#    'มม.',
#    'หนัก',
#    '168',
#    'กรัม',
#    'หน้าจอ',
#    'pls',
#    'tft',
#    'lcd',
#    'ความละเอียด',
#    '720',
#    'x',
#    '1520',
#    'พิกเซล',
#    'hd',
#    'ขนาด',
#    '6.2',
#    'นิ้ว'],
#   ['ชิปเซต',
#    'mediatek',
#    'mt',
#    '6762',
#    'helio',
#    'p',
#    '22',
#    'ประมวลผล',
#    'octa',
#    'core',
#    '2.0',
#    'ghz',
#    'cortex',
#    '53',
#    'gpu',
#    'powervr',
#    'ge',
#    '8320'],
#   ['หน่วยความจำ',
#    'ram',
#    '2',
#    'gb',
#    'rom',
#    '32',
#    'gb',
#    'รองรับ',
#    'หน่วยความจำเสริม',
#    'microsd',
#    'card',
#    '512',
#    'gb'],
#   ['กล้องหลัง',
#    'เลนส์คู่',
#    'กล้องหลัก',
#    '13',
#    'ล้านพิกเซล',
#    'รูรับแสง',
#    'f',
#    '1.8',
#    'มีระบบออโต้โฟกัส'],
#   ['กล้อง', 'depth', 'sensor', '2', 'ล้านพิกเซล', 'รูรับแสง', 'f', '2.4'],
#   ['รองรับ', 'การบันทึกวีดีโอสูงสุด', 'fhd', '1920', 'x', '1080', '30', 'fps'],
#   ['กล้องหน้า',
#    '8',
#    'ล้านพิกเซล',
#    'รูรับแสง',
#    'f',
#    '2.0',
#    'รองรับ',
#    'การทำงานสองซิม'],
#   ['สัญญานเครือข่ายที่',
#    'รองรับ',
#    '2',
#    'g',
#    'gsm',
#    '3',
#    'g',
#    'wcdma',
#    '4',
#    'g',
#    'lte',
#    'fdd',
#    '4',
#    'g',
#    'lte',
#    'tdd'],
#   ['รองรับ',
#    'wi',
#    'fi',
#    '802.11',
#    'b',
#    'g',
#    'n',
#    '2.4',
#    'ghz',
#    'wi',
#    'fi',
#    'direct',
#    'สนับสนุน',
#    'bluetooth',
#    '4.2'],
#   ['เทคโนโลยีระบุพิกัด', 'gps', 'glonass', 'galileo'],
#   ['มีสแกนลายนิ้วมือ', 'และปลดล็อคด้วยใบหน้า'],
#   ['แบตเตอรี่', 'ขนาด', '4000', 'mah'],
#   ['ระบบปฏิบัติการ', 'android', '9', 'pie', 'oneui'],
#   ['สีที่จำหน่ายในไทย', 'เขียว', 'ดำ', 'แดง'],
#   ['ราคาเปิดตัว', '4490', 'บาท'],
#   ['brand', 'ซัมซุง'],
#   ['sku', '594306208', 'th', '1115720937'],
#   ['ประเภทของการรับประกัน', 'การรับประกันจากโรงงานในประเทศ'],
#   ['กล้องหน้า', 'เมกะพิกเซล', '7', 'mp', 'ขึ้นไป'],
#   ['model', 'samsung', '10', 's'],
#   ['กล้องด้านหลัง', '11', '15', 'mp'],
#   ['ระยะเวลาการรับประกัน', '1', 'ปี'],
#   ['ความจุ', 'แบตเตอรี่', '1000', 'mah', '5000', 'mah']],
#  'category_0_15': [['samsung',
#    'galaxy',
#    '30',
#    '4',
#    'gb',
#    'ram',
#    '64',
#    'gb',
#    'rom',
#    '6.4',
#    'นิ้ว',
#    '3',
#    'กล้อง',
#    '16',
#    'mp',
#    'ff',
#    'f',
#    '2.0',
#    'โทรศัพท์มือถือ',
#    '฿',
#    '5990.00',
#    '฿',
#    '7290.00',
#    '18',
#    'เปอร์เซนต์'],
#   ['ซื้อ',
#    '1',
#    'แถม',
#    '1',
#    'ฟรี',
#    'สำหรับ',
#    'vivo',
#    'v',
#    '9',
#    'v',
#    '11',
#    'v',
#    '11',
#    'v',
#    '7',
#    'y',
#    '15',
#    'pro',
#    'y',
#    '12',
#    'หลายรุ่น',
#    'non',
#    'slip',
#    'soft',
#    '3',
#    'd',
#    'คาร์บอนไฟเบอร์ฝาหลังฟิล์มป้องกันด้านหลังสติกเกอร์ป้องกัน',
#    '฿',
#    '55.00',
#    '฿',
#    '92.00',
#    '40',
#    'เปอร์เซนต์'],
#   ['samsung',
#    'galaxy',
#    'tab',
#    's',
#    '6',
#    '6',
#    'gb',
#    '128',
#    'gb',
#    'แท็บเล็ต',
#    '฿',
#    '23900.00',
#    '฿',
#    '25900.00',
#    '8',
#    'เปอร์เซนต์'],
#   ['samsung',
#    'galaxy',
#    'watch',
#    'active',
#    'สมาร์ทวอทช์',
#    'smart',
#    'watch',
#    '฿',
#    '5890.00',
#    '฿',
#    '8900.00',
#    '34',
#    'เปอร์เซนต์'],
#   ['samsung',
#    'galaxy',
#    'note',
#    '10',
#    'leather',
#    'cover',
#    'เคสโทรศัพท์',
#    '฿',
#    '1490.00',
#    '฿',
#    '1590.00',
#    '6',
#    'เปอร์เซนต์'],
#   ['samsung',
#    'galaxy',
#    'note',
#    '10',
#    'plus',
#    '256',
#    'gb',
#    'snap',
#    '855',
#    '฿',
#    '27100.00',
#    '฿',
#    '37900.00',
#    '28',
#    'เปอร์เซนต์'],
#   ['3',
#    'g',
#    '4',
#    'g',
#    'เสาอากาศภายนอก',
#    'cpe',
#    'ไวไฟเราเตอร์พร้อมกับซิมการ์ด',
#    'lte',
#    'fdd',
#    'เราเตอร์ไร้สาย',
#    'lan',
#    'wan',
#    'wi',
#    'fi',
#    'ฮอตสปอตโมเด็ม',
#    '฿',
#    '1499.00',
#    '฿',
#    '2930.00',
#    '49',
#    'เปอร์เซนต์'],
#   ['samsung',
#    'galaxy',
#    '50',
#    'ram',
#    '6',
#    'rom',
#    '128',
#    '฿',
#    '7450.00',
#    '฿',
#    '11490.00',
#    '35',
#    'เปอร์เซนต์'],
#   ['apple',
#    'iphone',
#    '7',
#    '32',
#    'gb',
#    'โทรศัพท์',
#    'second',
#    'hand',
#    'สภาพใหม่',
#    '90',
#    'เปอร์เซนต์',
#    'ไม่ผ่านการซ่อมบำรุง',
#    '฿',
#    '5199.00',
#    '฿',
#    '9999.00',
#    '48',
#    'เปอร์เซนต์'],
#   ['samsung',
#    'galaxy',
#    'buds',
#    'หูฟัง',
#    'บลูทูธ',
#    'หูฟังไร้สาย',
#    '฿',
#    '4199.00',
#    '฿',
#    '4990.00',
#    '16',
#    'เปอร์เซนต์'],
#   ['apple',
#    'ipad',
#    '10.2',
#    'inch',
#    'wi',
#    'fi',
#    'ipad',
#    '7',
#    'th',
#    'gen',
#    '2019',
#    '฿',
#    '10500.00',
#    '฿',
#    '10900.00',
#    '4',
#    'เปอร์เซนต์'],
#   ['samsung',
#    'galaxy',
#    'fit',
#    'e',
#    'สมาร์ทวอทช์',
#    'smart',
#    'watch',
#    '฿',
#    '1080.00',
#    '฿',
#    '1290.00',
#    '16',
#    'เปอร์เซนต์']],
#  'category_0_16': [['โทรศัพท์มือถือและแท็บเล็ต'],
#   ['smartphones'],
#   ['samsung',
#    'galaxy',
#    's',
#    '10',
#    '8',
#    'gb',
#    'ram',
#    '128',
#    'gb',
#    'rom',
#    '6.1',
#    'นิ้ว',
#    '4',
#    'กล้อง',
#    '16',
#    'mp',
#    'ff',
#    'f',
#    '2.2',
#    'โทรศัพท์มือถือ'],
#   ['หน้าจอ',
#    '6.1',
#    'นิ้ว',
#    'ความละเอียด',
#    '3040',
#    'x',
#    '1440',
#    'quad',
#    'hd',
#    '550',
#    'ppi'],
#   ['กล้องหลัง',
#    '3',
#    'ตัว',
#    '16',
#    'mp',
#    'f',
#    '2.2',
#    'ultra',
#    'wide',
#    '12',
#    'mp',
#    'f',
#    '1.5',
#    '2.4',
#    'wide',
#    '12',
#    'mp',
#    'f',
#    '2.4',
#    'tele'],
#   ['กล้องหน้า', '10', 'mp', 'f', '1.9'],
#   ['หน่วยประมวลผล',
#    'octa',
#    'core',
#    'snapdragon',
#    '855',
#    'octa',
#    'core',
#    'exynos',
#    '9',
#    '9820'],
#   ['ram', '8', '128', 'gb'],
#   ['แบตเตอรี่', '3400', 'mah', 'typical'],
#   ['brand', 'ซัมซุง'],
#   ['sku', '289434461', 'th', '479544867'],
#   ['ประเภทของการรับประกัน', 'มีการรับประกัน'],
#   ['model', 's', '10', '128', 'gb'],
#   ['ระยะเวลาการรับประกัน', '1', 'ปี']],
#  'category_0_17': [['โทรศัพท์มือถือและแท็บเล็ต'],
#   ['smartphones'],
#   ['samsung',
#    '20',
#    's',
#    'ram',
#    '3',
#    'gb',
#    'rom',
#    '32',
#    'gb',
#    'มือ',
#    '1',
#    'ประกันศูนย์',
#    '1',
#    'ปี'],
#   ['คุณสมบัติ', 'samsung', '20', 's'],
#   ['ขนาด',
#    'น้ำหนัก',
#    '163.3',
#    '77.5',
#    'หนา',
#    '8',
#    'มม.',
#    'น้ำหนัก',
#    '183',
#    'กรัม'],
#   ['จอภาพ',
#    'ชนิดจอ',
#    'จอสัมผัส',
#    'tft',
#    'ขนาด',
#    'ความละเอียด',
#    '6.5',
#    'นิ้ว',
#    '264',
#    'ppi',
#    '720',
#    '1560',
#    'px'],
#   ['หน้าจอ',
#    'tft',
#    'infinity',
#    'u',
#    'display',
#    'ขนาด',
#    '6.5',
#    'นิ้ว',
#    'ความละเอียด',
#    'hd',
#    '720',
#    'x',
#    '1560',
#    'พิกเซล',
#    'อัตราส่วนหน้าจอ',
#    '19.5',
#    '9'],
#   ['หน่วยประมวลผล',
#    'cpu',
#    'snapdragon',
#    '450',
#    'หน่วยประมวลผล',
#    'gpu',
#    'adreno',
#    '506'],
#   ['หน่วยความจำ',
#    'ram',
#    '3',
#    'gb',
#    'rom',
#    '32',
#    'gb',
#    'micro',
#    'sd',
#    '512',
#    'gb',
#    'รองรับ',
#    '2',
#    'ซิมการ์ด',
#    'รองรับ',
#    'การเพิ่มความจำด้วย',
#    'microsd',
#    'card',
#    '512',
#    'gb'],
#   ['กล้องหลัง', '3', 'ตัว', 'ประกอบด้วย'],
#   ['เลนส์หลัก',
#    'ความละเอียด',
#    '13',
#    'mp',
#    'f',
#    '1.8',
#    'เลนส์',
#    'ultra',
#    'wide',
#    '120',
#    'องศา',
#    'ความละเอียด',
#    '8',
#    'mp',
#    'f',
#    '2.2',
#    'เลนส์',
#    'depth',
#    'ความละเอียด',
#    '5',
#    'mp',
#    'f',
#    '2.2'],
#   ['กล้องหน้า', 'ความละเอียด', '8', 'mp', 'f', '2.0'],
#   ['รองรับ',
#    'ระบบเสียง',
#    'dolby',
#    'atmos',
#    'เซ็นเซอร์',
#    'accelerometer',
#    'fingerprint',
#    'sensor',
#    'gyro',
#    'sensor',
#    'geomagnetic',
#    'sensor',
#    'light',
#    'sensor',
#    'proximity',
#    'sensor',
#    'การเชื่อมต่อ',
#    'bluetooth',
#    '4.2',
#    'wi',
#    'fi',
#    '802.11',
#    'b',
#    'g',
#    'n',
#    '2.4',
#    'ghz',
#    '3.5',
#    'มม.',
#    'earjack',
#    'usb',
#    'type',
#    'c',
#    'wi',
#    'fi',
#    'direct',
#    'gps',
#    'glonass',
#    'beidou',
#    'galileo',
#    'pc',
#    'sync',
#    '.',
#    '2',
#    'g',
#    'gsm',
#    '850',
#    'gsm',
#    '900',
#    'dcs',
#    '1800',
#    'pcs',
#    '1900',
#    '3',
#    'g',
#    'b',
#    '1',
#    '2100',
#    'b',
#    '2',
#    '1900',
#    'b',
#    '5',
#    '850',
#    'b',
#    '8',
#    '900',
#    '4',
#    'g',
#    'lte'],
#   ['แบตเตอรี่',
#    'ความจุ',
#    '4000',
#    'mah',
#    'รองรับ',
#    '15',
#    'w',
#    'fast',
#    'charging',
#    'ระบบปฎิบัติการ',
#    'android',
#    '9.0',
#    'pi'],
#   ['มีสีให้เลือก', 'colors', 'ดำ', 'แดง', 'เขียว'],
#   ['brand', 'ซัมซุง'],
#   ['sku', '594338092', 'th', '1115814517'],
#   ['ประเภทของการรับประกัน', 'การรับประกันจากโรงงานในประเทศ'],
#   ['กล้องหน้า', 'เมกะพิกเซล', '7', 'mp', 'ขึ้นไป'],
#   ['model', 'samsung', '20', 's'],
#   ['กล้องด้านหลัง', '11', '15', 'mp'],
#   ['ระยะเวลาการรับประกัน', '1', 'ปี'],
#   ['ความจุ', 'แบตเตอรี่', '1000', 'mah', '5000', 'mah']],
#  'category_0_18': [['โทรศัพท์มือถือและแท็บเล็ต'],
#   ['smartphones'],
#   ['samsung',
#    'galaxy',
#    '80',
#    '8',
#    '128',
#    'gb',
#    'โทรศัพท์มือถือ',
#    'แถมฟรี',
#    'หูฟัง',
#    'akg',
#    'y',
#    '500',
#    'มูลค่า',
#    '3990',
#    'บาท',
#    'แถมเพิ่ม',
#    'travel',
#    'set',
#    'มูลค่า',
#    '2990',
#    'บาท'],
#   ['หน้าจอ',
#    'super',
#    'amoled',
#    'ขนาด',
#    '6.7',
#    'นิ้ว',
#    'ความละเอียด',
#    'fhd',
#    '1080',
#    'x',
#    '2400'],
#   ['cpu', 'snapdragon', '730'],
#   ['ram', '8', 'gb', 'ddr', '4'],
#   ['ความจุ', '128', 'gb', 'ufs', '2.1', 'รองรับ', 'microsd', 'card'],
#   ['กล้องหน้า',
#    '48',
#    'mp',
#    'f',
#    '2.0',
#    'imx',
#    '586',
#    'ultra',
#    'wide',
#    '8',
#    'mp',
#    'f',
#    '2.2',
#    'tof'],
#   ['สแกนนิ้วมือบนหน้าจอ'],
#   ['แบตเตอรี่',
#    '3700',
#    'mah',
#    'รองรับ',
#    'super',
#    'fast',
#    'charging',
#    '25',
#    'w'],
#   ['brand', 'ซัมซุง'],
#   ['sku', '340860812', 'th', '661136678'],
#   ['มือถือ', 'smartphone'],
#   ['ระยะเวลาการรับประกัน', '1', 'ปี'],
#   ['ระบบปฏิบัติการ', 'android'],
#   ['ประเภทของการรับประกัน', 'มีการรับประกัน'],
#   ['คุณสมบัติของโทรศัพท์', 'ทัชสกรีน'],
#   ['ระบบปฏิบัติการ', 'เวอร์ชัน', 'android', '9.0', 'pie'],
#   ['model', '80'],
#   ['หน่วยความจำ', 'ram', '8', 'gb'],
#   ['ขนาดหน้าจอ', 'นิ้ว', '6.7'],
#   ['ความจุ', 'แบตเตอรี่', '3000', '3999', 'mah'],
#   ['ช่องเสียบแบบบาง', 'คู่']],
#  'category_0_19': [['โทรศัพท์มือถือและแท็บเล็ต'],
#   ['smartphones'],
#   ['samsung',
#    'galaxy',
#    'note',
#    '9',
#    '6',
#    'gb',
#    '128',
#    'gb',
#    'เครื่องศูนย์',
#    'มีประกัน',
#    'ocean',
#    'blue'],
#   ['เทคโนโลยีการรับ',
#    'ส่งข้อมูล',
#    '2',
#    'g',
#    'edge',
#    'gprs',
#    '3',
#    'g',
#    'hspa',
#    '4',
#    'g'],
#   ['ใช้งาน', 'nano', 'sim'],
#   ['รองรับ', '2', 'ซิมการ์ด'],
#   ['จอแสดงผล',
#    'super',
#    'amoled',
#    '24',
#    'bit',
#    '16',
#    'ล้านสี',
#    'ระบบสัมผัส',
#    'multi',
#    'touch',
#    '6.4',
#    'นิ้ว',
#    'แนวทะแยง',
#    'ความละเอียด',
#    '2960',
#    'x',
#    '1440',
#    'พิกเซล',
#    'capacitive',
#    'corning',
#    'gorilla',
#    'glass',
#    '5',
#    'ระบบป้องกัน',
#    'ฝุ่นละออง',
#    'resistance',
#    'dust'],
#   ['ระบบเซ็นเซอร์',
#    'sensor',
#    'ระบบตรวจสอบลายนิ้วมือ',
#    'finger',
#    'print',
#    'ระบบจดจำใบหน้า',
#    'face',
#    'detection',
#    'ระบบหมุนภาพอัตโนมัติ',
#    'accelerometer',
#    'ระบบเปิด',
#    'ปิดหน้าจออัตโนมัติขณะสนทนา',
#    'proximity',
#    'ระบบเซนเซอร์หมุนภาพ',
#    'gyroscope',
#    'ระบบวัดความกดอากาศ',
#    'barometer',
#    'รองรับ',
#    's',
#    'pen',
#    'ระบบปากกาอัจฉริยะ',
#    'ระบบสแกนม่านตา'],
#   ['คุณสมบัติการกันน้ำ', 'waterproof', 'กันน้ำได้ชั่วคราว'],
#   ['ระบบปฏิบัติการ', 'android', '8.1', 'oreo'],
#   ['หน่วยประมวลผล',
#    'exynos',
#    '9810',
#    'octa',
#    'core',
#    'ความเร็ว',
#    '2.7',
#    'ghz'],
#   ['หน่วยความจำ', 'rom', '128', 'gb', 'ram', '6', 'gb'],
#   ['การ์ดหน่วยความจำ'],
#   ['microsd', '512', 'gb'],
#   ['usb', 'type', 'c'],
#   ['ช่องเสียบชุดหูฟัง', '3.', 'มม.'],
#   ['กล้องดิจิตอล',
#    '12',
#    '12',
#    'ล้านพิกเซล',
#    'dual',
#    'camera',
#    'รูรับแสงขนาด',
#    '1.5',
#    'ไฟแฟลช',
#    'led',
#    'ซูมออฟติคอล',
#    '2',
#    '2',
#    'x',
#    'optical',
#    'zoom',
#    'โฟกัสอัตโนมัติ',
#    'auto',
#    'focus',
#    'แตะเลือกจุดโฟกัส',
#    'touch',
#    'focus',
#    'ระบบป้องกันภาพสั่นไหวแบบออปติคอล',
#    'ois',
#    'ค้นหาใบหน้าอัตโนมัติ',
#    'face',
#    'detection',
#    'โหมดถ่ายภาพพาโนราม่า',
#    'panorama'],
#   ['โหมดถ่ายภาพช่วงการรับแสงสูง', 'hdr'],
#   ['กล้องหน้า',
#    'front',
#    'camera',
#    'ความละเอียด',
#    '8',
#    'mp',
#    'รูรับแสงขนาด',
#    '1.7'],
#   ['บันทึกวีดีโอ',
#    'ภาพเคลื่อนไหว',
#    'video',
#    'recording',
#    'slow',
#    'motion',
#    'รูปแบบไฟล์วีดีโอ',
#    'mpeg',
#    '4'],
#   ['ระบบเสียง', 'dolby', 'atmos'],
#   ['ลำโพงคู่', 'dual', 'loud', 'speaker'],
#   ['ไมโครโฟนสำหรับตัดเสียงรบกวนการสนทนา'],
#   ['เทคโนโลยีเพิ่มความเร็วในการชาร์จ'],
#   ['มีระบบชาร์จไร้สายในตัว'],
#   ['แบตเตอรี่', 'มาตรฐาน', '4000', 'mah', 'standard', 'battery'],
#   ['brand', 'ซัมซุง'],
#   ['sku', '283666353', 'th', '461390461'],
#   ['ประเภทของการรับประกัน', 'การรับประกันจากโรงงานในประเทศ'],
#   ['model',
#    'samsung',
#    'galaxy',
#    'note',
#    '9',
#    '6',
#    'gb',
#    '128',
#    'gb',
#    'เครื่องศูนย์',
#    'มีประกัน',
#    'ocean',
#    'blue'],
#   ['ระยะเวลาการรับประกัน', '1', 'ปี'],
#   ['ระบบปฏิบัติการ', 'android']],
#  'category_0_20': [['โทรศัพท์มือถือและแท็บเล็ต'],
#   ['smartphones'],
#   ['samsung',
#    'galaxy',
#    '10',
#    's',
#    'สมาร์ทโฟน',
#    'กล้องหลัง',
#    'คู่',
#    '13',
#    '2',
#    'mp',
#    'แบต',
#    '4000',
#    'mah',
#    'ประกันศูนย์',
#    '1',
#    'ปี',
#    'แถมฟรีหูฟังซัมซุง',
#    'มูลค่า',
#    '399',
#    'บาท'],
#   ['ตัวเครื่อง', '156.9', 'x', '75.8', 'x', '7.', 'มม.'],
#   ['น้ำหนัก', '168', 'กรัม'],
#   ['หน้าจอแสดงผล',
#    'tft',
#    'lcd',
#    '6.2',
#    'นิ้ว',
#    'ความละเอียด',
#    '1520',
#    'x',
#    '720',
#    'พิกเซล',
#    'hd',
#    'มีดีไซน์รอยแหว่งแบบ',
#    'infinity',
#    'v'],
#   ['ชิปเซ็ต', 'mediatek', 'helio', 'p', '22'],
#   ['ram', '2', 'gb'],
#   ['rom', '32', 'gb', 'microsd', 'card', 'ได้สูงสุด', '512', 'gb'],
#   ['ระบบปฏิบัติการ', 'one', 'ui', '1.1', 'บนพื้นฐาน', 'android', '9', 'pie'],
#   ['กล้องหลัง',
#    '2',
#    'เลนส์',
#    'พร้อมไฟแฟลชเลนส์หลัก',
#    'ความละเอียด',
#    '13',
#    'ล้านพิกเซล',
#    'รูรับแสง',
#    'f',
#    '1.8'],
#   ['เลนส์', 'depth', 'ความละเอียด', '2', 'ล้านพิกเซล', 'รูรับแสง', 'f', '2.4'],
#   ['กล้องหน้า', 'ความละเอียด', '8', 'ล้านพิกเซล', 'รูรับแสง', 'f', '2.2'],
#   ['ซิมการ์ด', 'รองรับ', '2', 'ซิมแบบ', 'nano', 'sim'],
#   ['การเชื่อมต่อ',
#    'w',
#    'fi',
#    '2.4',
#    'ghz',
#    'blurtooth',
#    '4.2',
#    'พอร์ต',
#    'micro',
#    'usb',
#    '2.0',
#    'ช่องเสียบหูฟัง',
#    '3.',
#    'มม.'],
#   ['ระบบความปลอดภัย', 'รหัส', 'สแกนใบหน้า', 'สแกนลายนิ้วมือ'],
#   ['แบตเตอรี่', '4000', 'mah'],
#   ['ตัวเครื่อง', 'samsung', 'galaxy', '10', 's'],
#   ['สาย', 'micro', 'usb', '2.0'],
#   ['อะแดปเตอร์'],
#   ['ที่นำซิมออก'],
#   ['ถาดซิม'],
#   ['คู่มือการใช้งาน', 'และใบรับประกัน'],
#   ['brand', 'ซัมซุง'],
#   ['sku', '616572478', 'th', '1170962904'],
#   ['มือถือ', 'smartphone'],
#   ['ระยะเวลาการรับประกัน', '1', 'ปี'],
#   ['ประเภทของการรับประกัน', 'มีการรับประกัน'],
#   ['ประเภทของ', 'แบตเตอรี่', 'built', 'rechargeable', 'battery'],
#   ['สภาพสินค้า'],
#   ['คุณสมบัติของโทรศัพท์',
#    'หน่วยความจำที่ขยายได้เซ็นเซอร์ตรวจลายนิ้วมือ',
#    'gps',
#    'ทัชสกรีน'],
#   ['กล้องหน้า', 'เมกะพิกเซล', '7', 'mp', 'ขึ้นไป'],
#   ['ระบบปฏิบัติการ', 'เวอร์ชัน', 'android', '9.0', 'pie'],
#   ['model', 'samsung', 'galaxy', '10', 's', 'sm', '107', 'f']],
#  'category_0_21': [['โทรศัพท์มือถือและแท็บเล็ต'],
#   ['smartphones'],
#   ['samsung', 'galaxy', 'j', '4', 'plus', 'ประกันศูนย์', 'pink'],
#   ['brand', 'ซัมซุง'],
#   ['sku', '307684896', 'th', '537048806'],
#   ['ประเภทของการรับประกัน', 'การรับประกันจากโรงงานในประเทศ'],
#   ['model', 'samsung', 'galaxy', 'j', '4', 'plus'],
#   ['ระยะเวลาการรับประกัน', '1', 'ปี']],
#  'category_0_22': [['โทรศัพท์มือถือและแท็บเล็ต'],
#   ['smartphones'],
#   ['samsung', 'galaxy', 'note', '10', '8', '256', 'gb', 'โทรศัพท์มือถือ'],
#   ['ขนาดหน้าจอ', '6.3', 'นิ้ว'],
#   ['ram', '8', 'gb'],
#   ['ความจุ', 'storage', '256', 'gb'],
#   ['แบตเตอรี่', '3500', 'mah', 'typical'],
#   ['มาตรฐานการกันน้ำและกันฝุ่น', 'ip', '68'],
#   ['brand', 'ซัมซุง'],
#   ['sku', '373972071', 'th', '728742055'],
#   ['ประเภทของการรับประกัน', 'มีการรับประกัน'],
#   ['model', '8', '256', 'gb'],
#   ['ระยะเวลาการรับประกัน', '1', 'ปี']],
#  'category_0_23': [['โทรศัพท์มือถือและแท็บเล็ต'],
#   ['smartphones'],
#   ['samsung',
#    'galaxy',
#    'note',
#    '8',
#    '64',
#    'gb',
#    'midnight',
#    'แถมฟรีฟิล์มใสติดเครื่อง',
#    'เคสใส'],
#   ['หน้าจอกว้างขนาด', '6.3', 'ใหญ่ที่สุดในตระกูล', 'note'],
#   ['ปากกาอัจฉริยะ', 's', 'pen', 'มิติใหม่แห่งการสื่อสาร'],
#   ['ถ่ายภาพได้คมชัดแม้ในที่แสงน้อย'],
#   ['โพรเซสเซอร์ประสิทธิภาพสูง', '10', 'nm', 'หน่วยความจำ', '6', 'gb'],
#   ['เปลี่ยนโอนข้อมูลด้วย', 'smart', 'switch'],
#   ['หน้าจอกว้างขึ้น',
#    'ด้วยขนาด',
#    '6.3',
#    'ใหญ่ที่สุดในตระกูล',
#    'note',
#    'มอบภาพที่คมชัด',
#    'แจ้มแจ้งในทุกรายละเอียด'],
#   ['สร้างความแตกต่างใบแบบที่เป็นคุณด้วยการวาด',
#    'emojis',
#    'ส่วนตัว',
#    'ผ่านปากกาอัจฉริยะ',
#    's',
#    'pen'],
#   ['มีทั้งกล้องมุมกว้าง', 'ซึ่งสามารถถ่ายภาพได้ดีในสภาวะแสงน้อย'],
#   ['โพรเซสเซอร์ประสิทธิภาพสูง',
#    '10',
#    'nm',
#    'หน่วยความจำ',
#    '6',
#    'gb',
#    'เพื่อการทำงานที่ลื่นไหลมากขึ้น'],
#   ['เทคโนโลยี',
#    'phone',
#    'ช่วยให้คุณเชื่อมต่อกับโลกได้กว้างขึ้น',
#    'ระหว่างตัวอุปกรณ์กับอินเตอร์เฟซต่าง'],
#   ['เปลี่ยนถ่าย',
#    'และโอนข้อมูลง่ายๆ',
#    'smart',
#    'switch',
#    'เพื่อให้ทันการอัพเดททุกเรื่องราวในชีวิต'],
#   ['รับชมภาพยนตร์ได้สนุกสนานยิ่งขึ้นด้วยอัตราส่วนภาพ',
#    '18',
#    '9',
#    'ในโหมดแนวนอน',
#    'เพิ่มพื้นที่ในการรับชมมากขึ้นถึง',
#    '14',
#    'เปอร์เซนต์'],
#   ['ตัวดีไซน์แบบไร้รอยต่อ',
#    'พร้อมเพิ่มพื้นที่ในการขีดเขียนอย่างอิสระ',
#    'และเครื่องสแกนลายนิ้วมือที่อยู่ด้านหลัง',
#    'สะดวกต่อการใช้งาน'],
#   ['โหมด',
#    'multi',
#    'window',
#    'เปิดสองแอปพลิเคชันพร้อมกันด้วยการแท็บเพียงครั้งเดียว'],
#   ['อัตราส่วน',
#    'หน้าจอขนาด',
#    '18',
#    '5',
#    '9',
#    'ช่วยให้คุณเห็นรายละเอียดบนหน้าจอที่มาก',
#    'ปรับแต่งรายการต่างๆ',
#    'พร้อมขยับจอน้อยลง'],
#   ['brand', 'ซัมซุง'],
#   ['sku', '310302392', 'th', '552106447'],
#   ['ประเภทของการรับประกัน', 'มีการรับประกันจากผู้ขาย'],
#   ['model', 'sm', 'n', '950'],
#   ['ระยะเวลาการรับประกัน', '1', 'ปี']],
#  'category_0_24': [['โทรศัพท์มือถือและแท็บเล็ต'],
#   ['smartphones'],
#   ['samsung',
#    'galaxy',
#    '9',
#    '2018',
#    '6',
#    '128',
#    'gb',
#    'เครื่องศูนย์',
#    'เคลียสตอคไม่มีประกัน',
#    'caviar',
#    'black'],
#   ['จอแสดงผล',
#    'super',
#    'amoled',
#    '24',
#    'bit',
#    '16',
#    'ล้านสี',
#    'fullview',
#    'display',
#    '6.3',
#    'นิ้ว'],
#   ['ระบบตรวจสอบลายนิ้วมือ',
#    'fingerprint',
#    'ระบบจดจำใบหน้า',
#    'face',
#    'detection'],
#   ['กล้องดิจิตอล',
#    'main',
#    'camera',
#    '24',
#    'mp',
#    'ultra',
#    'wide',
#    'camera',
#    '8',
#    'mp',
#    'telephoto',
#    'camera',
#    '10',
#    'mp',
#    'depth',
#    'camera',
#    '5',
#    'mp',
#    'fourth',
#    'camera',
#    'รูรับแสงขนาด',
#    '1.7'],
#   ['กล้องหน้า', 'ความละเอียด', '24', 'mp'],
#   ['ram', '6', 'gb'],
#   ['หน่วยความจำตัวเครื่อง', '128', 'gb'],
#   ['brand', 'ซัมซุง'],
#   ['sku', '280354579', 'th', '453591358'],
#   ['ระยะเวลาการรับประกัน', '5'],
#   ['ระบบปฏิบัติการ', 'android'],
#   ['ประเภทของการรับประกัน', 'ไม่มีการประกัน'],
#   ['กล้องหน้า', 'เมกะพิกเซล', '7', 'mp', 'ขึ้นไป'],
#   ['ระบบปฏิบัติการ', 'เวอร์ชัน', 'android', '8.0', 'oreo'],
#   ['model',
#    'samsung',
#    'galaxy',
#    '9',
#    '2018',
#    '6',
#    '128',
#    'gb',
#    'เครื่องศูนย์',
#    'เคลียสตอคไม่มีประกัน',
#    'caviar',
#    'black'],
#   ['หน่วยความจำ', 'ram', '6', 'gb'],
#   ['ขนาดหน้าจอ', 'นิ้ว', '6.3'],
#   ['กล้องด้านหลัง', '21', 'mp', 'ขึ้นไป'],
#   ['ความจุ', 'แบตเตอรี่', '1000', 'mah', '5000', 'mah'],
#   ['ช่องเสียบแบบบาง', 'คู่']],
#  'category_0_25': [['โทรศัพท์มือถือและแท็บเล็ต'],
#   ['smartphones'],
#   ['samsung', '70', 'ram', '8', '128', 'เครื่องศูนย์เคลียร์สต๊อค'],
#   ['จอแสดงผล',
#    'super',
#    'amoled',
#    '24',
#    'bit',
#    '16',
#    'ล้านสี',
#    'หน้าจอทรงหยดน้ำ',
#    'รูปตัว',
#    'u',
#    'infinity',
#    'u',
#    'ระบบสัมผัส',
#    'multi',
#    'touch',
#    '6.7',
#    'นิ้ว',
#    'แนวทะแยง',
#    'ความละเอียด',
#    '1080',
#    'x',
#    '2400',
#    'พิกเซล',
#    'capacitive',
#    'ระบบเซ็นเซอร์',
#    'sensor',
#    'ระบบสแกนลายนิ้วมือใต้หน้าจอ',
#    'fingerprint',
#    'display',
#    'ระบบจดจำใบหน้า',
#    'face',
#    'detection',
#    'ระบบหมุนภาพอัตโนมัติ',
#    'accelerometer',
#    'ตรวจจับแสงปรับความสว่างอัตโนมัติ',
#    'ambient',
#    'light',
#    'ระบบเปิด',
#    'ปิดหน้าจออัตโนมัติขณะสนทนา',
#    'proximity',
#    'ระบบเซนเซอร์หมุนภาพ',
#    'gyroscope',
#    'ปรับมุมมองการแสดงผลอัตโนมัติ',
#    'orientation',
#    'ระบบปฏิบัติการ',
#    'android',
#    '9',
#    'pie',
#    'หน่วยประมวลผล',
#    'snapdragon',
#    '675',
#    'octa',
#    'core',
#    'ความเร็ว',
#    '2.0',
#    'ghz',
#    'หน่วยความจำ',
#    'rom',
#    '128',
#    'gb',
#    'ram',
#    '8',
#    'gb',
#    'การ์ดหน่วยความจำ',
#    'microsd',
#    '512',
#    'gb',
#    'กล้องดิจิตอล',
#    '32',
#    'mp',
#    '8',
#    'ultra',
#    'wide',
#    '5',
#    'triple',
#    'camera',
#    'รูรับแสงขนาด',
#    '1.7',
#    'ไฟแฟลช',
#    'led',
#    'ค้นหาใบหน้าอัตโนมัติ',
#    'face',
#    'detection',
#    'เทคโนโลยีถ่ายภาพอัจฉริยะ',
#    'ai',
#    'camera',
#    'โหมดปรับหน้าสวยอัตโนมัติ',
#    'ai',
#    'face',
#    'beauty',
#    'โหมดเปลี่ยนภาพเซลฟี่เป็นอิโมจิ',
#    'ar',
#    'emoji',
#    'โหมดเปลี่ยนภาพเซลฟี่เป็นสติกเกอร์',
#    'ar',
#    'sticker',
#    'โหมดถ่ายภาพพาโนราม่า',
#    'panorama',
#    'โหมดถ่ายภาพช่วงการรับแสงสูง',
#    'hdr',
#    'กล้องหน้า',
#    'front',
#    'camera',
#    'ความละเอียด',
#    '32',
#    'รูรับแสงขนาด',
#    '2.0',
#    'กล้องหน้า',
#    'hdr',
#    'บันทึกวีดีโอ',
#    'ภาพเคลื่อนไหว',
#    'video',
#    'recording',
#    'รูปแบบไฟล์วีดีโอ',
#    'mpeg',
#    '4',
#    'เครื่องเล่นวีดีโอ',
#    'video',
#    'player',
#    'รูปแบบไฟล์',
#    'mpeg',
#    '4',
#    'รองรับ',
#    'วีดีโอจาก',
#    'youtube',
#    'เครื่องเล่นเพลง',
#    'music',
#    'player',
#    'รูปแบบไฟล์',
#    'mp',
#    '3',
#    'ระบบเสียง',
#    'dolby',
#    'atmos',
#    'เทคโนโลยีเพิ่มความเร็วในการชาร์จ',
#    'แบตเตอรี่',
#    'มาตรฐาน',
#    '4500',
#    'mah',
#    'standard',
#    'battery'],
#   ['brand', 'ซัมซุง'],
#   ['sku', '595150747', 'th', '1117932783'],
#   ['ประเภทของการรับประกัน', 'ไม่มีการประกัน'],
#   ['model', 'samsung', '70']],
#  'category_0_26': [['โทรศัพท์มือถือและแท็บเล็ต'],
#   ['smartphones'],
#   ['samsung', 'galaxy', '6', '4', '32', 'gb'],
#   ['จอคุณภาพสูง', 'full', 'front', 'display', 'samoled'],
#   ['กล้องหน้า', 'หลังความละเอียดเท่ากัน', '16', 'mp'],
#   ['กล้องหน้า',
#    'มาพร้อม',
#    '3',
#    'step',
#    'lighting',
#    'ช่วยปรับแสงได้',
#    '3',
#    'ระดับ',
#    'กล้องหลัง',
#    'รูรับแสงกว้าง',
#    'f',
#    '1.7'],
#   ['ถ่ายสนุกด้วยโหมดเซลฟี่หน้าชัดหลังละลาและเซลฟี่สติ๊กเกอร์',
#    'ar',
#    'sticker',
#    'ที่มีแบบให้เลือกมากกว่า',
#    '30'],
#   ['app',
#    'pair',
#    'สามารถเปิด',
#    '2',
#    'แอพที่ชอบได้พร้อมกัน',
#    '2',
#    'หน้าจอในคลิ๊กเดียว'],
#   ['แชทได้พร้อมกัน',
#    '2',
#    'บัญชีในเครื่องเดียว',
#    'รองรับ',
#    'แอพ',
#    'social',
#    'เยอะที่สุดถึง',
#    '18',
#    'แอพ'],
#   ['brand', 'ซัมซุง'],
#   ['sku', '264741378', 'th', '411062149'],
#   ['ประเภทของการรับประกัน', 'มีการรับประกัน'],
#   ['model', 'galaxy', '6', 'sm', '605', 'g', 'ds'],
#   ['หน่วยความจำ', 'ram', '4', 'gb'],
#   ['ขนาดหน้าจอ', 'นิ้ว', '6'],
#   ['ระยะเวลาการรับประกัน', '1', 'ปี'],
#   ['262.0']],
#  'category_0_27': [['โทรศัพท์มือถือและแท็บเล็ต'],
#   ['smartphones'],
#   ['samsung',
#    'galaxy',
#    '50',
#    's',
#    '128',
#    'gb',
#    '6',
#    'gb',
#    'ram',
#    'original',
#    'set'],
#   ['samsung',
#    'galaxy',
#    '50',
#    's',
#    '128',
#    'gb',
#    '6',
#    'gb',
#    'ram',
#    'original',
#    'set',
#    'brand',
#    'new',
#    'original',
#    'packaging',
#    'undamaged',
#    'unopened',
#    'unused',
#    'item',
#    'original',
#    'packaging',
#    'found',
#    'retail',
#    'store',
#    'unless',
#    'item',
#    'handmade',
#    'packaged',
#    'manufacturer',
#    'non',
#    'retail',
#    'packaging',
#    'unprinted',
#    'box',
#    'plastic',
#    'bag'],
#   ['brand', 'ซัมซุง'],
#   ['sku', '617108827', 'th', '1172618764'],
#   ['ประเภทของการรับประกัน', 'มีการรับประกัน'],
#   ['ระบบปฏิบัติการ', 'เวอร์ชัน', 'android', '9.0', 'pie'],
#   ['model',
#    'samsung',
#    'galaxy',
#    '50',
#    's',
#    '128',
#    'gb',
#    '6',
#    'gb',
#    'ram',
#    'original',
#    'set'],
#   ['ระยะเวลาการรับประกัน', '1', 'ปี'],
#   ['ช่องเสียบแบบบาง', 'คู่']],
#  'category_0_28': [['โทรศัพท์มือถือและแท็บเล็ต'],
#   ['smartphones'],
#   ['samsung', 'galaxy', '20', 's', '3', '32', 'gb', 'โทรศัพท์มือถือ'],
#   ['galaxy', '20', 's'],
#   ['สนุกทุกประสบการณ์กับหน้าจอใหญ่ที่เต็มตากว่าเดิม'],
#   ['ด้านหลังเรียบเงา', 'ใช้งานได้ถนัดมือ'],
#   ['เด่นทุกมุมมองด้วยกล้องสามเลนส์'],
#   ['brand', 'ซัมซุง'],
#   ['sku', '511068392', 'th', '907938105'],
#   ['ประเภทของการรับประกัน', 'มีการรับประกัน'],
#   ['model', 'galaxy', '20', 's', '3', '32', 'gb'],
#   ['ระยะเวลาการรับประกัน', '1', 'ปี']],
#  'category_0_29': [['โทรศัพท์มือถือและแท็บเล็ต'],
#   ['smartphones'],
#   ['refurbish', 'samsung', 'galaxy', '8', '2018', 'gold'],
#   ['หน้าจอใหญ่', 'super', 'amoled', '5.6', 'นิ้ว', 'สัดส่วน', '18.5', '9'],
#   ['ชิพเซต', 'exynos', '7885', 'octa', 'core', '2.2', 'ghz'],
#   ['rom', '32', 'gb', 'ram', '4', 'gb', 'microsd', '256', 'gb'],
#   ['ระบบปฏิบัติการ', 'แอนดรอยด์', '7.1', 'nougat'],
#   ['กล้องถ่ายภาพ', '16', 'ล้านพิกเซล', 'รูรับแสงกว้าง', 'f', '1.7'],
#   ['กล้องหน้า', 'แบบคู่', '16', '8', 'ล้านพิกเซล', 'รูรับแสง', 'f', '1.9'],
#   ['กล้องหน้า', 'รองรับ', 'live', 'focus', 'ปรับฉากหลังละลายได้'],
#   ['ปลดล็อคหน้าจอด้วยการสแกนใบหน้า'],
#   ['รองรับ', 'การใช้งาน', 'secure', 'folder'],
#   ['รองรับ', 'การสแกนลายนิ้วมือ'],
#   ['จ่ายเงินผ่าน', 'samsung', 'pay'],
#   ['ตัวเครื่องกันน้ำลึก',
#    '1.5',
#    'เมตรนาน',
#    '30',
#    'นาที',
#    'มาตรฐาน',
#    'ip',
#    '68'],
#   ['หน้าจอใหญ่', 'super', 'amoled', '5.6', 'นิ้ว', 'สัดส่วน', '18.5', '9'],
#   ['ชิพเซต', 'exynos', '7885', 'octa', 'core', '2.2', 'ghz'],
#   ['rom', '32', 'gb', 'ram', '4', 'gb', 'microsd', '256', 'gb'],
#   ['ระบบปฏิบัติการ', 'แอนดรอยด์', '7.1', 'nougat'],
#   ['กล้องถ่ายภาพ', '16', 'ล้านพิกเซล', 'รูรับแสงกว้าง', 'f', '1.7'],
#   ['กล้องหน้า', 'แบบคู่', '16', '8', 'ล้านพิกเซล', 'รูรับแสง', 'f', '1.9'],
#   ['กล้องหน้า', 'รองรับ', 'live', 'focus', 'ปรับฉากหลังละลายได้'],
#   ['ปลดล็อคหน้าจอด้วยการสแกนใบหน้า'],
#   ['รองรับ', 'การใช้งาน', 'secure', 'folder'],
#   ['รองรับ', 'การสแกนลายนิ้วมือ'],
#   ['จ่ายเงินผ่าน', 'samsung', 'pay'],
#   ['ตัวเครื่องกันน้ำลึก',
#    '1.5',
#    'เมตรนาน',
#    '30',
#    'นาที',
#    'มาตรฐาน',
#    'ip',
#    '68'],
#   ['brand', 'ซัมซุง'],
#   ['sku', '207916690', 'th', '313021622'],
#   ['ประเภทของการรับประกัน', 'มีการรับประกัน'],
#   ['model', 'refurbish', 'samsung', 'galaxy', '8', '2018', 'gold'],
#   ['ระยะเวลาการรับประกัน', '3', 'เดือน']],
#  'category_0_30': [['โทรศัพท์มือถือและแท็บเล็ต'],
#   ['smartphones'],
#   ['samsung',
#    'galaxy',
#    's',
#    '10',
#    '8',
#    'gb',
#    'ram',
#    '128',
#    'gb',
#    'rom',
#    '6.4',
#    'นิ้ว',
#    '5',
#    'กล้อง',
#    '16',
#    'mp',
#    'ff',
#    'f',
#    '2.2',
#    'โทรศัพท์มือถือ'],
#   ['หน้าจอ',
#    '6.4',
#    'นิ้ว',
#    'ความละเอียด',
#    '3040',
#    'x',
#    '1440',
#    'quad',
#    'hd',
#    '550',
#    'ppi'],
#   ['กล้องหลัง',
#    '3',
#    'ตัว',
#    '16',
#    'mp',
#    'f',
#    '2.2',
#    'ultra',
#    'wide',
#    '12',
#    'mp',
#    'f',
#    '1.5',
#    '2.4',
#    'wide',
#    '12',
#    'mp',
#    'f',
#    '2.4',
#    'tele'],
#   ['กล้องหน้า',
#    '2',
#    'ตัว',
#    '10',
#    'mp',
#    'f',
#    '1.9',
#    'main',
#    '8',
#    'mp',
#    'f',
#    '2.2',
#    'live',
#    'focus'],
#   ['หน่วยประมวลผล',
#    'octa',
#    'core',
#    'snapdragon',
#    '855',
#    'octa',
#    'core',
#    'exynos',
#    '9',
#    '9820'],
#   ['ram', '8', '128', 'gb'],
#   ['แบตเตอรี่', '4100', 'mah', 'typical'],
#   ['brand', 'ซัมซุง'],
#   ['sku', '289426638', 'th', '479560515'],
#   ['ประเภทของการรับประกัน', 'มีการรับประกัน'],
#   ['model', 's', '10', '128', 'gb'],
#   ['ระยะเวลาการรับประกัน', '1', 'ปี'],
#   ['139']],
#  'category_0_31': [['โทรศัพท์มือถือและแท็บเล็ต'],
#   ['smartphones'],
#   ['samsung',
#    'j',
#    '8',
#    'ram',
#    '3',
#    '32',
#    'gb',
#    'เครื่องศูนย์ประกันมีเดือน',
#    'สีทอง',
#    'แถมฟรี',
#    'เคสใส',
#    'ฟิลม์กระจก'],
#   ['ระบบปฏิบัติการ', 'os', 'cpu', 'ระบบปฏิบัติการ', 'android', '8.0', 'oreo'],
#   ['หน่วยประมวลผล', 'qualco', 'มม.', 'snapdragon', '450', 'octa', 'core'],
#   ['ความเร็ว', '1.8', 'ghz'],
#   ['หน่วยความจำ', '32', 'gb', 'ตัวเครื่อง'],
#   ['ram', '3', 'gb', 'การ์ดหน่วยความจำ'],
#   ['microsd', '256', 'gb'],
#   ['slide', '1'],
#   ['slide', '2'],
#   ['slide', '1'],
#   ['slide', '2'],
#   ['ความพร้อมให้บริการอาจแตกต่างกันไปในแต่ละประเทศ',
#    'ภาพต่าง',
#    'จำลองขึ้นมาเพื่อจุดประสงค์ด้านการนำเสนอเท่านั้น'],
#   ['brand', 'ซัมซุง'],
#   ['sku', '289402378', 'th', '479508064'],
#   ['ประเภทของการรับประกัน', 'การรับประกันจากโรงงานในประเทศ'],
#   ['model',
#    'samsung',
#    'j',
#    '8',
#    'ram',
#    '3',
#    '32',
#    'gb',
#    'เครื่องศูนย์ประกันมีเดือน',
#    'สีทอง',
#    'แถมฟรี',
#    'เคสใส',
#    'ฟิลม์กระจก'],
#   ['ระยะเวลาการรับประกัน', '3', 'เดือน'],
#   ['ระบบปฏิบัติการ', 'android']],
#  'category_0_32': [['xiaomi',
#    'redmi',
#    'note',
#    '8',
#    '3',
#    'gb',
#    '32',
#    'gb',
#    'สมาร์ตโฟน',
#    '4',
#    'กล้อง',
#    'ai',
#    'ความละเอียด',
#    '48',
#    'mp',
#    'จอกว้าง',
#    '6.3',
#    'นิ้ว',
#    'fhd',
#    'ชิปเซ็ต',
#    'qualco',
#    'มม.',
#    'sd',
#    '665',
#    '฿',
#    '4299.00',
#    '฿',
#    '4999.00',
#    '14',
#    'เปอร์เซนต์'],
#   ['เครื่องเกาหลี',
#    'นำเข้า',
#    'note',
#    '9',
#    '฿',
#    '4299.00',
#    '฿',
#    '6999.00',
#    '39',
#    'เปอร์เซนต์'],
#   ['samsung',
#    'wireless',
#    'battery',
#    'pack',
#    '10000',
#    'mah',
#    'พาวเวอร์แบงค์',
#    'แบตเตอรี่',
#    'สำรอง',
#    '฿',
#    '1290.00',
#    '฿',
#    '1590.00',
#    '19',
#    'เปอร์เซนต์'],
#   ['samsung',
#    'galaxy',
#    'note',
#    '9',
#    'snapdragon',
#    '845',
#    'ram',
#    '6',
#    'rom',
#    '128',
#    'gb',
#    'เครื่องนอกไม่มีประกัน',
#    '฿',
#    '18880.00',
#    '฿',
#    '31900.00',
#    '41',
#    'เปอร์เซนต์'],
#   ['samsung',
#    'galaxy',
#    'note',
#    '10',
#    'ram',
#    '8',
#    'gb',
#    'rom',
#    '256',
#    'gb',
#    'aura',
#    'pink',
#    '฿',
#    '24280.00',
#    '฿',
#    '29500.00',
#    '18',
#    'เปอร์เซนต์'],
#   ['samsung',
#    'galaxy',
#    'note',
#    '10',
#    'ram',
#    '8',
#    'gb',
#    'rom',
#    '256',
#    'gb',
#    'aura',
#    'glow',
#    '฿',
#    '24280.00',
#    '฿',
#    '29500.00',
#    '18',
#    'เปอร์เซนต์'],
#   ['samsung',
#    'galaxy',
#    '30',
#    's',
#    '4',
#    '64',
#    'gb',
#    'โทรศัพท์มือถือ',
#    '฿',
#    '6290.00',
#    '฿',
#    '7990.00',
#    '21',
#    'เปอร์เซนต์'],
#   ['samsung',
#    'galaxy',
#    '20',
#    's',
#    '4',
#    '64',
#    'gb',
#    'โทรศัพท์มือถือ',
#    '฿',
#    '5250.00',
#    '฿',
#    '6490.00',
#    '19',
#    'เปอร์เซนต์'],
#   ['samsung', 'j', '2', 'prime', '฿', '1690.00'],
#   ['samsung',
#    'galaxy',
#    'tab',
#    's',
#    '4',
#    '10.5',
#    '4',
#    'gb',
#    'ram',
#    '64',
#    'gb',
#    'rom',
#    '10.5',
#    'นิ้ว',
#    'แท็บเล็ต',
#    '฿',
#    '13990.00',
#    '฿',
#    '23900.00',
#    '41',
#    'เปอร์เซนต์'],
#   ['samsung',
#    'galaxy',
#    '90',
#    'black',
#    '฿',
#    '19230.00',
#    '฿',
#    '23500.00',
#    '18',
#    'เปอร์เซนต์'],
#   ['samsung',
#    'galaxy',
#    'watch',
#    '1.3',
#    '46',
#    'มม.',
#    'สมาร์ทวอทช์',
#    'smart',
#    'watch',
#    '฿',
#    '8590.00',
#    '฿',
#    '12900.00',
#    '33',
#    'เปอร์เซนต์']],
#  'category_0_33': [['โทรศัพท์มือถือและแท็บเล็ต'],
#   ['smartphones'],
#   ['samsung', 'galaxy', 'note', '10', 'plus', '512', 'gb'],
#   ['brand', 'new'],
#   ['original'],
#   ['sealed', 'box'],
#   ['1', 'year', 'thailand', 'warranty', '90', 'days', 'return'],
#   ['interested',
#    'n',
#    'serious',
#    'buyers',
#    'contact',
#    'line',
#    'making',
#    'payment'],
#   ['username', 'flashsale', '2019', 'ใหม่เอี่ยม'],
#   ['ต้นฉบับ'],
#   ['ปิดผนึกในกล่อง'],
#   ['รับประกันประเทศไทย', '1', 'ปีและส่งคืน', '90'],
#   ['ผู้ซื้อที่สนใจและจริงจังควรติดต่อฉันที่ไลน์ก่อนชำระเงิน'],
#   ['ชื่อผู้ใช้คือ', 'flashsale', '2019'],
#   ['h', 'm', 'xe', 'ym'],
#   ['t', 'nc', 'hb', 'b'],
#   ['pid', 'p', 'hn', 'k', 'n', 'kl', 'xng'],
#   ['r',
#    'bprak',
#    'n',
#    'prathe',
#    'th',
#    'y',
#    '1',
#    'p',
#    'l',
#    's',
#    'ng',
#    'kh',
#    'n',
#    '90',
#    'w',
#    'n'],
#   ['p',
#    'h',
#    's',
#    'x',
#    'th',
#    's',
#    'nc',
#    'l',
#    'cringc',
#    'ng',
#    'khwr',
#    'tidt',
#    'x',
#    'c',
#    'h',
#    'n',
#    'th',
#    'l',
#    'n',
#    'k',
#    'xn',
#    'ch',
#    'ra',
#    'ngein'],
#   ['ch', 'x', 'p', 'h', 'ch', 'kh', 'x', 'flashsale', '2019'],
#   ['brand', 'ซัมซุง'],
#   ['sku', '612014873', 'th', '1155486191'],
#   ['ประเภทของการรับประกัน', 'การรับประกันจากโรงงานในประเทศ'],
#   ['ระบบปฏิบัติการ', 'เวอร์ชัน', 'android', '8.1', 'oreo'],
#   ['model', 'samsung', 'galaxy', 'note', '10', 'plus'],
#   ['ระยะเวลาการรับประกัน', '1', 'ปี'],
#   ['ช่องเสียบแบบบาง', 'คู่']]}

# %% [markdown]
# # Create BOW and train-test split

# %%
tokens_list = []
for i,v in token.items():
    tmp = [','.join(tkn) for tkn in v]
    tokens_list.append(tmp)

# %%
tokens_list
# Out:
# [['โทรศัพท์มือถือและแท็บเล็ต',
#   'smartphones',
#   'samsung,galaxy,m,30,s,4,64,gb,โทรศัพท์มือถือ',
#   'แบต,อึดอยู่นาน,สนุกได้ทั้งวัน,กับความจุ,6000,mah,และสามารถชาร์จ,แบต,fast,charging',
#   'ระบบ,กล้องหลัง,3,ตัว,ที่มีกล้องชัดสูงสุดถึง,48,mp,มาพร้อมกับเลนส์มุมกว้างพิเศษ,ultra,wide',
#   'exynos,9611,สเป็กแรงขึ้นเล่นเกมส์ได้ไม่มีสะดุด,ram,4,gb,rom,64,gb',
#   'หน้าจอแสดงผล,super,amoled,infinity,u,ขนาด,6.4,นิ้ว',
#   'brand,ซัมซุง',
#   'sku,480942616,th,870640886',
#   'ประเภทของการรับประกัน,มีการรับประกัน',
#   'model,galaxy,m,30,s,4,64,gb',
#   'ระยะเวลาการรับประกัน,1,ปี',
#   '793'],
#  ['โทรศัพท์มือถือและแท็บเล็ต',
#   'smartphones',
#   'โทรศัพท์มือถือ,samsung,galaxy,50,s,ram,4,64,gb,รับประกันศูนย์,jaymart',
#   'gsm,850,900,1800,1900,mhz',
#   '3,g,wcdma,850,900,1900,2100,mhz',
#   '4,g,fdd,lte,b,1,2100,b,3,1800,b,5,850,b,7,2600,b,8,900,b,20,800,b,28,700',
#   '4,g,tdd,lte,b,38,2600,b,40,2300,b,41,2500',
#   'รองรับ,2,ซิม,nano,sim',
#   'หน่วยประมวลผล,exynos,9610,quad,2.3,ghz,quad,1.7,ghz',
#   'ระบบปฏิบัติการ,android',
#   'หน่วยความจำภายใน,64,gb,micro,sd,รองรับ,512,gb',
#   'ram,4,gb',
#   'หน้าจอ,6.4,นิ้ว,ความละเอียด,1080,x,2340,พิกเซล,fhd',
#   'กล้องหลัง,3,เลนส์,48,ล้านพิกเซล,f,2.0,5,ล้านพิกเซล,f,2.2,bokeh,8,ล้านพิกเซล,f,2.4,ultrawide,แฟลช,led',
#   'กล้องหน้า,32,ล้านพิกเซล,f,2.0',
#   'wifi,802.11,b,g,n,ac',
#   'bluetooth,5.0',
#   'แบตเตอรี่,4000,mah',
#   'ขนาด,158.5,x,74.5,x,7.7,มม.',
#   'น้ำหนัก,169,g',
#   'brand,ซัมซุง',
#   'sku,593772364,th,1113954823',
#   'ระยะเวลาการรับประกัน,1,ปี',
#   'ประเภทของการรับประกัน,การรับประกันจากโรงงานในประเทศ',
#   'กล้องหน้า,เมกะพิกเซล,7,mp,ขึ้นไป',
#   'ระบบปฏิบัติการ,เวอร์ชัน,android,9.0,pie',
#   'model,50,s',
#   'หน่วยความจำ,ram,512,mb,และน้อยกว่า',
#   'ขนาดหน้าจอ,นิ้ว,6.4',
#   'กล้องด้านหลัง,21,mp,ขึ้นไป',
#   'ความจุ,แบตเตอรี่,1000,mah,5000,mah',
#   'ช่องเสียบแบบบาง,คู่'],
#  ['โทรศัพท์มือถือและแท็บเล็ต',
#   'smartphones',
#   'samsung,galaxy,10,s,ram,2,gb,rom,32,gb',
#   'สมาร์ทโฟน,โทรศัพท์มือถือพร้อม,ระบบปฏิบัติการ',
#   'จอแสดงผล,tft,lcd,24,bit,16,ล้านสี,หน้าจอทรงหยดน้ำ,รูปตัว,v,infinity,v,6.2,นิ้ว,แนวทะแยง,ความละเอียด,1520,x,720,พิกเซล',
#   'ระบบเซ็นเซอร์,sensor,ระบบตรวจสอบลายนิ้วมือ,fingerprint,ระบบหมุนภาพอัตโนมัติ,accelerometer,ระบบเซนเซอร์หมุนภาพ,gyroscope',
#   'มีสีให้เลือก,colors,black,red,green,blue',
#   'brand,ซัมซุง',
#   'sku,404422189,th,784670279',
#   'มือถือ,smartphone',
#   'ระยะเวลาการรับประกัน,1,ปี',
#   'ระบบปฏิบัติการ,android,9.0,pie',
#   'ประเภทของการรับประกัน,มีการรับประกัน',
#   'กล้องหน้า,เมกะพิกเซล,7,mp,ขึ้นไป',
#   'ระบบปฏิบัติการ,เวอร์ชัน,android,9.0,pie',
#   'model,samsung,galaxy,10,s,ram,2,gb,rom,32,gb',
#   'หน่วยความจำ,ram,2,gb',
#   'ขนาดหน้าจอ,นิ้ว,6.2',
#   'กล้องด้านหลัง,11,15,mp',
#   'ความจุ,แบตเตอรี่,1000,mah,5000,mah',
#   'ช่องเสียบแบบบาง,เตียงเดี่ยว',
#   '143'],
#  ['โทรศัพท์มือถือและแท็บเล็ต',
#   'smartphones',
#   'samsung,galaxy,note,10,12,256,gb,โทรศัพท์มือถือ',
#   'ขนาดหน้าจอ,6.8,นิ้ว',
#   'ram,12,gb',
#   'ความจุ,storage,256,gb',
#   'แบตเตอรี่,4300,mah,typical',
#   'มาตรฐานการกันน้ำและกันฝุ่น,ip,68',
#   'brand,ซัมซุง',
#   'sku,385536916,th,749070165',
#   'ประเภทของการรับประกัน,มีการรับประกัน',
#   'model,galaxy,note,10',
#   'ขนาดหน้าจอ,นิ้ว,6.8',
#   'ระยะเวลาการรับประกัน,1,ปี',
#   '243'],
#  ['โทรศัพท์มือถือและแท็บเล็ต',
#   'smartphones',
#   'samsung,galaxy,7,2017',
#   'ระบบเซ็นเซอร์,sensor,ระบบตรวจสอบลายนิ้วมือ,fingerprint,ระบบหมุนภาพอัตโนมัติ,accelerometer,ระบบเปิด,ปิดหน้าจออัตโนมัติขณะสนทนา,proximity,ระบบตรวจจับคลื่นแม่เหล็ก,geomagnetic,ระบบเซนเซอร์หมุนภาพ,gyroscope,ระบบวัดความกดอากาศ,barometer',
#   'คุณสมบัติการกันน้ำ,waterproof,กันน้ำได้ชั่วคราว',
#   'มีสีให้เลือก,colors,black,pink,gold,bluelight',
#   'เทคโนโลยีการรับ,ส่งข้อมูล,2,g,edge,gprs,3,g,hspa,4,g,lte,dl,lte,ul',
#   'ใช้งาน,nano,sim',
#   'รองรับ,2,ซิมการ์ด',
#   'ระบบปฏิบัติการ,android,6.0.1,marshmallow',
#   'หน่วยประมวลผล,octa,core,ความเร็ว,1.9,ghz',
#   'หน่วยความจำ,32,gb,ตัวเครื่อง,ram,3,gb',
#   'การ์ดหน่วยความจำ',
#   'microsd',
#   'การหาตำแหน่ง,assisted,gps',
#   'wifi,802.11,b,g,n,ac,จุดกระจายสัญญาณอินเตอร์เน็ตแบบพกพา,portable,wi,fi,hotspot,เชื่อมต่อไร้สายระหว่างอุปกรณ์โดยตรง,wi,fi,direct',
#   'bluetooth,4.2,รองรับ,ชุดหูฟังสเตอริโอ,2,dp,bluetooth,stereo',
#   'รองรับ,nfc,near,field,co,มม.,unication',
#   'ant',
#   'usb,type,c',
#   'ช่องเสียบชุดหูฟัง,3.,มม.',
#   'โซเชียลเน็ตเวิร์คแอพฯ,facebook,twitter',
#   'กล้องดิจิตอล,16,ล้านพิกเซล,digital,camera,รูรับแสงขนาด,1.9,ไฟแฟลช,led,โฟกัสอัตโนมัติ,auto,focus,แตะเลือกจุดโฟกัส,touch,focus,ค้นหาใบหน้าอัตโนมัติ,face,detection,โหมดถ่ายภาพพาโนราม่า,panorama',
#   'โหมดถ่ายภาพช่วงการรับแสงสูง,hdr',
#   'กล้องหน้า,front,camera,ความละเอียด,16,mp,รูรับแสงขนาด,1.9',
#   'บันทึกวีดีโอ,ภาพเคลื่อนไหว,video,recording,รูปแบบไฟล์วีดีโอ,mpeg,4',
#   'เครื่องเล่นวีดีโอ,video,player,รูปแบบไฟล์,mpeg,4,wmv,h,.,264,h,.,263,รองรับ,วีดีโอจาก,youtube',
#   'เครื่องเล่นเพลง,music,player,รูปแบบไฟล์,amr,nb,aac,lc,aac,eaac,mp,3,wma,flac',
#   'sms,มม.,s',
#   'ข้อความแชท,skype',
#   'สนับสนุน,gmail,google,search',
#   'ไมโครโฟนสำหรับตัดเสียงรบกวนการสนทนา',
#   'ออร์กาไนเซอร์,ปฏิทิน,เครื่องคิดเลข,นาฬิกาปลุก,จดบันทึก',
#   'ริงโทน,mp,3,ระบบสั่น,vibration,phone'],
#  ['โทรศัพท์มือถือและแท็บเล็ต',
#   'smartphones',
#   'samsung,galaxy,9,2018,6,gb,ram,128,gb,rom,6.3,นิ้ว,5,กล้อง,24,mp,tetra,cell,f,1.7,โทรศัพท์มือถือ',
#   'จอแสดงผล,super,amoled,24,bit,16,ล้านสี,fullview,display,6.3,นิ้ว',
#   'ระบบตรวจสอบลายนิ้วมือ,fingerprint,ระบบจดจำใบหน้า,face,detection',
#   'กล้องดิจิตอล,main,camera,24,mp,ultra,wide,camera,8,mp,telephoto,camera,10,mp,depth,camera,5,mp,fourth,camera,รูรับแสงขนาด,1.7',
#   'กล้องหน้า,ความละเอียด,24,mp',
#   'ram,6,gb',
#   'หน่วยความจำตัวเครื่อง,128,gb',
#   'brand,ซัมซุง',
#   'sku,265390897,th,412154584',
#   'ประเภทของการรับประกัน,มีการรับประกัน',
#   'model,galaxy,9,2018',
#   'ระยะเวลาการรับประกัน,1,ปี',
#   '141'],
#  ['โทรศัพท์มือถือและแท็บเล็ต',
#   'smartphones',
#   'samsung,30,s,ram,4,gb,rom,64,gb,มือ,1,ประกันศูนย์,1,ปี',
#   'คุณสมบัติ,samsung,30,s',
#   'จอแสดงผล,super,amoled,24,bit,16,ล้านสี',
#   '6.4,นิ้ว,แนวทะแยง,ความละเอียด,720,x,1560,พิกเซล,268,ppi',
#   'ประเภทจอ,corning,gorilla,glass,3,ระบบปฏิบัติการ',
#   'android,9.0,pie,หน่วยประมวลผล,exynos,7885,octa,core,ความเร็ว,1.8,mhz,หน่วยความจำ',
#   'ram,4,gb,rom,64,gb,การ์ดหน่วยความจำ',
#   'microsd,1,tb',
#   'กล้องดิจิตอล,25,mp,8,mp,ultrawide,5,mp,depth,sensor,triple,camera,รูรับแสงขนาด,1.7,ไฟแฟลช,led,โหมดถ่ายภาพช่วงการรับแสงสูง,hdr',
#   'กล้องหน้า,front,camera,ความละเอียด,16,mp,รูรับแสงขนาด,2.0',
#   'ลำโพงเสียงสเตอริโอ,stereo,speakers,wifi,802.11,b,g,n,ac',
#   'จุดกระจายสัญญาณอินเตอร์เน็ตแบบพกพา,portable,wi,fi,hotspot',
#   'เชื่อมต่อไร้สายระหว่างอุปกรณ์โดยตรง,wi,fi,direct,bluetooth,5.0,type,c,usb,2.0,ช่องเสียบชุดหูฟัง,3.,มม.',
#   'เครือข่าย,gsm,850,900,1800,1900,mhz,umts,850,900,2100,mhz,lte,bands,1,3,5,7,8,20,38,40,41,เทคโนโลยีการรับ,ส่งข้อมูล,2,g,edge,gprs,3,g,4,g',
#   'ใช้งาน,nano,sim,รองรับ,2,ซิมการ์ด',
#   'ระบบเซ็นเซอร์,sensor,ระบบสแกนลายนิ้วมือใต้หน้าจอ,fingerprint,display,ตรวจจับความเคลื่อนไหวของตัวเครื่อง,accelerometer,ระบบเปิด,ปิดหน้าจออัตโนมัติขณะสนทนา,proximity',
#   'แบตเตอรี่,มาตรฐาน,li,pol,4000,mah,standard,battery',
#   'มีสีให้เลือก,colors,ดำขาว,เขียว',
#   'brand,ซัมซุง',
#   'sku,594352438,th,1115888431',
#   'ประเภทของการรับประกัน,การรับประกันจากโรงงานในประเทศ',
#   'กล้องหน้า,เมกะพิกเซล,16,mp',
#   'model,samsung,30,s',
#   'กล้องด้านหลัง,21,mp,ขึ้นไป',
#   'ระยะเวลาการรับประกัน,1,ปี',
#   'ความจุ,แบตเตอรี่,1000,mah,5000,mah'],
#  ['โทรศัพท์มือถือและแท็บเล็ต',
#   'smartphones',
#   'มือ,1,ศูนย์ไทย,samsung,galaxy,note,10,plus,note,10,12,256,gb,ประกัน,1,ปี',
#   'samsung,galaxy,note,10,plus,th,ประกันศูนย์ไทย,1,ปี,เข้าศูนย์ซัมซุงได้ทั่วประเทศ,มือ,1,เครื่องแท้,100,เปอร์เซนต์',
#   'brand,ซัมซุง',
#   'sku,599364278,th,1176694583',
#   'ประเภทของการรับประกัน,มีการรับประกัน',
#   'ระบบปฏิบัติการ,เวอร์ชัน,android,9.0,pie',
#   'model,samsung,galaxy,note,10,plus',
#   'ขนาดหน้าจอ,นิ้ว,6.8',
#   'ระยะเวลาการรับประกัน,1,ปี',
#   'ช่องเสียบแบบบาง,เตียงเดี่ยว'],
#  ['โทรศัพท์มือถือและแท็บเล็ต',
#   'smartphones',
#   'samsung,galaxy,70,8,128,gb,โทรศัพท์มือถือ',
#   'galaxy,70,sm,705,fzbgthl',
#   'สเปคเทพของเกมเมอร์',
#   'หน้าจอกว้าง,6.7,infinity,u,display',
#   '3,กล้อง,พร้อมเลนส์,ultra,wide',
#   'brand,ซัมซุง',
#   'sku,309636084,th,547152150',
#   'ประเภทของการรับประกัน,มีการรับประกัน',
#   'model,70,8,128,gb',
#   'ระยะเวลาการรับประกัน,1,ปี',
#   '249'],
#  ['โทรศัพท์มือถือและแท็บเล็ต',
#   'smartphones',
#   'smartphone,โทรศัพท์มือถือ,samsung,galaxy,10,s,sm,107,m,ขนาดหน้าจอ,6.2,นิ้ว,ram,2,rom,32,gb,สีน้ำเงิน',
#   'brand,ซัมซุง',
#   'sku,571250946,th,1048780375',
#   'มือถือ,smartphone',
#   'ระยะเวลาการรับประกัน,1,เดือน',
#   'ประเภทของการรับประกัน,มีการรับประกันจากผู้ขาย',
#   'ประเภทของ,แบตเตอรี่,แบตเตอรี่,ชาร์จใหม่ได้และถอดได้',
#   'สภาพสินค้า',
#   'กล้องหน้า,เมกะพิกเซล,7,mp,ขึ้นไป',
#   'model,smartphone,โทรศัพท์มือถือ,samsung,galaxy,10,s,sm,107,m,ขนาดหน้าจอ,6.2,นิ้ว,ram,2,rom,32,gb,สีน้ำเงิน',
#   'ประเภทหน้าจอ,lcd',
#   'กล้องด้านหลัง,11,15,mp',
#   'ppi,500,ppi',
#   'ความละเอียดวิดีโอ,1080,p',
#   'resolution,full,hd',
#   'ความจุ,แบตเตอรี่,1000,mah,5000,mah'],
#  ['โทรศัพท์มือถือและแท็บเล็ต',
#   'smartphones',
#   'samsung,galaxy,5,2017',
#   'สมาร์ทโฟน,โทรศัพท์มือถือพร้อม,ระบบปฏิบัติการ',
#   'จอแสดงผล,super,amoled,24,bit,16,ล้านสี,5.2,นิ้ว,แนวทะแยง,ความละเอียด,1080,x,1920,พิกเซล,ประเภทจอ,หน้าจอกระจกแข็ง,ประเภทจอ,ระบบป้องกัน,ฝุ่นละออง,resistance,dust',
#   'ระบบเซ็นเซอร์,sensor,ระบบตรวจสอบลายนิ้วมือ,fingerprint,ระบบหมุนภาพอัตโนมัติ,accelerometer,ระบบเปิด,ปิดหน้าจออัตโนมัติขณะสนทนา,proximity,ระบบตรวจจับคลื่นแม่เหล็ก,geomagnetic,ระบบเซนเซอร์หมุนภาพ,gyroscope,ระบบวัดความกดอากาศ,barometer',
#   'คุณสมบัติการกันน้ำ,waterproof,กันน้ำได้ชั่วคราว',
#   'มีสีให้เลือก,colors,black,pink,gold,bluelight',
#   'เทคโนโลยีการรับ,ส่งข้อมูล,2,g,edge,gprs,3,g,hspa,4,g,lte,dl,lte,ul',
#   'ใช้งาน,nano,sim',
#   'รองรับ,2,ซิมการ์ด',
#   'ระบบปฏิบัติการ,android,6.0.1,marshmallow',
#   'หน่วยประมวลผล,octa,core,ความเร็ว,1.9,ghz',
#   'หน่วยความจำ,32,gb,ตัวเครื่อง,ram,3,gb',
#   'การ์ดหน่วยความจำ',
#   'microsd,256,gb',
#   'การหาตำแหน่ง,assisted,gps',
#   'wifi,802.11,b,g,n,ac,จุดกระจายสัญญาณอินเตอร์เน็ตแบบพกพา,portable,wi,fi,hotspot,เชื่อมต่อไร้สายระหว่างอุปกรณ์โดยตรง,wi,fi,direct',
#   'bluetooth,4.2,รองรับ,ชุดหูฟังสเตอริโอ,2,dp,bluetooth,stereo',
#   'รองรับ,nfc,near,field,co,มม.,unication',
#   'ant',
#   'usb,type,c',
#   'ช่องเสียบชุดหูฟัง,3.,มม.',
#   'โซเชียลเน็ตเวิร์คแอพฯ,facebook,twitter',
#   'กล้องดิจิตอล,16,ล้านพิกเซล,digital,camera,รูรับแสงขนาด,1.9,ไฟแฟลช,led,โฟกัสอัตโนมัติ,auto,focus,แตะเลือกจุดโฟกัส,touch,focus,โหมดถ่ายภาพพาโนราม่า,panorama',
#   'โหมดถ่ายภาพช่วงการรับแสงสูง,hdr',
#   'กล้องหน้า,front,camera,ความละเอียด,16,mp,รูรับแสงขนาด,1.9',
#   'บันทึกวีดีโอ,ภาพเคลื่อนไหว,video,recording,รูปแบบไฟล์วีดีโอ,mpeg,4',
#   'เครื่องเล่นวีดีโอ,video,player,รูปแบบไฟล์,mpeg,4,wmv,h,.,264,h,.,263,รองรับ,วีดีโอจาก,youtube',
#   'เครื่องเล่นเพลง,music,player,รูปแบบไฟล์,amr,nb,aac,lc,aac,eaac,mp,3,wma,flac',
#   'sms,มม.,s',
#   'ข้อความแชท,skype',
#   'สนับสนุน,gmail,google,search',
#   'ออร์กาไนเซอร์,ปฏิทิน,เครื่องคิดเลข,นาฬิกาปลุก,จดบันทึก'],
#  ['โทรศัพท์มือถือและแท็บเล็ต',
#   'smartphones',
#   'samsung,galaxy,5,2017,gold',
#   'หน้าจอแสดงผลแบบ,super,amoled,ขนาด,5.2,นิ้ว',
#   'ความละเอียดระดับ,full,hd,1080,p,1080,x,1920,พิกเซล',
#   'หน่วยความจำ,ram,ram,ขนาด,3,gb',
#   'หน่วยความจำภายในขนาด,32,gb',
#   'กล้องด้านหลังความละเอียด,16,ล้านพิกเซล',
#   'brand,ซัมซุง',
#   'sku,sa,861,elaa,8,nxs,2,anth,17866375',
#   'ระยะเวลาการรับประกัน,1,ปี',
#   'ระบบปฏิบัติการ,android',
#   'ประเภทของการรับประกัน,การรับประกันจากโรงงานในประเทศ',
#   'สภาพสินค้า',
#   'กล้องหน้า,เมกะพิกเซล,7,mp,ขึ้นไป',
#   'ระบบปฏิบัติการ,เวอร์ชัน,marshmallow',
#   'model,samsung,galaxy,5,2017,gold',
#   'หน่วยความจำ,ram,3,gb',
#   'ประเภทหน้าจอ,amoled',
#   'ขนาดหน้าจอ,นิ้ว,5.2',
#   'กล้องด้านหลัง,16,20,mp'],
#  ['โทรศัพท์มือถือและแท็บเล็ต',
#   'smartphones',
#   'samsung,galaxy,s,10,e,6,128,gb,โทรศัพท์มือถือ',
#   'galaxy,s,10,e',
#   'หน้าจอความละเอียดสูงระดับ,dynamic,amoled,ให้สีสันและความคมชัดเสมือนจอทีวีระดับพรีเมี่ยม',
#   'กล้องหลัง,2,ตัวพร้อมระบบถ่ายภาพอัจฉริยะ',
#   'brand,ซัมซุง',
#   'sku,526004055,th,942110374',
#   'ประเภทของการรับประกัน,มีการรับประกัน',
#   'model,s,10,e,6,128,gb',
#   'ระยะเวลาการรับประกัน,1,ปี'],
#  ['โทรศัพท์มือถือและแท็บเล็ต',
#   'smartphones',
#   'smartphone,โทรศัพท์มือถือ,samsung,galaxy,10,s,sm,107,m,ขนาดหน้าจอ,6.2,นิ้ว,ram,2,rom,32,gb,สีเขียว',
#   'brand,ซัมซุง',
#   'sku,571320012,th,1048806072',
#   'มือถือ,smartphone',
#   'ระยะเวลาการรับประกัน,1,เดือน',
#   'ประเภทของการรับประกัน,มีการรับประกันจากผู้ขาย',
#   'ประเภทของ,แบตเตอรี่,แบตเตอรี่,ชาร์จใหม่ได้และถอดได้',
#   'สภาพสินค้า',
#   'กล้องหน้า,เมกะพิกเซล,7,mp,ขึ้นไป',
#   'model,smartphone,โทรศัพท์มือถือ,samsung,galaxy,10,s,sm,107,m,ขนาดหน้าจอ,6.2,นิ้ว,ram,2,rom,32,gb,สีเขียว',
#   'ประเภทหน้าจอ,lcd',
#   'กล้องด้านหลัง,11,15,mp',
#   'ppi,500,ppi',
#   'ความละเอียดวิดีโอ,1080,p',
#   'resolution,full,hd',
#   'ความจุ,แบตเตอรี่,1000,mah,5000,mah'],
#  ['โทรศัพท์มือถือและแท็บเล็ต',
#   'smartphones',
#   'samsung,10,s,ram,2,gb,rom,32,gr,มือ,1,ประกันศูนย์,1,ปี',
#   'ขนาดเครื่อง,156.9,x,75.8,x,7.8,มม.,หนัก,168,กรัม,หน้าจอ,pls,tft,lcd,ความละเอียด,720,x,1520,พิกเซล,hd,ขนาด,6.2,นิ้ว',
#   'ชิปเซต,mediatek,mt,6762,helio,p,22,ประมวลผล,octa,core,2.0,ghz,cortex,53,gpu,powervr,ge,8320',
#   'หน่วยความจำ,ram,2,gb,rom,32,gb,รองรับ,หน่วยความจำเสริม,microsd,card,512,gb',
#   'กล้องหลัง,เลนส์คู่,กล้องหลัก,13,ล้านพิกเซล,รูรับแสง,f,1.8,มีระบบออโต้โฟกัส',
#   'กล้อง,depth,sensor,2,ล้านพิกเซล,รูรับแสง,f,2.4',
#   'รองรับ,การบันทึกวีดีโอสูงสุด,fhd,1920,x,1080,30,fps',
#   'กล้องหน้า,8,ล้านพิกเซล,รูรับแสง,f,2.0,รองรับ,การทำงานสองซิม',
#   'สัญญานเครือข่ายที่,รองรับ,2,g,gsm,3,g,wcdma,4,g,lte,fdd,4,g,lte,tdd',
#   'รองรับ,wi,fi,802.11,b,g,n,2.4,ghz,wi,fi,direct,สนับสนุน,bluetooth,4.2',
#   'เทคโนโลยีระบุพิกัด,gps,glonass,galileo',
#   'มีสแกนลายนิ้วมือ,และปลดล็อคด้วยใบหน้า',
#   'แบตเตอรี่,ขนาด,4000,mah',
#   'ระบบปฏิบัติการ,android,9,pie,oneui',
#   'สีที่จำหน่ายในไทย,เขียว,ดำ,แดง',
#   'ราคาเปิดตัว,4490,บาท',
#   'brand,ซัมซุง',
#   'sku,594306208,th,1115720937',
#   'ประเภทของการรับประกัน,การรับประกันจากโรงงานในประเทศ',
#   'กล้องหน้า,เมกะพิกเซล,7,mp,ขึ้นไป',
#   'model,samsung,10,s',
#   'กล้องด้านหลัง,11,15,mp',
#   'ระยะเวลาการรับประกัน,1,ปี',
#   'ความจุ,แบตเตอรี่,1000,mah,5000,mah'],
#  ['samsung,galaxy,30,4,gb,ram,64,gb,rom,6.4,นิ้ว,3,กล้อง,16,mp,ff,f,2.0,โทรศัพท์มือถือ,฿,5990.00,฿,7290.00,18,เปอร์เซนต์',
#   'ซื้อ,1,แถม,1,ฟรี,สำหรับ,vivo,v,9,v,11,v,11,v,7,y,15,pro,y,12,หลายรุ่น,non,slip,soft,3,d,คาร์บอนไฟเบอร์ฝาหลังฟิล์มป้องกันด้านหลังสติกเกอร์ป้องกัน,฿,55.00,฿,92.00,40,เปอร์เซนต์',
#   'samsung,galaxy,tab,s,6,6,gb,128,gb,แท็บเล็ต,฿,23900.00,฿,25900.00,8,เปอร์เซนต์',
#   'samsung,galaxy,watch,active,สมาร์ทวอทช์,smart,watch,฿,5890.00,฿,8900.00,34,เปอร์เซนต์',
#   'samsung,galaxy,note,10,leather,cover,เคสโทรศัพท์,฿,1490.00,฿,1590.00,6,เปอร์เซนต์',
#   'samsung,galaxy,note,10,plus,256,gb,snap,855,฿,27100.00,฿,37900.00,28,เปอร์เซนต์',
#   '3,g,4,g,เสาอากาศภายนอก,cpe,ไวไฟเราเตอร์พร้อมกับซิมการ์ด,lte,fdd,เราเตอร์ไร้สาย,lan,wan,wi,fi,ฮอตสปอตโมเด็ม,฿,1499.00,฿,2930.00,49,เปอร์เซนต์',
#   'samsung,galaxy,50,ram,6,rom,128,฿,7450.00,฿,11490.00,35,เปอร์เซนต์',
#   'apple,iphone,7,32,gb,โทรศัพท์,second,hand,สภาพใหม่,90,เปอร์เซนต์,ไม่ผ่านการซ่อมบำรุง,฿,5199.00,฿,9999.00,48,เปอร์เซนต์',
#   'samsung,galaxy,buds,หูฟัง,บลูทูธ,หูฟังไร้สาย,฿,4199.00,฿,4990.00,16,เปอร์เซนต์',
#   'apple,ipad,10.2,inch,wi,fi,ipad,7,th,gen,2019,฿,10500.00,฿,10900.00,4,เปอร์เซนต์',
#   'samsung,galaxy,fit,e,สมาร์ทวอทช์,smart,watch,฿,1080.00,฿,1290.00,16,เปอร์เซนต์'],
#  ['โทรศัพท์มือถือและแท็บเล็ต',
#   'smartphones',
#   'samsung,galaxy,s,10,8,gb,ram,128,gb,rom,6.1,นิ้ว,4,กล้อง,16,mp,ff,f,2.2,โทรศัพท์มือถือ',
#   'หน้าจอ,6.1,นิ้ว,ความละเอียด,3040,x,1440,quad,hd,550,ppi',
#   'กล้องหลัง,3,ตัว,16,mp,f,2.2,ultra,wide,12,mp,f,1.5,2.4,wide,12,mp,f,2.4,tele',
#   'กล้องหน้า,10,mp,f,1.9',
#   'หน่วยประมวลผล,octa,core,snapdragon,855,octa,core,exynos,9,9820',
#   'ram,8,128,gb',
#   'แบตเตอรี่,3400,mah,typical',
#   'brand,ซัมซุง',
#   'sku,289434461,th,479544867',
#   'ประเภทของการรับประกัน,มีการรับประกัน',
#   'model,s,10,128,gb',
#   'ระยะเวลาการรับประกัน,1,ปี'],
#  ['โทรศัพท์มือถือและแท็บเล็ต',
#   'smartphones',
#   'samsung,20,s,ram,3,gb,rom,32,gb,มือ,1,ประกันศูนย์,1,ปี',
#   'คุณสมบัติ,samsung,20,s',
#   'ขนาด,น้ำหนัก,163.3,77.5,หนา,8,มม.,น้ำหนัก,183,กรัม',
#   'จอภาพ,ชนิดจอ,จอสัมผัส,tft,ขนาด,ความละเอียด,6.5,นิ้ว,264,ppi,720,1560,px',
#   'หน้าจอ,tft,infinity,u,display,ขนาด,6.5,นิ้ว,ความละเอียด,hd,720,x,1560,พิกเซล,อัตราส่วนหน้าจอ,19.5,9',
#   'หน่วยประมวลผล,cpu,snapdragon,450,หน่วยประมวลผล,gpu,adreno,506',
#   'หน่วยความจำ,ram,3,gb,rom,32,gb,micro,sd,512,gb,รองรับ,2,ซิมการ์ด,รองรับ,การเพิ่มความจำด้วย,microsd,card,512,gb',
#   'กล้องหลัง,3,ตัว,ประกอบด้วย',
#   'เลนส์หลัก,ความละเอียด,13,mp,f,1.8,เลนส์,ultra,wide,120,องศา,ความละเอียด,8,mp,f,2.2,เลนส์,depth,ความละเอียด,5,mp,f,2.2',
#   'กล้องหน้า,ความละเอียด,8,mp,f,2.0',
#   'รองรับ,ระบบเสียง,dolby,atmos,เซ็นเซอร์,accelerometer,fingerprint,sensor,gyro,sensor,geomagnetic,sensor,light,sensor,proximity,sensor,การเชื่อมต่อ,bluetooth,4.2,wi,fi,802.11,b,g,n,2.4,ghz,3.5,มม.,earjack,usb,type,c,wi,fi,direct,gps,glonass,beidou,galileo,pc,sync,.,2,g,gsm,850,gsm,900,dcs,1800,pcs,1900,3,g,b,1,2100,b,2,1900,b,5,850,b,8,900,4,g,lte',
#   'แบตเตอรี่,ความจุ,4000,mah,รองรับ,15,w,fast,charging,ระบบปฎิบัติการ,android,9.0,pi',
#   'มีสีให้เลือก,colors,ดำ,แดง,เขียว',
#   'brand,ซัมซุง',
#   'sku,594338092,th,1115814517',
#   'ประเภทของการรับประกัน,การรับประกันจากโรงงานในประเทศ',
#   'กล้องหน้า,เมกะพิกเซล,7,mp,ขึ้นไป',
#   'model,samsung,20,s',
#   'กล้องด้านหลัง,11,15,mp',
#   'ระยะเวลาการรับประกัน,1,ปี',
#   'ความจุ,แบตเตอรี่,1000,mah,5000,mah'],
#  ['โทรศัพท์มือถือและแท็บเล็ต',
#   'smartphones',
#   'samsung,galaxy,80,8,128,gb,โทรศัพท์มือถือ,แถมฟรี,หูฟัง,akg,y,500,มูลค่า,3990,บาท,แถมเพิ่ม,travel,set,มูลค่า,2990,บาท',
#   'หน้าจอ,super,amoled,ขนาด,6.7,นิ้ว,ความละเอียด,fhd,1080,x,2400',
#   'cpu,snapdragon,730',
#   'ram,8,gb,ddr,4',
#   'ความจุ,128,gb,ufs,2.1,รองรับ,microsd,card',
#   'กล้องหน้า,48,mp,f,2.0,imx,586,ultra,wide,8,mp,f,2.2,tof',
#   'สแกนนิ้วมือบนหน้าจอ',
#   'แบตเตอรี่,3700,mah,รองรับ,super,fast,charging,25,w',
#   'brand,ซัมซุง',
#   'sku,340860812,th,661136678',
#   'มือถือ,smartphone',
#   'ระยะเวลาการรับประกัน,1,ปี',
#   'ระบบปฏิบัติการ,android',
#   'ประเภทของการรับประกัน,มีการรับประกัน',
#   'คุณสมบัติของโทรศัพท์,ทัชสกรีน',
#   'ระบบปฏิบัติการ,เวอร์ชัน,android,9.0,pie',
#   'model,80',
#   'หน่วยความจำ,ram,8,gb',
#   'ขนาดหน้าจอ,นิ้ว,6.7',
#   'ความจุ,แบตเตอรี่,3000,3999,mah',
#   'ช่องเสียบแบบบาง,คู่'],
#  ['โทรศัพท์มือถือและแท็บเล็ต',
#   'smartphones',
#   'samsung,galaxy,note,9,6,gb,128,gb,เครื่องศูนย์,มีประกัน,ocean,blue',
#   'เทคโนโลยีการรับ,ส่งข้อมูล,2,g,edge,gprs,3,g,hspa,4,g',
#   'ใช้งาน,nano,sim',
#   'รองรับ,2,ซิมการ์ด',
#   'จอแสดงผล,super,amoled,24,bit,16,ล้านสี,ระบบสัมผัส,multi,touch,6.4,นิ้ว,แนวทะแยง,ความละเอียด,2960,x,1440,พิกเซล,capacitive,corning,gorilla,glass,5,ระบบป้องกัน,ฝุ่นละออง,resistance,dust',
#   'ระบบเซ็นเซอร์,sensor,ระบบตรวจสอบลายนิ้วมือ,finger,print,ระบบจดจำใบหน้า,face,detection,ระบบหมุนภาพอัตโนมัติ,accelerometer,ระบบเปิด,ปิดหน้าจออัตโนมัติขณะสนทนา,proximity,ระบบเซนเซอร์หมุนภาพ,gyroscope,ระบบวัดความกดอากาศ,barometer,รองรับ,s,pen,ระบบปากกาอัจฉริยะ,ระบบสแกนม่านตา',
#   'คุณสมบัติการกันน้ำ,waterproof,กันน้ำได้ชั่วคราว',
#   'ระบบปฏิบัติการ,android,8.1,oreo',
#   'หน่วยประมวลผล,exynos,9810,octa,core,ความเร็ว,2.7,ghz',
#   'หน่วยความจำ,rom,128,gb,ram,6,gb',
#   'การ์ดหน่วยความจำ',
#   'microsd,512,gb',
#   'usb,type,c',
#   'ช่องเสียบชุดหูฟัง,3.,มม.',
#   'กล้องดิจิตอล,12,12,ล้านพิกเซล,dual,camera,รูรับแสงขนาด,1.5,ไฟแฟลช,led,ซูมออฟติคอล,2,2,x,optical,zoom,โฟกัสอัตโนมัติ,auto,focus,แตะเลือกจุดโฟกัส,touch,focus,ระบบป้องกันภาพสั่นไหวแบบออปติคอล,ois,ค้นหาใบหน้าอัตโนมัติ,face,detection,โหมดถ่ายภาพพาโนราม่า,panorama',
#   'โหมดถ่ายภาพช่วงการรับแสงสูง,hdr',
#   'กล้องหน้า,front,camera,ความละเอียด,8,mp,รูรับแสงขนาด,1.7',
#   'บันทึกวีดีโอ,ภาพเคลื่อนไหว,video,recording,slow,motion,รูปแบบไฟล์วีดีโอ,mpeg,4',
#   'ระบบเสียง,dolby,atmos',
#   'ลำโพงคู่,dual,loud,speaker',
#   'ไมโครโฟนสำหรับตัดเสียงรบกวนการสนทนา',
#   'เทคโนโลยีเพิ่มความเร็วในการชาร์จ',
#   'มีระบบชาร์จไร้สายในตัว',
#   'แบตเตอรี่,มาตรฐาน,4000,mah,standard,battery',
#   'brand,ซัมซุง',
#   'sku,283666353,th,461390461',
#   'ประเภทของการรับประกัน,การรับประกันจากโรงงานในประเทศ',
#   'model,samsung,galaxy,note,9,6,gb,128,gb,เครื่องศูนย์,มีประกัน,ocean,blue',
#   'ระยะเวลาการรับประกัน,1,ปี',
#   'ระบบปฏิบัติการ,android'],
#  ['โทรศัพท์มือถือและแท็บเล็ต',
#   'smartphones',
#   'samsung,galaxy,10,s,สมาร์ทโฟน,กล้องหลัง,คู่,13,2,mp,แบต,4000,mah,ประกันศูนย์,1,ปี,แถมฟรีหูฟังซัมซุง,มูลค่า,399,บาท',
#   'ตัวเครื่อง,156.9,x,75.8,x,7.,มม.',
#   'น้ำหนัก,168,กรัม',
#   'หน้าจอแสดงผล,tft,lcd,6.2,นิ้ว,ความละเอียด,1520,x,720,พิกเซล,hd,มีดีไซน์รอยแหว่งแบบ,infinity,v',
#   'ชิปเซ็ต,mediatek,helio,p,22',
#   'ram,2,gb',
#   'rom,32,gb,microsd,card,ได้สูงสุด,512,gb',
#   'ระบบปฏิบัติการ,one,ui,1.1,บนพื้นฐาน,android,9,pie',
#   'กล้องหลัง,2,เลนส์,พร้อมไฟแฟลชเลนส์หลัก,ความละเอียด,13,ล้านพิกเซล,รูรับแสง,f,1.8',
#   'เลนส์,depth,ความละเอียด,2,ล้านพิกเซล,รูรับแสง,f,2.4',
#   'กล้องหน้า,ความละเอียด,8,ล้านพิกเซล,รูรับแสง,f,2.2',
#   'ซิมการ์ด,รองรับ,2,ซิมแบบ,nano,sim',
#   'การเชื่อมต่อ,w,fi,2.4,ghz,blurtooth,4.2,พอร์ต,micro,usb,2.0,ช่องเสียบหูฟัง,3.,มม.',
#   'ระบบความปลอดภัย,รหัส,สแกนใบหน้า,สแกนลายนิ้วมือ',
#   'แบตเตอรี่,4000,mah',
#   'ตัวเครื่อง,samsung,galaxy,10,s',
#   'สาย,micro,usb,2.0',
#   'อะแดปเตอร์',
#   'ที่นำซิมออก',
#   'ถาดซิม',
#   'คู่มือการใช้งาน,และใบรับประกัน',
#   'brand,ซัมซุง',
#   'sku,616572478,th,1170962904',
#   'มือถือ,smartphone',
#   'ระยะเวลาการรับประกัน,1,ปี',
#   'ประเภทของการรับประกัน,มีการรับประกัน',
#   'ประเภทของ,แบตเตอรี่,built,rechargeable,battery',
#   'สภาพสินค้า',
#   'คุณสมบัติของโทรศัพท์,หน่วยความจำที่ขยายได้เซ็นเซอร์ตรวจลายนิ้วมือ,gps,ทัชสกรีน',
#   'กล้องหน้า,เมกะพิกเซล,7,mp,ขึ้นไป',
#   'ระบบปฏิบัติการ,เวอร์ชัน,android,9.0,pie',
#   'model,samsung,galaxy,10,s,sm,107,f'],
#  ['โทรศัพท์มือถือและแท็บเล็ต',
#   'smartphones',
#   'samsung,galaxy,j,4,plus,ประกันศูนย์,pink',
#   'brand,ซัมซุง',
#   'sku,307684896,th,537048806',
#   'ประเภทของการรับประกัน,การรับประกันจากโรงงานในประเทศ',
#   'model,samsung,galaxy,j,4,plus',
#   'ระยะเวลาการรับประกัน,1,ปี'],
#  ['โทรศัพท์มือถือและแท็บเล็ต',
#   'smartphones',
#   'samsung,galaxy,note,10,8,256,gb,โทรศัพท์มือถือ',
#   'ขนาดหน้าจอ,6.3,นิ้ว',
#   'ram,8,gb',
#   'ความจุ,storage,256,gb',
#   'แบตเตอรี่,3500,mah,typical',
#   'มาตรฐานการกันน้ำและกันฝุ่น,ip,68',
#   'brand,ซัมซุง',
#   'sku,373972071,th,728742055',
#   'ประเภทของการรับประกัน,มีการรับประกัน',
#   'model,8,256,gb',
#   'ระยะเวลาการรับประกัน,1,ปี'],
#  ['โทรศัพท์มือถือและแท็บเล็ต',
#   'smartphones',
#   'samsung,galaxy,note,8,64,gb,midnight,แถมฟรีฟิล์มใสติดเครื่อง,เคสใส',
#   'หน้าจอกว้างขนาด,6.3,ใหญ่ที่สุดในตระกูล,note',
#   'ปากกาอัจฉริยะ,s,pen,มิติใหม่แห่งการสื่อสาร',
#   'ถ่ายภาพได้คมชัดแม้ในที่แสงน้อย',
#   'โพรเซสเซอร์ประสิทธิภาพสูง,10,nm,หน่วยความจำ,6,gb',
#   'เปลี่ยนโอนข้อมูลด้วย,smart,switch',
#   'หน้าจอกว้างขึ้น,ด้วยขนาด,6.3,ใหญ่ที่สุดในตระกูล,note,มอบภาพที่คมชัด,แจ้มแจ้งในทุกรายละเอียด',
#   'สร้างความแตกต่างใบแบบที่เป็นคุณด้วยการวาด,emojis,ส่วนตัว,ผ่านปากกาอัจฉริยะ,s,pen',
#   'มีทั้งกล้องมุมกว้าง,ซึ่งสามารถถ่ายภาพได้ดีในสภาวะแสงน้อย',
#   'โพรเซสเซอร์ประสิทธิภาพสูง,10,nm,หน่วยความจำ,6,gb,เพื่อการทำงานที่ลื่นไหลมากขึ้น',
#   'เทคโนโลยี,phone,ช่วยให้คุณเชื่อมต่อกับโลกได้กว้างขึ้น,ระหว่างตัวอุปกรณ์กับอินเตอร์เฟซต่าง',
#   'เปลี่ยนถ่าย,และโอนข้อมูลง่ายๆ,smart,switch,เพื่อให้ทันการอัพเดททุกเรื่องราวในชีวิต',
#   'รับชมภาพยนตร์ได้สนุกสนานยิ่งขึ้นด้วยอัตราส่วนภาพ,18,9,ในโหมดแนวนอน,เพิ่มพื้นที่ในการรับชมมากขึ้นถึง,14,เปอร์เซนต์',
#   'ตัวดีไซน์แบบไร้รอยต่อ,พร้อมเพิ่มพื้นที่ในการขีดเขียนอย่างอิสระ,และเครื่องสแกนลายนิ้วมือที่อยู่ด้านหลัง,สะดวกต่อการใช้งาน',
#   'โหมด,multi,window,เปิดสองแอปพลิเคชันพร้อมกันด้วยการแท็บเพียงครั้งเดียว',
#   'อัตราส่วน,หน้าจอขนาด,18,5,9,ช่วยให้คุณเห็นรายละเอียดบนหน้าจอที่มาก,ปรับแต่งรายการต่างๆ,พร้อมขยับจอน้อยลง',
#   'brand,ซัมซุง',
#   'sku,310302392,th,552106447',
#   'ประเภทของการรับประกัน,มีการรับประกันจากผู้ขาย',
#   'model,sm,n,950',
#   'ระยะเวลาการรับประกัน,1,ปี'],
#  ['โทรศัพท์มือถือและแท็บเล็ต',
#   'smartphones',
#   'samsung,galaxy,9,2018,6,128,gb,เครื่องศูนย์,เคลียสตอคไม่มีประกัน,caviar,black',
#   'จอแสดงผล,super,amoled,24,bit,16,ล้านสี,fullview,display,6.3,นิ้ว',
#   'ระบบตรวจสอบลายนิ้วมือ,fingerprint,ระบบจดจำใบหน้า,face,detection',
#   'กล้องดิจิตอล,main,camera,24,mp,ultra,wide,camera,8,mp,telephoto,camera,10,mp,depth,camera,5,mp,fourth,camera,รูรับแสงขนาด,1.7',
#   'กล้องหน้า,ความละเอียด,24,mp',
#   'ram,6,gb',
#   'หน่วยความจำตัวเครื่อง,128,gb',
#   'brand,ซัมซุง',
#   'sku,280354579,th,453591358',
#   'ระยะเวลาการรับประกัน,5',
#   'ระบบปฏิบัติการ,android',
#   'ประเภทของการรับประกัน,ไม่มีการประกัน',
#   'กล้องหน้า,เมกะพิกเซล,7,mp,ขึ้นไป',
#   'ระบบปฏิบัติการ,เวอร์ชัน,android,8.0,oreo',
#   'model,samsung,galaxy,9,2018,6,128,gb,เครื่องศูนย์,เคลียสตอคไม่มีประกัน,caviar,black',
#   'หน่วยความจำ,ram,6,gb',
#   'ขนาดหน้าจอ,นิ้ว,6.3',
#   'กล้องด้านหลัง,21,mp,ขึ้นไป',
#   'ความจุ,แบตเตอรี่,1000,mah,5000,mah',
#   'ช่องเสียบแบบบาง,คู่'],
#  ['โทรศัพท์มือถือและแท็บเล็ต',
#   'smartphones',
#   'samsung,70,ram,8,128,เครื่องศูนย์เคลียร์สต๊อค',
#   'จอแสดงผล,super,amoled,24,bit,16,ล้านสี,หน้าจอทรงหยดน้ำ,รูปตัว,u,infinity,u,ระบบสัมผัส,multi,touch,6.7,นิ้ว,แนวทะแยง,ความละเอียด,1080,x,2400,พิกเซล,capacitive,ระบบเซ็นเซอร์,sensor,ระบบสแกนลายนิ้วมือใต้หน้าจอ,fingerprint,display,ระบบจดจำใบหน้า,face,detection,ระบบหมุนภาพอัตโนมัติ,accelerometer,ตรวจจับแสงปรับความสว่างอัตโนมัติ,ambient,light,ระบบเปิด,ปิดหน้าจออัตโนมัติขณะสนทนา,proximity,ระบบเซนเซอร์หมุนภาพ,gyroscope,ปรับมุมมองการแสดงผลอัตโนมัติ,orientation,ระบบปฏิบัติการ,android,9,pie,หน่วยประมวลผล,snapdragon,675,octa,core,ความเร็ว,2.0,ghz,หน่วยความจำ,rom,128,gb,ram,8,gb,การ์ดหน่วยความจำ,microsd,512,gb,กล้องดิจิตอล,32,mp,8,ultra,wide,5,triple,camera,รูรับแสงขนาด,1.7,ไฟแฟลช,led,ค้นหาใบหน้าอัตโนมัติ,face,detection,เทคโนโลยีถ่ายภาพอัจฉริยะ,ai,camera,โหมดปรับหน้าสวยอัตโนมัติ,ai,face,beauty,โหมดเปลี่ยนภาพเซลฟี่เป็นอิโมจิ,ar,emoji,โหมดเปลี่ยนภาพเซลฟี่เป็นสติกเกอร์,ar,sticker,โหมดถ่ายภาพพาโนราม่า,panorama,โหมดถ่ายภาพช่วงการรับแสงสูง,hdr,กล้องหน้า,front,camera,ความละเอียด,32,รูรับแสงขนาด,2.0,กล้องหน้า,hdr,บันทึกวีดีโอ,ภาพเคลื่อนไหว,video,recording,รูปแบบไฟล์วีดีโอ,mpeg,4,เครื่องเล่นวีดีโอ,video,player,รูปแบบไฟล์,mpeg,4,รองรับ,วีดีโอจาก,youtube,เครื่องเล่นเพลง,music,player,รูปแบบไฟล์,mp,3,ระบบเสียง,dolby,atmos,เทคโนโลยีเพิ่มความเร็วในการชาร์จ,แบตเตอรี่,มาตรฐาน,4500,mah,standard,battery',
#   'brand,ซัมซุง',
#   'sku,595150747,th,1117932783',
#   'ประเภทของการรับประกัน,ไม่มีการประกัน',
#   'model,samsung,70'],
#  ['โทรศัพท์มือถือและแท็บเล็ต',
#   'smartphones',
#   'samsung,galaxy,6,4,32,gb',
#   'จอคุณภาพสูง,full,front,display,samoled',
#   'กล้องหน้า,หลังความละเอียดเท่ากัน,16,mp',
#   'กล้องหน้า,มาพร้อม,3,step,lighting,ช่วยปรับแสงได้,3,ระดับ,กล้องหลัง,รูรับแสงกว้าง,f,1.7',
#   'ถ่ายสนุกด้วยโหมดเซลฟี่หน้าชัดหลังละลาและเซลฟี่สติ๊กเกอร์,ar,sticker,ที่มีแบบให้เลือกมากกว่า,30',
#   'app,pair,สามารถเปิด,2,แอพที่ชอบได้พร้อมกัน,2,หน้าจอในคลิ๊กเดียว',
#   'แชทได้พร้อมกัน,2,บัญชีในเครื่องเดียว,รองรับ,แอพ,social,เยอะที่สุดถึง,18,แอพ',
#   'brand,ซัมซุง',
#   'sku,264741378,th,411062149',
#   'ประเภทของการรับประกัน,มีการรับประกัน',
#   'model,galaxy,6,sm,605,g,ds',
#   'หน่วยความจำ,ram,4,gb',
#   'ขนาดหน้าจอ,นิ้ว,6',
#   'ระยะเวลาการรับประกัน,1,ปี',
#   '262.0'],
#  ['โทรศัพท์มือถือและแท็บเล็ต',
#   'smartphones',
#   'samsung,galaxy,50,s,128,gb,6,gb,ram,original,set',
#   'samsung,galaxy,50,s,128,gb,6,gb,ram,original,set,brand,new,original,packaging,undamaged,unopened,unused,item,original,packaging,found,retail,store,unless,item,handmade,packaged,manufacturer,non,retail,packaging,unprinted,box,plastic,bag',
#   'brand,ซัมซุง',
#   'sku,617108827,th,1172618764',
#   'ประเภทของการรับประกัน,มีการรับประกัน',
#   'ระบบปฏิบัติการ,เวอร์ชัน,android,9.0,pie',
#   'model,samsung,galaxy,50,s,128,gb,6,gb,ram,original,set',
#   'ระยะเวลาการรับประกัน,1,ปี',
#   'ช่องเสียบแบบบาง,คู่'],
#  ['โทรศัพท์มือถือและแท็บเล็ต',
#   'smartphones',
#   'samsung,galaxy,20,s,3,32,gb,โทรศัพท์มือถือ',
#   'galaxy,20,s',
#   'สนุกทุกประสบการณ์กับหน้าจอใหญ่ที่เต็มตากว่าเดิม',
#   'ด้านหลังเรียบเงา,ใช้งานได้ถนัดมือ',
#   'เด่นทุกมุมมองด้วยกล้องสามเลนส์',
#   'brand,ซัมซุง',
#   'sku,511068392,th,907938105',
#   'ประเภทของการรับประกัน,มีการรับประกัน',
#   'model,galaxy,20,s,3,32,gb',
#   'ระยะเวลาการรับประกัน,1,ปี'],
#  ['โทรศัพท์มือถือและแท็บเล็ต',
#   'smartphones',
#   'refurbish,samsung,galaxy,8,2018,gold',
#   'หน้าจอใหญ่,super,amoled,5.6,นิ้ว,สัดส่วน,18.5,9',
#   'ชิพเซต,exynos,7885,octa,core,2.2,ghz',
#   'rom,32,gb,ram,4,gb,microsd,256,gb',
#   'ระบบปฏิบัติการ,แอนดรอยด์,7.1,nougat',
#   'กล้องถ่ายภาพ,16,ล้านพิกเซล,รูรับแสงกว้าง,f,1.7',
#   'กล้องหน้า,แบบคู่,16,8,ล้านพิกเซล,รูรับแสง,f,1.9',
#   'กล้องหน้า,รองรับ,live,focus,ปรับฉากหลังละลายได้',
#   'ปลดล็อคหน้าจอด้วยการสแกนใบหน้า',
#   'รองรับ,การใช้งาน,secure,folder',
#   'รองรับ,การสแกนลายนิ้วมือ',
#   'จ่ายเงินผ่าน,samsung,pay',
#   'ตัวเครื่องกันน้ำลึก,1.5,เมตรนาน,30,นาที,มาตรฐาน,ip,68',
#   'หน้าจอใหญ่,super,amoled,5.6,นิ้ว,สัดส่วน,18.5,9',
#   'ชิพเซต,exynos,7885,octa,core,2.2,ghz',
#   'rom,32,gb,ram,4,gb,microsd,256,gb',
#   'ระบบปฏิบัติการ,แอนดรอยด์,7.1,nougat',
#   'กล้องถ่ายภาพ,16,ล้านพิกเซล,รูรับแสงกว้าง,f,1.7',
#   'กล้องหน้า,แบบคู่,16,8,ล้านพิกเซล,รูรับแสง,f,1.9',
#   'กล้องหน้า,รองรับ,live,focus,ปรับฉากหลังละลายได้',
#   'ปลดล็อคหน้าจอด้วยการสแกนใบหน้า',
#   'รองรับ,การใช้งาน,secure,folder',
#   'รองรับ,การสแกนลายนิ้วมือ',
#   'จ่ายเงินผ่าน,samsung,pay',
#   'ตัวเครื่องกันน้ำลึก,1.5,เมตรนาน,30,นาที,มาตรฐาน,ip,68',
#   'brand,ซัมซุง',
#   'sku,207916690,th,313021622',
#   'ประเภทของการรับประกัน,มีการรับประกัน',
#   'model,refurbish,samsung,galaxy,8,2018,gold',
#   'ระยะเวลาการรับประกัน,3,เดือน'],
#  ['โทรศัพท์มือถือและแท็บเล็ต',
#   'smartphones',
#   'samsung,galaxy,s,10,8,gb,ram,128,gb,rom,6.4,นิ้ว,5,กล้อง,16,mp,ff,f,2.2,โทรศัพท์มือถือ',
#   'หน้าจอ,6.4,นิ้ว,ความละเอียด,3040,x,1440,quad,hd,550,ppi',
#   'กล้องหลัง,3,ตัว,16,mp,f,2.2,ultra,wide,12,mp,f,1.5,2.4,wide,12,mp,f,2.4,tele',
#   'กล้องหน้า,2,ตัว,10,mp,f,1.9,main,8,mp,f,2.2,live,focus',
#   'หน่วยประมวลผล,octa,core,snapdragon,855,octa,core,exynos,9,9820',
#   'ram,8,128,gb',
#   'แบตเตอรี่,4100,mah,typical',
#   'brand,ซัมซุง',
#   'sku,289426638,th,479560515',
#   'ประเภทของการรับประกัน,มีการรับประกัน',
#   'model,s,10,128,gb',
#   'ระยะเวลาการรับประกัน,1,ปี',
#   '139'],
#  ['โทรศัพท์มือถือและแท็บเล็ต',
#   'smartphones',
#   'samsung,j,8,ram,3,32,gb,เครื่องศูนย์ประกันมีเดือน,สีทอง,แถมฟรี,เคสใส,ฟิลม์กระจก',
#   'ระบบปฏิบัติการ,os,cpu,ระบบปฏิบัติการ,android,8.0,oreo',
#   'หน่วยประมวลผล,qualco,มม.,snapdragon,450,octa,core',
#   'ความเร็ว,1.8,ghz',
#   'หน่วยความจำ,32,gb,ตัวเครื่อง',
#   'ram,3,gb,การ์ดหน่วยความจำ',
#   'microsd,256,gb',
#   'slide,1',
#   'slide,2',
#   'slide,1',
#   'slide,2',
#   'ความพร้อมให้บริการอาจแตกต่างกันไปในแต่ละประเทศ,ภาพต่าง,จำลองขึ้นมาเพื่อจุดประสงค์ด้านการนำเสนอเท่านั้น',
#   'brand,ซัมซุง',
#   'sku,289402378,th,479508064',
#   'ประเภทของการรับประกัน,การรับประกันจากโรงงานในประเทศ',
#   'model,samsung,j,8,ram,3,32,gb,เครื่องศูนย์ประกันมีเดือน,สีทอง,แถมฟรี,เคสใส,ฟิลม์กระจก',
#   'ระยะเวลาการรับประกัน,3,เดือน',
#   'ระบบปฏิบัติการ,android'],
#  ['xiaomi,redmi,note,8,3,gb,32,gb,สมาร์ตโฟน,4,กล้อง,ai,ความละเอียด,48,mp,จอกว้าง,6.3,นิ้ว,fhd,ชิปเซ็ต,qualco,มม.,sd,665,฿,4299.00,฿,4999.00,14,เปอร์เซนต์',
#   'เครื่องเกาหลี,นำเข้า,note,9,฿,4299.00,฿,6999.00,39,เปอร์เซนต์',
#   'samsung,wireless,battery,pack,10000,mah,พาวเวอร์แบงค์,แบตเตอรี่,สำรอง,฿,1290.00,฿,1590.00,19,เปอร์เซนต์',
#   'samsung,galaxy,note,9,snapdragon,845,ram,6,rom,128,gb,เครื่องนอกไม่มีประกัน,฿,18880.00,฿,31900.00,41,เปอร์เซนต์',
#   'samsung,galaxy,note,10,ram,8,gb,rom,256,gb,aura,pink,฿,24280.00,฿,29500.00,18,เปอร์เซนต์',
#   'samsung,galaxy,note,10,ram,8,gb,rom,256,gb,aura,glow,฿,24280.00,฿,29500.00,18,เปอร์เซนต์',
#   'samsung,galaxy,30,s,4,64,gb,โทรศัพท์มือถือ,฿,6290.00,฿,7990.00,21,เปอร์เซนต์',
#   'samsung,galaxy,20,s,4,64,gb,โทรศัพท์มือถือ,฿,5250.00,฿,6490.00,19,เปอร์เซนต์',
#   'samsung,j,2,prime,฿,1690.00',
#   'samsung,galaxy,tab,s,4,10.5,4,gb,ram,64,gb,rom,10.5,นิ้ว,แท็บเล็ต,฿,13990.00,฿,23900.00,41,เปอร์เซนต์',
#   'samsung,galaxy,90,black,฿,19230.00,฿,23500.00,18,เปอร์เซนต์',
#   'samsung,galaxy,watch,1.3,46,มม.,สมาร์ทวอทช์,smart,watch,฿,8590.00,฿,12900.00,33,เปอร์เซนต์'],
#  ['โทรศัพท์มือถือและแท็บเล็ต',
#   'smartphones',
#   'samsung,galaxy,note,10,plus,512,gb',
#   'brand,new',
#   'original',
#   'sealed,box',
#   '1,year,thailand,warranty,90,days,return',
#   'interested,n,serious,buyers,contact,line,making,payment',
#   'username,flashsale,2019,ใหม่เอี่ยม',
#   'ต้นฉบับ',
#   'ปิดผนึกในกล่อง',
#   'รับประกันประเทศไทย,1,ปีและส่งคืน,90',
#   'ผู้ซื้อที่สนใจและจริงจังควรติดต่อฉันที่ไลน์ก่อนชำระเงิน',
#   'ชื่อผู้ใช้คือ,flashsale,2019',
#   'h,m,xe,ym',
#   't,nc,hb,b',
#   'pid,p,hn,k,n,kl,xng',
#   'r,bprak,n,prathe,th,y,1,p,l,s,ng,kh,n,90,w,n',
#   'p,h,s,x,th,s,nc,l,cringc,ng,khwr,tidt,x,c,h,n,th,l,n,k,xn,ch,ra,ngein',
#   'ch,x,p,h,ch,kh,x,flashsale,2019',
#   'brand,ซัมซุง',
#   'sku,612014873,th,1155486191',
#   'ประเภทของการรับประกัน,การรับประกันจากโรงงานในประเทศ',
#   'ระบบปฏิบัติการ,เวอร์ชัน,android,8.1,oreo',
#   'model,samsung,galaxy,note,10,plus',
#   'ระยะเวลาการรับประกัน,1,ปี',
#   'ช่องเสียบแบบบาง,คู่']]

# %%
for i,v in token.items():
    tokens_list_j = [','.join(tkn) for tkn in tokens_list]

cvec = CountVectorizer(analyzer=lambda x:x.split(','))
c_feat = cvec.fit_transform(tokens_list_j)

# %%
# bag of words
cvec.vocabulary_
# Out:
# {'โทรศัพท์มือถือและแท็บเล็ต': 938,
#  'smartphones': 542,
#  'samsung': 524,
#  'galaxy': 374,
#  'm': 433,
#  '30': 117,
#  's': 521,
#  '4': 141,
#  '64': 212,
#  'gb': 376,
#  'โทรศัพท์มือถือ': 936,
#  'แบต': 921,
#  'อึดอยู่นาน': 866,
#  'สนุกได้ทั้งวัน': 811,
#  'กับความจุ': 629,
#  '6000': 206,
#  'mah': 434,
#  'และสามารถชาร์จ': 927,
#  'fast': 353,
#  'charging': 315,
#  'ระบบ': 770,
#  'กล้องหลัง': 627,
#  '3': 114,
#  'ตัว': 692,
#  'ที่มีกล้องชัดสูงสุดถึง': 703,
#  '48': 162,
#  'mp': 447,
#  'มาพร้อมกับเลนส์มุมกว้างพิเศษ': 753,
#  'ultra': 581,
#  'wide': 603,
#  'exynos': 349,
#  '9611': 264,
#  'สเป็กแรงขึ้นเล่นเกมส์ได้ไม่มีสะดุด': 830,
#  'ram': 510,
#  'rom': 520,
#  'หน้าจอแสดงผล': 853,
#  'super': 556,
#  'amoled': 276,
#  'infinity': 408,
#  'u': 577,
#  'ขนาด': 639,
#  '6.4': 202,
#  'นิ้ว': 708,
#  'brand': 304,
#  'ซัมซุง': 679,
#  'sku': 534,
#  '480942616': 163,
#  'th': 567,
#  '870640886': 253,
#  'ประเภทของการรับประกัน': 722,
#  'มีการรับประกัน': 755,
#  'model': 445,
#  'ระยะเวลาการรับประกัน': 790,
#  '1': 1,
#  'ปี': 732,
#  '793': 239,
#  '50': 171,
#  'รับประกันศูนย์': 794,
#  'jaymart': 415,
#  'gsm': 393,
#  '850': 249,
#  '900': 258,
#  '1800': 60,
#  '1900': 65,
#  'mhz': 441,
#  'g': 373,
#  'wcdma': 601,
#  '2100': 81,
#  'fdd': 354,
#  'lte': 432,
#  'b': 288,
#  '5': 167,
#  '7': 220,
#  '2600': 96,
#  '8': 241,
#  '20': 75,
#  '800': 245,
#  '28': 104,
#  '700': 226,
#  'tdd': 562,
#  '38': 135,
#  '40': 143,
#  '2300': 83,
#  '41': 146,
#  '2500': 93,
#  'รองรับ': 768,
#  '2': 68,
#  'ซิม': 680,
#  'nano': 453,
#  'sim': 533,
#  'หน่วยประมวลผล': 844,
#  '9610': 263,
#  'quad': 506,
#  '2.3': 72,
#  'ghz': 380,
#  '1.7': 5,
#  'ระบบปฏิบัติการ': 776,
#  'android': 278,
#  'หน่วยความจำภายใน': 841,
#  'micro': 442,
#  'sd': 525,
#  '512': 176,
#  'หน้าจอ': 845,
#  'ความละเอียด': 646,
#  '1080': 18,
#  'x': 609,
#  '2340': 84,
#  'พิกเซล': 743,
#  'fhd': 356,
#  'เลนส์': 905,
#  'ล้านพิกเซล': 805,
#  'f': 350,
#  '2.0': 69,
#  '2.2': 71,
#  'bokeh': 301,
#  '2.4': 73,
#  'ultrawide': 582,
#  'แฟลช': 924,
#  'led': 425,
#  'กล้องหน้า': 625,
#  '32': 125,
#  'wifi': 604,
#  '802.11': 246,
#  'n': 452,
#  'ac': 269,
#  'bluetooth': 299,
#  '5.0': 168,
#  'แบตเตอรี่': 922,
#  '4000': 144,
#  '158.5': 50,
#  '74.5': 232,
#  '7.7': 223,
#  'มม.': 748,
#  'น้ำหนัก': 709,
#  '169': 55,
#  '593772364': 190,
#  '1113954823': 22,
#  'การรับประกันจากโรงงานในประเทศ': 632,
#  'เมกะพิกเซล': 901,
#  'ขึ้นไป': 642,
#  'เวอร์ชัน': 908,
#  '9.0': 256,
#  'pie': 490,
#  'หน่วยความจำ': 838,
#  'mb': 439,
#  'และน้อยกว่า': 925,
#  'ขนาดหน้าจอ': 640,
#  'กล้องด้านหลัง': 622,
#  '21': 80,
#  'ความจุ': 644,
#  '1000': 12,
#  '5000': 173,
#  'ช่องเสียบแบบบาง': 678,
#  'คู่': 654,
#  '10': 8,
#  'สมาร์ทโฟน': 816,
#  'โทรศัพท์มือถือพร้อม': 937,
#  'จอแสดงผล': 662,
#  'tft': 566,
#  'lcd': 423,
#  '24': 87,
#  'bit': 295,
#  '16': 52,
#  'ล้านสี': 806,
#  'หน้าจอทรงหยดน้ำ': 852,
#  'รูปตัว': 797,
#  'v': 592,
#  '6.2': 200,
#  'แนวทะแยง': 920,
#  '1520': 47,
#  '720': 228,
#  'ระบบเซ็นเซอร์': 787,
#  'sensor': 530,
#  'ระบบตรวจสอบลายนิ้วมือ': 774,
#  'fingerprint': 360,
#  'ระบบหมุนภาพอัตโนมัติ': 785,
#  'accelerometer': 270,
#  'ระบบเซนเซอร์หมุนภาพ': 786,
#  'gyroscope': 395,
#  'มีสีให้เลือก': 762,
#  'colors': 317,
#  'black': 296,
#  'red': 513,
#  'green': 392,
#  'blue': 297,
#  '404422189': 145,
#  '784670279': 237,
#  'มือถือ': 765,
#  'smartphone': 541,
#  '11': 21,
#  '15': 46,
#  'เตียงเดี่ยว': 888,
#  '143': 42,
#  'note': 463,
#  '12': 32,
#  '256': 94,
#  '6.8': 205,
#  'storage': 554,
#  '4300': 152,
#  'typical': 576,
#  'มาตรฐานการกันน้ำและกันฝุ่น': 751,
#  'ip': 410,
#  '68': 218,
#  '385536916': 136,
#  '749070165': 234,
#  '243': 90,
#  '2017': 76,
#  'ระบบเปิด': 788,
#  'ปิดหน้าจออัตโนมัติขณะสนทนา': 731,
#  'proximity': 504,
#  'ระบบตรวจจับคลื่นแม่เหล็ก': 773,
#  'geomagnetic': 379,
#  'ระบบวัดความกดอากาศ': 780,
#  'barometer': 291,
#  'คุณสมบัติการกันน้ำ': 652,
#  'waterproof': 600,
#  'กันน้ำได้ชั่วคราว': 628,
#  'pink': 491,
#  'gold': 385,
#  'bluelight': 298,
#  'เทคโนโลยีการรับ': 890,
#  'ส่งข้อมูล': 834,
#  'edge': 345,
#  'gprs': 388,
#  'hspa': 405,
#  'dl': 335,
#  'ul': 580,
#  'ใช้งาน': 947,
#  'ซิมการ์ด': 681,
#  '6.0.1': 198,
#  'marshmallow': 438,
#  'octa': 467,
#  'core': 319,
#  'ความเร็ว': 649,
#  '1.9': 7,
#  'ตัวเครื่อง': 695,
#  'การ์ดหน่วยความจำ': 638,
#  'microsd': 443,
#  'การหาตำแหน่ง': 634,
#  'assisted': 284,
#  'gps': 389,
#  'จุดกระจายสัญญาณอินเตอร์เน็ตแบบพกพา': 664,
#  'portable': 497,
#  'wi': 602,
#  'fi': 357,
#  'hotspot': 404,
#  'เชื่อมต่อไร้สายระหว่างอุปกรณ์โดยตรง': 884,
#  'direct': 333,
#  '4.2': 142,
#  'ชุดหูฟังสเตอริโอ': 672,
#  'dp': 337,
#  'stereo': 552,
#  'nfc': 458,
#  'near': 456,
#  'field': 358,
#  'co': 316,
#  'unication': 585,
#  'ant': 279,
#  'usb': 590,
#  'type': 575,
#  'c': 308,
#  'ช่องเสียบชุดหูฟัง': 676,
#  '3.': 115,
#  'โซเชียลเน็ตเวิร์คแอพฯ': 934,
#  'facebook': 352,
#  'twitter': 574,
#  'กล้องดิจิตอล': 621,
#  'digital': 332,
#  'camera': 309,
#  'รูรับแสงขนาด': 802,
#  'ไฟแฟลช': 954,
#  'โฟกัสอัตโนมัติ': 940,
#  'auto': 287,
#  'focus': 364,
#  'แตะเลือกจุดโฟกัส': 913,
#  'touch': 571,
#  'ค้นหาใบหน้าอัตโนมัติ': 656,
#  'face': 351,
#  'detection': 331,
#  'โหมดถ่ายภาพพาโนราม่า': 943,
#  'panorama': 481,
#  'โหมดถ่ายภาพช่วงการรับแสงสูง': 942,
#  'hdr': 401,
#  'front': 369,
#  'บันทึกวีดีโอ': 713,
#  'ภาพเคลื่อนไหว': 747,
#  'video': 594,
#  'recording': 512,
#  'รูปแบบไฟล์วีดีโอ': 799,
#  'mpeg': 448,
#  'เครื่องเล่นวีดีโอ': 878,
#  'player': 493,
#  'รูปแบบไฟล์': 798,
#  'wmv': 608,
#  'h': 396,
#  '.': 0,
#  '264': 99,
#  '263': 98,
#  'วีดีโอจาก': 807,
#  'youtube': 617,
#  'เครื่องเล่นเพลง': 879,
#  'music': 451,
#  'amr': 277,
#  'nb': 454,
#  'aac': 268,
#  'lc': 422,
#  'eaac': 343,
#  'wma': 607,
#  'flac': 362,
#  'sms': 543,
#  'ข้อความแชท': 643,
#  'skype': 535,
#  'สนับสนุน': 809,
#  'gmail': 384,
#  'google': 386,
#  'search': 527,
#  'ไมโครโฟนสำหรับตัดเสียงรบกวนการสนทนา': 955,
#  'ออร์กาไนเซอร์': 862,
#  'ปฏิทิน': 715,
#  'เครื่องคิดเลข': 872,
#  'นาฬิกาปลุก': 706,
#  'จดบันทึก': 657,
#  'ริงโทน': 796,
#  'ระบบสั่น': 782,
#  'vibration': 593,
#  'phone': 487,
#  '9': 255,
#  '2018': 77,
#  '6': 197,
#  '128': 34,
#  '6.3': 201,
#  'กล้อง': 620,
#  'tetra': 565,
#  'cell': 313,
#  'fullview': 371,
#  'display': 334,
#  'ระบบจดจำใบหน้า': 772,
#  'main': 435,
#  'telephoto': 564,
#  'depth': 330,
#  'fourth': 367,
#  'หน่วยความจำตัวเครื่อง': 839,
#  '265390897': 101,
#  '412154584': 149,
#  '141': 41,
#  'มือ': 764,
#  'ประกันศูนย์': 718,
#  'คุณสมบัติ': 651,
#  '1560': 49,
#  '268': 102,
#  'ppi': 499,
#  'ประเภทจอ': 723,
#  'corning': 320,
#  'gorilla': 387,
#  'glass': 381,
#  '7885': 238,
#  '1.8': 6,
#  'tb': 561,
#  '25': 92,
#  'triple': 573,
#  'ลำโพงเสียงสเตอริโอ': 804,
#  'speakers': 549,
#  'เครือข่าย': 871,
#  'umts': 583,
#  'bands': 290,
#  'ระบบสแกนลายนิ้วมือใต้หน้าจอ': 784,
#  'ตรวจจับความเคลื่อนไหวของตัวเครื่อง': 690,
#  'มาตรฐาน': 750,
#  'li': 426,
#  'pol': 496,
#  'standard': 550,
#  'battery': 292,
#  'ดำขาว': 687,
#  'เขียว': 869,
#  '594352438': 193,
#  '1115888431': 25,
#  'ศูนย์ไทย': 808,
#  'plus': 495,
#  'ประกัน': 717,
#  'ประกันศูนย์ไทย': 719,
#  'เข้าศูนย์ซัมซุงได้ทั่วประเทศ': 870,
#  'เครื่องแท้': 880,
#  '100': 11,
#  'เปอร์เซนต์': 896,
#  '599364278': 196,
#  '1176694583': 31,
#  '70': 225,
#  'sm': 539,
#  '705': 227,
#  'fzbgthl': 372,
#  'สเปคเทพของเกมเมอร์': 829,
#  'หน้าจอกว้าง': 847,
#  '6.7': 204,
#  'พร้อมเลนส์': 739,
#  '309636084': 121,
#  '547152150': 182,
#  '249': 91,
#  '107': 17,
#  'สีน้ำเงิน': 827,
#  '571250946': 186,
#  '1048780375': 14,
#  'เดือน': 886,
#  'มีการรับประกันจากผู้ขาย': 756,
#  'ประเภทของ': 721,
#  'ชาร์จใหม่ได้และถอดได้': 667,
#  'สภาพสินค้า': 812,
#  'ประเภทหน้าจอ': 724,
#  '500': 172,
#  'ความละเอียดวิดีโอ': 648,
#  'p': 476,
#  'resolution': 517,
#  'full': 370,
#  'hd': 400,
#  '5.2': 169,
#  '1920': 66,
#  'หน้าจอกระจกแข็ง': 846,
#  'ระบบป้องกัน': 778,
#  'ฝุ่นละออง': 736,
#  'resistance': 516,
#  'dust': 340,
#  'หน้าจอแสดงผลแบบ': 854,
#  'ความละเอียดระดับ': 647,
#  'หน่วยความจำภายในขนาด': 842,
#  'กล้องด้านหลังความละเอียด': 623,
#  'sa': 522,
#  '861': 252,
#  'elaa': 346,
#  'nxs': 465,
#  'anth': 280,
#  '17866375': 57,
#  'e': 342,
#  'หน้าจอความละเอียดสูงระดับ': 851,
#  'dynamic': 341,
#  'ให้สีสันและความคมชัดเสมือนจอทีวีระดับพรีเมี่ยม': 952,
#  'ตัวพร้อมระบบถ่ายภาพอัจฉริยะ': 694,
#  '526004055': 179,
#  '942110374': 261,
#  'สีเขียว': 828,
#  '571320012': 187,
#  '1048806072': 15,
#  'gr': 391,
#  'ขนาดเครื่อง': 641,
#  '156.9': 48,
#  '75.8': 235,
#  '7.8': 224,
#  'หนัก': 836,
#  '168': 54,
#  'กรัม': 619,
#  'pls': 494,
#  'ชิปเซต': 668,
#  'mediatek': 440,
#  'mt': 449,
#  '6762': 217,
#  'helio': 402,
#  '22': 82,
#  'ประมวลผล': 720,
#  'cortex': 321,
#  '53': 180,
#  'gpu': 390,
#  'powervr': 498,
#  'ge': 377,
#  '8320': 247,
#  'หน่วยความจำเสริม': 843,
#  'card': 311,
#  'เลนส์คู่': 906,
#  'กล้องหลัก': 626,
#  '13': 37,
#  'รูรับแสง': 800,
#  'มีระบบออโต้โฟกัส': 761,
#  'การบันทึกวีดีโอสูงสุด': 631,
#  'fps': 368,
#  'การทำงานสองซิม': 630,
#  'สัญญานเครือข่ายที่': 819,
#  'เทคโนโลยีระบุพิกัด': 892,
#  'glonass': 382,
#  'galileo': 375,
#  'มีสแกนลายนิ้วมือ': 763,
#  'และปลดล็อคด้วยใบหน้า': 926,
#  'oneui': 470,
#  'สีที่จำหน่ายในไทย': 826,
#  'ดำ': 686,
#  'แดง': 912,
#  'ราคาเปิดตัว': 795,
#  '4490': 153,
#  'บาท': 714,
#  '594306208': 191,
#  '1115720937': 23,
#  'ff': 355,
#  '฿': 868,
#  '5990.00': 195,
#  '7290.00': 230,
#  '18': 58,
#  'ซื้อ': 684,
#  'แถม': 914,
#  'ฟรี': 744,
#  'สำหรับ': 824,
#  'vivo': 595,
#  'y': 614,
#  'pro': 503,
#  'หลายรุ่น': 858,
#  'non': 462,
#  'slip': 537,
#  'soft': 547,
#  'd': 326,
#  'คาร์บอนไฟเบอร์ฝาหลังฟิล์มป้องกันด้านหลังสติกเกอร์ป้องกัน': 650,
#  '55.00': 183,
#  '92.00': 260,
#  'tab': 560,
#  'แท็บเล็ต': 919,
#  '23900.00': 86,
#  '25900.00': 95,
#  'watch': 599,
#  'active': 271,
#  'สมาร์ทวอทช์': 815,
#  'smart': 540,
#  '5890.00': 189,
#  '8900.00': 254,
#  '34': 127,
#  'leather': 424,
#  'cover': 322,
#  'เคสโทรศัพท์': 882,
#  '1490.00': 44,
#  '1590.00': 51,
#  'snap': 544,
#  '855': 250,
#  '27100.00': 103,
#  '37900.00': 134,
#  'เสาอากาศภายนอก': 909,
#  'cpe': 323,
#  'ไวไฟเราเตอร์พร้อมกับซิมการ์ด': 958,
#  'เราเตอร์ไร้สาย': 904,
#  'lan': 421,
#  'wan': 597,
#  'ฮอตสปอตโมเด็ม': 867,
#  '1499.00': 45,
#  '2930.00': 110,
#  '49': 164,
#  '7450.00': 233,
#  '11490.00': 27,
#  '35': 130,
#  'apple': 282,
#  'iphone': 412,
#  'โทรศัพท์': 935,
#  'second': 528,
#  'hand': 397,
#  'สภาพใหม่': 813,
#  '90': 257,
#  'ไม่ผ่านการซ่อมบำรุง': 956,
#  '5199.00': 177,
#  '9999.00': 267,
#  'buds': 305,
#  'หูฟัง': 859,
#  'บลูทูธ': 711,
#  'หูฟังไร้สาย': 860,
#  '4199.00': 150,
#  '4990.00': 165,
#  'ipad': 411,
#  '10.2': 9,
#  'inch': 407,
#  'gen': 378,
#  '2019': 78,
#  '10500.00': 16,
#  '10900.00': 20,
#  'fit': 361,
#  '1080.00': 19,
#  '1290.00': 35,
#  '6.1': 199,
#  '3040': 119,
#  '1440': 43,
#  '550': 184,
#  '1.5': 4,
#  'tele': 563,
#  'snapdragon': 545,
#  '9820': 266,
#  '3400': 128,
#  '289434461': 109,
#  '479544867': 160,
#  '163.3': 53,
#  '77.5': 236,
#  'หนา': 837,
#  '183': 61,
#  'จอภาพ': 660,
#  'ชนิดจอ': 666,
#  'จอสัมผัส': 661,
#  '6.5': 203,
#  'px': 505,
#  'อัตราส่วนหน้าจอ': 865,
#  '19.5': 64,
#  'cpu': 324,
#  '450': 154,
#  'adreno': 272,
#  '506': 174,
#  'การเพิ่มความจำด้วย': 636,
#  'ประกอบด้วย': 716,
#  'เลนส์หลัก': 907,
#  '120': 33,
#  'องศา': 861,
#  'ระบบเสียง': 789,
#  'dolby': 336,
#  'atmos': 285,
#  'เซ็นเซอร์': 885,
#  'gyro': 394,
#  'light': 427,
#  'การเชื่อมต่อ': 635,
#  '3.5': 116,
#  'earjack': 344,
#  'beidou': 294,
#  'pc': 484,
#  'sync': 558,
#  'dcs': 328,
#  'pcs': 485,
#  'w': 596,
#  'ระบบปฎิบัติการ': 775,
#  'pi': 488,
#  '594338092': 192,
#  '1115814517': 24,
#  '80': 244,
#  'แถมฟรี': 915,
#  'akg': 274,
#  'มูลค่า': 766,
#  '3990': 139,
#  'แถมเพิ่ม': 918,
#  'travel': 572,
#  'set': 532,
#  '2990': 113,
#  '2400': 88,
#  '730': 231,
#  'ddr': 329,
#  'ufs': 578,
#  '2.1': 70,
#  'imx': 406,
#  '586': 188,
#  'tof': 570,
#  'สแกนนิ้วมือบนหน้าจอ': 831,
#  '3700': 132,
#  '340860812': 129,
#  '661136678': 214,
#  'คุณสมบัติของโทรศัพท์': 653,
#  'ทัชสกรีน': 701,
#  '3000': 118,
#  '3999': 140,
#  'เครื่องศูนย์': 874,
#  'มีประกัน': 759,
#  'ocean': 466,
#  'ระบบสัมผัส': 781,
#  'multi': 450,
#  '2960': 112,
#  'capacitive': 310,
#  'finger': 359,
#  'print': 502,
#  'pen': 486,
#  'ระบบปากกาอัจฉริยะ': 777,
#  'ระบบสแกนม่านตา': 783,
#  '8.1': 243,
#  'oreo': 472,
#  '9810': 265,
#  '2.7': 74,
#  'dual': 339,
#  'ซูมออฟติคอล': 685,
#  'optical': 471,
#  'zoom': 618,
#  'ระบบป้องกันภาพสั่นไหวแบบออปติคอล': 779,
#  'ois': 468,
#  'slow': 538,
#  'motion': 446,
#  'ลำโพงคู่': 803,
#  'loud': 431,
#  'speaker': 548,
#  'เทคโนโลยีเพิ่มความเร็วในการชาร์จ': 893,
#  'มีระบบชาร์จไร้สายในตัว': 760,
#  '283666353': 106,
#  '461390461': 158,
#  'แถมฟรีหูฟังซัมซุง': 917,
#  '399': 138,
#  '7.': 221,
#  'มีดีไซน์รอยแหว่งแบบ': 757,
#  'ชิปเซ็ต': 669,
#  'ได้สูงสุด': 953,
#  'one': 469,
#  'ui': 579,
#  '1.1': 2,
#  'บนพื้นฐาน': 710,
#  'พร้อมไฟแฟลชเลนส์หลัก': 740,
#  'ซิมแบบ': 682,
#  'blurtooth': 300,
#  'พอร์ต': 741,
#  'ช่องเสียบหูฟัง': 677,
#  'ระบบความปลอดภัย': 771,
#  'รหัส': 767,
#  'สแกนใบหน้า': 833,
#  'สแกนลายนิ้วมือ': 832,
#  'สาย': 822,
#  'อะแดปเตอร์': 863,
#  'ที่นำซิมออก': 702,
#  'ถาดซิม': 698,
#  'คู่มือการใช้งาน': 655,
#  'และใบรับประกัน': 930,
#  '616572478': 209,
#  '1170962904': 29,
#  'built': 306,
#  'rechargeable': 511,
#  'หน่วยความจำที่ขยายได้เซ็นเซอร์ตรวจลายนิ้วมือ': 840,
#  'j': 414,
#  '307684896': 120,
#  '537048806': 181,
#  '3500': 131,
#  '373972071': 133,
#  '728742055': 229,
#  'midnight': 444,
#  'แถมฟรีฟิล์มใสติดเครื่อง': 916,
#  'เคสใส': 883,
#  'หน้าจอกว้างขนาด': 848,
#  'ใหญ่ที่สุดในตระกูล': 950,
#  'ปากกาอัจฉริยะ': 729,
#  'มิติใหม่แห่งการสื่อสาร': 754,
#  'ถ่ายภาพได้คมชัดแม้ในที่แสงน้อย': 699,
#  'โพรเซสเซอร์ประสิทธิภาพสูง': 939,
#  'nm': 461,
#  'เปลี่ยนโอนข้อมูลด้วย': 895,
#  'switch': 557,
#  'หน้าจอกว้างขึ้น': 849,
#  'ด้วยขนาด': 688,
#  'มอบภาพที่คมชัด': 749,
#  'แจ้มแจ้งในทุกรายละเอียด': 910,
#  'สร้างความแตกต่างใบแบบที่เป็นคุณด้วยการวาด': 817,
#  'emojis': 348,
#  'ส่วนตัว': 835,
#  'ผ่านปากกาอัจฉริยะ': 735,
#  'มีทั้งกล้องมุมกว้าง': 758,
#  'ซึ่งสามารถถ่ายภาพได้ดีในสภาวะแสงน้อย': 683,
#  'เพื่อการทำงานที่ลื่นไหลมากขึ้น': 899,
#  'เทคโนโลยี': 889,
#  'ช่วยให้คุณเชื่อมต่อกับโลกได้กว้างขึ้น': 674,
#  'ระหว่างตัวอุปกรณ์กับอินเตอร์เฟซต่าง': 791,
#  'เปลี่ยนถ่าย': 894,
#  'และโอนข้อมูลง่ายๆ': 929,
#  'เพื่อให้ทันการอัพเดททุกเรื่องราวในชีวิต': 900,
#  'รับชมภาพยนตร์ได้สนุกสนานยิ่งขึ้นด้วยอัตราส่วนภาพ': 792,
#  'ในโหมดแนวนอน': 949,
#  'เพิ่มพื้นที่ในการรับชมมากขึ้นถึง': 898,
#  '14': 40,
#  'ตัวดีไซน์แบบไร้รอยต่อ': 693,
#  'พร้อมเพิ่มพื้นที่ในการขีดเขียนอย่างอิสระ': 738,
#  'และเครื่องสแกนลายนิ้วมือที่อยู่ด้านหลัง': 928,
#  'สะดวกต่อการใช้งาน': 818,
#  'โหมด': 941,
#  'window': 605,
#  'เปิดสองแอปพลิเคชันพร้อมกันด้วยการแท็บเพียงครั้งเดียว': 897,
#  'อัตราส่วน': 864,
#  'หน้าจอขนาด': 850,
#  'ช่วยให้คุณเห็นรายละเอียดบนหน้าจอที่มาก': 675,
#  'ปรับแต่งรายการต่างๆ': 727,
#  'พร้อมขยับจอน้อยลง': 737,
#  '310302392': 122,
#  '552106447': 185,
#  '950': 262,
#  'เคลียสตอคไม่มีประกัน': 881,
#  'caviar': 312,
#  '280354579': 105,
#  '453591358': 156,
#  'ไม่มีการประกัน': 957,
#  '8.0': 242,
#  'เครื่องศูนย์เคลียร์สต๊อค': 876,
#  'ตรวจจับแสงปรับความสว่างอัตโนมัติ': 691,
#  'ambient': 275,
#  'ปรับมุมมองการแสดงผลอัตโนมัติ': 726,
#  'orientation': 473,
#  '675': 216,
#  'เทคโนโลยีถ่ายภาพอัจฉริยะ': 891,
#  'ai': 273,
#  'โหมดปรับหน้าสวยอัตโนมัติ': 944,
#  'beauty': 293,
#  'โหมดเปลี่ยนภาพเซลฟี่เป็นอิโมจิ': 946,
#  'ar': 283,
#  'emoji': 347,
#  'โหมดเปลี่ยนภาพเซลฟี่เป็นสติกเกอร์': 945,
#  'sticker': 553,
#  '4500': 155,
#  '595150747': 194,
#  '1117932783': 26,
#  'จอคุณภาพสูง': 659,
#  'samoled': 523,
#  'หลังความละเอียดเท่ากัน': 857,
#  'มาพร้อม': 752,
#  'step': 551,
#  'lighting': 428,
#  'ช่วยปรับแสงได้': 673,
#  'ระดับ': 769,
#  'รูรับแสงกว้าง': 801,
#  'ถ่ายสนุกด้วยโหมดเซลฟี่หน้าชัดหลังละลาและเซลฟี่สติ๊กเกอร์': 700,
#  'ที่มีแบบให้เลือกมากกว่า': 704,
#  'app': 281,
#  'pair': 480,
#  'สามารถเปิด': 821,
#  'แอพที่ชอบได้พร้อมกัน': 933,
#  'หน้าจอในคลิ๊กเดียว': 855,
#  'แชทได้พร้อมกัน': 911,
#  'บัญชีในเครื่องเดียว': 712,
#  'แอพ': 932,
#  'social': 546,
#  'เยอะที่สุดถึง': 903,
#  '264741378': 100,
#  '411062149': 148,
#  '605': 207,
#  'ds': 338,
#  '262.0': 97,
#  'original': 474,
#  'new': 457,
#  'packaging': 479,
#  'undamaged': 584,
#  'unopened': 587,
#  'unused': 589,
#  'item': 413,
#  'found': 366,
#  'retail': 518,
#  'store': 555,
#  'unless': 586,
#  'handmade': 398,
#  'packaged': 478,
#  'manufacturer': 437,
#  'unprinted': 588,
#  'box': 302,
#  'plastic': 492,
#  'bag': 289,
#  '617108827': 210,
#  '1172618764': 30,
#  'สนุกทุกประสบการณ์กับหน้าจอใหญ่ที่เต็มตากว่าเดิม': 810,
#  'ด้านหลังเรียบเงา': 689,
#  'ใช้งานได้ถนัดมือ': 948,
#  'เด่นทุกมุมมองด้วยกล้องสามเลนส์': 887,
#  '511068392': 175,
#  '907938105': 259,
#  'refurbish': 515,
#  'หน้าจอใหญ่': 856,
#  '5.6': 170,
#  'สัดส่วน': 820,
#  '18.5': 59,
#  'ชิพเซต': 670,
#  'แอนดรอยด์': 931,
#  '7.1': 222,
#  'nougat': 464,
#  'กล้องถ่ายภาพ': 624,
#  'แบบคู่': 923,
#  'live': 430,
#  'ปรับฉากหลังละลายได้': 725,
#  'ปลดล็อคหน้าจอด้วยการสแกนใบหน้า': 728,
#  'การใช้งาน': 637,
#  'secure': 529,
#  'folder': 365,
#  'การสแกนลายนิ้วมือ': 633,
#  'จ่ายเงินผ่าน': 665,
#  'pay': 482,
#  'ตัวเครื่องกันน้ำลึก': 696,
#  'เมตรนาน': 902,
#  'นาที': 705,
#  '207916690': 79,
#  '313021622': 123,
#  '4100': 147,
#  '289426638': 108,
#  '479560515': 161,
#  '139': 38,
#  'เครื่องศูนย์ประกันมีเดือน': 875,
#  'สีทอง': 825,
#  'ฟิลม์กระจก': 745,
#  'os': 475,
#  'qualco': 507,
#  'slide': 536,
#  'ความพร้อมให้บริการอาจแตกต่างกันไปในแต่ละประเทศ': 645,
#  'ภาพต่าง': 746,
#  'จำลองขึ้นมาเพื่อจุดประสงค์ด้านการนำเสนอเท่านั้น': 663,
#  '289402378': 107,
#  '479508064': 159,
#  'xiaomi': 611,
#  'redmi': 514,
#  'สมาร์ตโฟน': 814,
#  'จอกว้าง': 658,
#  '665': 215,
#  '4299.00': 151,
#  '4999.00': 166,
#  'เครื่องเกาหลี': 877,
#  'นำเข้า': 707,
#  '6999.00': 219,
#  '39': 137,
#  'wireless': 606,
#  'pack': 477,
#  '10000': 13,
#  'พาวเวอร์แบงค์': 742,
#  'สำรอง': 823,
#  '19': 63,
#  '845': 248,
#  'เครื่องนอกไม่มีประกัน': 873,
#  '18880.00': 62,
#  '31900.00': 124,
#  'aura': 286,
#  '24280.00': 89,
#  '29500.00': 111,
#  'glow': 383,
#  '6290.00': 211,
#  '7990.00': 240,
#  '5250.00': 178,
#  '6490.00': 213,
#  'prime': 501,
#  '1690.00': 56,
#  '10.5': 10,
#  '13990.00': 39,
#  '19230.00': 67,
#  '23500.00': 85,
#  '1.3': 3,
#  '46': 157,
#  '8590.00': 251,
#  '12900.00': 36,
#  '33': 126,
#  'sealed': 526,
#  'year': 615,
#  'thailand': 568,
#  'warranty': 598,
#  'days': 327,
#  'return': 519,
#  'interested': 409,
#  'serious': 531,
#  'buyers': 307,
#  'contact': 318,
#  'line': 429,
#  'making': 436,
#  'payment': 483,
#  'username': 591,
#  'flashsale': 363,
#  'ใหม่เอี่ยม': 951,
#  'ต้นฉบับ': 697,
#  'ปิดผนึกในกล่อง': 730,
#  'รับประกันประเทศไทย': 793,
#  'ปีและส่งคืน': 733,
#  'ผู้ซื้อที่สนใจและจริงจังควรติดต่อฉันที่ไลน์ก่อนชำระเงิน': 734,
#  'ชื่อผู้ใช้คือ': 671,
#  'xe': 610,
#  'ym': 616,
#  't': 559,
#  'nc': 455,
#  'hb': 399,
#  'pid': 489,
#  'hn': 403,
#  'k': 416,
#  'kl': 419,
#  'xng': 613,
#  'r': 508,
#  'bprak': 303,
#  'prathe': 500,
#  'l': 420,
#  'ng': 459,
#  'kh': 417,
#  'cringc': 325,
#  'khwr': 418,
#  'tidt': 569,
#  'xn': 612,
#  'ch': 314,
#  'ra': 509,
#  'ngein': 460,
#  '612014873': 208,
#  '1155486191': 28}

# %%
# จะแบ่ง train test split ข้อมูล แล้วเอาไป fit กับ bag of words ที่สร้างไว้ เพื่อแปลงเป็นตัวเลขก่อนเอาไปเข้าโมเดล
# https://realpython.com/python-keras-text-classification/

# %%
# Save to csv file (label)
#pd.DataFrame.from_dict(label,orient='index').transpose().to_csv('./Data/536-585-label.csv')

# %%
# Save to csv file (word)
#pd.DataFrame.from_dict(groupProduct,orient='index').transpose().to_csv('./Data/536-585-processed.csv')
